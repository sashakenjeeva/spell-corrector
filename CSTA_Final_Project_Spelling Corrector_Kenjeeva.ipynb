# %% [markdown]
# **Project by**: Sasha (Alexandra) Kenjeeva <br>
# **Date of submission**: 08/02/2021

# %% [markdown]
# # A context-sensitive, one-edit distance spelling corrector

# %% [markdown]
# In my project I develop a spelling corrector. Spelling correctors are now at an advanced stage: they are online (suggest word as you write it), and they also take into account the user's individual preferences. My project takes a step back, to the origins so to say, and focuses on the basic, behind-the-stage word correction process.
#
# The project unfolds in several stages, from word-level correction to integrating context in the correction. Thus, the program starts by analysing the specific permutations that occur when mistyping a word, then gives a weighted candidate selection for typos, and finally selects the best based on the latter combined with the the word before and after (**bigram language model**). Throughout the report, I explain every step and the logic behind it.
#
# The main idea behind this project is the so-called **noisy channel model**: the idea that a correct word has been put through a noisy channel that modified it ([Jurafsky and Martin, 2020](https://web.stanford.edu/~jurafsky/slp3/3.pdf)). Through the probability of a specific 'noise' (i.e., the probability of specific characters being mistyped as other characters), we'll get the intended word with highest probability. Then, we'll have to also integrate the absolute probability of a word occurring in a corpus (**unigram**) and of it occurring with the words around (**bigrams**).
#
# So, ultimately my spelling corrector should be able to do this:
#
# *\"I **walke** to the **suprmarket** **tody**\"* --> *\"I **walked** to the **supermarket** **today**\"*

# %% [markdown]
# ## Step 1: Deletion, insertion, transposition, substitution computations
#
# When a word is misspelled, there are several systematic ways in which it can be misspelled. Below, from [Jurafsky & Martin (2020)](https://web.stanford.edu/~jurafsky/slp3/B.pdf), we can see, for instance, all the possible corrections of the word *acress*. The 4 types of errors are:
#
# - **deletion**: one letter is deleted
# - **insertion**: one letter is inserted
# - **transposition**: two letters are interchanged
# - **substitution**: one letter is substituted by another letter
#
# This specific collection of errors is called **Damerau-Levenshtein edit distance** (Jurafsky and Martin, 2020).
#
# In this step, I will proceed in developing functions for all 4 types of errors, which will give me all the variants of the input when the deletion, insertion, transposition, or substitution function has been applied. I assume that the mispellings have only an **edit distance of 1**, meaning that only one letter is mistakenly deleted/inserted/substituted or only one pair of letters is transposed. Of course, more developed models consider the possibility of a bigger edit distance, but I am going to assume an almost-perfect user who only mispells occasionally, and not severely.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 1.1: Deletion
#
# Give all the versions of the word without one letter in it.

# %%
def deletion(word):
    """A function that takes a string and returns a list of 
    strings with a removed character from that string"""
    l_delete = [] #empty list to populate
    for i in range(len(word)): #indexing
        modified_word = word[:i] + word[i:][1:] #e.g., hello, i = 0 --> "" + "ello" = "ello"
        l_delete.append(modified_word) #append the modified version
    return list(set(l_delete)) #return the set, since some words may be repeated

# %%
deletion("actress") #try it out
# Out:
# ['acress', 'actres', 'atress', 'actess', 'ctress', 'actrss']

# %% [markdown]
# ### Step 1.2: Insertion
#
# Here, again, I make a basic function, assuming that the insertions are letters, not signs.

# %%
def insertion(word):
    """Function that takes a string and gives a list of strings, 
    for each of which one letter is inserted between a pair of letters of the original string"""
    l_insert = []
    letters = 'abcdefghijklmnopqrstuvwxyz'#we need letters to insert
    for i in range(len(word)+1): #indexing at length of the word+1 to allow for insertion after the end of the word
        for letter in letters: #for loop to access each letter in the alphabet
            modified_word = word[:i] + letter + word[i:] #insert letter in between word until i and word from i on
            l_insert.append(modified_word) #append modified word
    return list(set(l_insert)) #return list

# %%
insertion("hello") #e.g., actress would be correct
# Out:
# ['bhello',
#  'hellof',
#  'helloj',
#  'heollo',
#  'xhello',
#  'hellto',
#  'helleo',
#  'hellog',
#  'hellon',
#  'vhello',
#  'hxello',
#  'helplo',
#  'helolo',
#  'hewllo',
#  'heldlo',
#  'hecllo',
#  'helslo',
#  'hellwo',
#  'helxlo',
#  'helljo',
#  'helloi',
#  'helloz',
#  'hellho',
#  'hsello',
#  'hellor',
#  'helllo',
#  'helldo',
#  'hesllo',
#  'helnlo',
#  'helluo',
#  'hehllo',
#  'hefllo',
#  'hzello',
#  'hmello',
#  'helloo',
#  'heyllo',
#  'hellod',
#  'hemllo',
#  'helclo',
#  'helglo',
#  'hellio',
#  'heillo',
#  'hepllo',
#  'hellmo',
#  'henllo',
#  'helloe',
#  'hellgo',
#  'lhello',
#  'hegllo',
#  'hwello',
#  'hexllo',
#  'khello',
#  'hellbo',
#  'hrello',
#  'fhello',
#  'hellot',
#  'hpello',
#  'helulo',
#  'hellro',
#  'hellxo',
#  'hellop',
#  'chello',
#  'nhello',
#  'helilo',
#  'hvello',
#  'hedllo',
#  'qhello',
#  'hlello',
#  'helalo',
#  'heullo',
#  'hhello',
#  'helrlo',
#  'hellom',
#  'hdello',
#  'ohello',
#  'hqello',
#  'hellno',
#  'dhello',
#  'heljlo',
#  'hellyo',
#  'helloh',
#  'ahello',
#  'heello',
#  'mhello',
#  'helzlo',
#  'uhello',
#  'hfello',
#  'haello',
#  'hebllo',
#  'hellou',
#  'helloq',
#  'ghello',
#  'helwlo',
#  'heltlo',
#  'herllo',
#  'hellow',
#  'heqllo',
#  'hellos',
#  'zhello',
#  'helloc',
#  'phello',
#  'hellko',
#  'helelo',
#  'hbello',
#  'hiello',
#  'thello',
#  'hellox',
#  'helblo',
#  'helqlo',
#  'helflo',
#  'hellzo',
#  'hellol',
#  'hellqo',
#  'hcello',
#  'helklo',
#  'hkello',
#  'helloy',
#  'hyello',
#  'hellob',
#  'hellco',
#  'hetllo',
#  'helmlo',
#  'hnello',
#  'yhello',
#  'helvlo',
#  'hjello',
#  'helylo',
#  'hellvo',
#  'hellok',
#  'hgello',
#  'hekllo',
#  'shello',
#  'hejllo',
#  'ihello',
#  'hellao',
#  'htello',
#  'hellfo',
#  'hoello',
#  'huello',
#  'hellso',
#  'ehello',
#  'helhlo',
#  'hellpo',
#  'hevllo',
#  'hellov',
#  'helloa',
#  'hezllo',
#  'rhello',
#  'jhello',
#  'whello',
#  'heallo']

# %% [markdown]
# ### Step 1.3: Transposition
#
# Word with a pair of letters swapped.

# %%
def transposition(word):
    """Function that takes a string and returns a list of
    strings where two characters have been exchanged"""
    l_transpose = [] #empty list
    list_char = [x for x in word] #we need a list here in order to exchange letters, since strings are immutable
    for i in range(len(list_char)-1): #length-1 because later we will index at i+1, so we need to stop one before the end of the word
        list_char[i], list_char[i+1] = list_char[i+1], list_char[i] #swap characters by exchanging them in the list
        modified_word = ''.join(list_char) #convert the list into a string
        l_transpose.append(modified_word) #append the modified_word to the list
        list_char = [x for x in word] #reset list
    return list(set(l_transpose))

# %%
transposition("hello") #trying it out
# Out:
# ['helol', 'ehllo', 'hello', 'hlelo']

# %%
transposition("elevator") #trying it out with a longer word
# Out:
# ['elevtaor',
#  'elveator',
#  'elevatro',
#  'leevator',
#  'eleavtor',
#  'eelvator',
#  'elevaotr']

# %% [markdown]
# ### Step 1.4: Substitution
#
# Word with one letter substituted by another.

# %%
def substitution(word):
    """A function that takes a string and returns a list of candidates
    where one letter has been exchanged for another letter of the alphabet"""
    letters = 'abcdefghijklmnopqrstuvwxyz'
    l_substitute = []
    list_char = [x for x in word] #convert string into list so it can be modified
    for i in range(len(list_char)): #indexing with just the length of the list
        for letter in letters:
            list_char[i] = letter #swap characters
            modified_word = ''.join(list_char) #convert list into string
            l_substitute.append(modified_word) #append modified word
            list_char = [x for x in word] #reset list
    return l_substitute

# %%
substitution("hjllo")
# Out:
# ['ajllo',
#  'bjllo',
#  'cjllo',
#  'djllo',
#  'ejllo',
#  'fjllo',
#  'gjllo',
#  'hjllo',
#  'ijllo',
#  'jjllo',
#  'kjllo',
#  'ljllo',
#  'mjllo',
#  'njllo',
#  'ojllo',
#  'pjllo',
#  'qjllo',
#  'rjllo',
#  'sjllo',
#  'tjllo',
#  'ujllo',
#  'vjllo',
#  'wjllo',
#  'xjllo',
#  'yjllo',
#  'zjllo',
#  'hallo',
#  'hbllo',
#  'hcllo',
#  'hdllo',
#  'hello',
#  'hfllo',
#  'hgllo',
#  'hhllo',
#  'hillo',
#  'hjllo',
#  'hkllo',
#  'hlllo',
#  'hmllo',
#  'hnllo',
#  'hollo',
#  'hpllo',
#  'hqllo',
#  'hrllo',
#  'hsllo',
#  'htllo',
#  'hullo',
#  'hvllo',
#  'hwllo',
#  'hxllo',
#  'hyllo',
#  'hzllo',
#  'hjalo',
#  'hjblo',
#  'hjclo',
#  'hjdlo',
#  'hjelo',
#  'hjflo',
#  'hjglo',
#  'hjhlo',
#  'hjilo',
#  'hjjlo',
#  'hjklo',
#  'hjllo',
#  'hjmlo',
#  'hjnlo',
#  'hjolo',
#  'hjplo',
#  'hjqlo',
#  'hjrlo',
#  'hjslo',
#  'hjtlo',
#  'hjulo',
#  'hjvlo',
#  'hjwlo',
#  'hjxlo',
#  'hjylo',
#  'hjzlo',
#  'hjlao',
#  'hjlbo',
#  'hjlco',
#  'hjldo',
#  'hjleo',
#  'hjlfo',
#  'hjlgo',
#  'hjlho',
#  'hjlio',
#  'hjljo',
#  'hjlko',
#  'hjllo',
#  'hjlmo',
#  'hjlno',
#  'hjloo',
#  'hjlpo',
#  'hjlqo',
#  'hjlro',
#  'hjlso',
#  'hjlto',
#  'hjluo',
#  'hjlvo',
#  'hjlwo',
#  'hjlxo',
#  'hjlyo',
#  'hjlzo',
#  'hjlla',
#  'hjllb',
#  'hjllc',
#  'hjlld',
#  'hjlle',
#  'hjllf',
#  'hjllg',
#  'hjllh',
#  'hjlli',
#  'hjllj',
#  'hjllk',
#  'hjlll',
#  'hjllm',
#  'hjlln',
#  'hjllo',
#  'hjllp',
#  'hjllq',
#  'hjllr',
#  'hjlls',
#  'hjllt',
#  'hjllu',
#  'hjllv',
#  'hjllw',
#  'hjllx',
#  'hjlly',
#  'hjllz']

# %% [markdown]
# ### Step 1.5: Unifying the functions to give rise to a confusion set
#
# Here, I created a function that unifies my functions. This will be needed later in order to select those words that are real words in English.

# %%
def set_confusion(word):
    """Function that takes a string and returns a set of edits of that word"""
    s_c = list(set(substitution(word) + insertion(word) + transposition(word) + deletion(word))) #we input the word to each of our functions and take the set of that list
    return s_c

# %%
set_confusion("acress")
# Out:
# ['acreqs',
#  'acremss',
#  'aocress',
#  'asress',
#  'acrejs',
#  'acrvss',
#  'acrwess',
#  'agcress',
#  'acrness',
#  'agress',
#  'adcress',
#  'acuess',
#  'ecress',
#  'acless',
#  'acresos',
#  'acbress',
#  'ascress',
#  'acrmess',
#  'acrsss',
#  'acrkess',
#  'acrpess',
#  'acreks',
#  'arress',
#  'acreis',
#  'acresk',
#  'uacress',
#  'atress',
#  'ccress',
#  'racress',
#  'acresh',
#  'acresg',
#  'acreszs',
#  'across',
#  'acruss',
#  'acrzss',
#  'acresi',
#  'wcress',
#  'kcress',
#  'aucress',
#  'ocress',
#  'acresus',
#  'tcress',
#  'acrexs',
#  'acrxss',
#  'lcress',
#  'acrers',
#  'acrgss',
#  'akcress',
#  'aclress',
#  'acqess',
#  'acressb',
#  'aeress',
#  'acess',
#  'afcress',
#  'acregs',
#  'acrems',
#  'acrbess',
#  'acrtess',
#  'ackress',
#  'axress',
#  'acrehs',
#  'acyress',
#  'avcress',
#  'vacress',
#  'acrlss',
#  'mcress',
#  'acrecs',
#  'acriss',
#  'caress',
#  'access',
#  'acreas',
#  'abcress',
#  'acressd',
#  'acsess',
#  'acrescs',
#  'acrehss',
#  'acresvs',
#  'acresds',
#  'zacress',
#  'acresc',
#  'acresj',
#  'adress',
#  'acresd',
#  'bacress',
#  'acrefss',
#  'ackess',
#  'acrezs',
#  'acressi',
#  'awress',
#  'acresse',
#  'acressv',
#  'acriess',
#  'acreoss',
#  'acresfs',
#  'acressc',
#  'acresx',
#  'lacress',
#  'acressh',
#  'acwess',
#  'vcress',
#  'azcress',
#  'nacress',
#  'acrels',
#  'acrebs',
#  'acressp',
#  'acresps',
#  'acdess',
#  'ayress',
#  'awcress',
#  'acredss',
#  'acreps',
#  'aycress',
#  'oacress',
#  'acrcss',
#  'icress',
#  'acmess',
#  'acrejss',
#  'dacress',
#  'acrsess',
#  'acresm',
#  'acaress',
#  'acresms',
#  'ajcress',
#  'acraess',
#  'acrevss',
#  'atcress',
#  'acreso',
#  'acres',
#  'gacress',
#  'acrhss',
#  'aaress',
#  'acresas',
#  'acruess',
#  'anress',
#  'acnress',
#  'acrcess',
#  'acressn',
#  'acerss',
#  'ycress',
#  'acfess',
#  'acrests',
#  'dcress',
#  'cacress',
#  'acresa',
#  'qcress',
#  'aczress',
#  'pcress',
#  'acresss',
#  'avress',
#  'acressq',
#  'ancress',
#  'acrnss',
#  'aress',
#  'acuress',
#  'jcress',
#  'acrjss',
#  'acretss',
#  'scress',
#  'acreus',
#  'xacress',
#  'yacress',
#  'actress',
#  'acvress',
#  'acoress',
#  'acroess',
#  'acresjs',
#  'actess',
#  'acressy',
#  'jacress',
#  'acrass',
#  'acresso',
#  'acrpss',
#  'amcress',
#  'aqcress',
#  'zcress',
#  'acrees',
#  'facress',
#  'arcress',
#  'acresf',
#  'acrhess',
#  'acresq',
#  'alress',
#  'acrdess',
#  'acrezss',
#  'acoess',
#  'acxess',
#  'acreshs',
#  'acrets',
#  'acreses',
#  'auress',
#  'acrexss',
#  'acbess',
#  'acresws',
#  'acmress',
#  'acreess',
#  'acressg',
#  'acrese',
#  'acrress',
#  'acrvess',
#  'acresxs',
#  'acaess',
#  'ajress',
#  'acressm',
#  'acresqs',
#  'acrkss',
#  'acreyss',
#  'achess',
#  'acrxess',
#  'ahcress',
#  'acressr',
#  'acresy',
#  'akress',
#  'ahress',
#  'acpress',
#  'acresks',
#  'acressu',
#  'acrest',
#  'acrzess',
#  'aciess',
#  'acressf',
#  'apress',
#  'fcress',
#  'abress',
#  'bcress',
#  'acress',
#  'accress',
#  'aicress',
#  'acfress',
#  'cress',
#  'tacress',
#  'acresgs',
#  'aqress',
#  'acresis',
#  'macress',
#  'acressa',
#  'acreds',
#  'acressz',
#  'acressx',
#  'acresr',
#  'acresns',
#  'acregss',
#  'afress',
#  'rcress',
#  'acrerss',
#  'airess',
#  'acresb',
#  'acressj',
#  'aoress',
#  'acrjess',
#  'xcress',
#  'acrelss',
#  'acrepss',
#  'acrens',
#  'wacress',
#  'acreiss',
#  'acresp',
#  'sacress',
#  'acresw',
#  'acreos',
#  'acdress',
#  'acresst',
#  'acqress',
#  'acrless',
#  'acreass',
#  'hcress',
#  'acgress',
#  'acresbs',
#  'acrews',
#  'acresn',
#  'aacress',
#  'acxress',
#  'acrenss',
#  'acryess',
#  'acgess',
#  'acressk',
#  'acpess',
#  'aecress',
#  'acness',
#  'acwress',
#  'acresl',
#  'acresz',
#  'alcress',
#  'eacress',
#  'acressw',
#  'acresv',
#  'acrses',
#  'acresrs',
#  'acressl',
#  'aciress',
#  'acrecss',
#  'iacress',
#  'acrwss',
#  'acsress',
#  'qacress',
#  'acrefs',
#  'acrfess',
#  'acryss',
#  'aceess',
#  'acrdss',
#  'hacress',
#  'apcress',
#  'acresu',
#  'acrss',
#  'acrekss',
#  'acyess',
#  'acrbss',
#  'kacress',
#  'acresls',
#  'acrebss',
#  'acrqess',
#  'acreys',
#  'acvess',
#  'achress',
#  'ncress',
#  'acjess',
#  'acresys',
#  'aczess',
#  'acreqss',
#  'acrtss',
#  'azress',
#  'acrmss',
#  'aceress',
#  'amress',
#  'acrrss',
#  'acrevs',
#  'arcess',
#  'acrgess',
#  'ucress',
#  'acrfss',
#  'acrewss',
#  'acjress',
#  'pacress',
#  'acreuss',
#  'acrqss',
#  'gcress',
#  'axcress']

# %% [markdown]
# ## Step 2: Possible candidates
#
# After having defined the functions, we need a way to further restrict the set of candidates to those candidates that are in the **English lexicon**. In order to do that, I first used the lexical resource called *words* from nltk. It is not a corpus, in the sense that it does not give frequencies (we don't need them yet), but it is able to check whether a word is in the English language or not.

# %% [markdown]
# ### Step 2.1: Importing the lexical resource

# %%
import nltk
nltk.download('words')
from nltk.corpus import words
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/sashakenjeeva/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
vocab = set([x.lower() for x in words.words()]) #making a set so it is more efficient

# %%
"hello" in vocab #checking
# Out:
# True

# %%
"amazing" in vocab
# Out:
# True

# %%
"chairs" in vocab #bad that it doesn't recognise plurals
# Out:
# False

# %% [markdown]
# ### Step 2.2: How good is the lexical resource?
#
# Since making a set of possible words needs to include an algorithm that detects real words reliably, I wanted to see how many words the lexical resource would recognise. In order to do that, I used a random module.

# %%
pip install random-word
# Out:
# Requirement already satisfied: random-word in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (1.0.4)
# Requirement already satisfied: nose in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from random-word) (1.3.7)
# Requirement already satisfied: requests in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from random-word) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade random-word
# Out:
# Collecting random-word
#   Downloading https://files.pythonhosted.org/packages/98/23/52384ce3bb48719cfb2290ff4211144568926a6ecea6736327df128b7d5c/Random_Word-1.0.5-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from random-word) (2.22.0)
# Requirement already satisfied, skipping upgrade: nose in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from random-word) (1.3.7)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (1.24.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/sashakenjeeva/anaconda3/lib/python3.7/site-packages (from requests->random-word) (2019.6.16)
# Installing collected packages: random-word
#   Found existing installation: Random-Word 1.0.4
#     Uninstalling Random-Word-1.0.4:
#       Successfully uninstalled Random-Word-1.0.4
# Successfully installed random-word-1.0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from random_word import RandomWords
r = RandomWords()

# %%
random_w = r.get_random_word()
random_w
# Out:
# 'solfatara'

# %%
random_w in vocab
# Out:
# False

# %%
list_rand = [x.lower() for x in r.get_random_words(minCorpusCount=1000)] #put the minimum corpus count to 1000 so that they are not super obscure, unused words
list_rand
# Out:
# ['songs',
#  'shekel',
#  'readiest',
#  'clopidogrel',
#  'boded',
#  'malignity',
#  'naira',
#  'impiety',
#  'igniting',
#  'determinant',
#  'speyer',
#  'dingo',
#  'bovine',
#  'falsehoods',
#  'self-devotion',
#  'accrues',
#  'waken',
#  'husbandmen',
#  'underside',
#  'maneuverable',
#  'fashionably',
#  'vivian',
#  'toenails',
#  'journeymen',
#  'ingredients',
#  'network',
#  'fooled',
#  'forfeited',
#  'lahti',
#  'succumbing',
#  'meadow',
#  'messes',
#  'collected',
#  'morasses',
#  'intoning',
#  'nostalgic',
#  'mallards',
#  'dunedin',
#  'desecration',
#  'clothe',
#  'daily',
#  'grizzly',
#  'fair-minded',
#  'restriction',
#  'advertiser',
#  'riveted',
#  'incitement',
#  'groceries',
#  'sepia',
#  'inauguration']

# %%
def vocab_checker(rand_list, lexicon):
    d = {}
    for word in rand_list:
        is_word = word in lexicon
        d[word] = str(is_word)
    return d

# %%
vocab_checker(list_rand, vocab)
# Out:
# {'songs': 'False',
#  'shekel': 'True',
#  'readiest': 'False',
#  'clopidogrel': 'False',
#  'boded': 'False',
#  'malignity': 'True',
#  'naira': 'False',
#  'impiety': 'True',
#  'igniting': 'False',
#  'determinant': 'True',
#  'speyer': 'False',
#  'dingo': 'True',
#  'bovine': 'True',
#  'falsehoods': 'False',
#  'self-devotion': 'False',
#  'accrues': 'False',
#  'waken': 'True',
#  'husbandmen': 'False',
#  'underside': 'True',
#  'maneuverable': 'True',
#  'fashionably': 'True',
#  'vivian': 'False',
#  'toenails': 'False',
#  'journeymen': 'False',
#  'ingredients': 'False',
#  'network': 'True',
#  'fooled': 'False',
#  'forfeited': 'False',
#  'lahti': 'False',
#  'succumbing': 'False',
#  'meadow': 'True',
#  'messes': 'False',
#  'collected': 'True',
#  'morasses': 'False',
#  'intoning': 'False',
#  'nostalgic': 'True',
#  'mallards': 'False',
#  'dunedin': 'False',
#  'desecration': 'True',
#  'clothe': 'True',
#  'daily': 'True',
#  'grizzly': 'True',
#  'fair-minded': 'False',
#  'restriction': 'True',
#  'advertiser': 'True',
#  'riveted': 'False',
#  'incitement': 'True',
#  'groceries': 'False',
#  'sepia': 'True',
#  'inauguration': 'True'}

# %%
def percent_correct(rand_list, lexicon):
    """Function that takes a random list and lexicon, and returns the percentage of correctly recognised
    words in the random list by the lexicon"""
    count = 0
    for value in vocab_checker(rand_list, lexicon).values():
        if value == "True":
            count += 1
    perc = (count*100)/(len(vocab_checker(rand_list, lexicon)))
    txt = "the lexicon recognises " + str(perc) + "% of the random words list"
    return txt

# %%
percent_correct(list_rand, vocab)
# Out:
# 'the lexicon recognises 46.0% of the random words list'

# %% [markdown]
# ### Step 2.3: Adding lexicon and checking if string is a word in English
#
# Since the performance above was not great (less than 50%), I imported another corpus, the [big.txt](http://norvig.com/big.txt) one from Norvig. Performance was around the same, but together -- best of all. I therefore combined the two as my English word lexicon.

# %%
from nltk import word_tokenize

# %%
with open ("/Users/sashakenjeeva/Desktop/Sasha/Masters/Trento/Fall 2020/Computational Skills for Text Analysis/Coding/Project/big.txt", "r") as big:
    read_big = big.read()
    big_txt = [word.lower() for word in word_tokenize(read_big)] #not too big of a problem if it's not cleaned, since we just need to check the presence of words

# %%
set_big_txt = set(big_txt) #more efficient

# %%
"chairs" in set_big_txt #plural is there
# Out:
# True

# %%
percent_correct(list_rand, set_big_txt)
# Out:
# 'the lexicon recognises 44.0% of the random words list'

# %%
lexicon_comb = set(list(vocab)+list(set_big_txt)) #combining

# %%
percent_correct(list_rand, lexicon_comb)
# Out:
# 'the lexicon recognises 62.0% of the random words list'

# %% [markdown]
# Went up! Let's try another random list.

# %%
list_rand_2 = [x.lower() for x in r.get_random_words(minCorpusCount=1000)]
list_rand_2
# Out:
# ['rehoboam',
#  'tuneful',
#  'almost',
#  'treasurer',
#  'mountains',
#  'looking-glass',
#  'cloudless',
#  'disadvantaged',
#  'metaphorical',
#  'heartless',
#  'protestation',
#  'tautology',
#  'bypassing',
#  'judea',
#  'generous',
#  'inequalities',
#  'costumed',
#  'spoils',
#  'korngold',
#  'disagrees',
#  'linchpin',
#  'inches',
#  'speculating',
#  'orbital',
#  'inequality',
#  'bream',
#  'phenol',
#  'educator',
#  'castello',
#  'damming',
#  'inaccurate',
#  'advisement',
#  'biophysics',
#  'rocks',
#  'well-to-do',
#  'browning',
#  'old-school',
#  'alarmed',
#  'access',
#  'takers',
#  'fifths',
#  'inaptly',
#  'surfeit',
#  'wished-for',
#  'day-long',
#  'drinker',
#  'spirituals',
#  'repayment',
#  'rallying',
#  'fistfight']

# %%
percent_correct(list_rand_2, set_big_txt)
# Out:
# 'the lexicon recognises 46.0% of the random words list'

# %%
percent_correct(list_rand_2, vocab)
# Out:
# 'the lexicon recognises 50.0% of the random words list'

# %%
percent_correct(list_rand_2, lexicon_comb)
# Out:
# 'the lexicon recognises 72.0% of the random words list'

# %% [markdown]
# Even better! Hence, the function above tells us if a word is in the lexicon or not:

# %%
def english_word(word):
    if word in lexicon_comb:
        return True

# %%
english_word("wanderer") #checking
# Out:
# True

# %% [markdown]
# ### Step 2.4: a list of candidate possible words
#
# Now that we have the confusion set of a word (the 4 types of errors applied and the candidates given) and the English word checker, we can develop a function that gives us the intended English words given a typo. No probabilities yet, but an unweighted list of candidates.

# %%
def intended_possible_words(typo):
    """Function that takes a word and returns a list of possible English
    intended words"""
    list_words = []
    s_c = set_confusion(typo) #all the words that come out of the noisy channel
    for word in s_c:
        if english_word(word): #if the word is an English word
            list_words.append(word)
    if len(list_words) > 0:
        return list_words
    else:
        return []

# %%
intended_possible_words("acress")
# Out:
# ['across', 'caress', 'access', 'acres', 'actress', 'cress']

# %% [markdown]
# Let's look again at the table, my function gives all the same options: ![image.png](attachment:image.png)

# %% [markdown]
# Let's try some other words:

# %%
intended_possible_words("strng")
# Out:
# ['steng',
#  'strang',
#  'strag',
#  'sting',
#  'stong',
#  'stang',
#  'strung',
#  'stung',
#  'strong',
#  'string',
#  'strig',
#  'streng']

# %%
intended_possible_words("somthing")
# Out:
# ['something', 'southing', 'soothing']

# %%
intended_possible_words("beaity")
# Out:
# ['bepity', 'beauty']

# %% [markdown]
# ## Step 3: The noisy channel: probabilities of intended words
#
# The noisy channel model posits that in order to get the probability of a word being misspelled as another word, you have to calculate the **prior** of that word (absolute probability of a word) multiplied by the **error model** or **likelihood** (conditional probability of **a character appearing instead/before another character or other permutations**) ([Jurafsky and Martin, 2020, p. 3](https://web.stanford.edu/~jurafsky/slp3/B.pdf)). Then, an argmax function is applied, where the function with best probability has to be selected. This is the formula for the **noisy channel probability**:
#
# ![image.png](attachment:image.png)
#
# P(candidate) = P(typo_char|target_char) * P(candidate)

# %% [markdown]
# ### Step 3.1: Calculating the prior
#
# We start with the **prior**, since it is simpler to calculate (just the probability of the word occurring in a corpus). In order to do that, I first downloaded and used the Nrown corpus, a large corpus with various sources. Then, however, I realised that the big_txt might be a better option, given that it is bigger (evidence below). In this step I calculated everything for both, and chose one (suspense!) in the section below this one.

# %%
import nltk
from nltk.corpus import brown
nltk.download('universal_tagset')
tokens_pos_tuples = brown.tagged_words(tagset="universal")
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/sashakenjeeva/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %%
brown_words = [word.lower() for word, token in tokens_pos_tuples] #extract only words and lowercase them

# %%
len(brown_words)
# Out:
# 1161192

# %%
len(big_txt)
# Out:
# 1288761

# %% [markdown]
# Made a count dictionary function:

# %%
def dict_freq(corpus):
    """Function that takes a corpus in the form of a list and returns the frequency of each word"""
    d_freq = {}
    for word in corpus:
        if word not in d_freq:
            d_freq[word] = 1
        else:
            d_freq[word] += 1
    freq = {k: v for k, v in sorted(d_freq.items(), key=lambda x: x[1], reverse = True)} #sort by frequency, descending order
    return freq

freq_brown_corpus = dict_freq(brown_words)

freq_brown_corpus
# Out:
# {'the': 69971,
#  ',': 58334,
#  '.': 49346,
#  'of': 36412,
#  'and': 28853,
#  'to': 26158,
#  'a': 23195,
#  'in': 21337,
#  'that': 10594,
#  'is': 10109,
#  'was': 9815,
#  'he': 9548,
#  'for': 9489,
#  '``': 8837,
#  "''": 8789,
#  'it': 8760,
#  'with': 7289,
#  'as': 7253,
#  'his': 6996,
#  'on': 6741,
#  'be': 6377,
#  ';': 5566,
#  'at': 5372,
#  'by': 5306,
#  'i': 5164,
#  'this': 5145,
#  'had': 5133,
#  '?': 4693,
#  'not': 4610,
#  'are': 4394,
#  'but': 4381,
#  'from': 4370,
#  'or': 4206,
#  'have': 3942,
#  'an': 3740,
#  'they': 3620,
#  'which': 3561,
#  '--': 3432,
#  'one': 3292,
#  'you': 3286,
#  'were': 3284,
#  'her': 3036,
#  'all': 3001,
#  'she': 2860,
#  'there': 2728,
#  'would': 2714,
#  'their': 2669,
#  'we': 2652,
#  'him': 2619,
#  'been': 2472,
#  ')': 2466,
#  'has': 2437,
#  '(': 2435,
#  'when': 2331,
#  'who': 2252,
#  'will': 2245,
#  'more': 2215,
#  'if': 2198,
#  'no': 2139,
#  'out': 2097,
#  'so': 1985,
#  'said': 1961,
#  'what': 1908,
#  'up': 1890,
#  'its': 1858,
#  'about': 1815,
#  ':': 1795,
#  'into': 1791,
#  'than': 1790,
#  'them': 1788,
#  'can': 1772,
#  'only': 1748,
#  'other': 1702,
#  'new': 1635,
#  'some': 1618,
#  'could': 1601,
#  'time': 1598,
#  '!': 1596,
#  'these': 1573,
#  'two': 1412,
#  'may': 1402,
#  'then': 1380,
#  'do': 1363,
#  'first': 1361,
#  'any': 1344,
#  'my': 1318,
#  'now': 1314,
#  'such': 1303,
#  'like': 1292,
#  'our': 1252,
#  'over': 1236,
#  'man': 1207,
#  'me': 1181,
#  'even': 1170,
#  'most': 1159,
#  'made': 1125,
#  'also': 1069,
#  'after': 1069,
#  'did': 1044,
#  'many': 1030,
#  'before': 1016,
#  'must': 1013,
#  'af': 996,
#  'through': 971,
#  'back': 966,
#  'years': 950,
#  'where': 937,
#  'much': 937,
#  'your': 923,
#  'way': 908,
#  'well': 897,
#  'down': 895,
#  'should': 888,
#  'because': 883,
#  'each': 877,
#  'just': 872,
#  'those': 850,
#  'people': 847,
#  'mr.': 844,
#  'too': 834,
#  'how': 834,
#  'little': 831,
#  'state': 807,
#  'good': 806,
#  'very': 796,
#  'make': 794,
#  'world': 787,
#  'still': 782,
#  'see': 772,
#  'own': 772,
#  'men': 763,
#  'work': 762,
#  'long': 752,
#  'here': 750,
#  'get': 749,
#  'both': 730,
#  'between': 730,
#  'life': 715,
#  'being': 712,
#  'under': 707,
#  'never': 697,
#  'day': 687,
#  'same': 686,
#  'another': 684,
#  'know': 683,
#  'while': 680,
#  'last': 676,
#  'us': 675,
#  'might': 672,
#  'great': 665,
#  'old': 661,
#  'year': 658,
#  'off': 639,
#  'come': 630,
#  'since': 628,
#  'against': 627,
#  'go': 626,
#  'came': 622,
#  'right': 613,
#  'used': 611,
#  'take': 610,
#  'three': 610,
#  'himself': 603,
#  'states': 603,
#  'few': 601,
#  'house': 591,
#  'use': 591,
#  'during': 585,
#  'without': 583,
#  'again': 577,
#  'place': 570,
#  'american': 569,
#  'around': 562,
#  'however': 552,
#  'home': 547,
#  'small': 542,
#  'found': 536,
#  'mrs.': 534,
#  '1': 527,
#  'thought': 517,
#  'went': 507,
#  'say': 504,
#  'part': 500,
#  'once': 499,
#  'general': 498,
#  'high': 497,
#  'upon': 495,
#  'school': 493,
#  'every': 491,
#  "don't": 489,
#  'does': 485,
#  'got': 482,
#  'united': 482,
#  'left': 480,
#  'number': 472,
#  'course': 465,
#  'war': 464,
#  'until': 461,
#  'always': 458,
#  'away': 456,
#  'something': 450,
#  'fact': 447,
#  '2': 446,
#  'water': 445,
#  'though': 440,
#  'public': 438,
#  'less': 437,
#  'put': 437,
#  'think': 433,
#  'almost': 432,
#  'hand': 431,
#  'enough': 430,
#  'took': 426,
#  'far': 426,
#  'head': 424,
#  'yet': 419,
#  'government': 418,
#  'system': 416,
#  'set': 414,
#  'better': 414,
#  'told': 413,
#  'night': 411,
#  'nothing': 411,
#  'end': 409,
#  'why': 404,
#  "didn't": 401,
#  'called': 401,
#  'eyes': 401,
#  'find': 400,
#  'going': 399,
#  'look': 399,
#  'asked': 398,
#  'later': 397,
#  'knew': 395,
#  'point': 395,
#  'next': 394,
#  'program': 394,
#  'city': 393,
#  'business': 393,
#  'group': 390,
#  'give': 389,
#  'toward': 386,
#  'young': 385,
#  'let': 384,
#  'days': 384,
#  'room': 384,
#  'president': 382,
#  'side': 381,
#  'social': 380,
#  'present': 377,
#  'given': 377,
#  'several': 377,
#  'order': 376,
#  'national': 375,
#  'possible': 374,
#  'rather': 373,
#  'second': 373,
#  'face': 371,
#  'per': 371,
#  'among': 370,
#  'form': 370,
#  'often': 369,
#  'important': 369,
#  'things': 368,
#  'looked': 367,
#  'early': 366,
#  'white': 365,
#  'john': 362,
#  'case': 362,
#  'large': 361,
#  'four': 360,
#  'need': 360,
#  'big': 360,
#  'become': 359,
#  'within': 359,
#  'felt': 357,
#  'children': 355,
#  'along': 355,
#  'saw': 352,
#  'best': 351,
#  'church': 348,
#  'ever': 344,
#  'least': 343,
#  'power': 342,
#  'development': 334,
#  'seemed': 333,
#  'thing': 333,
#  'light': 333,
#  'family': 331,
#  'interest': 330,
#  'want': 328,
#  'members': 325,
#  'mind': 325,
#  'area': 324,
#  'country': 324,
#  'others': 323,
#  'although': 321,
#  'turned': 320,
#  'done': 319,
#  'open': 318,
#  "'": 317,
#  'god': 316,
#  'service': 315,
#  'problem': 313,
#  'certain': 313,
#  'kind': 313,
#  'different': 312,
#  'thus': 312,
#  'began': 312,
#  'door': 312,
#  'help': 311,
#  'sense': 311,
#  'means': 310,
#  'whole': 309,
#  'matter': 308,
#  'perhaps': 307,
#  'itself': 304,
#  'york': 302,
#  "it's": 302,
#  'times': 300,
#  'law': 299,
#  'human': 299,
#  'line': 298,
#  'above': 296,
#  'name': 294,
#  'example': 292,
#  'action': 291,
#  'company': 290,
#  'hands': 289,
#  'local': 288,
#  'show': 288,
#  '3': 287,
#  'whether': 286,
#  'five': 286,
#  'history': 286,
#  'gave': 285,
#  'today': 284,
#  'either': 284,
#  'act': 283,
#  'feet': 283,
#  'across': 282,
#  'taken': 281,
#  'past': 281,
#  'quite': 281,
#  'anything': 280,
#  'seen': 279,
#  'having': 279,
#  'death': 277,
#  'experience': 276,
#  'body': 276,
#  'week': 275,
#  'half': 275,
#  'really': 275,
#  'word': 274,
#  'field': 274,
#  'car': 274,
#  'words': 274,
#  'already': 273,
#  'themselves': 270,
#  "i'm": 269,
#  'information': 269,
#  'tell': 268,
#  'shall': 268,
#  'together': 267,
#  'college': 267,
#  'money': 265,
#  'period': 265,
#  'held': 264,
#  'keep': 264,
#  'sure': 263,
#  'probably': 261,
#  'free': 259,
#  'seems': 259,
#  'political': 258,
#  'real': 258,
#  'cannot': 258,
#  'behind': 258,
#  'question': 257,
#  'air': 257,
#  'office': 255,
#  'making': 255,
#  'brought': 253,
#  'miss': 253,
#  'whose': 251,
#  'special': 250,
#  'major': 247,
#  'heard': 247,
#  'problems': 247,
#  'federal': 246,
#  'became': 246,
#  'study': 246,
#  'ago': 246,
#  'moment': 246,
#  'available': 245,
#  'known': 245,
#  'result': 244,
#  'street': 244,
#  'economic': 243,
#  'boy': 242,
#  'position': 241,
#  'reason': 241,
#  'change': 240,
#  'south': 240,
#  'board': 239,
#  'individual': 239,
#  'job': 238,
#  'am': 237,
#  'society': 237,
#  'areas': 236,
#  'west': 235,
#  'close': 234,
#  'turn': 233,
#  'community': 231,
#  'true': 231,
#  'love': 231,
#  'court': 230,
#  'force': 230,
#  'full': 230,
#  'cost': 229,
#  'seem': 229,
#  'wife': 228,
#  'future': 227,
#  'age': 227,
#  'wanted': 226,
#  'voice': 226,
#  'department': 225,
#  'center': 224,
#  'woman': 224,
#  'control': 223,
#  'common': 223,
#  'policy': 222,
#  'necessary': 222,
#  'following': 221,
#  'front': 221,
#  'sometimes': 221,
#  'six': 220,
#  'girl': 220,
#  'clear': 219,
#  'further': 218,
#  'land': 218,
#  'provide': 216,
#  'feel': 216,
#  'party': 216,
#  'able': 216,
#  'mother': 216,
#  'music': 216,
#  'education': 214,
#  'university': 214,
#  'child': 213,
#  'effect': 213,
#  'students': 213,
#  'level': 213,
#  'run': 212,
#  'stood': 212,
#  'military': 212,
#  'town': 212,
#  'short': 212,
#  'morning': 211,
#  'total': 211,
#  'outside': 210,
#  'rate': 209,
#  'figure': 209,
#  'art': 208,
#  'century': 207,
#  'class': 207,
#  'washington': 206,
#  '4': 206,
#  'north': 206,
#  'usually': 206,
#  'plan': 205,
#  'leave': 205,
#  'therefore': 205,
#  'evidence': 204,
#  'top': 204,
#  'million': 204,
#  'sound': 204,
#  'black': 203,
#  'strong': 202,
#  'hard': 202,
#  'tax': 201,
#  'various': 201,
#  'says': 200,
#  'believe': 200,
#  'type': 200,
#  'value': 200,
#  'play': 200,
#  'surface': 200,
#  'soon': 199,
#  'mean': 199,
#  'near': 198,
#  'lines': 198,
#  'table': 198,
#  'peace': 198,
#  'modern': 198,
#  'road': 197,
#  'red': 197,
#  'book': 197,
#  'personal': 196,
#  'process': 196,
#  'situation': 196,
#  'minutes': 196,
#  'increase': 195,
#  'schools': 195,
#  'idea': 195,
#  'english': 195,
#  'alone': 195,
#  'women': 195,
#  'gone': 195,
#  'nor': 195,
#  'living': 194,
#  'america': 194,
#  'started': 194,
#  'longer': 193,
#  'dr.': 192,
#  'cut': 192,
#  'finally': 191,
#  'secretary': 191,
#  'nature': 191,
#  'private': 191,
#  'third': 190,
#  'months': 189,
#  'section': 189,
#  'greater': 188,
#  'call': 188,
#  'fire': 187,
#  'expected': 187,
#  'needed': 187,
#  "that's": 187,
#  'kept': 186,
#  'ground': 186,
#  'view': 186,
#  'values': 186,
#  'everything': 185,
#  'pressure': 185,
#  'dark': 185,
#  'basis': 184,
#  'space': 184,
#  'east': 183,
#  'father': 183,
#  'required': 182,
#  'union': 182,
#  'spirit': 182,
#  'complete': 182,
#  'except': 181,
#  'wrote': 181,
#  "i'll": 181,
#  'moved': 181,
#  'support': 180,
#  'return': 180,
#  'conditions': 180,
#  'recent': 179,
#  'attention': 179,
#  'late': 179,
#  'particular': 179,
#  'live': 177,
#  'hope': 177,
#  'costs': 176,
#  'else': 176,
#  'brown': 176,
#  'taking': 175,
#  "couldn't": 175,
#  'forces': 175,
#  'nations': 175,
#  'beyond': 175,
#  'stage': 175,
#  'read': 174,
#  'report': 174,
#  'coming': 174,
#  'hours': 174,
#  'person': 174,
#  'inside': 174,
#  'dead': 174,
#  'material': 174,
#  'instead': 173,
#  'lost': 173,
#  'heart': 173,
#  'looking': 173,
#  'low': 173,
#  'miles': 173,
#  'data': 173,
#  'added': 172,
#  'pay': 172,
#  'amount': 172,
#  'followed': 172,
#  'feeling': 172,
#  '1960': 172,
#  'single': 172,
#  'makes': 172,
#  'research': 171,
#  'including': 171,
#  'basic': 171,
#  'hundred': 171,
#  'move': 171,
#  'industry': 171,
#  'cold': 171,
#  'simply': 171,
#  'developed': 170,
#  'tried': 170,
#  'hold': 169,
#  "can't": 169,
#  'reached': 169,
#  'committee': 168,
#  'island': 167,
#  'defense': 167,
#  'equipment': 167,
#  'actually': 166,
#  'shown': 166,
#  'son': 165,
#  'central': 165,
#  'religious': 165,
#  'river': 165,
#  'getting': 164,
#  'st.': 164,
#  'beginning': 164,
#  'sort': 164,
#  'ten': 164,
#  'received': 163,
#  '&': 163,
#  'doing': 163,
#  'terms': 163,
#  'trying': 163,
#  'rest': 163,
#  'medical': 162,
#  'u.s.': 162,
#  'care': 162,
#  'especially': 162,
#  'friends': 162,
#  'picture': 162,
#  'indeed': 162,
#  'administration': 161,
#  'fine': 161,
#  'subject': 161,
#  'difficult': 161,
#  'building': 160,
#  'higher': 160,
#  'wall': 160,
#  'simple': 160,
#  'meeting': 159,
#  'walked': 159,
#  'floor': 158,
#  'foreign': 158,
#  'bring': 158,
#  'similar': 157,
#  'passed': 157,
#  'range': 157,
#  'paper': 157,
#  'property': 156,
#  'natural': 156,
#  'final': 156,
#  'training': 156,
#  'county': 155,
#  'police': 155,
#  'cent': 155,
#  'international': 155,
#  'growth': 155,
#  'market': 155,
#  "wasn't": 154,
#  'talk': 154,
#  'start': 154,
#  'england': 154,
#  'written': 154,
#  'hear': 153,
#  'suddenly': 153,
#  'story': 153,
#  'issue': 152,
#  'congress': 152,
#  'needs': 152,
#  '10': 152,
#  'answer': 152,
#  'hall': 152,
#  'likely': 151,
#  'working': 151,
#  'countries': 151,
#  'considered': 151,
#  "you're": 151,
#  'earth': 150,
#  'sat': 150,
#  'purpose': 149,
#  'meet': 149,
#  'labor': 149,
#  'results': 149,
#  'entire': 149,
#  'happened': 149,
#  'william': 148,
#  'cases': 148,
#  'stand': 148,
#  'difference': 148,
#  'production': 148,
#  'hair': 148,
#  'involved': 147,
#  'fall': 147,
#  'stock': 147,
#  'food': 147,
#  'earlier': 146,
#  'increased': 146,
#  'whom': 146,
#  'particularly': 146,
#  'paid': 145,
#  'sent': 145,
#  'effort': 145,
#  'knowledge': 145,
#  'hour': 145,
#  'letter': 145,
#  'club': 145,
#  'using': 145,
#  'below': 145,
#  'thinking': 145,
#  'yes': 144,
#  'christian': 144,
#  'blue': 143,
#  'ready': 143,
#  'bill': 143,
#  'deal': 143,
#  'points': 143,
#  'trade': 143,
#  'certainly': 143,
#  'ideas': 143,
#  'industrial': 143,
#  'square': 143,
#  'boys': 143,
#  'methods': 142,
#  'addition': 142,
#  'method': 142,
#  'bad': 142,
#  'due': 142,
#  '5': 142,
#  'girls': 142,
#  'moral': 142,
#  'decided': 141,
#  'reading': 141,
#  'statement': 141,
#  'weeks': 141,
#  'neither': 141,
#  'nearly': 141,
#  'directly': 141,
#  'showed': 141,
#  'throughout': 141,
#  'according': 140,
#  'questions': 140,
#  'color': 140,
#  'kennedy': 140,
#  'anyone': 140,
#  'try': 140,
#  'services': 139,
#  'programs': 139,
#  'nation': 139,
#  'lay': 139,
#  'french': 139,
#  'size': 138,
#  'remember': 138,
#  'physical': 138,
#  'record': 137,
#  'member': 137,
#  'comes': 137,
#  'understand': 137,
#  'southern': 137,
#  'western': 137,
#  'strength': 137,
#  'population': 136,
#  'normal': 136,
#  'merely': 135,
#  'district': 135,
#  'volume': 135,
#  'concerned': 135,
#  'appeared': 135,
#  'temperature': 135,
#  '1961': 134,
#  'aid': 134,
#  'trouble': 134,
#  'trial': 134,
#  'summer': 134,
#  'direction': 134,
#  'ran': 134,
#  'sales': 133,
#  'list': 133,
#  'continued': 133,
#  'friend': 133,
#  'evening': 133,
#  'maybe': 133,
#  'literature': 133,
#  'generally': 132,
#  'association': 132,
#  'provided': 132,
#  'led': 132,
#  'army': 132,
#  'met': 132,
#  'influence': 132,
#  'opened': 131,
#  'former': 131,
#  'science': 131,
#  'student': 131,
#  'step': 131,
#  'changes': 131,
#  'chance': 131,
#  'husband': 131,
#  'hot': 130,
#  'series': 130,
#  'average': 130,
#  'works': 130,
#  'month': 130,
#  'cause': 130,
#  'effective': 129,
#  'george': 129,
#  'planning': 129,
#  'systems': 129,
#  "wouldn't": 129,
#  'direct': 129,
#  'soviet': 129,
#  'stopped': 129,
#  'wrong': 129,
#  'lead': 129,
#  'myself': 129,
#  'piece': 129,
#  'theory': 129,
#  'ask': 128,
#  'worked': 128,
#  'freedom': 128,
#  'organization': 128,
#  'clearly': 128,
#  'movement': 128,
#  'ways': 128,
#  'press': 127,
#  'somewhat': 127,
#  'spring': 127,
#  'efforts': 127,
#  'consider': 127,
#  'meaning': 127,
#  'bed': 127,
#  'fear': 127,
#  'lot': 127,
#  'treatment': 127,
#  'beautiful': 127,
#  'note': 127,
#  'forms': 127,
#  'placed': 126,
#  'hotel': 126,
#  'truth': 126,
#  'apparently': 125,
#  'degree': 125,
#  'groups': 125,
#  "he's": 125,
#  'plant': 125,
#  'carried': 125,
#  'wide': 125,
#  "i've": 125,
#  'respect': 125,
#  "man's": 125,
#  'herself': 125,
#  'numbers': 125,
#  'manner': 124,
#  'reaction': 124,
#  'easy': 124,
#  'farm': 124,
#  'immediately': 123,
#  'running': 123,
#  'approach': 123,
#  'game': 123,
#  'recently': 123,
#  'larger': 123,
#  'lower': 123,
#  'charge': 122,
#  'couple': 122,
#  'de': 122,
#  'daily': 122,
#  'eye': 122,
#  'performance': 122,
#  'feed': 122,
#  'oh': 122,
#  'march': 121,
#  'persons': 121,
#  'understanding': 121,
#  'arms': 121,
#  'opportunity': 121,
#  'c': 121,
#  'blood': 121,
#  'additional': 120,
#  'j.': 120,
#  'technical': 120,
#  'fiscal': 120,
#  'radio': 120,
#  'described': 120,
#  'stop': 120,
#  'progress': 120,
#  'steps': 119,
#  'test': 119,
#  'chief': 119,
#  'reported': 119,
#  'served': 119,
#  'based': 119,
#  'main': 119,
#  'determined': 119,
#  'image': 119,
#  'decision': 119,
#  'window': 119,
#  'religion': 119,
#  'aj': 118,
#  'gun': 118,
#  'responsibility': 118,
#  'middle': 118,
#  'europe': 118,
#  'british': 118,
#  'character': 118,
#  'learned': 117,
#  'horse': 117,
#  'writing': 117,
#  'appear': 117,
#  's.': 117,
#  'account': 117,
#  'ones': 116,
#  'serious': 116,
#  'activity': 116,
#  'types': 116,
#  'green': 116,
#  'length': 116,
#  'lived': 115,
#  'audience': 115,
#  'letters': 115,
#  'returned': 115,
#  'obtained': 115,
#  'nuclear': 115,
#  'specific': 115,
#  'corner': 115,
#  'forward': 115,
#  'activities': 115,
#  'slowly': 115,
#  'doubt': 114,
#  '6': 114,
#  'justice': 114,
#  'moving': 114,
#  'latter': 114,
#  'gives': 114,
#  'straight': 114,
#  'hit': 114,
#  'plane': 114,
#  'quality': 114,
#  'design': 114,
#  'obviously': 114,
#  'operation': 113,
#  'plans': 113,
#  'shot': 113,
#  'seven': 113,
#  'a.': 113,
#  'choice': 113,
#  'poor': 113,
#  'staff': 113,
#  'function': 113,
#  'figures': 113,
#  'parts': 113,
#  'stay': 113,
#  'saying': 113,
#  'include': 113,
#  '15': 113,
#  'born': 113,
#  'pattern': 113,
#  '30': 112,
#  'cars': 112,
#  'whatever': 112,
#  'sun': 112,
#  'faith': 111,
#  'pool': 111,
#  'hospital': 110,
#  'corps': 110,
#  'wish': 110,
#  'lack': 110,
#  'completely': 110,
#  'heavy': 110,
#  'waiting': 110,
#  'speak': 110,
#  'ball': 110,
#  'standard': 110,
#  'extent': 110,
#  'visit': 109,
#  'democratic': 109,
#  'firm': 109,
#  'income': 109,
#  'ahead': 109,
#  'deep': 109,
#  "there's": 109,
#  'language': 109,
#  'principle': 109,
#  'none': 108,
#  'price': 108,
#  'designed': 108,
#  'indicated': 108,
#  'analysis': 108,
#  'distance': 108,
#  'expect': 108,
#  'established': 108,
#  'products': 108,
#  'effects': 108,
#  'growing': 108,
#  'importance': 108,
#  'continue': 107,
#  'serve': 107,
#  'determine': 107,
#  'cities': 107,
#  'elements': 107,
#  'negro': 107,
#  'leaders': 107,
#  'division': 107,
#  ...}

# %%
freq_big_corpus = dict_freq(big_txt)

freq_big_corpus
# Out:
# {'the': 79401,
#  ',': 77143,
#  '.': 49215,
#  'of': 40018,
#  'and': 38258,
#  'to': 28674,
#  'in': 21933,
#  'a': 21039,
#  "''": 13683,
#  'that': 12488,
#  '``': 12428,
#  'he': 12384,
#  'was': 11426,
#  'it': 10649,
#  'his': 10034,
#  'is': 9817,
#  'with': 9740,
#  'as': 8058,
#  'i': 7642,
#  'had': 7395,
#  'for': 6921,
#  'not': 6898,
#  'at': 6786,
#  'by': 6676,
#  'on': 6633,
#  'be': 6155,
#  'from': 5681,
#  'but': 5640,
#  'you': 5570,
#  '--': 5566,
#  'or': 5349,
#  'her': 5284,
#  'him': 5226,
#  "'s": 5129,
#  'which': 4840,
#  '!': 4346,
#  'were': 4297,
#  '?': 4156,
#  'all': 4124,
#  'this': 4058,
#  'she': 3939,
#  'they': 3928,
#  'are': 3646,
#  'have': 3518,
#  ';': 3512,
#  'said': 3464,
#  'an': 3418,
#  'one': 3300,
#  'who': 3044,
#  'what': 2991,
#  'their': 2956,
#  'there': 2955,
#  'so': 2955,
#  'when': 2918,
#  'been': 2600,
#  'may': 2550,
#  'if': 2367,
#  'no': 2333,
#  'up': 2251,
#  'my': 2241,
#  'them': 2241,
#  'into': 2125,
#  'do': 2027,
#  'more': 1996,
#  'would': 1979,
#  'out': 1969,
#  'pierre': 1950,
#  '...': 1946,
#  'did': 1940,
#  'prince': 1932,
#  'me': 1917,
#  'we': 1887,
#  'only': 1873,
#  ':': 1848,
#  '(': 1749,
#  ')': 1749,
#  'could': 1711,
#  'now': 1696,
#  'its': 1636,
#  'man': 1633,
#  'has': 1613,
#  'will': 1570,
#  'then': 1553,
#  'some': 1535,
#  'time': 1516,
#  'other': 1499,
#  'about': 1495,
#  'after': 1495,
#  'such': 1436,
#  'before': 1360,
#  'very': 1336,
#  'should': 1314,
#  "'": 1310,
#  'how': 1307,
#  'your': 1277,
#  'over': 1262,
#  'these': 1230,
#  "n't": 1225,
#  'than': 1207,
#  'natasha': 1205,
#  'any': 1204,
#  'those': 1201,
#  'new': 1196,
#  'andrew': 1164,
#  'first': 1160,
#  'can': 1160,
#  'himself': 1157,
#  'men': 1143,
#  'old': 1139,
#  'face': 1125,
#  'down': 1115,
#  'upon': 1112,
#  'well': 1090,
#  'two': 1079,
#  'french': 1065,
#  'our': 1062,
#  'same': 1053,
#  'know': 1048,
#  'like': 1028,
#  'without': 1014,
#  'see': 1013,
#  'went': 1009,
#  'made': 1004,
#  'little': 999,
#  'came': 980,
#  'must': 970,
#  'where': 970,
#  'under': 962,
#  'even': 946,
#  'long': 941,
#  'eyes': 935,
#  'come': 931,
#  'princess': 916,
#  'being': 915,
#  'still': 913,
#  'room': 910,
#  'most': 908,
#  'thought': 903,
#  'go': 902,
#  'states': 898,
#  'people': 882,
#  'again': 867,
#  'way': 858,
#  'life': 855,
#  'war': 846,
#  'another': 840,
#  'away': 837,
#  'left': 827,
#  'hand': 822,
#  'through': 815,
#  'began': 811,
#  'general': 802,
#  'own': 786,
#  'great': 785,
#  'day': 782,
#  'rostov': 774,
#  'while': 769,
#  'just': 768,
#  'asked': 767,
#  'army': 762,
#  'looked': 761,
#  'say': 756,
#  '#': 743,
#  'whole': 742,
#  'count': 742,
#  'back': 740,
#  'am': 739,
#  'shall': 736,
#  'also': 735,
#  'moscow': 722,
#  'head': 721,
#  'right': 708,
#  'american': 705,
#  'part': 703,
#  'mary': 701,
#  'felt': 696,
#  'seemed': 696,
#  'here': 687,
#  'something': 684,
#  'us': 682,
#  'yes': 676,
#  'having': 674,
#  'place': 673,
#  'much': 672,
#  'why': 662,
#  'against': 659,
#  'state': 656,
#  'every': 651,
#  'though': 650,
#  'house': 649,
#  'between': 648,
#  'government': 640,
#  'nothing': 639,
#  'heard': 637,
#  'nicholas': 632,
#  'off': 631,
#  'because': 630,
#  'young': 626,
#  'emperor': 620,
#  'take': 615,
#  'always': 609,
#  'many': 606,
#  'bone': 603,
#  'good': 601,
#  'saw': 599,
#  'disease': 597,
#  'napoleon': 591,
#  'never': 589,
#  'took': 574,
#  'years': 569,
#  'once': 569,
#  'look': 566,
#  'last': 564,
#  'think': 558,
#  'united': 558,
#  'found': 549,
#  'too': 548,
#  'met': 545,
#  'round': 544,
#  'skin': 543,
#  'power': 541,
#  'might': 537,
#  'tissue': 535,
#  'both': 530,
#  'three': 530,
#  'usually': 530,
#  'give': 524,
#  'small': 523,
#  'kutuzov': 517,
#  'father': 515,
#  'let': 506,
#  'form': 504,
#  'side': 504,
#  'during': 504,
#  'make': 502,
#  'quite': 500,
#  'turned': 499,
#  'knew': 497,
#  'suddenly': 496,
#  'countess': 495,
#  'door': 494,
#  'told': 490,
#  'whom': 490,
#  'yet': 489,
#  'tell': 488,
#  'already': 488,
#  'moment': 486,
#  'love': 482,
#  'large': 480,
#  'holmes': 468,
#  'get': 468,
#  'chapter': 465,
#  'voice': 463,
#  'russian': 460,
#  'few': 459,
#  'words': 459,
#  'officer': 459,
#  'end': 457,
#  'hands': 454,
#  'cases': 453,
#  'blood': 453,
#  'among': 452,
#  'days': 452,
#  'looking': 451,
#  'everything': 451,
#  'seen': 445,
#  'dear': 444,
#  'often': 444,
#  'gave': 443,
#  'sonya': 443,
#  'battle': 440,
#  'taken': 439,
#  '[': 436,
#  ']': 436,
#  'congress': 435,
#  'position': 433,
#  'put': 433,
#  'case': 431,
#  'however': 431,
#  'done': 429,
#  'smile': 426,
#  'sometimes': 426,
#  'soon': 422,
#  'country': 420,
#  'denisov': 419,
#  'called': 416,
#  'understand': 413,
#  'each': 412,
#  'free': 411,
#  "'ll": 411,
#  'others': 410,
#  'become': 410,
#  'soldiers': 409,
#  'brought': 407,
#  'along': 405,
#  'sat': 404,
#  'especially': 404,
#  'order': 403,
#  'behind': 402,
#  'far': 397,
#  'oh': 395,
#  'does': 394,
#  'course': 389,
#  'result': 387,
#  'stood': 384,
#  'patient': 379,
#  'anything': 379,
#  'known': 379,
#  'work': 376,
#  'evidently': 375,
#  'several': 374,
#  'cause': 373,
#  'going': 371,
#  'law': 370,
#  '=the': 370,
#  'passed': 368,
#  'less': 368,
#  'women': 368,
#  'matter': 365,
#  'wife': 364,
#  'given': 364,
#  'certain': 362,
#  'feeling': 361,
#  'front': 359,
#  'whether': 358,
#  'action': 357,
#  'infection': 355,
#  'world': 354,
#  'god': 353,
#  'night': 347,
#  'chief': 347,
#  'question': 344,
#  'mr.': 343,
#  'mind': 342,
#  'herself': 342,
#  'possible': 340,
#  'movement': 340,
#  'history': 339,
#  'alone': 338,
#  'president': 338,
#  'condition': 337,
#  'morning': 336,
#  'later': 335,
#  'son': 335,
#  'white': 334,
#  'joint': 334,
#  'toward': 332,
#  'body': 331,
#  'followed': 330,
#  'present': 328,
#  'necessary': 328,
#  '|': 328,
#  'almost': 326,
#  'until': 326,
#  'dolokhov': 326,
#  'death': 325,
#  'money': 325,
#  'ran': 323,
#  'things': 322,
#  'want': 322,
#  'expression': 322,
#  'horse': 322,
#  'replied': 321,
#  'fig': 321,
#  'troops': 320,
#  'set': 319,
#  'sent': 319,
#  'treatment': 319,
#  'woman': 318,
#  'act': 317,
#  'officers': 316,
#  'became': 315,
#  'within': 314,
#  'use': 313,
#  'business': 312,
#  'labor': 312,
#  'mother': 309,
#  'pp': 309,
#  'thing': 304,
#  'taking': 304,
#  'themselves': 304,
#  'south': 303,
#  'number': 302,
#  'leave': 301,
#  'england': 300,
#  'commander': 300,
#  'added': 299,
#  'above': 299,
#  'pain': 299,
#  'word': 298,
#  'find': 295,
#  'lay': 295,
#  'wound': 295,
#  'parts': 294,
#  'anna': 294,
#  'near': 293,
#  'either': 292,
#  'boris': 292,
#  'home': 291,
#  'open': 291,
#  'fact': 291,
#  'party': 291,
#  'tissues': 291,
#  'enemy': 290,
#  'project': 289,
#  'continued': 289,
#  'letter': 289,
#  'table': 288,
#  'held': 288,
#  'talk': 288,
#  'example': 287,
#  'illustration': 286,
#  'common': 285,
#  'year': 284,
#  'constitution': 283,
#  'carried': 282,
#  'public': 282,
#  'important': 281,
#  'friend': 281,
#  'received': 281,
#  'nor': 281,
#  'cried': 280,
#  'got': 280,
#  'entered': 279,
#  'next': 277,
#  'used': 276,
#  'surface': 276,
#  'different': 275,
#  'land': 274,
#  'itself': 273,
#  'really': 273,
#  'west': 272,
#  'around': 271,
#  'fire': 271,
#  'high': 271,
#  'second': 271,
#  'saying': 271,
#  'national': 269,
#  'nerve': 267,
#  'better': 265,
#  'petya': 265,
#  'light': 264,
#  'evening': 264,
#  'america': 264,
#  'name': 262,
#  'horses': 262,
#  'since': 261,
#  'together': 261,
#  'best': 261,
#  'british': 261,
#  'union': 261,
#  'early': 258,
#  'road': 257,
#  'political': 257,
#  'full': 257,
#  'bones': 257,
#  'ever': 256,
#  'half': 256,
#  'speak': 256,
#  'thousand': 256,
#  'shouted': 255,
#  'arm': 255,
#  'means': 254,
#  'forms': 254,
#  'cold': 253,
#  'heart': 253,
#  'sitting': 252,
#  'glands': 252,
#  'ask': 251,
#  'kept': 251,
#  'due': 250,
#  'impossible': 249,
#  'moved': 249,
#  'four': 248,
#  'petersburg': 247,
#  'arms': 246,
#  'becomes': 246,
#  'line': 245,
#  'wish': 244,
#  'vasili': 242,
#  'rose': 241,
#  'vessels': 241,
#  'force': 239,
#  'gone': 238,
#  'conditions': 238,
#  'five': 234,
#  'rise': 234,
#  'clear': 233,
#  'times': 233,
#  'fellow': 233,
#  'everyone': 233,
#  'longer': 233,
#  '*': 233,
#  'laws': 232,
#  'remained': 232,
#  '2': 231,
#  'regiment': 231,
#  'tuberculous': 230,
#  'help': 229,
#  'hundred': 229,
#  'formed': 229,
#  'results': 228,
#  'king': 228,
#  'system': 228,
#  'forward': 228,
#  'ready': 228,
#  'rode': 228,
#  'drawing': 227,
#  'myself': 227,
#  'children': 227,
#  'wounded': 227,
#  'beyond': 226,
#  'tried': 226,
#  'crowd': 226,
#  'hair': 226,
#  'third': 226,
#  'military': 226,
#  'answered': 224,
#  'lost': 224,
#  'anyone': 224,
#  'orders': 223,
#  'north': 223,
#  'understood': 223,
#  'peace': 222,
#  'across': 221,
#  'strange': 221,
#  'news': 221,
#  'reached': 221,
#  '_the': 221,
#  'anatole': 221,
#  'rather': 220,
#  'service': 220,
#  'pressure': 220,
#  'process': 219,
#  'frequently': 219,
#  'sound': 219,
#  'beside': 219,
#  'happy': 219,
#  'spoke': 218,
#  'interest': 218,
#  'coming': 218,
#  'opinion': 218,
#  'growth': 218,
#  'read': 217,
#  'past': 217,
#  'presence': 217,
#  'close': 216,
#  'opened': 216,
#  'ten': 216,
#  'till': 216,
#  'limb': 216,
#  'soldier': 216,
#  'tumour': 216,
#  'point': 214,
#  'wanted': 214,
#  'red': 214,
#  'show': 213,
#  'short': 213,
#  'thus': 213,
#  'raised': 212,
#  'formation': 212,
#  'family': 211,
#  'field': 211,
#  'stopped': 211,
#  'repeated': 210,
#  'affairs': 210,
#  'making': 210,
#  'wished': 210,
#  'trade': 210,
#  'black': 209,
#  'ah': 209,
#  'turning': 209,
#  'happened': 209,
#  'following': 208,
#  'standing': 208,
#  'rest': 207,
#  'seeing': 206,
#  'applied': 206,
#  'true': 205,
#  'perhaps': 205,
#  'english': 204,
#  'talking': 204,
#  'occur': 204,
#  'operation': 204,
#  'answer': 203,
#  'affected': 203,
#  '1': 203,
#  'ca': 202,
#  'else': 202,
#  'events': 202,
#  'air': 200,
#  'kind': 200,
#  'muscles': 200,
#  'colonies': 200,
#  'bed': 199,
#  'call': 198,
#  'neck': 198,
#  'appeared': 198,
#  'able': 198,
#  'rapidly': 198,
#  'led': 197,
#  'associated': 197,
#  'german': 196,
#  'husband': 196,
#  'terrible': 196,
#  'york': 196,
#  'returned': 195,
#  'deep': 195,
#  'least': 195,
#  'period': 195,
#  'aneurysm': 195,
#  'lower': 194,
#  'spread': 194,
#  'cut': 194,
#  'russia': 193,
#  'attention': 192,
#  'reason': 192,
#  'noticed': 192,
#  'merely': 190,
#  'southern': 190,
#  'lymph': 190,
#  'wall': 189,
#  'whose': 189,
#  'campaign': 189,
#  'return': 189,
#  'silent': 189,
#  'steps': 188,
#  'therefore': 187,
#  'laid': 187,
#  'company': 187,
#  'giving': 187,
#  'subject': 186,
#  'turn': 186,
#  'effect': 186,
#  'window': 185,
#  'person': 185,
#  'size': 185,
#  'foot': 185,
#  'abscess': 185,
#  'hear': 184,
#  'speaking': 184,
#  'placed': 183,
#  'believe': 183,
#  'strength': 183,
#  'quickly': 183,
#  'honor': 183,
#  'federal': 183,
#  'doctor': 182,
#  'immediately': 182,
#  'trying': 182,
#  'local': 182,
#  'slavery': 182,
#  'street': 181,
#  'conversation': 181,
#  'city': 180,
#  'soft': 180,
#  'feet': 179,
#  'view': 179,
#  'dinner': 179,
#  'usual': 179,
#  'removed': 179,
#  'account': 178,
#  'former': 178,
#  'fell': 178,
#  'sir': 177,
#  'civil': 177,
#  'glanced': 177,
#  'nearly': 177,
#  'middle': 177,
#  'colonial': 177,
#  'bolkonski': 177,
#  'enough': 176,
#  'doing': 176,
#  'child': 176,
#  'forces': 176,
#  'character': 175,
#  'particularly': 175,
#  'lady': 175,
#  'measures': 175,
#  'foreign': 175,
#  'revolution': 175,
#  'tumours': 175,
#  'hardly': 174,
#  'fine': 174,
#  'afraid': 174,
#  'considerable': 174,
#  'severe': 174,
#  'wounds': 174,
#  'water': 173,
#  'tears': 173,
#  'sides': 172,
#  'town': 172,
#  'republican': 172,
#  'please': 171,
#  'paper': 171,
#  'seat': 171,
#  'daughter': 171,
#  'hard': 171,
#  'meet': 171,
#  'society': 170,
#  'human': 170,
#  'nature': 169,
#  'remarked': 169,
#  'single': 169,
#  'ground': 169,
#  'closed': 169,
#  'although': 169,
#  'waiting': 168,
#  'neither': 168,
#  'freedom': 168,
#  'symptoms': 168,
#  'strong': 167,
#  'soul': 167,
#  'spirit': 167,
#  'hours': 167,
#  'reply': 167,
#  'grew': 167,
#  'tone': 167,
#  'bring': 166,
#  'fear': 166,
#  'thin': 166,
#  'de': 166,
#  'adjutant': 166,
#  'late': 165,
#  'girl': 165,
#  'boy': 165,
#  'except': 165,
#  'according': 165,
#  'considered': 165,
#  'swelling': 165,
#  'need': 164,
#  'brother': 164,
#  'rights': 163,
#  'yourself': 163,
#  'dead': 163,
#  'mouth': 163,
#  'court': 163,
#  'france': 163,
#  'area': 163,
#  'faces': 163,
#  'smiling': 162,
#  'feel': 162,
#  'changes': 162,
#  '3': 162,
#  'someone': 161,
#  'coat': 161,
#  'remember': 161,
#  'village': 161,
#  'washington': 161,
#  'helene': 161,
#  'artery': 160,
#  'plan': 159,
#  'contrary': 159,
#  'smiled': 159,
#  'fresh': 158,
#  'special': 158,
#  'attack': 158,
#  'members': 158,
#  'finally': 157,
#  'dark': 157,
#  'employed': 157,
#  'listened': 157,
#  'bridge': 157,
#  'joints': 157,
#  'bagration': 157,
#  'wo': 156,
#  'questions': 156,
#  'friends': 156,
#  'nation': 156,
#  'various': 156,
#  'pass': 155,
#  'bad': 155,
#  'lesions': 155,
#  'drew': 154,
#  'takes': 154,
#  'pale': 154,
#  'alexander': 154,
#  'occurs': 154,
#  'rostovs': 154,
#  'doubt': 153,
#  'six': 153,
#  'covered': 153,
#  'gangrene': 153,
#  'command': 152,
#  'described': 152,
#  'pavlovna': 152,
#  'change': 151,
#  'glad': 151,
#  'europe': 151,
#  'appear': 151,
#  'cancer': 151,
#  'hour': 150,
#  'wrote': 150,
#  'acute': 150,
#  'voices': 150,
#  'showed': 150,
#  'george': 150,
#  'decided': 150,
#  'primary': 150,
#  'syphilis': 150,
#  'difficult': 149,
#  'hope': 149,
#  'growing': 149,
#  'russians': 149,
#  'powers': 148,
#  'john': 148,
#  'probably': 148,
#  'fixed': 148,
#  'membrane': 148,
#  'minutes': 147,
#  'direction': 147,
#  'says': 147,
#  'killed': 147,
#  'unable': 147,
#  'independence': 147,
#  'convention': 147,
#  'liable': 147,
#  'run': 146,
#  'lips': 146,
#  'ordered': 146,
#  'fingers': 146,
#  'terms': 146,
#  'causes': 146,
#  'pus': 146,
#  'complete': 145,
#  'opening': 145,
#  'frightened': 145,
#  'relations': 145,
#  'suppuration': 145,
#  'happiness': 144,
#  'study': 144,
#  'cry': 144,
#  'natural': 144,
#  'holding': 144,
#  'greater': 144,
#  'beginning': 144,
#  'moving': 144,
#  'virginia': 144,
#  'staff': 144,
#  'republicans': 144,
#  'muscle': 144,
#  'capital': 143,
#  'mademoiselle': 143,
#  "'ve": 143,
#  'colonel': 143,
#  'serious': 142,
#  'remain': 142,
#  'carriage': 142,
#  'struck': 142,
#  'nerves': 142,
#  'keep': 142,
#  'loss': 142,
#  'idea': 142,
#  'firm': 142,
#  'st.': 141,
#  'running': 141,
#  'smoke': 141,
#  'leg': 141,
#  'direct': 141,
#  'indeed': 140,
#  'relation': 140,
#  'increased': 140,
#  'declared': 140,
#  'governor': 140,
#  'consists': 140,
#  'secondary': 140,
#  'heavy': 139,
#  'pleasure': 139,
#  'group': 139,
#  'further': 139,
#  'ulcer': 139,
#  'prepared': 138,
#  'instead': 138,
#  'step': 138,
#  'influence': 138,
#  'drawn': 138,
#  'property': 138,
#  'vessel': 138,
#  'haemorrhage': 138,
#  'lead': 137,
#  'matters': 137,
#  'silence': 137,
#  'thinking': 137,
#  'duty': 137,
#  'leaders': 137,
#  'master': 136,
#  'appearance': 136,
#  'marked': 136,
#  'method': 136,
#  'expressed': 136,
#  'alpatych': 136,
#  'march': 135,
#  'manner': 135,
#  'changed': 135,
#  'simple': 135,
#  'dress': 135,
#  'passing': 135,
#  'living': 135,
#  'features': 135,
#  'seems': 135,
#  'prevent': 135,
#  'chiefly': 135,
#  'diseases': 135,
#  'slowly': 134,
#  'besides': 134,
#  'knee': 134,
#  'lines': 134,
#  'leaving': 133,
#  'attended': 133,
#  'veins': 133,
#  'produced': 133,
#  'activity': 132,
#  'story': 132,
#  'observed': 132,
#  'angry': 132,
#  'uncle': 132,
#  'term': 132,
#  'twenty': 131,
#  'months': 131,
#  'effort': 131,
#  'age': 131,
#  'east': 131,
#  'clearly': 131,
#  'injury': 131,
#  'mikhaylovna': 131,
#  'chair': 130,
#  'latter': 130,
#  'similar': 130,
#  'o': 130,
#  'victory': 130,
#  'historians': 130,
#  'loved': 129,
#  'live': 129,
#  'lord': 129,
#  'popular': 129,
#  'excellency': 129,
#  'series': 128,
#  'corner': 128,
#  'upper': 128,
#  'wait': 128,
#  'poor': 128,
#  'sight': 128,
#  'low': 128,
#  'peasants': 128,
#  'bourienne': 128,
#  'pay': 127,
#  'future': 127,
#  "'re": 127,
#  'everybody': 127,
#  'destroyed': 127,
#  'cells': 127,
#  'gutenberg-tm': 127,
#  'tendon': 127,
#  'shoulders': 126,
#  'thoughts': 126,
#  'industry': 126,
#  'straight': 125,
#  'expected': 125,
#  'fall': 125,
#  'office': 125,
#  'dry': 125,
#  'sure': 124,
#  'explain': 124,
#  'danger': 124,
#  'sister': 124,
#  'ball': 124,
#  'uniform': 124,
#  'kissed': 124,
#  'resulting': 124,
#  'divided': 124,
#  'silver': 123,
#  'pressed': 123,
#  'captain': 123,
#  'portion': 123,
#  'purpose': 122,
#  'broken': 122,
#  'occurred': 122,
#  'asking': 122,
#  'established': 122,
#  'majority': 122,
#  'prisoners': 122,
#  'seven': 121,
#  'produce': 121,
#  'arrived': 121,
#  '4': 121,
#  'syphilitic': 121,
#  'presented': 120,
#  'rule': 120,
#  'filled': 120,
#  'persons': 120,
#  'individual': 120,
#  'interests': 119,
#  'gold': 119,
#  'legs': 119,
#  'quiet': 119,
#  'exclaimed': 119,
#  'remembered': 119,
#  'rostopchin': 119,
#  'written': 118,
#  'lying': 118,
#  ...}

# %% [markdown]
# The absolute probability function is given by the **count of a word** divided by the **length of the corpus**:

# %%
def abs_prob_dict(corpus):
    """Function that takes a corpus and returns a sorted dictionary of probabilities for each word"""
    prob = {k: v/len(corpus) for k, v in sorted(dict_freq(corpus).items(), key=lambda x: x[1], reverse = True)}
    return prob

# %%
abs_prob_big = abs_prob_dict(big_txt)
abs_prob_big
# Out:
# {'the': 0.06161033737054427,
#  ',': 0.05985826697114516,
#  '.': 0.03818784087972867,
#  'of': 0.03105152933709198,
#  'and': 0.02968587658999613,
#  'to': 0.022249276630810524,
#  'in': 0.01701867142162123,
#  'a': 0.016324981901221405,
#  "''": 0.010617174169609415,
#  'that': 0.009689926991893765,
#  '``': 0.00964337064824277,
#  'he': 0.009609229329565374,
#  'was': 0.008865879709271152,
#  'it': 0.008262975058990768,
#  'his': 0.0077857725365680685,
#  'is': 0.007617393760363636,
#  'with': 0.007557646452678192,
#  'as': 0.006252516952328632,
#  'i': 0.005929726303015067,
#  'had': 0.005738069354985137,
#  'for': 0.005370274240142276,
#  'not': 0.005352427641742728,
#  'at': 0.005265522466927537,
#  'by': 0.005180169170234047,
#  'on': 0.0051468037906175,
#  'be': 0.004775904919531239,
#  'from': 0.004408109804688379,
#  'but': 0.004376296303193533,
#  'you': 0.004321980568934038,
#  '--': 0.004318876812690639,
#  'or': 0.004150498036486206,
#  'her': 0.004100061997530962,
#  'him': 0.004055057532001667,
#  "'s": 0.003979791443099225,
#  'which': 0.003755545054513599,
#  '!': 0.0033722311584537396,
#  'were': 0.003334210144472094,
#  '?': 0.0032248027368922553,
#  'all': 0.0031999726869450583,
#  'this': 0.0031487607089289637,
#  'she': 0.0030564239606878235,
#  'they': 0.0030478886310184744,
#  'are': 0.0028290738158587977,
#  'have': 0.0027297536160700085,
#  ';': 0.002725097981704909,
#  'said': 0.0026878529067841128,
#  'an': 0.002652159709985017,
#  'one': 0.0025605989008047263,
#  'who': 0.002361958501227148,
#  'what': 0.002320833731002102,
#  'their': 0.002293675863872355,
#  'there': 0.002292899924811505,
#  'so': 0.002292899924811505,
#  'when': 0.002264190179560058,
#  'been': 0.0020174415582097844,
#  'may': 0.0019786446051672886,
#  'if': 0.0018366477570317538,
#  'no': 0.0018102658289628566,
#  'up': 0.0017466388259731634,
#  'my': 0.0017388794353646643,
#  'them': 0.0017388794353646643,
#  'into': 0.0016488705043060739,
#  'do': 0.001572828476342782,
#  'more': 0.0015487743654564346,
#  'would': 0.001535583401421986,
#  'out': 0.0015278240108134867,
#  'pierre': 0.0015130811686573384,
#  '...': 0.0015099774124139387,
#  'did': 0.0015053217780488391,
#  'prince': 0.0014991142655620398,
#  'me': 0.0014874751796492911,
#  'we': 0.0014641970078237935,
#  'only': 0.0014533338609718947,
#  ':': 0.0014339353844506468,
#  '(': 0.001357117417426505,
#  ')': 0.001357117417426505,
#  'could': 0.0013276317331142081,
#  'now': 0.0013159926472014593,
#  'its': 0.0012694363035504644,
#  'man': 0.0012671084863679146,
#  'has': 0.0012515897051509162,
#  'will': 0.0012182243255343698,
#  'then': 0.0012050333614999212,
#  'some': 0.0011910664584046228,
#  'time': 0.0011763236162484743,
#  'other': 0.0011631326522140257,
#  'about': 0.001160028895970626,
#  'after': 0.001160028895970626,
#  'such': 0.001114248491380481,
#  'before': 0.0010552771227558874,
#  'very': 0.0010366545852954893,
#  'should': 0.001019583925956791,
#  "'": 0.0010164801697133913,
#  'how': 0.0010141523525308417,
#  'your': 0.0009908741807053442,
#  'over': 0.0009792350947925954,
#  'these': 0.000954405044845398,
#  "n't": 0.0009505253495411484,
#  'than': 0.0009365584464458499,
#  'natasha': 0.0009350065683241501,
#  'any': 0.0009342306292633002,
#  'those': 0.0009319028120807504,
#  'new': 0.0009280231167765008,
#  'andrew': 0.0009031930668293035,
#  'first': 0.0009000893105859039,
#  'can': 0.0009000893105859039,
#  'himself': 0.000897761493403354,
#  'men': 0.0008868983465514552,
#  'old': 0.0008837945903080556,
#  'face': 0.0008729314434561567,
#  'down': 0.0008651720528476576,
#  'upon': 0.0008628442356651079,
#  'well': 0.0008457735763264096,
#  'two': 0.0008372382466570606,
#  'french': 0.0008263750998051617,
#  'our': 0.0008240472826226119,
#  'same': 0.0008170638310749627,
#  'know': 0.0008131841357707131,
#  'like': 0.0007976653545537148,
#  'without': 0.0007868022077018159,
#  'see': 0.000786026268640966,
#  'went': 0.0007829225123975663,
#  'made': 0.0007790428170933168,
#  'little': 0.0007751631217890672,
#  'came': 0.0007604202796329187,
#  'must': 0.0007526608890244196,
#  'where': 0.0007526608890244196,
#  'under': 0.0007464533765376202,
#  'even': 0.0007340383515640216,
#  'long': 0.000730158656259772,
#  'eyes': 0.0007255030218946724,
#  'come': 0.0007223992656512728,
#  'princess': 0.000710760179738524,
#  'being': 0.0007099842406776742,
#  'still': 0.0007084323625559743,
#  'room': 0.0007061045453734245,
#  'most': 0.0007045526672517247,
#  'thought': 0.0007006729719474751,
#  'go': 0.0006998970328866252,
#  'states': 0.0006967932766432256,
#  'people': 0.0006843782516696269,
#  'again': 0.0006727391657568782,
#  'way': 0.0006657557142092288,
#  'life': 0.0006634278970266791,
#  'war': 0.0006564444454790298,
#  'another': 0.0006517888111139304,
#  'away': 0.0006494609939313806,
#  'left': 0.0006417016033228814,
#  'hand': 0.0006378219080186319,
#  'through': 0.0006323903345926825,
#  'began': 0.0006292865783492828,
#  'general': 0.0006223031268016335,
#  'own': 0.0006098881018280349,
#  'great': 0.0006091121627671849,
#  'day': 0.0006067843455846352,
#  'rostov': 0.0006005768330978359,
#  'while': 0.0005966971377935862,
#  'just': 0.0005959211987327363,
#  'asked': 0.0005951452596718864,
#  'army': 0.0005912655643676368,
#  'looked': 0.000590489625306787,
#  'say': 0.0005866099300025373,
#  '#': 0.0005765227222114884,
#  'whole': 0.0005757467831506384,
#  'count': 0.0005757467831506384,
#  'back': 0.0005741949050289386,
#  'am': 0.0005734189659680887,
#  'shall': 0.0005710911487855389,
#  'also': 0.0005703152097246891,
#  'moscow': 0.0005602280019336402,
#  'head': 0.0005594520628727902,
#  'right': 0.0005493648550817413,
#  'american': 0.0005470370378991916,
#  'part': 0.0005454851597774918,
#  'mary': 0.0005439332816557919,
#  'felt': 0.0005400535863515423,
#  'seemed': 0.0005400535863515423,
#  'here': 0.0005330701348038931,
#  'something': 0.0005307423176213432,
#  'us': 0.0005291904394996434,
#  'yes': 0.000524534805134544,
#  'having': 0.0005229829270128442,
#  'place': 0.0005222069879519942,
#  'much': 0.0005214310488911443,
#  'why': 0.0005136716582826451,
#  'against': 0.0005113438411000953,
#  'state': 0.0005090160239175456,
#  'every': 0.0005051363286132961,
#  'though': 0.0005043603895524461,
#  'house': 0.0005035844504915962,
#  'between': 0.0005028085114307463,
#  'government': 0.0004966009989439469,
#  'nothing': 0.000495825059883097,
#  'heard': 0.0004942731817613972,
#  'nicholas': 0.0004903934864571476,
#  'off': 0.0004896175473962977,
#  'because': 0.0004888416083354477,
#  'young': 0.0004857378520920481,
#  'emperor': 0.0004810822177269486,
#  'take': 0.000477202522422699,
#  'always': 0.00047254688805759953,
#  'many': 0.00047021907087504977,
#  'bone': 0.0004678912536925,
#  'good': 0.0004663393755708002,
#  'saw': 0.00046478749744910034,
#  'disease': 0.0004632356193274005,
#  'napoleon': 0.000458579984962301,
#  'never': 0.00045702810684060115,
#  'took': 0.0004453890209278524,
#  'years': 0.0004415093256236028,
#  'once': 0.0004415093256236028,
#  'look': 0.00043918150844105306,
#  'last': 0.0004376296303193532,
#  'think': 0.0004329739959542537,
#  'united': 0.0004329739959542537,
#  'found': 0.0004259905444066045,
#  'too': 0.0004252146053457546,
#  'met': 0.0004228867881632048,
#  'round': 0.0004221108491023549,
#  'skin': 0.000421334910041505,
#  'power': 0.00041978303191980514,
#  'might': 0.00041667927567640546,
#  'tissue': 0.0004151273975547056,
#  'both': 0.0004112477022504561,
#  'three': 0.0004112477022504561,
#  'usually': 0.0004112477022504561,
#  'give': 0.00040659206788535657,
#  'small': 0.00040581612882450665,
#  'kutuzov': 0.00040116049445940714,
#  'father': 0.0003996086163377073,
#  'let': 0.000392625164790058,
#  'form': 0.0003910732866683582,
#  'side': 0.0003910732866683582,
#  'during': 0.0003910732866683582,
#  'make': 0.0003895214085466584,
#  'quite': 0.00038796953042495857,
#  'turned': 0.00038719359136410865,
#  'knew': 0.0003856417132424088,
#  'suddenly': 0.0003848657741815589,
#  'countess': 0.00038408983512070897,
#  'door': 0.00038331389605985905,
#  'told': 0.0003802101398164594,
#  'whom': 0.0003802101398164594,
#  'yet': 0.00037943420075560946,
#  'tell': 0.00037865826169475954,
#  'already': 0.00037865826169475954,
#  'moment': 0.0003771063835730597,
#  'love': 0.00037400262732966,
#  'large': 0.0003724507492079602,
#  'holmes': 0.0003631394804777612,
#  'get': 0.0003631394804777612,
#  'chapter': 0.00036081166329521145,
#  'voice': 0.0003592597851735116,
#  'russian': 0.00035693196799096186,
#  'few': 0.00035615602893011194,
#  'words': 0.00035615602893011194,
#  'officer': 0.00035615602893011194,
#  'end': 0.0003546041508084121,
#  'hands': 0.00035227633362586234,
#  'cases': 0.0003515003945650124,
#  'blood': 0.0003515003945650124,
#  'among': 0.0003507244555041625,
#  'days': 0.0003507244555041625,
#  'looking': 0.0003499485164433126,
#  'everything': 0.0003499485164433126,
#  'seen': 0.0003452928820782131,
#  'dear': 0.0003445169430173632,
#  'often': 0.0003445169430173632,
#  'gave': 0.0003437410039565133,
#  'sonya': 0.0003437410039565133,
#  'battle': 0.00034141318677396353,
#  'taken': 0.0003406372477131136,
#  '[': 0.00033830943053056385,
#  ']': 0.00033830943053056385,
#  'congress': 0.00033753349146971393,
#  'position': 0.0003359816133480141,
#  'put': 0.0003359816133480141,
#  'case': 0.00033442973522631426,
#  'however': 0.00033442973522631426,
#  'done': 0.0003328778571046144,
#  'smile': 0.00033055003992206466,
#  'sometimes': 0.00033055003992206466,
#  'soon': 0.000327446283678665,
#  'country': 0.0003258944055569652,
#  'denisov': 0.0003251184664961153,
#  'called': 0.0003227906493135655,
#  'understand': 0.00032046283213101577,
#  'each': 0.00031968689307016585,
#  'free': 0.00031891095400931593,
#  "'ll": 0.00031891095400931593,
#  'others': 0.000318135014948466,
#  'become': 0.000318135014948466,
#  'soldiers': 0.0003173590758876161,
#  'brought': 0.00031580719776591625,
#  'along': 0.0003142553196442164,
#  'sat': 0.0003134793805833665,
#  'especially': 0.0003134793805833665,
#  'order': 0.0003127034415225166,
#  'behind': 0.00031192750246166666,
#  'far': 0.00030804780715741706,
#  'oh': 0.0003064959290357172,
#  'does': 0.00030571998997486736,
#  'course': 0.00030184029467061776,
#  'result': 0.0003002884165489179,
#  'stood': 0.00029796059936636817,
#  'patient': 0.0002940809040621186,
#  'anything': 0.0002940809040621186,
#  'known': 0.0002940809040621186,
#  'work': 0.0002917530868795688,
#  'evidently': 0.0002909771478187189,
#  'several': 0.000290201208757869,
#  'cause': 0.00028942526969701906,
#  'going': 0.0002878733915753192,
#  'law': 0.0002870974525144693,
#  '=the': 0.0002870974525144693,
#  'passed': 0.00028554557439276946,
#  'less': 0.00028554557439276946,
#  'women': 0.00028554557439276946,
#  'matter': 0.00028321775721021976,
#  'wife': 0.00028244181814936984,
#  'given': 0.00028244181814936984,
#  'certain': 0.00028088994002767,
#  'feeling': 0.0002801140009668201,
#  'front': 0.00027856212284512025,
#  'whether': 0.0002777861837842703,
#  'action': 0.0002770102447234204,
#  'infection': 0.00027545836660172057,
#  'world': 0.00027468242754087065,
#  'god': 0.00027390648848002073,
#  'night': 0.0002692508541149212,
#  'chief': 0.0002692508541149212,
#  'question': 0.00026692303693237146,
#  'mr.': 0.00026614709787152154,
#  'mind': 0.0002653711588106716,
#  'herself': 0.0002653711588106716,
#  'possible': 0.00026381928068897184,
#  'movement': 0.00026381928068897184,
#  'history': 0.0002630433416281219,
#  'alone': 0.000262267402567272,
#  'president': 0.000262267402567272,
#  'condition': 0.0002614914635064221,
#  'morning': 0.00026071552444557216,
#  'later': 0.00025993958538472224,
#  'son': 0.00025993958538472224,
#  'white': 0.0002591636463238723,
#  'joint': 0.0002591636463238723,
#  'toward': 0.0002576117682021725,
#  'body': 0.00025683582914132257,
#  'followed': 0.00025605989008047265,
#  'present': 0.0002545080119587728,
#  'necessary': 0.0002545080119587728,
#  '|': 0.0002545080119587728,
#  'almost': 0.00025295613383707297,
#  'until': 0.00025295613383707297,
#  'dolokhov': 0.00025295613383707297,
#  'death': 0.00025218019477622305,
#  'money': 0.00025218019477622305,
#  'ran': 0.0002506283166545232,
#  'things': 0.0002498523775936733,
#  'want': 0.0002498523775936733,
#  'expression': 0.0002498523775936733,
#  'horse': 0.0002498523775936733,
#  'replied': 0.0002490764385328234,
#  'fig': 0.0002490764385328234,
#  'troops': 0.00024830049947197346,
#  'set': 0.00024752456041112354,
#  'sent': 0.00024752456041112354,
#  'treatment': 0.00024752456041112354,
#  'woman': 0.0002467486213502736,
#  'act': 0.0002459726822894237,
#  'officers': 0.0002451967432285738,
#  'became': 0.00024442080416772386,
#  'within': 0.00024364486510687397,
#  'use': 0.00024286892604602405,
#  'business': 0.00024209298698517413,
#  'labor': 0.00024209298698517413,
#  'mother': 0.00023976516980262437,
#  'pp': 0.00023976516980262437,
#  'thing': 0.0002358854744983748,
#  'taking': 0.0002358854744983748,
#  'themselves': 0.0002358854744983748,
#  'south': 0.00023510953543752489,
#  'number': 0.00023433359637667497,
#  'leave': 0.00023355765731582505,
#  'england': 0.00023278171825497513,
#  'commander': 0.00023278171825497513,
#  'added': 0.0002320057791941252,
#  'above': 0.0002320057791941252,
#  'pain': 0.0002320057791941252,
#  'word': 0.0002312298401332753,
#  'find': 0.00022890202295072553,
#  'lay': 0.00022890202295072553,
#  'wound': 0.00022890202295072553,
#  'parts': 0.00022812608388987561,
#  'anna': 0.00022812608388987561,
#  'near': 0.0002273501448290257,
#  'either': 0.0002265742057681758,
#  'boris': 0.0002265742057681758,
#  'home': 0.00022579826670732588,
#  'open': 0.00022579826670732588,
#  'fact': 0.00022579826670732588,
#  'party': 0.00022579826670732588,
#  'tissues': 0.00022579826670732588,
#  'enemy': 0.00022502232764647596,
#  'project': 0.00022424638858562605,
#  'continued': 0.00022424638858562605,
#  'letter': 0.00022424638858562605,
#  'table': 0.00022347044952477613,
#  'held': 0.00022347044952477613,
#  'talk': 0.00022347044952477613,
#  'example': 0.0002226945104639262,
#  'illustration': 0.0002219185714030763,
#  'common': 0.00022114263234222637,
#  'year': 0.00022036669328137645,
#  'constitution': 0.00021959075422052653,
#  'carried': 0.0002188148151596766,
#  'public': 0.0002188148151596766,
#  'important': 0.0002180388760988267,
#  'friend': 0.0002180388760988267,
#  'received': 0.0002180388760988267,
#  'nor': 0.0002180388760988267,
#  'cried': 0.00021726293703797677,
#  'got': 0.00021726293703797677,
#  'entered': 0.00021648699797712685,
#  'next': 0.00021493511985542704,
#  'used': 0.00021415918079457712,
#  'surface': 0.00021415918079457712,
#  'different': 0.0002133832417337272,
#  'land': 0.0002126073026728773,
#  'itself': 0.00021183136361202737,
#  'really': 0.00021183136361202737,
#  'west': 0.00021105542455117745,
#  'around': 0.00021027948549032753,
#  'fire': 0.00021027948549032753,
#  'high': 0.00021027948549032753,
#  'second': 0.00021027948549032753,
#  'saying': 0.00021027948549032753,
#  'national': 0.0002087276073686277,
#  'nerve': 0.00020717572924692785,
#  'better': 0.00020562385112522804,
#  'petya': 0.00020562385112522804,
#  'light': 0.00020484791206437812,
#  'evening': 0.00020484791206437812,
#  'america': 0.00020484791206437812,
#  'name': 0.00020329603394267828,
#  'horses': 0.00020329603394267828,
#  'since': 0.00020252009488182837,
#  'together': 0.00020252009488182837,
#  'best': 0.00020252009488182837,
#  'british': 0.00020252009488182837,
#  'union': 0.00020252009488182837,
#  'early': 0.0002001922776992786,
#  'road': 0.0001994163386384287,
#  'political': 0.0001994163386384287,
#  'full': 0.0001994163386384287,
#  'bones': 0.0001994163386384287,
#  'ever': 0.00019864039957757877,
#  'half': 0.00019864039957757877,
#  'speak': 0.00019864039957757877,
#  'thousand': 0.00019864039957757877,
#  'shouted': 0.00019786446051672885,
#  'arm': 0.00019786446051672885,
#  'means': 0.00019708852145587893,
#  'forms': 0.00019708852145587893,
#  'cold': 0.000196312582395029,
#  'heart': 0.000196312582395029,
#  'sitting': 0.0001955366433341791,
#  'glands': 0.0001955366433341791,
#  'ask': 0.0001947607042733292,
#  'kept': 0.0001947607042733292,
#  'due': 0.00019398476521247928,
#  'impossible': 0.00019320882615162936,
#  'moved': 0.00019320882615162936,
#  'four': 0.00019243288709077944,
#  'petersburg': 0.00019165694802992953,
#  'arms': 0.0001908810089690796,
#  'becomes': 0.0001908810089690796,
#  'line': 0.0001901050699082297,
#  'wish': 0.00018932913084737977,
#  'vasili': 0.00018777725272567993,
#  'rose': 0.00018700131366483,
#  'vessels': 0.00018700131366483,
#  'force': 0.00018544943554313017,
#  'gone': 0.00018467349648228028,
#  'conditions': 0.00018467349648228028,
#  'five': 0.0001815697402388806,
#  'rise': 0.0001815697402388806,
#  'clear': 0.00018079380117803069,
#  'times': 0.00018079380117803069,
#  'fellow': 0.00018079380117803069,
#  'everyone': 0.00018079380117803069,
#  'longer': 0.00018079380117803069,
#  '*': 0.00018079380117803069,
#  'laws': 0.00018001786211718077,
#  'remained': 0.00018001786211718077,
#  '2': 0.00017924192305633085,
#  'regiment': 0.00017924192305633085,
#  'tuberculous': 0.00017846598399548093,
#  'help': 0.000177690044934631,
#  'hundred': 0.000177690044934631,
#  'formed': 0.000177690044934631,
#  'results': 0.0001769141058737811,
#  'king': 0.0001769141058737811,
#  'system': 0.0001769141058737811,
#  'forward': 0.0001769141058737811,
#  'ready': 0.0001769141058737811,
#  'rode': 0.0001769141058737811,
#  'drawing': 0.00017613816681293117,
#  'myself': 0.00017613816681293117,
#  'children': 0.00017613816681293117,
#  'wounded': 0.00017613816681293117,
#  'beyond': 0.00017536222775208125,
#  'tried': 0.00017536222775208125,
#  'crowd': 0.00017536222775208125,
#  'hair': 0.00017536222775208125,
#  'third': 0.00017536222775208125,
#  'military': 0.00017536222775208125,
#  'answered': 0.00017381034963038144,
#  'lost': 0.00017381034963038144,
#  'anyone': 0.00017381034963038144,
#  'orders': 0.00017303441056953152,
#  'north': 0.00017303441056953152,
#  'understood': 0.00017303441056953152,
#  'peace': 0.0001722584715086816,
#  'across': 0.00017148253244783168,
#  'strange': 0.00017148253244783168,
#  'news': 0.00017148253244783168,
#  'reached': 0.00017148253244783168,
#  '_the': 0.00017148253244783168,
#  'anatole': 0.00017148253244783168,
#  'rather': 0.00017070659338698176,
#  'service': 0.00017070659338698176,
#  'pressure': 0.00017070659338698176,
#  'process': 0.00016993065432613185,
#  'frequently': 0.00016993065432613185,
#  'sound': 0.00016993065432613185,
#  'beside': 0.00016993065432613185,
#  'happy': 0.00016993065432613185,
#  'spoke': 0.00016915471526528193,
#  'interest': 0.00016915471526528193,
#  'coming': 0.00016915471526528193,
#  'opinion': 0.00016915471526528193,
#  'growth': 0.00016915471526528193,
#  'read': 0.000168378776204432,
#  'past': 0.000168378776204432,
#  'presence': 0.000168378776204432,
#  'close': 0.0001676028371435821,
#  'opened': 0.0001676028371435821,
#  'ten': 0.0001676028371435821,
#  'till': 0.0001676028371435821,
#  'limb': 0.0001676028371435821,
#  'soldier': 0.0001676028371435821,
#  'tumour': 0.0001676028371435821,
#  'point': 0.00016605095902188225,
#  'wanted': 0.00016605095902188225,
#  'red': 0.00016605095902188225,
#  'show': 0.00016527501996103233,
#  'short': 0.00016527501996103233,
#  'thus': 0.00016527501996103233,
#  'raised': 0.0001644990809001824,
#  'formation': 0.0001644990809001824,
#  'family': 0.0001637231418393325,
#  'field': 0.0001637231418393325,
#  'stopped': 0.0001637231418393325,
#  'repeated': 0.0001629472027784826,
#  'affairs': 0.0001629472027784826,
#  'making': 0.0001629472027784826,
#  'wished': 0.0001629472027784826,
#  'trade': 0.0001629472027784826,
#  'black': 0.00016217126371763268,
#  'ah': 0.00016217126371763268,
#  'turning': 0.00016217126371763268,
#  'happened': 0.00016217126371763268,
#  'following': 0.00016139532465678276,
#  'standing': 0.00016139532465678276,
#  'rest': 0.00016061938559593284,
#  'seeing': 0.00015984344653508292,
#  'applied': 0.00015984344653508292,
#  'true': 0.000159067507474233,
#  'perhaps': 0.000159067507474233,
#  'english': 0.00015829156841338309,
#  'talking': 0.00015829156841338309,
#  'occur': 0.00015829156841338309,
#  'operation': 0.00015829156841338309,
#  'answer': 0.00015751562935253317,
#  'affected': 0.00015751562935253317,
#  '1': 0.00015751562935253317,
#  'ca': 0.00015673969029168325,
#  'else': 0.00015673969029168325,
#  'events': 0.00015673969029168325,
#  'air': 0.0001551878121699834,
#  'kind': 0.0001551878121699834,
#  'muscles': 0.0001551878121699834,
#  'colonies': 0.0001551878121699834,
#  'bed': 0.0001544118731091335,
#  'call': 0.00015363593404828357,
#  'neck': 0.00015363593404828357,
#  'appeared': 0.00015363593404828357,
#  'able': 0.00015363593404828357,
#  'rapidly': 0.00015363593404828357,
#  'led': 0.00015285999498743368,
#  'associated': 0.00015285999498743368,
#  'german': 0.00015208405592658376,
#  'husband': 0.00015208405592658376,
#  'terrible': 0.00015208405592658376,
#  'york': 0.00015208405592658376,
#  'returned': 0.00015130811686573384,
#  'deep': 0.00015130811686573384,
#  'least': 0.00015130811686573384,
#  'period': 0.00015130811686573384,
#  'aneurysm': 0.00015130811686573384,
#  'lower': 0.00015053217780488392,
#  'spread': 0.00015053217780488392,
#  'cut': 0.00015053217780488392,
#  'russia': 0.000149756238744034,
#  'attention': 0.00014898029968318408,
#  'reason': 0.00014898029968318408,
#  'noticed': 0.00014898029968318408,
#  'merely': 0.00014742842156148425,
#  'southern': 0.00014742842156148425,
#  'lymph': 0.00014742842156148425,
#  'wall': 0.00014665248250063433,
#  'whose': 0.00014665248250063433,
#  'campaign': 0.00014665248250063433,
#  'return': 0.00014665248250063433,
#  'silent': 0.00014665248250063433,
#  'steps': 0.0001458765434397844,
#  'therefore': 0.0001451006043789345,
#  'laid': 0.0001451006043789345,
#  'company': 0.0001451006043789345,
#  'giving': 0.0001451006043789345,
#  'subject': 0.00014432466531808457,
#  'turn': 0.00014432466531808457,
#  'effect': 0.00014432466531808457,
#  'window': 0.00014354872625723465,
#  'person': 0.00014354872625723465,
#  'size': 0.00014354872625723465,
#  'foot': 0.00014354872625723465,
#  'abscess': 0.00014354872625723465,
#  'hear': 0.00014277278719638473,
#  'speaking': 0.00014277278719638473,
#  'placed': 0.00014199684813553484,
#  'believe': 0.00014199684813553484,
#  'strength': 0.00014199684813553484,
#  'quickly': 0.00014199684813553484,
#  'honor': 0.00014199684813553484,
#  'federal': 0.00014199684813553484,
#  'doctor': 0.00014122090907468492,
#  'immediately': 0.00014122090907468492,
#  'trying': 0.00014122090907468492,
#  'local': 0.00014122090907468492,
#  'slavery': 0.00014122090907468492,
#  'street': 0.000140444970013835,
#  'conversation': 0.000140444970013835,
#  'city': 0.00013966903095298508,
#  'soft': 0.00013966903095298508,
#  'feet': 0.00013889309189213516,
#  'view': 0.00013889309189213516,
#  'dinner': 0.00013889309189213516,
#  'usual': 0.00013889309189213516,
#  'removed': 0.00013889309189213516,
#  'account': 0.00013811715283128524,
#  'former': 0.00013811715283128524,
#  'fell': 0.00013811715283128524,
#  'sir': 0.00013734121377043533,
#  'civil': 0.00013734121377043533,
#  'glanced': 0.00013734121377043533,
#  'nearly': 0.00013734121377043533,
#  'middle': 0.00013734121377043533,
#  'colonial': 0.00013734121377043533,
#  'bolkonski': 0.00013734121377043533,
#  'enough': 0.0001365652747095854,
#  'doing': 0.0001365652747095854,
#  'child': 0.0001365652747095854,
#  'forces': 0.0001365652747095854,
#  'character': 0.0001357893356487355,
#  'particularly': 0.0001357893356487355,
#  'lady': 0.0001357893356487355,
#  'measures': 0.0001357893356487355,
#  'foreign': 0.0001357893356487355,
#  'revolution': 0.0001357893356487355,
#  'tumours': 0.0001357893356487355,
#  'hardly': 0.00013501339658788557,
#  'fine': 0.00013501339658788557,
#  'afraid': 0.00013501339658788557,
#  'considerable': 0.00013501339658788557,
#  'severe': 0.00013501339658788557,
#  'wounds': 0.00013501339658788557,
#  'water': 0.00013423745752703565,
#  'tears': 0.00013423745752703565,
#  'sides': 0.00013346151846618573,
#  'town': 0.00013346151846618573,
#  'republican': 0.00013346151846618573,
#  'please': 0.0001326855794053358,
#  'paper': 0.0001326855794053358,
#  'seat': 0.0001326855794053358,
#  'daughter': 0.0001326855794053358,
#  'hard': 0.0001326855794053358,
#  'meet': 0.0001326855794053358,
#  'society': 0.00013190964034448592,
#  'human': 0.00013190964034448592,
#  'nature': 0.000131133701283636,
#  'remarked': 0.000131133701283636,
#  'single': 0.000131133701283636,
#  'ground': 0.000131133701283636,
#  'closed': 0.000131133701283636,
#  'although': 0.000131133701283636,
#  'waiting': 0.00013035776222278608,
#  'neither': 0.00013035776222278608,
#  'freedom': 0.00013035776222278608,
#  'symptoms': 0.00013035776222278608,
#  'strong': 0.00012958182316193616,
#  'soul': 0.00012958182316193616,
#  'spirit': 0.00012958182316193616,
#  'hours': 0.00012958182316193616,
#  'reply': 0.00012958182316193616,
#  'grew': 0.00012958182316193616,
#  'tone': 0.00012958182316193616,
#  'bring': 0.00012880588410108624,
#  'fear': 0.00012880588410108624,
#  'thin': 0.00012880588410108624,
#  'de': 0.00012880588410108624,
#  'adjutant': 0.00012880588410108624,
#  'late': 0.00012802994504023632,
#  'girl': 0.00012802994504023632,
#  'boy': 0.00012802994504023632,
#  'except': 0.00012802994504023632,
#  'according': 0.00012802994504023632,
#  'considered': 0.00012802994504023632,
#  'swelling': 0.00012802994504023632,
#  'need': 0.0001272540059793864,
#  'brother': 0.0001272540059793864,
#  'rights': 0.00012647806691853649,
#  'yourself': 0.00012647806691853649,
#  'dead': 0.00012647806691853649,
#  'mouth': 0.00012647806691853649,
#  'court': 0.00012647806691853649,
#  'france': 0.00012647806691853649,
#  'area': 0.00012647806691853649,
#  'faces': 0.00012647806691853649,
#  'smiling': 0.00012570212785768657,
#  'feel': 0.00012570212785768657,
#  'changes': 0.00012570212785768657,
#  '3': 0.00012570212785768657,
#  'someone': 0.00012492618879683665,
#  'coat': 0.00012492618879683665,
#  'remember': 0.00012492618879683665,
#  'village': 0.00012492618879683665,
#  'washington': 0.00012492618879683665,
#  'helene': 0.00012492618879683665,
#  'artery': 0.00012415024973598673,
#  'plan': 0.0001233743106751368,
#  'contrary': 0.0001233743106751368,
#  'smiled': 0.0001233743106751368,
#  'fresh': 0.0001225983716142869,
#  'special': 0.0001225983716142869,
#  'attack': 0.0001225983716142869,
#  'members': 0.0001225983716142869,
#  'finally': 0.00012182243255343698,
#  'dark': 0.00012182243255343698,
#  'employed': 0.00012182243255343698,
#  'listened': 0.00012182243255343698,
#  'bridge': 0.00012182243255343698,
#  'joints': 0.00012182243255343698,
#  'bagration': 0.00012182243255343698,
#  'wo': 0.00012104649349258707,
#  'questions': 0.00012104649349258707,
#  'friends': 0.00012104649349258707,
#  'nation': 0.00012104649349258707,
#  'various': 0.00012104649349258707,
#  'pass': 0.00012027055443173715,
#  'bad': 0.00012027055443173715,
#  'lesions': 0.00012027055443173715,
#  'drew': 0.00011949461537088723,
#  'takes': 0.00011949461537088723,
#  'pale': 0.00011949461537088723,
#  'alexander': 0.00011949461537088723,
#  'occurs': 0.00011949461537088723,
#  'rostovs': 0.00011949461537088723,
#  'doubt': 0.00011871867631003732,
#  'six': 0.00011871867631003732,
#  'covered': 0.00011871867631003732,
#  'gangrene': 0.00011871867631003732,
#  'command': 0.0001179427372491874,
#  'described': 0.0001179427372491874,
#  'pavlovna': 0.0001179427372491874,
#  'change': 0.00011716679818833748,
#  'glad': 0.00011716679818833748,
#  'europe': 0.00011716679818833748,
#  'appear': 0.00011716679818833748,
#  'cancer': 0.00011716679818833748,
#  'hour': 0.00011639085912748756,
#  'wrote': 0.00011639085912748756,
#  'acute': 0.00011639085912748756,
#  'voices': 0.00011639085912748756,
#  'showed': 0.00011639085912748756,
#  'george': 0.00011639085912748756,
#  'decided': 0.00011639085912748756,
#  'primary': 0.00011639085912748756,
#  'syphilis': 0.00011639085912748756,
#  'difficult': 0.00011561492006663765,
#  'hope': 0.00011561492006663765,
#  'growing': 0.00011561492006663765,
#  'russians': 0.00011561492006663765,
#  'powers': 0.00011483898100578773,
#  'john': 0.00011483898100578773,
#  'probably': 0.00011483898100578773,
#  'fixed': 0.00011483898100578773,
#  'membrane': 0.00011483898100578773,
#  'minutes': 0.00011406304194493781,
#  'direction': 0.00011406304194493781,
#  'says': 0.00011406304194493781,
#  'killed': 0.00011406304194493781,
#  'unable': 0.00011406304194493781,
#  'independence': 0.00011406304194493781,
#  'convention': 0.00011406304194493781,
#  'liable': 0.00011406304194493781,
#  'run': 0.0001132871028840879,
#  'lips': 0.0001132871028840879,
#  'ordered': 0.0001132871028840879,
#  'fingers': 0.0001132871028840879,
#  'terms': 0.0001132871028840879,
#  'causes': 0.0001132871028840879,
#  'pus': 0.0001132871028840879,
#  'complete': 0.00011251116382323798,
#  'opening': 0.00011251116382323798,
#  'frightened': 0.00011251116382323798,
#  'relations': 0.00011251116382323798,
#  'suppuration': 0.00011251116382323798,
#  'happiness': 0.00011173522476238806,
#  'study': 0.00011173522476238806,
#  'cry': 0.00011173522476238806,
#  'natural': 0.00011173522476238806,
#  'holding': 0.00011173522476238806,
#  'greater': 0.00011173522476238806,
#  'beginning': 0.00011173522476238806,
#  'moving': 0.00011173522476238806,
#  'virginia': 0.00011173522476238806,
#  'staff': 0.00011173522476238806,
#  'republicans': 0.00011173522476238806,
#  'muscle': 0.00011173522476238806,
#  'capital': 0.00011095928570153814,
#  'mademoiselle': 0.00011095928570153814,
#  "'ve": 0.00011095928570153814,
#  'colonel': 0.00011095928570153814,
#  'serious': 0.00011018334664068823,
#  'remain': 0.00011018334664068823,
#  'carriage': 0.00011018334664068823,
#  'struck': 0.00011018334664068823,
#  'nerves': 0.00011018334664068823,
#  'keep': 0.00011018334664068823,
#  'loss': 0.00011018334664068823,
#  'idea': 0.00011018334664068823,
#  'firm': 0.00011018334664068823,
#  'st.': 0.0001094074075798383,
#  'running': 0.0001094074075798383,
#  'smoke': 0.0001094074075798383,
#  'leg': 0.0001094074075798383,
#  'direct': 0.0001094074075798383,
#  'indeed': 0.00010863146851898839,
#  'relation': 0.00010863146851898839,
#  'increased': 0.00010863146851898839,
#  'declared': 0.00010863146851898839,
#  'governor': 0.00010863146851898839,
#  'consists': 0.00010863146851898839,
#  'secondary': 0.00010863146851898839,
#  'heavy': 0.00010785552945813848,
#  'pleasure': 0.00010785552945813848,
#  'group': 0.00010785552945813848,
#  'further': 0.00010785552945813848,
#  'ulcer': 0.00010785552945813848,
#  'prepared': 0.00010707959039728856,
#  'instead': 0.00010707959039728856,
#  'step': 0.00010707959039728856,
#  'influence': 0.00010707959039728856,
#  'drawn': 0.00010707959039728856,
#  'property': 0.00010707959039728856,
#  'vessel': 0.00010707959039728856,
#  'haemorrhage': 0.00010707959039728856,
#  'lead': 0.00010630365133643864,
#  'matters': 0.00010630365133643864,
#  'silence': 0.00010630365133643864,
#  'thinking': 0.00010630365133643864,
#  'duty': 0.00010630365133643864,
#  'leaders': 0.00010630365133643864,
#  'master': 0.00010552771227558872,
#  'appearance': 0.00010552771227558872,
#  'marked': 0.00010552771227558872,
#  'method': 0.00010552771227558872,
#  'expressed': 0.00010552771227558872,
#  'alpatych': 0.00010552771227558872,
#  'march': 0.0001047517732147388,
#  'manner': 0.0001047517732147388,
#  'changed': 0.0001047517732147388,
#  'simple': 0.0001047517732147388,
#  'dress': 0.0001047517732147388,
#  'passing': 0.0001047517732147388,
#  'living': 0.0001047517732147388,
#  'features': 0.0001047517732147388,
#  'seems': 0.0001047517732147388,
#  'prevent': 0.0001047517732147388,
#  'chiefly': 0.0001047517732147388,
#  'diseases': 0.0001047517732147388,
#  'slowly': 0.00010397583415388889,
#  'besides': 0.00010397583415388889,
#  'knee': 0.00010397583415388889,
#  'lines': 0.00010397583415388889,
#  'leaving': 0.00010319989509303897,
#  'attended': 0.00010319989509303897,
#  'veins': 0.00010319989509303897,
#  'produced': 0.00010319989509303897,
#  'activity': 0.00010242395603218906,
#  'story': 0.00010242395603218906,
#  'observed': 0.00010242395603218906,
#  'angry': 0.00010242395603218906,
#  'uncle': 0.00010242395603218906,
#  'term': 0.00010242395603218906,
#  'twenty': 0.00010164801697133914,
#  'months': 0.00010164801697133914,
#  'effort': 0.00010164801697133914,
#  'age': 0.00010164801697133914,
#  'east': 0.00010164801697133914,
#  'clearly': 0.00010164801697133914,
#  'injury': 0.00010164801697133914,
#  'mikhaylovna': 0.00010164801697133914,
#  'chair': 0.00010087207791048922,
#  'latter': 0.00010087207791048922,
#  'similar': 0.00010087207791048922,
#  'o': 0.00010087207791048922,
#  'victory': 0.00010087207791048922,
#  'historians': 0.00010087207791048922,
#  'loved': 0.0001000961388496393,
#  'live': 0.0001000961388496393,
#  'lord': 0.0001000961388496393,
#  'popular': 0.0001000961388496393,
#  'excellency': 0.0001000961388496393,
#  'series': 9.932019978878939e-05,
#  'corner': 9.932019978878939e-05,
#  'upper': 9.932019978878939e-05,
#  'wait': 9.932019978878939e-05,
#  'poor': 9.932019978878939e-05,
#  'sight': 9.932019978878939e-05,
#  'low': 9.932019978878939e-05,
#  'peasants': 9.932019978878939e-05,
#  'bourienne': 9.932019978878939e-05,
#  'pay': 9.854426072793947e-05,
#  'future': 9.854426072793947e-05,
#  "'re": 9.854426072793947e-05,
#  'everybody': 9.854426072793947e-05,
#  'destroyed': 9.854426072793947e-05,
#  'cells': 9.854426072793947e-05,
#  'gutenberg-tm': 9.854426072793947e-05,
#  'tendon': 9.854426072793947e-05,
#  'shoulders': 9.776832166708955e-05,
#  'thoughts': 9.776832166708955e-05,
#  'industry': 9.776832166708955e-05,
#  'straight': 9.699238260623964e-05,
#  'expected': 9.699238260623964e-05,
#  'fall': 9.699238260623964e-05,
#  'office': 9.699238260623964e-05,
#  'dry': 9.699238260623964e-05,
#  'sure': 9.621644354538972e-05,
#  'explain': 9.621644354538972e-05,
#  'danger': 9.621644354538972e-05,
#  'sister': 9.621644354538972e-05,
#  'ball': 9.621644354538972e-05,
#  'uniform': 9.621644354538972e-05,
#  'kissed': 9.621644354538972e-05,
#  'resulting': 9.621644354538972e-05,
#  'divided': 9.621644354538972e-05,
#  'silver': 9.54405044845398e-05,
#  'pressed': 9.54405044845398e-05,
#  'captain': 9.54405044845398e-05,
#  'portion': 9.54405044845398e-05,
#  'purpose': 9.466456542368988e-05,
#  'broken': 9.466456542368988e-05,
#  'occurred': 9.466456542368988e-05,
#  'asking': 9.466456542368988e-05,
#  'established': 9.466456542368988e-05,
#  'majority': 9.466456542368988e-05,
#  'prisoners': 9.466456542368988e-05,
#  'seven': 9.388862636283997e-05,
#  'produce': 9.388862636283997e-05,
#  'arrived': 9.388862636283997e-05,
#  '4': 9.388862636283997e-05,
#  'syphilitic': 9.388862636283997e-05,
#  'presented': 9.311268730199005e-05,
#  'rule': 9.311268730199005e-05,
#  'filled': 9.311268730199005e-05,
#  'persons': 9.311268730199005e-05,
#  'individual': 9.311268730199005e-05,
#  'interests': 9.233674824114014e-05,
#  'gold': 9.233674824114014e-05,
#  'legs': 9.233674824114014e-05,
#  'quiet': 9.233674824114014e-05,
#  'exclaimed': 9.233674824114014e-05,
#  'remembered': 9.233674824114014e-05,
#  'rostopchin': 9.233674824114014e-05,
#  'written': 9.156080918029022e-05,
#  'lying': 9.156080918029022e-05,
#  ...}

# %%
abs_prob_brown = abs_prob_dict(brown_words)
abs_prob_brown
# Out:
# {'the': 0.06025876857573941,
#  ',': 0.05023717008040014,
#  '.': 0.042496848066469625,
#  'of': 0.031358293891105005,
#  'and': 0.024848603848459168,
#  'to': 0.022527712901914583,
#  'a': 0.01997602463675258,
#  'in': 0.018375944718875086,
#  'that': 0.009124244741610344,
#  'is': 0.00870657048963479,
#  'was': 0.00845338238637538,
#  'he': 0.00822344625178265,
#  'for': 0.008172636394325831,
#  '``': 0.007611144410226732,
#  "''": 0.007569807577041523,
#  'it': 0.007544833240325458,
#  'with': 0.0062780315400037204,
#  'as': 0.006247028915114813,
#  'his': 0.006025704620769003,
#  'on': 0.005806102694472576,
#  'be': 0.005492631709484736,
#  ';': 0.004794211465459631,
#  'at': 0.004627141764669409,
#  'by': 0.004570303619039745,
#  'i': 0.0044480154875335,
#  'this': 0.004431652991064354,
#  'had': 0.004421318782768052,
#  '?': 0.00404239781190363,
#  'not': 0.003970919537854205,
#  'are': 0.0037849037885207613,
#  'but': 0.003773708396199767,
#  'from': 0.0037642353719281566,
#  'or': 0.0036230011918786903,
#  'have': 0.003395648609360037,
#  'an': 0.0032216894363722797,
#  'they': 0.0031183473534092555,
#  'which': 0.003067537495952435,
#  '--': 0.002956444756767184,
#  'one': 0.0028358789933103225,
#  'you': 0.0028307118891621715,
#  'were': 0.0028289895211127875,
#  'her': 0.002615415882989204,
#  'all': 0.0025852744421249888,
#  'she': 0.0024638474946434355,
#  'there': 0.002350171203384109,
#  'would': 0.0023381146270384226,
#  'their': 0.0022993613459272883,
#  'we': 0.0022847212175075267,
#  'him': 0.0022563021446926953,
#  'been': 0.0021297080930629906,
#  ')': 0.002124540988914839,
#  'has': 0.002099566652198775,
#  '(': 0.0020978442841493913,
#  'when': 0.002008281145581437,
#  'who': 0.0019402476076307794,
#  'will': 0.0019342193194579363,
#  'more': 0.0019083837987171803,
#  'if': 0.0018937436702974185,
#  'no': 0.0018429338128405984,
#  'out': 0.0018067640838035398,
#  'so': 0.0017103114730380505,
#  'said': 0.0016896430564454458,
#  'what': 0.0016440003031367766,
#  'up': 0.001628498990692323,
#  'its': 0.0016009411019021833,
#  'about': 0.0015639101888404328,
#  ':': 0.0015466865083465955,
#  'into': 0.001543241772247828,
#  'than': 0.0015423805882231363,
#  'them': 0.0015406582201737526,
#  'can': 0.0015268792757786825,
#  'only': 0.0015062108591860778,
#  'other': 0.0014665963940502518,
#  'new': 0.0014088970643958967,
#  'some': 0.0013942569359761349,
#  'could': 0.001379616807556373,
#  'time': 0.0013770332554822976,
#  '!': 0.0013753108874329139,
#  'these': 0.0013555036548650009,
#  'two': 0.00121685302688961,
#  'may': 0.0012082411866426914,
#  'then': 0.0011892951380994702,
#  'do': 0.0011746550096797084,
#  'first': 0.0011729326416303246,
#  'any': 0.001158292513210563,
#  'my': 0.0011359017285685743,
#  'now': 0.0011324569924698069,
#  'such': 0.0011229839681981962,
#  'like': 0.0011135109439265858,
#  'our': 0.001079063582938911,
#  'over': 0.0010652846385438412,
#  'man': 0.001040310301827777,
#  'me': 0.0010179195171857885,
#  'even': 0.0010084464929141779,
#  'most': 0.0009989734686425672,
#  'made': 0.0009696932118030437,
#  'also': 0.0009214669064202992,
#  'after': 0.0009214669064202992,
#  'did': 0.0008999373058030025,
#  'many': 0.0008878807294573162,
#  'before': 0.0008758241531116301,
#  'must': 0.0008732406010375545,
#  'af': 0.0008586004726177927,
#  'through': 0.0008370708720004961,
#  'back': 0.0008327649518770367,
#  'years': 0.0008189860074819668,
#  'where': 0.0008077906151609725,
#  'much': 0.0008077906151609725,
#  'your': 0.0007957340388152864,
#  'way': 0.0007828162784449084,
#  'well': 0.0007733432541732978,
#  'down': 0.000771620886123914,
#  'should': 0.000765592597951071,
#  'because': 0.0007612866778276117,
#  'each': 0.0007561195736794605,
#  'just': 0.000751813653556001,
#  'those': 0.00073286760501278,
#  'people': 0.0007302840529387044,
#  'mr.': 0.0007277005008646288,
#  'too': 0.0007190886606177101,
#  'how': 0.0007190886606177101,
#  'little': 0.0007165051085436345,
#  'state': 0.0006958366919510296,
#  'good': 0.0006949755079263377,
#  'very': 0.0006863636676794191,
#  'make': 0.0006846412996300353,
#  'world': 0.0006786130114571923,
#  'still': 0.000674307091333733,
#  'see': 0.0006656952510868142,
#  'own': 0.0006656952510868142,
#  'men': 0.0006579445948645874,
#  'work': 0.0006570834108398956,
#  'long': 0.0006484715705929769,
#  'here': 0.0006467492025435932,
#  'get': 0.0006458880185189013,
#  'both': 0.0006295255220497558,
#  'between': 0.0006295255220497558,
#  'life': 0.0006166077616793777,
#  'being': 0.0006140242096053021,
#  'under': 0.0006097182894818428,
#  'never': 0.0006011064492349241,
#  'day': 0.0005924946089880055,
#  'same': 0.0005916334249633136,
#  'another': 0.0005899110569139298,
#  'know': 0.0005890498728892379,
#  'while': 0.0005864663208151623,
#  'last': 0.0005830215847163949,
#  'us': 0.000582160400691703,
#  'might': 0.0005795768486176274,
#  'great': 0.0005735485604447843,
#  'old': 0.0005701038243460169,
#  'year': 0.0005675202722719413,
#  'off': 0.0005511577758027957,
#  'come': 0.000543407119580569,
#  'since': 0.0005416847515311852,
#  'against': 0.0005408235675064934,
#  'go': 0.0005399623834818015,
#  'came': 0.000536517647383034,
#  'right': 0.0005287669911608071,
#  'used': 0.0005270446231114234,
#  'take': 0.0005261834390867315,
#  'three': 0.0005261834390867315,
#  'himself': 0.0005201551509138885,
#  'states': 0.0005201551509138885,
#  'few': 0.0005184327828645048,
#  'house': 0.0005098209426175861,
#  'use': 0.0005098209426175861,
#  'during': 0.0005046538384694348,
#  'without': 0.0005029314704200511,
#  'again': 0.0004977643662718999,
#  'place': 0.0004917360780990568,
#  'american': 0.000490874894074365,
#  'around': 0.00048484660590152187,
#  'however': 0.0004762347656546032,
#  'home': 0.00047192884553114384,
#  'small': 0.0004676229254076845,
#  'found': 0.0004624558212595333,
#  'mrs.': 0.0004607334532101496,
#  '1': 0.0004547051650373065,
#  'thought': 0.00044609332479038783,
#  'went': 0.00043748148454346913,
#  'say': 0.00043489793246939354,
#  'part': 0.000431453196370626,
#  'once': 0.00043059201234593416,
#  'general': 0.0004297308283212423,
#  'high': 0.00042886964429655043,
#  'upon': 0.0004271472762471667,
#  'school': 0.00042542490819778297,
#  'every': 0.00042370254014839924,
#  "don't": 0.0004219801720990155,
#  'does': 0.00041853543600024805,
#  'got': 0.0004159518839261724,
#  'united': 0.0004159518839261724,
#  'left': 0.00041422951587678867,
#  'number': 0.00040734004367925375,
#  'course': 0.00040131175550641064,
#  'war': 0.0004004505714817188,
#  'until': 0.0003978670194076432,
#  'always': 0.0003952834673335676,
#  'away': 0.00039356109928418386,
#  'something': 0.0003883939951360326,
#  'fact': 0.000385810443061957,
#  '2': 0.00038494925903726515,
#  'water': 0.0003840880750125733,
#  'though': 0.00037978215488911396,
#  'public': 0.00037805978683973023,
#  'less': 0.0003771986028150383,
#  'put': 0.0003771986028150383,
#  'think': 0.00037375386671627085,
#  'almost': 0.000372892682691579,
#  'hand': 0.0003720314986668871,
#  'enough': 0.00037117031464219526,
#  'took': 0.0003677255785434278,
#  'far': 0.0003677255785434278,
#  'head': 0.00036600321049404407,
#  'yet': 0.0003616972903705847,
#  'government': 0.0003608361063458928,
#  'system': 0.0003591137382965091,
#  'set': 0.00035739137024712537,
#  'better': 0.00035739137024712537,
#  'told': 0.0003565301862224335,
#  'night': 0.00035480781817304977,
#  'nothing': 0.00035480781817304977,
#  'end': 0.00035308545012366604,
#  'why': 0.00034877953000020666,
#  "didn't": 0.00034619597792613107,
#  'called': 0.00034619597792613107,
#  'eyes': 0.00034619597792613107,
#  'find': 0.0003453347939014392,
#  'going': 0.00034447360987674734,
#  'look': 0.00034447360987674734,
#  'asked': 0.00034361242585205547,
#  'later': 0.0003427512418273636,
#  'knew': 0.0003410288737779799,
#  'point': 0.0003410288737779799,
#  'next': 0.000340167689753288,
#  'program': 0.000340167689753288,
#  'city': 0.00033930650572859615,
#  'business': 0.00033930650572859615,
#  'group': 0.00033672295365452055,
#  'give': 0.00033586176962982863,
#  'toward': 0.00033327821755575304,
#  'young': 0.0003324170335310612,
#  'let': 0.0003315558495063693,
#  'days': 0.0003315558495063693,
#  'room': 0.0003315558495063693,
#  'president': 0.0003298334814569856,
#  'side': 0.0003289722974322937,
#  'social': 0.00032811111340760185,
#  'present': 0.00032552756133352625,
#  'given': 0.00032552756133352625,
#  'several': 0.00032552756133352625,
#  'order': 0.0003246663773088344,
#  'national': 0.0003238051932841425,
#  'possible': 0.00032294400925945066,
#  'rather': 0.00032208282523475874,
#  'second': 0.00032208282523475874,
#  'face': 0.000320360457185375,
#  'per': 0.000320360457185375,
#  'among': 0.00031949927316068314,
#  'form': 0.00031949927316068314,
#  'often': 0.0003186380891359913,
#  'important': 0.0003186380891359913,
#  'things': 0.0003177769051112994,
#  'looked': 0.00031691572108660755,
#  'early': 0.0003160545370619157,
#  'white': 0.0003151933530372238,
#  'john': 0.0003126098009631482,
#  'case': 0.0003126098009631482,
#  'large': 0.00031174861693845636,
#  'four': 0.0003108874329137645,
#  'need': 0.0003108874329137645,
#  'big': 0.0003108874329137645,
#  'become': 0.00031002624888907263,
#  'within': 0.00031002624888907263,
#  'felt': 0.00030830388083968885,
#  'children': 0.0003065815127903051,
#  'along': 0.0003065815127903051,
#  'saw': 0.0003039979607162295,
#  'best': 0.00030313677669153766,
#  'church': 0.00030055322461746206,
#  'ever': 0.0002971084885186946,
#  'least': 0.00029624730449400274,
#  'power': 0.00029538612046931087,
#  'development': 0.0002884966482717759,
#  'seemed': 0.00028763546424708403,
#  'thing': 0.00028763546424708403,
#  'light': 0.00028763546424708403,
#  'family': 0.0002859130961977003,
#  'interest': 0.00028505191217300844,
#  'want': 0.0002833295441236247,
#  'members': 0.00028074599204954906,
#  'mind': 0.00028074599204954906,
#  'area': 0.0002798848080248572,
#  'country': 0.0002798848080248572,
#  'others': 0.00027902362400016533,
#  'although': 0.0002773012559507816,
#  'turned': 0.00027644007192608973,
#  'done': 0.00027557888790139787,
#  'open': 0.000274717703876706,
#  "'": 0.00027385651985201414,
#  'god': 0.0002729953358273223,
#  'service': 0.0002721341518026304,
#  'problem': 0.0002704117837532467,
#  'certain': 0.0002704117837532467,
#  'kind': 0.0002704117837532467,
#  'different': 0.0002695505997285548,
#  'thus': 0.0002695505997285548,
#  'began': 0.0002695505997285548,
#  'door': 0.0002695505997285548,
#  'help': 0.00026868941570386295,
#  'sense': 0.00026868941570386295,
#  'means': 0.0002678282316791711,
#  'whole': 0.00026696704765447917,
#  'matter': 0.0002661058636297873,
#  'perhaps': 0.00026524467960509544,
#  'itself': 0.00026266112753101984,
#  'york': 0.0002609387594816361,
#  "it's": 0.0002609387594816361,
#  'times': 0.0002592163914322524,
#  'law': 0.0002583552074075605,
#  'human': 0.0002583552074075605,
#  'line': 0.00025749402338286865,
#  'above': 0.0002557716553334849,
#  'name': 0.0002540492872841012,
#  'example': 0.0002523269192347174,
#  'action': 0.00025146573521002554,
#  'company': 0.0002506045511853337,
#  'hands': 0.0002497433671606418,
#  'local': 0.00024888218313594995,
#  'show': 0.00024888218313594995,
#  '3': 0.0002480209991112581,
#  'whether': 0.0002471598150865662,
#  'five': 0.0002471598150865662,
#  'history': 0.0002471598150865662,
#  'gave': 0.00024629863106187435,
#  'today': 0.0002454374470371825,
#  'either': 0.0002454374470371825,
#  'act': 0.0002445762630124906,
#  'feet': 0.0002445762630124906,
#  'across': 0.00024371507898779876,
#  'taken': 0.00024285389496310687,
#  'past': 0.00024285389496310687,
#  'quite': 0.00024285389496310687,
#  'anything': 0.000241992710938415,
#  'seen': 0.00024113152691372314,
#  'having': 0.00024113152691372314,
#  'death': 0.0002394091588643394,
#  'experience': 0.00023854797483964754,
#  'body': 0.00023854797483964754,
#  'week': 0.00023768679081495568,
#  'half': 0.00023768679081495568,
#  'really': 0.00023768679081495568,
#  'word': 0.0002368256067902638,
#  'field': 0.0002368256067902638,
#  'car': 0.0002368256067902638,
#  'words': 0.0002368256067902638,
#  'already': 0.00023596442276557192,
#  'themselves': 0.00023338087069149632,
#  "i'm": 0.00023251968666680446,
#  'information': 0.00023251968666680446,
#  'tell': 0.0002316585026421126,
#  'shall': 0.0002316585026421126,
#  'together': 0.00023079731861742073,
#  'college': 0.00023079731861742073,
#  'money': 0.00022907495056803697,
#  'period': 0.00022907495056803697,
#  'held': 0.0002282137665433451,
#  'keep': 0.0002282137665433451,
#  'sure': 0.00022735258251865324,
#  'probably': 0.0002256302144692695,
#  'free': 0.00022390784641988578,
#  'seems': 0.00022390784641988578,
#  'political': 0.00022304666239519392,
#  'real': 0.00022304666239519392,
#  'cannot': 0.00022304666239519392,
#  'behind': 0.00022304666239519392,
#  'question': 0.00022218547837050203,
#  'air': 0.00022218547837050203,
#  'office': 0.0002204631103211183,
#  'making': 0.0002204631103211183,
#  'brought': 0.00021874074227173457,
#  'miss': 0.00021874074227173457,
#  'whose': 0.00021701837422235084,
#  'special': 0.00021615719019765897,
#  'major': 0.00021357363812358335,
#  'heard': 0.00021357363812358335,
#  'problems': 0.00021357363812358335,
#  'federal': 0.00021271245409889148,
#  'became': 0.00021271245409889148,
#  'study': 0.00021271245409889148,
#  'ago': 0.00021271245409889148,
#  'moment': 0.00021271245409889148,
#  'available': 0.00021185127007419962,
#  'known': 0.00021185127007419962,
#  'result': 0.00021099008604950775,
#  'street': 0.00021099008604950775,
#  'economic': 0.0002101289020248159,
#  'boy': 0.00020926771800012402,
#  'position': 0.00020840653397543213,
#  'reason': 0.00020840653397543213,
#  'change': 0.00020754534995074027,
#  'south': 0.00020754534995074027,
#  'board': 0.0002066841659260484,
#  'individual': 0.0002066841659260484,
#  'job': 0.00020582298190135654,
#  'am': 0.00020496179787666467,
#  'society': 0.00020496179787666467,
#  'areas': 0.0002041006138519728,
#  'west': 0.00020323942982728094,
#  'close': 0.00020237824580258905,
#  'turn': 0.00020151706177789719,
#  'community': 0.00019979469372851346,
#  'true': 0.00019979469372851346,
#  'love': 0.00019979469372851346,
#  'court': 0.0001989335097038216,
#  'force': 0.0001989335097038216,
#  'full': 0.0001989335097038216,
#  'cost': 0.00019807232567912973,
#  'seem': 0.00019807232567912973,
#  'wife': 0.00019721114165443786,
#  'future': 0.000196349957629746,
#  'age': 0.000196349957629746,
#  'wanted': 0.0001954887736050541,
#  'voice': 0.0001954887736050541,
#  'department': 0.00019462758958036224,
#  'center': 0.00019376640555567037,
#  'woman': 0.00019376640555567037,
#  'control': 0.0001929052215309785,
#  'common': 0.0001929052215309785,
#  'policy': 0.00019204403750628664,
#  'necessary': 0.00019204403750628664,
#  'following': 0.00019118285348159478,
#  'front': 0.00019118285348159478,
#  'sometimes': 0.00019118285348159478,
#  'six': 0.00019032166945690291,
#  'girl': 0.00019032166945690291,
#  'clear': 0.00018946048543221105,
#  'further': 0.00018859930140751916,
#  'land': 0.00018859930140751916,
#  'provide': 0.00018687693335813543,
#  'feel': 0.00018687693335813543,
#  'party': 0.00018687693335813543,
#  'able': 0.00018687693335813543,
#  'mother': 0.00018687693335813543,
#  'music': 0.00018687693335813543,
#  'education': 0.0001851545653087517,
#  'university': 0.0001851545653087517,
#  'child': 0.00018429338128405983,
#  'effect': 0.00018429338128405983,
#  'students': 0.00018429338128405983,
#  'level': 0.00018429338128405983,
#  'run': 0.00018343219725936797,
#  'stood': 0.00018343219725936797,
#  'military': 0.00018343219725936797,
#  'town': 0.00018343219725936797,
#  'short': 0.00018343219725936797,
#  'morning': 0.0001825710132346761,
#  'total': 0.0001825710132346761,
#  'outside': 0.0001817098292099842,
#  'rate': 0.00018084864518529234,
#  'figure': 0.00018084864518529234,
#  'art': 0.00017998746116060048,
#  'century': 0.00017912627713590862,
#  'class': 0.00017912627713590862,
#  'washington': 0.00017826509311121675,
#  '4': 0.00017826509311121675,
#  'north': 0.00017826509311121675,
#  'usually': 0.00017826509311121675,
#  'plan': 0.00017740390908652489,
#  'leave': 0.00017740390908652489,
#  'therefore': 0.00017740390908652489,
#  'evidence': 0.00017654272506183302,
#  'top': 0.00017654272506183302,
#  'million': 0.00017654272506183302,
#  'sound': 0.00017654272506183302,
#  'black': 0.00017568154103714116,
#  'strong': 0.00017482035701244926,
#  'hard': 0.00017482035701244926,
#  'tax': 0.0001739591729877574,
#  'various': 0.0001739591729877574,
#  'says': 0.00017309798896306553,
#  'believe': 0.00017309798896306553,
#  'type': 0.00017309798896306553,
#  'value': 0.00017309798896306553,
#  'play': 0.00017309798896306553,
#  'surface': 0.00017309798896306553,
#  'soon': 0.00017223680493837367,
#  'mean': 0.00017223680493837367,
#  'near': 0.0001713756209136818,
#  'lines': 0.0001713756209136818,
#  'table': 0.0001713756209136818,
#  'peace': 0.0001713756209136818,
#  'modern': 0.0001713756209136818,
#  'road': 0.00017051443688898994,
#  'red': 0.00017051443688898994,
#  'book': 0.00017051443688898994,
#  'personal': 0.00016965325286429807,
#  'process': 0.00016965325286429807,
#  'situation': 0.00016965325286429807,
#  'minutes': 0.00016965325286429807,
#  'increase': 0.0001687920688396062,
#  'schools': 0.0001687920688396062,
#  'idea': 0.0001687920688396062,
#  'english': 0.0001687920688396062,
#  'alone': 0.0001687920688396062,
#  'women': 0.0001687920688396062,
#  'gone': 0.0001687920688396062,
#  'nor': 0.0001687920688396062,
#  'living': 0.00016793088481491432,
#  'america': 0.00016793088481491432,
#  'started': 0.00016793088481491432,
#  'longer': 0.00016706970079022245,
#  'dr.': 0.0001662085167655306,
#  'cut': 0.0001662085167655306,
#  'finally': 0.00016534733274083872,
#  'secretary': 0.00016534733274083872,
#  'nature': 0.00016534733274083872,
#  'private': 0.00016534733274083872,
#  'third': 0.00016448614871614686,
#  'months': 0.000163624964691455,
#  'section': 0.000163624964691455,
#  'greater': 0.00016276378066676313,
#  'call': 0.00016276378066676313,
#  'fire': 0.00016190259664207126,
#  'expected': 0.00016190259664207126,
#  'needed': 0.00016190259664207126,
#  "that's": 0.00016190259664207126,
#  'kept': 0.00016104141261737937,
#  'ground': 0.00016104141261737937,
#  'view': 0.00016104141261737937,
#  'values': 0.00016104141261737937,
#  'everything': 0.0001601802285926875,
#  'pressure': 0.0001601802285926875,
#  'dark': 0.0001601802285926875,
#  'basis': 0.00015931904456799564,
#  'space': 0.00015931904456799564,
#  'east': 0.00015845786054330377,
#  'father': 0.00015845786054330377,
#  'required': 0.0001575966765186119,
#  'union': 0.0001575966765186119,
#  'spirit': 0.0001575966765186119,
#  'complete': 0.0001575966765186119,
#  'except': 0.00015673549249392004,
#  'wrote': 0.00015673549249392004,
#  "i'll": 0.00015673549249392004,
#  'moved': 0.00015673549249392004,
#  'support': 0.00015587430846922818,
#  'return': 0.00015587430846922818,
#  'conditions': 0.00015587430846922818,
#  'recent': 0.00015501312444453632,
#  'attention': 0.00015501312444453632,
#  'late': 0.00015501312444453632,
#  'particular': 0.00015501312444453632,
#  'live': 0.00015329075639515256,
#  'hope': 0.00015329075639515256,
#  'costs': 0.0001524295723704607,
#  'else': 0.0001524295723704607,
#  'brown': 0.0001524295723704607,
#  'taking': 0.00015156838834576883,
#  "couldn't": 0.00015156838834576883,
#  'forces': 0.00015156838834576883,
#  'nations': 0.00015156838834576883,
#  'beyond': 0.00015156838834576883,
#  'stage': 0.00015156838834576883,
#  'read': 0.00015070720432107696,
#  'report': 0.00015070720432107696,
#  'coming': 0.00015070720432107696,
#  'hours': 0.00015070720432107696,
#  'person': 0.00015070720432107696,
#  'inside': 0.00015070720432107696,
#  'dead': 0.00015070720432107696,
#  'material': 0.00015070720432107696,
#  'instead': 0.0001498460202963851,
#  'lost': 0.0001498460202963851,
#  'heart': 0.0001498460202963851,
#  'looking': 0.0001498460202963851,
#  'low': 0.0001498460202963851,
#  'miles': 0.0001498460202963851,
#  'data': 0.0001498460202963851,
#  'added': 0.00014898483627169323,
#  'pay': 0.00014898483627169323,
#  'amount': 0.00014898483627169323,
#  'followed': 0.00014898483627169323,
#  'feeling': 0.00014898483627169323,
#  '1960': 0.00014898483627169323,
#  'single': 0.00014898483627169323,
#  'makes': 0.00014898483627169323,
#  'research': 0.00014812365224700137,
#  'including': 0.00014812365224700137,
#  'basic': 0.00014812365224700137,
#  'hundred': 0.00014812365224700137,
#  'move': 0.00014812365224700137,
#  'industry': 0.00014812365224700137,
#  'cold': 0.00014812365224700137,
#  'simply': 0.00014812365224700137,
#  'developed': 0.00014726246822230948,
#  'tried': 0.00014726246822230948,
#  'hold': 0.0001464012841976176,
#  "can't": 0.0001464012841976176,
#  'reached': 0.0001464012841976176,
#  'committee': 0.00014554010017292575,
#  'island': 0.00014467891614823388,
#  'defense': 0.00014467891614823388,
#  'equipment': 0.00014467891614823388,
#  'actually': 0.00014381773212354202,
#  'shown': 0.00014381773212354202,
#  'son': 0.00014295654809885015,
#  'central': 0.00014295654809885015,
#  'religious': 0.00014295654809885015,
#  'river': 0.00014295654809885015,
#  'getting': 0.0001420953640741583,
#  'st.': 0.0001420953640741583,
#  'beginning': 0.0001420953640741583,
#  'sort': 0.0001420953640741583,
#  'ten': 0.0001420953640741583,
#  'received': 0.00014123418004946642,
#  '&': 0.00014123418004946642,
#  'doing': 0.00014123418004946642,
#  'terms': 0.00014123418004946642,
#  'trying': 0.00014123418004946642,
#  'rest': 0.00014123418004946642,
#  'medical': 0.00014037299602477453,
#  'u.s.': 0.00014037299602477453,
#  'care': 0.00014037299602477453,
#  'especially': 0.00014037299602477453,
#  'friends': 0.00014037299602477453,
#  'picture': 0.00014037299602477453,
#  'indeed': 0.00014037299602477453,
#  'administration': 0.00013951181200008266,
#  'fine': 0.00013951181200008266,
#  'subject': 0.00013951181200008266,
#  'difficult': 0.00013951181200008266,
#  'building': 0.0001386506279753908,
#  'higher': 0.0001386506279753908,
#  'wall': 0.0001386506279753908,
#  'simple': 0.0001386506279753908,
#  'meeting': 0.00013778944395069893,
#  'walked': 0.00013778944395069893,
#  'floor': 0.00013692825992600707,
#  'foreign': 0.00013692825992600707,
#  'bring': 0.00013692825992600707,
#  'similar': 0.0001360670759013152,
#  'passed': 0.0001360670759013152,
#  'range': 0.0001360670759013152,
#  'paper': 0.0001360670759013152,
#  'property': 0.00013520589187662334,
#  'natural': 0.00013520589187662334,
#  'final': 0.00013520589187662334,
#  'training': 0.00013520589187662334,
#  'county': 0.00013434470785193147,
#  'police': 0.00013434470785193147,
#  'cent': 0.00013434470785193147,
#  'international': 0.00013434470785193147,
#  'growth': 0.00013434470785193147,
#  'market': 0.00013434470785193147,
#  "wasn't": 0.00013348352382723958,
#  'talk': 0.00013348352382723958,
#  'start': 0.00013348352382723958,
#  'england': 0.00013348352382723958,
#  'written': 0.00013348352382723958,
#  'hear': 0.00013262233980254772,
#  'suddenly': 0.00013262233980254772,
#  'story': 0.00013262233980254772,
#  'issue': 0.00013176115577785585,
#  'congress': 0.00013176115577785585,
#  'needs': 0.00013176115577785585,
#  '10': 0.00013176115577785585,
#  'answer': 0.00013176115577785585,
#  'hall': 0.00013176115577785585,
#  'likely': 0.000130899971753164,
#  'working': 0.000130899971753164,
#  'countries': 0.000130899971753164,
#  'considered': 0.000130899971753164,
#  "you're": 0.000130899971753164,
#  'earth': 0.00013003878772847212,
#  'sat': 0.00013003878772847212,
#  'purpose': 0.00012917760370378026,
#  'meet': 0.00012917760370378026,
#  'labor': 0.00012917760370378026,
#  'results': 0.00012917760370378026,
#  'entire': 0.00012917760370378026,
#  'happened': 0.00012917760370378026,
#  'william': 0.0001283164196790884,
#  'cases': 0.0001283164196790884,
#  'stand': 0.0001283164196790884,
#  'difference': 0.0001283164196790884,
#  'production': 0.0001283164196790884,
#  'hair': 0.0001283164196790884,
#  'involved': 0.00012745523565439653,
#  'fall': 0.00012745523565439653,
#  'stock': 0.00012745523565439653,
#  'food': 0.00012745523565439653,
#  'earlier': 0.00012659405162970464,
#  'increased': 0.00012659405162970464,
#  'whom': 0.00012659405162970464,
#  'particularly': 0.00012659405162970464,
#  'paid': 0.00012573286760501277,
#  'sent': 0.00012573286760501277,
#  'effort': 0.00012573286760501277,
#  'knowledge': 0.00012573286760501277,
#  'hour': 0.00012573286760501277,
#  'letter': 0.00012573286760501277,
#  'club': 0.00012573286760501277,
#  'using': 0.00012573286760501277,
#  'below': 0.00012573286760501277,
#  'thinking': 0.00012573286760501277,
#  'yes': 0.0001248716835803209,
#  'christian': 0.0001248716835803209,
#  'blue': 0.00012401049955562904,
#  'ready': 0.00012401049955562904,
#  'bill': 0.00012401049955562904,
#  'deal': 0.00012401049955562904,
#  'points': 0.00012401049955562904,
#  'trade': 0.00012401049955562904,
#  'certainly': 0.00012401049955562904,
#  'ideas': 0.00012401049955562904,
#  'industrial': 0.00012401049955562904,
#  'square': 0.00012401049955562904,
#  'boys': 0.00012401049955562904,
#  'methods': 0.00012314931553093718,
#  'addition': 0.00012314931553093718,
#  'method': 0.00012314931553093718,
#  'bad': 0.00012314931553093718,
#  'due': 0.00012314931553093718,
#  '5': 0.00012314931553093718,
#  'girls': 0.00012314931553093718,
#  'moral': 0.00012314931553093718,
#  'decided': 0.0001222881315062453,
#  'reading': 0.0001222881315062453,
#  'statement': 0.0001222881315062453,
#  'weeks': 0.0001222881315062453,
#  'neither': 0.0001222881315062453,
#  'nearly': 0.0001222881315062453,
#  'directly': 0.0001222881315062453,
#  'showed': 0.0001222881315062453,
#  'throughout': 0.0001222881315062453,
#  'according': 0.00012142694748155343,
#  'questions': 0.00012142694748155343,
#  'color': 0.00012142694748155343,
#  'kennedy': 0.00012142694748155343,
#  'anyone': 0.00012142694748155343,
#  'try': 0.00012142694748155343,
#  'services': 0.00012056576345686157,
#  'programs': 0.00012056576345686157,
#  'nation': 0.00012056576345686157,
#  'lay': 0.00012056576345686157,
#  'french': 0.00012056576345686157,
#  'size': 0.0001197045794321697,
#  'remember': 0.0001197045794321697,
#  'physical': 0.0001197045794321697,
#  'record': 0.00011884339540747784,
#  'member': 0.00011884339540747784,
#  'comes': 0.00011884339540747784,
#  'understand': 0.00011884339540747784,
#  'southern': 0.00011884339540747784,
#  'western': 0.00011884339540747784,
#  'strength': 0.00011884339540747784,
#  'population': 0.00011798221138278596,
#  'normal': 0.00011798221138278596,
#  'merely': 0.0001171210273580941,
#  'district': 0.0001171210273580941,
#  'volume': 0.0001171210273580941,
#  'concerned': 0.0001171210273580941,
#  'appeared': 0.0001171210273580941,
#  'temperature': 0.0001171210273580941,
#  '1961': 0.00011625984333340223,
#  'aid': 0.00011625984333340223,
#  'trouble': 0.00011625984333340223,
#  'trial': 0.00011625984333340223,
#  'summer': 0.00011625984333340223,
#  'direction': 0.00011625984333340223,
#  'ran': 0.00011625984333340223,
#  'sales': 0.00011539865930871036,
#  'list': 0.00011539865930871036,
#  'continued': 0.00011539865930871036,
#  'friend': 0.00011539865930871036,
#  'evening': 0.00011539865930871036,
#  'maybe': 0.00011539865930871036,
#  'literature': 0.00011539865930871036,
#  'generally': 0.00011453747528401849,
#  'association': 0.00011453747528401849,
#  'provided': 0.00011453747528401849,
#  'led': 0.00011453747528401849,
#  'army': 0.00011453747528401849,
#  'met': 0.00011453747528401849,
#  'influence': 0.00011453747528401849,
#  'opened': 0.00011367629125932662,
#  'former': 0.00011367629125932662,
#  'science': 0.00011367629125932662,
#  'student': 0.00011367629125932662,
#  'step': 0.00011367629125932662,
#  'changes': 0.00011367629125932662,
#  'chance': 0.00011367629125932662,
#  'husband': 0.00011367629125932662,
#  'hot': 0.00011281510723463476,
#  'series': 0.00011281510723463476,
#  'average': 0.00011281510723463476,
#  'works': 0.00011281510723463476,
#  'month': 0.00011281510723463476,
#  'cause': 0.00011281510723463476,
#  'effective': 0.00011195392320994289,
#  'george': 0.00011195392320994289,
#  'planning': 0.00011195392320994289,
#  'systems': 0.00011195392320994289,
#  "wouldn't": 0.00011195392320994289,
#  'direct': 0.00011195392320994289,
#  'soviet': 0.00011195392320994289,
#  'stopped': 0.00011195392320994289,
#  'wrong': 0.00011195392320994289,
#  'lead': 0.00011195392320994289,
#  'myself': 0.00011195392320994289,
#  'piece': 0.00011195392320994289,
#  'theory': 0.00011195392320994289,
#  'ask': 0.00011109273918525101,
#  'worked': 0.00011109273918525101,
#  'freedom': 0.00011109273918525101,
#  'organization': 0.00011109273918525101,
#  'clearly': 0.00011109273918525101,
#  'movement': 0.00011109273918525101,
#  'ways': 0.00011109273918525101,
#  'press': 0.00011023155516055915,
#  'somewhat': 0.00011023155516055915,
#  'spring': 0.00011023155516055915,
#  'efforts': 0.00011023155516055915,
#  'consider': 0.00011023155516055915,
#  'meaning': 0.00011023155516055915,
#  'bed': 0.00011023155516055915,
#  'fear': 0.00011023155516055915,
#  'lot': 0.00011023155516055915,
#  'treatment': 0.00011023155516055915,
#  'beautiful': 0.00011023155516055915,
#  'note': 0.00011023155516055915,
#  'forms': 0.00011023155516055915,
#  'placed': 0.00010937037113586728,
#  'hotel': 0.00010937037113586728,
#  'truth': 0.00010937037113586728,
#  'apparently': 0.00010850918711117542,
#  'degree': 0.00010850918711117542,
#  'groups': 0.00010850918711117542,
#  "he's": 0.00010850918711117542,
#  'plant': 0.00010850918711117542,
#  'carried': 0.00010850918711117542,
#  'wide': 0.00010850918711117542,
#  "i've": 0.00010850918711117542,
#  'respect': 0.00010850918711117542,
#  "man's": 0.00010850918711117542,
#  'herself': 0.00010850918711117542,
#  'numbers': 0.00010850918711117542,
#  'manner': 0.00010764800308648354,
#  'reaction': 0.00010764800308648354,
#  'easy': 0.00010764800308648354,
#  'farm': 0.00010764800308648354,
#  'immediately': 0.00010678681906179167,
#  'running': 0.00010678681906179167,
#  'approach': 0.00010678681906179167,
#  'game': 0.00010678681906179167,
#  'recently': 0.00010678681906179167,
#  'larger': 0.00010678681906179167,
#  'lower': 0.00010678681906179167,
#  'charge': 0.00010592563503709981,
#  'couple': 0.00010592563503709981,
#  'de': 0.00010592563503709981,
#  'daily': 0.00010592563503709981,
#  'eye': 0.00010592563503709981,
#  'performance': 0.00010592563503709981,
#  'feed': 0.00010592563503709981,
#  'oh': 0.00010592563503709981,
#  'march': 0.00010506445101240794,
#  'persons': 0.00010506445101240794,
#  'understanding': 0.00010506445101240794,
#  'arms': 0.00010506445101240794,
#  'opportunity': 0.00010506445101240794,
#  'c': 0.00010506445101240794,
#  'blood': 0.00010506445101240794,
#  'additional': 0.00010420326698771607,
#  'j.': 0.00010420326698771607,
#  'technical': 0.00010420326698771607,
#  'fiscal': 0.00010420326698771607,
#  'radio': 0.00010420326698771607,
#  'described': 0.00010420326698771607,
#  'stop': 0.00010420326698771607,
#  'progress': 0.00010420326698771607,
#  'steps': 0.0001033420829630242,
#  'test': 0.0001033420829630242,
#  'chief': 0.0001033420829630242,
#  'reported': 0.0001033420829630242,
#  'served': 0.0001033420829630242,
#  'based': 0.0001033420829630242,
#  'main': 0.0001033420829630242,
#  'determined': 0.0001033420829630242,
#  'image': 0.0001033420829630242,
#  'decision': 0.0001033420829630242,
#  'window': 0.0001033420829630242,
#  'religion': 0.0001033420829630242,
#  'aj': 0.00010248089893833234,
#  'gun': 0.00010248089893833234,
#  'responsibility': 0.00010248089893833234,
#  'middle': 0.00010248089893833234,
#  'europe': 0.00010248089893833234,
#  'british': 0.00010248089893833234,
#  'character': 0.00010248089893833234,
#  'learned': 0.00010161971491364047,
#  'horse': 0.00010161971491364047,
#  'writing': 0.00010161971491364047,
#  'appear': 0.00010161971491364047,
#  's.': 0.00010161971491364047,
#  'account': 0.00010161971491364047,
#  'ones': 0.00010075853088894859,
#  'serious': 0.00010075853088894859,
#  'activity': 0.00010075853088894859,
#  'types': 0.00010075853088894859,
#  'green': 0.00010075853088894859,
#  'length': 0.00010075853088894859,
#  'lived': 9.989734686425673e-05,
#  'audience': 9.989734686425673e-05,
#  'letters': 9.989734686425673e-05,
#  'returned': 9.989734686425673e-05,
#  'obtained': 9.989734686425673e-05,
#  'nuclear': 9.989734686425673e-05,
#  'specific': 9.989734686425673e-05,
#  'corner': 9.989734686425673e-05,
#  'forward': 9.989734686425673e-05,
#  'activities': 9.989734686425673e-05,
#  'slowly': 9.989734686425673e-05,
#  'doubt': 9.903616283956486e-05,
#  '6': 9.903616283956486e-05,
#  'justice': 9.903616283956486e-05,
#  'moving': 9.903616283956486e-05,
#  'latter': 9.903616283956486e-05,
#  'gives': 9.903616283956486e-05,
#  'straight': 9.903616283956486e-05,
#  'hit': 9.903616283956486e-05,
#  'plane': 9.903616283956486e-05,
#  'quality': 9.903616283956486e-05,
#  'design': 9.903616283956486e-05,
#  'obviously': 9.903616283956486e-05,
#  'operation': 9.8174978814873e-05,
#  'plans': 9.8174978814873e-05,
#  'shot': 9.8174978814873e-05,
#  'seven': 9.8174978814873e-05,
#  'a.': 9.8174978814873e-05,
#  'choice': 9.8174978814873e-05,
#  'poor': 9.8174978814873e-05,
#  'staff': 9.8174978814873e-05,
#  'function': 9.8174978814873e-05,
#  'figures': 9.8174978814873e-05,
#  'parts': 9.8174978814873e-05,
#  'stay': 9.8174978814873e-05,
#  'saying': 9.8174978814873e-05,
#  'include': 9.8174978814873e-05,
#  '15': 9.8174978814873e-05,
#  'born': 9.8174978814873e-05,
#  'pattern': 9.8174978814873e-05,
#  '30': 9.731379479018112e-05,
#  'cars': 9.731379479018112e-05,
#  'whatever': 9.731379479018112e-05,
#  'sun': 9.731379479018112e-05,
#  'faith': 9.645261076548925e-05,
#  'pool': 9.645261076548925e-05,
#  'hospital': 9.559142674079739e-05,
#  'corps': 9.559142674079739e-05,
#  'wish': 9.559142674079739e-05,
#  'lack': 9.559142674079739e-05,
#  'completely': 9.559142674079739e-05,
#  'heavy': 9.559142674079739e-05,
#  'waiting': 9.559142674079739e-05,
#  'speak': 9.559142674079739e-05,
#  'ball': 9.559142674079739e-05,
#  'standard': 9.559142674079739e-05,
#  'extent': 9.559142674079739e-05,
#  'visit': 9.473024271610552e-05,
#  'democratic': 9.473024271610552e-05,
#  'firm': 9.473024271610552e-05,
#  'income': 9.473024271610552e-05,
#  'ahead': 9.473024271610552e-05,
#  'deep': 9.473024271610552e-05,
#  "there's": 9.473024271610552e-05,
#  'language': 9.473024271610552e-05,
#  'principle': 9.473024271610552e-05,
#  'none': 9.386905869141365e-05,
#  'price': 9.386905869141365e-05,
#  'designed': 9.386905869141365e-05,
#  'indicated': 9.386905869141365e-05,
#  'analysis': 9.386905869141365e-05,
#  'distance': 9.386905869141365e-05,
#  'expect': 9.386905869141365e-05,
#  'established': 9.386905869141365e-05,
#  'products': 9.386905869141365e-05,
#  'effects': 9.386905869141365e-05,
#  'growing': 9.386905869141365e-05,
#  'importance': 9.386905869141365e-05,
#  'continue': 9.300787466672178e-05,
#  'serve': 9.300787466672178e-05,
#  'determine': 9.300787466672178e-05,
#  'cities': 9.300787466672178e-05,
#  'elements': 9.300787466672178e-05,
#  'negro': 9.300787466672178e-05,
#  'leaders': 9.300787466672178e-05,
#  'division': 9.300787466672178e-05,
#  ...}

# %% [markdown]
# ### Step 3.2: Possible words using a unigram language model
#
# This is an intermediate step that I conducted in order to see whether the step above was conducted decently, whether the absolute probabilities would give me any clue as to what word might have been intended, and which between the **Brown corpus** and **the big.txt corpus** was the best option.
#
# This is an example of a **unigram language model** (only one word taken into account). I used the *acress* example that was seen throughout this report already.

# %%
def abs_prob(typo, corpus):
    """Function that takes a typo in the form of a string and a corpus in the form of a list
    and returns a dictionary of probabilities for all possible correction candidates"""
    count = {}
    freq_ = dict_freq(corpus)
    for poss_word in intended_possible_words(typo):
        if poss_word in freq_.keys():
            count[poss_word] = (freq_[poss_word],'{0:.10f}'.format((freq_[poss_word])/(len(corpus)))) #format up to 10 decimal places
        prob = {k: v for k, v in sorted(count.items(), key=lambda x: x[1], reverse = True)}
    return prob

# %% [markdown]
# Options for *acress* in the corpora:

# %%
acress_big = abs_prob("acress", big_txt)

# %%
acress_brown = abs_prob("acress", brown_words)

# %%
import pandas as pd #to make a nice table

pd.DataFrame.from_dict(acress_big, orient='index',
                       columns=['count(w)', 'p(w)'])
# Out:
#          count(w)          p(w)
# across        221  0.0001714825
# access         57  0.0000442285
# acres          37  0.0000287097
# actress         8  0.0000062075
# caress          4  0.0000031038

# %%
pd.DataFrame.from_dict(acress_brown, orient='index',
                       columns=['count(w)', 'p(w)'])
# Out:
#          count(w)          p(w)
# across        283  0.0002437151
# acres          45  0.0000387533
# access         25  0.0000215296
# actress         7  0.0000060283
# caress          2  0.0000017224

# %% [markdown]
# Let's compare with [Jurafsky & Martin's (2020, p. 4)](https://web.stanford.edu/~jurafsky/slp3/B.pdf) table: ![image.png](attachment:image.png)
# The **big.txt corpus** seems to be doing a better job in this unigram model, since *access* should have a higher p(w) than *acres*. Therefore, I will use the big_txt corpus for my aims.

# %% [markdown]
# ## Step 4: Error model/likelihood calculation: calculating the conditional probabilities of character permutations
#
# In this section, I develop functions that will tell me the probabilities of some characters in the target being mistyped as some other characters in the typo. In order to do that, I used a [typo corpus](http://norvig.com/ngrams/spell-errors.txt) by Norvig, made a dictionary out of it, and divided the typos corpus into the different **error-specific typo corpora** (deletion, insertion, substitution, transposition).
#
# For each created corpus, I then developed functions to give me **conditional probabilities** for character permutations in that specific error type. Finally, I developed functions that give the best candidates for each type of typo, which is the **noisy channel probability**.
#
# An example:
#
# **ehllo|hello**:
# --> *ehllo* typed given intended *hello* <br>
# --> **transposition error** <br>
# --> we need **p(eh|he)** <br>
# --> we get that from a **transposition typo corpus** --> how many times was **he** misspelled as **eh**? <br>
# --> multiply **p(eh|he)** by **p(hello)** <br>
# --> **hello** should be best candidate

# %% [markdown]
# ### Step 4.1 Extracting and cleaning the typo corpus
#
# First of all, I made a dictionary out of the [spell-errors.txt corpus](http://norvig.com/ngrams/spell-errors.txt) by Norvig. I used the editdistance module to extract only typos that are 1 edit distance away from the target.

# %%
import re
import editdistance

# %%
editdistance.eval("acress", "actress")
# Out:
# 1

# %% [markdown]
# Transposition is considered as an edit distance of 2: we are going to therefore include transposition as a condition later.

# %%
editdistance.eval("atcress", "actress")
# Out:
# 2

# %%
punctuation = r"[.!?:,]|\*[1-9]" #to remove all strings with a number and/or punctuation
with open("/Users/sashakenjeeva/Desktop/Sasha/Masters/Trento/Fall 2020/Computational Skills for Text Analysis/Coding/Project/spell-errors.txt", "r") as mistakes:
    spell_errors = []
    read_mistakes = mistakes.read() #read
    split_lines = read_mistakes.split("\n") #split with argument new line
    for line in split_lines:
        new_line = re.sub(punctuation, "", line).lower() #substitute any punctuation or number with an empty string and lower the line
        tok = word_tokenize(new_line) #tokenize, so it becomes a list of word
        spell_errors.append(tok) #append each tokenized line to the spell error list

# %%
spell_errors
# Out:
# [['raining', 'rainning', 'raning'],
#  ['writings', 'writtings'],
#  ['disparagingly', 'disparingly'],
#  ['yellow', 'yello'],
#  ['four', 'forer', 'fours', 'fuore', 'fore', 'for'],
#  ['woods', 'woodes'],
#  ['hanging', 'haing'],
#  ['aggression', 'agression'],
#  ['looking',
#   'loking',
#   'luing',
#   'look',
#   'locking',
#   'lucking',
#   'louk',
#   'looing',
#   'lookin',
#   'liking'],
#  ['eligible', 'eligble', 'elegable', 'eligable'],
#  ['electricity', 'electrisity', 'electricty', 'electrizity'],
#  ['scold', 'schold', 'skold'],
#  ['adaptable', 'adabtable'],
#  ['caned', 'canned', 'cained'],
#  ['immature', 'imature'],
#  ['should', "n't", 'shoudln', 'shouldnt'],
#  ['swivel', 'swival'],
#  ['appropriation', 'apropriation'],
#  ['fur', 'furr', 'fer'],
#  ['stabbed', 'stabed'],
#  ['southwold', 'suothwode'],
#  ['disturb', 'distrebe', 'desturb'],
#  ['recollections', 'reclections', 'recolections'],
#  ['prize', 'prise', 'prizer'],
#  ['wednesday', 'wensday', 'wedensday'],
#  ['succession', 'sucession', 'sucesion', 'succesion'],
#  ['straight', 'strate', 'strait', 'staidght', 'stright'],
#  ['guardsmen', 'gards_men'],
#  ['incremented', 'increented'],
#  ['bacon', 'backen', 'baken'],
#  ['pulse', 'pluse'],
#  ['elegant', 'elagent', 'elligit'],
#  ['second', 'secand', 'sexeon', 'secund', 'seconnd', 'seond', 'sekon'],
#  ['jamjar', 'jam_jar'],
#  ['sailed', 'saled', 'saild'],
#  ['blouse', 'boludes'],
#  ['thunder', 'thounder'],
#  ['cooking', 'coking', 'chocking', 'kooking', 'cocking'],
#  ['fossil', 'fosscil'],
#  ['increasing',
#   'incased',
#   'ingreesh_this',
#   'incresing',
#   'incriosing',
#   'increacing',
#   'incressing',
#   'increcing',
#   'ingeker',
#   'incrsin',
#   'inceasing',
#   'inceing',
#   'increase',
#   'insest',
#   'ingcresing',
#   'incuiseing',
#   'enchres',
#   'intheris',
#   'incesing',
#   'encreing',
#   'increesing',
#   'crace',
#   'encrising',
#   'increaseng',
#   'encressing',
#   'in_cresing',
#   'incrising',
#   'incersinges',
#   'changing',
#   'incesting',
#   'encreasing',
#   'crissing',
#   'incriasing',
#   'incsin',
#   'incing',
#   'increaseing',
#   'ingesing',
#   'imceasing',
#   'incristing',
#   'engressing',
#   'ingresin',
#   'incrase',
#   'encash'],
#  ['hero', 'heroe'],
#  ['dahl', 'dael'],
#  ['reporter',
#   'repoter',
#   'rebarter',
#   'reportor',
#   'reproter',
#   'reoporter',
#   'repoted',
#   'reporet',
#   'peportery'],
#  ['interrupting', 'interupting'],
#  ['here',
#   'hiar',
#   'hare',
#   'hir',
#   'hair',
#   'haiw',
#   'liet',
#   'hreb',
#   'hah',
#   'her',
#   'hes',
#   'hiyr',
#   'there',
#   'three',
#   'hay',
#   'hea',
#   'herre',
#   'har',
#   'werr',
#   'head',
#   'heere',
#   'hera',
#   'heir',
#   'herd',
#   'heat',
#   'hear1',
#   'handr',
#   'he',
#   'heer',
#   'hree',
#   'hire',
#   'thehe',
#   'hon',
#   'eate',
#   'poit'],
#  ['atoms', 'atom'],
#  ['tape-recorded', 'tape_recorded'],
#  ['shriek', 'shreik'],
#  ['substance', 'substace'],
#  ['elaborate', 'elaberate'],
#  ['climbed', 'climb', 'climed', 'cimed'],
#  ['reports', 'reoprts'],
#  ['controversy',
#   'contervercing',
#   'contervercuy',
#   'consonerse',
#   'counteversy',
#   'contravercy',
#   'contronversey',
#   'contiversey',
#   'countirversay',
#   'countrovesy',
#   'counterversing',
#   'comsversiary',
#   'controversave',
#   'contevesy',
#   'controveries',
#   'controversey',
#   'controvercy',
#   'contraversally',
#   'conteversy',
#   'comtevercy',
#   'controversaries',
#   'countufersey',
#   'controvarsey',
#   'conqouversing',
#   'contriversy',
#   'contraversey',
#   'controvesey',
#   'contraverse',
#   'countroversy',
#   'contraversy',
#   'constroversy',
#   'contruevency',
#   'connesary',
#   'contavercy',
#   'conversity',
#   'contretearsing',
#   'controvery',
#   'contrevy',
#   'controvsary',
#   'contiuvisy',
#   'controvese',
#   'contronersery',
#   'controvorsey',
#   'contravorsy',
#   'countrevercy',
#   'controvvesity',
#   'conterversy',
#   'conterverisy',
#   'contriversey',
#   'conterversty',
#   'contreversey',
#   'combtrovesy',
#   'conversey',
#   'contterversy',
#   'conturvesy',
#   'contrvercy',
#   'controvesy',
#   'coutueversy',
#   'controsory',
#   'contrefercing',
#   'counterners',
#   'controvercey',
#   'contowversie',
#   'controversay',
#   'conversation',
#   'controversary',
#   'contraversery',
#   'contreversy',
#   'controversie',
#   'contriverse',
#   'controversing',
#   'conterversay',
#   'contrusy'],
#  ['etiology', 'eitiology'],
#  ['snowing', 'showing'],
#  ['military', 'millitary', 'milatary', 'militery'],
#  ['cancellation',
#   'canselation',
#   'cassilation',
#   'canncelation',
#   'cancalation',
#   'consulation',
#   'cancelatin',
#   'canelation',
#   'cansallation',
#   'cansellation',
#   'cansilation',
#   'cancallation',
#   'canacellation',
#   'cannsulation',
#   'cansaltion',
#   'cancolateon',
#   'cansulation',
#   'consalation',
#   'canselution',
#   'cancilliation',
#   'canslation',
#   'cancillation',
#   'cancolation',
#   'cansalation',
#   'cancialation',
#   'cancatation',
#   'cancilation',
#   'canclation',
#   'cansolitation',
#   'cansolation',
#   'cancealation',
#   'cancilion',
#   'cancelation',
#   'chancelation',
#   'cansclitation'],
#  ['criticism',
#   'criticisim',
#   'critizeation',
#   'criticizem',
#   'coritisumn',
#   'critisicsm',
#   'criticisam',
#   'critisizem',
#   'critisium',
#   'critizition',
#   'critisisem',
#   'crisisem',
#   'critiscism',
#   'critisisum',
#   'critigism',
#   'critisum',
#   'critizim',
#   'certsemus',
#   'griticism',
#   'critizm',
#   'critizesum',
#   'cretism',
#   'crisizum',
#   'critisima',
#   'critizam',
#   'critisizum',
#   'critisiem',
#   'criticisiom',
#   'critisim',
#   'critizizem',
#   'critisizm',
#   'critisism',
#   'critisiciam',
#   'crictism',
#   'critizium',
#   'critisicm',
#   'crittissisam',
#   'criticiz',
#   'criticisium',
#   'critisyum',
#   'critisicem',
#   'critissam',
#   'criticiam',
#   'citisum',
#   'critizom',
#   'critiszm',
#   'criticise',
#   'critisisim',
#   'criticisum',
#   'criticizement',
#   'cridictcisim',
#   'criticisms',
#   'critisizime',
#   'criticisem',
#   'critisizim',
#   'critisision',
#   'critizism',
#   'crisiam',
#   'critisisam',
#   'criticsm',
#   'critisiam',
#   'criticizasm',
#   'critizum',
#   'criticizin',
#   'critizisum',
#   'critizen',
#   'critizem',
#   'critzen',
#   'cretacesum',
#   'courtesisum',
#   'critisym',
#   'cretisism',
#   'critizisim',
#   'criticitisem',
#   'crypticism',
#   'critizizam',
#   'critisesimon',
#   'critisem',
#   'critcism',
#   'criticem',
#   'criciticisms',
#   'cirtissimum',
#   'critici',
#   'criticm',
#   'critism',
#   'critision',
#   'crytisym',
#   'criticizm',
#   'courtisum',
#   'critisizen',
#   'critizitim',
#   'criticum'],
#  ['golden', 'goldin', 'gloden'],
#  ['sines', 'sinse'],
#  ['divide', 'devide', 'divid'],
#  ['subtracts', 'substracts'],
#  ['there_had', 'therad'],
#  ['criticise', 'critisize'],
#  ['sweetest', 'sweetes'],
#  ['explained',
#   'explan',
#   'epled',
#   'exclimed',
#   'exeplande',
#   'explainded',
#   'ecspained',
#   'explard',
#   'exslanded',
#   'explanned',
#   'expanel',
#   'exesnd',
#   'expaned',
#   'exlpand',
#   'explain',
#   'explaind',
#   'eixplaned',
#   'exsplaned',
#   'eplained',
#   'exsplain',
#   'explaid',
#   'explaned',
#   'epland',
#   'expand',
#   'extamed',
#   'explant',
#   'ekplaned',
#   'expaine',
#   'exploxen',
#   'explairded',
#   'explane',
#   'expland',
#   'expent',
#   'exclaimed',
#   'exprand',
#   'exple',
#   'exclamed'],
#  ['brought',
#   'broght',
#   'broug',
#   'brough',
#   'brot',
#   'bught',
#   'brort',
#   'brougth',
#   'bought'],
#  ['remnant', 'reminent'],
#  ['sizeable', 'sizable'],
#  ['opponents', 'oppenerts'],
#  ['spoke', 'spoak', 'spock', 'spok', 'spook'],
#  ['browse', 'bbrose'],
#  ['music', 'muic', 'muice'],
#  ['telegraph', 'telagraph'],
#  ['strike', 'stricke', 'sricke', 'strick'],
#  ['until', 'intal', 'untill', 'uatill', 'untl'],
#  ['holy', 'wholy', 'holly', 'holey'],
#  ['relax', 'relacks'],
#  ['successful',
#   'sucksesful',
#   'sucsselful',
#   'seckesful',
#   'sacsesful',
#   'sussecful',
#   'sucsesfult',
#   'sususful',
#   'seccesful',
#   'suxsesful',
#   'sucsful',
#   'sussfull',
#   'sucsesfull',
#   'sucssuful',
#   'sucsessful',
#   'siccesefull',
#   'sursenful',
#   'suxsusful',
#   'suksesfull',
#   'succful',
#   'successfull',
#   'sucessful',
#   'succesfull',
#   'secsecfuly',
#   'sucessfull',
#   'successeful',
#   'suxcessful',
#   'sesesful',
#   'scucfull',
#   'succesfel',
#   'sexcful',
#   'suckessful',
#   'succsesfull',
#   'secessful',
#   'sucfull',
#   'successfuly',
#   'seceful',
#   'suckcesfull',
#   'surseful',
#   'saseful',
#   'sucksfull',
#   'susesful',
#   'surou',
#   'sucefull',
#   'succeful',
#   'sucsfully',
#   'sexself',
#   'succesfully',
#   'uscsful',
#   'sucesful',
#   'sucseful',
#   'succfull',
#   'succusfull',
#   'secsecful',
#   'sucksesfull',
#   'suchsefull',
#   'sacksesful',
#   'scuksefuly',
#   'succesful',
#   'sucsefully',
#   'secseful',
#   'succeshful',
#   'sucsessfull',
#   'suchesbull',
#   'sucsesfle',
#   'suxsefal',
#   'sucsesful',
#   'suceseful',
#   'sukseful',
#   'succsessful',
#   'succsefull',
#   'suskfull',
#   'suceful',
#   'sucesfull',
#   'succsesful',
#   'sucesfful',
#   'sussefull',
#   'secsesful'],
#  ['hurt', 'heart', 'hert', 'hearte'],
#  ['glass', 'glas', 'glars'],
#  ['reversible', 'reversable'],
#  ['tying', 'tieing'],
#  ['hole', 'hol', 'hold', 'holler'],
#  ['hold', 'hod', 'holed'],
#  ['circumstances', 'circumstaces'],
#  ['locked', 'lock', 'locked', 'lockd'],
#  ['pursue', 'persue', 'presue'],
#  ['accomplishment', 'acomplishment'],
#  ['apologetics', 'apolegetics'],
#  ['locker', 'loker'],
#  ['example', 'exemple', 'exmaple', 'exsample', 'exmple'],
#  ['household', 'houshe'],
#  ['artillery', 'artillary'],
#  ['organized', 'oranised', 'orginized'],
#  ['caution', 'causion', 'cortion'],
#  ['want',
#   'wont',
#   'wants',
#   'what',
#   'mant',
#   'whant',
#   'wand',
#   'watn',
#   'wha',
#   "n't",
#   'woth',
#   'wnat',
#   'whon',
#   'whont',
#   'wo',
#   "n't",
#   'wernt',
#   'went',
#   'wat'],
#  ['preferably', 'preferrably'],
#  ['hog', 'hag'],
#  ['hoe', 'how', 'ho'],
#  ['complaining', 'complanig'],
#  ['travel', 'travle', 'travill', 'travell'],
#  ['damage',
#   'damaged',
#   'damadge',
#   'dameage',
#   'damge',
#   'damage',
#   'dammage',
#   'damuge',
#   'damagage',
#   'damaze',
#   'danage',
#   'damnage',
#   'damgous'],
#  ['machine',
#   'mecichly',
#   'merchen',
#   'meshien',
#   'michin',
#   'minhen',
#   'machane',
#   'merchain',
#   'mishn',
#   'maechen',
#   'mosien',
#   'moter',
#   'masir',
#   'matchine',
#   'macine',
#   'mashen',
#   'machiene',
#   'merchine',
#   'mishing',
#   'meirshin',
#   'mechine',
#   'micshine',
#   'mashin',
#   'mashine',
#   'manchine',
#   'mching',
#   'mesen',
#   'macien',
#   'muchien',
#   'mrosin',
#   'machian',
#   'masgen',
#   'mshin',
#   'machein',
#   'macheine'],
#  ['how', 'hou', 'haw'],
#  ['hot', 'thot', 'rat', 'hoot', 'hala', 'hote', 'aht', 'tert', 'hat'],
#  ['hop', 'hope'],
#  ['cheetah', 'cheter'],
#  ['preferable', 'preferrable'],
#  ['fanaticism', 'fanatism'],
#  ['vaccination', 'vacinnation'],
#  ['beauty', 'beuty', 'bueaty'],
#  ['outlawed', 'oulawed'],
#  ['wrong',
#   'wrang',
#   'wronge',
#   'ron',
#   'rong',
#   'long',
#   'rog',
#   'wong',
#   'ronge',
#   'ro',
#   'worng'],
#  ['monolithic', 'monolite'],
#  ['short-tempered', 'short_tempered'],
#  ['effective', 'affective'],
#  ['caisson', 'casion'],
#  ['headquarters', 'headquoters'],
#  ['season', 'seson'],
#  ['signatories', 'signitories'],
#  ['baggage', 'bagage'],
#  ['orally', 'erally'],
#  ['snowballs', 'snow_ball'],
#  ['keeps', 'keep'],
#  ['wind', 'win', 'wid'],
#  ['restriction', 'restrici'],
#  ['dreamed', 'dremd'],
#  ['misdemeanor', 'misdemenor', 'misdameanor'],
#  ['vary', 'varie'],
#  ['sunshine', 'sunshin'],
#  ['nazareth', 'nazereth'],
#  ['fir', 'fur'],
#  ['his', 'he', "'s", 'he'],
#  ['fit', 'fite', 'fanit', 'fid'],
#  ['unforeseen', 'unforseen'],
#  ['heretofore', 'heretofor'],
#  ['secede', 'seceed'],
#  ['survivors', 'survivers'],
#  ['coach-load', 'coach_load'],
#  ['distinguishing', 'distingishing'],
#  ['insubstantial', 'insubstancial'],
#  ['hidden', 'hidon'],
#  ['him', 'im'],
#  ['grievous', 'grievious'],
#  ['interrupt', 'interupt'],
#  ['blink', 'blnk'],
#  ['eisenhower', 'eisenhhower'],
#  ['scholar', 'scholer'],
#  ['rumour', 'rumer', 'rummer'],
#  ['represents', 'repreents'],
#  ['queues', 'ques'],
#  ['shoelace', 'shoe_lace'],
#  ['arrow', 'arow'],
#  ['volcano', 'volcanoe'],
#  ['dumpy', 'dunpty'],
#  ['obdurate', 'obdirate'],
#  ['preceded', 'preceeded'],
#  ['financial',
#   'vaysuntte',
#   'fiynalle',
#   'finachle',
#   'finashall',
#   'finaancle',
#   'finatul',
#   'finantual',
#   'fintrol',
#   'fina',
#   'finnance',
#   'financhial',
#   'finanturel',
#   'finasle',
#   'finanshel',
#   'fineshel',
#   'financal',
#   'finnanle',
#   'finanial',
#   'financhel',
#   'firanshal',
#   'finachial',
#   'finashal',
#   'finenashsure',
#   'finatial',
#   'finane',
#   'fianation',
#   'finantial',
#   'finacwell',
#   'firnashal',
#   'fenecherue',
#   'finanshiol',
#   'financual',
#   'finachel',
#   'finasial',
#   'finacal',
#   'finatoil',
#   'finantal',
#   'finacial',
#   'finesha',
#   'fiancial',
#   'finashel',
#   'finatical',
#   'firnanshel',
#   'finanction',
#   'fineancal',
#   'finalshal',
#   'financhall'],
#  ['snakes', 'snaks', 'snake'],
#  ['archetypes', 'archtypes'],
#  ['garment', 'garmet'],
#  ['teddy_boy', 'teddoy', 'tedeboy'],
#  ['spider', 'spiter'],
#  ['turnip', 'turnup'],
#  ['precedes', 'preceeds'],
#  ['fortnight', 'fort_night'],
#  ['laboratory',
#   'labory',
#   'labotorey',
#   'laboraty',
#   'labritory',
#   'labroratory',
#   'lavatory',
#   'labortory',
#   'labertory',
#   'labrotory',
#   'laboatory',
#   'libertory',
#   'labatory',
#   'laboretory',
#   'labratory',
#   'laberotary',
#   'labitory',
#   'labaratory',
#   'labetory',
#   'lavoratory',
#   'elatory',
#   'lab',
#   'laveratory',
#   'labartory',
#   'labortary',
#   'laboritory',
#   'labority',
#   'laborotory',
#   'labarotory',
#   'lavortory',
#   'laborbtory',
#   'laberatory',
#   'lavratory'],
#  ['ring', 'rings'],
#  ['whip', 'wip'],
#  ['excepting', 'exepting'],
#  ['encourage', 'incourage', 'encorage', 'encourge', 'encourg'],
#  ['engineer', 'engeneer', 'engieneer', 'enginer'],
#  ['foundation', 'foundition', 'fondation'],
#  ['inhabitants', 'habitants'],
#  ['assured', 'asured'],
#  ['threatened', 'thretened'],
#  ['surveys', 'survays', 'servays'],
#  ['grapes', 'graps'],
#  ['sheet', 'sheat', 'shet'],
#  ['estimate', 'estamate'],
#  ['knit', 'knitt', 'niet', 'nit'],
#  ['universally', 'universaly'],
#  ['enormous', 'enormas', 'emerous', 'enourmous', 'enormus'],
#  ['ate', 'et', 'aet', 'eat', 'ete'],
#  ['scruff', 'scruf'],
#  ['reprimanded', 'repremanded'],
#  ['dinner-hour', 'dinner_hour'],
#  ['today', "'s", 'todays'],
#  ['sallies', 'sally'],
#  ['wash', 'wach', 'wosh'],
#  ['instruct', 'instruck'],
#  ['customization', 'custamisation'],
#  ['bitten', 'biten'],
#  ['rhododendron', 'rhododrendon'],
#  ['basketball',
#   'baskball',
#   'basketball',
#   'basketbale',
#   'basket-ball',
#   'baskt-ball',
#   'baskeball',
#   'basket-ball',
#   'bascketball',
#   'basket-ball',
#   'baskitball',
#   'bascket-ball',
#   'basket_ball',
#   'bastestball'],
#  ['service', 'cirvice', 'survice', 'servise', 'servace'],
#  ['similarly', 'similarily'],
#  ['engagement', 'enagement'],
#  ['needed', 'need', 'nedded', 'mided', 'neaded'],
#  ['perturbations', 'pertubations'],
#  ['master', 'mater'],
#  ['architect', 'archetect'],
#  ['listen', 'lisen', 'lesson', 'lisn', 'leasten', 'listern'],
#  ['geneva', 'geniva'],
#  ['snooty', 'snoty'],
#  ['predictable', 'predicable'],
#  ['crawl', 'crol', 'crall'],
#  ['positively', 'positivly'],
#  ['sidereal', 'sedereal', 'sideral'],
#  ['showed', 'showd', 'shod'],
#  ['approximations', 'appoximations'],
#  ['tree', 'treee', 'tre', 'three', 'tee'],
#  ['omnivorous', 'omniverous'],
#  ['project',
#   'progetr',
#   'proget',
#   'prget',
#   'pojert',
#   'projer',
#   'prung',
#   'commet',
#   'pgett',
#   'projet',
#   'projoc',
#   'progect',
#   'porait',
#   'poujent',
#   'projent',
#   'projexty',
#   'poragced',
#   'porcet'],
#  ['pneumonia',
#   'nuemonia',
#   'memonia',
#   'pnenonia',
#   'pnuemonia',
#   'phneumonia',
#   'ammonia',
#   'pnmonia',
#   'phemonia',
#   'pneumaine',
#   'phneomia',
#   'phenomia',
#   'pnemounia',
#   'nomina',
#   'phenominia',
#   'phneomina',
#   'pnenumoia',
#   'phewmonia',
#   'pneimonia',
#   'newmonia',
#   'amnonnia',
#   'phemonuia',
#   'pneunomia',
#   'amomea',
#   'phenioma',
#   'nephonia',
#   'pheunomia',
#   'phenomenia',
#   'phunmonia',
#   'phnomeia',
#   'peneumia',
#   'phomonia',
#   'phumonia',
#   'pnumonia',
#   'pheuphmonia',
#   'pnemoninia',
#   'pneunonia',
#   'phonimonu',
#   'phuemonia',
#   'ponuime',
#   'anumonian',
#   'anomina',
#   'phnomia',
#   'pneaumonia',
#   'phenoumonia',
#   'phnumonia',
#   'pnomonia',
#   'phenoumina',
#   'penmonia',
#   'phenoumia',
#   'newmony',
#   'phenumia',
#   'pnueounia',
#   'phenimonia',
#   'numonia',
#   'penominia',
#   'phnumonia',
#   'pounia',
#   'puemonia',
#   'pnemonia',
#   'pnenomionia',
#   'phenomu',
#   'pneumia',
#   'pneumnia',
#   'pheomena',
#   'pnenonea',
#   'phemomina',
#   'phenomnia',
#   'anonianu',
#   'phmoinia',
#   'pneurminu',
#   'phnemona',
#   'pheunomina',
#   'pheumonia',
#   'phemonuime',
#   'pneumonia',
#   'phnenimonia',
#   'pheumonia',
#   'phnuemonia',
#   'namoia',
#   'nephenoma',
#   'namouny',
#   'pheneumonia',
#   'pnumonenia',
#   'numonuia',
#   'pneumunia',
#   'nemonia',
#   'pnumonea',
#   'phunemonia',
#   'peunmonia',
#   'pneumphia',
#   'neumonia',
#   'pnenomia',
#   'knemonu',
#   'phnemonia',
#   'phnemounia',
#   'pnumeia',
#   'pneomonia',
#   'peunomia',
#   'phomoniow',
#   'phonia',
#   'demondia',
#   'phmeuaina',
#   'phenemonia',
#   'numoia',
#   'remote',
#   'penumonia',
#   'munonia',
#   'phenumonia',
#   'pneuammia',
#   'amonia'],
#  ['idle', 'idel', 'ide'],
#  ['readjusted', 'reajusted'],
#  ['seminary', 'seminery'],
#  ['feeling', 'feling', 'felling', 'fealing'],
#  ['acquisition', 'aquisistion', 'aquisition'],
#  ['a_lot', 'lot', 'alote', 'alot'],
#  ['to-day',
#   "'s",
#   'two_days',
#   'todays',
#   'todays',
#   "'",
#   'to-days',
#   'today',
#   "'s",
#   'todaies',
#   'to_days'],
#  ['runner', 'runer'],
#  ['dozen', 'doxen', 'dosen'],
#  ['wholesome', 'wholsome', 'holesome'],
#  ['courier', 'coururier'],
#  ['responsible',
#   'resmoserbl',
#   'responsable',
#   'responcible',
#   'reponsible',
#   'reposable'],
#  ['metallic', 'metalic'],
#  ['asymmetric', 'assymmetric', 'asymetric', 'assymetric'],
#  ['bang', 'bankg'],
#  ['causing', 'corsing', 'coursing'],
#  ['absorbed', 'asorbed', 'abo'],
#  ['amusing', 'amsing'],
#  ['doors', 'doers', 'dors'],
#  ['responsibly', 'responsably'],
#  ['jones', 'johnes'],
#  ['committing', 'commiting', 'comiting', 'comitting'],
#  ['shall', 'shale', 'sall', 'she', 'shal'],
#  ['object', 'objet'],
#  ['a_little', 'alitl', 'alittle'],
#  ['mouth', 'moth'],
#  ['letter', 'letre', 'teller', 'leter'],
#  ['conceded', 'conseived'],
#  ['professor', 'professer', 'profesor', 'proffessor', 'proffesor'],
#  ['camp', 'kamp', 'canp'],
#  ['consummate', 'consumate'],
#  ['nineteenth', 'ninteenth'],
#  ['scream', 'scem', 'screem', 'screm'],
#  ['incomplete', 'incompleet', 'incomplot'],
#  ['marvel', 'marval'],
#  ['polypropylene', 'polypropalene'],
#  ['bomb',
#   'baumb',
#   'bombe',
#   'bome',
#   'bomm',
#   'bown',
#   'bonod',
#   'book',
#   'bom',
#   'bambe',
#   'boom'],
#  ['insects', 'insexs'],
#  ['gauge',
#   'gadg',
#   'gape',
#   'garge',
#   'gare',
#   'gange',
#   'gang',
#   'tade',
#   'garer',
#   'gage',
#   'gach',
#   'gagde',
#   'cauge',
#   'gams',
#   'gadje',
#   'bergage',
#   'gradnang',
#   'gar',
#   'grage',
#   'gagech',
#   'garind',
#   'gag',
#   'gaog',
#   'cage',
#   'gargch',
#   'gadeg',
#   'rage',
#   'gaige',
#   'gade',
#   'gager',
#   'guage',
#   'gadge',
#   'ghase',
#   'guadge',
#   'gaoge',
#   'gaged',
#   'geich'],
#  ['lessons',
#   'lesson',
#   "'s",
#   'lessens',
#   'lesons',
#   'leasons',
#   'lessions',
#   'listerse',
#   'lesson'],
#  ['busy', 'bise', 'buisy', 'bussy', 'bisy'],
#  ['shuffling', 'shufarling'],
#  ['than', 'then', 'thna', 'tahn', 'that'],
#  ['bush', 'buch'],
#  ['touched',
#   'tesded',
#   'toure',
#   'cher',
#   'toched',
#   'theed',
#   'tost',
#   'tuched',
#   'tusted',
#   'toughed',
#   'tosh',
#   'touch',
#   'toached',
#   'tache',
#   'tucked',
#   'tust',
#   'tutet',
#   'toght',
#   'tuses',
#   'tush',
#   'tougched',
#   'tacah',
#   'tuchd',
#   'toch',
#   'toulched',
#   'turst',
#   'toutched',
#   'chuched',
#   'trosh',
#   'tiups',
#   'stuched',
#   'tuch',
#   'thach',
#   'touh',
#   'thucht',
#   'tashed'],
#  ['rich', 'rick'],
#  ['rice', 'rise'],
#  ['lady', 'lade', 'ladey', 'ladiy', 'ladys'],
#  ['plate', 'blate', 'plat'],
#  ['stammered', 'stamerd'],
#  ['terrors', 'terrours'],
#  ['foremost', 'formost'],
#  ['pocket', 'poket'],
#  ['foundries', 'foundaries'],
#  ['cushion', 'cusion'],
#  ['altogether', 'alltogether', 'atlogeher', 'all_together'],
#  ['jaguar', 'jagaur'],
#  ['nicely', 'nicerly', 'nicly', 'micely'],
#  ['boarder', 'border'],
#  ['patch', 'pacth'],
#  ['blew', 'blow', 'blue'],
#  ['disaster', 'diaster'],
#  ['fair', 'fare'],
#  ['peripheral', 'periferal'],
#  ['radius', 'radiuss', 'radious'],
#  ['fail', 'fale'],
#  ['nocturnal', 'nocternal'],
#  ['hammer', 'hamer'],
#  ['best',
#   'bets',
#   'be',
#   'bast',
#   'dest',
#   'bass',
#   'beets',
#   'beat',
#   'bist',
#   'biwes',
#   'besh',
#   'besd',
#   'mest',
#   'beast',
#   'bettes',
#   'bister',
#   'bess',
#   'bes',
#   'bet'],
#  ['lots', 'losts', 'lotes', 'lot', 'lost'],
#  ['propagates', 'propogates'],
#  ['score', 'skore', 'scor'],
#  ['side', 'sied', 'se', 'sid'],
#  ['preserve', 'preseve'],
#  ['claws', 'clors'],
#  ['never',
#   'neve',
#   'newer',
#   'mever',
#   'nere',
#   'nof',
#   'knver',
#   'neaver',
#   'nether',
#   'nef',
#   'neiver',
#   'nerth',
#   'naver',
#   'nven',
#   'nese',
#   'ner',
#   'neven',
#   'nver'],
#  ['extend', 'exstend', 'extand'],
#  ['nature', 'nacher', 'nuture', 'natior', 'm'],
#  ['rolled', 'rolld', 'rold'],
#  ['invigorated', 'envigorated'],
#  ['souvenir', 'souvenier', 'suvenere', 'souviner'],
#  ['extent', 'exstent'],
#  ['wheelbarrow', 'wheel_barrow'],
#  ['debt', 'dept', 'deat'],
#  ['tyranny', 'tyrrany', 'tyrany'],
#  ['patented', 'pattented'],
#  ['accident',
#   'and',
#   'aserdent',
#   'exded',
#   'asden',
#   'sedent',
#   'acadent',
#   'ataren',
#   'axcident',
#   'askendent',
#   'castan',
#   'asdent',
#   'anitharent',
#   'esadend',
#   'a_canet',
#   'acedcedt',
#   'asde',
#   'anteght',
#   'aciddent',
#   'accicent',
#   'andandn',
#   'acciendent',
#   'aciedent',
#   'askedent',
#   'agisted',
#   'axedet',
#   'ascended',
#   'accierdent',
#   'asident',
#   'acsident',
#   'asedend',
#   'exedelt',
#   'harcent',
#   'accsident',
#   'andexns',
#   'acsdent',
#   'accend',
#   'axseadent',
#   'andet',
#   'accxident',
#   'aciadent',
#   'exiedent',
#   'axs',
#   'axerdent',
#   'advainet',
#   'exedent',
#   'andires',
#   'acsedent',
#   'andient',
#   'asadun',
#   'akcdent',
#   'acedent',
#   'axed',
#   'andint',
#   'ancident',
#   'aken',
#   'ased',
#   'asabed',
#   'acident',
#   'afanat',
#   'xedet',
#   'axedent',
#   'acist',
#   'acdent',
#   'acs',
#   'axidint',
#   'acats',
#   'asterdet',
#   'accdient',
#   'axedents',
#   'acddent',
#   'axident',
#   'addinent',
#   'acdend',
#   'accedent'],
#  ['chirped', 'cherped'],
#  ['country',
#   'ocuntry',
#   'carty',
#   'cout',
#   'contry',
#   'county',
#   'coontry',
#   'countrie'],
#  ['teddy_boy', 'teddoy', 'tedeboy'],
#  ['incense', 'insense'],
#  ['levitating', 'levetating'],
#  ['planned', 'planed'],
#  ['asked', 'ask', 'askt', 'arsed'],
#  ['unsymmetrical', 'unsyme'],
#  ['vain', 'vane'],
#  ['humming', 'huming'],
#  ['cardboard', 'cardbord'],
#  ['source', 'sorce', 'aource', 'sauce', 'sourse'],
#  ['union', 'unioun'],
#  ['criticised', 'critisized'],
#  ['much', 'must', 'mush', 'march', 'mach'],
#  ['stadium', 'staydium'],
#  ['privilege',
#   'priviledge',
#   'privlage',
#   'privelege',
#   'privelige',
#   'privaledge',
#   'pervieledges',
#   'prilavage',
#   'privoledge',
#   'prevelige',
#   'privilages',
#   'privielage',
#   'priviliage',
#   'previlege',
#   'prlige',
#   'privaledged',
#   'prilavge',
#   'providge',
#   'privelage',
#   'privelidge',
#   'privileged',
#   'priviladge',
#   'previllage',
#   'privieloge',
#   'priveelege',
#   'privilage',
#   'preminage',
#   'previlage',
#   'previlidge',
#   'privalogy',
#   'privalidge',
#   'priviage',
#   'privilidged',
#   'purlgy',
#   'privledge',
#   'prividleged',
#   'privileelge',
#   'privalage',
#   'prilviage',
#   'prevelage',
#   'privialage',
#   'privilidge',
#   'privilige',
#   'prilvege',
#   'priveleage',
#   'privi'],
#  ['fry', 'fri', 'frie'],
#  ['incompetent', 'incompetant'],
#  ['life', 'lif', 'lief', 'live', 'lefe'],
#  ['spit', 'spite'],
#  ['eastern', 'eastren'],
#  ['wish', 'wich', 'wis', 'whish'],
#  ['lift', 'left'],
#  ['toboggan',
#   'talogon',
#   'tabogan',
#   'tabogen',
#   'tobbogan',
#   'tabogoon',
#   'tobagon',
#   'tobagan',
#   'tobogon',
#   'tobugon',
#   'tobogan',
#   'tobon',
#   'taboggan',
#   'tobogar',
#   'tobbogen',
#   'tobogurn',
#   'tobogn',
#   'taboog',
#   'tobaggan',
#   'tobboan',
#   'tabbogan',
#   'torbogen',
#   'conboggon',
#   'tobag',
#   'toboggen',
#   'toban',
#   'tobgen',
#   'tobogen',
#   'tabbogon',
#   'tobogane',
#   'tobacon',
#   'talbogan',
#   'tobogone',
#   'terbogen'],
#  ['child', 'cild'],
#  ['worked', 'work', 'workt', 'worted'],
#  ['spin', 'spen'],
#  ['skilfully',
#   'silfely',
#   'scilfle',
#   'strillfully',
#   'sceiful',
#   'fouale',
#   'lefle',
#   'sifle',
#   'scilfl',
#   'scillfully',
#   'skillfuly',
#   'skillverly',
#   'slhing',
#   'scearfolly',
#   'scferly',
#   'skillfel',
#   'squialy',
#   'sillaf',
#   'scilfly',
#   'sckeleft',
#   'skyillferley',
#   'saill',
#   'scify',
#   'skilfuly',
#   'silf-fele',
#   'skilfuley',
#   'silfle',
#   'clefler',
#   'silag',
#   'scillfuly',
#   'careing',
#   'skiverly',
#   'sifrle',
#   'sivle',
#   'skillforlly',
#   'skellfortly',
#   'sdillfully',
#   'skefferly',
#   'skill-fullie',
#   'skifly',
#   'skcinfulle',
#   'scifuly',
#   'skillferly',
#   'sarefully',
#   'soft',
#   'skifaly',
#   'sciferly',
#   'skilfarly',
#   'sqilferly',
#   'skinfuly',
#   'scill_filly',
#   'skelfuly',
#   'skifle',
#   'scillferle',
#   'scilfully',
#   'skillfully',
#   'scifule',
#   'cifarte',
#   'scillfley',
#   'skiffuly',
#   'scilferly',
#   'skilly',
#   'skeaferly',
#   'sall',
#   'skilfoly',
#   'sech',
#   'sillfully',
#   'skillful',
#   'shfally',
#   'skifully',
#   'scifeley',
#   'skilferly',
#   'selfer',
#   'sciverly',
#   'slikely',
#   'sclfoly',
#   'scilfuly'],
#  ['commerce', 'comerce'],
#  ['adaptations', 'adaptions'],
#  ['dissect', 'disect'],
#  ['employ', 'employe', 'imploy'],
#  ['visit', 'visite', 'viste', 'vist'],
#  ['played', 'paly', 'play', 'plays', 'bagt'],
#  ['player', 'playa'],
#  ['anticipating',
#   'antisepating',
#   'antisapiting',
#   'anticipitating',
#   'taniseapating',
#   'antispating',
#   'anticicitating',
#   'antizapating',
#   'antiscimation',
#   'antecipating',
#   'anticapate',
#   'anticipation',
#   'ancisapating',
#   'antiecpating',
#   'antisapit',
#   'anticepating',
#   'anticopening',
#   'anntisipation',
#   'antiapating',
#   'antcspating',
#   'anticpating',
#   'anticipting',
#   'anticiputed',
#   'antistipating',
#   'anntisapating',
#   'antisipainting',
#   'antiscipating',
#   'antisispating',
#   'atticpate',
#   'antisipating',
#   'antisepate',
#   'anticapting',
#   'anticipate',
#   'antasipation',
#   'anticapating',
#   'anticipateing',
#   'antisupate',
#   'antisapating',
#   'anticap'],
#  ['foot-and-mouth', 'footandmouth', 'footanmouth'],
#  ['violin', 'voilion', 'volin', 'vioiln'],
#  ['oxymoron', 'oximoron'],
#  ['damaged',
#   'dagmed',
#   'damatge',
#   'dames',
#   'damiged',
#   'damge',
#   'dameaged',
#   'damidge',
#   'damidgd',
#   'damed',
#   'damanged',
#   'damised',
#   'daned',
#   'damgedid',
#   'damadge',
#   'dadge',
#   'damedged',
#   'damagd',
#   'damage',
#   'domg',
#   'daeged',
#   'depbiced',
#   'damigaigd',
#   'dammaged',
#   'daniged',
#   'demges',
#   'damged',
#   'dam',
#   'damagtd',
#   'damdend',
#   'damadged',
#   'bamaged',
#   'dmeg',
#   'dameged',
#   'ecage',
#   'danaged',
#   'dammage',
#   'damges',
#   'danmaged',
#   'damige',
#   'damigid',
#   'damedge'],
#  ['things',
#   'thigns',
#   'tings',
#   'thinks',
#   'thing',
#   'fens',
#   'thigsn',
#   'thnigs',
#   'think',
#   'thigs'],
#  ['demands', 'diemands'],
#  ['split', 'splite', 'spilt'],
#  ['babies',
#   'babyies',
#   'babis',
#   'badies',
#   'bayds',
#   'bebys',
#   'babbes',
#   'babes',
#   'babyis',
#   'babe',
#   'badys',
#   'babs',
#   'baby',
#   'bobs',
#   'babeyes',
#   'baddys',
#   'babys',
#   'baybis',
#   'babyes',
#   'abays',
#   'bady',
#   'baybes',
#   'dady'],
#  ['fairly', 'faily', 'farly', 'fairlu'],
#  ['married', 'marrid'],
#  ['typhoid', 'tifoid', 'tyfoid'],
#  ['middle-aged', 'middle_age'],
#  ['supper', 'super'],
#  ['someone', "'s", 'some_ones'],
#  ['peremptory', 'preemptory'],
#  ['rescinded', 'resinded'],
#  ['academic', 'accademic', 'acedemic'],
#  ['subpoena', 'subpena', 'sepina'],
#  ['form-mistress', 'formmistress', 'formistress', 'formmisstress'],
#  ['corporate', 'corparate'],
#  ['plaque', 'placque'],
#  ['capitol', 'capital'],
#  ['distribute', 'distribut', 'distrubute'],
#  ['sleepy', 'sleppy', 'sleepey'],
#  ['financially',
#   'fianancally',
#   'financial',
#   'financilly',
#   'funiluty',
#   'finatially',
#   'financely',
#   'fincially',
#   'finnancially',
#   'financialy',
#   'finically',
#   'fininculay',
#   'fineanancely',
#   'famficay',
#   'finatually',
#   'finattioncely',
#   'finachily',
#   'finincially',
#   'finnancilly',
#   'finantially',
#   'financally',
#   'fenancialy',
#   'fimashly',
#   'finnacally',
#   'financhally',
#   'finiancle',
#   'finally',
#   'finiancially',
#   'finaciancally',
#   'finacially',
#   'financuly',
#   'fnaniancly',
#   'financeally',
#   'finnacily',
#   'finincally',
#   'financle',
#   'financel',
#   'finiancely',
#   'financly',
#   'finaitially',
#   'fananually',
#   'fianancially',
#   'financhilly',
#   'finantionally',
#   'finately',
#   'finiancally',
#   'finantually',
#   'finiancialy',
#   'finationly',
#   'finanialy',
#   'fanincally',
#   'financily',
#   'fiancially',
#   'fianicially',
#   'finitually',
#   'finaling',
#   'finacilly',
#   'fianiclly',
#   'finaily',
#   'finncually',
#   'fanacialy',
#   'financinally',
#   'financually',
#   'finnanially',
#   'finanically',
#   'finicially',
#   'finially'],
#  ['portrayed', 'protrayed'],
#  ['succeeding', 'suceeding'],
#  ['previous', 'previvous', 'preveous', 'previos', 'previus'],
#  ['purchased', 'perchased'],
#  ['sciences', 'se'],
#  ['old-fashioned', 'old_fashion', 'old_fashend', 'oldfashioned'],
#  ['had',
#   'hut',
#   'head',
#   'ad',
#   'han',
#   'hab',
#   'hade',
#   'hed',
#   'add',
#   'ade',
#   'at',
#   'have',
#   'av',
#   'has',
#   'hat',
#   'haed',
#   'aud'],
#  ['thickening', 'thikning'],
#  ['connecticut', 'conneticut'],
#  ['obedient', 'obediant', 'obedent'],
#  ['innocent',
#   'inoscent',
#   'incensent',
#   'innoncent',
#   'innocense',
#   'inocence',
#   'insient',
#   'inosent',
#   'incouncent',
#   'inocient',
#   'inasence',
#   'innocent',
#   'ininsit',
#   'inocience',
#   'inocent',
#   'innosent',
#   'innisit',
#   'inasent',
#   'inconnent',
#   'innocents',
#   'innonce',
#   'imisant',
#   'innocence',
#   'innacent',
#   'innicent',
#   'enocent',
#   'ennocent',
#   'innocnce',
#   'innoscent',
#   'iniscent',
#   'inoncent',
#   'inoccent',
#   'insent',
#   'innoint',
#   'innorcent',
#   'inocense',
#   'inocent'],
#  ['prison', 'prisin', 'pisond', 'preson', 'prision'],
#  ['has', 'hase', 'as', 'his', 'hos', 'have'],
#  ['hat', 'hot'],
#  ['every_time', 'everytime'],
#  ['good-humoured', 'good_humer'],
#  ['confidentially', 'confidentally'],
#  ['disagreement', 'dissagreement'],
#  ['possible', 'possibly', 'pissible', 'possable', 'posible'],
#  ['unequivocally', 'unequivocaly'],
#  ['possibly', 'possably', 'possiply', 'possible'],
#  ['birth', 'berth'],
#  ['missouri', 'misouri'],
#  ['shadow', 'shaddow', 'shodow'],
#  ['unique', 'uneque'],
#  ['occurring', 'occuring'],
#  ['desire', 'disire'],
#  ['psychological', 'psycological'],
#  ['remind',
#   'remined',
#   'remained',
#   'reminded',
#   'remond',
#   'remied',
#   'rembenes',
#   'remine',
#   're_mind',
#   'remimed',
#   'renind',
#   'remaind'],
#  ['pavement', 'pathment', 'pavment'],
#  ['steps', 'staps'],
#  ['malnutrition', 'manutriction'],
#  ['prologue',
#   'prolague',
#   'parlog',
#   'prologd',
#   'plolog',
#   'prolode',
#   'proloug',
#   'prolad',
#   'proloame',
#   'prolong',
#   'prlog',
#   'prologe',
#   'prolougle',
#   'browlog',
#   'prealog',
#   'prolarge',
#   'prolouge',
#   'prollog',
#   'prlock',
#   'porlong',
#   'prolog'],
#  ['ithaca', 'ihaca'],
#  ['misdemeanors', 'misdameanors', 'misdemenors'],
#  ['swedish', 'sweedish'],
#  ['attorney',
#   'arteny',
#   'erternly',
#   'erterey',
#   'entereny',
#   'entany',
#   'atury',
#   'ertany',
#   'arterny',
#   'aterna',
#   'ertiney',
#   'aterny',
#   'eneretel',
#   'aterney',
#   'erterny',
#   'entely',
#   'aterning',
#   'aturney',
#   'atterney',
#   'atorney',
#   'erterney',
#   'eterny',
#   'enterny',
#   'attaney',
#   'interne',
#   'atterny',
#   'ertenely',
#   'aturny',
#   'eterany',
#   'atternary',
#   'aturne',
#   'atturney'],
#  ['right', 'write', 'rite', 'rigth'],
#  ['old', 'ald', 'ol', 'lod', 'olf'],
#  ['creek', 'creak'],
#  ['crowd', 'croud'],
#  ['people',
#   'pople',
#   'peaper',
#   'peepull',
#   'pleople',
#   'porle',
#   'pepo',
#   'pipoll',
#   'peiple',
#   'poeple',
#   'peapl',
#   'peps',
#   'po',
#   'peple',
#   'pecial',
#   'peopl',
#   'pepall',
#   'peropel',
#   'peopel',
#   'peopal',
#   'pelele',
#   'pepal',
#   'peolpe',
#   'peropl',
#   'peaple',
#   'peol',
#   'pepole'],
#  ['crown', 'croun'],
#  ['insistence', 'insistance'],
#  ['harassment', 'harasment', 'harrasment'],
#  ['creep', 'creap'],
#  ['enemies',
#   'emmines',
#   'enemeys',
#   'enemeies',
#   'emimies',
#   'enmenies',
#   'enameyes',
#   'enmoneys',
#   'eminies',
#   'enemes',
#   'enimes',
#   'emmies',
#   'emeny',
#   'eniemies',
#   'enimeys',
#   'enamys',
#   'enamies',
#   'enemyies',
#   'emenies',
#   'enimies',
#   'enimeies',
#   'enmies',
#   'enimeus',
#   'enemys',
#   'enemy',
#   'enanis',
#   'enimesies',
#   'ememy',
#   'emenys',
#   'enmeys',
#   'enames',
#   'enemy',
#   "'s"],
#  ['daddy', "'s", 'dadies'],
#  ['for',
#   'fror',
#   'fur',
#   'fre',
#   'from',
#   'far',
#   'of',
#   'fro',
#   'fore',
#   'four',
#   'foir',
#   'in',
#   'forr',
#   'fon',
#   'foow',
#   'frou',
#   'or',
#   'fo'],
#  ['bottom', 'botem', 'bottem', 'botome', 'botton', 'botom'],
#  ['fox', 'foxx'],
#  ['polluted', 'poluted'],
#  ['continue', 'contunie'],
#  ['periphery', 'perifery'],
#  ['syphilis', 'syphyllis'],
#  ['pollutes', 'polutes'],
#  ['pinched', 'picth'],
#  ['dinner-hours', 'dinner_hours'],
#  ['losing', 'loosing', 'loseing', 'lossing'],
#  ['memorable', 'memerable', 'memeroal'],
#  ['manufacturing', 'manufactoring', 'manufaturing'],
#  ['dollars', 'dollers'],
#  ['anomalous', 'anomolous', 'anomalus'],
#  ['recollect', 'reccollect', 'recolect'],
#  ['despair', 'dispair'],
#  ['slightly', 'slighlty'],
#  ['raised', 'rased'],
#  ['feb', 'fab'],
#  ['motorbike', 'motor-bikes'],
#  ['facility', 'facilitie'],
#  ['honeymoon', 'honey_moon', 'honymoon', 'hunemoon'],
#  ['well-suited', 'well_suited'],
#  ['son', 'sun'],
#  ['respectable', 'respectible'],
#  ['consummated', 'consumated'],
#  ['sow', 'sew'],
#  ['wrap', 'rap'],
#  ['unambiguous', 'unabiguous'],
#  ['hallo', 'alloe', 'halloe'],
#  ['altitude',
#   'ettalared',
#   'altutadue',
#   'atitude',
#   'actitude',
#   'altetede',
#   'intertourd',
#   'altechud',
#   'altitube',
#   'altituded',
#   'elit',
#   'outertod',
#   'alteytod',
#   'altechod',
#   'asitude',
#   'autityed',
#   'attetude',
#   'elitead',
#   'alletude',
#   'outatude',
#   'eltitude',
#   'altitud',
#   'altitub',
#   'alltitude',
#   'altechoued',
#   'outitude',
#   'outertude',
#   'atlesould',
#   'altiude',
#   'alterchood',
#   'altertude',
#   'altidud',
#   'outtide',
#   'autee',
#   'altilude',
#   'autachoot',
#   'altiertetude',
#   'atalrod',
#   'altihoched',
#   'altetud',
#   'alteturen',
#   'autridude',
#   'aoteod',
#   'alterrude',
#   'outituge',
#   'oiled',
#   'altuled',
#   'aletute',
#   'atain',
#   'atasher',
#   'outderer',
#   'elingtcewed',
#   'aboule',
#   'otchod',
#   'altude',
#   'alatetude',
#   'attitood',
#   'ata',
#   'altitued',
#   'outechut',
#   'altitob',
#   'altuide',
#   'altetude',
#   'atichood',
#   'altiuded'],
#  ['constantly', 'constanly', 'constently'],
#  ['tame', 'tam'],
#  ['width', 'with'],
#  ['boy', "'s", 'boy', 'boys'],
#  ['overhead', 'overhaed'],
#  ['happy',
#   'happiy',
#   'happe',
#   'happer',
#   'appey',
#   'hapr',
#   'hope',
#   'hapy',
#   'happler',
#   'happle',
#   'happi',
#   'hape',
#   'hoppe',
#   'happert',
#   'hepe',
#   'apay',
#   'h_pping',
#   'hap',
#   'happie',
#   'glad',
#   'ape'],
#  ['offer', 'ofer'],
#  ['fascination', 'fasantion'],
#  ['cassowary', 'cassawory', 'cassowarry'],
#  ['talents', 'tallents'],
#  ['understandable', 'understadable'],
#  ['beech', 'beach'],
#  ['safeguard', 'safegaurd'],
#  ['congratulations',
#   'congratalation',
#   'congragalations',
#   'congrulations',
#   'congratulation',
#   'concradulations',
#   'congraulations',
#   'congradulation',
#   'congreation',
#   'comcerracarlants',
#   'congratulate',
#   'congratalutions',
#   'congrutulations',
#   'congralulations',
#   'congraulation',
#   'congratulatons',
#   'congralutations',
#   'congradulations',
#   'congretulations',
#   'congraduation',
#   'congrationlation',
#   'conguralitions',
#   'congragulations',
#   'congratilations',
#   'congratualations',
#   'congraudulations',
#   'congratalations',
#   'congradualtions',
#   'congreatulations',
#   'congralutaions',
#   'congratilation',
#   'conglutation',
#   'congratrilations',
#   'congractulations',
#   'congraduations',
#   'congratuations',
#   'congratulions',
#   'congraturalations',
#   'congralation',
#   'congradutation',
#   'concrogulation'],
#  ['genealogy', 'geneology'],
#  ['else', "'s", 'elss', 'elesers'],
#  ['inside', 'insid', 'in_sis', 'in_side'],
#  ['equalization', 'equilisation'],
#  ['devices', 'def'],
#  ['unanimous',
#   'unamenous',
#   'youmanles',
#   'umamous',
#   'anonymous',
#   'unammious',
#   'unnamious',
#   'unamamous',
#   'unanumous',
#   'umanaress',
#   'eunaminus',
#   'uniamimus',
#   'unnanomous',
#   'ununumus',
#   'unanious',
#   'unninote',
#   'unonomious',
#   'unaminus',
#   'unaninous',
#   'unenamous',
#   'unoniums',
#   'unamusts',
#   'unaniae',
#   'younamenous',
#   'uniomus',
#   'unanumas',
#   'sallanous',
#   'unamuse',
#   'unanimoses',
#   'unnanimous',
#   'unmnus',
#   'younamess',
#   'unamimus',
#   'unammius',
#   'amius',
#   'unaimous',
#   'unumanious',
#   'unacious',
#   'unananois',
#   'unnambus',
#   'unanmous',
#   'unanomous',
#   'unanus',
#   'umamilus',
#   'unanamious',
#   'unaiminous',
#   'unaminuous',
#   'unaninus',
#   'inamimus',
#   'eunamous',
#   'unanonus',
#   'unamous',
#   'unamious',
#   'unnamous',
#   'umionus',
#   'unananus',
#   'annymus',
#   'unnames',
#   'unannanus',
#   'unanamous',
#   'unanously',
#   'unanimuss',
#   'unanimos',
#   'unamus',
#   'unnadimus',
#   'unanabus',
#   'unamatous',
#   'unamaious',
#   'unannimous',
#   'unamanus',
#   'unamnious',
#   'unamonus',
#   'unanimus',
#   'eumamious',
#   'ununmious',
#   'uninamous',
#   'unatimas',
#   'unamious',
#   'uniom',
#   'unannamous',
#   'unaimulas',
#   'unimas',
#   'unnamos',
#   'unariowas',
#   'munaniuous',
#   'uniamones',
#   'unanouis',
#   'unaminonus',
#   'unnanamous',
#   'umanmuse',
#   'unamanious',
#   'unanamus',
#   'unamamouse',
#   'unanemous',
#   'unanamuse',
#   'unionous',
#   'unamanius',
#   'enaumous',
#   'unimous',
#   'unanasmons',
#   'unminus',
#   'uniminus',
#   'unitomious',
#   'unananucs',
#   'unamos',
#   'unomanious',
#   'unamies',
#   'unnous',
#   'uniamoes',
#   'unamanous',
#   'unamomus',
#   'unsannamous',
#   'unnanumus',
#   'unamaless',
#   'unaminous',
#   'unomise',
#   'unanimise',
#   'unomust',
#   'unanis'],
#  ['smashed', 'spached'],
#  ['palm', 'parm'],
#  ['passenger', 'passanger'],
#  ['juvenile', 'juvinille'],
#  ['later', 'latey', 'latter', 'lated', 'letter'],
#  ['disgrace', 'discrase'],
#  ['steady', 'stedy'],
#  ['tournament',
#   'turmonent',
#   'turment',
#   'turnoments',
#   'touranment',
#   'tournment',
#   'tournanent',
#   'tournement',
#   'turament',
#   'tornamently',
#   'terminent',
#   'termament',
#   'turnement',
#   'touremount',
#   'turement',
#   'turnament',
#   'turnment',
#   'turminate',
#   'tornement',
#   'tourimant',
#   'turminent',
#   'tourament',
#   'tormenment',
#   'turmanent',
#   'tuarninent',
#   'torniment',
#   'tounement',
#   'atournament',
#   'turnmant',
#   'ternement',
#   'tormentement',
#   'tourment',
#   'turniment',
#   'tourmment',
#   'hermit',
#   'tourneyment',
#   'tourmament',
#   'tournmeant',
#   'trounment',
#   'ternament',
#   'tournnament',
#   'ternimate',
#   'tunement',
#   'teramant',
#   'terniment',
#   'termenont',
#   'turnimant',
#   'tourmad',
#   'termanent',
#   'tournamant',
#   'tournate',
#   'tornment',
#   'tornament',
#   'tourniment',
#   'turimant',
#   'tourement',
#   'torrment',
#   'turnent',
#   'touriment',
#   'termenent',
#   'tournmant'],
#  ['proves', 'prooves'],
#  ['exist', 'exsist'],
#  ['dealer', 'dealor'],
#  ['negotiations',
#   'nogotiations',
#   'degotitions',
#   'nogiations',
#   'negoccation',
#   'naggosiations',
#   'negossiations',
#   'negctiation',
#   'negosheation',
#   'negoshiationis',
#   'netyotiation',
#   'nigonations',
#   'egosatem',
#   'negostionaion',
#   'negogiation',
#   'negoshishayns',
#   'negoatiations',
#   'negocheations',
#   'negiotiation',
#   'negoshchiations',
#   'negotation',
#   'negotiolations',
#   'negotitations',
#   'neggosionion',
#   'negotions',
#   'negosiation',
#   'neguotiations',
#   'negoseeasion',
#   'agoshion',
#   'negiotations',
#   'negoshiations',
#   'necognitiomtions',
#   'negoitation',
#   'negoceations',
#   'negocations',
#   'negoeations',
#   'degosiations',
#   'ingosheaction',
#   'negocation',
#   'negotiation',
#   'negoation',
#   'negotiatetions',
#   'negosheations',
#   'negociatiances',
#   'negociasions',
#   'negoshation',
#   'negoseations',
#   'negoseciations',
#   'necogiations',
#   'negotians',
#   'negoacations',
#   'negotitions',
#   'negoatation',
#   'nocitin',
#   'negotiatins',
#   'nicociation',
#   'negoations',
#   'negociation',
#   'nogatuation',
#   'negottation',
#   'negioation',
#   'negorislation',
#   'negatiations',
#   'nogationes',
#   'negotionation',
#   'degotuations',
#   'negostions',
#   'negochictions',
#   'negosheaitions',
#   'negoiations',
#   'negotations',
#   'negotition',
#   'negoiation',
#   'negotianations',
#   'negiatations',
#   'negota',
#   'negeoations',
#   'negote',
#   'negotion',
#   'negoti',
#   'negotciations',
#   'agociate',
#   'negogiations',
#   'negogations',
#   'negoodations',
#   'negociations',
#   'negochiations',
#   'negatations',
#   'negociatione',
#   'negosiations'],
#  ['floor', 'flor', 'foor'],
#  ['flood', 'flud', 'flod'],
#  ['superfluous', 'superfulous'],
#  ['roll', 'rol'],
#  ['double-cross', 'double_cross'],
#  ['asterisk', 'asterick'],
#  ['eminent', 'imanent', 'emminent', 'iminent'],
#  ['scale', 'skale'],
#  ['rolling', 'roling'],
#  ['quandary', 'quandry'],
#  ['good-natured', 'good_natured'],
#  ['time', 'tiem', 'timne', 'tame', 'tim', 'tine', 'thim', 'tiome'],
#  ['push', 'puch'],
#  ['breadth', 'breath'],
#  ['cincinnati', 'cincinatti'],
#  ['chain', 'chane', 'chan', 'choin'],
#  ['whoever', 'who_ever'],
#  ['indians', 'indian', "'s"],
#  ['integration', 'intergration'],
#  ['skate', 'skat'],
#  ['chair', 'chere', 'char', 'chiar'],
#  ['midst', 'mist'],
#  ['ukrainian', 'ukranian'],
#  ['philosopher', 'philisopher'],
#  ['vet', 'vent', 'vethn', 'vetin', 'vethu'],
#  ['amplification', 'amification'],
#  ['mache', 'mashe'],
#  ['bicycles', 'bycicles', 'bciyle'],
#  ['cheap', 'cheep'],
#  ['choice', 'chose', 'choise'],
#  ['gloomy', 'glooming', 'gloomming', 'glomy'],
#  ['break_time', 'breaktime'],
#  ['exact', 'exsact'],
#  ['minute', 'minuet', 'minite', 'miniute', 'minit'],
#  ['tear', 'tair', 'tare'],
#  ['leave',
#   'life',
#   've',
#   'levef',
#   'live',
#   'lefnr',
#   'lever',
#   'leasve',
#   'leav',
#   'leve'],
#  ['settle', 'settel'],
#  ['team', 'term', 'teem', 'tem'],
#  ['loads', 'loess', 'loades'],
#  ['prevent', 'pervent'],
#  ['spiritual',
#   'spherical',
#   'speratral',
#   'spitural',
#   'spirisul',
#   'spiritul',
#   'speratual',
#   'pirtral',
#   'spearacher',
#   'speiritually',
#   'spiritually',
#   'spiritural',
#   'spiriturel',
#   'spitrial',
#   'spritural',
#   'speritual',
#   'spirtful',
#   'spirical',
#   'spiritiaul',
#   'spirurel',
#   'spritially',
#   'spuritily',
#   'spitirial',
#   'spritiual',
#   'spertial',
#   'spirchial',
#   'spirt',
#   'spirtial',
#   'spirtual',
#   'spirlial',
#   'spulcure',
#   'spertiaul',
#   'spritule',
#   'spirttual',
#   'sperical',
#   'spirtural',
#   'spirititual',
#   'speartiual',
#   'spirtional',
#   'sprirtual',
#   'spirituall',
#   'spieratually',
#   'spritual',
#   'spcerial',
#   'spirital',
#   'sprital',
#   'sipural',
#   'speratural',
#   'spearitial',
#   'spiritial'],
#  ['occurrence',
#   'occurance',
#   'occurrance',
#   'ocurrance',
#   'occurence',
#   'ocurrence'],
#  ['two-faced', 'two_faced'],
#  ['attic', 'atic'],
#  ['sign', 'sighn', 'eign', 'sion'],
#  ['candlestick', 'candle_stick'],
#  ['essence', 'essense'],
#  ['jeopardy', 'jeapardy', 'jepardy'],
#  ['celebrated', 'celebrate'],
#  ['melt', 'malt'],
#  ['current', 'curent'],
#  ['extraterrestrial', 'extraterrestial'],
#  ['chrysanthemums', 'chrisanthimums'],
#  ['falling', 'folling'],
#  ['badge', 'bage'],
#  ['jury', 'jurry'],
#  ['honour', 'honer'],
#  ['funeral', 'funerl', 'funrel'],
#  ['understanding', 'understanting', 'undestanding', 'under_standing'],
#  ['address', 'adress', 'adres', 'addres'],
#  ['alone', 'alown', 'a_lone', 'alon', 'aloun'],
#  ['along', 'a_long', 'all', 'aling', 'alog', 'allong'],
#  ['my', 'by'],
#  ['momentous', 'momentus'],
#  ['financiers', 'fincancers', 'financers'],
#  ['dusty', 'duste'],
#  ['studied', 'studed', 'studyed'],
#  ['wherever', 'whereever', 'wereever', 'where_ever', 'were_ever'],
#  ['commonly', 'commongly'],
#  ['accomplished',
#   'aclimplised',
#   'acolpleshed',
#   'comdash',
#   'acomplised',
#   'acombished',
#   'aconplised',
#   'accomplish',
#   'accaplished',
#   'acoplished',
#   'acoumpish',
#   'acaulle',
#   'acomplisht',
#   'acolplished',
#   'aconplish',
#   'acuplished',
#   'acalern',
#   'accomhed',
#   'aconase',
#   'accamplish',
#   'aclomplished',
#   'aco',
#   'acumlished',
#   'apcomplished',
#   'acompilsh',
#   'acomplished',
#   'acomplshed'],
#  ['proclamation', 'proclomation'],
#  ['studies', 'studys'],
#  ['love', 'lveo', 'lvoe', 'loev'],
#  ['radish', 'raddish'],
#  ['prefer',
#   'perfuer',
#   'perfour',
#   'preafer',
#   'perer',
#   'prefor',
#   'perfer',
#   'pefer',
#   'perfure',
#   'prefore',
#   'prof',
#   'proe',
#   'profer',
#   'prver',
#   'peair',
#   'perver',
#   'prefur',
#   'brfere',
#   'provere',
#   'perful',
#   'profferr',
#   'prefure',
#   'prefere'],
#  ['bloody', 'blody', 'bludy'],
#  ['marvelous', 'marvellous', 'marvalous'],
#  ['grandpa', "'s", 'grandpas'],
#  ['crammed', 'cramp'],
#  ['working', 'warking', 'wroking', 'work', 'wokring', 'woking'],
#  ['homesick', 'homsick'],
#  ['positive', 'positve', 'possitive'],
#  ['angry', 'angery', 'angrey'],
#  ['dangle', 'dongle'],
#  ['predictions', 'pe'],
#  ['vigour', 'vigeur'],
#  ['wood', 'wod'],
#  ['opposed', 'apposed'],
#  ['wondering', 'wondring'],
#  ['films', 'firms'],
#  ['theoretical', 'theridically', 'teridical'],
#  ['loving', 'loveing'],
#  ['marbles', 'marables', 'marballs'],
#  ['afford', 'affort', 'efford', 'aford'],
#  ['apparent',
#   'appreant',
#   'appearent',
#   'parent',
#   'apprarent',
#   'apparant',
#   'aparot',
#   'apperant',
#   'aprent',
#   'aparaent',
#   'aperant',
#   'apperent',
#   'aparant',
#   'apprent',
#   'aparent',
#   'apparient'],
#  ['appendix', 'apendix'],
#  ['everywhere',
#   'everwhere',
#   'eyerwhere',
#   'eveywhere',
#   'every_were',
#   'evry_were'],
#  ['virtue',
#   'vertue',
#   'vurtued',
#   'virchu',
#   'virtu',
#   'verue',
#   'verchew',
#   'vertieu',
#   'vergue',
#   'virteau',
#   'virture',
#   'vurtue',
#   'verterue',
#   'victure',
#   'verters',
#   'vertive',
#   'virtuals',
#   'furtue',
#   'ferture',
#   'verchue',
#   'fertued',
#   'verchu',
#   'virtues',
#   'virtuge',
#   'verture',
#   'vertie',
#   'verchude',
#   'verto',
#   'virtou',
#   'virercut',
#   'fertue',
#   'vertu',
#   'virtrue',
#   'virtiou',
#   'viricheu'],
#  ['originally',
#   'origonly',
#   'orrigalaly',
#   'organial',
#   'orrginally',
#   'originnally',
#   'origienoley',
#   'oringinally',
#   'arridgely',
#   'originial',
#   'arridionally',
#   'origionally',
#   'oridgenally',
#   'oridgenouly',
#   'originially',
#   'oridganaly',
#   'arigionaly',
#   'orriginally',
#   'orignially',
#   'originually',
#   'originality',
#   'orginially',
#   'orriganily',
#   'origially',
#   'oridtionaly',
#   'organially',
#   'organly',
#   'anganally',
#   'ariginaly',
#   'origianally',
#   'orrignally',
#   'eriganally',
#   'oringle',
#   'regularly',
#   'ornanly',
#   'arridgenally',
#   'arigale',
#   'orginaly',
#   'oreginally',
#   'arigionally',
#   'origanilly',
#   'origedenally',
#   'origanily',
#   'orridginally',
#   'orriganally',
#   'oring',
#   'origernally',
#   'origenally',
#   'orrigionally',
#   'oridgonally',
#   'oridnigly',
#   'ordinally',
#   'orrigontly',
#   'origanally',
#   'orridally',
#   'origonally',
#   'origionaly',
#   'orriginaly',
#   'orriginially',
#   'origenaly',
#   'aridgeanoly',
#   'ordinarily',
#   'originaly',
#   'oridinally',
#   'orginanly',
#   'orignoally',
#   'orginally',
#   'oridgenly',
#   'origanially',
#   'orignally',
#   'original'],
#  ['pretend',
#   'btade',
#   'preded',
#   'pertaned',
#   'petened',
#   'pertened',
#   'preted',
#   'prtened',
#   'protented',
#   'prutend',
#   'pretned',
#   'tende',
#   'prodederd',
#   'beten',
#   'pretented',
#   'portent',
#   'brutend',
#   'prenten',
#   'prolend',
#   'peretend',
#   'betend',
#   'petn',
#   'pretaned',
#   'protend',
#   'besau',
#   'prated',
#   'peameter',
#   'pretennd',
#   'prdend',
#   'betent',
#   'pretent',
#   'pretened',
#   'paot',
#   'pratent',
#   'petand',
#   'petane',
#   'preteneded',
#   'pretant',
#   'pretended',
#   'bretend',
#   'betained',
#   'petend',
#   'portend',
#   'prertend',
#   'preten',
#   'preatend',
#   'pritend',
#   'proten',
#   'predend',
#   'btend',
#   'prented',
#   'prtend',
#   'betendid',
#   'phretend',
#   'pertend',
#   'breatend',
#   'prelend',
#   'petent',
#   'preet',
#   'pred',
#   'prentend',
#   'prend',
#   'preterded',
#   'preatent',
#   'perdend'],
#  ['believes', 'belives', 'beleives'],
#  ['printing', 'priting', 'prenting'],
#  ['believed', 'beleived'],
#  ['detached', 'detatched'],
#  ['stockroom', 'stock_room'],
#  ['lodestone', 'loadstone'],
#  ['weasels', 'weazles'],
#  ['sacrament', 'sacrement'],
#  ['unequalled', 'unequaled'],
#  ['allowed', 'aloud', 'alloud', 'alowed', 'oloud'],
#  ['stole', 'stol', 'stowl', 'stold', 'stull'],
#  ['evidently', 'evedently', 'evidentally'],
#  ['monitoring', 'monitering'],
#  ['winter', 'witer', 'window'],
#  ['divided', 'dived', 'devided'],
#  ['thanking', 'thinking'],
#  ['elephant', 'elphant'],
#  ['extensions', 'extions'],
# ...
#  ['an_hour', 'anhour'],
#  ['resource',
#   'rescae',
#   'resorce',
#   'resouse',
#   'resoure',
#   'recouse',
#   'resause',
#   'resace',
#   'resouce',
#   'resarce',
#   'recuorse',
#   'resaise',
#   'recorce',
#   'recose',
#   'resors',
#   'recorse',
#   'recoce',
#   'rersorse',
#   'resoce',
#   'recource',
#   'resorses',
#   'recacorse',
#   'recauce',
#   'recourse',
#   'resans',
#   'resauece',
#   'resorse',
#   'resauce',
#   'resourse'],
#  ['artist', 'artest'],
#  ['parasitic', 'saresitic'],
#  ['borrow', 'brow', 'barrow'],
#  ['worried', 'woried', 'worid', 'worred'],
#  ['cochlea', 'ch'],
#  ['priest', 'preist'],
#  ['bee-keepers', 'bee_keepers'],
#  ['bombs', 'bomes', 'boms'],
#  ['liable', 'lieable', 'lible', 'lyable'],
#  ['worries', 'worre'],
#  ['where',
#   'we',
#   'wee',
#   'wer',
#   'wet',
#   'wart',
#   'there',
#   'werre',
#   'ther',
#   'wher',
#   'gaing',
#   'wuy',
#   'wear',
#   'were0',
#   'whrer',
#   'ware',
#   'with',
#   'war',
#   'hwere',
#   'wir'],
#  ['arrival', 'arival', 'arrivial'],
#  ['surgery', 'surgere'],
#  ['no-one', 'know_one', 'now_one', 'knowone'],
#  ['jumped', 'jump', 'jumb', 'jumpt', 'jumth', 'jumper'],
#  ['receivers', 'recievers'],
#  ['representatives',
#   'representative',
#   "'s",
#   'repersenitives',
#   'representiveties',
#   'representive',
#   'represntatives',
#   'represenatives',
#   'repesentatives',
#   'representatives',
#   'represenitives',
#   'repersentives',
#   'repersentitives',
#   'represempative',
#   'represinetives',
#   'representies',
#   'represenitive',
#   'represantives',
#   'represenatives',
#   'represtantives',
#   'repsenatives',
#   'represenitives',
#   'representitives',
#   'repistentives',
#   'representitatives',
#   'repersintives',
#   'repersentaves',
#   'represenetives',
#   'representitive',
#   'representatives',
#   "'",
#   'represnetatives',
#   'repstinues',
#   'representative',
#   'representivies',
#   'represident',
#   "'s",
#   'repasenatives',
#   'representives',
#   'respensations',
#   'repersentatives',
#   'repersenatives',
#   'repersentitive',
#   'repersentive',
#   'represenitatives',
#   'repesident'],
#  ['dormitory',
#   'domortory',
#   'dortory',
#   'dormentdory',
#   'dormoratory',
#   'dormiatory',
#   'dorinatory',
#   'domatarily',
#   'dormititory',
#   'durmatory',
#   'dormotory',
#   'dormertory',
#   'doormetory',
#   'doromatory',
#   'dormortory',
#   'dormitly',
#   'domotory',
#   'dormatory',
#   'domatory',
#   'dornoratory',
#   'dormortary',
#   'dormatary',
#   'doormintory',
#   'dormantory',
#   'doramatory',
#   'dormitary',
#   'adormatory',
#   'dormitoriy',
#   'dormentory',
#   'dormotary',
#   'doomator',
#   'dorimatory',
#   'doromortory',
#   'doornitory',
#   'doromitory',
#   'dormintory',
#   'dormenatory',
#   'dormetory',
#   'deormetormy',
#   'dorenatory',
#   'dormadory',
#   'domitory',
#   'dorrmatory',
#   'daumitary',
#   'dommority',
#   'doramtory',
#   'dornatorie',
#   'dooratory',
#   'dormortority',
#   'dormatoraly',
#   'domorotry',
#   'dormontory',
#   'dorimitory',
#   'dormatey',
#   'dormitlory',
#   'doratory',
#   'deomertory',
#   'dormitorrary',
#   'dormiltory',
#   'dorminatory',
#   'dorimtory',
#   'doromority',
#   'dorminty',
#   'domutory',
#   'dormarty',
#   'dominory',
#   'domeritria',
#   'doritory',
#   'domitry',
#   'dominatory',
#   'domteracy'],
#  ['kilometer', 'lilometer'],
#  ['bureau', 'beauro'],
#  ['enjoys', 'enyays'],
#  ['cantaloupe', 'cantaloube'],
#  ['vertical', 'verticle'],
#  ['aberration', 'aberation'],
#  ['screen', 'seveen'],
#  ['suppresses', 'supresses'],
#  ['revealed', 'revealled'],
#  ['gratefully', 'greatfully'],
#  ['concentrate', 'concetrate', 'consuntrate', 'consentrate', 'consantrate'],
#  ['spare',
#   'shar',
#   'spaip',
#   'spair',
#   'his',
#   'ser',
#   'spear',
#   'sper',
#   'share',
#   'spere',
#   'spu',
#   'ster',
#   'shaper',
#   'score',
#   'spar',
#   'sgre',
#   'sereine'],
#  ['in_between', 'inbetween'],
#  ['suppressed', 'surpressed', 'supressed'],
#  ['concentrated', 'consentrated'],
#  ['mans', 'masn'],
#  ['many', 'meny', 'meay', 'meney', 'memey', 'may', 'manny', 'mony'],
#  ['classroom', "'s", 'class_rooms'],
#  ['millionaire', 'million_air', 'millionnaire', 'millionere', 'million_ear'],
#  ['besieging', 'beseiging'],
#  ['personal', 'personly', 'personel', 'persnal'],
#  ['concentrates', 'consentrates'],
#  ['expression', 'expresion'],
#  ['ca', "n't", 'can', "n't", 'carnt', 'cant', 'car', "n't", 'canth'],
#  ['allowance', 'allowence'],
#  ['yearly', 'yearley'],
#  ['twin', 'twen'],
#  ['comeback', 'comback'],
#  ['geese', 'gees'],
#  ['buoyancy', 'bouyancy'],
#  ['considers', 'conciders'],
#  ['boat', 'boaut', 'bot'],
#  ['caring', 'careing'],
#  ['comb', 'come'],
#  ['unconsciousness', 'unconciousness'],
#  ['stretch', 'strech', 'streach'],
#  ['west', 'wast'],
#  ['locally', 'localy'],
#  ['vacation', 'vakation', 'vacashon', 'vaction'],
#  ['concede', 'consede'],
#  ['breath', 'breathe', 'breth', 'brath'],
#  ['almighty', 'almity'],
#  ['practised', 'practise', 'practiced'],
#  ['wants', 'wans', 'wnats', 'wantes', 'want'],
#  ['enable', 'unable', 'anable'],
#  ['unsafe', 'unsf'],
#  ['thousand', 'thousend', 'thousnand'],
#  ['formed', 'fromed', 'form', 'formd'],
#  ['observe', 'obsirve', 'obi'],
#  ['extant', 'extint'],
#  ['calligraphy', 'caligraphy'],
#  ['former', 'fro', 'farmer'],
#  ['prominence', 'prominance'],
#  ['straighten', 'straiten'],
#  ['easier', 'eassier', 'ease', 'easyer', 'easy', 'easery', 'easer'],
#  ['newspaper', 'newpaper', 'newspapper', 'news_paper'],
#  ['situation', 'situration', 'sitt', 'situating'],
#  ['constituency', 'consituency'],
#  ['all-round', 'all_round'],
#  ['purse', 'purce', 'perse'],
#  ['vandalism', 'vanderlism', 'vandolism', 'vanderlisium'],
#  ['unhygienic', 'unheigenic'],
#  ['barbed', 'barb'],
#  ['sickness', 'sicknes'],
#  ['i',
#   'a',
#   'and',
#   'ld',
#   'we',
#   'i',
#   'is',
#   'it',
#   'iy',
#   'if',
#   'are',
#   'has',
#   'he'],
#  ['defy', 'defie'],
#  ['advertisement', 'advertisment'],
#  ['volcanoes', 'volcanos'],
#  ['vacant', 'vacent'],
#  ['tentacle', 'tenacle'],
#  ['so_forth', 'soforth', 'so-forth'],
#  ['genii', 'genei'],
#  ['grumpy', 'grumby'],
#  ['botswana', 'botuania'],
#  ['summer', 'sumer'],
#  ['manifold', 'many_fold'],
#  ['being', 'bieng', 'be', 'bi', 'been', 'bieing', 'beeing'],
#  ['truculent', 'trucculent'],
#  ['exaggerating', 'exagerating', 'exagerrating'],
#  ['rest', 'rast'],
#  ['schools', 'school', 'schol'],
#  ['steamer', 'stemer'],
#  ['omissions', 'ommissions'],
#  ['weekly', 'weakly'],
#  ['sixteen', 'sixtine', 'sixten'],
#  ['generator', 'generrater'],
#  ['silver', 'siver', 'sliver'],
#  ['instrument', 'instrement', 'instrment', 'insromet', 'instriment'],
#  ['prominently', 'prominately', 'prominantly'],
#  ['aspects', 'spects'],
#  ['around',
#   'rand',
#   'arr',
#   'rend',
#   'a_rand',
#   'aradret',
#   'ar',
#   'a_rade',
#   'roned',
#   'arouned',
#   'ar_rounde',
#   'a_rarnd',
#   'rond',
#   'aroand',
#   'aron',
#   'aroud',
#   'arond',
#   'arround',
#   'arad',
#   'a_round',
#   'a_rond',
#   'arode',
#   'urand',
#   'aroude',
#   'arownd',
#   'round'],
#  ['decomposed', 'decomposited'],
#  ['knobbly', 'nobbly'],
#  ['dart',
#   'tat',
#   'art',
#   'darrt',
#   'doatg',
#   'darte',
#   'derter',
#   'brt',
#   'dered',
#   'daud',
#   'yaht',
#   'dorte',
#   'dute',
#   'drate',
#   'dete',
#   'durt',
#   'daring',
#   'darolt',
#   'byt',
#   'drte',
#   'snad',
#   'daet',
#   'doath',
#   'dutr',
#   'dard',
#   'dut',
#   'dunt',
#   'tart',
#   'dae',
#   'dert',
#   'burte',
#   'dirt',
#   'dorter',
#   'deent',
#   'but',
#   'dret',
#   'dat',
#   'drek',
#   'daw',
#   'nitty',
#   'datre',
#   'deatre',
#   'date',
#   'bit',
#   'deart',
#   'drat',
#   'dater',
#   'drit',
#   'adar',
#   'derdt',
#   'drt',
#   'dared',
#   'snt',
#   'drk',
#   'dort',
#   'duit',
#   'durte',
#   'dot'],
#  ['dark',
#   'ding',
#   'duc',
#   'durk',
#   'dake',
#   'back',
#   'ducr',
#   'dia',
#   'down',
#   'drlak',
#   'dick',
#   'barck',
#   'dining',
#   'dork',
#   'dagy',
#   'drck',
#   'drak',
#   'darrk',
#   'darw',
#   'dak',
#   'dreh',
#   'brek',
#   'dare',
#   'dard',
#   'bar',
#   'drow',
#   'dog',
#   'drk',
#   'dank',
#   'bnack',
#   'darch',
#   'darck',
#   'dir'],
#  ['traffic',
#   'travic',
#   'tacter',
#   'drafec',
#   'trafice',
#   'trafick',
#   'traffi',
#   'trofek',
#   'trafeck',
#   'tavit',
#   'trfick',
#   'traie',
#   'tatif',
#   'tiornef',
#   'tac',
#   'roads',
#   'tarnftian',
#   'peraffic',
#   'cafic',
#   'treffer',
#   'trafit',
#   'trafic',
#   'tafic',
#   'tavek',
#   'taafic',
#   'tiatic',
#   'taame',
#   'trafack',
#   'tatlek',
#   'tafeate',
#   'traffek',
#   'trafik',
#   'traffc',
#   'trafet',
#   'traveck',
#   'track',
#   'traff',
#   'traffig',
#   'tairer',
#   'traffice',
#   'tinict',
#   'traik',
#   'travick',
#   'tracky',
#   'traifec',
#   'terrec',
#   'traffik',
#   'trafek',
#   'tarffic',
#   'taveging',
#   'tafter',
#   'taraf',
#   'craffeck',
#   'tale',
#   'tate',
#   'thaiech',
#   'farolc',
#   'trare',
#   'traph',
#   'trafec'],
#  ['bandage', 'bandge'],
#  ['vacuum', 'vaccume', 'vaccum'],
#  ['world', 'wald', 'worde', 'word', 'would', 'wholed', 'wold', 'wourld'],
#  ['postal', 'postel'],
#  ['decomposes', 'decomposits'],
#  ['vague', 'vaig', 'vage'],
#  ['dare', 'dear', 'dair'],
#  ['satisfaction',
#   'shasan',
#   'satichfatshen',
#   'satisfacshoin',
#   'satisfacshion',
#   'wanat',
#   'sabfas',
#   'istis',
#   'satisfacshin',
#   'satisfashoin',
#   'satisfacsion',
#   'satfacso',
#   'sachfachn',
#   'stisfacho',
#   'satlistash',
#   'satisfacion',
#   'satesfaction',
#   'satisfation',
#   'satiusfacson',
#   'satifacian',
#   'satefasion',
#   'satisfactoin',
#   'satifoin',
#   'satishfacen',
#   'satisfaften',
#   'satfaction',
#   'sackaach',
#   'satfakess',
#   'satifactoin',
#   'saciffaction',
#   'satfacan',
#   'satisfacttion',
#   'satamachen',
#   'satishfation',
#   'silhen_fant',
#   'sacfatchen',
#   'satesfach_chere',
#   'satisfn',
#   'satirsh',
#   'siterfatur',
#   'satisfatch',
#   'eat_as_of_ede',
#   'satishfaction',
#   'satisfakshion',
#   'fian',
#   'satisfacshon',
#   'satifation',
#   'setisfate',
#   'satifachen',
#   'satishfaktion',
#   'satifishan',
#   'satitfaction',
#   'sat_oford',
#   'sartfasn',
#   'sats_fan',
#   'satisvetion',
#   'satisfacshun',
#   'satfasher',
#   'sicifaris',
#   'setitfared',
#   'sitisfaction',
#   'satisfuckshon',
#   'satishan',
#   'sat_fainand',
#   'sachen',
#   'sachfaen',
#   'statsiefacsed',
#   'argring_atoing',
#   'satigan',
#   'satichfachcen',
#   'satisfachan',
#   'satiffashon',
#   'sacisfacsh',
#   'satisfakson',
#   'satisfackshen',
#   'sackitvansh',
#   'satifaction',
#   'satifachon',
#   'satisfachen',
#   'soam',
#   'sackifsacshern',
#   'sattfashed',
#   'satsha',
#   'satifason',
#   'satispachoin',
#   'saticfacon',
#   'satisfakshon',
#   'satisfacin',
#   'call_fall',
#   'satisfcshion',
#   'satifacion',
#   'satistloin',
#   'satigaction',
#   'satisfackshon',
#   'satesfacshen',
#   'satisfachshon',
#   'satfatre',
#   'satisfain'],
#  ['unrepentant', 'unrepentent'],
#  ['nutrients', 'nutritents'],
#  ['souvenirs', 'souveniers'],
#  ['discarded', 'discare'],
#  ['stationary', 'stationery'],
#  ['clap', 'klap', 'clape'],
#  ['auditorium',
#   'autorm',
#   'autoruim',
#   'auditormunen',
#   'audiatorum',
#   'auditouim',
#   'allturman',
#   'audatoreum',
#   'oratoroum',
#   'autitorium',
#   'auditorm',
#   'additorium',
#   'auditorim',
#   'autormen',
#   'allortomdd',
#   'audaterame',
#   'adutorium',
#   'auditarium',
#   'auditory',
#   'attorium',
#   'audetorium',
#   'audotorium',
#   'auditourin',
#   'auditorial',
#   'auditoriam',
#   'autorum',
#   'auditoruium',
#   'autotorium',
#   'autatorum',
#   'autatorom',
#   'adetoreum',
#   'aduoteriam',
#   'auditorinum',
#   'audatorum',
#   'auttortism',
#   'auditiorm',
#   'audortum',
#   'ouditorium',
#   'auditorum',
#   'auditoium',
#   'auditoryum',
#   'auditoriom',
#   'auditorimn',
#   'adatorum',
#   'auditorym',
#   'arudtiorze',
#   'auditormeon',
#   'auditorumen',
#   'authorium',
#   'auditoreum',
#   'ottatorium',
#   'audiotorium',
#   'autitorum',
#   'audiortium',
#   'attoram',
#   'audetorn',
#   'auditor',
#   'audatorium',
#   'audortorium',
#   'auditoriumn',
#   'aduitorum',
#   'auditoriun',
#   'aditorum',
#   'aditorium'],
#  ['satisfactory', 'satsfactory', 'satifactory', 'satisfactary'],
#  ['superintendent', 'superintendant', 'supertendent'],
#  ['learning', 'learnning', 'learing', 'lerning', 'learining'],
#  ['supplementary', 'suplementary'],
#  ['divine',
#   'devin',
#   'devying',
#   'divide',
#   'deavine',
#   'devide',
#   'devine',
#   'devined',
#   'delvine',
#   'divene',
#   'define'],
#  ['thinks', 'thikns'],
#  ['there', "'ll", 'therell'],
#  ['memories',
#   'memoirs',
#   'mearise',
#   'memeroies',
#   'momories',
#   'memerories',
#   'meherey',
#   'merrerys',
#   'memoaries',
#   'memoraries',
#   'merries',
#   'mermarys',
#   'mermories',
#   'memory',
#   "'s",
#   'remison',
#   'memordies',
#   'memorries',
#   'mearsise',
#   'memey',
#   'memory',
#   'memoiries',
#   'memuries',
#   'memoreys',
#   'merrors',
#   'memmories',
#   'moniiy',
#   'monorious',
#   'merories',
#   'memeris',
#   'merores',
#   'moremery',
#   'memoreres',
#   'marysis',
#   'memoryes',
#   'memorarys',
#   'memouries',
#   'memorie',
#   "'s",
#   'memorys',
#   'memeries',
#   'mermiores',
#   'memmorys',
#   'memerys',
#   'mamrioes'],
#  ['noon', 'non'],
#  ['endocrine', 'endochrine'],
#  ['refer', 'refere'],
#  ['unsuccessfully', 'unsucesfuly', 'unsucessfully'],
#  ['accessing', 'accesing'],
#  ['scientific', 'scientic', 'scienfic', 'st'],
#  ['power', 'pwoer', 'pour'],
#  ['intimate', 'intermit'],
#  ['in_spite', 'inspite'],
#  ['playing-field', 'playfud', 'playing_field', 'playfeild'],
#  ['stone', 'ston'],
#  ['package', 'packege', 'pakage'],
#  ['disabilities', 'dissabiliteys'],
#  ['meal', 'mel', 'mell'],
#  ['neighbor', 'neighbour', 'neigbour'],
#  ['act', 'at', 'akt'],
#  ['luck', 'lock'],
#  ['rabbinical', 'rabinnical'],
#  ['burning', 'buring'],
#  ['legged', 'leged'],
#  ['lively', 'livly', 'livley'],
#  ['parties', 'partys', 'party', "'s"],
#  ['accumulated', 'acumulated'],
#  ['technically', 'technecally', 'techniquely'],
#  ['burglar', 'burgler', 'buglar'],
#  ['her', 'hir', 'there', 'them', 'here6', 'she', 'har', 'he'],
#  ['series', 'serious'],
#  ['water-rat', 'waterrat'],
#  ['bubble', 'buble'],
#  ['yearned', 'yerned'],
#  ['complete', 'compleat'],
#  ['beginners', 'begginers'],
#  ['elimination', 'eleimination', 'elimiation'],
#  ['impedance', 'impedence'],
#  ['mice', 'mise'],
#  ['with',
#   'whin',
#   'wif',
#   'wefe',
#   'wis',
#   'in',
#   'whit',
#   'iwth',
#   'wihth',
#   'wiy',
#   'will',
#   'what',
#   'wef',
#   'wien',
#   'when',
#   'wthe',
#   'whith',
#   'wethe',
#   'wivr',
#   'we',
#   'wihe',
#   'wh',
#   'wite',
#   'wiht',
#   'wive',
#   'wirth',
#   'went',
#   'wtih',
#   'withe',
#   'wint',
#   'weth',
#   'wit',
#   'yethe',
#   'witht',
#   'the',
#   'wheth'],
#  ['buying', 'buyin', 'bying'],
#  ['handsome', 'hansem', 'hansum', 'hansome'],
#  ['they', "'re", 'their', 'the', 'there', 'thier'],
#  ['rush', 'ruch'],
#  ['monopoly', 'monapaloy'],
#  ['dirty', 'dertses', 'diry', 'driy', 'durty'],
#  ['dispensing', 'dispencing'],
#  ['agree', 'agre'],
#  ['detailed', 'detailled'],
#  ['gone', 'gon', 'crome', 'gome', 'goon', 'gonne', 'gornd', 'go', 'gor'],
#  ['gratuitous', 'gratuitious'],
#  ['exhausted', 'exausted', 'exhasted', 'exa'],
#  ['certain',
#   'sorton',
#   'certian',
#   'surntered',
#   'sirtain',
#   'ceratin',
#   'curtain',
#   'sertain',
#   'cirtain',
#   'serton'],
#  ['accents', 'achsends'],
#  ['cinderella', 'cinderrella'],
#  ['am', 'ham', 'an'],
#  ['an', 'a', 'and', 'un', 'am', 'on'],
#  ['as',
#   'ass',
#   'a',
#   'his',
#   'asw',
#   'have',
#   'was',
#   'hase',
#   'is',
#   'tes',
#   'at',
#   'aas',
#   'has',
#   'saw',
#   'als'],
#  ['at', 'a', 'ast', 'al', 'an', 'as', 'are', 'att'],
#  ['hobbies', 'hobbys'],
#  ['creak', 'creek'],
#  ['cream', 'crem'],
#  ['ideally', 'idealy'],
#  ['graduate', 'graguate'],
#  ['tight', 'tite'],
#  ['watson', 'watston'],
#  ['unparalleled',
#   'umparralled',
#   'unparralel',
#   'unparalleld',
#   'unparallelled',
#   'unparlleled',
#   'parrealled',
#   'apparrelled',
#   'unparralleled',
#   'unparreled',
#   'unparielled',
#   'empalerleld',
#   'uparrelled',
#   'unparalled',
#   'unplaled',
#   'unparlled',
#   'unparallel',
#   'anparelle',
#   'unparelled',
#   'unpall',
#   'unparrelede',
#   'un-parrallel',
#   'unblale',
#   'unparale',
#   'unperalld',
#   'unparalel',
#   'unparrowllede',
#   'unparolled',
#   'unparalelled',
#   'unparaled',
#   'unpovaly',
#   'unparralled',
#   'unparraled',
#   'unparrallel',
#   'unparrled',
#   'unpareled',
#   'unapparralled',
#   'unparraleled',
#   'unparelelled',
#   'unparrelled',
#   'unparelleled',
#   'andpiotou',
#   'unproloud'],
#  ['puppy', 'pupy'],
#  ['contemporaries', 'contamporaries'],
#  ['congress',
#   'converce',
#   'curgress',
#   'congress',
#   'converse',
#   'cnongress',
#   'cangress',
#   'congres',
#   'comgress',
#   'congeres'],
#  ['spermatozoa', 'spermatozoan'],
#  ['tiger', 'tigar'],
#  ['partitioned', 'petitioned'],
#  ['mask', 'mast', 'masked', 'marsk'],
#  ['having', 'haveing', 'hvaing', 'have-ing', 'hower'],
#  ...]

# %% [markdown]
# Making a dictionary out of this list:

# %%
target_typos = {}
for line in spell_errors:
    target = line[0] #first is always target
    typos = line[1:] #rest is always typos
    for typo in typos:
        if editdistance.eval(target, typo) == 1 or typo in transposition(target): #either edit distance one or transposition
            if target not in target_typos.keys():
                target_typos[target] = [typo]
            else: #append typos to value of key already in dict
                target_typos[target].append(typo)
                
target_typos
# Out:
# {'raining': ['rainning', 'raning'],
#  'writings': ['writtings'],
#  'yellow': ['yello'],
#  'four': ['fours', 'for'],
#  'woods': ['woodes'],
#  'aggression': ['agression'],
#  'looking': ['loking', 'locking', 'looing', 'lookin'],
#  'eligible': ['eligble', 'eligable'],
#  'electricity': ['electrisity', 'electricty', 'electrizity'],
#  'scold': ['schold', 'skold'],
#  'adaptable': ['adabtable'],
#  'caned': ['canned', 'cained'],
#  'immature': ['imature'],
#  'swivel': ['swival'],
#  'appropriation': ['apropriation'],
#  'fur': ['furr', 'fer'],
#  'stabbed': ['stabed'],
#  'disturb': ['desturb'],
#  'recollections': ['recolections'],
#  'prize': ['prise', 'prizer'],
#  'wednesday': ['wedensday', 'wedensday'],
#  'succession': ['sucession', 'succesion'],
#  'straight': ['stright'],
#  'incremented': ['increented'],
#  'pulse': ['pluse'],
#  'second': ['secand', 'secund', 'seconnd', 'seond'],
#  'jamjar': ['jam_jar'],
#  'sailed': ['saled', 'saild'],
#  'thunder': ['thounder'],
#  'cooking': ['coking', 'kooking', 'cocking'],
#  'fossil': ['fosscil'],
#  'increasing': ['incresing',
#   'increacing',
#   'incressing',
#   'inceasing',
#   'increesing',
#   'increaseng',
#   'encreasing',
#   'incriasing',
#   'increaseing'],
#  'hero': ['heroe'],
#  'dahl': ['dael'],
#  'reporter': ['repoter', 'reportor', 'reproter', 'reoporter'],
#  'interrupting': ['interupting'],
#  'here': ['hare',
#   'her',
#   'there',
#   'herre',
#   'heere',
#   'hera',
#   'herd',
#   'heer',
#   'hree',
#   'hire'],
#  'atoms': ['atom'],
#  'tape-recorded': ['tape_recorded'],
#  'shriek': ['shreik'],
#  'substance': ['substace'],
#  'elaborate': ['elaberate'],
#  'climbed': ['climed'],
#  'reports': ['reoprts'],
#  'controversy': ['controversey',
#   'controvercy',
#   'contriversy',
#   'countroversy',
#   'contraversy',
#   'constroversy',
#   'controvery',
#   'controvesy',
#   'controversay',
#   'contreversy'],
#  'etiology': ['eitiology'],
#  'snowing': ['showing'],
#  'military': ['millitary', 'milatary', 'militery'],
#  'cancellation': ['cansellation',
#   'cancallation',
#   'canacellation',
#   'cancillation',
#   'cancealation',
#   'cancelation'],
#  'criticism': ['criticisim',
#   'criticisam',
#   'critiscism',
#   'critigism',
#   'griticism',
#   'critisism',
#   'criticiam',
#   'criticise',
#   'criticisum',
#   'criticisms',
#   'criticisem',
#   'critizism',
#   'criticsm',
#   'critcism',
#   'criticizm'],
#  'golden': ['goldin', 'gloden'],
#  'sines': ['sinse'],
#  'divide': ['devide', 'divid'],
#  'subtracts': ['substracts'],
#  'sweetest': ['sweetes'],
#  'explained': ['explainded', 'explanned', 'explaind', 'eplained', 'explaned'],
#  'brought': ['broght', 'brough', 'brougth', 'bought'],
#  'sizeable': ['sizable'],
#  'spoke': ['spok'],
#  'music': ['muic'],
#  'telegraph': ['telagraph'],
#  'strike': ['stricke'],
#  'until': ['untill', 'untl'],
#  'holy': ['wholy', 'holly', 'holey'],
#  'successful': ['sucsessful',
#   'successfull',
#   'sucessful',
#   'successeful',
#   'suxcessful',
#   'suckessful',
#   'successfuly',
#   'succesful',
#   'succeshful',
#   'succsessful',
#   'succsesful'],
#  'hurt': ['hert'],
#  'glass': ['glas', 'glars'],
#  'reversible': ['reversable'],
#  'hole': ['hol', 'hold'],
#  'hold': ['hod', 'holed'],
#  'circumstances': ['circumstaces'],
#  'locked': ['lockd'],
#  'pursue': ['persue'],
#  'accomplishment': ['acomplishment'],
#  'apologetics': ['apolegetics'],
#  'locker': ['loker'],
#  'example': ['exemple', 'exmaple', 'exsample', 'exmple'],
#  'artillery': ['artillary'],
#  'organized': ['orginized'],
#  'caution': ['causion'],
#  'want': ['wont',
#   'wants',
#   'mant',
#   'whant',
#   'wand',
#   'watn',
#   'wnat',
#   'went',
#   'wat'],
#  'preferably': ['preferrably'],
#  'hog': ['hag'],
#  'hoe': ['how', 'ho'],
#  'travel': ['travle', 'travell'],
#  'damage': ['damaged',
#   'damadge',
#   'dameage',
#   'damge',
#   'dammage',
#   'damuge',
#   'damaze',
#   'danage',
#   'damnage'],
#  'machine': ['machane',
#   'matchine',
#   'macine',
#   'machiene',
#   'mechine',
#   'mashine',
#   'manchine',
#   'macheine'],
#  'how': ['hou', 'haw'],
#  'hot': ['thot', 'hoot', 'hote', 'hat'],
#  'hop': ['hope'],
#  'preferable': ['preferrable'],
#  'beauty': ['beuty'],
#  'outlawed': ['oulawed'],
#  'wrong': ['wrang', 'wronge', 'rong', 'wong', 'worng'],
#  'short-tempered': ['short_tempered'],
#  'effective': ['affective'],
#  'season': ['seson'],
#  'signatories': ['signitories'],
#  'baggage': ['bagage'],
#  'orally': ['erally'],
#  'keeps': ['keep'],
#  'wind': ['win', 'wid'],
#  'misdemeanor': ['misdemenor', 'misdameanor'],
#  'sunshine': ['sunshin'],
#  'nazareth': ['nazereth'],
#  'fir': ['fur'],
#  'fit': ['fite', 'fid'],
#  'unforeseen': ['unforseen'],
#  'heretofore': ['heretofor'],
#  'secede': ['seceed'],
#  'survivors': ['survivers'],
#  'coach-load': ['coach_load'],
#  'distinguishing': ['distingishing'],
#  'insubstantial': ['insubstancial'],
#  'him': ['im', 'his', 'ham', 'im', 'hm', 'hem', 'hime', 'hin'],
#  'grievous': ['grievious'],
#  'interrupt': ['interupt'],
#  'blink': ['blnk'],
#  'eisenhower': ['eisenhhower'],
#  'scholar': ['scholer'],
#  'represents': ['repreents'],
#  'shoelace': ['shoe_lace'],
#  'arrow': ['arow'],
#  'volcano': ['volcanoe'],
#  'obdurate': ['obdirate'],
#  'preceded': ['preceeded'],
#  'financial': ['financhial',
#   'financal',
#   'finanial',
#   'finantial',
#   'financual',
#   'finacial',
#   'fiancial'],
#  'snakes': ['snaks', 'snake'],
#  'archetypes': ['archtypes'],
#  'garment': ['garmet'],
#  'spider': ['spiter'],
#  'turnip': ['turnup'],
#  'precedes': ['preceeds'],
#  'fortnight': ['fort_night'],
#  'laboratory': ['labroratory',
#   'labortory',
#   'laboatory',
#   'laboretory',
#   'labratory',
#   'labaratory',
#   'lavoratory',
#   'laboritory',
#   'laborotory',
#   'laborbtory',
#   'laberatory'],
#  'ring': ['rings'],
#  'whip': ['wip'],
#  'excepting': ['exepting'],
#  'encourage': ['incourage', 'encorage', 'encourge'],
#  'engineer': ['engeneer', 'engieneer', 'enginer'],
#  'foundation': ['foundition', 'fondation'],
#  'assured': ['asured'],
#  'threatened': ['thretened'],
#  'surveys': ['survays'],
#  'grapes': ['graps'],
#  'sheet': ['sheat', 'shet'],
#  'estimate': ['estamate'],
#  'knit': ['knitt', 'nit'],
#  'universally': ['universaly'],
#  'enormous': ['enourmous', 'enormus'],
#  'ate': ['aet', 'ete'],
#  'scruff': ['scruf'],
#  'reprimanded': ['repremanded'],
#  'dinner-hour': ['dinner_hour'],
#  'today': ['todays', 'todya', 'to_day'],
#  'wash': ['wach', 'wosh'],
#  'instruct': ['instruck'],
#  'bitten': ['biten'],
#  'basketball': ['basketball',
#   'basketbale',
#   'basket-ball',
#   'baskeball',
#   'basket-ball',
#   'bascketball',
#   'basket-ball',
#   'baskitball',
#   'basket_ball'],
#  'service': ['survice', 'servise', 'servace'],
#  'similarly': ['similarily'],
#  'engagement': ['enagement'],
#  'needed': ['nedded', 'neaded'],
#  'perturbations': ['pertubations'],
#  'master': ['mater'],
#  'architect': ['archetect'],
#  'listen': ['lisen', 'listern'],
#  'geneva': ['geniva'],
#  'snooty': ['snoty'],
#  'predictable': ['predicable'],
#  'crawl': ['crall'],
#  'positively': ['positivly'],
#  'sidereal': ['sedereal', 'sideral'],
#  'showed': ['showd'],
#  'approximations': ['appoximations'],
#  'tree': ['treee', 'tre', 'three', 'tee'],
#  'omnivorous': ['omniverous'],
#  'project': ['projet', 'progect', 'projent'],
#  'pneumonia': ['pnuemonia',
#   'phneumonia',
#   'pneimonia',
#   'pnumonia',
#   'pneunonia',
#   'pneaumonia',
#   'pnemonia',
#   'pneumnia',
#   'pheumonia',
#   'pheumonia',
#   'pneumunia',
#   'neumonia',
#   'pneomonia',
#   'penumonia'],
#  'idle': ['idel', 'ide'],
#  'readjusted': ['reajusted'],
#  'seminary': ['seminery'],
#  'feeling': ['feling', 'felling', 'fealing'],
#  'acquisition': ['aquisition'],
#  'a_lot': ['alot'],
#  'to-day': ['to-days', 'today'],
#  'runner': ['runer'],
#  'dozen': ['doxen', 'dosen'],
#  'wholesome': ['wholsome', 'holesome'],
#  'responsible': ['responsable', 'responcible', 'reponsible'],
#  'metallic': ['metalic'],
#  'asymmetric': ['assymmetric', 'asymetric'],
#  'bang': ['bankg'],
#  'absorbed': ['asorbed'],
#  'amusing': ['amsing'],
#  'doors': ['doers', 'dors'],
#  'responsibly': ['responsably'],
#  'jones': ['johnes'],
#  'committing': ['commiting', 'comitting'],
#  'shall': ['shale', 'sall', 'shal'],
#  'object': ['objet'],
#  'a_little': ['alittle'],
#  'mouth': ['moth'],
#  'letter': ['leter'],
#  'professor': ['professer', 'profesor', 'proffessor'],
#  'camp': ['kamp', 'canp'],
#  'consummate': ['consumate'],
#  'nineteenth': ['ninteenth'],
#  'scream': ['screem', 'screm'],
#  'incomplete': ['incompleet'],
#  'marvel': ['marval'],
#  'polypropylene': ['polypropalene'],
#  'bomb': ['bombe', 'bome', 'bomm', 'bom'],
#  'gauge': ['garge',
#   'gange',
#   'gage',
#   'cauge',
#   'gaige',
#   'guage',
#   'gadge',
#   'gaoge'],
#  'lessons': ['lesson', 'lessens', 'lesons', 'leasons', 'lessions', 'lesson'],
#  'busy': ['buisy', 'bussy', 'bisy'],
#  'than': ['then', 'thna', 'tahn', 'that'],
#  'bush': ['buch'],
#  'touched': ['toched',
#   'tuched',
#   'toughed',
#   'toached',
#   'tougched',
#   'toulched',
#   'toutched'],
#  'rich': ['rick'],
#  'rice': ['rise'],
#  'lady': ['lade', 'ladey', 'ladiy', 'ladys'],
#  'plate': ['blate', 'plat'],
#  'terrors': ['terrours'],
#  'foremost': ['formost'],
#  'pocket': ['poket'],
#  'foundries': ['foundaries'],
#  'cushion': ['cusion'],
#  'altogether': ['alltogether'],
#  'jaguar': ['jagaur'],
#  'nicely': ['nicerly', 'nicly', 'micely'],
#  'boarder': ['border'],
#  'patch': ['pacth'],
#  'blew': ['blow'],
#  'disaster': ['diaster'],
#  'radius': ['radiuss', 'radious'],
#  'nocturnal': ['nocternal'],
#  'hammer': ['hamer'],
#  'best': ['bets',
#   'bast',
#   'dest',
#   'beat',
#   'bist',
#   'besh',
#   'besd',
#   'mest',
#   'beast',
#   'bess',
#   'bes',
#   'bet'],
#  'lots': ['losts', 'lotes', 'lot', 'lost'],
#  'propagates': ['propogates'],
#  'score': ['skore', 'scor'],
#  'side': ['sied', 'sid'],
#  'preserve': ['preseve'],
#  'never': ['neve',
#   'newer',
#   'mever',
#   'neaver',
#   'neiver',
#   'naver',
#   'neven',
#   'nver'],
#  'extend': ['exstend', 'extand'],
#  'nature': ['nuture'],
#  'rolled': ['rolld'],
#  'invigorated': ['envigorated'],
#  'souvenir': ['souvenier'],
#  'extent': ['exstent'],
#  'wheelbarrow': ['wheel_barrow'],
#  'debt': ['dept', 'deat'],
#  'tyranny': ['tyrany'],
#  'patented': ['pattented'],
#  'accident': ['axcident',
#   'accicent',
#   'acsident',
#   'accsident',
#   'accxident',
#   'ancident',
#   'acident',
#   'accdient',
#   'accedent'],
#  'chirped': ['cherped'],
#  'country': ['ocuntry', 'contry', 'county', 'coontry'],
#  'incense': ['insense'],
#  'levitating': ['levetating'],
#  'planned': ['planed'],
#  'humming': ['huming'],
#  'cardboard': ['cardbord'],
#  'source': ['sorce', 'aource', 'sourse'],
#  'union': ['unioun'],
#  'much': ['mush', 'mach'],
#  'stadium': ['staydium'],
#  'privilege': ['priviledge',
#   'privelege',
#   'previlege',
#   'privileged',
#   'privilage',
#   'privilige'],
#  'fry': ['fri'],
#  'incompetent': ['incompetant'],
#  'life': ['lif', 'lief', 'live', 'lefe'],
#  'spit': ['spite'],
#  'eastern': ['eastren'],
#  'wish': ['wich', 'wis', 'whish'],
#  'lift': ['left'],
#  'toboggan': ['tobogan', 'taboggan', 'tobaggan', 'toboggen'],
#  'child': ['cild'],
#  'worked': ['worted'],
#  'spin': ['spen'],
#  'skilfully': ['skilfuly', 'skilfuley', 'scilfully', 'skillfully', 'skifully'],
#  'commerce': ['comerce'],
#  'dissect': ['disect'],
#  'employ': ['employe', 'imploy'],
#  'visit': ['visite', 'vist'],
#  'anticipating': ['antecipating',
#   'anticepating',
#   'anticpating',
#   'anticipting',
#   'antiscipating',
#   'antisipating',
#   'anticapating',
#   'anticipateing'],
#  'violin': ['volin', 'vioiln'],
#  'oxymoron': ['oximoron'],
#  'damaged': ['damiged',
#   'dameaged',
#   'damanged',
#   'damagd',
#   'damage',
#   'dammaged',
#   'damged',
#   'damagtd',
#   'damadged',
#   'bamaged',
#   'dameged',
#   'danaged',
#   'danmaged'],
#  'things': ['thigns', 'tings', 'thinks', 'thing', 'thnigs', 'thigs'],
#  'demands': ['diemands'],
#  'split': ['splite', 'spilt'],
#  'babies': ['babyies', 'babis', 'badies', 'babbes', 'babes', 'babyes'],
#  'fairly': ['faily', 'farly', 'fairlu'],
#  'married': ['marrid',
#   'marride',
#   'marryied',
#   'marreid',
#   'marriad',
#   'maried',
#   'marred',
#   'marrid'],
#  'supper': ['super'],
#  'peremptory': ['preemptory'],
#  'rescinded': ['resinded'],
#  'academic': ['accademic', 'acedemic'],
#  'subpoena': ['subpena'],
#  'form-mistress': ['formmistress'],
#  'corporate': ['corparate'],
#  'plaque': ['placque'],
#  'capitol': ['capital'],
#  'distribute': ['distribut', 'distrubute'],
#  'sleepy': ['sleppy', 'sleepey'],
#  'financially': ['financilly',
#   'finnancially',
#   'financialy',
#   'finincially',
#   'finantially',
#   'financally',
#   'financhally',
#   'finiancially',
#   'finacially',
#   'financeally',
#   'fianancially',
#   'fiancially',
#   'financinally',
#   'financually',
#   'finanically'],
#  'portrayed': ['protrayed'],
#  'succeeding': ['suceeding'],
#  'previous': ['previvous', 'preveous', 'previos', 'previus'],
#  'purchased': ['perchased'],
#  'old-fashioned': ['oldfashioned'],
#  'had': ['head',
#   'ad',
#   'han',
#   'hab',
#   'hade',
#   'hed',
#   'has',
#   'hat',
#   'haed',
#   'hade'],
#  'connecticut': ['conneticut'],
#  'obedient': ['obediant', 'obedent'],
#  'innocent': ['innoncent',
#   'innocent',
#   'inocent',
#   'innosent',
#   'innocents',
#   'innacent',
#   'innicent',
#   'ennocent',
#   'innoscent',
#   'inoncent',
#   'innorcent',
#   'inocent'],
#  'prison': ['prisin', 'preson', 'prision'],
#  'has': ['hase', 'as', 'his', 'hos', 'hase'],
#  'hat': ['hot'],
#  'every_time': ['everytime'],
#  'confidentially': ['confidentally'],
#  'disagreement': ['dissagreement'],
#  'possible': ['possibly', 'pissible', 'possable', 'posible'],
#  'unequivocally': ['unequivocaly'],
#  'possibly': ['possably', 'possiply', 'possible'],
#  'birth': ['berth'],
#  'missouri': ['misouri'],
#  'shadow': ['shaddow', 'shodow'],
#  'unique': ['uneque'],
#  'occurring': ['occuring'],
#  'desire': ['disire'],
#  'psychological': ['psycological'],
#  'remind': ['remined',
#   'remond',
#   'remied',
#   'remine',
#   're_mind',
#   'renind',
#   'remaind'],
#  'pavement': ['pavment'],
#  'steps': ['staps'],
#  'prologue': ['prolague', 'prologe', 'prolouge'],
#  'ithaca': ['ihaca'],
#  'misdemeanors': ['misdameanors', 'misdemenors'],
#  'swedish': ['sweedish'],
#  'attorney': ['atterney', 'atorney', 'atturney'],
#  'right': ['rigth'],
#  'old': ['ald', 'ol', 'lod', 'olf'],
#  'creek': ['creak'],
#  'crowd': ['croud'],
#  'people': ['pople',
#   'pleople',
#   'peiple',
#   'poeple',
#   'peple',
#   'peopl',
#   'peopel',
#   'peolpe',
#   'peaple',
#   'pepole'],
#  'crown': ['croun'],
#  'insistence': ['insistance'],
#  'harassment': ['harasment'],
#  'creep': ['creap'],
#  'enemies': ['enemeies',
#   'enemes',
#   'eniemies',
#   'enamies',
#   'enemyies',
#   'enimies',
#   'enmies'],
#  'for': ['fror',
#   'fur',
#   'far',
#   'fro',
#   'fore',
#   'four',
#   'foir',
#   'forr',
#   'fon',
#   'or',
#   'fo'],
#  'bottom': ['bottem', 'botton', 'botom'],
#  'fox': ['foxx'],
#  'polluted': ['poluted'],
#  'pollutes': ['polutes'],
#  'dinner-hours': ['dinner_hours'],
#  'losing': ['loosing', 'loseing', 'lossing'],
#  'memorable': ['memerable'],
#  'manufacturing': ['manufactoring', 'manufaturing'],
#  'dollars': ['dollers'],
#  'anomalous': ['anomolous', 'anomalus'],
#  'recollect': ['reccollect', 'recolect'],
#  'despair': ['dispair'],
#  'slightly': ['slighlty'],
#  'raised': ['rased'],
#  'feb': ['fab'],
#  'honeymoon': ['honey_moon', 'honymoon'],
#  'well-suited': ['well_suited'],
#  'son': ['sun'],
#  'respectable': ['respectible'],
#  'consummated': ['consumated'],
#  'sow': ['sew'],
#  'wrap': ['rap'],
#  'unambiguous': ['unabiguous'],
#  'hallo': ['halloe'],
#  'altitude': ['atitude',
#   'actitude',
#   'altitube',
#   'altituded',
#   'eltitude',
#   'altitud',
#   'alltitude',
#   'altiude',
#   'altilude',
#   'altitued',
#   'altetude'],
#  'constantly': ['constanly', 'constently'],
#  'tame': ['tam'],
#  'width': ['with'],
#  'boy': ['boys', 'buy', 'bay'],
#  'overhead': ['overhaed'],
#  'happy': ['happiy', 'happe', 'hapy', 'happi'],
#  'offer': ['ofer'],
#  'cassowary': ['cassowarry'],
#  'talents': ['tallents'],
#  'understandable': ['understadable'],
#  'beech': ['beach'],
#  'safeguard': ['safegaurd'],
#  'congratulations': ['congratulation',
#   'congraulations',
#   'congrutulations',
#   'congralulations',
#   'congratulatons',
#   'congradulations',
#   'congretulations',
#   'congragulations',
#   'congratilations',
#   'congratualations',
#   'congratalations',
#   'congreatulations',
#   'congractulations',
#   'congratuations'],
#  'genealogy': ['geneology'],
#  'else': ['elss', 'els', 'eles', 'esle'],
#  'inside': ['insid', 'in_side'],
#  'unanimous': ['unanumous',
#   'unanious',
#   'unaninous',
#   'unnanimous',
#   'unaimous',
#   'unanmous',
#   'unanomous',
#   'unanamous',
#   'unanimos',
#   'unannimous',
#   'unanimus',
#   'unanemous'],
#  'palm': ['parm'],
#  'passenger': ['passanger'],
#  'later': ['latey', 'latter', 'lated'],
#  'steady': ['stedy'],
#  'tournament': ['touranment',
#   'tournment',
#   'tournanent',
#   'tournement',
#   'turnament',
#   'tourament',
#   'atournament',
#   'tourmament',
#   'tournnament',
#   'tournamant',
#   'tornament',
#   'tourniment'],
#  'proves': ['prooves'],
#  'exist': ['exsist'],
#  'dealer': ['dealor'],
#  'negotiations': ['nogotiations',
#   'negoatiations',
#   'negotitations',
#   'neguotiations',
#   'negotiation',
#   'negotitions',
#   'negotiatins',
#   'negatiations',
#   'negoiations',
#   'negotations',
#   'negotciations',
#   'negogiations',
#   'negociations',
#   'negosiations'],
#  'floor': ['flor', 'foor'],
#  'flood': ['flod'],
#  'superfluous': ['superfulous'],
#  'roll': ['rol'],
#  'double-cross': ['double_cross'],
#  'asterisk': ['asterick'],
#  'eminent': ['emminent', 'iminent'],
#  'scale': ['skale'],
#  'rolling': ['roling'],
#  'quandary': ['quandry'],
#  'good-natured': ['good_natured'],
#  'time': ['tiem', 'timne', 'tame', 'tim', 'tine', 'tiome'],
#  'push': ['puch'],
#  'breadth': ['breath'],
#  'chain': ['chan', 'choin'],
#  'whoever': ['who_ever'],
#  'indians': ['indian'],
#  'integration': ['intergration'],
#  'skate': ['skat'],
#  'chair': ['char', 'chiar'],
#  'midst': ['mist'],
#  'ukrainian': ['ukranian'],
#  'philosopher': ['philisopher'],
#  'vet': ['vent'],
#  'mache': ['mashe'],
#  'cheap': ['cheep'],
#  'choice': ['choise'],
#  'gloomy': ['glomy'],
#  'break_time': ['breaktime'],
#  'exact': ['exsact'],
#  'minute': ['minuet', 'minite', 'miniute'],
#  'leave': ['leasve', 'leav', 'leve'],
#  'settle': ['settel'],
#  'team': ['term', 'teem', 'tem'],
#  'loads': ['loades'],
#  'prevent': ['pervent'],
#  'spiritual': ['spiritul',
#   'spiritural',
#   'speritual',
#   'spirtual',
#   'spirttual',
#   'spirituall',
#   'spritual',
#   'spirital',
#   'spiritial'],
#  'occurrence': ['occurrance', 'occurence', 'ocurrence'],
#  'two-faced': ['two_faced'],
#  'attic': ['atic'],
#  'sign': ['sighn', 'eign', 'sion'],
#  'candlestick': ['candle_stick'],
#  'essence': ['essense'],
#  'jeopardy': ['jeapardy', 'jepardy'],
#  'celebrated': ['celebrate'],
#  'melt': ['malt'],
#  'current': ['curent'],
#  'extraterrestrial': ['extraterrestial'],
#  'falling': ['folling'],
#  'badge': ['bage'],
#  'jury': ['jurry'],
#  'funeral': ['funerl'],
#  'understanding': ['understanting', 'undestanding', 'under_standing'],
#  'address': ['adress', 'addres'],
#  'alone': ['a_lone', 'alon'],
#  'along': ['a_long', 'aling', 'alog', 'allong'],
#  'my': ['by', 'me', 'ma', 'may', 'mi', 'miy', 'ny', 'by'],
#  'momentous': ['momentus'],
#  'financiers': ['financers'],
#  'dusty': ['duste'],
#  'studied': ['studed', 'studyed'],
#  'wherever': ['whereever'],
#  'commonly': ['commongly'],
#  'accomplished': ['aclomplished', 'apcomplished', 'acomplished'],
#  'proclamation': ['proclomation'],
#  'love': ['lvoe', 'loev'],
#  'radish': ['raddish'],
#  'prefer': ['preafer',
#   'prefor',
#   'perfer',
#   'pefer',
#   'profer',
#   'prefur',
#   'prefere'],
#  'bloody': ['blody'],
#  'marvelous': ['marvellous', 'marvalous'],
#  'grandpa': ['grandpas', 'grandpar'],
#  'working': ['warking', 'wroking', 'wokring', 'woking'],
#  'homesick': ['homsick'],
#  'positive': ['positve', 'possitive'],
#  'angry': ['angery', 'angrey'],
#  'dangle': ['dongle'],
#  'vigour': ['vigeur'],
#  'wood': ['wod'],
#  'opposed': ['apposed'],
#  'wondering': ['wondring'],
#  'films': ['firms'],
#  'loving': ['loveing'],
#  'marbles': ['marables'],
#  'afford': ['affort', 'efford', 'aford'],
#  'apparent': ['appearent',
#   'apprarent',
#   'apparant',
#   'apperent',
#   'apprent',
#   'aparent',
#   'apparient'],
#  'appendix': ['apendix'],
#  'everywhere': ['everwhere', 'eveywhere'],
#  'virtue': ['vertue',
#   'virtu',
#   'virture',
#   'vurtue',
#   'virtues',
#   'virtuge',
#   'virtrue'],
#  'originally': ['orrginally',
#   'originnally',
#   'oringinally',
#   'origionally',
#   'originially',
#   'orriginally',
#   'orignially',
#   'originually',
#   'origially',
#   'origianally',
#   'oreginally',
#   'origenally',
#   'origanally',
#   'origonally',
#   'originaly',
#   'oridinally',
#   'orginally',
#   'orignally'],
#  'pretend': ['preted',
#   'prutend',
#   'pretned',
#   'peretend',
#   'protend',
#   'pretennd',
#   'pretent',
#   'pretened',
#   'bretend',
#   'petend',
#   'prertend',
#   'preten',
#   'preatend',
#   'pritend',
#   'predend',
#   'prtend',
#   'phretend',
#   'pertend',
#   'prelend',
#   'prentend'],
#  'believes': ['belives', 'beleives'],
#  'printing': ['priting', 'prenting'],
#  'believed': ['beleived'],
#  'detached': ['detatched'],
#  'stockroom': ['stock_room'],
#  'sacrament': ['sacrement'],
#  'unequalled': ['unequaled'],
#  'allowed': ['alowed'],
#  'stole': ['stol', 'stold'],
#  'evidently': ['evedently'],
#  'monitoring': ['monitering'],
#  'winter': ['witer'],
#  'divided': ['devided'],
#  'thanking': ['thinking'],
#  'elephant': ['elphant'],
#  'laundry': ['loundry', 'landry'],
#  'spot': ['shot', 'spout', 'srot', 'sport', 'spat'],
#  'elbow-grease': ['elbowgrease'],
#  'rehabilitate': ['rehabilatate'],
#  'date': ['dake', 'dute', 'datr', 'dat', 'dade'],
#  'such': ['sach', 'shuch', 'suh'],
#  'data': ['dat', 'dsata'],
#  'natural': ['natureal', 'naturual', 'natrual'],
#  'varieties': ['varities'],
#  'conscious': ['conscius',
#   'conicious',
#   'consious',
#   'counscious',
#   'consciouse',
#   'consceious',
#   'consicious',
#   'concious'],
#  'wheelchair': ['wheel_chair'],
#  'ordinarily': ['ordinairily',
#   'ordanarily',
#   'oridinarily',
#   'ordinarialy',
#   'ordinarlily',
#   'ordinaryly',
#   'ordinarly',
#   'ordinairly',
#   'ordinarilly',
#   'ordinarrly',
#   'ardinarily',
#   'ordinarlly',
#   'ordinarely',
#   'ordinaraly',
#   'ordainarily',
#   'ordinerily',
#   'ordinaroly',
#   'ordinaryily',
#   'ordonarily'],
#  'so': ['soe', 'som', 'sol', 'sow', 'sor'],
#  'swollen': ['swolen'],
#  'definitions': ['defenitions'],
#  'innocuous': ['inocuous'],
#  'archeologist': ['archeaologist'],
#  'flips': ['frips'],
#  'years': ['yeasr',
#   'eyars',
#   'yeers',
#   'yeras',
#   'yesars',
#   'yars',
#   'yeas',
#   'year',
#   'yers'],
#  'course': ['coure', 'corse', 'coarse'],
#  'experiments': ['experments', 'experiaments'],
#  'quarrelled': ['quarelled'],
#  'omitting': ['ommitting', 'omiting'],
#  'deity': ['diety'],
#  'tendency': ['tendancy'],
#  'tore': ['tor'],
#  'solitary': ['solatary'],
#  'thumb': ['thum'],
#  'internationally': ['internationlly'],
#  'hymn-books': ['hymn_books'],
#  'torn': ['tourn', 'tron', 'turn'],
#  'councillor': ['councellor'],
#  'attraction': ['atraction'],
#  'suspicion': ['susspicion',
#   'suppicion',
#   'suspecion',
#   'suspition',
#   'supicion',
#   'suspician',
#   'suspicison',
#   'suspiscion',
#   'suspicsion',
#   'supsicion',
#   'suspiction',
#   'suspision'],
#  'petition': ['petetion'],
#  'apron': ['apon'],
#  'recipients': ['recepients', 'recipiants'],
#  'civilian': ['civillian'],
#  'matches': ['maches'],
#  'bashful': ['basful', 'bashfull'],
#  'records': ['rocords'],
#  'compelled': ['compeled'],
#  'subscribers': ['suscribers'],
#  'twilight': ['twlight'],
#  'handiwork': ['handywork'],
#  'shouted': ['shauted'],
#  'establishing': ['establashing',
#   'establisheng',
#   'establising',
#   'estableshing',
#   'estaplishing',
#   'esstablishing',
#   'astablishing',
#   'istablishing',
#   'estableishing',
#   'estsablishing',
#   'eastablishing',
#   'exstablishing',
#   'estabishing'],
#  'splinters': ['spliters'],
#  'stanley': ['stanlay'],
#  'quarter': ['quater'],
#  'turtle': ['turtel'],
#  'square': ['sqare', 'squar'],
#  'receipt': ['reciept', 'recipt', 'receit', 'recept'],
#  'breakthrough': ['breakthough'],
#  'frames': ['frame'],
#  'owing': ['oweing'],
#  'sponsor': ['sponser'],
#  'canvas': ['canvis'],
#  'michigan': ['michagan'],
#  'contained': ['contasined', 'containd'],
#  'investigation': ['investagation'],
#  'chemically': ['chemicaly', 'chemcially'],
#  'disintegrated': ['desintegrated'],
#  'siege': ['seige'],
#  'million': ['millon'],
#  'striven': ['strived'],
#  'possibility': ['posibility', 'possibilty'],
#  'quite': ['quit', 'quiet', 'qutie'],
#  'complicated': ['compicated'],
#  'grandma': ['grandna'],
#  'poems': ['pomems',
#   'poams',
#   'poemas',
#   'poem',
#   'poemes',
#   'peoms',
#   'poims',
#   'pomes',
#   'paems',
#   'powems',
#   'porms'],
#  'remainder': ['remander'],
#  'training': ['trianing', 'traning', 'taining', 'trainning', 'tranning'],
#  'modest': ['modist'],
#  'recompense': ['recompence'],
#  'neglect': ['neclect', 'neglet'],
#  'emotion': ['emition'],
#  'saving': ['saveing'],
#  'symmetry': ['symmatry', 'symetry'],
#  'architecturally': ['archetecturally'],
#  'royal': ['royl'],
#  'one': ['on', 'ome', 'onen', 'ond', 'oen', 'ont'],
#  'cloakroom': ['cloak_room'],
#  'submit': ['submite', 'sumit'],
#  'vote': ['vot', 'voet'],
#  'open': ['opin', 'opne', 'opean'],
#  'affords': ['effords'],
#  'exaggerations': ['exagerations'],
#  'city': ['citty', 'sity', 'cite'],
#  'monday': ['munday'],
#  'thirdly': ['thirdy'],
#  'bite': ['bit'],
#  'structured': ['stuctured'],
#  'under_ladder': ['underladder'],
#  'indicate': ['indecate'],
#  'teacher': ['teather',
#   'teaher',
#   'techer',
#   'tearcher',
#   'teachur',
#   'teasher',
#   'teatcher',
#   'teahcher',
#   'tearcher'],
#  'draft': ['deaft'],
#  'structures': ['structurs'],
#  'ridiculous': ['ridiculeous',
#   'ridiculois',
#   'ridiculos',
#   'rudiculous',
#   'ridiculious',
#   'ridicilous',
#   'ridiculus',
#   'rideculous',
#   'rediculous'],
#  'sept': ['sep'],
#  'boyfriend': ['boyfrend', 'boyfreind', 'boy_friend'],
#  'depressed': ['depresed'],
#  'folly': ['foly',
#   'folloy',
#   'folley',
#   'fooly',
#   'foley',
#   'fally',
#   'floly',
#   'foully'],
#  'coats': ['coots'],
#  'athenians': ['atheneans'],
#  'unfit': ['unfitt'],
#  'in_front': ['infront'],
#  'janitor': ['janiter'],
#  'prospect': ['propect'],
#  'addressing': ['addresing', 'adressing'],
#  'turned': ['turened',
#   'tured',
#   'tuned',
#   'turrned',
#   'teurned',
#   'turend',
#   'truned',
#   'terned',
#   'turnd'],
#  'argument': ['aurgument', 'arguement'],
#  'alley': ['ally'],
#  'sad': ['sed', 'sade'],
#  'prestigious': ['prestigous', 'prestigeous'],
#  'rained': ['raind'],
#  'buried': ['buired',
#   'burried',
#   'buriel',
#   'bured',
#   'bried',
#   'baried',
#   'buiried',
#   'buryed',
#   'beried',
#   'buryied',
#   'burred'],
#  'saw': ['sew', 'sow', 'sa', 'san'],
#  'sat': ['set'],
#  'handicraft': ['handi_craft', 'hand_craft'],
#  'did_not': ['didnot'],
#  'note': ['not', 'noet'],
#  'maintain': ['mantain'],
#  'take': ['tacke', 'tkae', 'taek', 'tak'],
#  'destroy': ['distroy'],
#  'encouraged': ['encourage', 'incouraged'],
#  'opposite': ['opposit',
#   'oposite',
#   'oppsite',
#   'oppoiste',
#   'opposte',
#   'oppisite',
#   'opposited',
#   'oppasite',
#   'oppossite',
#   'oppesite'],
#  'syllable': ['sylable'],
#  'knew': ['new'],
#  'printed': ['prented'],
#  'knee': ['nee'],
#  'personalty': ['personality'],
#  'pages': ['pagis'],
#  'adaptability': ['adaptibility'],
#  'portuguese': ['portugese'],
#  'lawn': ['lown'],
#  'average': ['avarage'],
#  'drive': ['driv'],
#  'ways': ['was', 'way'],
#  'salt': ['slat', 'solt'],
#  'walking': ['wallking',
#   'waulking',
#   'wolking',
#   'warking',
#   'wakking',
#   'wilking',
#   'waking',
#   'wacking'],
#  'murmurs': ['murmers'],
#  'surplus': ['surples',
#   'serplus',
#   'surpluse',
#   'surpluss',
#   'surplas',
#   'surplis',
#   'surplut',
#   'sirplus',
#   'surplos',
#   'suplus'],
#  'pencilled': ['penciled'],
#  'infuriate': ['enfuriate'],
#  'merit': ['merrit'],
#  'peaches': ['peches'],
#  'scarce': ['scarse'],
#  'aggressive': ['aggresive', 'agressive'],
#  'weapons': ['wepons'],
#  'slow': ['slo'],
#  'gourd': ['gaurd'],
#  'cloak': ['clock'],
#  'going': ['oging', 'gonig', 'goign', 'gowing', 'gying', 'goning'],
#  'hockey': ['hocky'],
#  'equipped': ['aquipped',
#   'eqquipped',
#   'equipted',
#   'equippted',
#   'equiped',
#   'iquipped',
#   'equpped',
#   'ecquipped'],
#  'congressional': ['congresional'],
#  'dispute': ['disput'],
#  'assistant': ['assitant', 'assisstant'],
#  'freezing': ['freeing',
#   'frezing',
#   'feezing',
#   'freesing',
#   'freezzing',
#   'freeding',
#   'frezzing',
#   'frezeing'],
#  'awaiting': ['awaitin'],
#  'an_hour': ['anhour'],
#  'resource': ['resorce', 'resoure', 'resouce', 'recource', 'resourse'],
#  'artist': ['artest'],
#  'borrow': ['barrow'],
#  'worried': ['woried', 'worred'],
#  'priest': ['preist'],
#  'bee-keepers': ['bee_keepers'],
#  'bombs': ['bomes', 'boms'],
#  'liable': ['lieable', 'lible', 'lyable'],
#  'where': ['there', 'wher', 'hwere'],
#  'arrival': ['arival', 'arrivial'],
#  'surgery': ['surgere'],
#  'jumped': ['jumper'],
#  'receivers': ['recievers'],
#  'representatives': ['representative',
#   'represntatives',
#   'represenatives',
#   'repesentatives',
#   'represenatives',
#   'representitives',
#   'represnetatives',
#   'representative',
#   'repersentatives',
#   'represenitatives'],
#  'dormitory': ['dormiatory',
#   'dormotory',
#   'dormatory',
#   'dormitary',
#   'dormitoriy',
#   'doromitory',
#   'dormintory',
#   'dormetory',
#   'domitory',
#   'dorimitory',
#   'dormitlory',
#   'dormiltory',
#   'dorimtory',
#   'doritory'],
#  'kilometer': ['lilometer'],
#  'cantaloupe': ['cantaloube'],
#  'aberration': ['aberation'],
#  'suppresses': ['supresses'],
#  'revealed': ['revealled'],
#  'concentrate': ['concetrate', 'consentrate'],
#  'spare': ['share', 'spere', 'spar'],
#  'in_between': ['inbetween'],
#  'suppressed': ['surpressed', 'supressed'],
#  'concentrated': ['consentrated'],
#  'mans': ['masn'],
#  'many': ['meny', 'may', 'manny', 'mony'],
#  'millionaire': ['millionnaire'],
#  'besieging': ['beseiging'],
#  'personal': ['personel', 'persnal'],
#  'concentrates': ['consentrates'],
#  'expression': ['expresion'],
#  'ca': ['can', 'car'],
#  'allowance': ['allowence'],
#  'yearly': ['yearley'],
#  'twin': ['twen'],
#  'comeback': ['comback'],
#  'geese': ['gees'],
#  'buoyancy': ['bouyancy'],
#  'considers': ['conciders'],
#  'boat': ['boaut', 'bot'],
#  'caring': ['careing'],
#  'comb': ['come'],
#  'unconsciousness': ['unconciousness'],
#  'stretch': ['strech', 'streach'],
#  'west': ['wast'],
#  'locally': ['localy'],
#  'vacation': ['vakation', 'vaction'],
#  'concede': ['consede'],
#  'breath': ['breathe', 'breth', 'brath'],
#  'practised': ['practise', 'practiced'],
#  'wants': ['wans', 'wnats', 'wantes', 'want'],
#  'enable': ['unable', 'anable'],
#  'thousand': ['thousend', 'thousnand'],
#  'formed': ['fromed', 'formd'],
#  'observe': ['obsirve'],
#  'extant': ['extint'],
#  'calligraphy': ['caligraphy'],
#  'former': ['farmer'],
#  'prominence': ['prominance'],
#  'easier': ['eassier', 'easyer', 'easer'],
#  'newspaper': ['newpaper', 'newspapper', 'news_paper'],
#  'situation': ['situration'],
#  'constituency': ['consituency'],
#  'all-round': ['all_round'],
#  'purse': ['purce', 'perse'],
#  'vandalism': ['vandolism'],
#  'sickness': ['sicknes'],
#  'i': ['a', 'is', 'it', 'iy', 'if', "'", 'v', 'id', "'", 'n', 'im', 'im'],
#  'advertisement': ['advertisment'],
#  'volcanoes': ['volcanos'],
#  'vacant': ['vacent'],
#  'tentacle': ['tenacle'],
#  'so_forth': ['soforth', 'so-forth'],
#  'genii': ['genei'],
#  'grumpy': ['grumby'],
#  'summer': ['sumer'],
#  'being': ['bieng', 'bieing', 'beeing'],
#  'truculent': ['trucculent'],
#  'exaggerating': ['exagerating'],
#  'rest': ['rast'],
#  'schools': ['school'],
#  'steamer': ['stemer'],
#  'omissions': ['ommissions'],
#  'weekly': ['weakly'],
#  'sixteen': ['sixten'],
#  'silver': ['siver', 'sliver'],
#  'instrument': ['instrement', 'instrment', 'instriment'],
#  'prominently': ['prominantly'],
#  'aspects': ['spects'],
#  'around': ['arouned',
#   'aroand',
#   'aroud',
#   'arond',
#   'arround',
#   'a_round',
#   'arownd',
#   'round'],
#  'knobbly': ['nobbly'],
#  'dart': ['art',
#   'darrt',
#   'darte',
#   'durt',
#   'daet',
#   'dard',
#   'tart',
#   'dert',
#   'dirt',
#   'dat',
#   'deart',
#   'drat',
#   'drt',
#   'dort'],
#  'dark': ['durk',
#   'dork',
#   'drak',
#   'darrk',
#   'darw',
#   'dak',
#   'dare',
#   'dard',
#   'drk',
#   'dank',
#   'darck'],
#  'traffic': ['traffi',
#   'trafic',
#   'traffc',
#   'traffig',
#   'traffice',
#   'traffik',
#   'tarffic'],
#  'bandage': ['bandge'],
#  'vacuum': ['vaccum'],
#  'world': ['word', 'would', 'wold', 'wourld'],
#  'postal': ['postel'],
#  'vague': ['vage'],
#  'satisfaction': ['satisfacsion',
#   'satisfacion',
#   'satesfaction',
#   'satisfation',
#   'satisfactoin',
#   'satisfacttion',
#   'satishfaction',
#   'satitfaction',
#   'sitisfaction',
#   'satifaction'],
#  'unrepentant': ['unrepentent'],
#  'nutrients': ['nutritents'],
#  'souvenirs': ['souveniers'],
#  'stationary': ['stationery'],
#  'clap': ['klap', 'clape'],
#  'auditorium': ['autitorium',
#   'additorium',
#   'auditorim',
#   'auditarium',
#   'audetorium',
#   'audotorium',
#   'auditoriam',
#   'auditoruium',
#   'auditorinum',
#   'ouditorium',
#   'auditorum',
#   'auditoium',
#   'auditoryum',
#   'auditoriom',
#   'auditoreum',
#   'audiotorium',
#   'audatorium',
#   'auditoriumn',
#   'auditoriun',
#   'aditorium'],
#  'satisfactory': ['satsfactory', 'satifactory', 'satisfactary'],
#  'superintendent': ['superintendant'],
#  'learning': ['learnning', 'learing', 'lerning', 'learining'],
#  'supplementary': ['suplementary'],
#  'divine': ['divide', 'devine', 'divene'],
#  'thinks': ['thikns'],
#  'memories': ['momories',
#   'memoaries',
#   'mermories',
#   'memordies',
#   'memorries',
#   'memoiries',
#   'memuries',
#   'memmories',
#   'merories',
#   'memoryes',
#   'memouries',
#   'memorie',
#   'memeries'],
#  'noon': ['non'],
#  'endocrine': ['endochrine'],
#  'refer': ['refere'],
#  'unsuccessfully': ['unsucessfully'],
#  'accessing': ['accesing'],
#  'power': ['pwoer'],
#  'in_spite': ['inspite'],
#  'playing-field': ['playing_field'],
#  'stone': ['ston'],
#  'package': ['packege', 'pakage'],
#  'meal': ['mel', 'mell'],
#  'neighbor': ['neighbour'],
#  'act': ['at', 'akt'],
#  'luck': ['lock'],
#  'burning': ['buring'],
#  'legged': ['leged'],
#  'lively': ['livly', 'livley'],
#  'accumulated': ['acumulated'],
#  'technically': ['technecally'],
#  'burglar': ['burgler', 'buglar'],
#  'her': ['hir', 'har', 'he', 'here'],
#  'water-rat': ['waterrat'],
#  'bubble': ['buble'],
#  'yearned': ['yerned'],
#  'elimination': ['eleimination', 'elimiation'],
#  'impedance': ['impedence'],
#  'mice': ['mise'],
#  'with': ['iwth',
#   'wihth',
#   'whith',
#   'wite',
#   'wiht',
#   'wirth',
#   'wtih',
#   'withe',
#   'weth',
#   'wit',
#   'witht'],
#  'buying': ['buyin', 'bying'],
#  'handsome': ['hansome'],
#  'they': ['the', 'thy', 'thay', 'thea', 'tehy', 'the', 'ther'],
#  'rush': ['ruch'],
#  'dirty': ['diry', 'durty'],
#  'dispensing': ['dispencing'],
#  'agree': ['agre'],
#  'detailed': ['detailled'],
#  'gone': ['gon', 'gome', 'gonne'],
#  'gratuitous': ['gratuitious'],
#  'exhausted': ['exausted', 'exhasted'],
#  'certain': ['certian', 'ceratin', 'curtain', 'sertain', 'cirtain'],
#  'cinderella': ['cinderrella'],
#  'am': ['ham', 'an'],
#  'an': ['a', 'and', 'un', 'am', 'on'],
#  'as': ['ass', 'a', 'asw', 'was', 'is', 'at', 'aas', 'has', 'als'],
#  'at': ['a', 'ast', 'al', 'an', 'as', 'att'],
#  'creak': ['creek'],
#  'cream': ['crem'],
#  'ideally': ['idealy'],
#  'graduate': ['graguate'],
#  'watson': ['watston'],
#  'unparalleled': ['unparalleld',
#   'unparallelled',
#   'unparlleled',
#   'unparralleled',
#   'unparalelled',
#   'unparelleled'],
#  'puppy': ['pupy'],
#  'contemporaries': ['contamporaries'],
#  'congress': ['congress', 'cnongress', 'cangress', 'congres', 'comgress'],
#  'spermatozoa': ['spermatozoan'],
#  'tiger': ['tigar'],
#  'mask': ['mast', 'marsk'],
#  'having': ['haveing', 'hvaing'],
#  'impossibility': ['impossibilty'],
#  'mass': ['mas'],
#  'original': ['origional', 'orginal', 'origanal'],
#  'canada': ['canda'],
#  'gingham': ['gingam'],
#  'consider': ['consdider', 'concider', 'consiter'],
#  'caused': ['cased'],
#  'beware': ['bewere'],
#  'caesar': ['ceasar'],
#  'causes': ['cases'],
#  'hunting': ['hanting'],
#  'to': ['ro', 'tow', 'too', 'th', 'ot'],
#  'tail': ['tall'],
#  'scratch': ['scrach'],
#  'smile': ['smil'],
#  'case': ['cace'],
#  'appointment': ['appoitment', 'apointment'],
#  'debit': ['defit',
#   'deblit',
#   'debet',
#   'debat',
#   'devit',
#   'debot',
#   'depit',
#   'debt',
#   'dibit',
#   'debut',
#   'debtit',
#   'depbit',
#   'debite'],
#  'baton': ['batton'],
#  'puzzles': ['puzzle'],
#  'manageable': ['managable'],
#  'condition': ['condidtion'],
#  'accompanying': ['accumpanying',
#   'accompaning',
#   'occompanying',
#   'accompaying',
#   'accomponying',
#   'acompanying',
#   'accompnying',
#   'accompagnying',
#   'accompanning'],
#  'marvellous': ['marvelous'],
#  'toby': ['tobe'],
#  'dodged': ['dogged',
#   'lodged',
#   'dodjed',
#   'doged',
#   'dodge',
#   'dodeged',
#   'dooged',
#   'dogded',
#   'dodger'],
#  'large': ['mlarge', 'larg', 'lare', 'lardge', 'lage', 'lagre'],
#  'dinosaur': ['dinasaur'],
#  'sand': ['sant'],
#  'adjust': ['ajust'],
#  'small': ['smal'],
#  'mammal': ['mamal'],
#  'sank': ['sak',
#   'san',
#   'cank',
#   'sack',
#   'snak',
#   'scank',
#   'sant',
#   'sunk',
#   'sang',
#   'sane',
#   'sanc',
#   'sanck'],
#  'ninetieth': ['nintieth'],
#  'form-room': ['formroom'],
#  'past': ['parst', 'pass'],
#  'pass': ['pas', 'pars'],
#  'canvass': ['canvase', 'canvaus', 'canvas', 'canfass', 'cavass', 'canvess'],
#  'rye': ['rey'],
#  'trick': ['trik'],
#  'semi-skilled': ['semie-skilled', 'seim-skilled'],
#  'clock': ['clok'],
#  'poisonous': ['poisenous'],
#  'scientists': ['scientist'],
#  'nurse': ['nuse'],
#  'method': ['methed'],
#  'full': ['foll', 'ful', 'fill', 'fall'],
#  'mad': ['made', 'nad'],
#  'strata': ['strat'],
#  'hours': ['ours', 'houres'],
#  'experience': ['experinence',
#   'expeirence',
#   'experiance',
#   'exprience',
#   'experence'],
#  'prior': ['prioor',
#   'prier',
#   'pryor',
#   'priror',
#   'prieor',
#   'priar',
#   'piror',
#   'plior',
#   'pior',
#   'priore',
#   'priour'],
#  'hamster': ['hapster'],
#  'social': ['socal'],
#  'murdering': ['mudering'],
#  'followed': ['fellowed'],
#  'sherbet': ['sherbert'],
#  'select': ['celect'],
#  'archived': ['achived'],
#  'attendance': ['attendence'],
#  'britannia': ['britania'],
#  'gorgeous': ['guorgeous',
#   'georgeous',
#   'gorgeus',
#   'gorgious',
#   'gorgeious',
#   'gorgous',
#   'gourgeous',
#   'goregous',
#   'goreous',
#   'gordeous'],
#  'russian': ['russina', 'russion'],
#  'reminiscing': ['reminising'],
#  'door': ['dor', 'boor', 'doar'],
#  'company': ['compeny'],
#  'emission': ['emision'],
#  'cunning': ['conning'],
#  'sizing': ['siezing'],
#  'keeping': ['kepping'],
#  'pleasing': ['plasing', 'pleaseing'],
#  'science': ['sceince', 'sience', 'scienc', 'scienee'],
#  'sent': ['sant', 'send'],
#  'learn': ['larn', 'lean', 'leanr', 'learne', 'lern', 'leran'],
#  'knocked': ['knoked', 'nocked'],
#  'beautiful': ['beaotiful',
#   'beutiful',
#   'beaufiful',
#   'beauiful',
#   'bautiful',
#   'beautifull',
#   'beautful',
#   'beautyful',
#   'beauitful',
#   'beatiful',
#   'baeutiful'],
#  'prompt': ['promt'],
#  'accept': ['axcept', 'acept'],
#  'autumn': ['autunm', 'autum'],
#  'sense': ['senes', 'sence'],
#  'disliked': ['dislike'],
#  'dress': ['dres'],
#  'condemn': ['condem'],
#  'information': ['imformation',
#   'onformation',
#   'infomation',
#   'infromation',
#   'informasion'],
#  'imminent': ['emminent', 'iminent'],
#  'shipped': ['shiped'],
#  'occur': ['occure', 'occurr'],
#  'pogrom': ['progrom'],
#  'creature': ['creture'],
#  'plant': ['plat'],
#  'intended': ['inteaded', 'intened', 'intented'],
#  'countryside': ['country_side'],
#  'variant': ['vairiant'],
#  'plane': ['plaine'],
#  'conveniences': ['conveniances'],
#  'backyard': ['back_yard'],
#  'plank': ['planck'],
#  'refuse': ['refuce', 'refues'],
#  'resemble': ['rezemble', 'ressemble'],
#  'loud': ['load',
#   'loed',
#   'lowd',
#   'lond',
#   'lod',
#   'lold',
#   'lourd',
#   'lould',
#   'lord',
#   'loued',
#   'lound',
#   'loucd',
#   'lood',
#   'laud',
#   'louk',
#   'lour'],
#  'register': ['regester', 'rgister', 'registur'],
#  'rowdy': ['roudy'],
#  'broadcasting': ['bradcasting'],
#  'fundamental': ['vundamental',
#   'fundumental',
#   'fundimental',
#   'fundmental',
#   'fundemental',
#   'fundtmental',
#   'fundanental',
#   'fundamentel',
#   'fundametal',
#   'fundomental',
#   'funamental',
#   'fundamntal'],
#  'replied': ['replyed', 'replid'],
#  'incessantly': ['incessently'],
#  'reminded': ['remined'],
#  'trade': ['trad', 'trede'],
#  'stylus': ['stilus'],
#  'attitude': ['atitude', 'attitide'],
#  'naughty': ['naught'],
#  'smiling': ['smilin'],
#  'its': ['it', 'is', 'it'],
#  'rapidly': ['rapedly'],
#  'team-games': ['team_games'],
#  'triumph': ['triumh',
#   'triaumph',
#   'triumpth',
#   'trumph',
#   'trimph',
#   'triump',
#   'truimph',
#   'trimuph',
#   'triumpt',
#   'tryumph',
#   'triamph',
#   'tirumph'],
#  'bypass': ['bipass'],
#  'travelling': ['traveling'],
#  'colleague': ['colleaque', 'collegue'],
#  'pickerel': ['pickeral'],
#  'abandons': ['abondons'],
#  'severely': ['severly', 'severley'],
#  'propose': ['proppose'],
#  'prefect': ['prefact'],
#  'snowball': ['snow_ball'],
#  'weedy': ['weedey'],
#  'reticent': ['retecent'],
#  'coping': ['copping'],
#  'always': ['alwasy', 'alway', 'alway', 'alwyas', 'allways'],
#  'assemblies': ['assembelies'],
#  'spinning': ['spining', 'skinning', 'sinning', 'spinging', 'spinnig'],
#  'courses': ['course',
#   'cources',
#   'coursecs',
#   'couses',
#   'coureses',
#   'corses',
#   'coures',
#   'cousses'],
#  'aggrieved': ['agrieved'],
#  'found': ['fount', 'fond', 'foudn'],
#  'lantern': ['lanturn'],
#  'reactions': ['reactioos', 'reactioons'],
#  'begged': ['beged'],
#  'upstairs': ['up_stairs', 'upstaires'],
#  'catalogues': ['catalogueds',
#   'catalogue',
#   'catologues',
#   'catalouges',
#   'cattalogues',
#   'catalogus',
#   'cataloges',
#   'catalogue'],
#  'reduce': ['reduse'],
#  'gaoler': ['gaolers'],
#  'peripatetic': ['peripathetic'],
#  'exorbitant': ['exhorbitant'],
#  'investigated': ['investegated'],
#  'operation': ['opperation'],
#  'penicillin': ['penecillin'],
#  'really': ['relly',
#   'raelly',
#   'erally',
#   'realy',
#   'realyl',
#   'rearly',
#   'relaly'],
#  'try': ['tri'],
#  'shepherdess': ['sheperdess'],
#  'psychology': ['psyciology',
#   'phsychology',
#   'pcychology',
#   'psycology',
#   'sychology',
#   'pyschology',
#   'phychology',
#   'pschology'],
#  'missel': ['missle'],
#  'research': ['reasearch', 'researh', 'reserch'],
#  'darling': ['darlin', 'dalling'],
#  'meteorological': ['meterological'],
#  'salute': ['salut', 'sulute'],
#  'seizures': ['siezures'],
#  'belief': ['belife', 'beleif', 'beilief', 'beliefe', 'belif', 'belef'],
#  'rockefeller': ['rockerfeller'],
#  'conditioning': ['conditining'],
#  'murmur': ['murmer'],
#  ...}

# %%
target_typos["corner"]
# Out:
# ['corer', 'coner', 'conner', 'croner']

# %% [markdown]
# I inverted the dictionary so that I could later index by typos:

# %%
typos_target = {tuple(value): key for key, value in target_typos.items()} #lists can't be keys
typos_target
# Out:
# {('rainning', 'raning'): 'raining',
#  ('writtings',): 'writings',
#  ('yello',): 'yellow',
#  ('fours', 'for'): 'four',
#  ('woodes',): 'woods',
#  ('agression',): 'aggression',
#  ('loking', 'locking', 'looing', 'lookin'): 'looking',
#  ('eligble', 'eligable'): 'eligible',
#  ('electrisity', 'electricty', 'electrizity'): 'electricity',
#  ('schold', 'skold'): 'scold',
#  ('adabtable',): 'adaptable',
#  ('canned', 'cained'): 'caned',
#  ('imature',): 'immature',
#  ('swival',): 'swivel',
#  ('apropriation',): 'appropriation',
#  ('furr', 'fer'): 'fur',
#  ('stabed',): 'stabbed',
#  ('desturb',): 'disturb',
#  ('recolections',): 'recollections',
#  ('prise', 'prizer'): 'prize',
#  ('wedensday', 'wedensday'): 'wednesday',
#  ('sucession', 'succesion'): 'succession',
#  ('stright',): 'straight',
#  ('increented',): 'incremented',
#  ('pluse',): 'plus',
#  ('secand', 'secund', 'seconnd', 'seond'): 'second',
#  ('jam_jar',): 'jamjar',
#  ('saled', 'saild'): 'sailed',
#  ('thounder',): 'thunder',
#  ('coking', 'kooking', 'cocking'): 'cooking',
#  ('fosscil',): 'fossil',
#  ('incresing',
#   'increacing',
#   'incressing',
#   'inceasing',
#   'increesing',
#   'increaseng',
#   'encreasing',
#   'incriasing',
#   'increaseing'): 'increasing',
#  ('heroe',): 'hero',
#  ('dael',): 'dahl',
#  ('repoter', 'reportor', 'reproter', 'reoporter'): 'reporter',
#  ('interupting',): 'interrupting',
#  ('hare',
#   'her',
#   'there',
#   'herre',
#   'heere',
#   'hera',
#   'herd',
#   'heer',
#   'hree',
#   'hire'): 'here',
#  ('atom',): 'atoms',
#  ('tape_recorded',): 'tape-recorded',
#  ('shreik',): 'shriek',
#  ('substace',): 'substance',
#  ('elaberate',): 'elaborate',
#  ('climed',): 'climbed',
#  ('reoprts',): 'reports',
#  ('controversey',
#   'controvercy',
#   'contriversy',
#   'countroversy',
#   'contraversy',
#   'constroversy',
#   'controvery',
#   'controvesy',
#   'controversay',
#   'contreversy'): 'controversy',
#  ('eitiology',): 'etiology',
#  ('showing',): 'snowing',
#  ('millitary', 'milatary', 'militery'): 'military',
#  ('cansellation',
#   'cancallation',
#   'canacellation',
#   'cancillation',
#   'cancealation',
#   'cancelation'): 'cancellation',
#  ('criticisim',
#   'criticisam',
#   'critiscism',
#   'critigism',
#   'griticism',
#   'critisism',
#   'criticiam',
#   'criticise',
#   'criticisum',
#   'criticisms',
#   'criticisem',
#   'critizism',
#   'criticsm',
#   'critcism',
#   'criticizm'): 'criticism',
#  ('goldin', 'gloden'): 'golden',
#  ('sinse',): 'sines',
#  ('devide', 'divid'): 'divide',
#  ('substracts',): 'subtracts',
#  ('sweetes',): 'sweetest',
#  ('explainded', 'explanned', 'explaind', 'eplained', 'explaned'): 'explained',
#  ('broght', 'brough', 'brougth', 'bought'): 'brought',
#  ('sizable',): 'sizeable',
#  ('spok',): 'spoke',
#  ('muic',): 'music',
#  ('telagraph',): 'telegraph',
#  ('stricke',): 'strike',
#  ('untill', 'untl'): 'until',
#  ('wholy', 'holly', 'holey'): 'holy',
#  ('sucsessful',
#   'successfull',
#   'sucessful',
#   'successeful',
#   'suxcessful',
#   'suckessful',
#   'successfuly',
#   'succesful',
#   'succeshful',
#   'succsessful',
#   'succsesful'): 'successful',
#  ('hert',): 'hurt',
#  ('glas', 'glars'): 'glass',
#  ('reversable',): 'reversible',
#  ('hol', 'hold'): 'hole',
#  ('hod', 'holed'): 'hold',
#  ('circumstaces',): 'circumstances',
#  ('lockd',): 'locked',
#  ('persue',): 'pursue',
#  ('acomplishment',): 'accomplishment',
#  ('apolegetics',): 'apologetics',
#  ('loker',): 'locker',
#  ('exemple', 'exmaple', 'exsample', 'exmple'): 'example',
#  ('artillary',): 'artillery',
#  ('orginized',): 'organized',
#  ('causion',): 'caution',
#  ('wont',
#   'wants',
#   'mant',
#   'whant',
#   'wand',
#   'watn',
#   'wnat',
#   'went',
#   'wat'): 'want',
#  ('preferrably',): 'preferably',
#  ('hag',): 'hog',
#  ('how', 'ho'): 'hoe',
#  ('travle', 'travell'): 'travel',
#  ('damaged',
#   'damadge',
#   'dameage',
#   'damge',
#   'dammage',
#   'damuge',
#   'damaze',
#   'danage',
#   'damnage'): 'damage',
#  ('machane',
#   'matchine',
#   'macine',
#   'machiene',
#   'mechine',
#   'mashine',
#   'manchine',
#   'macheine'): 'machine',
#  ('hou', 'haw'): 'how',
#  ('thot', 'hoot', 'hote', 'hat'): 'hot',
#  ('hope',): 'hop',
#  ('preferrable',): 'preferable',
#  ('beuty',): 'beauty',
#  ('oulawed',): 'outlawed',
#  ('wrang', 'wronge', 'rong', 'wong', 'worng'): 'wrong',
#  ('short_tempered',): 'short-tempered',
#  ('affective',): 'effective',
#  ('seson',): 'season',
#  ('signitories',): 'signatories',
#  ('bagage',): 'baggage',
#  ('erally',): 'orally',
#  ('keep',): 'keeps',
#  ('win', 'wid'): 'wind',
#  ('misdemenor', 'misdameanor'): 'misdemeanor',
#  ('sunshin',): 'sunshine',
#  ('nazereth',): 'nazareth',
#  ('fur',): 'fir',
#  ('fite', 'fid'): 'fit',
#  ('unforseen',): 'unforeseen',
#  ('heretofor',): 'heretofore',
#  ('seceed',): 'secede',
#  ('survivers',): 'survivors',
#  ('coach_load',): 'coach-load',
#  ('distingishing',): 'distinguishing',
#  ('insubstancial',): 'insubstantial',
#  ('im', 'his', 'ham', 'im', 'hm', 'hem', 'hime', 'hin'): 'him',
#  ('grievious',): 'grievous',
#  ('interupt',): 'interrupt',
#  ('blnk',): 'blink',
#  ('eisenhhower',): 'eisenhower',
#  ('scholer',): 'scholar',
#  ('repreents',): 'represents',
#  ('shoe_lace',): 'shoelace',
#  ('arow',): 'arrow',
#  ('volcanoe',): 'volcano',
#  ('obdirate',): 'obdurate',
#  ('preceeded',): 'preceded',
#  ('financhial',
#   'financal',
#   'finanial',
#   'finantial',
#   'financual',
#   'finacial',
#   'fiancial'): 'financial',
#  ('snaks', 'snake'): 'snakes',
#  ('archtypes',): 'archetypes',
#  ('garmet',): 'garment',
#  ('spiter',): 'spider',
#  ('turnup',): 'turnip',
#  ('preceeds',): 'precedes',
#  ('fort_night',): 'fortnight',
#  ('labroratory',
#   'labortory',
#   'laboatory',
#   'laboretory',
#   'labratory',
#   'labaratory',
#   'lavoratory',
#   'laboritory',
#   'laborotory',
#   'laborbtory',
#   'laberatory'): 'laboratory',
#  ('rings',): 'ring',
#  ('wip',): 'wipe',
#  ('exepting',): 'excepting',
#  ('incourage', 'encorage', 'encourge'): 'encourage',
#  ('engeneer', 'engieneer', 'enginer'): 'engineer',
#  ('foundition', 'fondation'): 'foundation',
#  ('asured',): 'assured',
#  ('thretened',): 'threatened',
#  ('survays',): 'surveys',
#  ('graps',): 'grapes',
#  ('sheat', 'shet'): 'sheet',
#  ('estamate',): 'estimate',
#  ('knitt', 'nit'): 'knit',
#  ('universaly',): 'universally',
#  ('enourmous', 'enormus'): 'enormous',
#  ('aet', 'ete'): 'ate',
#  ('scruf',): 'scruff',
#  ('repremanded',): 'reprimanded',
#  ('dinner_hour',): 'dinner-hour',
#  ('todays', 'todya', 'to_day'): 'today',
#  ('wach', 'wosh'): 'wash',
#  ('instruck',): 'instruct',
#  ('biten',): 'bitten',
#  ('basketball',
#   'basketbale',
#   'basket-ball',
#   'baskeball',
#   'basket-ball',
#   'bascketball',
#   'basket-ball',
#   'baskitball',
#   'basket_ball'): 'basketball',
#  ('survice', 'servise', 'servace'): 'service',
#  ('similarily',): 'similarly',
#  ('enagement',): 'engagement',
#  ('nedded', 'neaded'): 'needed',
#  ('pertubations',): 'perturbations',
#  ('mater',): 'master',
#  ('archetect',): 'architect',
#  ('lisen', 'listern'): 'listen',
#  ('geniva',): 'geneva',
#  ('snoty',): 'snooty',
#  ('predicable',): 'predictable',
#  ('crall',): 'crawl',
#  ('positivly',): 'positively',
#  ('sedereal', 'sideral'): 'sidereal',
#  ('showd',): 'showed',
#  ('appoximations',): 'approximations',
#  ('treee', 'tre', 'three', 'tee'): 'tree',
#  ('omniverous',): 'omnivorous',
#  ('projet', 'progect', 'projent'): 'project',
#  ('pnuemonia',
#   'phneumonia',
#   'pneimonia',
#   'pnumonia',
#   'pneunonia',
#   'pneaumonia',
#   'pnemonia',
#   'pneumnia',
#   'pheumonia',
#   'pheumonia',
#   'pneumunia',
#   'neumonia',
#   'pneomonia',
#   'penumonia'): 'pneumonia',
#  ('idel', 'ide'): 'idle',
#  ('reajusted',): 'readjusted',
#  ('seminery',): 'seminary',
#  ('feling', 'felling', 'fealing'): 'feeling',
#  ('aquisition',): 'acquisition',
#  ('alot',): 'allot',
#  ('to-days', 'today'): 'to-day',
#  ('runer',): 'runner',
#  ('doxen', 'dosen'): 'dozen',
#  ('wholsome', 'holesome'): 'wholesome',
#  ('responsable', 'responcible', 'reponsible'): 'responsible',
#  ('metalic',): 'metallic',
#  ('assymmetric', 'asymetric'): 'asymmetric',
#  ('bankg',): 'bang',
#  ('asorbed',): 'absorbed',
#  ('amsing',): 'amusing',
#  ('doers', 'dors'): 'doors',
#  ('responsably',): 'responsibly',
#  ('johnes',): 'jones',
#  ('commiting', 'comitting'): 'committing',
#  ('shale', 'sall', 'shal'): 'shall',
#  ('objet',): 'object',
#  ('alittle',): 'a_little',
#  ('moth',): 'mouth',
#  ('leter',): 'letter',
#  ('professer', 'profesor', 'proffessor'): 'professor',
#  ('kamp', 'canp'): 'camp',
#  ('consumate',): 'consummate',
#  ('ninteenth',): 'nineteenth',
#  ('screem', 'screm'): 'scream',
#  ('incompleet',): 'incomplete',
#  ('marval',): 'marvel',
#  ('polypropalene',): 'polypropylene',
#  ('bombe', 'bome', 'bomm', 'bom'): 'bomb',
#  ('garge',
#   'gange',
#   'gage',
#   'cauge',
#   'gaige',
#   'guage',
#   'gadge',
#   'gaoge'): 'gauge',
#  ('lesson', 'lessens', 'lesons', 'leasons', 'lessions', 'lesson'): 'lessons',
#  ('buisy', 'bussy', 'bisy'): 'busy',
#  ('then', 'thna', 'tahn', 'that'): 'than',
#  ('buch',): 'bush',
#  ('toched',
#   'tuched',
#   'toughed',
#   'toached',
#   'tougched',
#   'toulched',
#   'toutched'): 'touched',
#  ('rick',): 'rich',
#  ('rise',): 'rice',
#  ('lade', 'ladey', 'ladiy', 'ladys'): 'lady',
#  ('blate', 'plat'): 'plate',
#  ('terrours',): 'terrors',
#  ('formost',): 'foremost',
#  ('poket',): 'pocket',
#  ('foundaries',): 'foundries',
#  ('cusion',): 'cushion',
#  ('alltogether',): 'altogether',
#  ('jagaur',): 'jaguar',
#  ('nicerly', 'nicly', 'micely'): 'nicely',
#  ('border',): 'boarder',
#  ('pacth',): 'patch',
#  ('blow',): 'blew',
#  ('diaster',): 'disaster',
#  ('radiuss', 'radious'): 'radius',
#  ('nocternal',): 'nocturnal',
#  ('hamer',): 'hammer',
#  ('bets',
#   'bast',
#   'dest',
#   'beat',
#   'bist',
#   'besh',
#   'besd',
#   'mest',
#   'beast',
#   'bess',
#   'bes',
#   'bet'): 'best',
#  ('losts', 'lotes', 'lot', 'lost'): 'lots',
#  ('propogates',): 'propagates',
#  ('skore', 'scor'): 'score',
#  ('sied', 'sid'): 'side',
#  ('preseve',): 'preserve',
#  ('neve',
#   'newer',
#   'mever',
#   'neaver',
#   'neiver',
#   'naver',
#   'neven',
#   'nver'): 'never',
#  ('exstend', 'extand'): 'extend',
#  ('nuture',): 'nature',
#  ('rolld',): 'rolled',
#  ('envigorated',): 'invigorated',
#  ('souvenier',): 'souvenir',
#  ('exstent',): 'extent',
#  ('wheel_barrow',): 'wheelbarrow',
#  ('dept', 'deat'): 'debt',
#  ('tyrany',): 'tyranny',
#  ('pattented',): 'patented',
#  ('axcident',
#   'accicent',
#   'acsident',
#   'accsident',
#   'accxident',
#   'ancident',
#   'acident',
#   'accdient',
#   'accedent'): 'accident',
#  ('cherped',): 'chirped',
#  ('ocuntry', 'contry', 'county', 'coontry'): 'country',
#  ('insense',): 'incense',
#  ('levetating',): 'levitating',
#  ('planed',): 'planned',
#  ('huming',): 'humming',
#  ('cardbord',): 'cardboard',
#  ('sorce', 'aource', 'sourse'): 'source',
#  ('unioun',): 'union',
#  ('mush', 'mach'): 'much',
#  ('staydium',): 'stadium',
#  ('priviledge',
#   'privelege',
#   'previlege',
#   'privileged',
#   'privilage',
#   'privilige'): 'privilege',
#  ('fri',): 'fry',
#  ('incompetant',): 'incompetent',
#  ('lif', 'lief', 'live', 'lefe'): 'life',
#  ('spite',): 'spit',
#  ('eastren',): 'eastern',
#  ('wich', 'wis', 'whish'): 'wish',
#  ('left',): 'lift',
#  ('tobogan', 'taboggan', 'tobaggan', 'toboggen'): 'toboggan',
#  ('cild',): 'child',
#  ('worted',): 'worked',
#  ('spen',): 'spin',
#  ('skilfuly', 'skilfuley', 'scilfully', 'skillfully', 'skifully'): 'skilfully',
#  ('comerce',): 'commerce',
#  ('disect',): 'dissect',
#  ('employe', 'imploy'): 'employ',
#  ('visite', 'vist'): 'visit',
#  ('antecipating',
#   'anticepating',
#   'anticpating',
#   'anticipting',
#   'antiscipating',
#   'antisipating',
#   'anticapating',
#   'anticipateing'): 'anticipating',
#  ('volin', 'vioiln'): 'violin',
#  ('oximoron',): 'oxymoron',
#  ('damiged',
#   'dameaged',
#   'damanged',
#   'damagd',
#   'damage',
#   'dammaged',
#   'damged',
#   'damagtd',
#   'damadged',
#   'bamaged',
#   'dameged',
#   'danaged',
#   'danmaged'): 'damaged',
#  ('thigns', 'tings', 'thinks', 'thing', 'thnigs', 'thigs'): 'things',
#  ('diemands',): 'demands',
#  ('splite', 'spilt'): 'split',
#  ('babyies', 'babis', 'badies', 'babbes', 'babes', 'babyes'): 'babies',
#  ('faily', 'farly', 'fairlu'): 'fairly',
#  ('marrid',
#   'marride',
#   'marryied',
#   'marreid',
#   'marriad',
#   'maried',
#   'marred',
#   'marrid'): 'married',
#  ('super',): 'supper',
#  ('preemptory',): 'peremptory',
#  ('resinded',): 'rescinded',
#  ('accademic', 'acedemic'): 'academic',
#  ('subpena',): 'subpoena',
#  ('formmistress',): 'form-mistress',
#  ('corparate',): 'corporate',
#  ('placque',): 'plaque',
#  ('capital',): 'capitol',
#  ('distribut', 'distrubute'): 'distribute',
#  ('sleppy', 'sleepey'): 'sleepy',
#  ('financilly',
#   'finnancially',
#   'financialy',
#   'finincially',
#   'finantially',
#   'financally',
#   'financhally',
#   'finiancially',
#   'finacially',
#   'financeally',
#   'fianancially',
#   'fiancially',
#   'financinally',
#   'financually',
#   'finanically'): 'financially',
#  ('protrayed',): 'portrayed',
#  ('suceeding',): 'succeeding',
#  ('previvous', 'preveous', 'previos', 'previus'): 'previous',
#  ('perchased',): 'purchased',
#  ('oldfashioned',): 'old-fashioned',
#  ('head',
#   'ad',
#   'han',
#   'hab',
#   'hade',
#   'hed',
#   'has',
#   'hat',
#   'haed',
#   'hade'): 'had',
#  ('conneticut',): 'connecticut',
#  ('obediant', 'obedent'): 'obedient',
#  ('innoncent',
#   'innocent',
#   'inocent',
#   'innosent',
#   'innocents',
#   'innacent',
#   'innicent',
#   'ennocent',
#   'innoscent',
#   'inoncent',
#   'innorcent',
#   'inocent'): 'innocent',
#  ('prisin', 'preson', 'prision'): 'prison',
#  ('hase', 'as', 'his', 'hos', 'hase'): 'has',
#  ('hot',): 'hat',
#  ('everytime',): 'every_time',
#  ('confidentally',): 'confidentially',
#  ('dissagreement',): 'disagreement',
#  ('possibly', 'pissible', 'possable', 'posible'): 'possible',
#  ('unequivocaly',): 'unequivocally',
#  ('possably', 'possiply', 'possible'): 'possibly',
#  ('berth',): 'birth',
#  ('misouri',): 'missouri',
#  ('shaddow', 'shodow'): 'shadow',
#  ('uneque',): 'unique',
#  ('occuring',): 'occurring',
#  ('disire',): 'desire',
#  ('psycological',): 'psychological',
#  ('remined',
#   'remond',
#   'remied',
#   'remine',
#   're_mind',
#   'renind',
#   'remaind'): 'remind',
#  ('pavment',): 'pavement',
#  ('staps',): 'steps',
#  ('prolague', 'prologe', 'prolouge'): 'prologue',
#  ('ihaca',): 'ithaca',
#  ('misdameanors', 'misdemenors'): 'misdemeanors',
#  ('sweedish',): 'swedish',
#  ('atterney', 'atorney', 'atturney'): 'attorney',
#  ('rigth',): 'right',
#  ('ald', 'ol', 'lod', 'olf'): 'old',
#  ('creak',): 'creek',
#  ('croud',): 'crowd',
#  ('pople',
#   'pleople',
#   'peiple',
#   'poeple',
#   'peple',
#   'peopl',
#   'peopel',
#   'peolpe',
#   'peaple',
#   'pepole'): 'people',
#  ('croun',): 'crown',
#  ('insistance',): 'insistence',
#  ('harasment',): 'harassment',
#  ('creap',): 'creep',
#  ('enemeies',
#   'enemes',
#   'eniemies',
#   'enamies',
#   'enemyies',
#   'enimies',
#   'enmies'): 'enemies',
#  ('fror',
#   'fur',
#   'far',
#   'fro',
#   'fore',
#   'four',
#   'foir',
#   'forr',
#   'fon',
#   'or',
#   'fo'): 'for',
#  ('bottem', 'botton', 'botom'): 'bottom',
#  ('foxx',): 'fox',
#  ('poluted',): 'polluted',
#  ('polutes',): 'pollutes',
#  ('dinner_hours',): 'dinner-hours',
#  ('loosing', 'loseing', 'lossing'): 'losing',
#  ('memerable',): 'memorable',
#  ('manufactoring', 'manufaturing'): 'manufacturing',
#  ('dollers',): 'dollars',
#  ('anomolous', 'anomalus'): 'anomalous',
#  ('reccollect', 'recolect'): 'recollect',
#  ('dispair',): 'despair',
#  ('slighlty',): 'slightly',
#  ('rased',): 'raised',
#  ('fab',): 'feb',
#  ('honey_moon', 'honymoon'): 'honeymoon',
#  ('well_suited',): 'well-suited',
#  ('sun',): 'son',
#  ('respectible',): 'respectable',
#  ('consumated',): 'consummated',
#  ('sew',): 'sow',
#  ('rap',): 'wrap',
#  ('unabiguous',): 'unambiguous',
#  ('halloe',): 'hallo',
#  ('atitude',
#   'actitude',
#   'altitube',
#   'altituded',
#   'eltitude',
#   'altitud',
#   'alltitude',
#   'altiude',
#   'altilude',
#   'altitued',
#   'altetude'): 'altitude',
#  ('constanly', 'constently'): 'constantly',
#  ('tam',): 'tame',
#  ('with',): 'width',
#  ('boys', 'buy', 'bay'): 'boy',
#  ('overhaed',): 'overhead',
#  ('happiy', 'happe', 'hapy', 'happi'): 'happy',
#  ('ofer',): 'offer',
#  ('cassowarry',): 'cassowary',
#  ('tallents',): 'talents',
#  ('understadable',): 'understandable',
#  ('beach',): 'beech',
#  ('safegaurd',): 'safeguard',
#  ('congratulation',
#   'congraulations',
#   'congrutulations',
#   'congralulations',
#   'congratulatons',
#   'congradulations',
#   'congretulations',
#   'congragulations',
#   'congratilations',
#   'congratualations',
#   'congratalations',
#   'congreatulations',
#   'congractulations',
#   'congratuations'): 'congratulations',
#  ('geneology',): 'genealogy',
#  ('elss', 'els', 'eles', 'esle'): 'else',
#  ('insid', 'in_side'): 'inside',
#  ('unanumous',
#   'unanious',
#   'unaninous',
#   'unnanimous',
#   'unaimous',
#   'unanmous',
#   'unanomous',
#   'unanamous',
#   'unanimos',
#   'unannimous',
#   'unanimus',
#   'unanemous'): 'unanimous',
#  ('parm',): 'palm',
#  ('passanger',): 'passenger',
#  ('latey', 'latter', 'lated'): 'later',
#  ('stedy',): 'steady',
#  ('touranment',
#   'tournment',
#   'tournanent',
#   'tournement',
#   'turnament',
#   'tourament',
#   'atournament',
#   'tourmament',
#   'tournnament',
#   'tournamant',
#   'tornament',
#   'tourniment'): 'tournament',
#  ('prooves',): 'proves',
#  ('exsist',): 'exist',
#  ('dealor',): 'dealer',
#  ('nogotiations',
#   'negoatiations',
#   'negotitations',
#   'neguotiations',
#   'negotiation',
#   'negotitions',
#   'negotiatins',
#   'negatiations',
#   'negoiations',
#   'negotations',
#   'negotciations',
#   'negogiations',
#   'negociations',
#   'negosiations'): 'negotiations',
#  ('flor', 'foor'): 'floor',
#  ('flod',): 'flood',
#  ('superfulous',): 'superfluous',
#  ('rol',): 'roll',
#  ('double_cross',): 'double-cross',
#  ('asterick',): 'asterisk',
#  ('emminent', 'iminent'): 'imminent',
#  ('skale',): 'scale',
#  ('roling',): 'rolling',
#  ('quandry',): 'quandary',
#  ('good_natured',): 'good-natured',
#  ('tiem', 'timne', 'tame', 'tim', 'tine', 'tiome'): 'time',
#  ('puch',): 'push',
#  ('breath',): 'breadth',
#  ('chan', 'choin'): 'chain',
#  ('who_ever',): 'whoever',
#  ('indian',): 'indians',
#  ('intergration',): 'integration',
#  ('skat',): 'skate',
#  ('char', 'chiar'): 'chair',
#  ('mist',): 'midst',
#  ('ukranian',): 'ukrainian',
#  ('philisopher',): 'philosopher',
#  ('vent',): 'vet',
#  ('mashe',): 'mache',
#  ('cheep',): 'cheap',
#  ('choise',): 'choice',
#  ('glomy',): 'gloomy',
#  ('breaktime',): 'break_time',
#  ('exsact',): 'exact',
#  ('minuet', 'minite', 'miniute'): 'minute',
#  ('leasve', 'leav', 'leve'): 'leave',
#  ('settel',): 'settle',
#  ('term', 'teem', 'tem'): 'team',
#  ('loades',): 'loads',
#  ('pervent',): 'prevent',
#  ('spiritul',
#   'spiritural',
#   'speritual',
#   'spirtual',
#   'spirttual',
#   'spirituall',
#   'spritual',
#   'spirital',
#   'spiritial'): 'spiritual',
#  ('occurrance', 'occurence', 'ocurrence'): 'occurrence',
#  ('two_faced',): 'two-faced',
#  ('atic',): 'attic',
#  ('sighn', 'eign', 'sion'): 'sign',
#  ('candle_stick',): 'candlestick',
#  ('essense',): 'essence',
#  ('jeapardy', 'jepardy'): 'jeopardy',
#  ('celebrate',): 'celebrated',
#  ('malt',): 'melt',
#  ('curent',): 'current',
#  ('extraterrestial',): 'extraterrestrial',
#  ('folling',): 'falling',
#  ('bage',): 'badge',
#  ('jurry',): 'jury',
#  ('funerl',): 'funeral',
#  ('understanting', 'undestanding', 'under_standing'): 'understanding',
#  ('adress', 'addres'): 'address',
#  ('a_lone', 'alon'): 'alone',
#  ('a_long', 'aling', 'alog', 'allong'): 'along',
#  ('by', 'me', 'ma', 'may', 'mi', 'miy', 'ny', 'by'): 'my',
#  ('momentus',): 'momentous',
#  ('financers',): 'financiers',
#  ('duste',): 'dusty',
#  ('studed', 'studyed'): 'studied',
#  ('whereever',): 'wherever',
#  ('commongly',): 'commonly',
#  ('aclomplished', 'apcomplished', 'acomplished'): 'accomplished',
#  ('proclomation',): 'proclamation',
#  ('lvoe', 'loev'): 'love',
#  ('raddish',): 'radish',
#  ('preafer',
#   'prefor',
#   'perfer',
#   'pefer',
#   'profer',
#   'prefur',
#   'prefere'): 'prefer',
#  ('blody',): 'bloody',
#  ('marvellous', 'marvalous'): 'marvelous',
#  ('grandpas', 'grandpar'): 'grandpa',
#  ('warking', 'wroking', 'wokring', 'woking'): 'working',
#  ('homsick',): 'homesick',
#  ('positve', 'possitive'): 'positive',
#  ('angery', 'angrey'): 'angry',
#  ('dongle',): 'dangle',
#  ('vigeur',): 'vigour',
#  ('wod',): 'wood',
#  ('apposed',): 'opposed',
#  ('wondring',): 'wondering',
#  ('firms',): 'films',
#  ('loveing',): 'loving',
#  ('marables',): 'marbles',
#  ('affort', 'efford', 'aford'): 'afford',
#  ('appearent',
#   'apprarent',
#   'apparant',
#   'apperent',
#   'apprent',
#   'aparent',
#   'apparient'): 'apparent',
#  ('apendix',): 'appendix',
#  ('everwhere', 'eveywhere'): 'everywhere',
#  ('vertue',
#   'virtu',
#   'virture',
#   'vurtue',
#   'virtues',
#   'virtuge',
#   'virtrue'): 'virtue',
#  ('orrginally',
#   'originnally',
#   'oringinally',
#   'origionally',
#   'originially',
#   'orriginally',
#   'orignially',
#   'originually',
#   'origially',
#   'origianally',
#   'oreginally',
#   'origenally',
#   'origanally',
#   'origonally',
#   'originaly',
#   'oridinally',
#   'orginally',
#   'orignally'): 'originally',
#  ('preted',
#   'prutend',
#   'pretned',
#   'peretend',
#   'protend',
#   'pretennd',
#   'pretent',
#   'pretened',
#   'bretend',
#   'petend',
#   'prertend',
#   'preten',
#   'preatend',
#   'pritend',
#   'predend',
#   'prtend',
#   'phretend',
#   'pertend',
#   'prelend',
#   'prentend'): 'pretend',
#  ('belives', 'beleives'): 'believes',
#  ('priting', 'prenting'): 'printing',
#  ('beleived',): 'believed',
#  ('detatched',): 'detached',
#  ('stock_room',): 'stockroom',
#  ('sacrement',): 'sacrament',
#  ('unequaled',): 'unequalled',
#  ('alowed',): 'allowed',
#  ('stol', 'stold'): 'stole',
#  ('evedently',): 'evidently',
#  ('monitering',): 'monitoring',
#  ('witer',): 'winter',
#  ('devided',): 'divided',
#  ('thinking',): 'thanking',
#  ('elphant',): 'elephant',
#  ('loundry', 'landry'): 'laundry',
#  ('shot', 'spout', 'srot', 'sport', 'spat'): 'spot',
#  ('elbowgrease',): 'elbow-grease',
#  ('rehabilatate',): 'rehabilitate',
#  ('dake', 'dute', 'datr', 'dat', 'dade'): 'date',
#  ('sach', 'shuch', 'suh'): 'such',
#  ('dat', 'dsata'): 'data',
#  ('natureal', 'naturual', 'natrual'): 'natural',
#  ('varities',): 'varieties',
#  ('conscius',
#   'conicious',
#   'consious',
#   'counscious',
#   'consciouse',
#   'consceious',
#   'consicious',
#   'concious'): 'conscious',
#  ('wheel_chair',): 'wheelchair',
#  ('ordinairily',
#   'ordanarily',
#   'oridinarily',
#   'ordinarialy',
#   'ordinarlily',
#   'ordinaryly',
#   'ordinarly',
#   'ordinairly',
#   'ordinarilly',
#   'ordinarrly',
#   'ardinarily',
#   'ordinarlly',
#   'ordinarely',
#   'ordinaraly',
#   'ordainarily',
#   'ordinerily',
#   'ordinaroly',
#   'ordinaryily',
#   'ordonarily'): 'ordinarily',
#  ('soe', 'som', 'sol', 'sow', 'sor'): 'so',
#  ('swolen',): 'swollen',
#  ('defenitions',): 'definitions',
#  ('inocuous',): 'innocuous',
#  ('archeaologist',): 'archaeologist',
#  ('frips',): 'flips',
#  ('yeasr',
#   'eyars',
#   'yeers',
#   'yeras',
#   'yesars',
#   'yars',
#   'yeas',
#   'year',
#   'yers'): 'years',
#  ('coure', 'corse', 'coarse'): 'course',
#  ('experments', 'experiaments'): 'experiments',
#  ('quarelled',): 'quarrelled',
#  ('ommitting', 'omiting'): 'omitting',
#  ('diety',): 'deity',
#  ('tendancy',): 'tendency',
#  ('tor',): 'tore',
#  ('solatary',): 'solitary',
#  ('thum',): 'thumb',
#  ('internationlly',): 'internationally',
#  ('hymn_books',): 'hymn-books',
#  ('tourn', 'tron', 'turn'): 'torn',
#  ('councellor',): 'counsellor',
#  ('atraction',): 'attraction',
#  ('susspicion',
#   'suppicion',
#   'suspecion',
#   'suspition',
#   'supicion',
#   'suspician',
#   'suspicison',
#   'suspiscion',
#   'suspicsion',
#   'supsicion',
#   'suspiction',
#   'suspision'): 'suspicion',
#  ('petetion',): 'petition',
#  ('apon',): 'apron',
#  ('recepients', 'recipiants'): 'recipients',
#  ('civillian',): 'civilian',
#  ('maches',): 'matches',
#  ('basful', 'bashfull'): 'bashful',
#  ('rocords',): 'records',
#  ('compeled',): 'compelled',
#  ('suscribers',): 'subscribers',
#  ('twlight',): 'twilight',
#  ('handywork',): 'handiwork',
#  ('shauted',): 'shouted',
#  ('establashing',
#   'establisheng',
#   'establising',
#   'estableshing',
#   'estaplishing',
#   'esstablishing',
#   'astablishing',
#   'istablishing',
#   'estableishing',
#   'estsablishing',
#   'eastablishing',
#   'exstablishing',
#   'estabishing'): 'establishing',
#  ('spliters',): 'splinters',
#  ('stanlay',): 'stanley',
#  ('quater',): 'quarter',
#  ('turtel',): 'turtle',
#  ('sqare', 'squar'): 'square',
#  ('reciept', 'recipt', 'receit', 'recept'): 'receipt',
#  ('breakthough',): 'breakthrough',
#  ('frame',): 'frames',
#  ('oweing',): 'owing',
#  ('sponser',): 'sponsor',
#  ('canvis',): 'canvas',
#  ('michagan',): 'michigan',
#  ('contasined', 'containd'): 'contained',
#  ('investagation',): 'investigation',
#  ('chemicaly', 'chemcially'): 'chemically',
#  ('desintegrated',): 'disintegrated',
#  ('seige',): 'siege',
#  ('millon',): 'million',
#  ('strived',): 'striven',
#  ('posibility', 'possibilty'): 'possibility',
#  ('quit', 'quiet', 'qutie'): 'quite',
#  ('compicated',): 'complicated',
#  ('grandna',): 'grandma',
#  ('pomems',
#   'poams',
#   'poemas',
#   'poem',
#   'poemes',
#   'peoms',
#   'poims',
#   'pomes',
#   'paems',
#   'powems',
#   'porms'): 'poems',
#  ('remander',): 'remainder',
#  ('trianing', 'traning', 'taining', 'trainning', 'tranning'): 'training',
#  ('modist',): 'modest',
#  ('recompence',): 'recompense',
#  ('neclect', 'neglet'): 'neglect',
#  ('emition',): 'emotion',
#  ('saveing',): 'saving',
#  ('symmatry', 'symetry'): 'symmetry',
#  ('archetecturally',): 'architecturally',
#  ('royl',): 'royal',
#  ('on', 'ome', 'onen', 'ond', 'oen', 'ont'): 'one',
#  ('cloak_room',): 'cloakroom',
#  ('submite', 'sumit'): 'submit',
#  ('vot', 'voet'): 'vote',
#  ('opin', 'opne', 'opean'): 'open',
#  ('effords',): 'affords',
#  ('exagerations',): 'exaggerations',
#  ('citty', 'sity', 'cite'): 'city',
#  ('munday',): 'monday',
#  ('thirdy',): 'thirdly',
#  ('bit',): 'bite',
#  ('stuctured',): 'structured',
#  ('underladder',): 'under_ladder',
#  ('indecate',): 'indicate',
#  ('teather',
#   'teaher',
#   'techer',
#   'tearcher',
#   'teachur',
#   'teasher',
#   'teatcher',
#   'teahcher',
#   'tearcher'): 'teacher',
#  ('deaft',): 'draft',
#  ('structurs',): 'structures',
#  ('ridiculeous',
#   'ridiculois',
#   'ridiculos',
#   'rudiculous',
#   'ridiculious',
#   'ridicilous',
#   'ridiculus',
#   'rideculous',
#   'rediculous'): 'ridiculous',
#  ('sep',): 'sept',
#  ('boyfrend', 'boyfreind', 'boy_friend'): 'boyfriend',
#  ('depresed',): 'depressed',
#  ('foly',
#   'folloy',
#   'folley',
#   'fooly',
#   'foley',
#   'fally',
#   'floly',
#   'foully'): 'folly',
#  ('coots',): 'coats',
#  ('atheneans',): 'athenians',
#  ('unfitt',): 'unfit',
#  ('infront',): 'in_front',
#  ('janiter',): 'janitor',
#  ('propect',): 'prospect',
#  ('addresing', 'adressing'): 'addressing',
#  ('turened',
#   'tured',
#   'tuned',
#   'turrned',
#   'teurned',
#   'turend',
#   'truned',
#   'terned',
#   'turnd'): 'turned',
#  ('aurgument', 'arguement'): 'argument',
#  ('ally',): 'alley',
#  ('sed', 'sade'): 'sad',
#  ('prestigous', 'prestigeous'): 'prestigious',
#  ('raind',): 'rained',
#  ('buired',
#   'burried',
#   'buriel',
#   'bured',
#   'bried',
#   'baried',
#   'buiried',
#   'buryed',
#   'beried',
#   'buryied',
#   'burred'): 'buried',
#  ('sew', 'sow', 'sa', 'san'): 'saw',
#  ('set',): 'sat',
#  ('handi_craft', 'hand_craft'): 'handicraft',
#  ('didnot',): 'did_not',
#  ('not', 'noet'): 'note',
#  ('mantain',): 'maintain',
#  ('tacke', 'tkae', 'taek', 'tak'): 'take',
#  ('distroy',): 'destroy',
#  ('encourage', 'incouraged'): 'encouraged',
#  ('opposit',
#   'oposite',
#   'oppsite',
#   'oppoiste',
#   'opposte',
#   'oppisite',
#   'opposited',
#   'oppasite',
#   'oppossite',
#   'oppesite'): 'opposite',
#  ('sylable',): 'syllable',
#  ('new',): 'knew',
#  ('prented',): 'printed',
#  ('nee',): 'knee',
#  ('personality',): 'personalty',
#  ('pagis',): 'pages',
#  ('adaptibility',): 'adaptability',
#  ('portugese',): 'portuguese',
#  ('lown',): 'lawn',
#  ('avarage',): 'average',
#  ('driv',): 'drive',
#  ('was', 'way'): 'ways',
#  ('slat', 'solt'): 'salt',
#  ('wallking',
#   'waulking',
#   'wolking',
#   'warking',
#   'wakking',
#   'wilking',
#   'waking',
#   'wacking'): 'walking',
#  ('murmers',): 'murmurs',
#  ('surples',
#   'serplus',
#   'surpluse',
#   'surpluss',
#   'surplas',
#   'surplis',
#   'surplut',
#   'sirplus',
#   'surplos',
#   'suplus'): 'surplus',
#  ('penciled',): 'pencilled',
#  ('enfuriate',): 'infuriate',
#  ('merrit',): 'merit',
#  ('peches',): 'peaches',
#  ('scarse',): 'scarce',
#  ('aggresive', 'agressive'): 'aggressive',
#  ('wepons',): 'weapons',
#  ('slo',): 'slow',
#  ('gaurd',): 'guard',
#  ('clock',): 'cloak',
#  ('oging', 'gonig', 'goign', 'gowing', 'gying', 'goning'): 'going',
#  ('hocky',): 'hockey',
#  ('aquipped',
#   'eqquipped',
#   'equipted',
#   'equippted',
#   'equiped',
#   'iquipped',
#   'equpped',
#   'ecquipped'): 'equipped',
#  ('congresional',): 'congressional',
#  ('disput',): 'dispute',
#  ('assitant', 'assisstant'): 'assistant',
#  ('freeing',
#   'frezing',
#   'feezing',
#   'freesing',
#   'freezzing',
#   'freeding',
#   'frezzing',
#   'frezeing'): 'freezing',
#  ('awaitin',): 'awaiting',
#  ('anhour',): 'an_hour',
#  ('resorce', 'resoure', 'resouce', 'recource', 'resourse'): 'resource',
#  ('artest',): 'artist',
#  ('barrow',): 'borrow',
#  ('woried', 'worred'): 'worried',
#  ('preist',): 'priest',
#  ('bee_keepers',): 'bee-keepers',
#  ('bomes', 'boms'): 'bombs',
#  ('lieable', 'lible', 'lyable'): 'liable',
#  ('there', 'wher', 'hwere'): 'where',
#  ('arival', 'arrivial'): 'arrival',
#  ('surgere',): 'surgery',
#  ('jumper',): 'jumped',
#  ('recievers',): 'receivers',
#  ('representative',
#   'represntatives',
#   'represenatives',
#   'repesentatives',
#   'represenatives',
#   'representitives',
#   'represnetatives',
#   'representative',
#   'repersentatives',
#   'represenitatives'): 'representatives',
#  ('dormiatory',
#   'dormotory',
#   'dormatory',
#   'dormitary',
#   'dormitoriy',
#   'doromitory',
#   'dormintory',
#   'dormetory',
#   'domitory',
#   'dorimitory',
#   'dormitlory',
#   'dormiltory',
#   'dorimtory',
#   'doritory'): 'dormitory',
#  ('lilometer',): 'kilometer',
#  ('cantaloube',): 'cantaloupe',
#  ('aberation',): 'aberration',
#  ('supresses',): 'suppresses',
#  ('revealled',): 'revealed',
#  ('concetrate', 'consentrate'): 'concentrate',
#  ('share', 'spere', 'spar'): 'spare',
#  ('inbetween',): 'in_between',
#  ('surpressed', 'supressed'): 'suppressed',
#  ('consentrated',): 'concentrated',
#  ('masn',): 'mans',
#  ('meny', 'may', 'manny', 'mony'): 'many',
#  ('millionnaire',): 'millionaire',
#  ('beseiging',): 'besieging',
#  ('personel', 'persnal'): 'personal',
#  ('consentrates',): 'concentrates',
#  ('expresion',): 'expression',
#  ('can', 'car'): 'ca',
#  ('allowence',): 'allowance',
#  ('yearley',): 'yearly',
#  ('twen',): 'twin',
#  ('comback',): 'comeback',
#  ('gees',): 'geese',
#  ('bouyancy',): 'buoyancy',
#  ('conciders',): 'considers',
#  ('boaut', 'bot'): 'boat',
#  ('careing',): 'caring',
#  ('come',): 'comb',
#  ('unconciousness',): 'unconsciousness',
#  ('strech', 'streach'): 'stretch',
#  ('wast',): 'waist',
#  ('localy',): 'locally',
#  ('vakation', 'vaction'): 'vacation',
#  ('consede',): 'concede',
#  ('breathe', 'breth', 'brath'): 'breath',
#  ('practise', 'practiced'): 'practised',
#  ('wans', 'wnats', 'wantes', 'want'): 'wants',
#  ('unable', 'anable'): 'enable',
#  ('thousend', 'thousnand'): 'thousand',
#  ('fromed', 'formd'): 'formed',
#  ('obsirve',): 'observe',
#  ('extint',): 'extinct',
#  ('caligraphy',): 'calligraphy',
#  ('farmer',): 'former',
#  ('prominance',): 'prominence',
#  ('eassier', 'easyer', 'easer'): 'easier',
#  ('newpaper', 'newspapper', 'news_paper'): 'newspaper',
#  ('situration',): 'situation',
#  ('consituency',): 'constituency',
#  ('all_round',): 'all-round',
#  ('purce', 'perse'): 'purse',
#  ('vandolism',): 'vandalism',
#  ('sicknes',): 'sickness',
#  ('a', 'is', 'it', 'iy', 'if', "'", 'v', 'id', "'", 'n', 'im', 'im'): 'i',
#  ('advertisment',): 'advertisement',
#  ('volcanos',): 'volcanoes',
#  ('vacent',): 'vacant',
#  ('tenacle',): 'tentacle',
#  ('soforth', 'so-forth'): 'so_forth',
#  ('genei',): 'genii',
#  ('grumby',): 'grumpy',
#  ('sumer',): 'summer',
#  ('bieng', 'bieing', 'beeing'): 'being',
#  ('trucculent',): 'truculent',
#  ('exagerating',): 'exaggerating',
#  ('rast',): 'rest',
#  ('school',): 'schools',
#  ('stemer',): 'steamer',
#  ('ommissions',): 'omissions',
#  ('weakly',): 'weekly',
#  ('sixten',): 'sixteen',
#  ('siver', 'sliver'): 'silver',
#  ('instrement', 'instrment', 'instriment'): 'instrument',
#  ('prominantly',): 'prominently',
#  ('spects',): 'aspects',
#  ('arouned',
#   'aroand',
#   'aroud',
#   'arond',
#   'arround',
#   'a_round',
#   'arownd',
#   'round'): 'around',
#  ('nobbly',): 'knobbly',
#  ('art',
#   'darrt',
#   'darte',
#   'durt',
#   'daet',
#   'dard',
#   'tart',
#   'dert',
#   'dirt',
#   'dat',
#   'deart',
#   'drat',
#   'drt',
#   'dort'): 'dart',
#  ('durk',
#   'dork',
#   'drak',
#   'darrk',
#   'darw',
#   'dak',
#   'dare',
#   'dard',
#   'drk',
#   'dank',
#   'darck'): 'dark',
#  ('traffi',
#   'trafic',
#   'traffc',
#   'traffig',
#   'traffice',
#   'traffik',
#   'tarffic'): 'traffic',
#  ('bandge',): 'bandage',
#  ('vaccum',): 'vacuum',
#  ('word', 'would', 'wold', 'wourld'): 'world',
#  ('postel',): 'postal',
#  ('vage',): 'vague',
#  ('satisfacsion',
#   'satisfacion',
#   'satesfaction',
#   'satisfation',
#   'satisfactoin',
#   'satisfacttion',
#   'satishfaction',
#   'satitfaction',
#   'sitisfaction',
#   'satifaction'): 'satisfaction',
#  ('unrepentent',): 'unrepentant',
#  ('nutritents',): 'nutrients',
#  ('souveniers',): 'souvenirs',
#  ('stationery',): 'stationary',
#  ('klap', 'clape'): 'clap',
#  ('autitorium',
#   'additorium',
#   'auditorim',
#   'auditarium',
#   'audetorium',
#   'audotorium',
#   'auditoriam',
#   'auditoruium',
#   'auditorinum',
#   'ouditorium',
#   'auditorum',
#   'auditoium',
#   'auditoryum',
#   'auditoriom',
#   'auditoreum',
#   'audiotorium',
#   'audatorium',
#   'auditoriumn',
#   'auditoriun',
#   'aditorium'): 'auditorium',
#  ('satsfactory', 'satifactory', 'satisfactary'): 'satisfactory',
#  ('superintendant',): 'superintendent',
#  ('learnning', 'learing', 'lerning', 'learining'): 'learning',
#  ('suplementary',): 'supplementary',
#  ('divide', 'devine', 'divene'): 'divine',
#  ('thikns',): 'thinks',
#  ('momories',
#   'memoaries',
#   'mermories',
#   'memordies',
#   'memorries',
#   'memoiries',
#   'memuries',
#   'memmories',
#   'merories',
#   'memoryes',
#   'memouries',
#   'memorie',
#   'memeries'): 'memories',
#  ('non',): 'none',
#  ('endochrine',): 'endocrine',
#  ('refere',): 'refer',
#  ('unsucessfully',): 'unsuccessfully',
#  ('accesing',): 'accessing',
#  ('pwoer',): 'power',
#  ('inspite',): 'in_spite',
#  ('playing_field',): 'playing-field',
#  ('ston',): 'stone',
#  ('packege', 'pakage'): 'package',
#  ('mel', 'mell'): 'meal',
#  ('neighbour',): 'neighbor',
#  ('at', 'akt'): 'act',
#  ('lock',): 'luck',
#  ('buring',): 'burin',
#  ('leged',): 'legged',
#  ('livly', 'livley'): 'lively',
#  ('acumulated',): 'accumulated',
#  ('technecally',): 'technically',
#  ('burgler', 'buglar'): 'burglar',
#  ('hir', 'har', 'he', 'here'): 'her',
#  ('waterrat',): 'water-rat',
#  ('buble',): 'bubble',
#  ('yerned',): 'yearned',
#  ('eleimination', 'elimiation'): 'elimination',
#  ('impedence',): 'impedance',
#  ('mise',): 'mice',
#  ('iwth',
#   'wihth',
#   'whith',
#   'wite',
#   'wiht',
#   'wirth',
#   'wtih',
#   'withe',
#   'weth',
#   'wit',
#   'witht'): 'with',
#  ('buyin', 'bying'): 'buying',
#  ('hansome',): 'handsome',
#  ('the', 'thy', 'thay', 'thea', 'tehy', 'the', 'ther'): 'they',
#  ('ruch',): 'rush',
#  ('diry', 'durty'): 'dirty',
#  ('dispencing',): 'dispensing',
#  ('agre',): 'agree',
#  ('detailled',): 'detailed',
#  ('gon', 'gome', 'gonne'): 'gone',
#  ('gratuitious',): 'gratuitous',
#  ('exausted', 'exhasted'): 'exhausted',
#  ('certian', 'ceratin', 'curtain', 'sertain', 'cirtain'): 'certain',
#  ('cinderrella',): 'cinderella',
#  ('ham', 'an'): 'am',
#  ('a', 'and', 'un', 'am', 'on'): 'an',
#  ('ass', 'a', 'asw', 'was', 'is', 'at', 'aas', 'has', 'als'): 'as',
#  ('a', 'ast', 'al', 'an', 'as', 'att'): 'at',
#  ('creek',): 'creak',
#  ('crem',): 'cream',
#  ('idealy',): 'ideally',
#  ('graguate',): 'graduate',
#  ('watston',): 'watson',
#  ('unparalleld',
#   'unparallelled',
#   'unparlleled',
#   'unparralleled',
#   'unparalelled',
#   'unparelleled'): 'unparalleled',
#  ('pupy',): 'puppy',
#  ('contamporaries',): 'contemporaries',
#  ('congress', 'cnongress', 'cangress', 'congres', 'comgress'): 'congress',
#  ('spermatozoan',): 'spermatozoon',
#  ('tigar',): 'tiger',
#  ('mast', 'marsk'): 'mask',
#  ('haveing', 'hvaing'): 'having',
#  ('impossibilty',): 'impossibility',
#  ('mas',): 'mass',
#  ('origional', 'orginal', 'origanal'): 'original',
#  ('canda',): 'canada',
#  ('gingam',): 'gingham',
#  ('consdider', 'concider', 'consiter'): 'consider',
#  ('cased',): 'caused',
#  ('bewere',): 'beware',
#  ('ceasar',): 'caesar',
#  ('cases',): 'causes',
#  ('hanting',): 'hunting',
#  ('ro', 'tow', 'too', 'th', 'ot'): 'to',
#  ('tall',): 'tail',
#  ('scrach',): 'scratch',
#  ('smil',): 'smile',
#  ('cace',): 'case',
#  ('appoitment', 'apointment'): 'appointment',
#  ('defit',
#   'deblit',
#   'debet',
#   'debat',
#   'devit',
#   'debot',
#   'depit',
#   'debt',
#   'dibit',
#   'debut',
#   'debtit',
#   'depbit',
#   'debite'): 'debit',
#  ('batton',): 'baton',
#  ('puzzle',): 'puzzles',
#  ('managable',): 'manageable',
#  ('condidtion',): 'condition',
#  ('accumpanying',
#   'accompaning',
#   'occompanying',
#   'accompaying',
#   'accomponying',
#   'acompanying',
#   'accompnying',
#   'accompagnying',
#   'accompanning'): 'accompanying',
#  ('marvelous',): 'marvellous',
#  ('tobe',): 'toby',
#  ('dogged',
#   'lodged',
#   'dodjed',
#   'doged',
#   'dodge',
#   'dodeged',
#   'dooged',
#   'dogded',
#   'dodger'): 'dodged',
#  ('mlarge', 'larg', 'lare', 'lardge', 'lage', 'lagre'): 'large',
#  ('dinasaur',): 'dinosaur',
#  ('sant',): 'sand',
#  ('ajust',): 'adjust',
#  ('smal',): 'small',
#  ('mamal',): 'mammal',
#  ('sak',
#   'san',
#   'cank',
#   'sack',
#   'snak',
#   'scank',
#   'sant',
#   'sunk',
#   'sang',
#   'sane',
#   'sanc',
#   'sanck'): 'sank',
#  ('nintieth',): 'ninetieth',
#  ('formroom',): 'form-room',
#  ('parst', 'pass'): 'past',
#  ('pas', 'pars'): 'pass',
#  ('canvase', 'canvaus', 'canvas', 'canfass', 'cavass', 'canvess'): 'canvass',
#  ('rey',): 'rye',
#  ('trik',): 'trick',
#  ('semie-skilled', 'seim-skilled'): 'semi-skilled',
#  ('clok',): 'clock',
#  ('poisenous',): 'poisonous',
#  ('scientist',): 'scientists',
#  ('nuse',): 'nurse',
#  ('methed',): 'method',
#  ('foll', 'ful', 'fill', 'fall'): 'full',
#  ('made', 'nad'): 'mad',
#  ('strat',): 'strata',
#  ('ours', 'houres'): 'hours',
#  ('experinence',
#   'expeirence',
#   'experiance',
#   'exprience',
#   'experence'): 'experience',
#  ('prioor',
#   'prier',
#   'pryor',
#   'priror',
#   'prieor',
#   'priar',
#   'piror',
#   'plior',
#   'pior',
#   'priore',
#   'priour'): 'prior',
#  ('hapster',): 'hamster',
#  ('socal',): 'social',
#  ('mudering',): 'murdering',
#  ('fellowed',): 'followed',
#  ('sherbert',): 'sherbet',
#  ('celect',): 'select',
#  ('achived',): 'archived',
#  ('attendence',): 'attendance',
#  ('britania',): 'britannia',
#  ('guorgeous',
#   'georgeous',
#   'gorgeus',
#   'gorgious',
#   'gorgeious',
#   'gorgous',
#   'gourgeous',
#   'goregous',
#   'goreous',
#   'gordeous'): 'gorgeous',
#  ('russina', 'russion'): 'russian',
#  ('reminising',): 'reminiscing',
#  ('dor', 'boor', 'doar'): 'door',
#  ('compeny',): 'company',
#  ('emision',): 'emission',
#  ('conning',): 'cunning',
#  ('siezing',): 'seizing',
#  ('kepping',): 'keeping',
#  ('plasing', 'pleaseing'): 'pleasing',
#  ('sceince', 'sience', 'scienc', 'scienee'): 'science',
#  ('sant', 'send'): 'sent',
#  ('larn', 'lean', 'leanr', 'learne', 'lern', 'leran'): 'learn',
#  ('knoked', 'nocked'): 'knocked',
#  ('beaotiful',
#   'beutiful',
#   'beaufiful',
#   'beauiful',
#   'bautiful',
#   'beautifull',
#   'beautful',
#   'beautyful',
#   'beauitful',
#   'beatiful',
#   'baeutiful'): 'beautiful',
#  ('promt',): 'prompt',
#  ('axcept', 'acept'): 'accept',
#  ('autunm', 'autum'): 'autumn',
#  ('senes', 'sence'): 'sense',
#  ('dislike',): 'disliked',
#  ('dres',): 'dress',
#  ('condem',): 'condemn',
#  ('imformation',
#   'onformation',
#   'infomation',
#   'infromation',
#   'informasion'): 'information',
#  ('shiped',): 'shipped',
#  ('occure', 'occurr'): 'occur',
#  ('progrom',): 'program',
#  ('creture',): 'creature',
#  ('plat',): 'plant',
#  ('inteaded', 'intened', 'intented'): 'intended',
#  ('country_side',): 'countryside',
#  ('vairiant',): 'variant',
#  ('plaine',): 'plane',
#  ('conveniances',): 'conveniences',
#  ('back_yard',): 'backyard',
#  ('planck',): 'plank',
#  ('refuce', 'refues'): 'refuse',
#  ('rezemble', 'ressemble'): 'resemble',
#  ('load',
#   'loed',
#   'lowd',
#   'lond',
#   'lod',
#   'lold',
#   'lourd',
#   'lould',
#   'lord',
#   'loued',
#   'lound',
#   'loucd',
#   'lood',
#   'laud',
#   'louk',
#   'lour'): 'loud',
#  ('regester', 'rgister', 'registur'): 'register',
#  ('roudy',): 'rowdy',
#  ('bradcasting',): 'broadcasting',
#  ('vundamental',
#   'fundumental',
#   'fundimental',
#   'fundmental',
#   'fundemental',
#   'fundtmental',
#   'fundanental',
#   'fundamentel',
#   'fundametal',
#   'fundomental',
#   'funamental',
#   'fundamntal'): 'fundamental',
#  ('replyed', 'replid'): 'replied',
#  ('incessently',): 'incessantly',
#  ('remined',): 'reminded',
#  ('trad', 'trede'): 'trade',
#  ('stilus',): 'stylus',
#  ('atitude', 'attitide'): 'attitude',
#  ('naught',): 'naughty',
#  ('smilin',): 'smiling',
#  ('it', 'is', 'it'): 'its',
#  ('rapedly',): 'rapidly',
#  ('team_games',): 'team-games',
#  ('triumh',
#   'triaumph',
#   'triumpth',
#   'trumph',
#   'trimph',
#   'triump',
#   'truimph',
#   'trimuph',
#   'triumpt',
#   'tryumph',
#   'triamph',
#   'tirumph'): 'triumph',
#  ('bipass',): 'bypass',
#  ('traveling',): 'travelling',
#  ('colleaque', 'collegue'): 'colleague',
#  ('pickeral',): 'pickerel',
#  ('abondons',): 'abandons',
#  ('severly', 'severley'): 'severely',
#  ('proppose',): 'propose',
#  ('prefact',): 'prefect',
#  ('snow_ball',): 'snowball',
#  ('weedey',): 'weedy',
#  ('retecent',): 'reticent',
#  ('copping',): 'coping',
#  ('alwasy', 'alway', 'alway', 'alwyas', 'allways'): 'always',
#  ('assembelies',): 'assemblies',
#  ('spining', 'skinning', 'sinning', 'spinging', 'spinnig'): 'spinning',
#  ('course',
#   'cources',
#   'coursecs',
#   'couses',
#   'coureses',
#   'corses',
#   'coures',
#   'cousses'): 'courses',
#  ('agrieved',): 'aggrieved',
#  ('fount', 'fond', 'foudn'): 'found',
#  ('lanturn',): 'lantern',
#  ('reactioos', 'reactioons'): 'reactions',
#  ('beged',): 'begged',
#  ('up_stairs', 'upstaires'): 'upstairs',
#  ('catalogueds',
#   'catalogue',
#   'catologues',
#   'catalouges',
#   'cattalogues',
#   'catalogus',
#   'cataloges',
#   'catalogue'): 'catalogues',
#  ('reduse',): 'reduce',
#  ('gaolers',): 'gaoler',
#  ('peripathetic',): 'peripatetic',
#  ('exhorbitant',): 'exorbitant',
#  ('investegated',): 'investigated',
#  ('opperation',): 'operation',
#  ('penecillin',): 'penicillin',
#  ('relly',
#   'raelly',
#   'erally',
#   'realy',
#   'realyl',
#   'rearly',
#   'relaly'): 'really',
#  ('tri',): 'try',
#  ('sheperdess',): 'shepherdess',
#  ('psyciology',
#   'phsychology',
#   'pcychology',
#   'psycology',
#   'sychology',
#   'pyschology',
#   'phychology',
#   'pschology'): 'psychology',
#  ('missle',): 'missel',
#  ('reasearch', 'researh', 'reserch'): 'research',
#  ('darlin', 'dalling'): 'darling',
#  ('meterological',): 'meteorological',
#  ('salut', 'sulute'): 'salute',
#  ('siezures',): 'seizures',
#  ('belife', 'beleif', 'beilief', 'beliefe', 'belif', 'belef'): 'belief',
#  ('rockerfeller',): 'rockefeller',
#  ('conditining',): 'conditioning',
#  ('murmer',): 'murmur',
#  ('imagin', 'immagine'): 'imagine',
#  ...}

# %%
typos_target[('corer', 'coner', 'conner', 'croner')]
# Out:
# 'corner'

# %% [markdown]
# ### Step 4.2: Making error-specific corpora
#
# Here, I am separating the typo dictionary in **4 error-type-specific dictionaries**, so that I can later compute the conditional probabilities for characters being deleted/inserted/transposed/substituted. Here, it becomes clear why I needed the inverted dictionary: so that for each typo I could retrieve the target (by indexing).

# %%
deletion_ = {}
insertion_ = {}
transposition_ = {}
substitution_ = {}
for typos in typos_target.keys(): #for each list of typos for each word
    for typo in typos: #for each typo for the target
        if typo in deletion(typos_target[typos]): #if the typo in a list of deletions for the target
            if typos_target[typos] not in deletion_: #if the target is not in the deletion dict
                 deletion_[typos_target[typos]] = [typo] #populate dict
            else:
                deletion_[typos_target[typos]].append(typo) #append if target is already in dict
        if typo in insertion(typos_target[typos]):
            if typos_target[typos] not in insertion_:
                insertion_[typos_target[typos]] = [typo]
            else:
                insertion_[typos_target[typos]].append(typo)
        if typo in transposition(typos_target[typos]):
            if typos_target[typos] not in transposition_:
                transposition_[typos_target[typos]] = [typo]
            else:
                transposition_[typos_target[typos]].append(typo)
        if typo in substitution(typos_target[typos]):
            if typos_target[typos] not in substitution_:
                substitution_[typos_target[typos]] = [typo]
            else:
                substitution_[typos_target[typos]].append(typo)

# %%
deletion_
# Out:
# {'raining': ['raning'],
#  'yellow': ['yello'],
#  'four': ['for'],
#  'aggression': ['agression'],
#  'looking': ['loking', 'looing', 'lookin'],
#  'eligible': ['eligble'],
#  'electricity': ['electricty'],
#  'immature': ['imature'],
#  'appropriation': ['apropriation'],
#  'stabbed': ['stabed'],
#  'recollections': ['recolections'],
#  'succession': ['sucession', 'succesion'],
#  'straight': ['stright'],
#  'incremented': ['increented'],
#  'second': ['seond'],
#  'sailed': ['saled', 'saild'],
#  'cooking': ['coking'],
#  'increasing': ['incresing', 'inceasing'],
#  'reporter': ['repoter'],
#  'interrupting': ['interupting'],
#  'here': ['her'],
#  'atoms': ['atom'],
#  'substance': ['substace'],
#  'climbed': ['climed'],
#  'controversy': ['controvery', 'controvesy'],
#  'cancellation': ['cancelation'],
#  'criticism': ['criticsm', 'critcism'],
#  'divide': ['divid'],
#  'sweetest': ['sweetes'],
#  'explained': ['explaind', 'eplained', 'explaned'],
#  'brought': ['broght', 'brough', 'bought'],
#  'sizeable': ['sizable'],
#  'spoke': ['spok'],
#  'music': ['muic'],
#  'until': ['untl'],
#  'successful': ['sucessful', 'succesful'],
#  'glass': ['glas'],
#  'hole': ['hol'],
#  'hold': ['hod'],
#  'circumstances': ['circumstaces'],
#  'locked': ['lockd'],
#  'accomplishment': ['acomplishment'],
#  'locker': ['loker'],
#  'example': ['exmple'],
#  'want': ['wat'],
#  'hoe': ['ho'],
#  'damage': ['damge'],
#  'machine': ['macine'],
#  'beauty': ['beuty'],
#  'outlawed': ['oulawed'],
#  'wrong': ['rong', 'wong'],
#  'season': ['seson'],
#  'baggage': ['bagage'],
#  'keeps': ['keep'],
#  'wind': ['win', 'wid'],
#  'misdemeanor': ['misdemenor'],
#  'sunshine': ['sunshin'],
#  'unforeseen': ['unforseen'],
#  'heretofore': ['heretofor'],
#  'distinguishing': ['distingishing'],
#  'him': ['im', 'im', 'hm'],
#  'interrupt': ['interupt'],
#  'blink': ['blnk'],
#  'represents': ['repreents'],
#  'arrow': ['arow'],
#  'financial': ['financal', 'finanial', 'finacial', 'fiancial'],
#  'snakes': ['snaks', 'snake'],
#  'archetypes': ['archtypes'],
#  'garment': ['garmet'],
#  'laboratory': ['labortory', 'laboatory', 'labratory'],
#  'wipe': ['wip'],
#  'excepting': ['exepting'],
#  'encourage': ['encorage', 'encourge'],
#  'engineer': ['enginer'],
#  'foundation': ['fondation'],
#  'assured': ['asured'],
#  'threatened': ['thretened'],
#  'grapes': ['graps'],
#  'sheet': ['shet'],
#  'knit': ['nit'],
#  'universally': ['universaly'],
#  'enormous': ['enormus'],
#  'scruff': ['scruf'],
#  'bitten': ['biten'],
#  'basketball': ['baskeball'],
#  'engagement': ['enagement'],
#  'perturbations': ['pertubations'],
#  'master': ['mater'],
#  'listen': ['lisen'],
#  'snooty': ['snoty'],
#  'predictable': ['predicable'],
#  'positively': ['positivly'],
#  'sidereal': ['sideral'],
#  'showed': ['showd'],
#  'approximations': ['appoximations'],
#  'tree': ['tre', 'tee'],
#  'project': ['projet'],
#  'pneumonia': ['pnumonia', 'pnemonia', 'pneumnia', 'neumonia'],
#  'idle': ['ide'],
#  'readjusted': ['reajusted'],
#  'feeling': ['feling'],
#  'acquisition': ['aquisition'],
#  'allot': ['alot'],
#  'to-day': ['today'],
#  'runner': ['runer'],
#  'wholesome': ['wholsome', 'holesome'],
#  'responsible': ['reponsible'],
#  'metallic': ['metalic'],
#  'asymmetric': ['asymetric'],
#  'absorbed': ['asorbed'],
#  'amusing': ['amsing'],
#  'doors': ['dors'],
#  'committing': ['commiting', 'comitting'],
#  'shall': ['sall', 'shal'],
#  'object': ['objet'],
#  'a_little': ['alittle'],
#  'mouth': ['moth'],
#  'letter': ['leter'],
#  'professor': ['profesor'],
#  'consummate': ['consumate'],
#  'nineteenth': ['ninteenth'],
#  'scream': ['screm'],
#  'bomb': ['bom'],
#  'gauge': ['gage'],
#  'lessons': ['lesson', 'lesons', 'lesson'],
#  'touched': ['toched', 'tuched'],
#  'plate': ['plat'],
#  'foremost': ['formost'],
#  'pocket': ['poket'],
#  'cushion': ['cusion'],
#  'nicely': ['nicly'],
#  'boarder': ['border'],
#  'disaster': ['diaster'],
#  'hammer': ['hamer'],
#  'best': ['bes', 'bet'],
#  'lots': ['lot'],
#  'score': ['scor'],
#  'side': ['sid'],
#  'preserve': ['preseve'],
#  'never': ['neve', 'nver'],
#  'rolled': ['rolld'],
#  'tyranny': ['tyrany'],
#  'accident': ['acident'],
#  'country': ['contry', 'county'],
#  'planned': ['planed'],
#  'humming': ['huming'],
#  'cardboard': ['cardbord'],
#  'source': ['sorce'],
#  'life': ['lif'],
#  'wish': ['wis'],
#  'toboggan': ['tobogan'],
#  'child': ['cild'],
#  'skilfully': ['skilfuly', 'skifully'],
#  'commerce': ['comerce'],
#  'dissect': ['disect'],
#  'visit': ['vist'],
#  'anticipating': ['anticpating', 'anticipting'],
#  'violin': ['volin'],
#  'damaged': ['damagd', 'damage', 'damged'],
#  'things': ['tings', 'thing', 'thigs'],
#  'babies': ['babis', 'babes'],
#  'fairly': ['faily', 'farly'],
#  'married': ['marrid', 'maried', 'marred', 'marrid'],
#  'supper': ['super'],
#  'rescinded': ['resinded'],
#  'subpoena': ['subpena'],
#  'form-mistress': ['formmistress'],
#  'distribute': ['distribut'],
#  'financially': ['financilly',
#   'financialy',
#   'financally',
#   'finacially',
#   'fiancially'],
#  'succeeding': ['suceeding'],
#  'previous': ['previos', 'previus'],
#  'old-fashioned': ['oldfashioned'],
#  'had': ['ad'],
#  'connecticut': ['conneticut'],
#  'obedient': ['obedent'],
#  'innocent': ['inocent', 'inocent'],
#  'has': ['as'],
#  'every_time': ['everytime'],
#  'confidentially': ['confidentally'],
#  'possible': ['posible'],
#  'unequivocally': ['unequivocaly'],
#  'missouri': ['misouri'],
#  'occurring': ['occuring'],
#  'psychological': ['psycological'],
#  'pavement': ['pavment'],
#  'prologue': ['prologe'],
#  'ithaca': ['ihaca'],
#  'misdemeanors': ['misdemenors'],
#  'attorney': ['atorney'],
#  'old': ['ol'],
#  'people': ['pople', 'peple', 'peopl'],
#  'harassment': ['harasment'],
#  'enemies': ['enemes', 'enmies'],
#  'for': ['or', 'fo'],
#  'bottom': ['botom'],
#  'polluted': ['poluted'],
#  'pollutes': ['polutes'],
#  'manufacturing': ['manufaturing'],
#  'anomalous': ['anomalus'],
#  'recollect': ['recolect'],
#  'raised': ['rased'],
#  'honeymoon': ['honymoon'],
#  'consummated': ['consumated'],
#  'wrap': ['rap'],
#  'unambiguous': ['unabiguous'],
#  'altitude': ['atitude', 'altitud', 'altiude'],
#  'constantly': ['constanly'],
#  'tame': ['tam'],
#  'width': ['with'],
#  'happy': ['hapy'],
#  'offer': ['ofer'],
#  'understandable': ['understadable'],
#  'congratulations': ['congratulation',
#   'congraulations',
#   'congratulatons',
#   'congratuations'],
#  'else': ['els'],
#  'inside': ['insid'],
#  'unanimous': ['unanious', 'unaimous', 'unanmous', 'unanimos', 'unanimus'],
#  'steady': ['stedy'],
#  'tournament': ['tournment', 'turnament', 'tourament', 'tornament'],
#  'negotiations': ['negotiation',
#   'negotitions',
#   'negotiatins',
#   'negoiations',
#   'negotations'],
#  'floor': ['flor', 'foor'],
#  'flood': ['flod'],
#  'roll': ['rol'],
#  'imminent': ['iminent'],
#  'rolling': ['roling'],
#  'quandary': ['quandry'],
#  'time': ['tim'],
#  'breadth': ['breath'],
#  'chain': ['chan'],
#  'indians': ['indian'],
#  'skate': ['skat'],
#  'chair': ['char'],
#  'midst': ['mist'],
#  'ukrainian': ['ukranian'],
#  'gloomy': ['glomy'],
#  'break_time': ['breaktime'],
#  'leave': ['leav', 'leve'],
#  'team': ['tem'],
#  'spiritual': ['spiritul', 'spirtual', 'spritual', 'spirital'],
#  'occurrence': ['occurence', 'ocurrence'],
#  'attic': ['atic'],
#  'jeopardy': ['jepardy'],
#  'celebrated': ['celebrate'],
#  'current': ['curent'],
#  'extraterrestrial': ['extraterrestial'],
#  'badge': ['bage'],
#  'funeral': ['funerl'],
#  'understanding': ['undestanding'],
#  'address': ['adress', 'addres'],
#  'alone': ['alon'],
#  'along': ['alog'],
#  'momentous': ['momentus'],
#  'financiers': ['financers'],
#  'studied': ['studed'],
#  'accomplished': ['acomplished'],
#  'prefer': ['pefer'],
#  'bloody': ['blody'],
#  'working': ['woking'],
#  'homesick': ['homsick'],
#  'positive': ['positve'],
#  'wood': ['wod'],
#  'wondering': ['wondring'],
#  'afford': ['aford'],
#  'apparent': ['apprent', 'aparent'],
#  'appendix': ['apendix'],
#  'everywhere': ['everwhere', 'eveywhere'],
#  'virtue': ['virtu'],
#  'originally': ['origially', 'originaly', 'orginally', 'orignally'],
#  'pretend': ['preted', 'petend', 'preten', 'prtend'],
#  'believes': ['belives'],
#  'printing': ['priting'],
#  'unequalled': ['unequaled'],
#  'allowed': ['alowed'],
#  'stole': ['stol'],
#  'winter': ['witer'],
#  'elephant': ['elphant'],
#  'laundry': ['landry'],
#  'elbow-grease': ['elbowgrease'],
#  'date': ['dat'],
#  'such': ['suh'],
#  'data': ['dat'],
#  'varieties': ['varities'],
#  'conscious': ['conscius', 'consious', 'concious'],
#  'ordinarily': ['ordinarly'],
#  'swollen': ['swolen'],
#  'innocuous': ['inocuous'],
#  'years': ['yars', 'yeas', 'year', 'yers'],
#  'course': ['coure', 'corse'],
#  'experiments': ['experments'],
#  'quarrelled': ['quarelled'],
#  'omitting': ['omiting'],
#  'tore': ['tor'],
#  'thumb': ['thum'],
#  'internationally': ['internationlly'],
#  'attraction': ['atraction'],
#  'suspicion': ['supicion'],
#  'apron': ['apon'],
#  'matches': ['maches'],
#  'bashful': ['basful'],
#  'compelled': ['compeled'],
#  'subscribers': ['suscribers'],
#  'twilight': ['twlight'],
#  'establishing': ['establising', 'estabishing'],
#  'splinters': ['spliters'],
#  'quarter': ['quater'],
#  'square': ['sqare', 'squar'],
#  'receipt': ['recipt', 'receit', 'recept'],
#  'breakthrough': ['breakthough'],
#  'frames': ['frame'],
#  'contained': ['containd'],
#  'chemically': ['chemicaly'],
#  'million': ['millon'],
#  'possibility': ['posibility', 'possibilty'],
#  'quite': ['quit'],
#  'complicated': ['compicated'],
#  'poems': ['poem'],
#  'remainder': ['remander'],
#  'training': ['traning', 'taining'],
#  'neglect': ['neglet'],
#  'symmetry': ['symetry'],
#  'royal': ['royl'],
#  'one': ['on'],
#  'submit': ['sumit'],
#  'vote': ['vot'],
#  'exaggerations': ['exagerations'],
#  'thirdly': ['thirdy'],
#  'bite': ['bit'],
#  'structured': ['stuctured'],
#  'under_ladder': ['underladder'],
#  'teacher': ['teaher', 'techer'],
#  'structures': ['structurs'],
#  'ridiculous': ['ridiculos', 'ridiculus'],
#  'sept': ['sep'],
#  'boyfriend': ['boyfrend'],
#  'depressed': ['depresed'],
#  'folly': ['foly'],
#  'in_front': ['infront'],
#  'prospect': ['propect'],
#  'addressing': ['addresing', 'adressing'],
#  'turned': ['tured', 'tuned', 'turnd'],
#  'alley': ['ally'],
#  'prestigious': ['prestigous'],
#  'rained': ['raind'],
#  'buried': ['bured', 'bried'],
#  'saw': ['sa'],
#  'did_not': ['didnot'],
#  'note': ['not'],
#  'maintain': ['mantain'],
#  'take': ['tak'],
#  'encouraged': ['encourage'],
#  'opposite': ['opposit', 'oposite', 'oppsite', 'opposte'],
#  'syllable': ['sylable'],
#  'knew': ['new'],
#  'knee': ['nee'],
#  'portuguese': ['portugese'],
#  'drive': ['driv'],
#  'ways': ['was', 'way'],
#  'walking': ['waking'],
#  'surplus': ['suplus'],
#  'pencilled': ['penciled'],
#  'peaches': ['peches'],
#  'aggressive': ['aggresive', 'agressive'],
#  'weapons': ['wepons'],
#  'slow': ['slo'],
#  'hockey': ['hocky'],
#  'equipped': ['equiped', 'equpped'],
#  'congressional': ['congresional'],
#  'dispute': ['disput'],
#  'assistant': ['assitant'],
#  'freezing': ['freeing', 'frezing', 'feezing'],
#  'awaiting': ['awaitin'],
#  'an_hour': ['anhour'],
#  'resource': ['resorce', 'resoure', 'resouce'],
#  'worried': ['woried', 'worred'],
#  'bombs': ['boms'],
#  'liable': ['lible'],
#  'where': ['wher'],
#  'arrival': ['arival'],
#  'representatives': ['representative',
#   'represntatives',
#   'represenatives',
#   'repesentatives',
#   'represenatives',
#   'representative'],
#  'dormitory': ['domitory', 'doritory'],
#  'aberration': ['aberation'],
#  'suppresses': ['supresses'],
#  'concentrate': ['concetrate'],
#  'spare': ['spar'],
#  'in_between': ['inbetween'],
#  'suppressed': ['supressed'],
#  'many': ['may'],
#  'personal': ['persnal'],
#  'expression': ['expresion'],
#  'comeback': ['comback'],
#  'geese': ['gees'],
#  'boat': ['bot'],
#  'unconsciousness': ['unconciousness'],
#  'stretch': ['strech'],
#  'waist': ['wast'],
#  'locally': ['localy'],
#  'vacation': ['vaction'],
#  'breath': ['breth', 'brath'],
#  'practised': ['practise'],
#  'wants': ['wans', 'want'],
#  'formed': ['formd'],
#  'extinct': ['extint'],
#  'calligraphy': ['caligraphy'],
#  'easier': ['easer'],
#  'newspaper': ['newpaper'],
#  'constituency': ['consituency'],
#  'sickness': ['sicknes'],
#  'advertisement': ['advertisment'],
#  'volcanoes': ['volcanos'],
#  'tentacle': ['tenacle'],
#  'so_forth': ['soforth'],
#  'summer': ['sumer'],
#  'exaggerating': ['exagerating'],
#  'schools': ['school'],
#  'steamer': ['stemer'],
#  'sixteen': ['sixten'],
#  'silver': ['siver'],
#  'instrument': ['instrment'],
#  'aspects': ['spects'],
#  'around': ['aroud', 'arond', 'round'],
#  'knobbly': ['nobbly'],
#  'dart': ['art', 'dat', 'drt'],
#  'dark': ['dak', 'drk'],
#  'traffic': ['traffi', 'trafic', 'traffc'],
#  'bandage': ['bandge'],
#  'world': ['word', 'wold'],
#  'vague': ['vage'],
#  'satisfaction': ['satisfacion', 'satisfation', 'satifaction'],
#  'auditorium': ['auditorim', 'auditorum', 'auditoium', 'aditorium'],
#  'satisfactory': ['satsfactory', 'satifactory'],
#  'learning': ['learing', 'lerning'],
#  'supplementary': ['suplementary'],
#  'memories': ['memorie'],
#  'none': ['non'],
#  'unsuccessfully': ['unsucessfully'],
#  'accessing': ['accesing'],
#  'in_spite': ['inspite'],
#  'stone': ['ston'],
#  'package': ['pakage'],
#  'meal': ['mel'],
#  'act': ['at'],
#  'legged': ['leged'],
#  'lively': ['livly'],
#  'accumulated': ['acumulated'],
#  'burglar': ['buglar'],
#  'her': ['he'],
#  'water-rat': ['waterrat'],
#  'bubble': ['buble'],
#  'yearned': ['yerned'],
#  'elimination': ['elimiation'],
#  'with': ['wit'],
#  'buying': ['buyin', 'bying'],
#  'handsome': ['hansome'],
#  'they': ['the', 'thy', 'the'],
#  'dirty': ['diry'],
#  'agree': ['agre'],
#  'gone': ['gon'],
#  'exhausted': ['exausted', 'exhasted'],
#  'an': ['a'],
#  'as': ['a'],
#  'at': ['a'],
#  'cream': ['crem'],
#  'ideally': ['idealy'],
#  'unparalleled': ['unparalleld', 'unparlleled'],
#  'puppy': ['pupy'],
#  'congress': ['congres'],
#  'impossibility': ['impossibilty'],
#  'mass': ['mas'],
#  'original': ['orginal'],
#  'canada': ['canda'],
#  'gingham': ['gingam'],
#  'caused': ['cased'],
#  'causes': ['cases'],
#  'scratch': ['scrach'],
#  'smile': ['smil'],
#  'appointment': ['appoitment', 'apointment'],
#  'debit': ['debt'],
#  'puzzles': ['puzzle'],
#  'manageable': ['managable'],
#  'accompanying': ['accompaning', 'accompaying', 'acompanying', 'accompnying'],
#  'marvellous': ['marvelous'],
#  'dodged': ['doged', 'dodge'],
#  'large': ['larg', 'lare', 'lage'],
#  'adjust': ['ajust'],
#  'small': ['smal'],
#  'mammal': ['mamal'],
#  'sank': ['sak', 'san'],
#  'ninetieth': ['nintieth'],
#  'form-room': ['formroom'],
#  'pass': ['pas'],
#  'canvass': ['canvas', 'cavass'],
#  'trick': ['trik'],
#  'clock': ['clok'],
#  'scientists': ['scientist'],
#  'nurse': ['nuse'],
#  'full': ['ful'],
#  'strata': ['strat'],
#  'hours': ['ours'],
#  'experience': ['exprience', 'experence'],
#  'prior': ['pior'],
#  'social': ['socal'],
#  'murdering': ['mudering'],
#  'archived': ['achived'],
#  'britannia': ['britania'],
#  'gorgeous': ['gorgeus', 'gorgous', 'goreous'],
#  'reminiscing': ['reminising'],
#  'door': ['dor'],
#  'emission': ['emision'],
#  'pleasing': ['plasing'],
#  'science': ['sience', 'scienc'],
#  'learn': ['larn', 'lean', 'lern'],
#  'knocked': ['knoked', 'nocked'],
#  'beautiful': ['beutiful', 'beauiful', 'bautiful', 'beautful', 'beatiful'],
#  'prompt': ['promt'],
#  'accept': ['acept'],
#  'autumn': ['autum'],
#  'disliked': ['dislike'],
#  'dress': ['dres'],
#  'condemn': ['condem'],
#  'information': ['infomation'],
#  'shipped': ['shiped'],
#  'creature': ['creture'],
#  'plant': ['plat'],
#  'intended': ['intened'],
#  'loud': ['lod'],
#  'register': ['rgister'],
#  'broadcasting': ['bradcasting'],
#  'fundamental': ['fundmental', 'fundametal', 'funamental', 'fundamntal'],
#  'replied': ['replid'],
#  'reminded': ['remined'],
#  'trade': ['trad'],
#  'attitude': ['atitude'],
#  'naughty': ['naught'],
#  'smiling': ['smilin'],
#  'its': ['it', 'is', 'it'],
#  'triumph': ['triumh', 'trumph', 'trimph', 'triump'],
#  'travelling': ['traveling'],
#  'colleague': ['collegue'],
#  'severely': ['severly'],
#  'always': ['alway', 'alway'],
#  'spinning': ['spining', 'sinning', 'spinnig'],
#  'courses': ['course', 'couses', 'corses', 'coures'],
#  'aggrieved': ['agrieved'],
#  'found': ['fond'],
#  'begged': ['beged'],
#  'catalogues': ['catalogue', 'catalogus', 'cataloges', 'catalogue'],
#  'really': ['relly', 'realy'],
#  'shepherdess': ['sheperdess'],
#  'psychology': ['psycology', 'sychology', 'pschology'],
#  'research': ['researh', 'reserch'],
#  'darling': ['darlin'],
#  'meteorological': ['meterological'],
#  'salute': ['salut'],
#  'belief': ['belif', 'belef'],
#  'conditioning': ['conditining'],
#  'imagine': ['imagin'],
#  'reversing': ['revrsing'],
#  'number': ['numbe', 'nuber'],
#  'slipper': ['sliper'],
#  'ironing': ['irning'],
#  'guest': ['gest'],
#  'introduction': ['introdution'],
#  'essays': ['essay'],
#  'molecular': ['molcular', 'moleclar'],
#  'relationship': ['reltionship'],
#  'immediate': ['imediate'],
#  'appreciation': ['apreciation'],
#  'stairs': ['sairs', 'stars'],
#  'determines': ['detrmines'],
#  'annihilation': ['anihilation'],
#  'determined': ['determine',
#   'determind',
#   'detemined',
#   'deterined',
#   'determied'],
#  'marriage': ['marrige', 'marrage'],
#  'beneficial': ['benficial', 'benefical'],
#  'constitutional': ['consitutional', 'constituional'],
#  'it': ['i', 'i'],
#  'guarding': ['garding'],
#  'also': ['aso', 'als'],
#  'play': ['pay'],
#  'unused': ['unsed'],
#  'plan': ['lan', 'pan', 'pla'],
#  'oyster': ['oster'],
#  'on_to': ['onto'],
#  'sometimes': ['sometmes', 'somtimes', 'sometime'],
#  'administrate': ['adminstrate'],
#  'amusements': ['amusments'],
#  'dragged': ['draged'],
#  'accommodations': ['accomodations'],
#  'aghast': ['agast'],
#  'session': ['sesion'],
#  'bookstand': ['booksand'],
#  'failed': ['faild', 'faled'],
#  'cassette': ['casette'],
#  'quizzes': ['quizes'],
#  'sunny': ['suny'],
#  'adheres': ['adhere'],
#  'closely': ['closly'],
#  'frightening': ['frighteing'],
#  'delving': ['delvin'],
#  'enemy': ['enmy'],
#  'kill': ['kil'],
#  'approaching': ['approching', 'aproaching', 'appoaching'],
#  'sows': ['sow'],
#  'set': ['et'],
#  'see': ['se'],
#  'sees': ['see'],
#  'currently': ['currenly'],
#  'coffee': ['cofee', 'coffe'],
#  'interface': ['inerface'],
#  'barley': ['barly'],
#  'bachelor': ['bachlor'],
#  'connection': ['connecton', 'conection'],
#  'approve': ['aprove'],
#  'load': ['lod'],
#  'community': ['communty', 'comunity'],
#  'hollow': ['holow'],
#  'pronominal': ['pronomial'],
#  'church': ['curch'],
#  'indefinite': ['indefinit', 'indefinte'],
#  'belt': ['bet'],
#  'assassinates': ['assasinates'],
#  'hitting': ['hiting'],
#  'initiation': ['intiation', 'initation'],
#  'assassinated': ['assasinated'],
#  'resting': ['resing'],
#  'champion': ['campion'],
#  'fire': ['fir', 'fre'],
#  'what': ['wat'],
#  'awake': ['awak'],
#  'judicial': ['judical'],
#  'reliable': ['relible', 'relable'],
#  'empirical': ['empirial'],
#  'technical': ['technial', 'techical', 'tecnical'],
#  'error': ['erro', 'eror'],
#  'miss': ['mis', 'mis'],
#  'scheduled': ['scheuled', 'sceduled', 'schedule'],
#  'pound': ['pond'],
#  'funny': ['funy'],
#  'knitting': ['nitting'],
#  'canned': ['caned'],
#  'advertisements': ['advertisments'],
#  'recommended': ['recommened', 'recommeded', 'recomended'],
#  'eager': ['eger'],
#  'parents': ['parent'],
#  'location': ['loction'],
#  'crying': ['cring'],
#  'input': ['inut'],
#  'surprised': ['suprised'],
#  'oh': ['o'],
#  'couple': ['cuple'],
#  'high-ranking': ['highranking'],
#  'innumerable': ['inumerable'],
#  'projects': ['projets'],
#  'individuals': ['indviduals'],
#  'pertaining': ['pertaning'],
#  'irresistibly': ['iresistibly'],
#  'spring': ['sping'],
#  'sight': ['sigt'],
#  'curious': ['curous'],
#  'irresistible': ['iresistible'],
#  'transactions': ['trasactions'],
#  'religion': ['religon'],
#  'even_though': ['eventhough'],
#  'be': ['b'],
#  'crooks': ['croks'],
#  'analysing': ['aalysing'],
#  'anything': ['anythin', 'anyting'],
#  'exaggerated': ['exagerated'],
#  'hatchet': ['hachet'],
#  'round_about': ['roundabout'],
#  'hatched': ['hached'],
#  'exaggerates': ['exagerates'],
#  'at_all': ['atall'],
#  'a-quiver': ['aquiver'],
#  'appropriate': ['apprpriate',
#   'approriate',
#   'appropiate',
#   'apropriate',
#   'appropriae',
#   'appropriat',
#   'appopriate',
#   'approprate'],
#  'controversies': ['controveries'],
#  'primarily': ['pimarily'],
#  'specifically': ['specfically', 'specificaly', 'specifcally', 'specificlly'],
#  'occupy': ['ocupy'],
#  'elsewhere': ['elswhere'],
#  'inches': ['inchs'],
#  'line': ['lin'],
#  'considerable': ['considerble'],
#  'peeped': ['peped'],
#  'verification': ['verfication'],
#  'spectroscopy': ['spectoscopy'],
#  'continuously': ['continously'],
#  'outside': ['outsid'],
#  'questionnaire': ['questionnair',
#   'questionnare',
#   'questionaire',
#   'quesionnaire'],
#  'occasional': ['ocasional'],
#  'scrub': ['scub'],
#  'ago': ['go'],
#  'algorithm': ['algoritm'],
#  'age': ['ag'],
#  'walked': ['waked'],
#  'came': ['cam'],
#  'enrolled': ['enroled'],
#  'hello': ['helo'],
#  'essay': ['essa', 'esay'],
#  'saying': ['saing'],
#  'results': ['result'],
#  'gossip': ['gosip'],
#  'seemed': ['semed'],
#  'concerned': ['concened'],
#  'young': ['yong', 'youg', 'yung'],
#  'send': ['sed', 'snd'],
#  'carelessly': ['carlessly'],
#  'resources': ['resorces'],
#  'jurisdiction': ['juridiction'],
#  'susceptible': ['suseptible'],
#  'transmission': ['ransmission'],
#  'marry': ['mary'],
#  'anxious': ['axious', 'anious', 'anxous', 'anxios'],
#  'pledge': ['plege'],
#  'incidentally': ['incidenally', 'incidentaly', 'incidentlly'],
#  'apparatus': ['appratus', 'aparatus', 'appartus'],
#  'indian': ['indan'],
#  'polluting': ['poluting'],
#  'proffer': ['profer'],
#  'scenery': ['senery'],
#  'gathered': ['gatherd'],
#  'poverty': ['povety'],
#  'fifteen': ['fiften'],
#  'great': ['geat', 'gret', 'grat'],
#  'fetch': ['fech'],
#  'resulting': ['reulting'],
#  'opinion': ['opinon'],
#  'makes': ['maks'],
#  'innocence': ['inocence'],
#  'standing': ['staning', 'sanding', 'stading'],
#  'druggies': ['drugies'],
#  'next': ['nex'],
#  'eleven': ['elven'],
#  'doubt': ['dout', 'doub'],
#  'pencil': ['pecil'],
#  'occurred': ['ocurred', 'occured'],
#  'carrying': ['carring'],
#  'labelled': ['labeled'],
#  'rubbish': ['rubish'],
#  'gladly': ['glady'],
#  'animals': ['animal'],
#  'this': ['ths'],
#  'challenge': ['chalenge'],
#  'thin': ['tin'],
#  'drill': ['dril'],
#  'scatter': ['scater'],
#  'police': ['polic'],
#  'rode': ['rod'],
#  'pieces': ['piece'],
#  'sleep': ['slep'],
#  'christmas': ['cristmas', 'chrismas'],
#  'hydrophilic': ['hydropilic'],
#  'intelligent': ['inteligent'],
#  'tied': ['tid', 'tie'],
#  'preferring': ['prefering'],
#  'cabbage': ['cabbge'],
#  'autograph': ['autgraph'],
#  'tomato': ['tomto', 'tmato'],
#  'realized': ['relized'],
#  'counter': ['conter'],
#  'reminders': ['remnders'],
#  'acquitted': ['acquited', 'aquitted'],
#  'allow': ['alow'],
#  'doubtful': ['doutful'],
#  'chosen': ['chose'],
#  'meantime': ['mentime'],
#  'thieves': ['theves', 'thives'],
#  'instruments': ['instrument',
#   'intruments',
#   'instrumets',
#   'instrments',
#   'instuments'],
#  'earn': ['ern'],
#  'kiss': ['kis'],
#  'cage': ['cag'],
#  'orphaned': ['orphaed'],
#  'presidential': ['presidental'],
#  'sufficiently': ['suficiently', 'sufficently'],
#  'delightful': ['delighful'],
#  'accompanied': ['acompanied'],
#  'beneath': ['beneth', 'benath', 'beneat'],
#  'glasses': ['glases'],
#  'operator': ['opertor', 'oprator'],
#  'books': ['book'],
#  'allophones': ['allopones'],
#  'surely': ['surly'],
#  'embarrass': ['embarass', 'embarras'],
#  'steering': ['stering'],
#  'spill': ['spil'],
#  'could': ['coud'],
#  'length': ['lenth', 'lengh'],
#  'pudding': ['puding'],
#  'scare': ['scar'],
#  'diagrammatically': ['diagramatically'],
#  'owned': ['oned'],
#  'straining': ['strainin'],
#  'occurrences': ['occurences'],
#  'owner': ['oner'],
#  'reference': ['refernce', 'rference'],
#  'system': ['sysem'],
#  'sergeant': ['sergant'],
#  'travelled': ['traveled'],
#  'efficiently': ['efficently'],
#  'accompany': ['acompany'],
#  'stars': ['sars'],
#  'shorts': ['short'],
#  'extraordinarily': ['extrordinarily'],
#  'steep': ['step'],
#  'steer': ['ster'],
#  'have_to': ['haveto'],
#  'a_few': ['afew'],
#  'clearly': ['cleary'],
#  'viewed': ['vewed', 'viwed'],
#  'documents': ['document', 'document', 'documens'],
#  'connived': ['conived'],
#  'studying': ['studing'],
#  'tyrannical': ['tyranical'],
#  'courtesy': ['courtsy', 'curtesy'],
#  'amongst': ['amonst'],
#  'so-called': ['socalled'],
#  'hypocrite': ['hypocrit'],
#  'thanksgiving': ['thankgiving'],
#  'you': ['yo'],
#  'unscramble': ['unscamble'],
#  'painting': ['panting'],
#  'atmosphere': ['atmospher'],
#  'assassinations': ['assasinations'],
#  'vacancy': ['vacany'],
#  'bring': ['bing'],
#  'infants': ['infant'],
#  'principal': ['pricipal'],
#  'meanwhile': ['meanwile'],
#  'should': ['sould', 'shoud', 'shold', 'shuld'],
#  'terminal': ['termial'],
#  'planted': ['planed', 'plated'],
#  'molecules': ['moleculs'],
#  'hoop': ['hop'],
#  'meant': ['ment'],
#  'means': ['mens'],
#  'familiar': ['familar', 'familia'],
#  'lucky': ['luky'],
#  'committees': ['committes', 'committee', 'comittees', 'commitees'],
#  'contemptible': ['contempible'],
#  'victuals': ['vituals'],
#  'stuff': ['stuf'],
#  'strengthened': ['strenghened'],
#  'temporarily': ['temporaily', 'temporarly', 'temorarily'],
#  'allusion': ['alusion'],
#  'frame': ['fram', 'fame'],
#  'edition': ['ediion'],
#  'carboniferous': ['carbonferous'],
#  'nuclear': ['nucler'],
#  'megabytes': ['egabytes'],
#  'interchangeably': ['interchangably'],
#  'figures': ['figurs'],
#  'puff': ['puf'],
#  'christ': ['crist'],
#  'conclude': ['conclud'],
#  'drank': ['drak'],
#  'feather': ['fether'],
#  'waste': ['wate'],
#  'neighbour': ['neigbour', 'neighbor'],
#  'run_away': ['runaway'],
#  'ripe': ['rip'],
#  'excessively': ['exessively'],
#  'adultery': ['adultry'],
#  'tattoo': ['tatoo'],
#  'painstaking': ['paintaking'],
#  'digging': ['diggin', 'diging'],
#  'ball': ['bal'],
#  'drink': ['drik'],
#  'nationally': ['nationaly'],
#  'forecasts': ['forcasts'],
#  'at_least': ['atleast'],
#  'acknowledgement': ['acknowledement',
#   'acknowedgement',
#   'acknowledgment',
#   'aknowledgement',
#   'acknoledgement',
#   'acknowlegement'],
#  'colour': ['color', 'colur'],
#  'command': ['comand'],
#  'administered': ['admiistered'],
#  'diphtheria': ['diptheria'],
#  'drawing': ['drawin'],
#  'snake': ['snak'],
#  'least': ['lest'],
#  'realize': ['relize'],
#  'arrest': ['arest'],
#  'crack': ['crak'],
#  'increased': ['increase'],
#  'government': ['goverment'],
#  'five': ['fiv'],
#  'incessant': ['incesant'],
#  'descendant': ['decendant'],
#  'onion': ['onin'],
#  'chairs': ['chirs'],
#  'garage': ['grage', 'garge'],
#  'become': ['becom', 'beome'],
#  'need_not': ['neednot'],
#  'poor': ['por'],
#  'foreseeable': ['forseeable'],
#  'thief': ['thif'],
#  'immortal': ['imortal'],
#  'choosing': ['chosing'],
#  'asynchronously': ['asyncronously'],
#  'recognition': ['recogition', 'reconition'],
#  'literally': ['literaly', 'litrally'],
#  'avoid': ['avid', 'avod'],
#  'shone': ['shon'],
#  'her_a': ['hera'],
#  'blowing': ['bloing'],
#  'schedule': ['schedul', 'shedule', 'scedule', 'scheule'],
#  'peas': ['pes'],
#  'pressure': ['presure'],
#  'stage': ['stag'],
#  'gained': ['ganed'],
#  'sister': ['siter'],
#  'drumming': ['druming'],
#  'nose': ['nos'],
#  'larvae': ['lavae'],
#  'disapproval': ['disaproval'],
#  'specimens': ['specimns', 'specimen', 'specimen'],
#  'naturally': ['naturaly', 'natually'],
#  'function': ['fuction'],
#  'construction': ['constuction'],
#  'count': ['cont'],
#  'bicycle': ['bicyle', 'bicyle', 'biycle'],
#  'society': ['socity', 'sciety'],
#  'official': ['offical'],
#  'smooth': ['smoth'],
#  'excitement': ['excitment'],
#  'problem': ['proble', 'problm'],
#  'profession': ['profesion'],
#  'nurses': ['nurse'],
#  'recognize': ['recogize', 'reconize'],
#  'dissemination': ['disemination'],
#  'variety': ['varity'],
#  'lately': ['latly'],
#  'details': ['detals'],
#  'suppress': ['supress'],
#  'incorrigible': ['incorigible'],
#  'february': ['febuary', 'febuary', 'febuary'],
#  'repeat': ['repet'],
#  'annual': ['anual'],
#  'searched': ['serched', 'seached', 'searhed'],
#  'commandos': ['comandos'],
#  'neighbours': ['neigbours'],
#  'worth': ['woth'],
#  'wreath': ['reath'],
#  'women': ['wmen', 'wome'],
#  'lecture': ['lectur'],
#  'abhorrence': ['abhorence'],
#  'progression': ['progresion'],
#  'exaggerate': ['exagerate'],
#  'announced': ['anounced'],
#  'galas': ['gala'],
#  'sabbath': ['sabath'],
#  'horn': ['hon'],
#  'preacher': ['precher'],
#  'colloquialism': ['colloquilism'],
#  'specs': ['spec'],
#  'phoned': ['phone'],
#  'above': ['abve'],
#  'churches': ['churchs'],
#  'officially': ['offically', 'officialy'],
#  'told': ['tod'],
#  'tuesday': ['tusday'],
#  'smoke': ['smok'],
#  'archaeological': ['archeological'],
#  'lorry': ['lory'],
#  'reign': ['rein'],
#  'indent': ['ident'],
#  'eclipse': ['ecipse'],
#  'mammalian': ['mamalian'],
#  'ere': ['ee', 'er', 'er'],
#  'elbow': ['elbo'],
#  'ascetic': ['asetic'],
#  'pollute': ['polute'],
#  'tornadoes': ['tornados'],
#  'provide': ['provid'],
#  'interview': ['intervew'],
#  'disappoint': ['disapoint'],
#  'ladder': ['lader'],
#  'after': ['aftr'],
#  'lay': ['la'],
#  'nipped': ['niped'],
#  'appreciate': ['appreciat', 'apreciate'],
#  'encompassing': ['encompasing'],
#  'green': ['gren'],
#  'ambulance': ['amblance'],
#  'order': ['oder'],
#  'woollen': ['woolen'],
#  'office': ['ofice'],
#  'plastics': ['plastis'],
#  'satisfies': ['satifies'],
#  'somewhere': ['somewere', 'somewher'],
#  'recreational': ['recrational'],
#  'eventually': ['evetually',
#   'evenually',
#   'eventully',
#   'eventally',
#   'eventualy'],
#  'them': ['the'],
#  'safe': ['saf'],
#  'break': ['brak'],
#  'roommate': ['roomate'],
#  'bread': ['bred', 'brad'],
#  'rocks': ['roks'],
#  'reasonable': ['resonable'],
#  'schemes': ['schems', 'scemes'],
#  'flock': ['flok'],
#  'diesel': ['disel'],
#  'medicine': ['medicin'],
#  'campaigns': ['campains'],
#  ...}

# %%
insertion_
# Out:
# {'raining': ['rainning'],
#  'writings': ['writtings'],
#  'four': ['fours'],
#  'woods': ['woodes'],
#  'scold': ['schold'],
#  'caned': ['canned', 'cained'],
#  'fur': ['furr'],
#  'prize': ['prizer'],
#  'plus': ['pluse'],
#  'second': ['seconnd'],
#  'thunder': ['thounder'],
#  'fossil': ['fosscil'],
#  'increasing': ['increaseing'],
#  'hero': ['heroe'],
#  'reporter': ['reoporter'],
#  'here': ['there', 'herre', 'heere'],
#  'controversy': ['controversey',
#   'countroversy',
#   'constroversy',
#   'controversay'],
#  'etiology': ['eitiology'],
#  'military': ['millitary'],
#  'cancellation': ['canacellation'],
#  'criticism': ['criticisim',
#   'criticisam',
#   'critiscism',
#   'criticisum',
#   'criticisms',
#   'criticisem'],
#  'subtracts': ['substracts'],
#  'explained': ['explainded'],
#  'strike': ['stricke'],
#  'until': ['untill'],
#  'holy': ['wholy', 'holly', 'holey'],
#  'successful': ['successfull', 'successeful', 'successfuly', 'succsessful'],
#  'hold': ['holed'],
#  'example': ['exsample'],
#  'want': ['wants', 'whant'],
#  'preferably': ['preferrably'],
#  'travel': ['travell'],
#  'damage': ['damaged', 'damadge', 'dameage', 'dammage', 'damnage'],
#  'machine': ['matchine', 'machiene', 'manchine', 'macheine'],
#  'hot': ['thot', 'hoot', 'hote'],
#  'hop': ['hope'],
#  'preferable': ['preferrable'],
#  'wrong': ['wronge'],
#  'fit': ['fite'],
#  'him': ['hime'],
#  'grievous': ['grievious'],
#  'eisenhower': ['eisenhhower'],
#  'volcano': ['volcanoe'],
#  'preceded': ['preceeded'],
#  'financial': ['financhial'],
#  'laboratory': ['labroratory'],
#  'ring': ['rings'],
#  'engineer': ['engieneer'],
#  'knit': ['knitt'],
#  'enormous': ['enourmous'],
#  'today': ['todays'],
#  'basketball': ['bascketball'],
#  'similarly': ['similarily'],
#  'listen': ['listern'],
#  'tree': ['treee', 'three'],
#  'pneumonia': ['phneumonia', 'pneaumonia'],
#  'to-day': ['to-days'],
#  'asymmetric': ['assymmetric'],
#  'bang': ['bankg'],
#  'jones': ['johnes'],
#  'professor': ['proffessor'],
#  'bomb': ['bombe'],
#  'lessons': ['lessions'],
#  'busy': ['buisy', 'bussy'],
#  'touched': ['tougched', 'toulched', 'toutched'],
#  'lady': ['ladey', 'ladiy', 'ladys'],
#  'terrors': ['terrours'],
#  'foundries': ['foundaries'],
#  'altogether': ['alltogether'],
#  'nicely': ['nicerly'],
#  'radius': ['radiuss', 'radious'],
#  'best': ['beast'],
#  'lots': ['losts', 'lotes'],
#  'never': ['neaver', 'neiver'],
#  'extend': ['exstend'],
#  'souvenir': ['souvenier'],
#  'extent': ['exstent'],
#  'patented': ['pattented'],
#  'accident': ['accsident', 'accxident'],
#  'union': ['unioun'],
#  'stadium': ['staydium'],
#  'privilege': ['priviledge', 'privileged'],
#  'spit': ['spite'],
#  'wish': ['whish'],
#  'skilfully': ['skillfully'],
#  'employ': ['employe'],
#  'visit': ['visite'],
#  'anticipating': ['antiscipating', 'anticipateing'],
#  'damaged': ['dameaged', 'damanged', 'dammaged', 'damadged', 'danmaged'],
#  'demands': ['diemands'],
#  'split': ['splite'],
#  'babies': ['babyies'],
#  'married': ['marryied'],
#  'academic': ['accademic'],
#  'plaque': ['placque'],
#  'sleepy': ['sleepey'],
#  'financially': ['finnancially',
#   'finiancially',
#   'fianancially',
#   'financinally'],
#  'previous': ['previvous'],
#  'had': ['head', 'hade', 'haed', 'hade'],
#  'innocent': ['innoncent', 'innocents', 'innoscent', 'innorcent'],
#  'prison': ['prision'],
#  'has': ['hase', 'hase'],
#  'disagreement': ['dissagreement'],
#  'shadow': ['shaddow'],
#  'remind': ['remined', 'remaind'],
#  'swedish': ['sweedish'],
#  'people': ['pleople'],
#  'enemies': ['enemeies', 'eniemies', 'enemyies'],
#  'for': ['fror', 'fore', 'four', 'foir', 'forr'],
#  'fox': ['foxx'],
#  'losing': ['loosing', 'loseing', 'lossing'],
#  'recollect': ['reccollect'],
#  'hallo': ['halloe'],
#  'altitude': ['altituded', 'alltitude'],
#  'boy': ['boys'],
#  'happy': ['happiy'],
#  'cassowary': ['cassowarry'],
#  'talents': ['tallents'],
#  'congratulations': ['congratualations',
#   'congreatulations',
#   'congractulations'],
#  'unanimous': ['unnanimous', 'unannimous'],
#  'later': ['latter'],
#  'tournament': ['atournament', 'tournnament'],
#  'proves': ['prooves'],
#  'exist': ['exsist'],
#  'negotiations': ['negoatiations',
#   'negotitations',
#   'neguotiations',
#   'negotciations'],
#  'time': ['timne', 'tiome'],
#  'integration': ['intergration'],
#  'vet': ['vent'],
#  'exact': ['exsact'],
#  'minute': ['miniute'],
#  'leave': ['leasve'],
#  'loads': ['loades'],
#  'spiritual': ['spiritural', 'spirituall'],
#  'sign': ['sighn'],
#  'jury': ['jurry'],
#  'along': ['allong'],
#  'my': ['may', 'miy'],
#  'wherever': ['whereever'],
#  'commonly': ['commongly'],
#  'radish': ['raddish'],
#  'prefer': ['preafer', 'prefere'],
#  'marvelous': ['marvellous'],
#  'grandpa': ['grandpas', 'grandpar'],
#  'positive': ['possitive'],
#  'angry': ['angery', 'angrey'],
#  'loving': ['loveing'],
#  'marbles': ['marables'],
#  'apparent': ['appearent', 'apprarent', 'apparient'],
#  'virtue': ['virture', 'virtues', 'virtuge', 'virtrue'],
#  'originally': ['originnally',
#   'oringinally',
#   'origionally',
#   'originially',
#   'orriginally',
#   'originually',
#   'origianally'],
#  'pretend': ['peretend',
#   'pretennd',
#   'pretened',
#   'prertend',
#   'preatend',
#   'phretend',
#   'prentend'],
#  'detached': ['detatched'],
#  'spot': ['spout', 'sport'],
#  'such': ['shuch'],
#  'data': ['dsata'],
#  'natural': ['natureal', 'naturual'],
#  'conscious': ['counscious', 'consciouse', 'consceious', 'consicious'],
#  'ordinarily': ['ordinairily',
#   'oridinarily',
#   'ordinarialy',
#   'ordinarlily',
#   'ordinarilly',
#   'ordainarily',
#   'ordinaryily'],
#  'so': ['soe', 'som', 'sol', 'sow', 'sor'],
#  'years': ['yesars'],
#  'experiments': ['experiaments'],
#  'omitting': ['ommitting'],
#  'torn': ['tourn'],
#  'suspicion': ['susspicion',
#   'suspicison',
#   'suspiscion',
#   'suspicsion',
#   'suspiction'],
#  'civilian': ['civillian'],
#  'bashful': ['bashfull'],
#  'establishing': ['esstablishing',
#   'estableishing',
#   'estsablishing',
#   'eastablishing',
#   'exstablishing'],
#  'owing': ['oweing'],
#  'contained': ['contasined'],
#  'poems': ['pomems', 'poemas', 'poemes', 'powems'],
#  'training': ['trainning'],
#  'saving': ['saveing'],
#  'one': ['onen'],
#  'submit': ['submite'],
#  'open': ['opean'],
#  'city': ['citty'],
#  'teacher': ['tearcher', 'teatcher', 'teahcher', 'tearcher'],
#  'ridiculous': ['ridiculeous', 'ridiculious'],
#  'folly': ['folloy', 'folley', 'foully'],
#  'unfit': ['unfitt'],
#  'turned': ['turened', 'turrned', 'teurned'],
#  'argument': ['aurgument', 'arguement'],
#  'sad': ['sade'],
#  'buried': ['burried', 'buiried', 'buryied'],
#  'take': ['tacke'],
#  'opposite': ['opposited', 'oppossite'],
#  'personalty': ['personality'],
#  'walking': ['wallking', 'waulking'],
#  'surplus': ['surpluse', 'surpluss'],
#  'merit': ['merrit'],
#  'going': ['gowing', 'goning'],
#  'equipped': ['eqquipped', 'equippted', 'ecquipped'],
#  'assistant': ['assisstant'],
#  'freezing': ['freezzing'],
#  'liable': ['lieable'],
#  'arrival': ['arrivial'],
#  'representatives': ['represenitatives'],
#  'dormitory': ['dormiatory',
#   'dormitoriy',
#   'doromitory',
#   'dormintory',
#   'dorimitory',
#   'dormitlory',
#   'dormiltory'],
#  'revealed': ['revealled'],
#  'many': ['manny'],
#  'millionaire': ['millionnaire'],
#  'ca': ['can', 'car'],
#  'yearly': ['yearley'],
#  'boat': ['boaut'],
#  'caring': ['careing'],
#  'breath': ['breathe'],
#  'wants': ['wantes'],
#  'thousand': ['thousnand'],
#  'easier': ['eassier'],
#  'newspaper': ['newspapper'],
#  'situation': ['situration'],
#  'i': ['is', 'it', 'iy', 'if', 'id', 'im', 'im'],
#  'being': ['bieing', 'beeing'],
#  'truculent': ['trucculent'],
#  'omissions': ['ommissions'],
#  'around': ['arouned', 'arround'],
#  'dart': ['darrt', 'darte', 'deart'],
#  'dark': ['darrk', 'darck'],
#  'traffic': ['traffice'],
#  'world': ['wourld'],
#  'satisfaction': ['satisfacttion', 'satishfaction'],
#  'nutrients': ['nutritents'],
#  'souvenirs': ['souveniers'],
#  'clap': ['clape'],
#  'auditorium': ['auditoruium', 'auditorinum', 'audiotorium', 'auditoriumn'],
#  'learning': ['learnning', 'learining'],
#  'memories': ['memoaries',
#   'mermories',
#   'memordies',
#   'memorries',
#   'memoiries',
#   'memmories',
#   'memouries'],
#  'endocrine': ['endochrine'],
#  'refer': ['refere'],
#  'neighbor': ['neighbour'],
#  'burin': ['buring'],
#  'her': ['here'],
#  'elimination': ['eleimination'],
#  'with': ['wihth', 'whith', 'wirth', 'withe', 'witht'],
#  'detailed': ['detailled'],
#  'gone': ['gonne'],
#  'gratuitous': ['gratuitious'],
#  'cinderella': ['cinderrella'],
#  'am': ['ham'],
#  'an': ['and'],
#  'as': ['ass', 'asw', 'was', 'aas', 'has', 'als'],
#  'at': ['ast', 'att'],
#  'watson': ['watston'],
#  'unparalleled': ['unparallelled', 'unparralleled'],
#  'congress': ['cnongress'],
#  'mask': ['marsk'],
#  'having': ['haveing'],
#  'original': ['origional'],
#  'consider': ['consdider'],
#  'to': ['tow', 'too'],
#  'debit': ['deblit', 'debtit', 'depbit', 'debite'],
#  'baton': ['batton'],
#  'condition': ['condidtion'],
#  'accompanying': ['accompagnying'],
#  'dodged': ['dodeged'],
#  'large': ['mlarge', 'lardge'],
#  'sank': ['scank', 'sanck'],
#  'past': ['parst'],
#  'semi-skilled': ['semie-skilled'],
#  'mad': ['made'],
#  'hours': ['houres'],
#  'experience': ['experinence'],
#  'prior': ['prioor', 'priror', 'prieor', 'priore', 'priour'],
#  'sherbet': ['sherbert'],
#  'gorgeous': ['guorgeous', 'georgeous', 'gorgeious', 'gourgeous'],
#  'pleasing': ['pleaseing'],
#  'learn': ['learne'],
#  'beautiful': ['beautifull'],
#  'occur': ['occure', 'occurr'],
#  'variant': ['vairiant'],
#  'plane': ['plaine'],
#  'plank': ['planck'],
#  'resemble': ['ressemble'],
#  'loud': ['lourd', 'lould', 'loued', 'lound', 'loucd'],
#  'triumph': ['triaumph', 'triumpth'],
#  'propose': ['proppose'],
#  'weedy': ['weedey'],
#  'coping': ['copping'],
#  'always': ['allways'],
#  'assemblies': ['assembelies'],
#  'courses': ['coursecs', 'coureses'],
#  'reactions': ['reactioons'],
#  'upstairs': ['upstaires'],
#  'catalogues': ['catalogueds', 'cattalogues'],
#  'gaoler': ['gaolers'],
#  'peripatetic': ['peripathetic'],
#  'exorbitant': ['exhorbitant'],
#  'operation': ['opperation'],
#  'psychology': ['phsychology'],
#  'research': ['reasearch'],
#  'belief': ['beilief', 'beliefe'],
#  'rockefeller': ['rockerfeller'],
#  'imagine': ['immagine'],
#  'definition': ['deffinition'],
#  'rack': ['wrack'],
#  'number': ['numbeer', 'numbers'],
#  'relationship': ['relatiopnship'],
#  'ethos': ['ethose'],
#  'determined': ['determuined', 'dertermined', 'determinied', 'determained'],
#  'beneficial': ['beneificial', 'benieficial'],
#  'it': ['hit', 'its'],
#  'blond': ['blonde'],
#  'sell': ['selle'],
#  'self': ['selfe'],
#  'also': ['alsot', 'allso'],
#  'without': ['whithout'],
#  'commemorated': ['commmemorated'],
#  'effecting': ['effectinge'],
#  'plan': ['plean', 'plane', 'plain'],
#  'writer': ['writter'],
#  'sunny': ['sunney'],
#  'preparing': ['prepairing'],
#  'enemy': ['enemey'],
#  'renewed': ['renewded'],
#  'bachelor': ['batchelor'],
#  'let': ['lets', 'lets'],
#  'indefinite': ['indefiniate', 'indeffinite'],
#  'belt': ['bellt', 'belts', 'belte'],
#  'initiation': ['inititation',
#   'iniatiation',
#   'innitiation',
#   'intitiation',
#   'inistiation'],
#  'fire': ['fires', 'firer', 'firve'],
#  'what': ['whats', 'whats', 'whate'],
#  'bitchy': ['bitchey'],
#  'fond': ['found'],
#  'systematic': ['systermatic'],
#  'handling': ['handeling', 'handleing'],
#  'reliable': ['relieable'],
#  'admire': ['addmire'],
#  'technical': ['technickal',
#   'techinical',
#   'technicale',
#   'technincal',
#   'techenical',
#   'techneical',
#   'technicial',
#   'techanical',
#   'technichal'],
#  'robin': ['robbin'],
#  'scheduled': ['scheuduled',
#   'schedualed',
#   'schedueled',
#   'schueduled',
#   'schedudled',
#   'sceheduled'],
#  'hoping': ['hopeing', 'hopping'],
#  'funny': ['funney'],
#  'comprehensive': ['comphrehensive'],
#  'necessity': ['neccessity'],
#  'clearance': ['cleareance'],
#  'admission': ['addmission'],
#  'recommended': ['reccommended'],
#  'parents': ['parrents', 'prarents'],
#  'projects': ['projeccts'],
#  'stylish': ['styleish'],
#  'curious': ['courious', 'curiouse', 'currious'],
#  'be': ['bee', 'bei'],
#  'performs': ['performes'],
#  'agreement': ['aggreement'],
#  'by': ['buy', 'biy'],
#  'democrat': ['democrate'],
#  'appropriate': ['approppriate', 'appropreiate', 'appropriatte'],
#  'specifically': ['speciffically',
#   'specificually',
#   'specificalely',
#   'sepecifically'],
#  'suit': ['suite'],
#  'smoking': ['smocking', 'smokeing', 'smooking'],
#  'us': ['use', 'hus'],
#  'continuously': ['continuousely'],
#  'defined': ['deffined'],
#  'graceful': ['gracefull'],
#  'occasional': ['occassional'],
#  'rabies': ['rabbies'],
#  'oblige': ['oblidge'],
#  'worsened': ['worstened'],
#  'fresh': ['freash'],
#  'hello': ['hellow'],
#  'partial': ['partiall', 'partical'],
#  'enjoyable': ['enjoyeable'],
#  'renown': ['reknown'],
#  'citing': ['cisting'],
#  'dislike': ['disliked'],
#  'resources': ['rescources'],
#  'anxious': ['anxcious', 'anxsious'],
#  'athlete': ['athlette'],
#  'cannibals': ['canniballs'],
#  'incidentally': ['incidentially', 'inncidentally', 'inccidentally'],
#  'wet': ['weat'],
#  'apparatus': ['apparatous', 'apparratus', 'apparattus', 'appauratus'],
#  'led': ['lead', 'lend', 'leed', 'lede', 'lled', 'lred'],
#  'eminently': ['emminently'],
#  'leg': ['lege'],
#  'engage': ['engauge'],
#  'opinion': ['oppinion'],
#  'tools': ['tooles'],
#  'next': ['nexst'],
#  'doubt': ['doubte'],
#  'lodgment': ['lodgement'],
#  'baby': ['babby', 'babys'],
#  'customer': ['customers', 'coustomer', 'customers', 'coustomer'],
#  'pejorative': ['perjorative'],
#  'this': ['thhis'],
#  'thin': ['thine'],
#  'police': ['poilice', 'pollice'],
#  'process': ['proccess'],
#  'lock': ['loack'],
#  'high': ['hiegh', 'higth'],
#  'insistent': ['insistenet'],
#  'singular': ['singulaur'],
#  'tied': ['tired', 'tieed', 'tried', 'tided', 'tiyed'],
#  'weighed': ['weighted'],
#  'volunteers': ['volounteers'],
#  'doubtful': ['doubtfull'],
#  'chosen': ['choosen'],
#  'lamp': ['lamps'],
#  'thieves': ['thifeves'],
#  'instruments': ['instrusments', 'insturuments'],
#  'animal': ['animals'],
#  'earn': ['hearn'],
#  'asymmetrical': ['assymmetrical'],
#  'sufficiently': ['suffieciently'],
#  'expels': ['expells'],
#  'mum': ['mums'],
#  'truth': ['thruth'],
#  'beneath': ['beaneath'],
#  'doing': ['dowing'],
#  'books': ['bookes'],
#  'witness': ['wittness'],
#  'unwieldy': ['unwieldly'],
#  'log': ['loge'],
#  'transferable': ['transferrable'],
#  'receding': ['receeding'],
#  'scare': ['sceare'],
#  'diagrammatically': ['diagrammaticaally'],
#  'reference': ['refereence', 'refference', 'referrence'],
#  'festival': ['fesctival'],
#  'painful': ['painfull'],
#  'interests': ['interrests'],
#  'stars': ['stares', 'stairs'],
#  'bother': ['borther'],
#  'appealing': ['appealling'],
#  'collecting': ['collecyting'],
#  'false': ['faulse'],
#  'documents': ['doctuments',
#   'doccuments',
#   'docquments',
#   'dockuments',
#   'docuements',
#   'docutments',
#   'dockuments'],
#  'lily': ['lilly'],
#  'soap': ['soape'],
#  'courtesy': ['courtessy',
#   'courtesey',
#   'courtesiy',
#   'courtescy',
#   'courtesty',
#   'courteosy',
#   'courtiesy'],
#  'amongst': ['amoungst'],
#  'so-called': ['sol-called'],
#  'you': ['your', 'your', 'your', 'your'],
#  'fact': ['fackt'],
#  'atmosphere': ['atmousphere'],
#  'vacancy': ['vacancey', 'vacantcy', 'vaccancy', 'vancancy'],
#  'rough': ['rougth', 'rought', 'roughe'],
#  'planted': ['plarnted', 'plansted'],
#  'riding': ['rideing'],
#  'familiar': ['farmiliar', 'familliar'],
#  'lucky': ['luckey'],
#  'committees': ['committeies', 'comimittees'],
#  'temporarily': ['temporarilly', 'temporarialy', 'temporairily'],
#  'edition': ['ediition', 'editions', 'eidition', 'eddition'],
#  'wire': ['wirer'],
#  'nuclear': ['nuculear'],
#  'buffalos': ['buffaloes'],
#  'staring': ['stearing'],
#  'defiance': ['definance'],
#  'pity': ['pitty'],
#  'pedantry': ['pendantry'],
#  'laser': ['lasher'],
#  'site': ['sitte'],
#  'covenant': ['convenant'],
#  'acknowledgement': ['accknowledgement', 'aceknowledgement'],
#  'generous': ['generious'],
#  'combine': ['comibine'],
#  'decidable': ['decideable'],
#  'imprison': ['imprisons'],
#  'amendment': ['ammendment', 'admendment'],
#  'recognition': ['reckognition',
#   'recogniction',
#   'recocgnition',
#   'recongnition',
#   'recogonition'],
#  'literally': ['literalily',
#   'literially',
#   'literrally',
#   'litterally',
#   'literually'],
#  'avoid': ['avoide'],
#  'does': ['doens'],
#  'voluptuous': ['volumptuous'],
#  'schedule': ['sechedule', 'scheduled', 'scheduale'],
#  'targeting': ['targetting'],
#  'commitment': ['committment'],
#  'tiny': ['tiney'],
#  'housing': ['houssing'],
#  'specimens': ['speciemens',
#   'specimends',
#   'speicimens',
#   'speciamens',
#   'speciments'],
#  'naturally': ['naturually'],
#  'delivery': ['delievery'],
#  'construction': ['construcktion'],
#  'basin': ['bassin'],
#  'bicycle': ['biscycle', 'bicycles', 'bicyclle'],
#  'convince': ['convience'],
#  'problem': ['promblem', 'probleum', 'probalem', 'prroblem', 'probblem'],
#  'ink': ['inke'],
#  'renowned': ['reknowned'],
#  'compared': ['comppared'],
#  'repeat': ['reapeat'],
#  'coloration': ['colouration'],
#  'rule': ['rulle'],
#  'desirable': ['desireable'],
#  'commandos': ['commandoes'],
#  'merchantmen': ['merchantment'],
#  'women': ['womens', 'weomen', 'wommen'],
#  'disobedient': ['dissobedient'],
#  'we': ['wel', 'wee', 'wen', 'wey'],
#  'rigorous': ['rigourous'],
#  'above': ['abouve'],
#  'consisting': ['consisiting'],
#  'told': ['toled', 'tolld'],
#  'glance': ['glacnce'],
#  'reign': ['reighn'],
#  'tariff': ['tarriff'],
#  'work': ['worke'],
#  'worm': ['worme'],
#  'ere': ['eire', 'aere'],
#  'disappoint': ['dissappoint'],
#  'fever': ['feaver'],
#  'after': ['aftere'],
#  'bared': ['barred'],
#  'suing': ['sueing'],
#  'lap': ['lape'],
#  'alienate': ['allienate'],
#  'appreciate': ['appreiciate', 'apprieciate'],
#  'scarf': ['scarfe'],
#  'consent': ['conscent'],
#  'production': ['productions'],
#  'eventually': ['eventuially', 'eventiually', 'enventually', 'eventurally'],
#  'them': ['theme'],
#  'contaminate': ['contaiminate'],
#  'break': ['breack'],
#  'band': ['bande'],
#  'schemes': ['scheames'],
#  'forty': ['fourty'],
#  'forth': ['fourth'],
#  'created': ['creaeted'],
#  'another': ['annother'],
#  'john': ['johhn', 'johns'],
#  'unmistakable': ['unmistakeable'],
#  'stomach': ['stomache', 'stormach'],
#  'strength': ['streangth'],
#  'convenient': ['convienient'],
#  'subjects': ['subjectes'],
#  'pilgrimage': ['pilgrimmage'],
#  'completed': ['compleated'],
#  'gravy': ['gravey'],
#  'phase': ['phrase', 'phases', 'phause', 'phased', 'phaise'],
#  'calculated': ['caluculated'],
#  'alumni': ['alumuni',
#   'alumnii',
#   'anlumni',
#   'alumnis',
#   'alumnia',
#   'alumini',
#   'alumnie',
#   'alumani',
#   'allumni'],
#  'aunt': ['aunte', 'aunit', 'auant'],
#  'voting': ['voteing'],
#  'decidedly': ['decidedley', 'deciededly', 'descidedly'],
#  'resemblance': ['ressemblance'],
#  'adequate': ['adequante'],
#  'do': ['don', 'doo', 'dom', 'dor', 'doe', 'dow', 'dou', 'don'],
#  'leisure': ['leissure', 'leiusure'],
#  'suffrage': ['sufferage'],
#  'children': ['childrens', 'childrend', 'chilldren'],
#  'away': ['alway'],
#  'cooperation': ['coorperation'],
#  'co': ['com'],
#  'handful': ['handfull'],
#  'coy': ['cpoy'],
#  'ill': ['ills'],
#  'disappears': ['dissappears'],
#  'bran': ['brain'],
#  'speak': ['speack'],
#  'surreptitious': ['surrepetitious'],
#  'physician': ['physicians'],
#  'air': ['hair'],
#  'mistake': ['misstake'],
#  'brake': ['brakke'],
#  'girls': ['girles'],
#  'patent': ['patient', 'pattent'],
#  'hang': ['haing'],
#  'hand': ['hande'],
#  'mountainous': ['mountainouse'],
#  'blamed': ['blaimed'],
#  'kept': ['keept'],
#  'the': ['tehe', 'tjhe', 'thee', 'thge', 'they', 'ther', 'tghe'],
#  'athletic': ['atheletic'],
#  'expelled': ['exspelled'],
#  'usable': ['useable'],
#  'progresses': ['progressess'],
#  'invaluable': ['invalueable'],
#  'born': ['borne'],
#  'asking': ['arsking', 'askeing'],
#  'marketing': ['marketting'],
#  'binomial': ['binominal'],
#  'coral': ['corral'],
#  'months': ['monthes'],
#  'situated': ['situtated'],
#  'usefulness': ['usefullness'],
#  'balanced': ['ballanced'],
#  'fight': ['fright', 'feight', 'fieght', 'firght'],
#  'was': ['wase', 'wass', 'wase'],
#  'becoming': ['becomeing', 'becomming'],
#  'peninsula': ['peninsular', 'penninsula'],
#  'mysterious': ['myesterious', 'myssterious'],
#  'emotional': ['emothional'],
#  'no_one': ['now_one', 'not_one'],
#  'dying': ['deying', 'diying', 'dyeing'],
#  'interested': ['interrested'],
#  'test': ['tesst', 'ttest'],
#  'welcome': ['wellcome'],
#  'affidavit': ['affidavite'],
#  'together': ['togethers'],
#  'grateful': ['greateful', 'gratefull'],
#  'certainly': ['certaintly', 'certainley'],
#  'permanently': ['permannently', 'permantently', 'permanentley'],
#  'rhythm': ['rhythem', 'rhythim'],
#  'cargo': ['cargow'],
#  'collateral': ['collarteral', 'collaterial', 'coallateral', 'collatteral'],
#  'muslin': ['musslin'],
#  'appears': ['appeares'],
#  'usually': ['ussually'],
#  'controls': ['controlls'],
#  'pony': ['poney'],
#  'rarely': ['rareley'],
#  'prove': ['proove'],
#  'jam': ['jame'],
#  'entrance': ['entrances', 'enterance'],
#  'car': ['cars', 'care'],
#  'can': ['cane'],
#  'headmaster': ['heardmaster'],
#  'did': ['dind'],
#  'heard': ['heared'],
#  'spa': ['spar'],
#  'starch': ['startch'],
#  'southern': ['sourthern'],
#  'remember': ['rememeber',
#   'rermember',
#   'remmember',
#   'remermber',
#   'rememmber',
#   'rembember',
#   'rememberd'],
#  'explicit': ['explicite'],
#  'berets': ['berrets'],
#  'crept': ['creept'],
#  'trifle': ['triffle'],
#  'curly': ['curley', 'currly'],
#  'forms': ['formes'],
#  'trilby': ['trillby'],
#  'correspondence': ['correspondences'],
#  'introduce': ['inctroduce'],
#  'half': ['halfe', 'hailf'],
#  'not': ['knot', 'onot'],
#  'now': ['know'],
#  'provision': ['provission'],
#  'nor': ['nore'],
#  'thankful': ['thankfull'],
#  'year': ['yeare'],
#  'amusement': ['ammusement'],
#  'shown': ['showen'],
#  'opened': ['openend'],
#  'epistle': ['epistile', 'epistles', 'episitle', 'epistole', 'epistile'],
#  'rebel': ['rebell'],
#  'inevitable': ['inevyitable'],
#  'flying': ['flaying', 'fleying', 'fliying'],
#  'omitted': ['ommitted'],
#  'there': ['theres', 'theyre', 'theres', 'theire'],
#  'tomorrow': ['tommorrow'],
#  'size': ['sixze', 'sieze'],
#  'sheep': ['sheepe'],
#  'friend': ['freiend'],
#  'mostly': ['mostley'],
#  'that': ['thgat', 'tyhat', 'theat', 'thatt', 'thate', 'thats'],
#  'appreciated': ['appreceiated'],
#  'transferred': ['transeferred'],
#  'scholastic': ['scholarstic'],
#  'angel': ['angell'],
#  'overcoming': ['overcomming'],
#  'equipment': ['equippment'],
#  'begin': ['beggin', 'begine'],
#  'forever': ['foreever', 'forevere'],
#  'filing': ['filling'],
#  'tonnage': ['tonnauge'],
#  'ground': ['grouned'],
#  'chautauqua': ['cheautauqua'],
#  'title': ['tittle'],
#  'only': ['lonly'],
#  'truly': ['trully', 'truely', 'truley'],
#  'losers': ['loosers'],
#  'elected': ['ellected'],
#  'asleep': ['asleeep'],
#  'tackling': ['tackeling'],
#  'complexion': ['complextion'],
#  'between': ['beetween'],
#  'receded': ['receeded'],
#  'death': ['dearth'],
#  'madness': ['maddness'],
#  'proved': ['prooved'],
#  'these': ['thease', 'theese', 'thoese'],
#  'mining': ['minning'],
#  'zenith': ['zeenith'],
#  'alcoholic': ['alchoholic'],
#  'soil': ['soile'],
#  'commanded': ['commaunded'],
#  'ship': ['shipe'],
#  'develop': ['develope'],
#  'inquiry': ['inquirey'],
#  'document': ['doccument'],
#  'pedantic': ['pendantic'],
#  'fruit': ['fruite', 'fruilt'],
#  'theater': ['theather'],
#  'jane': ['janes'],
#  'valuable': ['valueable'],
#  'touch': ['tourch'],
#  'real': ['reall'],
#  'specimen': ['sepecimen',
#   'speciumen',
#   'speciemen',
#   'specimens',
#   'specimend',
#   'speciment',
#   'specismen',
#   'specimene'],
#  'using': ['useing'],
#  'execution': ['excecution'],
#  'fortune': ['fourtune'],
#  'output': ['oputput'],
#  'apartments': ['appartments'],
#  'deficit': ['deficite'],
#  'assembly': ['assembley', 'assembaly'],
#  'business': ['bussiness', 'busineses', 'businesss'],
#  'sixty': ['sixtey'],
#  'exciting': ['excieting', 'exciteing'],
#  'comparison': ['comparision', 'comparrison'],
#  'central': ['centeral'],
#  'chop': ['chopp', 'chope'],
#  'elementary': ['elementrary', 'ellementary', 'elementiary'],
#  'your': ['youre'],
#  'start': ['starte'],
#  'low': ['lowe'],
#  'lot': ['alot', 'lost'],
#  'dracula': ['draculla'],
#  'gown': ['grown'],
#  'mathematics': ['mathermatics',
#   'mathematicts',
#   'mathenmatics',
#   'mathemathics',
#   'mathlematics'],
#  'whistling': ['whisteling', 'whistiling', 'whistleing'],
#  'registry': ['registery'],
#  'requisition': ['rekquisition',
#   'recquisition',
#   'requizsition',
#   'requirsition'],
#  'cores': ['corres'],
#  'surrounded': ['surroundend'],
#  'ceased': ['ceasted', 'sceased'],
#  'customary': ['custoimary'],
#  'dreadful': ['dreadfull'],
#  'referring': ['refferring', 'referrings'],
#  'very': ['verry', 'verey', 'every'],
#  'decide': ['decided', 'descide'],
#  'mild': ['miled'],
#  'circuit': ['ciricuit'],
#  'study': ['studdy'],
#  'canonical': ['cannonical'],
#  'conscience': ['consicience'],
#  'certificates': ['cerstificates'],
#  'selective': ['seleactive'],
#  'advisable': ['adviseable'],
#  'arena': ['areana'],
#  'ahead': ['aheard'],
#  'amount': ['ammount'],
#  'advertising': ['advertiseing'],
#  'family': ['familly', 'fammily'],
#  'contains': ['containes', 'countains'],
#  'taken': ['tacken', 'takern', 'talken', 'takeon', 'taeken'],
#  'injury': ['injurey'],
#  'broke': ['broken'],
#  'sovereignty': ['sovereignity'],
#  'grill': ['grille'],
#  'courtesies': ['courtiesies'],
#  'a': ['ah', 'an', 'as'],
#  'telephoned': ['telephonied'],
#  'help': ['hellp'],
#  'administration': ['addministration'],
#  'committed': ['committied', 'committeed'],
#  'actually': ['acturally', 'acctually'],
#  'have': ['haven', 'havei', 'havne', 'haven'],
#  'motivated': ['motiviated'],
#  'irrationality': ['irrationallity'],
#  'occasions': ['occassions'],
#  'is': ['ise', 'his'],
#  'referred': ['referrred', 'refferred', 'preferred'],
#  'heavy': ['heavey'],
#  'unnatural': ['unnaturral'],
#  'since': ['scince'],
#  'base': ['basse', 'baese'],
#  'maths': ['mathes'],
#  'terrible': ['terriable'],
#  'expecting': ['exspecting'],
#  'unexpected': ['unexcpected', 'unexspected', 'unexpercted'],
#  'horse': ['howrse', 'hoarse', 'hourse', 'horese'],
#  'airborne': ['airbourne'],
#  'station': ['staytion'],
#  'banana': ['bannana', 'bananna'],
#  'behind': ['behined'],
#  'anticipate': ['antiscipate', 'anticcipate', 'anticipated'],
#  'obfuscate': ['obsfuscate'],
#  'father': ['farther', 'farther', 'farther'],
#  'juicy': ['juicey', 'juiciy'],
#  'juice': ['juices', 'jucice'],
#  'eaten': ['eatten'],
#  'clean': ['clearn'],
#  'usual': ['usueal'],
#  'perseverance': ['perserverance'],
#  'completion': ['complection',
#   'completeion',
#   'completicon',
#   'compleetion',
#   'complestion',
#   'compleation',
#   'commpletion'],
#  'flesh': ['fleash'],
#  'dominant': ['dominiant'],
#  'trees': ['threes'],
#  'pilot': ['pirlot', 'piolot', 'pilote'],
#  'famous': ['famours', 'famoust'],
#  'competing': ['compeating'],
#  'during': ['durring'],
#  'imitating': ['immitating'],
#  'adhering': ['adhearing'],
#  'retaliation': ['retalitation'],
#  'inefficient': ['innefficient'],
#  'recommendations': ['recommenddations', 'reccommendations'],
#  'horrid': ['horried'],
#  'won': ['wone'],
#  'probably': ['probabley', 'probablly'],
#  'conditions': ['condistions', 'condiptions', 'condictions', 'condidtions'],
#  'cartographer': ['carthographer'],
#  'flagrancy': ['flangrancy', 'flagerancy', 'flagrancey'],
#  'both': ['bothe'],
#  'would': ['woulde', 'whould'],
#  'liked': ['licked'],
#  'mr': ['mrs'],
#  'badminton': ['badmington'],
#  'partly': ['partley'],
#  'utmost': ['uttmost'],
#  'clerical': ['clearical'],
#  'grand': ['graned'],
#  'used': ['usued', 'unsed', 'usedf'],
#  'fulfilment': ['fulfillment'],
#  'grind': ['grined'],
#  'itemized': ['ithemized',
#   'ittemized',
#   'itemtized',
#   'intemized',
#   'eitemized',
#   'itemmized'],
#  'useful': ['usefull'],
#  'canisters': ['cannisters'],
#  'cemetery': ['cemertery'],
#  'debatable': ['debateable'],
#  'unravelled': ['unwravelled'],
#  'tiring': ['tiering'],
#  'some': ['somes'],
#  'economic': ['ecomnomic', 'enconomic', 'economics', 'ecconomic', 'econnomic'],
#  'mucous': ['mucuous'],
#  'massachusetts': ['massachussetts'],
#  'sympathetic': ['sympathethic', 'symphathetic'],
#  'processing': ['proccessing'],
#  'step': ['stepe'],
#  'subtract': ['substract'],
#  'hinge': ['hindge'],
#  'allotment': ['allottment'],
#  'seeing': ['seening'],
#  'within': ['withing'],
#  'conscientious': ['conscienctious', 'conscientiouse'],
#  'statistics': ['statisticks', 'statisticts'],
#  'himself': ['himselfe'],
#  'duly': ['dulay',
#   'duley',
#   'dutly',
#   'douly',
#   'dualy',
#   'dully',
#   'duely',
#   'dudly'],
#  'bolsters': ['boulsters'],
#  'fishy': ['fishey'],
#  'vacancies': ['vaciancies',
#   'vaccancies',
#   'vacantcies',
#   'vancancies',
#   'vacancises'],
#  'politic': ['politict'],
#  'accustomed': ['accusstomed',
#   'accustommed',
#   'accoustomed',
#   'accustiomed',
#   'accustomend',
#   'accumstomed',
#   'accustomned'],
#  'similar': ['simmilar', 'similiar'],
#  'drag': ['drage'],
#  'dram': ['deram'],
#  'required': ['reequired', 'recquired'],
#  'pamphlets': ['pamphelets',
#   'pamphleots',
#   'pamphletts',
#   'pamphalets',
#   'phamphlets'],
#  'cheerful': ['cheerfull'],
#  'go': ['got', 'gow'],
#  'gases': ['gasses'],
#  'anointed': ['annointed'],
#  'infinite': ['inffinite', 'infininte', 'inifinite'],
#  'wavy': ['wavey'],
#  'assignments': ['assighnments'],
#  'notwithstanding': ['nothwithstanding'],
#  'plays': ['playes'],
#  'sepulchre': ['sepulchure'],
#  'boys': ['boyes'],
#  'imitator': ['immitator'],
#  'america': ['american'],
#  'melancholy': ['mellancholy', 'melancholly'],
#  'commercial': ['commericial'],
#  'maneuverability': ['manoeuverability'],
#  'repel': ['repell'],
#  'were': ['where'],
#  'vilify': ['villify'],
#  'win': ['wind'],
#  'cloud': ['cloued'],
#  'simpler': ['simplier'],
#  'averaged': ['averageed'],
#  'irreparable': ['irrepairable'],
#  'control': ['controle', 'controll'],
#  'wonderful': ['wonderfull'],
#  'picturesque': ['pictureosque', 'pictureesque'],
#  'poetry': ['poeptry',
#   'poetory',
#   'poertry',
#   'poetrey',
#   'poetary',
#   'peoetry',
#   'poetery',
#   'powetry',
#   'poettry',
#   'poaetry',
#   'poeatry',
#   'poetray',
#   'poretry'],
#  'filament': ['filiament'],
#  'british': ['brittish'],
#  'mrs': ['mrss'],
#  'bakery': ['backery'],
#  'encyclopedia': ['enclyclopedia'],
#  'bathing': ['batheing'],
#  'banquet': ['bankquet', 'banquete'],
#  'subtraction': ['substraction'],
#  'front': ['frount'],
#  'documented': ['doccumented'],
#  'impresario': ['impressario'],
#  'special': ['speciall', 'speacial', 'spectial', 'speicial'],
#  'umbrella': ['umberella'],
#  'withdraw': ['withdrawl'],
#  'geometry': ['geometrey',
#   'geometary',
#   'geometriy',
#   'geomentry',
#   'geomeotry',
#   'geometery',
#   'geometery',
#   'geomeltry',
#   'geomertry'],
#  'powerful': ['powerfull'],
#  'improving': ['improoving'],
#  'relations': ['reylations'],
#  'attach': ['attache'],
#  'final': ['finial', 'finall', 'finale', 'finaly', 'finalt', 'fianal'],
#  'exactly': ['exsactly', 'exactely', 'excactly'],
#  'beg': ['begg', 'bege', 'begr', 'berg', 'becg'],
#  'bet': ['beat'],
#  'need': ['needd'],
#  'border': ['boarder', 'bourder'],
#  'able': ['abule'],
#  'future': ['furture'],
#  'gallery': ['gallerey', 'gallerry', 'gallerly', 'garllery'],
#  'subtracted': ['substracted'],
#  'scrambled': ['scrambeled'],
#  'partners': ['parteners'],
#  'envy': ['envey'],
#  'procedures': ['proceedures'],
#  'shy': ['shiy'],
#  'quarantine': ['quarrantine', 'quarantaine'],
#  'grab': ['grabe'],
#  'career': ['carreer'],
#  'admit': ['admite'],
#  'addition': ['addittion'],
#  'expenditure': ['expendidture',
#   'exspenditure',
#   'expeniditure',
#   'expenditures'],
#  'and': ['hand', 'anbd', 'aand'],
#  'tom': ['toms'],
#  'owns': ['ownes'],
#  'surface': ['sureface'],
#  'began': ['begain', 'begane'],
#  'speaker': ['speacker'],
#  'party': ['partey'],
#  'practitioner': ['practictioner'],
#  'forgotten': ['forgottern'],
#  'frequently': ['freequently'],
#  'scarcely': ['scarcelay', 'scarecely', 'scarcecly', 'secarcely'],
#  'warlord': ['warloord'],
#  'glowed': ['gloweld', 'gilowed'],
#  'enormously': ['enourmously'],
#  'mistaken': ['misstaken'],
#  'sunday': ['sundays', 'suntday'],
#  'restaurateur': ['restauranteur'],
#  'aficionados': ['afficionados'],
#  'immediately': ['immeadiately', 'immediantely', 'immiediately'],
#  'necessary': ['neccessary'],
#  'lost': ['loast', 'lorst', 'losst', 'losth', 'loost', 'loest'],
#  'sized': ['siezed', 'seized'],
#  'lose': ['loose'],
#  'phenomena': ['phenonmena'],
#  'connectives': ['connectivies'],
#  'home': ['homse'],
#  'broad': ['broard'],
#  'cradle': ['craddle'],
#  'monetary': ['monestary'],
#  'equally': ['eaqually', 'equalily'],
#  'museum': ['mueseum', 'meuseum'],
#  'triangular': ['triangulaur'],
#  'eat': ['eate'],
#  'he': ['her', 'hey', 'the'],
#  'signed': ['sighned'],
#  'coveted': ['coverted'],
#  'penny': ['penney'],
#  'education': ['eduacation'],
#  'functions': ['functuions'],
#  'star': ['stare'],
#  'stay': ['staye'],
#  'friends': ['frieneds'],
#  'spanish': ['spainish'],
#  'similarity': ['similiarity'],
#  'straws': ['strawes'],
#  'consists': ['consisits'],
#  'calculate': ['caluculate'],
#  'segments': ['segements'],
#  'disability': ['dissability'],
#  'seriously': ['seariously'],
#  'vast': ['vaste'],
#  'alpine': ['allpine', 'almpine', 'alphine'],
#  'baking': ['bakeing'],
#  'crops': ['cropes'],
#  'convenience': ['convienience'],
#  'vector': ['vectore'],
#  'force': ['forces'],
#  'japanese': ['japannese'],
#  'colourful': ['colourfull'],
#  'even': ['evene', 'eaven', 'event'],
#  'wreck': ['wreack'],
#  'desirous': ['desirious', 'desireous'],
#  'new': ['knew'],
#  'ever': ['every'],
#  'drew': ['drewe'],
#  'active': ['acttive'],
#  'are': ['arre', 'aree', 'arte'],
#  'dry': ['drye'],
#  'economics': ['eckonomics',
#   'ecconomics',
#   'economicks',
#   'econnomics',
#   'economicts'],
#  'credit': ['creadit'],
#  'harass': ['harrass'],
#  'permit': ['permite'],
#  'suitable': ['seuitable'],
#  'moral': ['morall'],
#  'army': ['armey'],
#  'recommend': ['recommened', 'reccommend'],
#  'calf': ['calft'],
#  'wary': ['weary'],
#  'adult': ['addult'],
#  'ward': ['whard'],
#  'bungalow': ['bungallow', 'bungalowe', 'boungalow'],
#  'give': ['giave'],
#  'laughs': ['laughes'],
#  'unforgettable': ['unforrgettable', 'unforgetteable'],
#  'answer': ['answear', 'answere', 'ansewer', 'ansower', 'ansawer'],
#  'aboard': ['abroard'],
#  'abuts': ['abutts'],
#  'curiosity': ['curitosity', 'curiousity', 'couriosity'],
#  'president': ['presidents',
#   'presidents',
#   'presidents',
#   'presidents',
#   'presidente'],
#  'frequent': ['freequent'],
#  'operate': ['opperate'],
#  'before': ['berfore', 'befoure', 'beefore'],
#  'vigorous': ['vigourous'],
#  ...}

# %%
transposition_
# Out:
# {'wednesday': ['wedensday'],
#  'reporter': ['reproter'],
#  'here': ['heer', 'hree'],
#  'shriek': ['shreik'],
#  'reports': ['reoprts'],
#  'golden': ['gloden'],
#  'sines': ['sinse'],
#  'brought': ['brougth'],
#  'successful': ['succsesful'],
#  'example': ['exmaple'],
#  'want': ['watn', 'wnat'],
#  'travel': ['travle'],
#  'wrong': ['worng'],
#  'secede': ['seceed'],
#  'precedes': ['preceeds'],
#  'ate': ['aet'],
#  'today': ['todya'],
#  'pneumonia': ['pnuemonia', 'penumonia'],
#  'idle': ['idel'],
#  'incomplete': ['incompleet'],
#  'gauge': ['guage'],
#  'than': ['thna', 'tahn'],
#  'jaguar': ['jagaur'],
#  'patch': ['pacth'],
#  'best': ['bets'],
#  'lots': ['lost'],
#  'side': ['sied'],
#  'accident': ['accdient'],
#  'country': ['ocuntry'],
#  'life': ['lief'],
#  'eastern': ['eastren'],
#  'violin': ['vioiln'],
#  'things': ['thigns', 'thnigs'],
#  'split': ['spilt'],
#  'peremptory': ['preemptory'],
#  'financially': ['finanically'],
#  'portrayed': ['protrayed'],
#  'innocent': ['inoncent'],
#  'prologue': ['prolouge'],
#  'right': ['rigth'],
#  'old': ['lod'],
#  'people': ['poeple', 'peopel', 'peolpe', 'pepole'],
#  'for': ['fro'],
#  'slightly': ['slighlty'],
#  'altitude': ['altitued'],
#  'overhead': ['overhaed'],
#  'safeguard': ['safegaurd'],
#  'else': ['eles', 'esle'],
#  'tournament': ['touranment'],
#  'superfluous': ['superfulous'],
#  'time': ['tiem'],
#  'chair': ['chiar'],
#  'minute': ['minuet'],
#  'settle': ['settel'],
#  'prevent': ['pervent'],
#  'love': ['lvoe', 'loev'],
#  'prefer': ['perfer'],
#  'working': ['wroking', 'wokring'],
#  'originally': ['orignially'],
#  'pretend': ['pretned', 'pertend'],
#  'believes': ['beleives'],
#  'believed': ['beleived'],
#  'natural': ['natrual'],
#  'ordinarily': ['ordinairly'],
#  'archaeologist': ['archeaologist'],
#  'years': ['yeasr', 'eyars', 'yeras'],
#  'deity': ['diety'],
#  'torn': ['tron'],
#  'suspicion': ['supsicion'],
#  'turtle': ['turtel'],
#  'receipt': ['reciept'],
#  'chemically': ['chemcially'],
#  'siege': ['seige'],
#  'quite': ['quiet', 'qutie'],
#  'poems': ['peoms', 'pomes'],
#  'training': ['trianing'],
#  'one': ['oen'],
#  'vote': ['voet'],
#  'open': ['opne'],
#  'boyfriend': ['boyfreind'],
#  'folly': ['floly'],
#  'turned': ['turend', 'truned'],
#  'buried': ['buired'],
#  'take': ['tkae', 'taek'],
#  'opposite': ['oppoiste'],
#  'salt': ['slat'],
#  'guard': ['gaurd'],
#  'going': ['oging', 'gonig', 'goign'],
#  'freezing': ['frezeing'],
#  'priest': ['preist'],
#  'where': ['hwere'],
#  'receivers': ['recievers'],
#  'representatives': ['represnetatives', 'repersentatives'],
#  'dormitory': ['dorimtory'],
#  'mans': ['masn'],
#  'besieging': ['beseiging'],
#  'buoyancy': ['bouyancy'],
#  'wants': ['wnats'],
#  'formed': ['fromed'],
#  'being': ['bieng'],
#  'silver': ['sliver'],
#  'dart': ['drat'],
#  'dark': ['drak'],
#  'traffic': ['tarffic'],
#  'satisfaction': ['satisfactoin'],
#  'thinks': ['thikns'],
#  'power': ['pwoer'],
#  'lively': ['livley'],
#  'with': ['iwth', 'wiht', 'wtih'],
#  'they': ['tehy'],
#  'certain': ['certian', 'ceratin'],
#  'unparalleled': ['unparalelled'],
#  'having': ['hvaing'],
#  'Caesar': ['Ceasar'],
#  'to': ['ot'],
#  'dodged': ['dogded'],
#  'large': ['lagre'],
#  'sank': ['snak'],
#  'rye': ['rey'],
#  'semi-skilled': ['seim-skilled'],
#  'experience': ['expeirence'],
#  'prior': ['piror'],
#  'gorgeous': ['goregous'],
#  'seizing': ['siezing'],
#  'science': ['sceince'],
#  'learn': ['leanr', 'leran'],
#  'beautiful': ['beauitful', 'baeutiful'],
#  'autumn': ['autunm'],
#  'sense': ['senes'],
#  'information': ['infromation'],
#  'refuse': ['refues'],
#  'severely': ['severley'],
#  'always': ['alwasy', 'alwyas'],
#  'found': ['foudn'],
#  'catalogues': ['catalouges'],
#  'really': ['raelly', 'erally', 'realyl', 'relaly'],
#  'psychology': ['pyschology'],
#  'missel': ['missle'],
#  'seizures': ['siezures'],
#  'belief': ['belife', 'beleif'],
#  'marriage': ['marraige'],
#  'guarding': ['gaurding'],
#  'self': ['slef'],
#  'also': ['aslo'],
#  'play': ['paly'],
#  'plan': ['paln'],
#  'seize': ['sieze'],
#  'barrel': ['barrle'],
#  'cruises': ['crusies'],
#  'freight': ['frieght'],
#  'enemy': ['enmey'],
#  'ripper': ['ripper'],
#  'agents': ['agenst'],
#  'fire': ['frie', 'fier'],
#  'what': ['waht', 'whta'],
#  'technical': ['techincal'],
#  'scheduled': ['scheudled'],
#  'curious': ['curoius'],
#  'temple': ['tempel'],
#  'at_all': ['a_tall'],
#  'into': ['inot'],
#  'appropriate': ['apporpriate', 'appropirate'],
#  'bargaining': ['baragining'],
#  'influence': ['infulence'],
#  'questionnaire': ['questionniare'],
#  'besiege': ['beseige'],
#  'saying': ['saiyng'],
#  'anxious': ['anixous'],
#  'apparatus': ['appartaus'],
#  'indian': ['indain'],
#  'bird': ['brid'],
#  'great': ['gerat', 'graet'],
#  'receive': ['recieve'],
#  'makes': ['makse', 'mkaes'],
#  'explain': ['expalin'],
#  'next': ['enxt'],
#  'this': ['thsi', 'tihs'],
#  'pieces': ['peices'],
#  'rhubarb': ['ruhbarb'],
#  'tied': ['tide', 'teid'],
#  'weighed': ['wieghed'],
#  'move': ['omve'],
#  'thieves': ['theives'],
#  'instruments': ['insturments', 'instrumenst'],
#  'sufficiently': ['sufficeintly'],
#  'doing': ['donig', 'doign'],
#  'operator': ['poerator'],
#  'surely': ['surley'],
#  'could': ['coudl'],
#  'length': ['lenght'],
#  'owner': ['onwer'],
#  'painful': ['pianful'],
#  'false': ['fales'],
#  'tonight': ['tonigth', 'tongiht'],
#  'gentle': ['gentel'],
#  'clearly': ['claerly'],
#  'viewed': ['veiwed'],
#  'chief': ['cheif'],
#  'courtesy': ['courtsey'],
#  'you': ['yuo'],
#  'should': ['shoudl'],
#  'handle': ['handel'],
#  'strengthened': ['strenghtened'],
#  'temporarily': ['temporairly'],
#  'wire': ['wier'],
#  'drum': ['durm'],
#  'etc': ['ect'],
#  'conclude': ['conclued'],
#  'attainder': ['attaindre'],
#  'drink': ['drnik'],
#  'fielder': ['fiedler'],
#  'acknowledgement': ['acknowlegdement'],
#  'thief': ['theif'],
#  'recognition': ['recgonition', 'recongition'],
#  'literally': ['literlaly'],
#  'avoid': ['aviod'],
#  'does': ['dose'],
#  'therapists': ['threapists'],
#  'schedule': ['scheduel'],
#  'problem': ['porblem', 'probelm'],
#  'recognize': ['recongize'],
#  'lately': ['latley'],
#  'February': ['Feburary'],
#  'searched': ['searchde', 'saerched'],
#  'worth': ['worht'],
#  'women': ['woemn'],
#  'chapel': ['chaple'],
#  'triumph': ['truimph', 'trimuph', 'tirumph'],
#  'midsummer': ['midsummer'],
#  'Tuesday': ['Teusday', 'Tuseday'],
#  'work': ['wokr', 'wrok', 'owrk'],
#  'eclipse': ['eclispe'],
#  'ere': ['eer'],
#  'provide': ['provied'],
#  'interview': ['interveiw'],
#  'disappoint': ['disappiont'],
#  'order': ['oredr'],
#  'standard': ['stnadard'],
#  'approximately': ['approxmiately'],
#  'iron': ['iorn'],
#  'rewrite': ['rewriet'],
#  'manner': ['amnner'],
#  'stomach': ['stoamch'],
#  'strengthening': ['strenghtening'],
#  'strength': ['strenght'],
#  'Christian': ['Christain'],
#  'convenient': ['conveinent'],
#  'calculated': ['caluclated'],
#  'alumni': ['alumin'],
#  'aunt': ['anut'],
#  'European': ['Eurpoean'],
#  'just': ['jsut'],
#  'leisure': ['liesure', 'lesiure'],
#  'happiest': ['happeist'],
#  'cattle': ['cattel'],
#  'away': ['awya'],
#  'gentleman': ['gentelman'],
#  'unable': ['unabel'],
#  'shields': ['sheilds'],
#  'received': ['recieved'],
#  'Britain': ['Britian'],
#  'receives': ['recieves'],
#  'receiver': ['reciever'],
#  'trunk': ['turnk'],
#  'seizure': ['siezure'],
#  'girls': ['grils'],
#  'mountainous': ['mountianous'],
#  'client': ['cleint'],
#  'the': ['teh', 'hte'],
#  'swears': ['swaers'],
#  'night': ['nigth'],
#  'born': ['bron'],
#  'hassle': ['hassel'],
#  'purple': ['purpel'],
#  'illustration': ['illustartion'],
#  'prisoners': ['prsioners'],
#  'segment': ['segemnt'],
#  'fight': ['figth'],
#  'clinical': ['clincial'],
#  'peninsula': ['pennisula'],
#  'together': ['togehter'],
#  'battle': ['battel'],
#  'permanently': ['permannetly'],
#  'perceived': ['percieved'],
#  'discrete': ['discreet'],
#  'regained': ['regianed'],
#  'trial': ['trail'],
#  'sincerely': ['sincerley'],
#  'angels': ['angles'],
#  'dedicated': ['dedciated'],
#  'write': ['wriet', 'rwite'],
#  'southern': ['southren'],
#  'flourish': ['fluorish'],
#  'remember': ['remmeber', 'remebmer'],
#  'birds': ['brids'],
#  'half': ['hlaf'],
#  'not': ['nto', 'ont'],
#  'entirely': ['entierly'],
#  'year': ['yera', 'eyar'],
#  'epistle': ['epistel', 'epislte'],
#  'receiving': ['recieving'],
#  'inevitably': ['ineviatbly'],
#  'honest': ['hoenst'],
#  'directly': ['driectly'],
#  'friend': ['firend', 'freind', 'frined'],
#  'that': ['thta', 'taht'],
#  'angel': ['angle'],
#  'dream': ['deram'],
#  'premiered': ['premeired'],
#  'only': ['onyl', 'olny'],
#  'July': ['Jluy'],
#  'sport': ['sprot'],
#  'article': ['articel'],
#  'homely': ['homley'],
#  'these': ['thees'],
#  'ship': ['sihp'],
#  'gentlemen': ['gentelmen'],
#  'noble': ['nobel'],
#  'centuries': ['centruies'],
#  'fruit': ['furit', 'friut'],
#  'valuable': ['valubale'],
#  'thinking': ['thikning'],
#  'real': ['rela'],
#  'spectacular': ['spectauclar'],
#  'read': ['raed'],
#  'specimen': ['sepcimen'],
#  'heightened': ['hieghtened'],
#  'business': ['buisness'],
#  'start': ['strat'],
#  'pitcher': ['picther'],
#  'trying': ['triyng'],
#  'drift': ['dirft'],
#  'whistling': ['whitsling', 'whislting'],
#  'building': ['biulding'],
#  'safety': ['saftey'],
#  'very': ['vrey', 'veyr'],
#  'conscience': ['consceince', 'consicence', 'concsience'],
#  'family': ['famliy'],
#  'takes': ['tkaes'],
#  'history': ['histroy'],
#  'tried': ['tride'],
#  'inconceivable': ['inconcievable'],
#  'telephoned': ['telehponed'],
#  'hierarchy': ['heirarchy'],
#  'environmentally': ['enviornmentally'],
#  'have': ['hvae', 'haev', 'ahve'],
#  'fairy': ['fariy'],
#  'is': ['si'],
#  'since': ['sicne'],
#  'fountain': ['fountian'],
#  'primaeval': ['primeaval'],
#  'dirt': ['drit'],
#  'unresolved': ['unresloved'],
#  'maple': ['mapel'],
#  'horse': ['hores'],
#  'station': ['staiton'],
#  'hundred': ['hunderd'],
#  'storm': ['strom'],
#  'toward': ['towrad'],
#  'juice': ['jucie'],
#  'comparisons': ['compariosns'],
#  'clear': ['clera', 'claer'],
#  'completion': ['compeltion'],
#  'pilot': ['piolt', 'pliot'],
#  'muscles': ['muscels'],
#  'conditions': ['conditoins'],
#  'archaeologists': ['archeaologists'],
#  'would': ['woudl'],
#  'liked': ['liekd'],
#  'vessel': ['vessle'],
#  'Mayfield': ['Mayfeild'],
#  'while': ['hwile'],
#  'cemetery': ['cemetrey'],
#  'signal': ['singal'],
#  'some': ['smoe', 'soem'],
#  'subtract': ['subtrcat'],
#  'abroad': ['abraod'],
#  'besieged': ['beseiged'],
#  'collapsed': ['collasped'],
#  'frost': ['forst'],
#  'structure': ['structrue'],
#  'friendly': ['freindly'],
#  'America': ['Amercia'],
#  'melancholy': ['melancohly'],
#  'were': ['wree', 'weer'],
#  'penalty': ['penatly'],
#  'unilaterally': ['unilatreally'],
#  'Wednesday': ['Wedensday'],
#  'starter': ['strater'],
#  'ride': ['ried'],
#  'meet': ['mete'],
#  'poetry': ['peotry', 'potery', 'poerty'],
#  'files': ['fiels'],
#  'Two': ['Tow'],
#  'university': ['univeristy'],
#  'slide': ['slied'],
#  'crossing': ['corssing'],
#  'special': ['speical', 'specail'],
#  'achievements': ['acheivements'],
#  'geometry': ['geomtery'],
#  'quality': ['quailty'],
#  'ankle': ['ankel'],
#  'final': ['fianl'],
#  'exactly': ['excatly'],
#  'lists': ['lsits'],
#  'herself': ['herslef'],
#  'need': ['ened', 'nede'],
#  'able': ['abel'],
#  'sewing': ['sweing'],
#  'gallery': ['gallrey'],
#  'scrambled': ['scrambeld'],
#  'soldiers': ['soliders'],
#  'shoes': ['shose'],
#  'tire': ['tier'],
#  'employer': ['empolyer'],
#  'fuel': ['fule'],
#  'achieve': ['acheive'],
#  'Austrian': ['Austrain'],
#  'computer': ['comupter'],
#  'neither': ['niether'],
#  'poem': ['peom', 'pome'],
#  'league': ['leauge'],
#  'fierce': ['feirce'],
#  'scarcely': ['scracely', 'scarcley', 'scarecly'],
#  'dose': ['does'],
#  'coordination': ['coordiantion'],
#  'immediately': ['immediatley'],
#  'lost': ['lots'],
#  'kettle': ['kettel'],
#  'cradle': ['cradel'],
#  'medieval': ['medeival'],
#  'April': ['Apirl'],
#  'equally': ['eqaully'],
#  'strategy': ['startegy'],
#  'museum': ['muesum'],
#  'grieve': ['greive'],
#  'signed': ['singed'],
#  'piece': ['peice'],
#  'friends': ['freinds', 'firends', 'frineds'],
#  'captain': ['captian'],
#  'calculate': ['caluclate'],
#  'lights': ['ligths'],
#  'are': ['rae', 'aer'],
#  'interpret': ['interprte'],
#  'suitable': ['siutable'],
#  'unforgettable': ['unforgettalbe'],
#  'answer': ['anwser', 'asnwer'],
#  'third': ['thrid'],
#  'before': ['befoer'],
#  'unemployed': ['unempolyed'],
#  'went': ['wetn', 'wnet'],
#  'principles': ['principels'],
#  'taught': ['tuaght'],
#  'forgot': ['frogot'],
#  'deceived': ['decieved'],
#  'starts': ['starst'],
#  'immensely': ['immensley'],
#  'ditch': ['dicth'],
#  'fiery': ['firey'],
#  'peculiar': ['pecuilar'],
#  'wielded': ['weilded'],
#  'seed': ['sede'],
#  'seem': ['seme'],
#  'niece': ['neice'],
#  'regular': ['regluar'],
#  'retire': ['retier'],
#  'stop': ['stpo'],
#  'perceive': ['preceive', 'percieve'],
#  'coast': ['caost'],
#  'fields': ['fileds'],
#  'said': ['siad'],
#  'scrap': ['scarp'],
#  'maneuvers': ['manuevers'],
#  'against': ['agianst'],
#  'guaranteed': ['gauranteed'],
#  'height': ['heigth', 'hieght'],
#  'hygiene': ['hygeine'],
#  'three': ['there'],
#  'lovely': ['lovley'],
#  'aeroplane': ['areoplane', 'earoplane'],
#  'employees': ['empolyees', 'employese', 'employees'],
#  'mouse': ['moues'],
#  'make': ['amke', 'mkae'],
#  'left': ['lfet'],
#  'Blitzkrieg': ['Blitzkreig'],
#  'dreams': ['dreasm'],
#  'deal': ['dael'],
#  'dear': ['daer'],
#  'amiable': ['aimable'],
#  'burn': ['brun'],
#  'sleigh': ['sliegh'],
#  'flourishes': ['fluorishes'],
#  'down': ['donw', 'dwon'],
#  'lies': ['lise'],
#  'annoyance': ['anonyance'],
#  'approximate': ['approxiamte'],
#  'form': ['from', 'fomr'],
#  'died': ['dide', 'deid'],
#  'relieve': ['releive'],
#  'finally': ['fianlly'],
#  'item': ['tiem'],
#  'round': ['ronud'],
#  'talked': ['talekd'],
#  'international': ['niternational'],
#  'guardian': ['gaurdian', 'guardain'],
#  'conveniently': ['conveinently'],
#  'flexibility': ['felxibility'],
#  'uncritical': ['uncritiacl'],
#  'soup': ['suop'],
#  'making': ['amking', 'mkaing'],
#  'sample': ['sampel'],
#  'chemical': ['chemcial'],
#  'persuasion': ['persausion'],
#  'designed': ['desgined', 'desinged'],
#  'grow': ['grwo'],
#  'deceive': ['decieve'],
#  'shield': ['sheild'],
#  'pitch': ['picth'],
#  'attorneys': ['attornyes'],
#  'scheme': ['scheem'],
#  'girl': ['gril'],
#  'language': ['langauge'],
#  'thing': ['thign', 'thnig'],
#  'think': ['thikn'],
#  'first': ['firts', 'frist'],
#  'sounds': ['soudns'],
#  'little': ['littel'],
#  'accurately': ['accruately'],
#  'scraping': ['scarping'],
#  'speakers': ['spaekers'],
#  'especially': ['especailly', 'espeically'],
#  'show': ['sohw'],
#  'corner': ['croner'],
#  'label': ['lable'],
#  'pharaohs': ['pharoahs'],
#  'yield': ['yeild'],
#  'disappointment': ['disappiontment'],
#  'attaching': ['atatching'],
#  'acre': ['acer'],
#  'wake': ['waek'],
#  'encapsulation': ['encapsualtion'],
#  'those': ['thoes', 'thsoe'],
#  'sound': ['soudn', 'sonud'],
#  'then': ['thne'],
#  'sprained': ['sprianed'],
#  'effluence': ['effulence'],
#  'same': ['smae'],
#  'drain': ['drian'],
#  'solve': ['slove'],
#  'bottle': ['bottel'],
#  'money': ['moeny'],
#  'knife': ['kinfe'],
#  'violence': ['voilence', 'viloence'],
#  'road': ['raod'],
#  'quietly': ['quitely'],
#  'imagination': ['imaginaiton'],
#  'deem': ['deme'],
#  'file': ['fiel'],
#  'film': ['flim'],
#  'tedious': ['tediuos'],
#  'again': ['agian'],
#  'field': ['filed', 'feild'],
#  'important': ['importnat'],
#  'tackle': ['tackel'],
#  'represent': ['repersent'],
#  'preserved': ['perserved'],
#  'further': ['furhter'],
#  'affectionately': ['affectionatley'],
#  'table': ['tabel'],
#  'enmity': ['emnity'],
#  'two': ['tow'],
#  'achieving': ['acheiving'],
#  'diamond': ['daimond'],
#  'sylph': ['slyph'],
#  'particular': ['partciular'],
#  'town': ['twon'],
#  'recall': ['reacll'],
#  'guards': ['gaurds'],
#  'strategies': ['startegies'],
#  'marble': ['marbel'],
#  'minimum': ['minmium'],
#  'receptacle': ['receptacel'],
#  'entry': ['netry'],
#  'biscuits': ['bisciuts'],
#  'house': ['houes'],
#  'idea': ['diea', 'idae'],
#  'done': ['doen', 'odne'],
#  'believe': ['beleive'],
#  'mountain': ['mountian'],
#  'built': ['biult'],
#  'build': ['biuld'],
#  'extremely': ['extreemly'],
#  'weigh': ['wiegh'],
#  'networks': ['netowrks'],
#  'giant': ['gaint'],
#  'permission': ['premission'],
#  'express': ['experss'],
#  'individual': ['individula'],
#  'repairs': ['reparis'],
#  'myriad': ['myraid'],
#  'burned': ['bruned'],
#  'restaurant': ['restuarant'],
#  'foreign': ['foriegn'],
#  'simple': ['simpel'],
#  'pierce': ['peirce'],
#  'talking': ['tlaking'],
#  'century': ['centruy'],
#  'itself': ['itslef'],
#  'rheumatism': ['rhuematism', 'rehumatism'],
#  'chemistry': ['chemsitry'],
#  'circling': ['cirlcing'],
#  'judgement': ['jugdement'],
#  'absolutely': ['absolutley'],
#  'magnificent': ['maginficent'],
#  'back': ['bcak', 'bakc'],
#  'candle': ['candel'],
#  'acquaintance': ['acquiantance'],
#  'jewelry': ['jewlery'],
#  'audience': ['audeince'],
#  'bored': ['borde'],
#  'constant': ['constatn'],
#  'single': ['singel'],
#  'ascertained': ['acsertained'],
#  'anywhere': ['anyhwere'],
#  'asteroid': ['asteriod'],
#  'train': ['trani', 'trian'],
#  'correspond': ['correspond'],
#  'tickled': ['tickeld'],
#  'greater': ['gretaer'],
#  'receipts': ['reciepts'],
#  'strategic': ['startegic'],
#  'ancient': ['anceint'],
#  'environmental': ['enviornmental'],
#  'visited': ['vistied'],
#  'exists': ['exsits'],
#  'taking': ['tkaing'],
#  'curtain': ['curtian'],
#  'value': ['vaule'],
#  'almost': ['almsot', 'alomst'],
#  'portray': ['protray'],
#  'casualty': ['casulaty'],
#  'latest': ['latets'],
#  'Friday': ['Firday'],
#  'like': ['liek'],
#  'kaleidoscope': ['kaliedoscope'],
#  'hair': ['hiar'],
#  'hose': ['hoes'],
#  'noisy': ['nosiy', 'niosy'],
#  'about': ['abuot', 'baout'],
#  'socks': ['scoks'],
#  'minutes': ['minuets'],
#  'bundle': ['bundel'],
#  'appetite': ['apeptite'],
#  'pride': ['pried'],
#  'conjecture': ['conjecutre'],
#  'every': ['evrey', 'eveyr'],
#  'school': ['shcool'],
#  'conceive': ['concieve'],
#  'bicycle': ['bicycel', 'bicylce'],
#  'blue': ['bleu', 'bule'],
#  'solemn': ['solmen'],
#  'poison': ['posion'],
#  'mischievous': ['mischeivous'],
#  'grief': ['greif'],
#  'casualties': ['casulaties'],
#  'join': ['jion'],
#  'Poem': ['Pome'],
#  'unilateral': ['unilatreal'],
#  'guarantee': ['gaurantee'],
#  'enquire': ['enquier'],
#  'gate': ['gaet'],
#  'parallel': ['paralell'],
#  'jungle': ['jungel'],
#  'archaeology': ['archaoelogy'],
#  'writing': ['wirting'],
#  'strand': ['strnad'],
#  'Judaism': ['Juadism'],
#  'potatoes': ['potateos'],
#  'choir': ['chior'],
#  'toroidal': ['toriodal'],
#  'forfeit': ['forfiet'],
#  'associate': ['associate'],
#  'wanted': ['wnated'],
#  'already': ['alreayd'],
#  'curtains': ['curtians'],
#  'ceiling': ['cieling'],
#  'bridge': ['birdge', 'brigde'],
#  'radio': ['raido'],
#  'queer': ['quere'],
#  'lodge': ['logde', 'lodeg'],
#  'watch': ['wacth'],
#  'countries': ['ocuntries'],
#  'accede': ['acceed'],
#  'capacity': ['capaicty'],
#  'approach': ['appraoch'],
#  'maudlin': ['mauldin'],
#  'been': ['bene'],
#  'bible': ['bibel'],
#  'precede': ['preceed'],
#  'procedure': ['proceduer'],
#  'Champagne': ['Champange'],
#  'khaki': ['kahki'],
#  'corn': ['cron'],
#  'puzzle': ['puzzel'],
#  'fought': ['fougth'],
#  'head': ['haed'],
#  'amateur': ['amatuer'],
#  'libel': ['lible'],
#  'heinous': ['hienous'],
#  'hear': ['haer'],
#  'more': ['mroe', 'omre'],
#  'radically': ['radiaclly'],
#  'no': ['on'],
#  'commercials': ['commerciasl'],
#  'yacht': ['yahct'],
#  'environment': ['enviornment'],
#  'level': ['levle'],
#  'brother': ['borther'],
#  'pork': ['prok'],
#  'says': ['sasy', 'syas'],
#  'goes': ['gose'],
#  'birthday': ['brithday'],
#  'mainly': ['mianly'],
#  'lonely': ['lonley'],
#  'sprinkle': ['sprinkel'],
#  'thirty': ['thrity'],
#  'maneuver': ['manuever'],
#  'virtues': ['virtuse'],
#  'turn': ['trun'],
#  'place': ['palce'],
#  'necessarily': ['necessairly'],
#  'copy': ['cpoy'],
#  'require': ['requier'],
#  'ideas': ['idesa', 'idaes'],
#  'sorority': ['sorroity'],
#  'clearer': ['claerer'],
#  'uncle': ['unlce'],
#  'senior': ['seinor'],
#  'believing': ['beleiving'],
#  'hedge': ['hegde'],
#  'penguins': ['pengiuns'],
#  'unusually': ['unusaully'],
#  'efficiency': ['efficeincy'],
#  'region': ['reigon'],
#  'quiet': ['quite'],
#  'period': ['peroid'],
#  'Note': ['Noet'],
#  'engine': ['enigne'],
#  'direction': ['directoin'],
#  'week': ['week'],
#  'refusal': ['refusla'],
#  'driven': ['dirven'],
#  'changing': ['chnaging'],
#  'relief': ['reilef', 'relife', 'releif'],
#  'model': ['modle'],
#  'when': ['wehn'],
#  'rose': ['roes'],
#  'thimble': ['thimbel'],
#  'loaned': ['laoned'],
#  'communicate': ['communciate'],
#  'on': ['no'],
#  'of': ['fo'],
#  'adders': ['addres'],
#  'communication': ['communciation'],
#  'mischief': ['mischeif'],
#  'britain': ['britian'],
#  'wife': ['wief'],
#  'settlement': ['settelment'],
#  'opportunities': ['opprotunities'],
#  'dairy': ['diary'],
#  'worse': ['wosre'],
#  'awful': ['awufl'],
#  'list': ['lits'],
#  'tea': ['tae'],
#  'brief': ['breif'],
#  'version': ['verison'],
#  'ruffle': ['ruffel'],
#  'deities': ['dieties'],
#  'proceed': ['procede'],
#  'wield': ['weild'],
#  'pervaded': ['prevaded'],
#  'wretched': ['wrecthed'],
#  'knows': ['konws', 'knwos'],
#  'basically': ['baiscally'],
#  'plagiarism': ['plaigarism'],
#  'occasionally': ['occaisonally'],
#  'avenue': ['aveune'],
#  'environmentalist': ['enviornmentalist'],
#  'might': ['migth'],
#  'friendship': ['freindship'],
#  'weight': ['wieght', 'weigth'],
#  'Joseph': ['Jospeh'],
#  'prejudice': ['perjudice', 'prejduice'],
#  'bushel': ['bushle'],
#  'story': ['stroy', 'sotry', 'stoyr'],
#  'temperature': ['tempreature'],
#  'script': ['scirpt'],
#  'relieved': ['releived'],
#  'hotel': ['hotle'],
#  'strengthen': ['strenghten'],
#  'tired': ['tried'],
#  'chairman': ['chariman'],
#  'inconvenience': ['inconveneince', 'inconveinence'],
#  'achievement': ['acheivement'],
#  'asphalt': ['ashpalt'],
#  'compiler': ['complier'],
#  'nickelodeon': ['nickleodeon'],
#  'wrote': ['wroet'],
#  'achieved': ['acheived'],
#  'achieves': ['acheives'],
#  'barn': ['bran'],
#  'learns': ['lerans'],
#  'various': ['vairous'],
#  'cancelling': ['cancelling'],
#  'succeed': ['succede'],
#  'flight': ['filght'],
#  'engineers': ['egnineers'],
#  'Italy': ['Itlay'],
#  'chauffeur': ['chauffuer'],
#  'weird': ['wierd'],
#  'analysis': ['anaylsis', 'anlaysis'],
#  'edge': ['egde'],
#  'saucer': ['sacuer', 'suacer'],
#  'altimeter': ['atlimeter', 'altimetre'],
#  'violins': ['voilins'],
#  'extraordinary': ['extarordinary', 'extroardinary'],
#  'perform': ['preform'],
#  'cloth': ['colth'],
#  'junior': ['junoir', 'juinor'],
#  'associated': ['assocaited'],
#  'jobcentre': ['jobcenter'],
#  'weights': ['weigths'],
#  'stable': ['stabel'],
#  'include': ['inclued'],
#  'seized': ['siezed'],
#  'folk': ['fokl'],
#  'universities': ['univeristies'],
#  'find': ['fidn'],
#  'perforation': ['preforation'],
#  'pickle': ['pickel'],
#  'initials': ['initails'],
#  'shovel': ['shovle'],
#  'apple': ['appel'],
#  'from': ['form'],
#  'frog': ['forg'],
#  'examination': ['examiantion'],
#  'saddle': ['saddel'],
#  'accrued': ['accrude', 'accured'],
#  'villain': ['villian'],
#  'buoyant': ['bouyant'],
#  'unbeliever': ['unbeleiver'],
#  'holiday': ['hoilday'],
#  'disaggregate': ['disaggreagte'],
#  'galvanized': ['galvanzied'],
#  'their': ['theri', 'thier'],
#  'afraid': ['afriad'],
#  'angle': ['angel'],
#  'which': ['whihc', 'whcih'],
#  'centre': ['center'],
#  'who': ['hwo', 'woh'],
#  'movie': ['movei'],
#  'piano': ['pinao', 'paino'],
#  'midnight': ['midnigth'],
#  'married': ['marride', 'marreid'],
#  'view': ['veiw'],
#  'available': ['avaliable'],
#  'violet': ['voilet'],
#  'guildhall': ['giuldhall'],
#  'genius': ['genuis'],
#  'stories': ['storeis', 'storise'],
#  'agencies': ['agenices'],
#  'environments': ['enviornments'],
#  'nickel': ['nickle'],
#  'last': ['lats', 'lsat'],
#  'will': ['iwll'],
#  'perhaps': ['perhasp', 'perhpas'],
#  'grandeur': ['granduer'],
#  'premiere': ['premeire'],
#  'conceived': ['concieved'],
#  'summerhouse': ['summerhouse'],
#  'whole': ['wohle', 'hwole'],
#  'fighting': ['figthing'],
#  'firstly': ['fisrtly'],
#  'cried': ['cride'],
#  'toilets': ['tiolets'],
#  'know': ['nkow', 'konw', 'knwo'],
#  'perpetual': ['prepetual'],
#  'exceed': ['excede'],
#  'because': ['becuase', 'becasue', 'becaues', 'beacuse'],
#  'employment': ['empolyment'],
#  'swear': ['swaer'],
#  'owl': ['olw'],
#  'own': ['onw'],
#  'secret': ['secert'],
#  'deuce': ['duece'],
#  'distract': ['distarct'],
#  'record': ['recrod'],
#  'happen': ['ahppen'],
#  'other': ['otehr'],
#  'marshland': ['marshladn']}

# %%
substitution_
# Out:
# {'looking': ['locking'],
#  'eligible': ['eligable'],
#  'electricity': ['electrisity', 'electrizity'],
#  'scold': ['skold'],
#  'adaptable': ['adabtable'],
#  'swivel': ['swival'],
#  'fur': ['fer'],
#  'disturb': ['desturb'],
#  'prize': ['prise'],
#  'second': ['secand', 'secund'],
#  'cooking': ['kooking', 'cocking'],
#  'increasing': ['increacing',
#   'incressing',
#   'increesing',
#   'increaseng',
#   'encreasing',
#   'incriasing'],
#  'dahl': ['dael'],
#  'reporter': ['reportor'],
#  'here': ['hare', 'hera', 'herd', 'hire'],
#  'elaborate': ['elaberate'],
#  'controversy': ['controvercy', 'contriversy', 'contraversy', 'contreversy'],
#  'snowing': ['showing'],
#  'military': ['milatary', 'militery'],
#  'cancellation': ['cansellation',
#   'cancallation',
#   'cancillation',
#   'cancealation'],
#  'criticism': ['critigism',
#   'griticism',
#   'critisism',
#   'criticiam',
#   'criticise',
#   'critizism',
#   'criticizm'],
#  'golden': ['goldin'],
#  'divide': ['devide'],
#  'explained': ['explanned'],
#  'telegraph': ['telagraph'],
#  'successful': ['sucsessful', 'suxcessful', 'suckessful', 'succeshful'],
#  'hurt': ['hert'],
#  'glass': ['glars'],
#  'reversible': ['reversable'],
#  'hole': ['hold'],
#  'pursue': ['persue'],
#  'apologetics': ['apolegetics'],
#  'example': ['exemple'],
#  'artillery': ['artillary'],
#  'organized': ['orginized'],
#  'caution': ['causion'],
#  'want': ['wont', 'mant', 'wand', 'went'],
#  'hog': ['hag'],
#  'hoe': ['how'],
#  'damage': ['damuge', 'damaze', 'danage'],
#  'machine': ['machane', 'mechine', 'mashine'],
#  'how': ['hou', 'haw'],
#  'hot': ['hat'],
#  'wrong': ['wrang'],
#  'effective': ['affective'],
#  'signatories': ['signitories'],
#  'orally': ['erally'],
#  'misdemeanor': ['misdameanor'],
#  'nazareth': ['nazereth'],
#  'fir': ['fur'],
#  'fit': ['fid'],
#  'survivors': ['survivers'],
#  'insubstantial': ['insubstancial'],
#  'him': ['his', 'ham', 'hem', 'hin'],
#  'scholar': ['scholer'],
#  'obdurate': ['obdirate'],
#  'financial': ['finantial', 'financual'],
#  'spider': ['spiter'],
#  'turnip': ['turnup'],
#  'laboratory': ['laboretory',
#   'labaratory',
#   'lavoratory',
#   'laboritory',
#   'laborotory',
#   'laborbtory',
#   'laberatory'],
#  'encourage': ['incourage'],
#  'engineer': ['engeneer'],
#  'foundation': ['foundition'],
#  'surveys': ['survays'],
#  'sheet': ['sheat'],
#  'estimate': ['estamate'],
#  'ate': ['ete'],
#  'reprimanded': ['repremanded'],
#  'wash': ['wach', 'wosh'],
#  'instruct': ['instruck'],
#  'basketball': ['basketball', 'basketbale', 'baskitball'],
#  'service': ['survice', 'servise', 'servace'],
#  'needed': ['nedded', 'neaded'],
#  'architect': ['archetect'],
#  'geneva': ['geniva'],
#  'crawl': ['crall'],
#  'sidereal': ['sedereal'],
#  'omnivorous': ['omniverous'],
#  'project': ['progect', 'projent'],
#  'pneumonia': ['pneimonia',
#   'pneunonia',
#   'pheumonia',
#   'pheumonia',
#   'pneumunia',
#   'pneomonia'],
#  'seminary': ['seminery'],
#  'feeling': ['felling', 'fealing'],
#  'dozen': ['doxen', 'dosen'],
#  'responsible': ['responsable', 'responcible'],
#  'doors': ['doers'],
#  'responsibly': ['responsably'],
#  'shall': ['shale'],
#  'professor': ['professer'],
#  'camp': ['kamp', 'canp'],
#  'scream': ['screem'],
#  'marvel': ['marval'],
#  'polypropylene': ['polypropalene'],
#  'bomb': ['bome', 'bomm'],
#  'gauge': ['garge', 'gange', 'cauge', 'gaige', 'gadge', 'gaoge'],
#  'lessons': ['lessens', 'leasons'],
#  'busy': ['bisy'],
#  'than': ['then', 'that'],
#  'bush': ['buch'],
#  'touched': ['toughed', 'toached'],
#  'rich': ['rick'],
#  'rice': ['rise'],
#  'lady': ['lade'],
#  'plate': ['blate'],
#  'nicely': ['micely'],
#  'blew': ['blow'],
#  'nocturnal': ['nocternal'],
#  'best': ['bast', 'dest', 'beat', 'bist', 'besh', 'besd', 'mest', 'bess'],
#  'propagates': ['propogates'],
#  'score': ['skore'],
#  'never': ['newer', 'mever', 'naver', 'neven'],
#  'extend': ['extand'],
#  'nature': ['nuture'],
#  'invigorated': ['envigorated'],
#  'debt': ['dept', 'deat'],
#  'accident': ['axcident', 'accicent', 'acsident', 'ancident', 'accedent'],
#  'chirped': ['cherped'],
#  'country': ['coontry'],
#  'incense': ['insense'],
#  'levitating': ['levetating'],
#  'source': ['aource', 'sourse'],
#  'much': ['mush', 'mach'],
#  'privilege': ['privelege', 'previlege', 'privilage', 'privilige'],
#  'fry': ['fri'],
#  'incompetent': ['incompetant'],
#  'life': ['live', 'lefe'],
#  'wish': ['wich'],
#  'lift': ['left'],
#  'toboggan': ['taboggan', 'tobaggan', 'toboggen'],
#  'worked': ['worted'],
#  'spin': ['spen'],
#  'skilfully': ['skilfuley', 'scilfully'],
#  'employ': ['imploy'],
#  'anticipating': ['antecipating',
#   'anticepating',
#   'antisipating',
#   'anticapating'],
#  'oxymoron': ['oximoron'],
#  'damaged': ['damiged', 'damagtd', 'bamaged', 'dameged', 'danaged'],
#  'things': ['thinks'],
#  'babies': ['badies', 'babbes', 'babyes'],
#  'fairly': ['fairlu'],
#  'married': ['marriad'],
#  'academic': ['acedemic'],
#  'corporate': ['corparate'],
#  'capitol': ['capital'],
#  'distribute': ['distrubute'],
#  'sleepy': ['sleppy'],
#  'financially': ['finincially',
#   'finantially',
#   'financhally',
#   'financeally',
#   'financually'],
#  'previous': ['preveous'],
#  'purchased': ['perchased'],
#  'had': ['han', 'hab', 'hed', 'has', 'hat'],
#  'obedient': ['obediant'],
#  'innocent': ['innocent', 'innosent', 'innacent', 'innicent', 'ennocent'],
#  'prison': ['prisin', 'preson'],
#  'has': ['his', 'hos'],
#  'hat': ['hot'],
#  'possible': ['possibly', 'pissible', 'possable'],
#  'possibly': ['possably', 'possiply', 'possible'],
#  'birth': ['berth'],
#  'shadow': ['shodow'],
#  'unique': ['uneque'],
#  'desire': ['disire'],
#  'remind': ['remond', 'remied', 'remine', 'renind'],
#  'steps': ['staps'],
#  'prologue': ['prolague'],
#  'misdemeanors': ['misdameanors'],
#  'attorney': ['atterney', 'atturney'],
#  'old': ['ald', 'olf'],
#  'creek': ['creak'],
#  'crowd': ['croud'],
#  'people': ['peiple', 'peaple'],
#  'crown': ['croun'],
#  'insistence': ['insistance'],
#  'creep': ['creap'],
#  'enemies': ['enamies', 'enimies'],
#  'for': ['fur', 'far', 'fon'],
#  'bottom': ['bottem', 'botton'],
#  'memorable': ['memerable'],
#  'manufacturing': ['manufactoring'],
#  'dollars': ['dollers'],
#  'anomalous': ['anomolous'],
#  'despair': ['dispair'],
#  'feb': ['fab'],
#  'son': ['sun'],
#  'respectable': ['respectible'],
#  'sow': ['sew'],
#  'altitude': ['actitude', 'altitube', 'eltitude', 'altilude', 'altetude'],
#  'constantly': ['constently'],
#  'boy': ['buy', 'bay'],
#  'happy': ['happe', 'happi'],
#  'beech': ['beach'],
#  'congratulations': ['congrutulations',
#   'congralulations',
#   'congradulations',
#   'congretulations',
#   'congragulations',
#   'congratilations',
#   'congratalations'],
#  'genealogy': ['geneology'],
#  'else': ['elss'],
#  'unanimous': ['unanumous',
#   'unaninous',
#   'unanomous',
#   'unanamous',
#   'unanemous'],
#  'palm': ['parm'],
#  'passenger': ['passanger'],
#  'later': ['latey', 'lated'],
#  'tournament': ['tournanent',
#   'tournement',
#   'tourmament',
#   'tournamant',
#   'tourniment'],
#  'dealer': ['dealor'],
#  'negotiations': ['nogotiations',
#   'negatiations',
#   'negogiations',
#   'negociations',
#   'negosiations'],
#  'asterisk': ['asterick'],
#  'imminent': ['emminent'],
#  'scale': ['skale'],
#  'time': ['tame', 'tine'],
#  'push': ['puch'],
#  'chain': ['choin'],
#  'philosopher': ['philisopher'],
#  'mache': ['mashe'],
#  'cheap': ['cheep'],
#  'choice': ['choise'],
#  'minute': ['minite'],
#  'team': ['term', 'teem'],
#  'spiritual': ['speritual', 'spirttual', 'spiritial'],
#  'occurrence': ['occurrance'],
#  'sign': ['eign', 'sion'],
#  'essence': ['essense'],
#  'jeopardy': ['jeapardy'],
#  'melt': ['malt'],
#  'falling': ['folling'],
#  'understanding': ['understanting'],
#  'along': ['aling'],
#  'my': ['by', 'me', 'ma', 'mi', 'ny', 'by'],
#  'dusty': ['duste'],
#  'studied': ['studyed'],
#  'accomplished': ['aclomplished', 'apcomplished'],
#  'proclamation': ['proclomation'],
#  'prefer': ['prefor', 'profer', 'prefur'],
#  'marvelous': ['marvalous'],
#  'working': ['warking'],
#  'dangle': ['dongle'],
#  'vigour': ['vigeur'],
#  'opposed': ['apposed'],
#  'films': ['firms'],
#  'afford': ['affort', 'efford'],
#  'apparent': ['apparant', 'apperent'],
#  'virtue': ['vertue', 'vurtue'],
#  'originally': ['orrginally',
#   'oreginally',
#   'origenally',
#   'origanally',
#   'origonally',
#   'oridinally'],
#  'pretend': ['prutend',
#   'protend',
#   'pretent',
#   'bretend',
#   'pritend',
#   'predend',
#   'prelend'],
#  'printing': ['prenting'],
#  'sacrament': ['sacrement'],
#  'stole': ['stold'],
#  'evidently': ['evedently'],
#  'monitoring': ['monitering'],
#  'divided': ['devided'],
#  'thanking': ['thinking'],
#  'laundry': ['loundry'],
#  'spot': ['shot', 'srot', 'spat'],
#  'rehabilitate': ['rehabilatate'],
#  'date': ['dake', 'dute', 'datr', 'dade'],
#  'such': ['sach'],
#  'conscious': ['conicious'],
#  'ordinarily': ['ordanarily',
#   'ordinaryly',
#   'ordinarrly',
#   'ardinarily',
#   'ordinarlly',
#   'ordinarely',
#   'ordinaraly',
#   'ordinerily',
#   'ordinaroly',
#   'ordonarily'],
#  'definitions': ['defenitions'],
#  'flips': ['frips'],
#  'years': ['yeers'],
#  'course': ['coarse'],
#  'tendency': ['tendancy'],
#  'solitary': ['solatary'],
#  'torn': ['turn'],
#  'counsellor': ['councellor'],
#  'suspicion': ['suppicion',
#   'suspecion',
#   'suspition',
#   'suspician',
#   'suspision'],
#  'petition': ['petetion'],
#  'recipients': ['recepients', 'recipiants'],
#  'records': ['rocords'],
#  'handiwork': ['handywork'],
#  'shouted': ['shauted'],
#  'establishing': ['establashing',
#   'establisheng',
#   'estableshing',
#   'estaplishing',
#   'astablishing',
#   'istablishing'],
#  'stanley': ['stanlay'],
#  'sponsor': ['sponser'],
#  'canvas': ['canvis'],
#  'michigan': ['michagan'],
#  'investigation': ['investagation'],
#  'disintegrated': ['desintegrated'],
#  'striven': ['strived'],
#  'grandma': ['grandna'],
#  'poems': ['poams', 'poims', 'paems', 'porms'],
#  'training': ['tranning'],
#  'modest': ['modist'],
#  'recompense': ['recompence'],
#  'neglect': ['neclect'],
#  'emotion': ['emition'],
#  'symmetry': ['symmatry'],
#  'architecturally': ['archetecturally'],
#  'one': ['ome', 'ond', 'ont'],
#  'open': ['opin'],
#  'affords': ['effords'],
#  'city': ['sity', 'cite'],
#  'monday': ['munday'],
#  'indicate': ['indecate'],
#  'teacher': ['teather', 'teachur', 'teasher'],
#  'draft': ['deaft'],
#  'ridiculous': ['ridiculois',
#   'rudiculous',
#   'ridicilous',
#   'rideculous',
#   'rediculous'],
#  'folly': ['fooly', 'foley', 'fally'],
#  'coats': ['coots'],
#  'athenians': ['atheneans'],
#  'janitor': ['janiter'],
#  'turned': ['terned'],
#  'sad': ['sed'],
#  'prestigious': ['prestigeous'],
#  'buried': ['buriel', 'baried', 'buryed', 'beried', 'burred'],
#  'saw': ['sew', 'sow', 'san'],
#  'sat': ['set'],
#  'destroy': ['distroy'],
#  'encouraged': ['incouraged'],
#  'opposite': ['oppisite', 'oppasite', 'oppesite'],
#  'printed': ['prented'],
#  'pages': ['pagis'],
#  'adaptability': ['adaptibility'],
#  'lawn': ['lown'],
#  'average': ['avarage'],
#  'salt': ['solt'],
#  'walking': ['wolking', 'warking', 'wakking', 'wilking', 'wacking'],
#  'murmurs': ['murmers'],
#  'surplus': ['surples',
#   'serplus',
#   'surplas',
#   'surplis',
#   'surplut',
#   'sirplus',
#   'surplos'],
#  'infuriate': ['enfuriate'],
#  'scarce': ['scarse'],
#  'cloak': ['clock'],
#  'going': ['gying'],
#  'equipped': ['aquipped', 'equipted', 'iquipped'],
#  'freezing': ['freesing', 'freeding', 'frezzing'],
#  'resource': ['recource', 'resourse'],
#  'artist': ['artest'],
#  'borrow': ['barrow'],
#  'bombs': ['bomes'],
#  'liable': ['lyable'],
#  'where': ['there'],
#  'surgery': ['surgere'],
#  'jumped': ['jumper'],
#  'representatives': ['representitives'],
#  'dormitory': ['dormotory', 'dormatory', 'dormitary', 'dormetory'],
#  'kilometer': ['lilometer'],
#  'cantaloupe': ['cantaloube'],
#  'concentrate': ['consentrate'],
#  'spare': ['share', 'spere'],
#  'suppressed': ['surpressed'],
#  'concentrated': ['consentrated'],
#  'many': ['meny', 'mony'],
#  'personal': ['personel'],
#  'concentrates': ['consentrates'],
#  'allowance': ['allowence'],
#  'twin': ['twen'],
#  'considers': ['conciders'],
#  'comb': ['come'],
#  'stretch': ['streach'],
#  'vacation': ['vakation'],
#  'concede': ['consede'],
#  'practised': ['practiced'],
#  'enable': ['unable', 'anable'],
#  'thousand': ['thousend'],
#  'observe': ['obsirve'],
#  'former': ['farmer'],
#  'prominence': ['prominance'],
#  'easier': ['easyer'],
#  'purse': ['purce', 'perse'],
#  'vandalism': ['vandolism'],
#  'i': ['a', 'v', 'n'],
#  'vacant': ['vacent'],
#  'genii': ['genei'],
#  'grumpy': ['grumby'],
#  'rest': ['rast'],
#  'weekly': ['weakly'],
#  'instrument': ['instrement', 'instriment'],
#  'prominently': ['prominantly'],
#  'around': ['aroand', 'arownd'],
#  'dart': ['durt', 'daet', 'dard', 'tart', 'dert', 'dirt', 'dort'],
#  'dark': ['durk', 'dork', 'darw', 'dare', 'dard', 'dank'],
#  'traffic': ['traffig', 'traffik'],
#  'vacuum': ['vaccum'],
#  'world': ['would'],
#  'postal': ['postel'],
#  'satisfaction': ['satisfacsion',
#   'satesfaction',
#   'satitfaction',
#   'sitisfaction'],
#  'unrepentant': ['unrepentent'],
#  'stationary': ['stationery'],
#  'clap': ['klap'],
#  'auditorium': ['autitorium',
#   'additorium',
#   'auditarium',
#   'audetorium',
#   'audotorium',
#   'auditoriam',
#   'ouditorium',
#   'auditoryum',
#   'auditoriom',
#   'auditoreum',
#   'audatorium',
#   'auditoriun'],
#  'satisfactory': ['satisfactary'],
#  'superintendent': ['superintendant'],
#  'divine': ['divide', 'devine', 'divene'],
#  'memories': ['momories', 'memuries', 'merories', 'memoryes', 'memeries'],
#  'package': ['packege'],
#  'meal': ['mell'],
#  'act': ['akt'],
#  'luck': ['lock'],
#  'technically': ['technecally'],
#  'burglar': ['burgler'],
#  'her': ['hir', 'har'],
#  'impedance': ['impedence'],
#  'mice': ['mise'],
#  'with': ['wite', 'weth'],
#  'they': ['thay', 'thea', 'ther'],
#  'rush': ['ruch'],
#  'dirty': ['durty'],
#  'dispensing': ['dispencing'],
#  'gone': ['gome'],
#  'certain': ['curtain', 'sertain', 'cirtain'],
#  'am': ['an'],
#  'an': ['un', 'am', 'on'],
#  'as': ['is', 'at'],
#  'at': ['al', 'an', 'as'],
#  'creak': ['creek'],
#  'graduate': ['graguate'],
#  'unparalleled': ['unparelleled'],
#  'contemporaries': ['contamporaries'],
#  'congress': ['congress', 'cangress', 'comgress'],
#  'spermatozoon': ['spermatozoan'],
#  'tiger': ['tigar'],
#  'mask': ['mast'],
#  'original': ['origanal'],
#  'consider': ['concider', 'consiter'],
#  'beware': ['bewere'],
#  'hunting': ['hanting'],
#  'to': ['ro', 'th'],
#  'tail': ['tall'],
#  'case': ['cace'],
#  'debit': ['defit',
#   'debet',
#   'debat',
#   'devit',
#   'debot',
#   'depit',
#   'dibit',
#   'debut'],
#  'accompanying': ['accumpanying',
#   'occompanying',
#   'accomponying',
#   'accompanning'],
#  'toby': ['tobe'],
#  'dodged': ['dogged', 'lodged', 'dodjed', 'dooged', 'dodger'],
#  'dinosaur': ['dinasaur'],
#  'sand': ['sant'],
#  'sank': ['cank', 'sack', 'sant', 'sunk', 'sang', 'sane', 'sanc'],
#  'past': ['pass'],
#  'pass': ['pars'],
#  'canvass': ['canvase', 'canvaus', 'canfass', 'canvess'],
#  'poisonous': ['poisenous'],
#  'method': ['methed'],
#  'full': ['foll', 'fill', 'fall'],
#  'mad': ['nad'],
#  'experience': ['experiance'],
#  'prior': ['prier', 'pryor', 'priar', 'plior'],
#  'hamster': ['hapster'],
#  'followed': ['fellowed'],
#  'select': ['celect'],
#  'attendance': ['attendence'],
#  'gorgeous': ['gorgious', 'gordeous'],
#  'russian': ['russion'],
#  'door': ['boor', 'doar'],
#  'company': ['compeny'],
#  'cunning': ['conning'],
#  'keeping': ['kepping'],
#  'science': ['scienee'],
#  'sent': ['sant', 'send'],
#  'beautiful': ['beaotiful', 'beaufiful', 'beautyful'],
#  'accept': ['axcept'],
#  'sense': ['sence'],
#  'information': ['imformation', 'onformation', 'informasion'],
#  'program': ['progrom'],
#  'intended': ['inteaded', 'intented'],
#  'conveniences': ['conveniances'],
#  'refuse': ['refuce'],
#  'resemble': ['rezemble'],
#  'loud': ['load',
#   'loed',
#   'lowd',
#   'lond',
#   'lold',
#   'lord',
#   'lood',
#   'laud',
#   'louk',
#   'lour'],
#  'register': ['regester', 'registur'],
#  'rowdy': ['roudy'],
#  'fundamental': ['vundamental',
#   'fundumental',
#   'fundimental',
#   'fundemental',
#   'fundtmental',
#   'fundanental',
#   'fundamentel',
#   'fundomental'],
#  'replied': ['replyed'],
#  'incessantly': ['incessently'],
#  'trade': ['trede'],
#  'stylus': ['stilus'],
#  'attitude': ['attitide'],
#  'rapidly': ['rapedly'],
#  'triumph': ['triumpt', 'tryumph', 'triamph'],
#  'bypass': ['bipass'],
#  'colleague': ['colleaque'],
#  'pickerel': ['pickeral'],
#  'abandons': ['abondons'],
#  'prefect': ['prefact'],
#  'reticent': ['retecent'],
#  'spinning': ['skinning', 'spinging'],
#  'courses': ['cources', 'cousses'],
#  'found': ['fount'],
#  'lantern': ['lanturn'],
#  'reactions': ['reactioos'],
#  'catalogues': ['catologues'],
#  'reduce': ['reduse'],
#  'investigated': ['investegated'],
#  'penicillin': ['penecillin'],
#  'really': ['rearly'],
#  'try': ['tri'],
#  'psychology': ['psyciology', 'pcychology', 'phychology'],
#  'darling': ['dalling'],
#  'salute': ['sulute'],
#  'murmur': ['murmer'],
#  'definition': ['defenition'],
#  'misogyny': ['mysogyny'],
#  'octahedron': ['octohedron'],
#  'corrugated': ['corrigated'],
#  'number': ['nomber'],
#  'tadpoles': ['tadpolls'],
#  'introduction': ['incroduction', 'infroduction'],
#  'determined': ['detormined',
#   'deternined',
#   'determoned',
#   'detirmined',
#   'determened'],
#  'beneficial': ['benefician',
#   'benaficial',
#   'benificial',
#   'benefecial',
#   'bemeficial',
#   'feneficial',
#   'benefictal'],
#  'it': ['is', 'et', 'il', 'is'],
#  'sell': ['sall'],
#  'self': ['silf'],
#  'also': ['alss', 'olso'],
#  'without': ['wethout', 'wathout'],
#  'vividly': ['vididly', 'vivadly', 'vivedly'],
#  'plan': ['blan', 'plun', 'play', 'plar', 'glan', 'plen', 'plon'],
#  'oyster': ['oister'],
#  'cover': ['cuver'],
#  'despise': ['dispise'],
#  'factor': ['facter'],
#  'constituent': ['constituant'],
#  'remedy': ['remidy'],
#  'enemy': ['enimy', 'enamy', 'eneny', 'ememy'],
#  'sleeve': ['sleave'],
#  'strictest': ['strictist'],
#  'cry': ['cri'],
#  'kill': ['cill'],
#  'river': ['rever'],
#  'approaching': ['approsching', 'approuching'],
#  'set': ['sat'],
#  'sex': ['ses'],
#  'spirits': ['sperits'],
#  'guinea': ['guenea'],
#  'currently': ['curruntly'],
#  'compliment': ['complement'],
#  'gnawing': ['knawing'],
#  'sparsely': ['sparcely'],
#  'ripper': ['ripper'],
#  'coffee': ['coffer'],
#  'signatory': ['signitory'],
#  'dividend': ['divident', 'divedend'],
#  'legislature': ['legeslature'],
#  'improved': ['inproved'],
#  'influential': ['influencial'],
#  'connection': ['connextion'],
#  'let': ['lat'],
#  'blaze': ['blase'],
#  'pendulum': ['pendelum'],
#  'drunk': ['druck', 'dronk'],
#  'allegiance': ['allegience'],
#  'community': ['commonity', 'commenity', 'commuaity'],
#  'adaptation': ['adeptation'],
#  'church': ['chirch', 'cherch'],
#  'indefinite': ['indifinite',
#   'endefinite',
#   'indefenite',
#   'indefinete',
#   'indefinate'],
#  'belt': ['beat', 'delt', 'balt', 'bilt'],
#  'devil': ['devel'],
#  'conveyor': ['conveyer'],
#  'acceptance': ['acceptence'],
#  'initiation': ['inatiation',
#   'inisiation',
#   'inigiation',
#   'iniciation',
#   'enitiation',
#   'initistion'],
#  'firm': ['ferm'],
#  'champion': ['champian'],
#  'counselling': ['councelling'],
#  'fire': ['fine', 'fare', 'fige', 'firh', 'fird', 'firy'],
#  'what': ['woat', 'whot'],
#  'races': ['rases'],
#  'representative': ['representitive'],
#  'empirical': ['emperical'],
#  'technical': ['technicol',
#   'tectnical',
#   'tecknical',
#   'technecal',
#   'tecinical'],
#  'error': ['errow'],
#  'miss': ['mess'],
#  'scheduled': ['schedaled',
#   'skheduled',
#   'schedules',
#   'scheluled',
#   'schuduled'],
#  'calculator': ['calculater'],
#  'chase': ['chasr', 'chace'],
#  'funny': ['funey'],
#  'virtually': ['vertually'],
#  'ruler': ['roler'],
#  'survey': ['survay'],
#  'flooded': ['flodded'],
#  'comprehensive': ['comphehensive'],
#  'deformity': ['deformaty'],
#  'levels': ['levals'],
#  'cucumber': ['cucomber'],
#  'recent': ['resent'],
#  'residing': ['reciding'],
#  'person': ['percon', 'persen', 'peason', 'porson'],
#  'leone': ['lione'],
#  'telegram': ['telagram'],
#  'recommended': ['recogmended', 'recommented'],
#  'eager': ['eagar'],
#  'parents': ['parants'],
#  'relevance': ['relevence'],
#  'surprised': ['surprized'],
#  'shove': ['shuve'],
#  'emergency': ['emergancy'],
#  'oh': ['ow', 'ow'],
#  'emanating': ['eminating'],
#  'suffering': ['suufering'],
#  'consensus': ['concensus'],
#  'irresistibly': ['irresistably'],
#  'senate': ['senete'],
#  'curious': ['cerious', 'qurious', 'currous', 'furious', 'cureous'],
#  'irresistible': ['inresistible', 'irresistable'],
#  'religion': ['religeon'],
#  'be': ['me', 'pe', 'we', 'de', 'by'],
#  'by': ['be'],
#  'anything': ['anythink', 'enything', 'anytying'],
#  'appropriate': ['appropreate', 'approproate'],
#  'contributor': ['contributer'],
#  'criticisms': ['critisisms'],
#  'specifically': ['specifucally',
#   'spectfically',
#   'spesifically',
#   'specefically',
#   'spacifically'],
#  'considerably': ['considerable'],
#  'pastor': ['paster'],
#  'considerable': ['conciderable'],
#  'resistible': ['resistable'],
#  'us': ['as'],
#  'influence': ['influance'],
#  'presided': ['prisided'],
#  'diverged': ['diversed'],
#  'invalid': ['invilid'],
#  'occasional': ['accasional'],
#  'sailor': ['sailer'],
#  'scrub': ['skrub'],
#  'ago': ['ogo'],
#  'walked': ['waiked', 'warked', 'walket'],
#  'came': ['cane', 'kame', 'ceme', 'come'],
#  'hello': ['hallo', 'herlo'],
#  'partial': ['parsial', 'parcial'],
#  'renown': ['renoun'],
#  'concerned': ['conserned'],
#  'send': ['sand'],
#  'dyeing': ['dieing'],
#  'resources': ['recources'],
#  'categories': ['catagories'],
#  'anxious': ['ancious', 'anxioss', 'angious', 'ansious', 'anxisus'],
#  'race': ['rase'],
#  'pledge': ['pleage'],
#  'licensed': ['licenced'],
#  'temperate': ['temparate'],
#  'incidentally': ['incidenially',
#   'insidentally',
#   'incidintally',
#   'incedentally'],
#  'apparatus': ['apperatus', 'appuratus'],
#  'led': ['lad', 'lud', 'let'],
#  'leg': ['lag'],
#  'licence': ['license', 'lisence'],
#  'consideration': ['concideration', 'consideraiion'],
#  'untidiness': ['untideness'],
#  'vinegar': ['vinigar'],
#  'great': ['grent'],
#  'engage': ['ingage'],
#  'receive': ['receave'],
#  'defeat': ['defeet'],
#  'residents': ['recidents'],
#  'assemble': ['assemple'],
#  'sugar': ['suger'],
#  'confidence': ['confedence'],
#  'chocolates': ['chocalates'],
#  'next': ['nest', 'nexe'],
#  'duplicate': ['duplacate', 'dublicate'],
#  'doubt': ['daubt', 'doupt'],
#  'infamy': ['imfamy'],
#  'occurred': ['occureed'],
#  'baby': ['baba', 'babe'],
#  'charity': ['charaty'],
#  'customer': ['costomer',
#   'costomer',
#   'custamer',
#   'customar',
#   'custamer',
#   'costomer',
#   'custumer'],
#  'animals': ['aninals'],
#  'this': ['thus', 'thes'],
#  'challenge': ['challange'],
#  'thin': ['then', 'than'],
#  'drill': ['drile'],
#  'police': ['pollce', 'palice'],
#  'bent': ['bant'],
#  'bend': ['band'],
#  'christmas': ['christmis', 'christman'],
#  'ideology': ['idealogy'],
#  'delay': ['deley'],
#  'insistent': ['insistant'],
#  'intelligent': ['intellegent'],
#  'tied': ['tird', 'tind', 'tiad', 'tyed'],
#  'hawk': ['hark'],
#  'varied': ['vqried'],
#  'redundant': ['redundent'],
#  'volunteers': ['volonteers'],
#  'perfect': ['perfact'],
#  'mistletoe': ['mistlitoe'],
#  'dispose': ['despose'],
#  'lamp': ['lanp'],
#  'instruments': ['instrements',
#   'instrumants',
#   'instrumints',
#   'instroments',
#   'instriments'],
#  'animal': ['anamal'],
#  'cage': ['kage'],
#  'sufficiently': ['sufficiuntly',
#   'sufficienily',
#   'suffeciently',
#   'sufficiantly',
#   'sufficienlly'],
#  'delightful': ['dilightful'],
#  'truth': ['troth'],
#  'accompanied': ['accompanyed'],
#  'beneath': ['beneeth'],
#  'glasses': ['glasser'],
#  'doing': ['daing'],
#  'operator': ['operater', 'operatar', 'oparator'],
#  'thirteen': ['therteen'],
#  'agriculture': ['agraculture'],
#  'fundamentally': ['fundementally'],
#  'troop': ['troup'],
#  'shut': ['shud', 'shot', 'shit', 'shat'],
#  'steering': ['stearing'],
#  'log': ['lag'],
#  'could': ['sould'],
#  'put': ['pot', 'but', 'pht'],
#  'scare': ['skare'],
#  'occurrences': ['occurrances'],
#  'collages': ['colloges'],
#  'reference': ['referance'],
#  'festival': ['fistival'],
#  'system': ['sistem'],
#  'exhilarating': ['exhilirating'],
#  'efficiently': ['effeciently'],
#  'enforcement': ['inforcement'],
#  'stars': ['stare', 'stors'],
#  'steel': ['steal'],
#  'negatively': ['negitively'],
#  'steep': ['steap'],
#  'steer': ['stear'],
#  'beggar': ['begger'],
#  'viewed': ['vieved', 'vieded'],
#  'documents': ['dotuments',
#   'ducuments',
#   'docoments',
#   'doculents',
#   'dockments',
#   'docements',
#   'doctments',
#   'docunents'],
#  'dishes': ['diches'],
#  'studying': ['studiing'],
#  'persistence': ['persistance'],
#  'samaritan': ['samariton'],
#  'courtesy': ['caurtesy', 'courtisy', 'courtecy'],
#  'amongst': ['anongst'],
#  'device': ['divice'],
#  'medal': ['medel'],
#  'so-called': ['sa-called', 'so-colled'],
#  'face': ['fase'],
#  'you': ['yoy', 'yau', 'yow'],
#  'mechanical': ['machanical'],
#  'painting': ['paitting'],
#  'dependant': ['dependent'],
#  'vacancy': ['vacaney',
#   'vacance',
#   'vavancy',
#   'vaconcy',
#   'vacatcy',
#   'vacansy',
#   'vacuncy',
#   'vacincy',
#   'vacency'],
#  'infants': ['enfants', 'enfants'],
#  'bedroom': ['bedroon'],
#  'rough': ['rouch', 'roagh', 'routh'],
#  'trivial': ['triveal'],
#  'jar': ['jur', 'gar'],
#  'should': ['shound', 'shoold'],
#  'terminal': ['terminel'],
#  'planted': ['plarted'],
#  'means': ['meens'],
#  'familiar': ['fameliar', 'femiliar', 'fimiliar', 'familier'],
#  'prohibition': ['prohabition'],
#  'blackcurrants': ['blackcurrents'],
#  'committees': ['committies'],
#  'temporarily': ['temporaroly',
#   'temperarily',
#   'temporarely',
#   'temporalily',
#   'tempororily',
#   'temporarrly',
#   'tempararily',
#   'temporarlly',
#   'temporaryly'],
#  'edition': ['adition', 'edision'],
#  'nuclear': ['nucleur'],
#  'couturier': ['coururier'],
#  'derogatory': ['derogitory'],
#  'invited': ['envited'],
#  'drug': ['drog'],
#  'puff': ['poff'],
#  'carnivorous': ['carniverous'],
#  'neighbour': ['neighboor'],
#  'laser': ['luser'],
#  'digging': ['bigging', 'degging'],
#  'ball': ['boll'],
#  'upon': ['apon', 'opon'],
#  'proficiency': ['proficiensy'],
#  'dust': ['dost'],
#  'acknowledgement': ['ecknowledgement'],
#  'patterns': ['pattarns'],
#  'practise': ['practice'],
#  'increased': ['increases'],
#  'government': ['gobernment'],
#  'haul': ['hall'],
#  'desk': ['dest', 'dask'],
#  'descendant': ['descendent'],
#  'crisp': ['cresp'],
#  'garage': ['carage'],
#  'become': ['bacome', 'beeome'],
#  'amendment': ['amendmant'],
#  'ballot': ['ballet'],
#  'recognition': ['reconnition',
#   'recignition',
#   'recognetion',
#   'recegnition',
#   'recodnition',
#   'recoznition',
#   'recognation',
#   'recognision',
#   'recogmition'],
#  'literally': ['literally',
#   'laterally',
#   'leterally',
#   'literarly',
#   'literaley',
#   'liberally',
#   'liturally'],
#  'avoid': ['avoud',
#   'aviid',
#   'avoij',
#   'avoad',
#   'avoed',
#   'avord',
#   'ivoid',
#   'aveid',
#   'avoyd'],
#  'forgiven': ['forgivon'],
#  'biology': ['biolagy'],
#  'schedule': ['schudule', 'schedute', 'schedele', 'sckedule'],
#  'invertebrates': ['invertibrates'],
#  'imaginary': ['imaginery', 'imagenary'],
#  'tiny': ['tine', 'tinu'],
#  'bump': ['bunp', 'bumb'],
#  'specimens': ['specimans',
#   'specinens',
#   'specumens',
#   'specamens',
#   'spicimens',
#   'specimuns',
#   'specimins'],
#  'bicycle': ['bisycle', 'bickcle', 'bicicle', 'bicykle', 'bycycle'],
#  'places': ['plases'],
#  'placed': ['plased'],
#  'problem': ['preblem',
#   'prodlem',
#   'problum',
#   'problom',
#   'proplem',
#   'pronlem',
#   'problam',
#   'problen'],
#  'recognize': ['recognise'],
#  'ink': ['ing'],
#  'compared': ['compased'],
#  'illusion': ['illution'],
#  'footprints': ['foodprints'],
#  'chance': ['change', 'chanch'],
#  'searched': ['searcked'],
#  'rural': ['rurel', 'roral'],
#  'consolidated': ['consolodated'],
#  'desirable': ['desireble'],
#  'controversial': ['controvercial'],
#  'stinks': ['sticks'],
#  'worth': ['werth'],
#  'distort': ['distart'],
#  'women': ['wemen',
#   'wamen',
#   'wumen',
#   'wimen',
#   'womem',
#   'woman',
#   'womin',
#   'womon',
#   'wonen',
#   'wowen'],
#  'disobedient': ['disobediant'],
#  'chapel': ['chapal'],
#  'we': ['be'],
#  'exaggerate': ['exargerate'],
#  'chew': ['chow'],
#  'midsummer': ['midsummer'],
#  'sabbath': ['sabboth'],
#  'levitate': ['levetate'],
#  'alsatian': ['alsation'],
#  'above': ['obove', 'ubove', 'abuve', 'abofe', 'adove', 'abowe'],
#  'told': ['teld', 'toll'],
#  'pursuit': ['persuit'],
#  'celebration': ['celabration'],
#  'items': ['itims'],
#  'diameter': ['diamater', 'diamiter'],
#  'secure': ['sicure', 'sucure'],
#  'lavatory': ['labatory'],
#  'sweater': ['swetter', 'sweeter'],
#  'separated': ['seperated'],
#  'separates': ['seperates'],
#  'word': ['ward', 'wood'],
#  'war': ['wor'],
#  'work': ['wark', 'wolk', 'werk'],
#  'worn': ['warn'],
#  'ere': ['are', 'err', 'era'],
#  'elbow': ['albow'],
#  'disappoint': ['desappoint', 'disappoint'],
#  'ordinary': ['ordinery', 'ordenary'],
#  'beach': ['beech'],
#  'lay': ['lae'],
#  'appreciate': ['apprechate',
#   'apprehiate',
#   'appreceate',
#   'appresiate',
#   'apareciate',
#   'appriciate'],
#  'greet': ['great'],
#  'scarf': ['skarf'],
#  'ambulance': ['ambulence'],
#  'order': ['orter'],
#  'consent': ['concent'],
#  'satisfied': ['satisfyed'],
#  'mayor': ['mayer'],
#  'eventually': ['edentually',
#   'evantually',
#   'eventually',
#   'evintually',
#   'eventially',
#   'evencually',
#   'aventually'],
#  'them': ['then', 'tham'],
#  'safe': ['sate', 'save', 'saff', 'saft', 'safr'],
#  'band': ['bend'],
#  'oxygen': ['oxigen'],
#  'reasonably': ['reasinably', 'reasonable'],
#  'sled': ['slad'],
#  'medicine': ['medecine', 'medicene', 'medacine'],
#  'standard': ['standerd'],
#  'mutilate': ['mutalate'],
#  'lollipop': ['lollypop'],
#  'september': ['septenber'],
#  'oppose': ['appose'],
#  'organize': ['orginize', 'organise'],
#  'cooper': ['copper'],
#  'render': ['rander'],
#  'palestinian': ['palistinian'],
#  'synonymous': ['synonomous'],
#  'guatemalan': ['guatamalan'],
#  'another': ['anather', 'anuther'],
#  'confectionery': ['confectionary'],
#  'approximately': ['approxamately',
#   'approxomately',
#   'approcimately',
#   'approximitely'],
#  'compromise': ['comprimise'],
#  'happily': ['happaly'],
#  'corresponded': ['corrisponded'],
#  'stomach': ['stamach', 'stumach', 'stomuch', 'stomack', 'stomact', 'stomech'],
#  'forced': ['forsed'],
#  'convenient': ['convinient'],
#  'subjects': ['subjecks'],
#  'acquire': ['adquire'],
#  'anatomy': ['anotomy'],
#  'phase': ['phaze', 'phace', 'fhase'],
#  'grave': ['crave'],
#  'alumni': ['ilumni', 'alumna', 'alumny'],
#  'aunt': ['aint', 'arnt', 'annt'],
#  'fitted': ['fifted', 'fitten', 'finted', 'fisted'],
#  'reserve': ['resurve'],
#  'decidedly': ['decidadly',
#   'dicidedly',
#   'decididly',
#   'decidetly',
#   'decidelly',
#   'desidedly',
#   'decidealy',
#   'decededly',
#   'dedidedly'],
#  'anniversary': ['anneversary',
#   'annaversary',
#   'anniversary',
#   'anniversiry',
#   'annivirsary',
#   'anniversery'],
#  'enjoyed': ['injoyed'],
#  'european': ['europian'],
#  'resemblance': ['resemblence'],
#  'just': ['gust'],
#  'guidance': ['guidence'],
#  'deepest': ['deapest'],
#  'pursuing': ['persuing'],
#  'adequate': ['adaquate', 'adequite', 'adiquate', 'adecuate', 'adequete'],
#  'do': ['bo', 'no', 'to', 'du', 'go'],
#  'leisure': ['leasure', 'lessure'],
#  'degradation': ['degredation'],
#  'children': ['childres', 'childran'],
#  'steal': ['steel'],
#  'steam': ['steem'],
#  'secretary': ['secretery', 'secratary'],
#  'lemonade': ['lemenade', 'lemanade'],
#  'miserable': ['misarable'],
#  'away': ['awar', 'ayay', 'auay', 'awaw'],
#  'gentleman': ['gentlemen'],
#  'unable': ['onable'],
#  'cooperation': ['coaperation', 'cooperqtion'],
#  'drawn': ['drown'],
#  'stealing': ['stelling'],
#  'kitchen': ['kitchin'],
#  'received': ['receaved'],
#  'cow': ['caw'],
#  'ill': ['ell'],
#  'receiver': ['received', 'receover', 'receaver', 'receivor', 'receever'],
#  'negotiation': ['negociation'],
#  'ingenious': ['ingeneous'],
#  'spear': ['speer'],
#  'trunk': ['tronk'],
#  'speak': ['speck'],
#  'gratitude': ['graditude'],
#  'condemned': ['condemmed'],
#  'exceeded': ['excedded'],
#  'flexible': ['flexable'],
#  'easy': ['eazy'],
#  'concerning': ['conserning'],
#  'coherent': ['coherant'],
#  'applied': ['applyed', 'upplied'],
#  'physician': ['phycician', 'physicion', 'phisician', 'physisian'],
#  'air': ['aer'],
#  'cylinder': ['cilinder'],
#  'sting': ['steng'],
#  'primitively': ['primatively'],
#  'comparative': ['comparitive'],
#  'girls': ['gerls'],
#  'independent': ['indipendent', 'independant'],
#  'hang': ['hung', 'hand'],
#  'run': ['ran'],
#  'kept': ['cept'],
#  'the': ['tie', 'tje', 'thw', 'thi'],
#  'victim': ['victom'],
#  'shout': ['showt'],
#  'cape': ['kape'],
#  'competence': ['competance'],
#  'critique': ['ctitique'],
#  'congratulate': ['congradulate'],
#  'purple': ['pupple',
#   'parple',
#   'pirple',
#   'perple',
#   'purpls',
#   'hurple',
#   'pulple'],
#  'phenomenal': ['phenominal'],
#  'hare': ['hace'],
#  'architectural': ['archetectural'],
#  'months': ['mouths'],
#  'propagate': ['propogate'],
#  'octopus': ['octapus'],
#  'wasting': ['wadting'],
#  'fight': ['finht', 'fighg'],
#  'way': ['uay'],
#  'was': ['wan', 'uas', 'wos', 'way', 'wus'],
#  'mysterious': ['masterious', 'mystirious', 'misterious'],
#  'absent': ['apsent'],
#  'crystal': ['cristal'],
#  'evidence': ['evedence'],
#  'enlist': ['enlish'],
#  'physical': ['phisical'],
#  'dying': ['diing'],
#  'heyday': ['heydey'],
#  'assiduous': ['assidious'],
#  'affidavit': ['affidevit',
#   'affadavit',
#   'affedavit',
#   'affidivit',
#   'effidavit',
#   'affidavat',
#   'affidavid'],
#  'together': ['togather'],
#  'reception': ['reseption'],
#  'concept': ['consept'],
#  'dance': ['danse'],
#  'grateful': ['gratiful'],
#  'certainly': ['sertainly'],
#  'flash': ['flass'],
#  'permanently': ['permonently',
#   'perminently',
#   'permalently',
#   'permamently',
#   'permenently',
#   'permaiently',
#   'permanantly',
#   'perminently'],
#  'feeble': ['feable'],
#  'gun': ['gon'],
#  'gum': ['gam', 'gun'],
#  'detonated': ['detenated'],
#  'regained': ['recained'],
#  'repetitive': ['repetative'],
#  'discover': ['descover'],
#  'cost': ['cast'],
#  'scarcity': ['scarsity'],
#  'assistance': ['assistence'],
#  'uniform': ['iniform', 'unifore', 'unaform'],
#  'collateral': ['cullateral',
#   'colladeral',
#   'coalateral',
#   'callateral',
#   'coolateral',
#   'collatoral'],
#  'muslin': ['muzlin'],
#  'english': ['inglish'],
#  'pedals': ['pedels'],
#  'precursor': ['precurser'],
#  'uphill': ['upwill'],
#  'pony': ['pone'],
#  'rarely': ['rerely'],
#  'live': ['life'],
#  'jam': ['lam', 'ham', 'dam', 'jan', 'gam', 'uam', 'jem'],
#  'obsolescence': ['obselescence'],
#  'entrance': ['entronce',
#   'entrence',
#   'entrence',
#   'entranse',
#   'intrance',
#   'entrante'],
#  'club': ['clob'],
#  'repentance': ['repentence'],
#  'envelope': ['envolope'],
#  'coerce': ['coeece'],
#  'car': ['cor'],
#  'cap': ['kap', 'cat'],
#  'nuisance': ['nuisanse'],
#  'can': ['con'],
#  'metamorphosis': ['metamorphysis'],
#  'headmaster': ['headmastes'],
#  'did': ['bid', 'ded'],
#  'chin': ['chen'],
#  'yard': ['yerd'],
#  'magazine': ['magizine'],
#  'criterion': ['critereon'],
#  'product': ['prodect'],
#  'influenced': ['influented'],
#  'southern': ['sorthern', 'southorn'],
#  'disgusted': ['discusted'],
#  'produce': ['produse'],
#  'remember': ['rimember',
#   'rememmer',
#   'remembed',
#   'remerber',
#   'remamber',
#   'remenber',
#   'rememder'],
#  'idiosyncratic': ['ideosyncratic'],
#  ...}

# %% [markdown]
# ### Step 4.3: Computing the conditional probabilities for all error types and error-specific best candidate functions
#
# In this section, I compute the conditional probabilities for each type of error, hence for each possible permutation. I use the formulas shown below, from [slide 24 on spelling corrections](https://web.stanford.edu/class/cs124/lec/spelling.pdf) by Jurafsky:
#
# ![image.png](attachment:image.png)
#
# This part was one of the most challenging for me, since I couldn't figure out quickly how to do this... There probably is a more efficient and less lengthy way to do it, but this is the best I could come up with.

# %% [markdown]
# ### Deletion:
#
# Here, I need to calculate the **probability of xy mistyped as x** (so **deletion of y after x**):
#
# **x|xy** --> typed **x** given that the correct is **xy**
#
# In order to do that, I need a **count of xy mistyped as x in typo** divided by **count of xy in target**. Hence, we need a function that makes character bigrams, which we will use to separate all target words in the deletion corpus in bigrams, to then count their occurrences. However, there are instances in which the deletion occurs at position 0 such as:
#
# **he|the** --> typed ***he*** given that the correct word was ***the***
#
# In such cases, we can say that the permutation occurring is the following:
#
# **""|""t**
#
# Thus, we need to calculate only the **counts of *t* in position 0**, since the bigram \[empty space\]t is always at the beginning. Therefore, a **letter count at position zero function** is also developed.

# %%
def bigram(word):
    """Function that takes a word and returns a list with character bigrams of that word"""
    letters = [x for x in word]
    ngrams = zip(*[letters[i:] for i in range(2)])
    return ["".join(ngram) for ngram in ngrams]

bigram("hello")
# Out:
# ['he', 'el', 'll', 'lo']

# %%
def bigram_count(typo_corpus):
    """Function that takes a typo corpus and returns a dictionary with frequencies for each bigram"""
    dd = {}
    for target in typo_corpus.keys():
        for bg in bigram(target):
            if bg not in dd.keys():
                dd[bg] = 1
            else:
                dd[bg] += 1
    return dd

# %%
bigrams_target = bigram_count(target_typos)
bigrams_target["unseen"] = 0 #we need unseen ones for later
bigrams_target
# Out:
# {'ra': 464,
#  'ai': 152,
#  'in': 1000,
#  'ni': 221,
#  'ng': 528,
#  'wr': 17,
#  'ri': 391,
#  'it': 383,
#  'ti': 642,
#  'gs': 21,
#  'ye': 30,
#  'el': 318,
#  'll': 312,
#  'lo': 215,
#  'ow': 115,
#  'fo': 101,
#  'ou': 329,
#  'ur': 274,
#  'wo': 54,
#  'oo': 122,
#  'od': 60,
#  'ds': 46,
#  'ag': 130,
#  'gg': 44,
#  'gr': 135,
#  're': 758,
#  'es': 596,
#  'ss': 251,
#  'si': 296,
#  'io': 349,
#  'on': 667,
#  'ok': 36,
#  'ki': 55,
#  'li': 331,
#  'ig': 128,
#  'gi': 83,
#  'ib': 68,
#  'bl': 192,
#  'le': 515,
#  'ec': 239,
#  'ct': 178,
#  'tr': 230,
#  'ic': 302,
#  'ci': 169,
#  'ty': 103,
#  'sc': 123,
#  'co': 436,
#  'ol': 201,
#  'ld': 50,
#  'ad': 163,
#  'da': 104,
#  'ap': 141,
#  'pt': 67,
#  'ta': 285,
#  'ab': 152,
#  'ca': 248,
#  'an': 523,
#  'ne': 328,
#  'ed': 645,
#  'im': 146,
#  'mm': 96,
#  'ma': 222,
#  'at': 596,
#  'tu': 126,
#  'sw': 28,
#  'wi': 70,
#  'iv': 134,
#  've': 319,
#  'pp': 125,
#  'pr': 263,
#  'ro': 341,
#  'op': 113,
#  'ia': 146,
#  'fu': 68,
#  'st': 475,
#  'bb': 22,
#  'be': 135,
#  'di': 245,
#  'is': 378,
#  'rb': 24,
#  'ns': 216,
#  'iz': 36,
#  'ze': 37,
#  'we': 85,
#  'dn': 6,
#  'sd': 5,
#  'ay': 68,
#  'su': 173,
#  'uc': 57,
#  'cc': 71,
#  'ce': 377,
#  'gh': 78,
#  'ht': 57,
#  'nc': 238,
#  'cr': 112,
#  'em': 212,
#  'me': 334,
#  'en': 705,
#  'nt': 535,
#  'te': 645,
#  'pu': 47,
#  'ul': 124,
#  'ls': 42,
#  'se': 375,
#  'nd': 274,
#  'ja': 17,
#  'am': 139,
#  'mj': 1,
#  'ar': 479,
#  'sa': 117,
#  'il': 214,
#  'th': 211,
#  'hu': 27,
#  'un': 210,
#  'de': 361,
#  'er': 790,
#  'os': 115,
#  'ea': 337,
#  'as': 236,
#  'he': 246,
#  'ah': 4,
#  'hl': 11,
#  'ep': 107,
#  'po': 188,
#  'or': 422,
#  'rt': 162,
#  'rr': 125,
#  'ru': 72,
#  'up': 67,
#  'to': 177,
#  'om': 227,
#  'ms': 26,
#  'pe': 287,
#  'e-': 17,
#  '-r': 9,
#  'rd': 88,
#  'sh': 149,
#  'hr': 22,
#  'ie': 226,
#  'ek': 9,
#  'ub': 52,
#  'bs': 23,
#  'la': 226,
#  'bo': 89,
#  'cl': 78,
#  'mb': 58,
#  'ts': 130,
#  'ov': 69,
#  'rs': 177,
#  'sy': 34,
#  'et': 206,
#  'og': 70,
#  'gy': 21,
#  'sn': 11,
#  'no': 141,
#  'mi': 204,
#  'ry': 150,
#  'sm': 32,
#  'go': 53,
#  'vi': 125,
#  'id': 133,
#  'bt': 12,
#  'ac': 226,
#  'ee': 168,
#  'ex': 114,
#  'xp': 31,
#  'pl': 124,
#  'br': 69,
#  'ug': 43,
#  'sp': 123,
#  'ke': 99,
#  'mu': 39,
#  'us': 234,
#  'eg': 80,
#  'ph': 73,
#  'ik': 12,
#  'ho': 164,
#  'ly': 286,
#  'sf': 14,
#  'gl': 27,
#  'ev': 100,
#  'ir': 140,
#  'rc': 82,
#  'cu': 99,
#  'um': 85,
#  'oc': 86,
#  'ck': 98,
#  'ue': 75,
#  'mp': 140,
#  'hm': 11,
#  'ge': 189,
#  'cs': 11,
#  'xa': 13,
#  'rg': 45,
#  'ga': 83,
#  'au': 56,
#  'ut': 107,
#  'wa': 71,
#  'ef': 82,
#  'fe': 105,
#  'oe': 23,
#  'av': 55,
#  'ch': 232,
#  'hi': 142,
#  'ot': 112,
#  'tl': 59,
#  'aw': 29,
#  't-': 6,
#  '-t': 9,
#  'ff': 65,
#  'so': 129,
#  'gn': 31,
#  'na': 185,
#  'ba': 93,
#  'al': 441,
#  'ps': 21,
#  'az': 6,
#  'za': 5,
#  'fi': 136,
#  'nf': 39,
#  'of': 31,
#  'rv': 30,
#  'vo': 41,
#  'oa': 58,
#  'h-': 4,
#  '-l': 7,
#  'gu': 67,
#  'ui': 91,
#  'nk': 34,
#  'ei': 59,
#  'nh': 5,
#  'lc': 12,
#  'ob': 45,
#  'bd': 1,
#  'du': 46,
#  'ak': 47,
#  'yp': 11,
#  'rm': 56,
#  'pi': 100,
#  'rn': 73,
#  'ip': 70,
#  'tn': 5,
#  'wh': 41,
#  'xc': 22,
#  'ey': 38,
#  'ys': 37,
#  'kn': 20,
#  'mo': 128,
#  'uf': 19,
#  'nn': 82,
#  'r-': 8,
#  '-h': 8,
#  'bi': 78,
#  'tt': 106,
#  'sk': 26,
#  'tb': 2,
#  'rl': 30,
#  'va': 67,
#  'wl': 11,
#  'ox': 11,
#  'xi': 14,
#  'mn': 12,
#  'oj': 2,
#  'je': 15,
#  'pn': 1,
#  'eu': 28,
#  'dl': 27,
#  'dj': 5,
#  'ju': 29,
#  'cq': 12,
#  'qu': 94,
#  'a_': 7,
#  '_l': 8,
#  'o-': 3,
#  '-d': 2,
#  'do': 73,
#  'oz': 5,
#  'ym': 23,
#  'jo': 23,
#  'ha': 153,
#  'bj': 5,
#  'py': 12,
#  'yl': 11,
#  'bu': 58,
#  'dy': 29,
#  'dr': 70,
#  'lt': 47,
#  'ua': 78,
#  'pa': 154,
#  'tc': 35,
#  'ew': 37,
#  'iu': 13,
#  'xt': 17,
#  'nv': 45,
#  'uv': 8,
#  'lb': 4,
#  'eb': 23,
#  'yr': 5,
#  'ny': 30,
#  'rp': 33,
#  'db': 3,
#  'fr': 44,
#  'if': 47,
#  'ft': 20,
#  'rk': 23,
#  'lf': 20,
#  'oy': 35,
#  'xy': 2,
#  'fa': 71,
#  'bp': 1,
#  'm-': 3,
#  '-m': 8,
#  'aq': 1,
#  'sl': 44,
#  'd-': 6,
#  '-f': 4,
#  'y_': 5,
#  '_t': 9,
#  'eq': 24,
#  'iq': 8,
#  'yc': 5,
#  'wd': 6,
#  'eo': 29,
#  'wn': 24,
#  'lu': 63,
#  'nu': 42,
#  'l-': 11,
#  '-s': 6,
#  'uo': 16,
#  'ud': 32,
#  'dt': 3,
#  'rh': 9,
#  'af': 29,
#  'lm': 12,
#  'fl': 37,
#  'rf': 24,
#  '-c': 8,
#  '-n': 1,
#  'ka': 7,
#  'uk': 2,
#  'kr': 6,
#  'oi': 44,
#  'my': 16,
#  'k_': 1,
#  'tw': 15,
#  'dg': 22,
#  'dd': 22,
#  'nl': 13,
#  'dp': 3,
#  'ix': 7,
#  'yw': 3,
#  'w-': 2,
#  '-g': 3,
#  'eh': 16,
#  'cy': 22,
#  'hy': 31,
#  'n-': 6,
#  '-b': 10,
#  'ks': 25,
#  'hf': 4,
#  'iw': 1,
#  'sq': 7,
#  'kt': 1,
#  'dm': 18,
#  'ya': 14,
#  'bm': 1,
#  'r_': 3,
#  'yf': 2,
#  'n_': 13,
#  '_f': 4,
#  'd_': 6,
#  '_n': 3,
#  'lk': 12,
#  'ez': 5,
#  'zi': 7,
#  '_h': 2,
#  '-k': 1,
#  '_b': 5,
#  'ws': 7,
#  'dv': 15,
#  'o_': 4,
#  'ii': 1,
#  'kl': 9,
#  'lv': 13,
#  'uu': 1,
#  'nr': 5,
#  '_s': 2,
#  'yi': 25,
#  'g-': 6,
#  'hb': 5,
#  'hn': 8,
#  'uy': 3,
#  'xh': 9,
#  'np': 4,
#  'zo': 2,
#  'ae': 12,
#  'tm': 13,
#  'uz': 3,
#  'zz': 5,
#  'zl': 3,
#  'by': 13,
#  'i-': 1,
#  'ky': 4,
#  'dc': 2,
#  'wb': 3,
#  'lw': 2,
#  'ao': 4,
#  'xo': 4,
#  'zu': 2,
#  'yn': 9,
#  'rw': 8,
#  's-': 4,
#  '-u': 1,
#  'ih': 3,
#  'kb': 1,
#  'dh': 3,
#  '-o': 3,
#  'yo': 14,
#  'yb': 4,
#  'oh': 7,
#  'yt': 8,
#  '_a': 4,
#  't_': 7,
#  'a-': 3,
#  '-q': 1,
#  'lg': 8,
#  'nj': 10,
#  'nx': 2,
#  '-p': 9,
#  'gm': 4,
#  'pw': 1,
#  'ej': 3,
#  'yd': 6,
#  'wk': 2,
#  'tf': 6,
#  'nw': 3,
#  'gt': 5,
#  '-e': 2,
#  'e_': 9,
#  'sg': 3,
#  'kc': 3,
#  'yg': 5,
#  'nm': 14,
#  'cw': 1,
#  'f-': 3,
#  'tp': 3,
#  'bh': 1,
#  'oq': 2,
#  'vy': 5,
#  's_': 3,
#  '_m': 2,
#  'dw': 5,
#  'mw': 1,
#  'df': 5,
#  'xe': 17,
#  'hs': 9,
#  'ln': 1,
#  'ax': 7,
#  '_o': 4,
#  "o'": 1,
#  "'c": 1,
#  '_e': 1,
#  '_p': 3,
#  'nq': 9,
#  'kf': 3,
#  'sb': 1,
#  'pm': 2,
#  'uq': 2,
#  'pk': 1,
#  'hw': 2,
#  '_u': 1,
#  '_c': 4,
#  'p_': 2,
#  'lp': 6,
#  'w_': 1,
#  '_y': 2,
#  'cn': 2,
#  'bf': 1,
#  'mr': 2,
#  '_g': 1,
#  'k-': 4,
#  'ku': 1,
#  'fy': 6,
#  'sr': 4,
#  'hd': 3,
#  'fd': 1,
#  '_r': 4,
#  '-a': 1,
#  'bv': 2,
#  'vu': 2,
#  'y-': 5,
#  'zy': 2,
#  'g_': 1,
#  '_k': 1,
#  'ko': 2,
#  'tz': 1,
#  'zk': 1,
#  'kg': 1,
#  'wt': 2,
#  'x-': 1,
#  'l_': 4,
#  'kd': 1,
#  'td': 1,
#  'f_': 1,
#  '_i': 2,
#  'lr': 4,
#  'wy': 1,
#  'kj': 1,
#  'xq': 1,
#  'tg': 2,
#  'aj': 1,
#  'ux': 2,
#  'wp': 1,
#  'mf': 3,
#  'pb': 2,
#  'xu': 1,
#  'kw': 3,
#  '_d': 4,
#  'zv': 1,
#  'dk': 1,
#  'kh': 1,
#  'hh': 1,
#  '-i': 1,
#  'wc': 1,
#  'p-': 1,
#  '_w': 1,
#  'wf': 2,
#  'lh': 1,
#  'km': 1,
#  'yz': 1,
#  'vr': 1,
#  'bc': 1,
#  'rj': 1,
#  'nb': 2,
#  'yj': 1,
#  'pf': 1,
#  'unseen': 0}

# %%
def del_diff(target, typo):
    """Function that takes a target and a typo of deletion type and returns the character permutation in the form
    of conditional probability"""
    for i in range(len(target)): 
        try:
            if target[i] != typo[i]: #if letter at position i does not correspond
                if i != 0: #if not the first letter
                    cond_prob = target[i-1].lower() + "|" + target[i-1:i+1].lower() #to account for cases where the typo is in the first bigram
                    break #to take only first difference
                if i == 0: #if first letter, then the letter before is just empty space
                    cond_prob = "|" + target[i].lower() #to account for cases where the typo is in the first bigram
                    break
                    
        except IndexError: #when i is not in the range of the typo (because deletion at last position)
            cond_prob = target[i-1].lower() + "|" + target[-2:].lower() #last letter of typo (one less than i in target) given that it was supposed to be the last two of the target
            break 
    return cond_prob

# %%
del_diff("yellow", "yello")
# Out:
# 'o|ow'

# %%
def occur_letter_zero_in_target(typo_corpus):
    """Function that takes a corpus typo and returns a dictionary of counts for each letter at position zero"""
    occ = {}
    for tar in typo_corpus.keys():
        letter_zero = tar[0]
        if letter_zero not in occ:
            occ[letter_zero] = 0
        else:
            occ[letter_zero] += 1
    return occ

# %%
letter_zero_count = {k:v for k, v in sorted(occur_letter_zero_in_target(target_typos).items(), key=lambda x: x[0])}
letter_zero_count["unseen"] = 0 #for later
letter_zero_count
# Out:
# {'a': 549,
#  'b': 333,
#  'c': 687,
#  'd': 385,
#  'e': 336,
#  'f': 288,
#  'g': 186,
#  'h': 200,
#  'i': 272,
#  'j': 53,
#  'k': 42,
#  'l': 206,
#  'm': 292,
#  'n': 135,
#  'o': 156,
#  'p': 549,
#  'q': 26,
#  'r': 346,
#  's': 779,
#  't': 311,
#  'u': 103,
#  'v': 87,
#  'w': 203,
#  'y': 19,
#  'z': 3,
#  'unseen': 0}

# %%
def del_prob(del_typos):
    """Function that takes a corpus of deletion typos and returns a dictionary of all the conditional probabilities
    for character permutations"""
    cond_prob_list = []
    for target, typos in del_typos.items(): #for target and typos
        for typo in typos:
            cond_p = del_diff(target, typo)
            cond_prob_list.append(cond_p)
            
    counts = {}
    for cp in cond_prob_list:
        if cp not in counts:
            counts[cp] = 1
        else:
            counts[cp] += 1
    
    prob = {}
    for pair, count in counts.items():
        intend = pair.split("|")[1] #take the second part, which is the intended characters
        if len(intend) == 2:
            prob[pair] = float(counts[pair]/bigrams_target[intend])
        else: #if we are dealing with the beginning of the word, i decided to just divide by the letter count of the next word, which would correspond to ""|""x
            prob[pair] = float(counts[pair]/letter_zero_count[intend])

    prob_sorted = {k: v for k, v in sorted(prob.items(), key=lambda x: x[1], reverse = True)}
    
    return prob_sorted

# %%
del_prob(deletion_)
# Out:
# {'y|y_': 1.0,
#  'k|k_': 1.0,
#  'r|r_': 1.0,
#  'o|o_': 1.0,
#  'n|nx': 1.0,
#  'g|gt': 1.0,
#  's|s_': 1.0,
#  'p|p_': 1.0,
#  'w|w_': 1.0,
#  'f|f_': 1.0,
#  'w|wy': 1.0,
#  'h|hh': 1.0,
#  'e|e_': 0.8888888888888888,
#  'g|gg': 0.8636363636363636,
#  't|t_': 0.8571428571428571,
#  'n|n_': 0.8461538461538461,
#  'y|yc': 0.8,
#  'm|mm': 0.7916666666666666,
#  'c|cc': 0.7464788732394366,
#  'p|pp': 0.744,
#  'n|nn': 0.7317073170731707,
#  'd|dd': 0.7272727272727273,
#  'a|a_': 0.7142857142857143,
#  't|tt': 0.6698113207547169,
#  'o|o-': 0.6666666666666666,
#  'm|m-': 0.6666666666666666,
#  'd|d_': 0.6666666666666666,
#  'x|xh': 0.6666666666666666,
#  'r|rr': 0.616,
#  'b|bb': 0.5909090909090909,
#  'x|xc': 0.5909090909090909,
#  'l|ll': 0.5480769230769231,
#  's|ss': 0.5378486055776892,
#  'e|ea': 0.5103857566765578,
#  'w|w-': 0.5,
#  'm|mn': 0.5,
#  'h|hn': 0.5,
#  'h|h-': 0.5,
#  'l|l_': 0.5,
#  't|tg': 0.5,
#  'w|wh': 0.4878048780487805,
#  'k|ks': 0.48,
#  'o|oa': 0.46551724137931033,
#  'f|ff': 0.46153846153846156,
#  'c|cs': 0.45454545454545453,
#  'a|ai': 0.45394736842105265,
#  'h|hs': 0.4444444444444444,
#  'e|ee': 0.44047619047619047,
#  'o|oe': 0.43478260869565216,
#  'y|ys': 0.43243243243243246,
#  'g|gs': 0.42857142857142855,
#  'e|ez': 0.4,
#  'z|zz': 0.4,
#  'o|oo': 0.3770491803278688,
#  'r|r-': 0.375,
#  'a|au': 0.35714285714285715,
#  'a|a-': 0.3333333333333333,
#  'r|rh': 0.3333333333333333,
#  'w|wd': 0.3333333333333333,
#  'o|ow': 0.3130434782608696,
#  'm|ms': 0.3076923076923077,
#  'p|ph': 0.3013698630136986,
#  'g|gu': 0.29850746268656714,
#  'o|ou': 0.2917933130699088,
#  'w|ws': 0.2857142857142857,
#  't|ts': 0.27692307692307694,
#  'e|eo': 0.27586206896551724,
#  'u|ui': 0.27472527472527475,
#  'h|hl': 0.2727272727272727,
#  'd|dl': 0.25925925925925924,
#  'f|fr': 0.25,
#  'n|np': 0.25,
#  'k|k-': 0.25,
#  'k|ke': 0.24242424242424243,
#  'm|mb': 0.2413793103448276,
#  '|k': 0.23809523809523808,
#  'c|ci': 0.23668639053254437,
#  's|sc': 0.23577235772357724,
#  'n|ne': 0.2347560975609756,
#  'i|iu': 0.23076923076923078,
#  'd|dg': 0.22727272727272727,
#  'o|oi': 0.22727272727272727,
#  'd|ds': 0.21739130434782608,
#  'y|ya': 0.21428571428571427,
#  'x|xi': 0.21428571428571427,
#  'd|dy': 0.20689655172413793,
#  'r|rn': 0.2054794520547945,
#  'g|gh': 0.20512820512820512,
#  't|tn': 0.2,
#  'g|ge': 0.19576719576719576,
#  'g|gn': 0.1935483870967742,
#  'u|uc': 0.19298245614035087,
#  'a|ay': 0.19117647058823528,
#  'u|ue': 0.18666666666666668,
#  'n|ns': 0.18518518518518517,
#  'h|hr': 0.18181818181818182,
#  'w|wl': 0.18181818181818182,
#  'u|ua': 0.1794871794871795,
#  'e|eu': 0.17857142857142858,
#  'n|ni': 0.17647058823529413,
#  'x|xe': 0.17647058823529413,
#  'j|jo': 0.17391304347826086,
#  'o|oy': 0.17142857142857143,
#  'e|ei': 0.1694915254237288,
#  'd|d-': 0.16666666666666666,
#  'y|ye': 0.16666666666666666,
#  'l|lc': 0.16666666666666666,
#  'a|ae': 0.16666666666666666,
#  'f|fy': 0.16666666666666666,
#  'g|g-': 0.16666666666666666,
#  'l|lp': 0.16666666666666666,
#  'i|ie': 0.16371681415929204,
#  'f|fl': 0.16216216216216217,
#  't|tr': 0.1608695652173913,
#  'r|re': 0.15963060686015831,
#  'b|br': 0.15942028985507245,
#  'e|ey': 0.15789473684210525,
#  'b|bu': 0.15517241379310345,
#  'x|xa': 0.15384615384615385,
#  'o|oc': 0.1511627906976744,
#  'f|ft': 0.15,
#  'a|ac': 0.14601769911504425,
#  'p|ps': 0.14285714285714285,
#  'o|oh': 0.14285714285714285,
#  'y|yo': 0.14285714285714285,
#  's|sw': 0.14285714285714285,
#  'c|ch': 0.14224137931034483,
#  'w|we': 0.1411764705882353,
#  'v|ve': 0.14106583072100312,
#  's|sh': 0.14093959731543623,
#  't|th': 0.13744075829383887,
#  's|se': 0.136,
#  'r|rl': 0.13333333333333333,
#  't|tw': 0.13333333333333333,
#  'm|me': 0.1317365269461078,
#  'r|rs': 0.12994350282485875,
#  'b|bi': 0.1282051282051282,
#  't|te': 0.12403100775193798,
#  'h|he': 0.12195121951219512,
#  'l|ls': 0.11904761904761904,
#  'n|nu': 0.11904761904761904,
#  'w|wr': 0.11764705882352941,
#  'x|xt': 0.11764705882352941,
#  'e|e-': 0.11764705882352941,
#  'i|ia': 0.11643835616438356,
#  'u|ub': 0.11538461538461539,
#  'm|mp': 0.11428571428571428,
#  'n|nd': 0.11313868613138686,
#  'e|es': 0.11241610738255034,
#  'r|ri': 0.10997442455242967,
#  'g|gi': 0.10843373493975904,
#  'o|or': 0.1066350710900474,
#  'h|ht': 0.10526315789473684,
#  'p|pt': 0.1044776119402985,
#  'a|ar': 0.10438413361169102,
#  'l|le': 0.1029126213592233,
#  'd|de': 0.10249307479224377,
#  'u|ur': 0.10218978102189781,
#  't|tl': 0.1016949152542373,
#  'l|ld': 0.1,
#  'n|ny': 0.1,
#  'n|nj': 0.1,
#  'i|ic': 0.09933774834437085,
#  'i|id': 0.09774436090225563,
#  'g|ga': 0.0963855421686747,
#  's|si': 0.0945945945945946,
#  's|st': 0.09263157894736843,
#  'c|ck': 0.09183673469387756,
#  'h|hi': 0.09154929577464789,
#  'l|l-': 0.09090909090909091,
#  's|sn': 0.09090909090909091,
#  'u|un': 0.09047619047619047,
#  'a|an': 0.08795411089866156,
#  'p|pr': 0.08745247148288973,
#  'r|ry': 0.08666666666666667,
#  'r|rc': 0.08536585365853659,
#  'e|ed': 0.08372093023255814,
#  'n|ng': 0.08333333333333333,
#  'b|bt': 0.08333333333333333,
#  'b|be': 0.08148148148148149,
#  'z|ze': 0.08108108108108109,
#  'p|pe': 0.08013937282229965,
#  'd|da': 0.07692307692307693,
#  'n|nl': 0.07692307692307693,
#  't|tm': 0.07692307692307693,
#  'l|lv': 0.07692307692307693,
#  'f|fe': 0.0761904761904762,
#  'n|na': 0.07567567567567568,
#  'u|ut': 0.07476635514018691,
#  'g|gl': 0.07407407407407407,
#  'f|fi': 0.07352941176470588,
#  'v|vo': 0.07317073170731707,
#  'k|ki': 0.07272727272727272,
#  'v|vi': 0.072,
#  'p|pa': 0.07142857142857142,
#  'e|ec': 0.07112970711297072,
#  'i|ig': 0.0703125,
#  's|so': 0.06976744186046512,
#  'r|ru': 0.06944444444444445,
#  'd|di': 0.06938775510204082,
#  '|w': 0.06896551724137931,
#  'c|ce': 0.06896551724137931,
#  'a|aw': 0.06896551724137931,
#  'a|as': 0.06779661016949153,
#  'e|en': 0.06666666666666667,
#  'a|am': 0.06474820143884892,
#  'p|pl': 0.06451612903225806,
#  'h|hy': 0.06451612903225806,
#  't|ti': 0.06386292834890965,
#  'i|is': 0.06349206349206349,
#  't|tu': 0.06349206349206349,
#  'e|et': 0.06310679611650485,
#  'i|it': 0.06266318537859007,
#  'c|cr': 0.0625,
#  'e|eh': 0.0625,
#  'u|ud': 0.0625,
#  'e|er': 0.0620253164556962,
#  'a|ad': 0.06134969325153374,
#  'l|li': 0.06042296072507553,
#  't|ta': 0.05964912280701754,
#  'g|gr': 0.05925925925925926,
#  't|tc': 0.05714285714285714,
#  't|to': 0.05649717514124294,
#  'r|ra': 0.05603448275862069,
#  'o|ok': 0.05555555555555555,
#  'n|nt': 0.05420560747663551,
#  'r|rm': 0.05357142857142857,
#  'o|od': 0.05,
#  'k|kn': 0.05,
#  'l|lf': 0.05,
#  'n|no': 0.04964539007092199,
#  'm|ma': 0.04954954954954955,
#  'r|rt': 0.04938271604938271,
#  's|sp': 0.04878048780487805,
#  'i|io': 0.04871060171919771,
#  'u|ul': 0.04838709677419355,
#  'g|gy': 0.047619047619047616,
#  'u|um': 0.047058823529411764,
#  'l|lo': 0.046511627906976744,
#  'n|nc': 0.046218487394957986,
#  '|h': 0.045,
#  'c|ct': 0.0449438202247191,
#  'r|rg': 0.044444444444444446,
#  'm|mi': 0.04411764705882353,
#  'r|ro': 0.04398826979472141,
#  'y|ym': 0.043478260869565216,
#  'b|bs': 0.043478260869565216,
#  'r|rk': 0.043478260869565216,
#  'i|ip': 0.04285714285714286,
#  'd|dr': 0.04285714285714286,
#  'u|us': 0.042735042735042736,
#  'h|ho': 0.042682926829268296,
#  'l|lt': 0.0425531914893617,
#  'w|wn': 0.041666666666666664,
#  'i|in': 0.041,
#  'c|cu': 0.04040404040404041,
#  'm|mo': 0.0390625,
#  'a|al': 0.036281179138321996,
#  'o|ot': 0.03571428571428571,
#  'e|ex': 0.03508771929824561,
#  'o|ol': 0.03482587064676617,
#  'o|on': 0.034482758620689655,
#  'j|ju': 0.034482758620689655,
#  'r|rd': 0.03409090909090909,
#  'p|po': 0.031914893617021274,
#  'q|qu': 0.031914893617021274,
#  'l|lu': 0.031746031746031744,
#  'l|la': 0.030973451327433628,
#  'r|rp': 0.030303030303030304,
#  'p|pi': 0.03,
#  'n|nk': 0.029411764705882353,
#  's|sy': 0.029411764705882353,
#  't|ty': 0.02912621359223301,
#  'i|ir': 0.02857142857142857,
#  'o|og': 0.02857142857142857,
#  'e|em': 0.02830188679245283,
#  'e|el': 0.02830188679245283,
#  'w|wa': 0.028169014084507043,
#  'i|il': 0.028037383177570093,
#  'i|im': 0.0273972602739726,
#  'h|ha': 0.026143790849673203,
#  'm|mu': 0.02564102564102564,
#  'c|cl': 0.02564102564102564,
#  's|sa': 0.02564102564102564,
#  'c|co': 0.02522935779816514,
#  'a|at': 0.02348993288590604,
#  'u|ug': 0.023255813953488372,
#  's|su': 0.023121387283236993,
#  'b|bo': 0.02247191011235955,
#  'o|ob': 0.022222222222222223,
#  'b|ba': 0.021505376344086023,
#  'a|ak': 0.02127659574468085,
#  'i|if': 0.02127659574468085,
#  'p|pu': 0.02127659574468085,
#  'b|bl': 0.020833333333333332,
#  'c|ca': 0.020161290322580645,
#  'w|wo': 0.018518518518518517,
#  'a|av': 0.01818181818181818,
#  'o|op': 0.017699115044247787,
#  'o|os': 0.017391304347826087,
#  'i|iv': 0.014925373134328358,
#  'u|up': 0.014925373134328358,
#  'v|va': 0.014925373134328358,
#  'w|wi': 0.014285714285714285,
#  '|s': 0.014120667522464698,
#  'f|fa': 0.014084507042253521,
#  'd|do': 0.0136986301369863,
#  'a|ab': 0.013157894736842105,
#  'e|ef': 0.012195121951219513,
#  '|v': 0.011494252873563218,
#  'l|ly': 0.01048951048951049,
#  '|f': 0.010416666666666666,
#  '|t': 0.00964630225080386,
#  '|a': 0.009107468123861567,
#  'o|om': 0.00881057268722467,
#  'a|ag': 0.007692307692307693,
#  '|p': 0.007285974499089253,
#  'a|ap': 0.0070921985815602835,
#  '|m': 0.00684931506849315,
#  '|o': 0.00641025641025641,
#  '|b': 0.006006006006006006,
#  '|g': 0.005376344086021506,
#  '|l': 0.0048543689320388345,
#  '|r': 0.002890173410404624,
#  '|d': 0.0025974025974025974,
#  '|c': 0.001455604075691412}

# %% [markdown]
# There is another catch, though... What if the a specific probability is not in our dictionary? So, for example, there is no **e|ew**?

# %%
"e|ew" in del_prob(deletion_).keys()
# Out:
# False

# %% [markdown]
# We need to use something called **Laplace or add-1 smoothing**, where we 'steal' some of the probabilities from existing conditional probabilities in the created dictionary, and 'give' them to bigrams that are not there. Below, from [slide 31](https://web.stanford.edu/class/cs276/handouts/spell_correction.ppt) by Manning & Nayak, the mechanism is explained:
#
# ![image.png](attachment:image.png)
#
# So, we do the 'stealing and giving' by **adding 1 to each count** and **adding the length of whatever source we are using to the denominator**. In the case of deletion, it will be the **length of the bigram count dictionary** or the **length of the letter at position zero** count for when the typo is at the beginning of the word.
#
# In order to better understand what is meant here, here is the confusion matrix for deletion by [Kernighan et al. (1990, p. 5)](https://www.aclweb.org/anthology/C90-2036.pdf). All the positions where the value is 0, will have some (low) probability with add-1 smoothing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So... I develop a function where the probabilities get counted taking into account the smoothing. I will do that for all the types of errors later on, too.

# %%
def del_prob_smooth(del_typos):
    """Function that takes a corpus of deletion typos and returns a dictionary of all the smoothed
    conditional probabilities for character permutations"""
    cond_prob_list = []
    for target, typos in del_typos.items(): #for target and typos
        for typo in typos:
            cond_p = del_diff(target, typo)
            cond_prob_list.append(cond_p)
            
    counts = {}
    for cp in cond_prob_list:
        if cp not in counts:
            counts[cp] = 1
        else:
            counts[cp] += 1
    
    prob = {}
    for pair, count in counts.items():
        intend = pair.split("|")[1] #take the second part, which is the intended character/bigram
        if len(intend) == 2: #if we are indeed dealing with a bigram (deletion not at the beginning of the word)
            prob[pair] = float((counts[pair]+1)/((bigrams_target[intend])+(len(bigrams_target)))) #adding 1 to count and length of bigram list to denominator
        else:
            prob[pair] = float((counts[pair]+1)/((letter_zero_count[intend])+(len(letter_zero_count)))) #if we are dealing with the beginning of the word, i decided to just divide by the letter count of the next word, which would correspond to ""|""x

    prob_sorted = {k: v for k, v in sorted(prob.items(), key=lambda x: x[1], reverse = True)}
    return prob_sorted

# %%
cond_prob_del = del_prob_smooth(deletion_)
cond_prob_del
# Out:
# {'l|ll': 0.2028301886792453,
#  'e|ea': 0.1981672394043528,
#  's|ss': 0.17280813214739518,
#  '|k': 0.16176470588235295,
#  'p|pp': 0.1422087745839637,
#  'm|mm': 0.12183544303797468,
#  'r|rr': 0.11800302571860817,
#  't|tt': 0.11214953271028037,
#  'o|ou': 0.11213872832369942,
#  'e|ee': 0.10653409090909091,
#  'a|ai': 0.10174418604651163,
#  'n|nn': 0.09870550161812297,
#  'r|re': 0.09428129829984544,
#  'n|ne': 0.09027777777777778,
#  'c|cc': 0.08896210873146623,
#  'o|oo': 0.07142857142857142,
#  't|te': 0.06858594411515664,
#  'g|gg': 0.06724137931034482,
#  '|w': 0.06550218340611354,
#  'e|es': 0.06007067137809187,
#  'c|ci': 0.05815602836879433,
#  's|se': 0.0570801317233809,
#  'o|ow': 0.05683563748079877,
#  't|ts': 0.05555555555555555,
#  'n|ns': 0.05452127659574468,
#  'v|ve': 0.05380116959064327,
#  'n|ni': 0.052840158520475564,
#  'g|ge': 0.05241379310344828,
#  'm|me': 0.05172413793103448,
#  'f|ff': 0.051580698835274545,
#  'l|le': 0.05137963843958135,
#  'a|ar': 0.05024630541871921,
#  'i|ie': 0.049868766404199474,
#  't|tr': 0.04960835509138381,
#  'o|or': 0.04801670146137787,
#  'r|ri': 0.04746494066882417,
#  'o|oa': 0.04713804713804714,
#  'e|ed': 0.04657070279424217,
#  's|sc': 0.04552352048558422,
#  'a|ac': 0.04461942257217848,
#  's|st': 0.04451038575667656,
#  'a|an': 0.044381491973559964,
#  'c|ch': 0.044270833333333336,
#  '|h': 0.04424778761061947,
#  'd|de': 0.042363433667781496,
#  'n|ng': 0.042293233082706765,
#  'u|ui': 0.04146730462519936,
#  't|th': 0.040160642570281124,
#  'h|he': 0.03964194373401535,
#  'n|nd': 0.03950617283950617,
#  'k|ke': 0.03937007874015748,
#  'e|en': 0.038678485092667206,
#  'p|ph': 0.03776683087027915,
#  'e|er': 0.03770739064856712,
#  'i|ic': 0.03699284009546539,
#  'w|wh': 0.036395147313691506,
#  'u|ur': 0.03580246913580247,
#  't|ti': 0.035653650254668934,
#  'a|au': 0.03547297297297297,
#  's|si': 0.03485576923076923,
#  'g|gu': 0.03482587064676617,
#  'r|rs': 0.033660589060308554,
#  's|sh': 0.032116788321167884,
#  'd|dd': 0.03046594982078853,
#  'p|pr': 0.030037546933667083,
#  'y|ys': 0.029668411867364748,
#  'c|ce': 0.029572836801752465,
#  'p|pe': 0.02916160388821385,
#  'n|nt': 0.028011204481792718,
#  'g|gh': 0.02768729641693811,
#  'i|is': 0.02735229759299781,
#  'i|in': 0.02734375,
#  'i|it': 0.02720348204570185,
#  'r|ra': 0.027,
#  'u|un': 0.02680965147453083,
#  'i|ia': 0.026392961876832845,
#  'r|rn': 0.026272577996715927,
#  'm|mb': 0.025252525252525252,
#  'm|mp': 0.02514792899408284,
#  'b|bb': 0.025089605734767026,
#  'x|xc': 0.025089605734767026,
#  'u|ue': 0.024549918166939442,
#  'u|ua': 0.024429967426710098,
#  'l|li': 0.02422145328719723,
#  'e|ec': 0.023225806451612905,
#  'a|ay': 0.023178807947019868,
#  'k|ks': 0.023172905525846704,
#  'd|di': 0.023047375160051217,
#  'o|oc': 0.022508038585209004,
#  'a|as': 0.022020725388601035,
#  't|ta': 0.02192448233861145,
#  'n|n_': 0.02185792349726776,
#  'w|we': 0.020933977455716585,
#  'i|id': 0.02092675635276532,
#  'n|na': 0.020804438280166437,
#  'f|fr': 0.020689655172413793,
#  'h|hi': 0.02064896755162242,
#  'r|ry': 0.02040816326530612,
#  'i|io': 0.020338983050847456,
#  'u|uc': 0.02023608768971332,
#  'o|on': 0.0199501246882793,
#  'b|br': 0.019834710743801654,
#  'o|oe': 0.01967799642218247,
#  'o|oi': 0.01896551724137931,
#  'd|ds': 0.018900343642611683,
#  'e|et': 0.018867924528301886,
#  'e|ei': 0.018487394957983194,
#  'r|ro': 0.018244013683010263,
#  'g|gs': 0.017953321364452424,
#  'b|bi': 0.017915309446254073,
#  'b|be': 0.01788375558867362,
#  '|v': 0.017699115044247787,
#  'a|al': 0.017400204708290685,
#  'p|pa': 0.017391304347826087,
#  'b|bu': 0.016835016835016835,
#  'e|e_': 0.01651376146788991,
#  'f|fi': 0.01636904761904762,
#  'g|gi': 0.01615508885298869,
#  'm|ms': 0.01601423487544484,
#  'e|eo': 0.01592920353982301,
#  'm|ma': 0.0158311345646438,
#  'c|ck': 0.015772870662460567,
#  'a|ad': 0.015736766809728183,
#  'n|nc': 0.015503875968992248,
#  't|to': 0.015427769985974754,
#  'v|vi': 0.015128593040847202,
#  'i|ig': 0.015060240963855422,
#  's|so': 0.015037593984962405,
#  '|s': 0.014906832298136646,
#  'a|am': 0.014814814814814815,
#  'l|lo': 0.014647137150466045,
#  'g|ga': 0.014539579967689823,
#  'u|us': 0.014285714285714285,
#  'd|dl': 0.014209591474245116,
#  'd|da': 0.0140625,
#  'f|fe': 0.014040561622464899,
#  'u|ut': 0.013996889580093312,
#  'p|pl': 0.013636363636363636,
#  't|tu': 0.013595166163141994,
#  'm|mi': 0.013513513513513514,
#  'g|gr': 0.013412816691505217,
#  'p|pt': 0.013266998341625208,
#  'a|at': 0.013250883392226149,
#  'r|rc': 0.012944983818770227,
#  'r|rt': 0.012893982808022923,
#  't|t_': 0.01289134438305709,
#  'x|xh': 0.012844036697247707,
#  'm|mn': 0.012773722627737226,
#  '|f': 0.012738853503184714,
#  'c|ct': 0.012605042016806723,
#  'd|dy': 0.012389380530973451,
#  'c|cr': 0.012345679012345678,
#  'c|co': 0.012345679012345678,
#  'g|gn': 0.012345679012345678,
#  'o|oy': 0.012259194395796848,
#  'f|fl': 0.012216404886561954,
#  'e|ey': 0.012195121951219513,
#  'u|ub': 0.011904761904761904,
#  '|t': 0.011869436201780416,
#  'n|no': 0.011816838995568686,
#  'h|ht': 0.011804384485666104,
#  't|tl': 0.011764705882352941,
#  'e|el': 0.0117096018735363,
#  'h|ho': 0.011428571428571429,
#  'y|y_': 0.011090573012939002,
#  'g|gt': 0.011090573012939002,
#  'a|a_': 0.011049723756906077,
#  '|o': 0.01098901098901099,
#  'c|cs': 0.010968921389396709,
#  'o|ol': 0.010854816824966078,
#  'd|dg': 0.010752688172043012,
#  'e|eu': 0.010638297872340425,
#  's|sp': 0.010622154779969651,
#  'u|ul': 0.010606060606060607,
#  'y|ye': 0.01060070671378092,
#  'l|la': 0.010498687664041995,
#  '|a': 0.010434782608695653,
#  'l|ls': 0.010380622837370242,
#  'n|nu': 0.010380622837370242,
#  'l|ld': 0.010238907849829351,
#  'r|ru': 0.009868421052631578,
#  'p|po': 0.009668508287292817,
#  '|m': 0.009433962264150943,
#  '|g': 0.009433962264150943,
#  'e|em': 0.009358288770053475,
#  'i|il': 0.009333333333333334,
#  'o|o_': 0.009259259259259259,
#  'y|yc': 0.009242144177449169,
#  'd|d_': 0.00922509225092251,
#  'h|hn': 0.009191176470588236,
#  'h|hs': 0.009174311926605505,
#  'm|mo': 0.009036144578313253,
#  'h|hr': 0.008960573476702509,
#  'j|jo': 0.008944543828264758,
#  's|sw': 0.008865248226950355,
#  'r|rl': 0.0088339222614841,
#  '|p': 0.008695652173913044,
#  '|l': 0.008620689655172414,
#  'k|ki': 0.008460236886632826,
#  '|b': 0.008356545961002786,
#  'u|um': 0.008051529790660225,
#  'c|cu': 0.007874015748031496,
#  'o|ot': 0.007716049382716049,
#  'e|ex': 0.007692307692307693,
#  'c|ca': 0.007653061224489796,
#  'r|r_': 0.0074211502782931356,
#  's|s_': 0.0074211502782931356,
#  'i|ir': 0.0073964497041420114,
#  'r|r-': 0.007352941176470588,
#  'r|rh': 0.007339449541284404,
#  'i|im': 0.007331378299120235,
#  'h|hl': 0.007312614259597806,
#  'i|iu': 0.007285974499089253,
#  'y|ya': 0.007272727272727273,
#  'x|xi': 0.007272727272727273,
#  'h|ha': 0.00725689404934688,
#  'x|xe': 0.007233273056057866,
#  'f|ft': 0.007194244604316547,
#  'p|ps': 0.00718132854578097,
#  'n|ny': 0.007067137809187279,
#  's|su': 0.007052186177715092,
#  'z|ze': 0.006980802792321117,
#  'v|vo': 0.006932409012131715,
#  'b|bl': 0.006868131868131868,
#  'r|rm': 0.006756756756756757,
#  'o|od': 0.006711409395973154,
#  'i|ip': 0.006600660066006601,
#  'd|dr': 0.006600660066006601,
#  'r|rd': 0.00641025641025641,
#  'q|qu': 0.006349206349206349,
#  'p|pi': 0.006289308176100629,
#  't|ty': 0.006259780907668232,
#  's|sa': 0.006125574272588055,
#  'n|nx': 0.0055762081784386614,
#  'p|p_': 0.0055762081784386614,
#  'o|o-': 0.0055658627087198514,
#  'm|m-': 0.0055658627087198514,
#  'h|h-': 0.005555555555555556,
#  'l|l_': 0.005555555555555556,
#  'e|ez': 0.005545286506469501,
#  'z|zz': 0.005545286506469501,
#  'w|wd': 0.005535055350553505,
#  'w|ws': 0.0055248618784530384,
#  'w|wl': 0.005484460694698354,
#  'l|lc': 0.005474452554744526,
#  'a|ae': 0.005474452554744526,
#  'x|xa': 0.00546448087431694,
#  'y|yo': 0.005454545454545455,
#  't|tw': 0.0054446460980036296,
#  'w|wr': 0.0054249547920434,
#  'x|xt': 0.0054249547920434,
#  'e|e-': 0.0054249547920434,
#  '|r': 0.005376344086021506,
#  'g|gl': 0.0053285968028419185,
#  'a|aw': 0.005309734513274336,
#  'h|hy': 0.005291005291005291,
#  'u|ud': 0.00528169014084507,
#  't|tc': 0.005253940455341506,
#  'o|ok': 0.005244755244755245,
#  'r|rg': 0.0051635111876075735,
#  'l|lt': 0.005145797598627788,
#  'l|lu': 0.005008347245409015,
#  'o|og': 0.0049504950495049506,
#  'w|wa': 0.004942339373970346,
#  'c|cl': 0.004885993485342019,
#  '|d': 0.004866180048661801,
#  'l|ly': 0.004866180048661801,
#  'b|bo': 0.0048,
#  'b|ba': 0.0047694753577106515,
#  'o|op': 0.004622496147919877,
#  'o|os': 0.004608294930875576,
#  'i|iv': 0.004477611940298508,
#  'a|ab': 0.00436046511627907,
#  'o|om': 0.003931847968545216,
#  'k|k_': 0.0037243947858473,
#  'w|w_': 0.0037243947858473,
#  'f|f_': 0.0037243947858473,
#  'w|wy': 0.0037243947858473,
#  'h|hh': 0.0037243947858473,
#  'w|w-': 0.0037174721189591076,
#  't|tg': 0.0037174721189591076,
#  'a|a-': 0.0037105751391465678,
#  'n|np': 0.003703703703703704,
#  'k|k-': 0.003703703703703704,
#  't|tn': 0.0036968576709796672,
#  'd|d-': 0.0036900369003690036,
#  'f|fy': 0.0036900369003690036,
#  'g|g-': 0.0036900369003690036,
#  'l|lp': 0.0036900369003690036,
#  'o|oh': 0.003683241252302026,
#  'n|nj': 0.003663003663003663,
#  'l|l-': 0.003656307129798903,
#  's|sn': 0.003656307129798903,
#  'b|bt': 0.0036496350364963502,
#  'n|nl': 0.0036429872495446266,
#  't|tm': 0.0036429872495446266,
#  'l|lv': 0.0036429872495446266,
#  'e|eh': 0.0036231884057971015,
#  'k|kn': 0.0035971223021582736,
#  'l|lf': 0.0035971223021582736,
#  'g|gy': 0.003590664272890485,
#  'y|ym': 0.0035778175313059034,
#  'b|bs': 0.0035778175313059034,
#  'r|rk': 0.0035778175313059034,
#  'w|wn': 0.0035714285714285713,
#  'j|ju': 0.0035398230088495575,
#  'r|rp': 0.0035149384885764497,
#  'n|nk': 0.0035087719298245615,
#  's|sy': 0.0035087719298245615,
#  'm|mu': 0.0034782608695652175,
#  'u|ug': 0.0034542314335060447,
#  'o|ob': 0.0034423407917383822,
#  'a|ak': 0.003430531732418525,
#  'i|if': 0.003430531732418525,
#  'p|pu': 0.003430531732418525,
#  'w|wo': 0.003389830508474576,
#  'a|av': 0.00338409475465313,
#  'u|up': 0.003316749585406302,
#  'v|va': 0.003316749585406302,
#  'w|wi': 0.0033003300330033004,
#  'f|fa': 0.0032948929159802307,
#  'd|do': 0.003284072249589491,
#  'e|ef': 0.003236245954692557,
#  'a|ag': 0.003003003003003003,
#  'a|ap': 0.0029542097488921715,
#  '|c': 0.002805049088359046}

# %% [markdown]
# Now it's time to develop the function that will give the best candidates given that the typo is of type **deletion**. Initially, before looking into smoothing, I had developed this function, which doesn't give me existing words as candidates if the character permutations are not in the conditional probabilities deletion dictionary:

# %%
def del_best_match_initial(typo):
    """Function that takes a typo and returns a dictionary with probabilities of the best candidates, given that
    the typo is of deletion-type, and the best candidate"""
    d = {}
    for word in intended_possible_words(typo):
        if typo in deletion(word):
            try:
                cond_p = del_diff(word, typo) #get the difference in cond prob format
                if word in abs_prob_big.keys(): #and cond_p in cond_prob_del.keys():
                    d[word] = '{0:.10f}'.format((cond_prob_del[cond_p])*abs_prob_big[word]) #multiply the conditional probability we got from the typo corpus with the absolute probability of the possible word that was meant
            except KeyError as e: #when conditional probability not in deletion probability dictionary
                print(word + ": the conditional probability of " + str(e) + " is not present in the deletion probabilities dictionary, since some bigrams present in vocab might be absent from the typo corpus")
                
    d = {k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse = True)}
    return d, max(d, key=d.get) #the max function takes the candidate with highest probability

# %%
del_best_match_initial("he") #here it can be seen that hew and hue are just not in the candidates
# Out:
# hew: the conditional probability of 'e|ew' is not present in the deletion probabilities dictionary, since some bigrams present in vocab might be absent from the typo corpus
# hue: the conditional probability of 'h|hu' is not present in the deletion probabilities dictionary, since some bigrams present in vocab might be absent from the typo corpus
# ({'the': '0.0007312800',
#   'her': '0.0001546026',
#   'she': '0.0000455616',
#   'hen': '0.0000002101',
#   'hey': '0.0000000946',
#   'hem': '0.0000000363',
#   'heh': '0.0000000084'},
#  'the')

# %% [markdown]
# However, this is undesirable. Coming back to Laplace smoothing, in case the character permutation that occurred in the typo typed by the user is not present in the conditional probability deletion dictionary, we will simply give it **a count of 1 and divide by the count of the intended characters + length of bigrams/letters**, as we did earlier. Then, just as we do with present probabilities, we will multiply it by the **absolute probability** of the word occurring.

# %%
def del_best_match(typo):
    """Function that takes a typo and returns a dictionary with smoothed probabilities of the best candidates, given that
    the typo is of deletion-type, and the best candidate"""
    d = {}
    for word in intended_possible_words(typo):
        if typo in deletion(word):
            if word in abs_prob_big.keys(): #if the word is in our dictionary that gives absolute probabilities
                try: #if the character confusion is present in the deletion count dictionary
                    cond_p = del_diff(word, typo)
                    d[word] = '{0:.10f}'.format((cond_prob_del[cond_p])*abs_prob_big[word]) #multiply the conditional probability we got from the typo corpus with the absolute probability of the possible word that was meant
                except KeyError: #if character confusion not present in the deletion count dictionary
                    cond_p = del_diff(word, typo)
                    split = cond_p.split("|") #split into typed and intended
                    intend = split[1]
                    if len(intend) == 2: #if intended is a bigram
                        try:
                            d[word] = '{0:.10f}'.format(((1/(bigrams_target[intend]+len(bigrams_target)))*abs_prob_big[word])) #count of 1
                        except KeyError: #if the bigram is not in the bigrams target
                            d[word] = '{0:.10f}'.format(((1/(bigrams_target["unseen"]+len(bigrams_target)))*abs_prob_big[word])) #count of 0+length of the bigrams target
                    else:
                        try:
                            d[word] = '{0:.10f}'.format((1/(letter_zero_count[intend]+len(letter_zero_count)))*abs_prob_big[word]) #count of 1
                        except KeyError: #if the letter is unseen in the letter_zero_count
                            d[word] = '{0:.10f}'.format((1/(letter_zero_count["unseen"]+len(letter_zero_count)))*abs_prob_big[word]) #count of 0+length of the bigrams target
            
    d = {k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse = True)}
    if len(d) > 0: #if the dictionary is not empty
        return d, max(d, key=d.get)
    else:
        return d,

# %%
del_best_match("he")
# Out:
# ({'the': '0.0007312800',
#   'her': '0.0001546026',
#   'she': '0.0000455616',
#   'hen': '0.0000002101',
#   'hey': '0.0000000946',
#   'hem': '0.0000000363',
#   'hue': '0.0000000179',
#   'heh': '0.0000000084',
#   'hew': '0.0000000027'},
#  'the')

# %% [markdown]
# Now the candidates with absent permutations are also there!

# %%
del_best_match("sta")
# Out:
# ({'seta': '0.0000030929',
#   'star': '0.0000027226',
#   'stra': '0.0000026880',
#   'stan': '0.0000024048',
#   'sita': '0.0000018886',
#   'stay': '0.0000012559',
#   'stoa': '0.0000008359',
#   'stam': '0.0000008027',
#   'asta': '0.0000005654',
#   'staw': '0.0000002877',
#   'stab': '0.0000002363',
#   'stag': '0.0000001627',
#   'stap': '0.0000001601'},
#  'seta')

# %%
del_best_match("the")
# Out:
# ({'then': '0.0000437531',
#   'they': '0.0000277923',
#   'them': '0.0000146300',
#   'thee': '0.0000019965'},
#  'then')

# %%
del_best_match("intigued")
# Out:
# ({},)

# %% [markdown]
# ### Insertion
#
# Here, I do exactly the same as I did for the deletion function, except I change the mechanism of detecting the difference. Indeed, here we are looking for:
#
# **x|y** --> inserting an **x** after a **y**
#
# The tricky case here is also when the insertion occurs at letter zero position, in which case the probability is:
#
# **x|""** --> an **x** inserted after the empty space that is at the beginning of the word.
#
# In order to calculate the conditional probability, I will have to divide the **count of x inserted before y** by the **count of y** (but we will use Laplace smoothing, once again).

# %%
def insert_diff(target, typo):
    """Function that takes a target and a typo of insertion type and returns the character permutation in the form
    of conditional probability"""
    global cond_p_ins
    if typo[-1] != target[-1]: #if the insertion occurs at last position
        cond_p_ins = typo[-1].lower() + "|" + target[-1].lower() #insertion at the last letter position given the last letter of the target word
    for i in range(len(target)): #take the shorter one not to incur in index errors (last position already accounted for in first condition)
        if target[i] != typo[i]: #comparison
            if i != 0: #if letter not inserted at position 0
                cond_p_ins = typo[i].lower() + "|" + target[i-1].lower() #insertion of a letter given another letter seen before
                break
            if i == 0: #if insertion occurs at first position: x given "" before
                cond_p_ins = typo[i].lower() + "|"
                break
    return cond_p_ins

# %%
insert_diff("hello", "helflo")
# Out:
# 'f|l'

# %% [markdown]
# Here I define the function of a letter occurring in the target (not only at position zero, like in deletion), since I will need that to calculate the conditional probabilities later on.

# %%
def occur_letter_in_target(typo_corpus):
    """Function that takes a typo corpus and returns a dictionary with the number occurrences for each letter
    in the corpus"""
    occ = {}
    for tar in typo_corpus.keys():
        for letter in tar:
            if letter not in occ:
                occ[letter] = 0
            else:
                occ[letter] += 1
    return occ

# %%
letter_count_target = {k:v for k,v in sorted(occur_letter_in_target(target_typos).items(), key=lambda x:x[0])}
letter_count_target["unseen"] = 0
letter_count_target
# Out:
# {"'": 0,
#  '-': 93,
#  '_': 66,
#  'a': 3772,
#  'b': 819,
#  'c': 2205,
#  'd': 1882,
#  'e': 6100,
#  'f': 693,
#  'g': 1299,
#  'h': 1054,
#  'i': 3956,
#  'j': 83,
#  'k': 348,
#  'l': 2507,
#  'm': 1394,
#  'n': 3529,
#  'o': 3058,
#  'p': 1540,
#  'q': 93,
#  'r': 3578,
#  's': 3388,
#  't': 3428,
#  'u': 1588,
#  'v': 559,
#  'w': 458,
#  'x': 142,
#  'y': 932,
#  'z': 65,
#  'unseen': 0}

# %%
def insert_prob_smooth(insert_typos):
    """Function that takes a corpus of insertion typos and returns a dictionary of all the smoothed
    conditional probabilities for character permutations"""
    cond_prob_l = []
    for target, typos in insert_typos.items(): #for target and typos
        for typo in typos:
            c_p = insert_diff(target, typo)
            cond_prob_l.append(c_p)
            
    counts = {}
    for cp in cond_prob_l:
        if cp not in counts:
            counts[cp] = 1
        else:
            counts[cp] += 1
    
    prob = {}
    for pair, count in counts.items():
        letter_before = pair.split("|")[1] #take the second part, which is the letter before the inserted letter
        if letter_before != '': #if insertion not at position zero
            prob[pair] = (counts[pair]+1)/(letter_count_target[letter_before]+len(letter_count_target)) #smoothed probability
        else: #if insertion at position zero
            prob[pair] = (counts[pair]+1)/(len(target_typos)+len(target_typos))#divided by all the times there is empty space in position zero, hence all words

    prob_sorted = {k: v for k, v in sorted(prob.items(), key=lambda x: x[1], reverse = True)}
    return prob_sorted

# %%
cond_prob_insert = insert_prob_smooth(insertion_)
cond_prob_insert
# Out:
# {'s|x': 0.12280701754385964,
#  'c|x': 0.08771929824561403,
#  'e|k': 0.06631299734748011,
#  'l|l': 0.03943217665615142,
#  'e|w': 0.039014373716632446,
#  'f|f': 0.038781163434903045,
#  'm|m': 0.03794799718903725,
#  'e|h': 0.03508771929824561,
#  'h|w': 0.03285420944558522,
#  'e|v': 0.03231292517006803,
#  'e|t': 0.029505351460804165,
#  'h|x': 0.029239766081871343,
#  'e|p': 0.0248565965583174,
#  'e|l': 0.02444794952681388,
#  'e|d': 0.024071166928309785,
#  'e|m': 0.023893183415319746,
#  'e|r': 0.023565289714444135,
#  'i|v': 0.022108843537414966,
#  'u|o': 0.021379980563654033,
#  's|s': 0.021363769388352355,
#  'z|z': 0.02127659574468085,
#  'w|_': 0.021052631578947368,
#  'e|n': 0.020517144463181564,
#  'e|g': 0.02033132530120482,
#  't|t': 0.01851316170089673,
#  'r|r': 0.018297754366509565,
#  'o|j': 0.017857142857142856,
#  'u|j': 0.017857142857142856,
#  'p|p': 0.017845761631612493,
#  'e|s': 0.01726660813579163,
#  'c|c': 0.017009847806624886,
#  'r|u': 0.016697588126159554,
#  'e|y': 0.01664932362122789,
#  'q|q': 0.01639344262295082,
#  's|k': 0.015915119363395226,
#  'n|n': 0.015739179314221474,
#  'e|f': 0.015235457063711912,
#  'e|u': 0.014842300556586271,
#  'a|e': 0.012889541523902757,
#  'd|d': 0.012558869701726845,
#  't|x': 0.011695906432748537,
#  'i|x': 0.011695906432748537,
#  'e|x': 0.011695906432748537,
#  'i|a': 0.01157590107866351,
#  'e|i': 0.011543287327478042,
#  'r|a': 0.01078663509602736,
#  'e|b': 0.01061320754716981,
#  'b|b': 0.01061320754716981,
#  'i|u': 0.010513296227581941,
#  's|y': 0.009365244536940686,
#  'a|u': 0.00927643784786642,
#  'u|g': 0.009036144578313253,
#  'r|e': 0.008973731440691793,
#  'i|t': 0.008967312698871854,
#  'o|o': 0.008746355685131196,
#  'i|l': 0.008675078864353312,
#  't|h': 0.008310249307479225,
#  's|b': 0.008254716981132075,
#  'l|w': 0.008213552361396304,
#  'i|n': 0.008150646430578976,
#  'e|c': 0.008057296329453895,
#  'k|c': 0.008057296329453895,
#  'n|m': 0.007730147575544624,
#  'h|p': 0.0076481835564053535,
#  's|t': 0.007231703789412786,
#  'a|m': 0.007027406886858749,
#  'i|r': 0.006930967563071805,
#  'e|e': 0.0065263501386849405,
#  'w|o': 0.00647878198898607,
#  't|c': 0.006266786034019696,
#  's|n': 0.006183249016301293,
#  't|n': 0.005902192242833052,
#  'r|b': 0.00589622641509434,
#  'a|b': 0.00589622641509434,
#  'd|e': 0.005873715124816446,
#  's|e': 0.005873715124816446,
#  'h|c': 0.005819158460161146,
#  'i|c': 0.005819158460161146,
#  'h|t': 0.005785363031530229,
#  'a|i': 0.005771643663739021,
#  'i|s': 0.00556043312847527,
#  'r|f': 0.00554016620498615,
#  'i|h': 0.00554016620498615,
#  'a|h': 0.00554016620498615,
#  'r|h': 0.00554016620498615,
#  'u|a': 0.0055248618784530384,
#  'a|o': 0.00550696469063816,
#  'k|k': 0.005305039787798408,
#  'g|k': 0.005305039787798408,
#  'i|k': 0.005305039787798408,
#  'g|g': 0.005271084337349397,
#  's|i': 0.005269761606022585,
#  'c|s': 0.0052677787532923615,
#  'n|a': 0.005261773217574322,
#  'r|v': 0.00510204081632653,
#  'n|u': 0.004947433518862091,
#  'i|m': 0.004919184820801124,
#  'e|o': 0.004859086491739553,
#  'n|i': 0.004767879548306148,
#  'u|b': 0.0047169811320754715,
#  'o|b': 0.0047169811320754715,
#  'o|h': 0.0046168051708217915,
#  'h|h': 0.0046168051708217915,
#  'r|o': 0.0045351473922902496,
#  'h|g': 0.004518072289156626,
#  'd|n': 0.004496908375491849,
#  'i|p': 0.004461440407903123,
#  's|r': 0.004435819240365955,
#  'i|e': 0.004405286343612335,
#  't|u': 0.004329004329004329,
#  's|m': 0.004216444132115249,
#  'u|m': 0.004216444132115249,
#  'o|f': 0.004155124653739612,
#  'd|w': 0.004106776180698152,
#  's|w': 0.004106776180698152,
#  'o|c': 0.0040286481647269475,
#  'c|a': 0.003946329913180742,
#  's|a': 0.003946329913180742,
#  'n|e': 0.003915810083210965,
#  'n|o': 0.003887269193391642,
#  'r|p': 0.0038240917782026767,
#  's|g': 0.0037650602409638554,
#  'c|i': 0.0037641154328732747,
#  'c|u': 0.0037105751391465678,
#  'u|h': 0.003693444136657433,
#  'a|d': 0.003663003663003663,
#  'i|o': 0.0035633300939423387,
#  'i|b': 0.003537735849056604,
#  'y|v': 0.003401360544217687,
#  'n|v': 0.003401360544217687,
#  'a|v': 0.003401360544217687,
#  'o|v': 0.003401360544217687,
#  'c|v': 0.003401360544217687,
#  'c|n': 0.003372681281618887,
#  't|s': 0.003219198127011999,
#  'o|l': 0.0031545741324921135,
#  'a|l': 0.0031545741324921135,
#  'i|d': 0.0031397174254317113,
#  's|d': 0.0031397174254317113,
#  'i|y': 0.003121748178980229,
#  't|g': 0.0030120481927710845,
#  't|i': 0.00301129234629862,
#  'y|r': 0.0027723870252287217,
#  'g|h': 0.002770083102493075,
#  'l|h': 0.002770083102493075,
#  't|f': 0.002770083102493075,
#  'i|f': 0.002770083102493075,
#  'o|i': 0.0027603513174404015,
#  's|c': 0.0026857654431512983,
#  'u|c': 0.0026857654431512983,
#  'm|o': 0.0025915127955944283,
#  't|p': 0.0025493945188017845,
#  'o|p': 0.0025493945188017845,
#  'g|n': 0.002529510961214165,
#  'd|u': 0.0024737167594310453,
#  's|u': 0.0024737167594310453,
#  's|l': 0.002365930599369085,
#  'y|b': 0.0023584905660377358,
#  'l|b': 0.0023584905660377358,
#  't|b': 0.0023584905660377358,
#  'a|t': 0.0023141452126120912,
#  'r|g': 0.002259036144578313,
#  'i|g': 0.002259036144578313,
#  'a|g': 0.002259036144578313,
#  'd|g': 0.002259036144578313,
#  'd|i': 0.002258469259723965,
#  'r|i': 0.002258469259723965,
#  'y|m': 0.0021082220660576245,
#  'b|m': 0.0021082220660576245,
#  'o|m': 0.0021082220660576245,
#  'a|a': 0.002104709287029729,
#  'u|y': 0.002081165452653486,
#  'a|s': 0.002048580626280363,
#  'h|s': 0.002048580626280363,
#  'r|t': 0.00202487706103558,
#  'o|n': 0.0019673974142776843,
#  'l|p': 0.0019120458891013384,
#  'g|u': 0.0018552875695732839,
#  'l|u': 0.0018552875695732839,
#  'm|u': 0.0018552875695732839,
#  's|h': 0.0018467220683287165,
#  'y|h': 0.0018467220683287165,
#  't|a': 0.001841620626151013,
#  'l|a': 0.001841620626151013,
#  'c|e': 0.0017947462881383587,
#  'y|c': 0.0017905102954341987,
#  'u|i': 0.0017565872020075283,
#  'a|r': 0.0016634322151372332,
#  'u|r': 0.0016634322151372332,
#  'l|r': 0.0016634322151372332,
#  'c|o': 0.0016196954972465176,
#  'e|a': 0.0015785319652722968,
#  'l|d': 0.0015698587127158557,
#  'o|g': 0.0015060240963855422,
#  'o|e': 0.0014684287812041115,
#  'u|s': 0.0014632718759145448,
#  'u|t': 0.0014463407578825572,
#  't|m': 0.0014054813773717498,
#  'r|m': 0.0014054813773717498,
#  'a|n': 0.001405283867341203,
#  'd|r': 0.0013861935126143609,
#  'x|c': 0.0013428827215756492,
#  'd|a': 0.0013154433043935806,
#  'y|a': 0.0013154433043935806,
#  'y|e': 0.0013052700277369881,
#  's|o': 0.0012957563977972141,
#  'p|o': 0.0012957563977972141,
#  't|o': 0.0012957563977972141,
#  's|p': 0.0012746972594008922,
#  'a|p': 0.0012746972594008922,
#  'm|i': 0.0012547051442910915,
#  'i|i': 0.0012547051442910915,
#  'o|u': 0.0012368583797155227,
#  'u|u': 0.0012368583797155227,
#  'v|u': 0.0012368583797155227,
#  'h|u': 0.0012368583797155227,
#  'y|l': 0.0011829652996845426,
#  'u|l': 0.0011829652996845426,
#  'o|t': 0.0011570726063060456,
#  'k|n': 0.0011242270938729624,
#  'u|n': 0.0011242270938729624,
#  'r|n': 0.0011242270938729624,
#  'c|r': 0.0011089548100914888,
#  't|r': 0.0011089548100914888,
#  'h|a': 0.0010523546435148646,
#  'f|d': 0.0010465724751439038,
#  'o|d': 0.0010465724751439038,
#  'r|d': 0.0010465724751439038,
#  't|d': 0.0010465724751439038,
#  'j|d': 0.0010465724751439038,
#  'l|i': 0.0010037641154328732,
#  'h|': 0.0009891949474965759,
#  'l|e': 0.0009789525208027412,
#  'l|o': 0.0009718172983479105,
#  'n|c': 0.0008952551477170994,
#  'q|c': 0.0008952551477170994,
#  'p|c': 0.0008952551477170994,
#  'l|c': 0.0008952551477170994,
#  'v|c': 0.0008952551477170994,
#  'a|c': 0.0008952551477170994,
#  'n|s': 0.000877963125548727,
#  'd|s': 0.000877963125548727,
#  'j|t': 0.0008678044547295343,
#  'd|t': 0.0008678044547295343,
#  'o|r': 0.0008317161075686166,
#  'n|r': 0.0008317161075686166,
#  'r|l': 0.0007886435331230284,
#  't|l': 0.0007886435331230284,
#  'm|l': 0.0007886435331230284,
#  'd|l': 0.0007886435331230284,
#  'c|l': 0.0007886435331230284,
#  'y|i': 0.000752823086574655,
#  'f|i': 0.000752823086574655,
#  'p|e': 0.0006526350138684941,
#  'k|e': 0.0006526350138684941,
#  'h|o': 0.0006478781988986071,
#  'y|o': 0.0006478781988986071,
#  'w|s': 0.000585308750365818,
#  'o|s': 0.000585308750365818,
#  'm|s': 0.000585308750365818,
#  'l|s': 0.000585308750365818,
#  'c|t': 0.0005785363031530228,
#  'l|t': 0.0005785363031530228,
#  'g|t': 0.0005785363031530228,
#  'y|t': 0.0005785363031530228,
#  'n|t': 0.0005785363031530228,
#  'w|n': 0.0005621135469364812,
#  'b|n': 0.0005621135469364812,
#  'h|n': 0.0005621135469364812,
#  'v|r': 0.0005544774050457444,
#  'h|r': 0.0005544774050457444,
#  'w|': 0.000532643433267387,
#  'a|': 0.000532643433267387,
#  'g|a': 0.0005261773217574323,
#  'v|i': 0.0005018820577164366,
#  'h|i': 0.0005018820577164366,
#  'x|i': 0.0005018820577164366,
#  'z|i': 0.0005018820577164366,
#  'p|i': 0.0005018820577164366,
#  'g|i': 0.0005018820577164366,
#  'u|e': 0.0004894762604013706,
#  't|': 0.0003804595951909907,
#  'k|': 0.0003804595951909907,
#  'e|': 0.0003804595951909907,
#  'x|e': 0.00032631750693424703,
#  'g|e': 0.00032631750693424703,
#  't|e': 0.00032631750693424703,
#  'z|e': 0.00032631750693424703,
#  'l|': 0.00030436767615279255,
#  's|': 0.00022827575711459444,
#  'm|': 0.00015218383807639628,
#  'o|': 0.00015218383807639628,
#  'p|': 0.00015218383807639628,
#  'u|': 0.00015218383807639628,
#  'g|': 0.00015218383807639628}

# %%
def insert_best_match(typo):
    """Function that takes a typo and returns a dictionary with smoothed probabilities of the best candidates, given that
    the typo is of insertion-type, and the best candidate"""
    d = {}
    for word in intended_possible_words(typo):
        if typo in insertion(word):
            if word in abs_prob_big.keys(): 
                try:
                    cond_p = insert_diff(word, typo)
                    d[word] = '{0:.10f}'.format((cond_prob_insert[cond_p])*abs_prob_big[word]) #multiply the conditional probability we got from the typo corpus with the absolute probability of the possible 
                except KeyError as e: 
                    cond_p = insert_diff(word, typo)
                    split = cond_p.split("|") #split into typed and intended
                    intend = split[1]
                    if intend != '': #if insertion doesn't happen in position zero
                        try:
                            d[word] = '{0:.10f}'.format((1/(letter_count_target[intend]+len(letter_count_target)))*abs_prob_big[word]) #count of 1
                        except KeyError: #if the letter in target that insert follows is unseen in the letter_count_target
                            d[word] = '{0:.10f}'.format((1/(letter_count_target["unseen"]+len(letter_count_target)))*abs_prob_big[word]) #cou
                    else: #if insertion happens in position zero
                        d[word] = '{0:.10f}'.format((1/(len(letter_count_target)+len(letter_count_target)))*abs_prob_big[word]) #count of 1
                        
    d = {k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse = True)}
    if len(d) > 0:
        return d, max(d, key=d.get)
    else:
        return d,

# %%
insert_best_match("rnot")
# Out:
# ({'not': '0.0000922832', 'rot': '0.0000000013'}, 'not')

# %%
insert_best_match("strain")
# Out:
# ({'stain': '0.0000000377', 'train': '0.0000000103'}, 'stain')

# %%
insert_best_match("card")
# Out:
# ({'car': '0.0000000075'}, 'car')

# %%
insert_best_match("penciel")
# Out:
# ({'pencil': '0.0000000985'}, 'pencil')

# %%
insert_best_match("acress")
# Out:
# ({'acres': '0.0000003314'}, 'acres')

# %% [markdown]
# ### Transposition
#
# Again, same process, except we need:
#
# **yx|xy** --> typed **yx** given intended **xy**
#
# Here, options are straightforward, since it will always concern characters present in the target word. To calculate probability, **the count of yx|xy** needs to be divided by the **count of xy** (Laplace smoothing will be used).

# %%
def transp_diff(target, typo):
    """Function that takes a target and a typo of transposition type and returns the character permutation in the form
    of conditional probability"""
    global cond_prob_t
    for i in range(len(target)):
        if target[i] != typo[i]:
            cond_prob_t = typo[i] + typo[i+1] + "|" + target[i] + target[i+1] #yx given xy
            break
    return cond_prob_t

# %%
transp_diff("hello", "helol") #checking
# Out:
# 'ol|lo'

# %%
def transp_prob_smooth(transp_typos):
    """Function that takes a corpus of transposition typos and returns a dictionary of all the smoothed
    conditional probabilities for character permutations"""
    cond_prob_l = []
    for target, typos in transp_typos.items(): #for target and typos
        for typo in typos:
            c_p = transp_diff(target, typo)
            cond_prob_l.append(c_p)
            
    counts = {}
    for cp in cond_prob_l:
        if cp not in counts:
            counts[cp] = 1
        else:
            counts[cp] += 1
    
    prob = {}
    for pair, count in counts.items():
        intended_bigram = pair.split("|")[1] #take the second part, which is the letter before the inserted letter
        prob[pair] = (counts[pair]+1)/(bigrams_target[intended_bigram]+len(bigrams_target)) #smoothed probability
    
    prob_sorted = {k: v for k, v in sorted(prob.items(), key=lambda x: x[1], reverse = True)}
    return prob_sorted

# %%
cond_prob_transp = transp_prob_smooth(transposition_)
cond_prob_transp
# Out:
# {'ei|ie': 0.09186351706036745,
#  'ie|ei': 0.07058823529411765,
#  'el|le': 0.05708848715509039,
#  'le|el': 0.04449648711943794,
#  'ia|ai': 0.040697674418604654,
#  'ro|or': 0.026096033402922755,
#  'ri|ir': 0.02514792899408284,
#  'er|re': 0.02472952086553323,
#  'th|ht': 0.023608768971332208,
#  'ai|ia': 0.02346041055718475,
#  'ae|ea': 0.022909507445589918,
#  'ir|ri': 0.021574973031283712,
#  'au|ua': 0.021172638436482084,
#  're|er': 0.0196078431372549,
#  'io|oi': 0.01896551724137931,
#  'or|ro': 0.01710376282782212,
#  'ed|de': 0.016722408026755852,
#  'es|se': 0.01646542261251372,
#  'ue|eu': 0.015957446808510637,
#  'ht|th': 0.014725568942436412,
#  'iu|ui': 0.014354066985645933,
#  'gd|dg': 0.014336917562724014,
#  'ng|gn': 0.014109347442680775,
#  'ct|tc': 0.014010507880910683,
#  'ra|ar': 0.013793103448275862,
#  'me|em': 0.013368983957219251,
#  'la|al': 0.01330603889457523,
#  'se|es': 0.013250883392226149,
#  'in|ni': 0.013210039630118891,
#  'ci|ic': 0.013126491646778043,
#  'en|ne': 0.01273148148148148,
#  'oi|io': 0.012429378531073447,
#  'ru|ur': 0.012345679012345678,
#  'si|is': 0.012035010940919038,
#  'ka|ak': 0.012006861063464836,
#  'de|ed': 0.011854360711261643,
#  'ur|ru': 0.011513157894736841,
#  'na|an': 0.0113314447592068,
#  'et|te': 0.01100762066045724,
#  'ea|ae': 0.010948905109489052,
#  'te|et': 0.01078167115902965,
#  'wo|ow': 0.010752688172043012,
#  'li|il': 0.010666666666666666,
#  'hw|wh': 0.010398613518197574,
#  'on|no': 0.0103397341211226,
#  'ah|ha': 0.010159651669085631,
#  'ua|au': 0.010135135135135136,
#  'ao|oa': 0.010101010101010102,
#  'ul|lu': 0.01001669449081803,
#  'ar|ra': 0.01,
#  'ya|ay': 0.009933774834437087,
#  'ic|ci': 0.009929078014184398,
#  'is|si': 0.009615384615384616,
#  'lo|ol': 0.009497964721845319,
#  'ek|ke': 0.009448818897637795,
#  'ol|lo': 0.009320905459387484,
#  'po|op': 0.009244992295839754,
#  'il|li': 0.00922722029988466,
#  'eo|oe': 0.008944543828264758,
#  'ne|en': 0.008863819500402902,
#  'dl|ld': 0.008532423208191127,
#  'ow|wo': 0.00847457627118644,
#  'an|na': 0.008321775312066574,
#  'uo|ou': 0.008092485549132947,
#  'em|me': 0.008045977011494253,
#  'am|ma': 0.0079155672823219,
#  'ts|st': 0.00791295746785361,
#  'al|la': 0.007874015748031496,
#  'eh|he': 0.0076726342710997444,
#  'ac|ca': 0.007653061224489796,
#  'st|ts': 0.0075075075075075074,
#  'dn|nd': 0.007407407407407408,
#  'sp|ps': 0.00718132854578097,
#  'nw|wn': 0.007142857142857143,
#  'oh|ho': 0.007142857142857143,
#  'ey|ye': 0.007067137809187279,
#  'kn|nk': 0.007017543859649123,
#  'sl|ls': 0.006920415224913495,
#  'lt|tl': 0.0067226890756302525,
#  'nu|un': 0.006702412868632708,
#  'ug|gu': 0.006633499170812604,
#  'lc|cl': 0.006514657980456026,
#  'ni|in': 0.006510416666666667,
#  'fe|ef': 0.006472491909385114,
#  'ig|gi': 0.006462035541195477,
#  'uc|cu': 0.006299212598425197,
#  'om|mo': 0.006024096385542169,
#  'gi|ig': 0.006024096385542169,
#  'yr|ry': 0.0058309037900874635,
#  'gn|ng': 0.005639097744360902,
#  'sr|rs': 0.005610098176718092,
#  'ot|to': 0.005610098176718092,
#  'oa|ao': 0.005555555555555556,
#  'ui|iu': 0.00546448087431694,
#  'ti|it': 0.00544069640914037,
#  'ou|uo': 0.005434782608695652,
#  'im|mi': 0.005405405405405406,
#  'kr|rk': 0.005366726296958855,
#  'iy|yi': 0.0053475935828877,
#  'oe|eo': 0.005309734513274336,
#  'ca|ac': 0.005249343832020997,
#  'sy|ys': 0.005235602094240838,
#  'hc|ch': 0.005208333333333333,
#  'tl|lt': 0.005145797598627788,
#  'va|av': 0.005076142131979695,
#  'iw|wi': 0.0049504950495049506,
#  'hp|ph': 0.0049261083743842365,
#  'eu|ue': 0.004909983633387889,
#  'at|ta': 0.0048721071863581,
#  'yl|ly': 0.004866180048661801,
#  'ag|ga': 0.004846526655896607,
#  'ef|fe': 0.0046801872074883,
#  'so|os': 0.004608294930875576,
#  'cs|sc': 0.004552352048558422,
#  'lu|ul': 0.004545454545454545,
#  'di|id': 0.004484304932735426,
#  'ma|am': 0.0044444444444444444,
#  'ih|hi': 0.004424778761061947,
#  'ta|at': 0.00441696113074205,
#  'mi|im': 0.004398826979472141,
#  'ba|ab': 0.00436046511627907,
#  'eg|ge': 0.004137931034482759,
#  'sn|ns': 0.003989361702127659,
#  'su|us': 0.003896103896103896,
#  'sa|as': 0.0038860103626943004,
#  'id|di': 0.0038412291933418692,
#  'tn|nt': 0.003734827264239029,
#  'ze|ez': 0.0036968576709796672,
#  '_t|t_': 0.003683241252302026,
#  'ly|yl': 0.003656307129798903,
#  'lw|wl': 0.003656307129798903,
#  'nm|mn': 0.0036496350364963502,
#  'kl|lk': 0.0036496350364963502,
#  'ep|pe': 0.0036452004860267314,
#  'ln|nl': 0.0036429872495446266,
#  'ix|xi': 0.0036363636363636364,
#  'mn|nm': 0.0036363636363636364,
#  'rw|wr': 0.003616636528028933,
#  'nk|kn': 0.0035971223021582736,
#  'sm|ms': 0.0035587188612099642,
#  'uh|hu': 0.003552397868561279,
#  'ld|dl': 0.003552397868561279,
#  'ws|sw': 0.0035460992907801418,
#  'yd|dy': 0.0035398230088495575,
#  'fo|of': 0.003527336860670194,
#  'du|ud': 0.0035211267605633804,
#  'ev|ve': 0.0035087719298245615,
#  'ys|sy': 0.0035087719298245615,
#  'zi|iz': 0.0034965034965034965,
#  'we|ew': 0.0034904013961605585,
#  'ye|ey': 0.003484320557491289,
#  'un|nu': 0.0034602076124567475,
#  'gr|rg': 0.0034423407917383822,
#  'ud|du': 0.003436426116838488,
#  'up|pu': 0.003430531732418525,
#  'og|go': 0.003395585738539898,
#  'it|ti': 0.003395585738539898,
#  'mr|rm': 0.0033783783783783786,
#  'cu|uc': 0.003372681281618887,
#  'bm|mb': 0.003367003367003367,
#  'uf|fu': 0.0033112582781456954,
#  'vo|ov': 0.003305785123966942,
#  'go|og': 0.0033003300330033004,
#  'nr|rn': 0.003284072249589491,
#  'od|do': 0.003284072249589491,
#  'mu|um': 0.00322061191626409,
#  'co|oc': 0.003215434083601286,
#  'kc|ck': 0.0031545741324921135,
#  'ad|da': 0.003125,
#  'pe|ep': 0.003110419906687403,
#  'oc|co': 0.0030864197530864196,
#  'to|ot': 0.0030864197530864196,
#  'ps|sp': 0.0030349013657056147,
#  'lp|pl': 0.0030303030303030303,
#  'ut|tu': 0.0030211480362537764,
#  'os|so': 0.0030075187969924814,
#  'pa|ap': 0.0029542097488921715,
#  'op|po': 0.0027624309392265192,
#  'lb|bl': 0.0027472527472527475,
#  'mo|om': 0.002621231979030144,
#  'rt|tr': 0.0026109660574412533,
#  'cn|nc': 0.002583979328165375,
#  'ec|ce': 0.002190580503833516,
#  'no|on': 0.0016625103906899418}

# %%
def transp_best_match(typo):
    """Function that takes a typo and returns a dictionary with smoothed probabilities of the best candidates, given that
    the typo is of transposition-type, and the best candidate"""
    d = {}
    for word in intended_possible_words(typo):
        if typo in transposition(word):
            if word in abs_prob_big.keys(): #and cond_p in cond_prob_del.keys():
                try:
                    cond_p_transp = transp_diff(word, typo)
                    d[word] = '{0:.10f}'.format((cond_prob_transp[cond_p_transp])*abs_prob_big[word]) #multiply the conditional probability we got from the typo corpus with the absolute probability of the possible 
                except KeyError as e: #when conditional probability is not in dictionary
                    cond_p_transp = transp_diff(word, typo)
                    split = cond_p_transp.split("|") #split into typed and intended
                    intend = split[1]
                    try:
                        d[word] = '{0:.10f}'.format(((1/(bigrams_target[intend]+len(bigrams_target)))*abs_prob_big[word])) #count of 1 for non-existent bigrams
                    except KeyError: #when intended bigram unseen in bigrams_target
                        d[word] = '{0:.10f}'.format(((1/(bigrams_target["unseen"]+len(bigrams_target)))*abs_prob_big[word]))
                        
    d = {k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse = True)}
    if len(d) > 0:
        return d, max(d, key=d.get)
    else:
        return d,

# %%
transp_best_match("onw")
# Out:
# ({'now': '0.0000136070', 'own': '0.0000043563'}, 'now')

# %%
transp_best_match("solt")
# Out:
# ({'slot': '0.0000000145'}, 'slot')

# %%
transp_best_match("acress")
# Out:
# ({'caress': '0.0000000238'}, 'caress')

# %% [markdown]
# ### Substitution
#
# Same, process. We need:
#
# **x|y** --> probability that **x** substituted **y**
#
# No special cases here. To calculate the probability we need to divide the **count of x|y** by the **count of y** (Laplace smoothing will be used).

# %%
def subst_diff(target, typo):
    """Function that takes a target word and a typo, and returns the difference in a
    conditional probability notation"""
    global cond_prob_s
    for i in range(len(target)):
        if target[i] != typo[i]:
            cond_prob_s = typo[i].lower() + "|" + target[i].lower() 
            break
    return cond_prob_s

# %%
def subst_prob_smooth(subst_typos):
    """Function that takes a corpus of substitution type typos and returns a dictionary of smoothed
    probabilities for each permutation seen"""
    cond_prob_l = []
    for target, typos in subst_typos.items(): #for target and typos
        for typo in typos:
            c_p = subst_diff(target, typo)
            cond_prob_l.append(c_p)
            
    counts = {}
    for cp in cond_prob_l:
        if cp not in counts:
            counts[cp] = 1
        else:
            counts[cp] += 1
    
    prob = {}
    for pair, count in counts.items():
        intended_letter = pair.split("|")[1] #take the second part, which is the letter before the inserted letter
        prob[pair] = (counts[pair]+1)/(letter_count_target[intended_letter]+len(letter_count_target))
    
    prob_sorted = {k: v for k, v in sorted(prob.items(), key=lambda x: x[1], reverse = True)}
    return prob_sorted

# %%
cond_prob_subst = subst_prob_smooth(substitution_)
cond_prob_subst
# Out:
# {'s|z': 0.2736842105263158,
#  'g|j': 0.11504424778761062,
#  'e|i': 0.09207225288509784,
#  'e|a': 0.08890057864281957,
#  'n|m': 0.08075842696629214,
#  's|c': 0.0738255033557047,
#  'a|e': 0.0701468189233279,
#  'u|w': 0.06967213114754098,
#  'e|y': 0.057172557172557176,
#  'a|o': 0.055375647668393785,
#  'o|u': 0.05377008652657602,
#  'i|y': 0.05197505197505198,
#  'a|i': 0.04716507777220271,
#  'i|e': 0.0466557911908646,
#  'e|o': 0.04404145077720207,
#  'e|u': 0.04388133498145859,
#  'o|a': 0.043398211467648606,
#  'c|k': 0.042328042328042326,
#  's|x': 0.040697674418604654,
#  'c|q': 0.04065040650406504,
#  'a|u': 0.03893695920889988,
#  'c|s': 0.03686366296079579,
#  'd|j': 0.035398230088495575,
#  'c|x': 0.03488372093023256,
#  'x|z': 0.031578947368421054,
#  'i|u': 0.030902348578491966,
#  'f|v': 0.028862478777589132,
#  'i|a': 0.028406102051551814,
#  'p|b': 0.028268551236749116,
#  'g|q': 0.024390243902439025,
#  't|k': 0.023809523809523808,
#  'd|z': 0.021052631578947368,
#  'c|z': 0.021052631578947368,
#  'g|z': 0.021052631578947368,
#  'n|_': 0.020833333333333332,
#  'l|_': 0.020833333333333332,
#  't|d': 0.020397489539748955,
#  'd|b': 0.020023557126030624,
#  'u|o': 0.018134715025906734,
#  'v|f': 0.017980636237897647,
#  'l|j': 0.017699115044247787,
#  'h|j': 0.017699115044247787,
#  'u|j': 0.017699115044247787,
#  't|j': 0.017699115044247787,
#  'g|k': 0.015873015873015872,
#  'k|c': 0.015659955257270694,
#  'y|i': 0.015554440541896638,
#  'm|n': 0.015453779151447036,
#  'w|u': 0.014215080346106305,
#  'd|t': 0.013591671486408328,
#  'u|i': 0.013547415955845458,
#  'c|g': 0.013544018058690745,
#  'u|a': 0.013413992635455023,
#  'o|e': 0.013376835236541599,
#  'i|o': 0.01327720207253886,
#  'h|k': 0.013227513227513227,
#  'e|w': 0.012295081967213115,
#  'g|x': 0.011627906976744186,
#  'z|x': 0.011627906976744186,
#  'm|x': 0.011627906976744186,
#  'v|x': 0.011627906976744186,
#  'k|x': 0.011627906976744186,
#  'r|x': 0.011627906976744186,
#  'o|i': 0.01154039136979428,
#  'u|e': 0.010929853181076673,
#  't|c': 0.010738255033557046,
#  'e|b': 0.01060070671378092,
#  'b|d': 0.010460251046025104,
#  'b|p': 0.01019108280254777,
#  'k|h': 0.01014760147601476,
#  's|t': 0.010121457489878543,
#  'm|b': 0.009422850412249705,
#  'r|l': 0.008671659440283799,
#  'w|v': 0.008488964346349746,
#  'b|v': 0.008488964346349746,
#  'a|y': 0.008316008316008316,
#  'm|w': 0.00819672131147541,
#  'l|w': 0.00819672131147541,
#  'r|w': 0.00819672131147541,
#  'o|w': 0.00819672131147541,
#  'e|k': 0.007936507936507936,
#  'd|k': 0.007936507936507936,
#  'd|g': 0.007524454477050414,
#  'c|t': 0.007518796992481203,
#  't|h': 0.007380073800738007,
#  'i|h': 0.007380073800738007,
#  'z|s': 0.007314218841427736,
#  't|p': 0.0070063694267515925,
#  'p|f': 0.006915629322268326,
#  'r|u': 0.006798516687268232,
#  'd|v': 0.006791171477079796,
#  'j|g': 0.006772009029345372,
#  'e|h': 0.006457564575645757,
#  'e|l': 0.0063066614111154905,
#  's|d': 0.006276150627615063,
#  'g|d': 0.006276150627615063,
#  'n|w': 0.006147540983606557,
#  'd|w': 0.006147540983606557,
#  'y|w': 0.006147540983606557,
#  'a|w': 0.006147540983606557,
#  'k|g': 0.006019563581640331,
#  'v|b': 0.005889281507656066,
#  'g|c': 0.0058165548098434005,
#  'n|d': 0.005753138075313808,
#  'r|f': 0.005532503457814661,
#  'l|k': 0.005291005291005291,
#  'w|k': 0.005291005291005291,
#  'r|k': 0.005291005291005291,
#  'f|k': 0.005291005291005291,
#  'u|y': 0.005197505197505198,
#  'r|y': 0.005197505197505198,
#  't|s': 0.00497366881217086,
#  'k|t': 0.004626951995373048,
#  'l|t': 0.004626951995373048,
#  's|h': 0.004612546125461255,
#  'q|g': 0.004514672686230248,
#  'e|s': 0.004388531304856641,
#  'n|u': 0.004326328800988875,
#  'y|u': 0.004326328800988875,
#  'e|d': 0.0041841004184100415,
#  't|y': 0.004158004158004158,
#  't|f': 0.004149377593360996,
#  'n|f': 0.004149377593360996,
#  't|w': 0.004098360655737705,
#  'v|w': 0.004098360655737705,
#  'b|w': 0.004098360655737705,
#  'h|w': 0.004098360655737705,
#  'i|w': 0.004098360655737705,
#  's|w': 0.004098360655737705,
#  'c|w': 0.004098360655737705,
#  'f|w': 0.004098360655737705,
#  'x|c': 0.004026845637583893,
#  'q|c': 0.004026845637583893,
#  'r|p': 0.003821656050955414,
#  'l|i': 0.003763171098845961,
#  'e|g': 0.003762227238525207,
#  'e|t': 0.0037593984962406013,
#  'l|u': 0.003708281829419036,
#  'w|h': 0.0036900369003690036,
#  'l|d': 0.0036610878661087866,
#  'r|d': 0.0036610878661087866,
#  'a|d': 0.0036610878661087866,
#  'f|b': 0.0035335689045936395,
#  'n|b': 0.0035335689045936395,
#  'l|b': 0.0035335689045936395,
#  'p|m': 0.0035112359550561797,
#  'g|m': 0.0035112359550561797,
#  'u|v': 0.003395585738539898,
#  'y|v': 0.003395585738539898,
#  'c|v': 0.003395585738539898,
#  'e|n': 0.0033717336330429896,
#  'r|n': 0.0033717336330429896,
#  'l|r': 0.0033259423503325942,
#  'h|p': 0.0031847133757961785,
#  'i|l': 0.0031533307055577452,
#  't|l': 0.0031533307055577452,
#  'o|y': 0.0031185031185031187,
#  's|y': 0.0031185031185031187,
#  'l|y': 0.0031185031185031187,
#  'y|e': 0.003099510603588907,
#  'r|e': 0.003099510603588907,
#  'n|r': 0.003048780487804878,
#  'e|r': 0.003048780487804878,
#  'r|i': 0.0030105368790767687,
#  't|g': 0.0030097817908201654,
#  'n|g': 0.0030097817908201654,
#  'f|g': 0.0030097817908201654,
#  'e|m': 0.0028089887640449437,
#  'b|m': 0.0028089887640449437,
#  'o|h': 0.0027675276752767526,
#  'a|h': 0.0027675276752767526,
#  'u|f': 0.0027662517289073307,
#  'h|f': 0.0027662517289073307,
#  'e|f': 0.0027662517289073307,
#  's|f': 0.0027662517289073307,
#  'a|f': 0.0027662517289073307,
#  'w|f': 0.0027662517289073307,
#  'l|f': 0.0027662517289073307,
#  'a|l': 0.0027591643673630273,
#  'd|c': 0.0026845637583892616,
#  'a|c': 0.0026845637583892616,
#  'k|p': 0.0025477707006369425,
#  'm|p': 0.0025477707006369425,
#  'c|l': 0.002364998029168309,
#  'a|b': 0.002355712603062426,
#  'w|b': 0.002355712603062426,
#  't|b': 0.002355712603062426,
#  'a|s': 0.0023405500292568754,
#  'r|s': 0.0023405500292568754,
#  'h|t': 0.002313475997686524,
#  'n|t': 0.002313475997686524,
#  'd|e': 0.0022838499184339315,
#  'l|e': 0.0022838499184339315,
#  'c|o': 0.0022668393782383418,
#  'z|g': 0.002257336343115124,
#  's|g': 0.002257336343115124,
#  'e|c': 0.0022371364653243847,
#  'd|r': 0.0022172949002217295,
#  'a|r': 0.0022172949002217295,
#  'r|m': 0.002106741573033708,
#  'w|m': 0.002106741573033708,
#  'k|d': 0.0020920502092050207,
#  'n|y': 0.002079002079002079,
#  'k|y': 0.002079002079002079,
#  'w|y': 0.002079002079002079,
#  'v|y': 0.002079002079002079,
#  'd|y': 0.002079002079002079,
#  'x|y': 0.002079002079002079,
#  'h|y': 0.002079002079002079,
#  'n|l': 0.001970831690973591,
#  'h|n': 0.001966844619275077,
#  't|n': 0.001966844619275077,
#  'd|n': 0.001966844619275077,
#  'c|n': 0.001966844619275077,
#  'y|o': 0.0019430051813471502,
#  'l|o': 0.0019430051813471502,
#  'd|p': 0.001910828025477707,
#  'd|u': 0.001854140914709518,
#  'h|u': 0.001854140914709518,
#  't|u': 0.001854140914709518,
#  'y|h': 0.0018450184501845018,
#  'j|h': 0.0018450184501845018,
#  'u|h': 0.0018450184501845018,
#  'f|h': 0.0018450184501845018,
#  'r|h': 0.0018450184501845018,
#  'p|h': 0.0018450184501845018,
#  'c|h': 0.0018450184501845018,
#  'g|h': 0.0018450184501845018,
#  'r|a': 0.001841136244082062,
#  't|e': 0.0017944535073409463,
#  'r|c': 0.0017897091722595079,
#  't|i': 0.0017561465127947818,
#  'n|s': 0.0017554125219426564,
#  'g|t': 0.001735106998264893,
#  'r|t': 0.001735106998264893,
#  'i|t': 0.001735106998264893,
#  'a|n': 0.0016858668165214948,
#  'u|n': 0.0016858668165214948,
#  's|r': 0.0016629711751662971,
#  's|e': 0.0016313213703099511,
#  's|a': 0.0015781167806417674,
#  'o|l': 0.0015766653527788726,
#  'u|l': 0.0015766653527788726,
#  'f|d': 0.0015690376569037657,
#  'o|d': 0.0015690376569037657,
#  'j|d': 0.0015690376569037657,
#  'm|d': 0.0015690376569037657,
#  'n|i': 0.0015052684395383843,
#  'o|g': 0.0015048908954100827,
#  'r|g': 0.0015048908954100827,
#  'y|g': 0.0015048908954100827,
#  'l|g': 0.0015048908954100827,
#  'u|g': 0.0015048908954100827,
#  'x|s': 0.001462843768285547,
#  'f|t': 0.0014459224985540775,
#  'y|t': 0.0014459224985540775,
#  's|m': 0.0014044943820224719,
#  'l|m': 0.0014044943820224719,
#  't|m': 0.0014044943820224719,
#  'a|m': 0.0014044943820224719,
#  'v|m': 0.0014044943820224719,
#  'd|m': 0.0014044943820224719,
#  'u|r': 0.001385809312638581,
#  'z|c': 0.0013422818791946308,
#  'n|c': 0.0013422818791946308,
#  'p|c': 0.0013422818791946308,
#  'h|o': 0.0012953367875647669,
#  's|o': 0.0012953367875647669,
#  'n|o': 0.0012953367875647669,
#  'g|p': 0.0012738853503184713,
#  'a|p': 0.0012738853503184713,
#  'f|p': 0.0012738853503184713,
#  's|p': 0.0012738853503184713,
#  'i|p': 0.0012738853503184713,
#  'h|i': 0.001254390366281987,
#  'c|u': 0.0012360939431396785,
#  's|u': 0.0012360939431396785,
#  'k|u': 0.0012360939431396785,
#  'k|l': 0.0011824990145841545,
#  'f|l': 0.0011824990145841545,
#  'h|l': 0.0011824990145841545,
#  'u|s': 0.0011702750146284377,
#  'a|t': 0.001156737998843262,
#  'w|e': 0.0011419249592169657,
#  'p|e': 0.0011419249592169657,
#  'o|n': 0.00112391121101433,
#  'y|n': 0.00112391121101433,
#  's|n': 0.00112391121101433,
#  'l|n': 0.00112391121101433,
#  'y|r': 0.0011086474501108647,
#  'w|r': 0.0011086474501108647,
#  'o|r': 0.0011086474501108647,
#  't|r': 0.0011086474501108647,
#  'c|a': 0.0010520778537611783,
#  'l|a': 0.0010520778537611783,
#  'n|a': 0.0010520778537611783,
#  'd|a': 0.0010520778537611783,
#  'c|d': 0.0010460251046025104,
#  'i|d': 0.0010460251046025104,
#  'p|d': 0.0010460251046025104,
#  'c|i': 0.0010035122930255895,
#  'h|e': 0.0009787928221859706,
#  'p|o': 0.0009715025906735751,
#  'l|c': 0.0008948545861297539,
#  'f|c': 0.0008948545861297539,
#  'v|c': 0.0008948545861297539,
#  'h|c': 0.0008948545861297539,
#  'u|c': 0.0008948545861297539,
#  'h|s': 0.0008777062609713282,
#  'y|s': 0.0008777062609713282,
#  'm|s': 0.0008777062609713282,
#  'u|t': 0.0008675534991324465,
#  'o|t': 0.0008675534991324465,
#  'p|t': 0.0008675534991324465,
#  'g|n': 0.0008429334082607474,
#  'i|n': 0.0008429334082607474,
#  'b|n': 0.0008429334082607474,
#  'f|n': 0.0008429334082607474,
#  'h|r': 0.0008314855875831486,
#  'p|r': 0.0008314855875831486,
#  't|a': 0.0007890583903208837,
#  'q|a': 0.0007890583903208837,
#  's|l': 0.0007883326763894363,
#  'p|l': 0.0007883326763894363,
#  's|i': 0.0007526342197691922,
#  'm|e': 0.0006525285481239804,
#  'g|e': 0.0006525285481239804,
#  'd|o': 0.0006476683937823834,
#  'r|o': 0.0006476683937823834,
#  'w|o': 0.0006476683937823834,
#  'g|o': 0.0006476683937823834,
#  'f|o': 0.0006476683937823834,
#  'i|s': 0.0005851375073142189,
#  'p|s': 0.0005851375073142189,
#  'd|s': 0.0005851375073142189,
#  'w|s': 0.0005851375073142189,
#  'o|s': 0.0005851375073142189,
#  'l|s': 0.0005851375073142189,
#  'b|t': 0.000578368999421631,
#  'x|t': 0.000578368999421631,
#  'v|n': 0.000561955605507165,
#  'x|n': 0.000561955605507165,
#  'g|r': 0.0005543237250554324,
#  'c|r': 0.0005543237250554324,
#  'i|r': 0.0005543237250554324,
#  'f|r': 0.0005543237250554324,
#  'b|a': 0.0005260389268805891,
#  'w|a': 0.0005260389268805891,
#  'y|a': 0.0005260389268805891,
#  'h|a': 0.0005260389268805891,
#  'k|a': 0.0005260389268805891,
#  'b|i': 0.0005017561465127947,
#  'v|i': 0.0005017561465127947,
#  'f|i': 0.0005017561465127947,
#  'm|i': 0.0005017561465127947,
#  'z|e': 0.0004893964110929853,
#  'f|e': 0.0004893964110929853,
#  'n|e': 0.0003262642740619902}

# %%
def subst_best_match(typo):
    """Function that takes a typo and returns a dictionary with smoothed probabilities of the best candidates, given that
    the typo is of substitution-type, and the best candidate"""
    d = {}
    for word in intended_possible_words(typo):
        if typo in substitution(word):
            if word in abs_prob_big.keys(): #and cond_p in cond_prob_del.keys():
                try:
                    cond_p_subst = subst_diff(word, typo)
                    d[word] = '{0:.10f}'.format((cond_prob_subst[cond_p_subst])*abs_prob_big[word]) #multiply the conditional probability we got from the typo corpus with the absolute probability of the possible 
                except KeyError: #when conditional probability is not in dictionary
                    cond_p_subst = subst_diff(word, typo)
                    split = cond_p_subst.split("|") #split into typed and intended
                    intend = split[1]
                    try:
                        d[word] = '{0:.10f}'.format((1/(letter_count_target[intend]+len(letter_count_target)))*abs_prob_big[word]) #count of 1
                    except KeyError: #when letter unseen in letter_count_target
                        d[word] = '{0:.10f}'.format((1/(letter_count_target["unseen"]+len(letter_count_target)))*abs_prob_big[word])
    d = {k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse = True)}
    if len(d) > 0:
        return d, max(d, key=d.get)
    else:
        return d,

# %%
subst_best_match("berd")
# Out:
# ({'bird': '0.0000025005',
#   'berg': '0.0000005780',
#   'bend': '0.0000000497',
#   'herd': '0.0000000115',
#   'bead': '0.0000000029'},
#  'bird')

# %%
subst_best_match("riad")
# Out:
# ({'read': '0.0000078571', 'road': '0.0000026485'}, 'read')

# %%
subst_best_match("crod")
# Out:
# ({'crop': '0.0000000341', 'trod': '0.0000000233', 'crow': '0.0000000143'},
#  'crop')

# %% [markdown]
# ## Step 5: Noisy channel spelling corrector
#
# Finally, I combined all of the functions above to give rise to a function that will give me the **absolute best** candidate out of all of them and an **ordered list** of other ones. If it would be on a phone, this would be what you see when selecting the correction. I also made a user input version for fun!

# %%
def overall_best_match(typo):
    """Function that takes a string being a typo and returns an ordered list of the best real-word candidates"""
    global error
    global all_cand_probs_sort #to use later in a context-sensitive spell checker
    all_cand_probs = {}
    try:
        prob_del, max_del = del_best_match(typo) #separate into others and best
        if len(prob_del) == 1: #if only one candidate
            all_cand_probs[max_del] = prob_del[max_del] #populate dictionary
        else: #if list of candidate is longer
            for word in prob_del.keys(): #for each word of those candidates
                all_cand_probs[word] = prob_del[word] #populate the dictionary
    except ValueError: #for when the typo fed in into any of the functions above gives an empty dict
        pass
    try:
        prob_insert, max_insert = insert_best_match(typo)
        if len(prob_insert) == 1:
            all_cand_probs[max_insert] = prob_insert[max_insert]
        else:
            for word in prob_insert.keys():
                all_cand_probs[word] = prob_insert[word]
    except ValueError: #for when the typo fed in into any of the functions above gives an empty dict
        pass
    try:
        prob_subst, max_subst = subst_best_match(typo)
        if len(prob_subst) == 1:
            all_cand_probs[max_subst] = prob_subst[max_subst]
        else:
            for word in prob_subst.keys():
                all_cand_probs[word] = prob_subst[word]
    except ValueError: #for when the typo fed in into any of the functions above gives an empty dict
        pass
    try:
        prob_transp, max_transp = transp_best_match(typo)
        if len(prob_transp) == 1:
            all_cand_probs[max_transp] = prob_transp[max_transp]
        else:
            for word in prob_transp.keys():
                all_cand_probs[word] = prob_transp[word]
    except ValueError: #for when the typo fed in into any of the functions above gives an empty dict
        pass


    all_cand_probs_sort = {k: v for k, v in sorted(all_cand_probs.items(), key=lambda x: x[1], reverse = True)} #sort the dictionary
    
    if len(all_cand_probs_sort) > 0:
        best = max(all_cand_probs_sort, key=all_cand_probs_sort.get) #get the best one
        return best, [x for x in all_cand_probs_sort.keys()] #return the best and a list of others in order of probability
    else:
        error = "the correction of \"" + typo + "\" you are looking for is not in the lexicon"
        return error

# %%
print(overall_best_match("acress"))
print(all_cand_probs_sort)
# Out:
# ('across', ['across', 'acres', 'access', 'actress', 'caress'])
# {'across': '0.0000075523', 'acres': '0.0000001591', 'access': '0.0000000792', 'actress': '0.0000000782', 'caress': '0.0000000238'}

# %%
overall_best_match("soil")
# Out:
# ('soul',
#  ['soul',
#   'soil',
#   'coil',
#   'sail',
#   'toil',
#   'spoil',
#   'soils',
#   'boil',
#   'oil',
#   'sol',
#   'soll',
#   'foil',
#   'soie'])

# %%
overall_best_match("cindrella")
# Out:
# 'the correction of "cindrella" you are looking for is not in the lexicon'

# %% [markdown]
# #### Little time checker:

# %%
import time
start = time.process_time()
print(overall_best_match("thew"))  
print(time.process_time() - start)
# Out:
# ('the', ['the', 'they', 'them', 'threw', 'then', 'thaw', 'thee', 'whew', 'chew', 'shew', 'hew'])
# 0.01153599999997823

# %% [markdown]
# Pretty quick! Now, the user function:

# %%
def overall_best_match_user():
    """Function that takes a string being a typo and returns an ordered list of the best real-word candidates"""
    typo=input("you wrote this: ")
    return overall_best_match(typo)

# %%
overall_best_match_user()
# Out:
# you wrote this: riad
# ('read', ['read', 'road', 'raid', 'rid'])

# %%
overall_best_match_user()
# Out:
# you wrote this: ylem
# the correction of "ylem" you are looking for is not in the lexicon

# %%
overall_best_match_user()
# Out:
# you wrote this: hllo
# ('hello', ['hello', 'hallo', 'hullo', 'halo'])

# %% [markdown]
# To be executed!

# %%
overall_best_match_user()

# %% [markdown]
# ### Step 5.1: Spot typos in a sentence and correct them with noisy channel probability
#
# Here I expanded the corrector to a sentence.

# %%
def spot_typos(sentence):
    """Function that takes a sentence and returns a list of typos"""
    global s_l
    typos = []
    s_l = [x.lower() for x in word_tokenize(sentence)]
    for word in s_l:
        if word not in vocab or word not in big_txt:
            typos.append(word)
    return typos

# %%
spot_typos("they rae acress the field")
# Out:
# ['rae', 'acress']

# %%
def correct_typos(sentence):
    """Function that takes a sentence and corrects its typos"""
    for typo in spot_typos(sentence):
        try:
            best, all_ = overall_best_match(typo)
            s_l[s_l.index(typo)] = best
        except ValueError: #problem that arises when the typo is recognised as such but no options are given because the word is not in the lexicon
                           #it is a ValueError because the overall_best_match function gives only 'error' as output in those cases, and can't be split in 2
            print("\"" + typo + "\" has been recognised as a typo, but cannot be corrected at this time")
    return " ".join(s_l)

# %%
correct_typos("the snow is faling and it is beauitful")
# Out:
# 'the snow is falling and it is beautiful'

# %%
correct_typos("i am intriued by this huse") #it corrects "house" but not "intrigued"
# Out:
# "intriued" has been recognised as a typo, but cannot be corrected at this time
# 'i am intriued by this house'

# %%
correct_typos("tha cat is siting on the cair")
# Out:
# 'the cat is sitting on the chair'

# %% [markdown]
# # Step 6: Testing
#
# In this step, I used [the test typo corpus by Birkbeck](https://www.dcs.bbk.ac.uk/~ROGER/missp.dat) to check the performance of my spell checker. As argued by Norvig [here](http://norvig.com/ngrams/), it is important not to look at the test set, so I never print it.

# %% [markdown]
# ### Step 6.1: Cleaning the corpus and extracting the target-typo pairs

# %%
with open("/Users/sashakenjeeva/Desktop/Sasha/Masters/Trento/Fall 2020/Computational Skills for Text Analysis/Coding/Project/missp.dat.txt", "r") as birkbeck:
    test = {}
    read_birkbeck = birkbeck.read().split("$") #split according to the dollar sign which can be found before the target
    line_string = [x.replace("\n", " ").strip().lower() for x in read_birkbeck] #clean, lowercase
    line_string.remove("") #remove empty strings from list
    line_list = [word_tokenize(word) for word in line_string] #tokenize
    test_set = {} #we'll need the dictionary form
    for element in line_list:
        correct = element[0] #correct is always first one
        incorrect = element[1:] #incorrect ones are after
        for incor in incorrect:
            if editdistance.eval(correct, incor) == 1 or incor in transposition(correct): 
                test[correct] = incor #populate

# %% [markdown]
# I made an inverted version for convenience in indexing:

# %%
incorrect_correct = {v:k for k,v in test.items()}

# %% [markdown]
# Since the performance of my laptop is not always great, I made a function to make smaller version of the test set and test the spell checker first on those:

# %%
def slice_dict(dictionary, number):
    """Function that takes a dictionary and an integer, and returns a slice of that dictionary, until the
    input number"""
    number_keys = list(dictionary.keys())[:number]
    smaller_test = {key: dictionary[key] for key in number_keys}
    return smaller_test

# %%
smaller_test = slice_dict(incorrect_correct, 200)

# %%
tiny_test = slice_dict(incorrect_correct, 5)

# %% [markdown]
# Here is the test function, to which I added several measures: percentage of correct, percentage of cases where the correct candidate is not the best chosen but still in the list, percentage of no candidate given.

# %%
def test_spell_corrector(corpus):
    """Function that takes a corpus in the form of a list and returns a series of measures concerning
    the performance of the spell corrector"""
    other_option_won = []
    no_cand = []
    hits = 0
    for mistyped in corpus.keys():
        try:
            best, other = overall_best_match(mistyped)
            if best == corpus[mistyped]:
                hits += 1
            else:
                if len(other) > 1: #if other candidates are present as a result of the best match function
                    for tar in other: #for each of the targets given 
                        if tar == corpus[mistyped]: #if it corresponds to the target in the test set 
                            cand_numb = str(other.index(tar)) #take the index of it in the list
                            other_option_won.append("candidate number " + cand_numb + " corresponds to correct spelling for the typo " + mistyped + " with target " + corpus[mistyped]) #say which position it was in
        except ValueError: #if the spelling corrector doesn't even recognise the word and hence can't unpack overall_best_match
            no_cand.append(error) #append the error text we get from the overall best match function


    percentage_correct = (hits*100)/len(corpus) 
    other_candidates = (len(other_option_won)*100)/len(corpus)
    no_candidates = (len(no_cand)*100)/len(corpus)
    hits_text = "The spelling corrector has " + str(hits) + " hits."
    perc_text = "The spelling corrector gives correct candidates in " + str(percentage_correct) + "% of the cases."
    other_text = "The spelling corrector does not give the correct candidate, but has the target candidate in the list of candidates in " + str(other_candidates) + "% of the cases."
    no_cand_text = "The spelling corrector does not give any candidate in " + str(no_candidates) + "% of the cases."
    return hits_text, perc_text, other_text, no_cand_text, other_option_won

# %%
test_spell_corrector(tiny_test)
# Out:
# ('The spelling corrector has 5 hits.',
#  'The spelling corrector gives correct candidates in 100.0% of the cases.',
#  'The spelling corrector does not give the correct candidate, but has the target candidate in the list of candidates in 0.0% of the cases.',
#  [],
#  [])

# %%
test_spell_corrector(smaller_test)
# Out:
# ('The spelling corrector has 152 hits.',
#  'The spelling corrector gives correct candidates in 76.0% of the cases.',
#  'The spelling corrector does not give the correct candidate, but has the target candidate in the list of candidates in 9.0% of the cases.',
#  'The spelling corrector does not give any candidate in 9.5% of the cases.',
#  ['candidate number 6 corresponds to correct spelling for the typo des with target dec',
#   'candidate number 1 corresponds to correct spelling for the typo v with target i',
#   'candidate number 4 corresponds to correct spelling for the typo mrss with target mrs',
#   'candidate number 1 corresponds to correct spelling for the typo scotts with target scots',
#   'candidate number 3 corresponds to correct spelling for the typo wesh with target welsh',
#   'candidate number 2 corresponds to correct spelling for the typo as with target a',
#   'candidate number 2 corresponds to correct spelling for the typo bout with target about',
#   'candidate number 1 corresponds to correct spelling for the typo axcept with target accept',
#   'candidate number 1 corresponds to correct spelling for the typo acke with target ache',
#   'candidate number 4 corresponds to correct spelling for the typo at with target act',
#   'candidate number 1 corresponds to correct spelling for the typo acks with target acts',
#   'candidate number 5 corresponds to correct spelling for the typo ade with target add',
#   'candidate number 1 corresponds to correct spelling for the typo adhere with target adheres',
#   'candidate number 1 corresponds to correct spelling for the typo ajust with target adjust',
#   'candidate number 1 corresponds to correct spelling for the typo advice with target advise',
#   'candidate number 1 corresponds to correct spelling for the typo effect with target affect',
#   'candidate number 2 corresponds to correct spelling for the typo ag with target age',
#   'candidate number 3 corresponds to correct spelling for the typo ages with target aged'])

# %%
test_spell_corrector(incorrect_correct)
# Out:
# ('The spelling corrector has 3609 hits.',
#  'The spelling corrector gives correct candidates in 69.44390994804695% of the cases.',
#  'The spelling corrector does not give the correct candidate, but has the target candidate in the list of candidates in 16.548008466422935% of the cases.',
#  'The spelling corrector does not give any candidate in 10.659996151625938% of the cases.',
#  ['candidate number 6 corresponds to correct spelling for the typo des with target dec',
#   'candidate number 1 corresponds to correct spelling for the typo v with target i',
#   'candidate number 4 corresponds to correct spelling for the typo mrss with target mrs',
#   'candidate number 1 corresponds to correct spelling for the typo scotts with target scots',
#   'candidate number 3 corresponds to correct spelling for the typo wesh with target welsh',
#   'candidate number 2 corresponds to correct spelling for the typo as with target a',
#   'candidate number 2 corresponds to correct spelling for the typo bout with target about',
#   'candidate number 1 corresponds to correct spelling for the typo axcept with target accept',
#   'candidate number 1 corresponds to correct spelling for the typo acke with target ache',
#   'candidate number 4 corresponds to correct spelling for the typo at with target act',
#   'candidate number 1 corresponds to correct spelling for the typo acks with target acts',
#   'candidate number 5 corresponds to correct spelling for the typo ade with target add',
#   'candidate number 1 corresponds to correct spelling for the typo adhere with target adheres',
#   'candidate number 1 corresponds to correct spelling for the typo ajust with target adjust',
#   'candidate number 1 corresponds to correct spelling for the typo advice with target advise',
#   'candidate number 1 corresponds to correct spelling for the typo effect with target affect',
#   'candidate number 2 corresponds to correct spelling for the typo ag with target age',
#   'candidate number 3 corresponds to correct spelling for the typo ages with target aged',
#   'candidate number 5 corresponds to correct spelling for the typo hair with target air',
#   'candidate number 2 corresponds to correct spelling for the typo alass with target alas',
#   'candidate number 2 corresponds to correct spelling for the typo ham with target harm',
#   'candidate number 1 corresponds to correct spelling for the typo amout with target amount',
#   'candidate number 2 corresponds to correct spelling for the typo un with target an',
#   'candidate number 1 corresponds to correct spelling for the typo animals with target animal',
#   'candidate number 1 corresponds to correct spelling for the typo arn with target arm',
#   'candidate number 1 corresponds to correct spelling for the typo round with target around',
#   'candidate number 2 corresponds to correct spelling for the typo ort with target art',
#   'candidate number 2 corresponds to correct spelling for the typo was with target as',
#   'candidate number 1 corresponds to correct spelling for the typo aske with target ask',
#   'candidate number 2 corresponds to correct spelling for the typo associate with target associate',
#   'candidate number 9 corresponds to correct spelling for the typo aet with target ate',
#   'candidate number 2 corresponds to correct spelling for the typo attache with target attach',
#   'candidate number 1 corresponds to correct spelling for the typo attacked with target attached',
#   'candidate number 1 corresponds to correct spelling for the typo awak with target awake',
#   'candidate number 4 corresponds to correct spelling for the typo ox with target ax',
#   'candidate number 1 corresponds to correct spelling for the typo badies with target babies',
#   'candidate number 3 corresponds to correct spelling for the typo bed with target bid',
#   'candidate number 3 corresponds to correct spelling for the typo bage with target badge',
#   'candidate number 5 corresponds to correct spelling for the typo bages with target badges',
#   'candidate number 1 corresponds to correct spelling for the typo bend with target band',
#   'candidate number 1 corresponds to correct spelling for the typo barly with target barley',
#   'candidate number 3 corresponds to correct spelling for the typo bran with target barn',
#   'candidate number 1 corresponds to correct spelling for the typo pase with target base',
#   'candidate number 1 corresponds to correct spelling for the typo basen with target based',
#   'candidate number 2 corresponds to correct spelling for the typo bet with target beat',
#   'candidate number 1 corresponds to correct spelling for the typo barth with target bath',
#   'candidate number 3 corresponds to correct spelling for the typo bath with target bathe',
#   'candidate number 1 corresponds to correct spelling for the typo batton with target baton',
#   'candidate number 3 corresponds to correct spelling for the typo beed with target bead',
#   'candidate number 3 corresponds to correct spelling for the typo beame with target beam',
#   'candidate number 5 corresponds to correct spelling for the typo ben with target bean',
#   'candidate number 5 corresponds to correct spelling for the typo bean with target beans',
#   'candidate number 2 corresponds to correct spelling for the typo bar with target bear',
#   'candidate number 1 corresponds to correct spelling for the typo become with target becomes',
#   'candidate number 7 corresponds to correct spelling for the typo be with target bee',
#   'candidate number 2 corresponds to correct spelling for the typo beach with target beech',
#   'candidate number 1 corresponds to correct spelling for the typo bene with target been',
#   'candidate number 5 corresponds to correct spelling for the typo beat with target bet',
#   'candidate number 1 corresponds to correct spelling for the typo begon with target begun',
#   'candidate number 3 corresponds to correct spelling for the typo ball with target bell',
#   'candidate number 1 corresponds to correct spelling for the typo blong with target belong',
#   'candidate number 2 corresponds to correct spelling for the typo blow with target blew',
#   'candidate number 2 corresponds to correct spelling for the typo band with target bend',
#   'candidate number 4 corresponds to correct spelling for the typo mest with target best',
#   'candidate number 1 corresponds to correct spelling for the typo dig with target big',
#   'candidate number 1 corresponds to correct spelling for the typo pit with target bit',
#   'candidate number 2 corresponds to correct spelling for the typo bit with target bite',
#   'candidate number 1 corresponds to correct spelling for the typo blak with target blank',
#   'candidate number 1 corresponds to correct spelling for the typo bled with target bleed',
#   'candidate number 1 corresponds to correct spelling for the typo blnk with target blink',
#   'candidate number 1 corresponds to correct spelling for the typo blat with target blot',
#   'candidate number 6 corresponds to correct spelling for the typo bot with target boat',
#   'candidate number 4 corresponds to correct spelling for the typo bound with target bounds',
#   'candidate number 1 corresponds to correct spelling for the typo bon with target bone',
#   'candidate number 1 corresponds to correct spelling for the typo bonet with target bonnet',
#   'candidate number 2 corresponds to correct spelling for the typo bonas with target bonus',
#   'candidate number 1 corresponds to correct spelling for the typo boured with target bored',
#   'candidate number 1 corresponds to correct spelling for the typo borring with target boring',
#   'candidate number 1 corresponds to correct spelling for the typo bron with target born',
#   'candidate number 8 corresponds to correct spelling for the typo bose with target boss',
#   'candidate number 1 corresponds to correct spelling for the typo bosed with target bossed',
#   'candidate number 1 corresponds to correct spelling for the typo buth with target both',
#   'candidate number 1 corresponds to correct spelling for the typo borther with target bother',
#   'candidate number 1 corresponds to correct spelling for the typo botton with target button',
#   'candidate number 1 corresponds to correct spelling for the typo brought with target bought',
#   'candidate number 1 corresponds to correct spelling for the typo boxs with target boxes',
#   'candidate number 1 corresponds to correct spelling for the typo bay with target boy',
#   'candidate number 1 corresponds to correct spelling for the typo brin with target brain',
#   'candidate number 3 corresponds to correct spelling for the typo breath with target breadth',
#   'candidate number 1 corresponds to correct spelling for the typo brick with target bricks',
#   'candidate number 1 corresponds to correct spelling for the typo bing with target bring',
#   'candidate number 3 corresponds to correct spelling for the typo bittle with target brittle',
#   'candidate number 1 corresponds to correct spelling for the typo broken with target broke',
#   'candidate number 3 corresponds to correct spelling for the typo brock with target brook',
#   'candidate number 1 corresponds to correct spelling for the typo brom with target broom',
#   'candidate number 1 corresponds to correct spelling for the typo bruse with target bruise',
#   'candidate number 1 corresponds to correct spelling for the typo buble with target bubble',
#   'candidate number 10 corresponds to correct spelling for the typo but with target bud',
#   'candidate number 6 corresponds to correct spelling for the typo big with target bug',
#   'candidate number 1 corresponds to correct spelling for the typo bult with target built',
#   'candidate number 2 corresponds to correct spelling for the typo brun with target burn',
#   'candidate number 4 corresponds to correct spelling for the typo bust with target burst',
#   'candidate number 2 corresponds to correct spelling for the typo buch with target bush',
#   'candidate number 1 corresponds to correct spelling for the typo bucher with target butcher',
#   'candidate number 3 corresponds to correct spelling for the typo by with target buy',
#   'candidate number 2 corresponds to correct spelling for the typo bying with target buying',
#   'candidate number 1 corresponds to correct spelling for the typo kage with target cage',
#   'candidate number 1 corresponds to correct spelling for the typo calender with target calendar',
#   'candidate number 7 corresponds to correct spelling for the typo coll with target cool',
#   'candidate number 2 corresponds to correct spelling for the typo carm with target calm',
#   'candidate number 1 corresponds to correct spelling for the typo camal with target camel',
#   'candidate number 1 corresponds to correct spelling for the typo con with target can',
#   'candidate number 8 corresponds to correct spelling for the typo cand with target candy',
#   'candidate number 1 corresponds to correct spelling for the typo capital with target capitol',
#   'candidate number 5 corresponds to correct spelling for the typo cor with target car',
#   'candidate number 1 corresponds to correct spelling for the typo kard with target card',
#   'candidate number 4 corresponds to correct spelling for the typo cars with target cards',
#   'candidate number 1 corresponds to correct spelling for the typo carrers with target careers',
#   'candidate number 1 corresponds to correct spelling for the typo kars with target cars',
#   'candidate number 2 corresponds to correct spelling for the typo kave with target cave',
#   'candidate number 1 corresponds to correct spelling for the typo sent with target cent',
#   'candidate number 1 corresponds to correct spelling for the typo center with target centre',
#   'candidate number 1 corresponds to correct spelling for the typo cens with target cents',
#   'candidate number 2 corresponds to correct spelling for the typo chan with target chain',
#   'candidate number 1 corresponds to correct spelling for the typo change with target changed',
#   'candidate number 1 corresponds to correct spelling for the typo chater with target chapter',
#   'candidate number 1 corresponds to correct spelling for the typo character with target characters',
#   'candidate number 1 corresponds to correct spelling for the typo chace with target chase',
#   'candidate number 1 corresponds to correct spelling for the typo chet with target cheat',
#   'candidate number 1 corresponds to correct spelling for the typo cheak with target check',
#   'candidate number 1 corresponds to correct spelling for the typo chear with target cheer',
#   'candidate number 2 corresponds to correct spelling for the typo chen with target chin',
#   'candidate number 1 corresponds to correct spelling for the typo chouse with target choose',
#   'candidate number 3 corresponds to correct spelling for the typo thop with target chop',
#   'candidate number 1 corresponds to correct spelling for the typo choose with target chose',
#   'candidate number 2 corresponds to correct spelling for the typo chose with target chosen',
#   'candidate number 1 corresponds to correct spelling for the typo glass with target class',
#   'candidate number 1 corresponds to correct spelling for the typo glasses with target classes',
#   'candidate number 4 corresponds to correct spelling for the typo causes with target clauses',
#   'candidate number 1 corresponds to correct spelling for the typo clumb with target climb',
#   'candidate number 2 corresponds to correct spelling for the typo clock with target cloak',
#   'candidate number 1 corresponds to correct spelling for the typo clok with target clock',
#   'candidate number 2 corresponds to correct spelling for the typo cloth with target clothe',
#   'candidate number 1 corresponds to correct spelling for the typo clowd with target cloud',
#   'candidate number 1 corresponds to correct spelling for the typo couch with target coach',
#   'candidate number 1 corresponds to correct spelling for the typo course with target coarse',
#   'candidate number 1 corresponds to correct spelling for the typo cost with target coast',
#   'candidate number 2 corresponds to correct spelling for the typo cot with target coat',
#   'candidate number 1 corresponds to correct spelling for the typo coffer with target coffee',
#   'candidate number 1 corresponds to correct spelling for the typo collor with target collar',
#   'candidate number 10 corresponds to correct spelling for the typo cold with target colt',
#   'candidate number 9 corresponds to correct spelling for the typo come with target comb',
#   'candidate number 1 corresponds to correct spelling for the typo combination with target combinations',
#   'candidate number 1 corresponds to correct spelling for the typo conclued with target conclude',
#   'candidate number 1 corresponds to correct spelling for the typo confusin with target confusing',
#   'candidate number 1 corresponds to correct spelling for the typo considerable with target considerably',
#   'candidate number 1 corresponds to correct spelling for the typo contant with target content',
#   'candidate number 2 corresponds to correct spelling for the typo kook with target cook',
#   'candidate number 1 corresponds to correct spelling for the typo kooking with target cooking',
#   'candidate number 1 corresponds to correct spelling for the typo coperation with target cooperation',
#   'candidate number 2 corresponds to correct spelling for the typo courd with target cord',
#   'candidate number 1 corresponds to correct spelling for the typo cron with target corn',
#   'candidate number 1 corresponds to correct spelling for the typo caugh with target cough',
#   'candidate number 2 corresponds to correct spelling for the typo caw with target cow',
#   'candidate number 1 corresponds to correct spelling for the typo crak with target crack',
#   'candidate number 1 corresponds to correct spelling for the typo crall with target crawl',
#   'candidate number 1 corresponds to correct spelling for the typo creak with target creek',
#   'candidate number 4 corresponds to correct spelling for the typo crow with target crew',
#   'candidate number 1 corresponds to correct spelling for the typo croe with target crow',
#   'candidate number 4 corresponds to correct spelling for the typo cruse with target cruise',
#   'candidate number 1 corresponds to correct spelling for the typo cring with target crying',
#   'candidate number 1 corresponds to correct spelling for the typo kup with target cup',
#   'candidate number 9 corresponds to correct spelling for the typo cup with target cups',
#   'candidate number 1 corresponds to correct spelling for the typo cirl with target curl',
#   'candidate number 2 corresponds to correct spelling for the typo cerve with target curve',
#   'candidate number 2 corresponds to correct spelling for the typo cat with target cut',
#   'candidate number 1 corresponds to correct spelling for the typo cymbols with target cymbals',
#   'candidate number 1 corresponds to correct spelling for the typo diary with target dairy',
#   'candidate number 3 corresponds to correct spelling for the typo dasy with target daisy',
#   'candidate number 1 corresponds to correct spelling for the typo danse with target dance',
#   'candidate number 1 corresponds to correct spelling for the typo dearing with target daring',
#   'candidate number 5 corresponds to correct spelling for the typo tart with target dart',
#   'candidate number 3 corresponds to correct spelling for the typo dute with target date',
#   'candidate number 3 corresponds to correct spelling for the typo down with target dawn',
#   'candidate number 1 corresponds to correct spelling for the typo day with target days',
#   'candidate number 2 corresponds to correct spelling for the typo ded with target deed',
#   'candidate number 2 corresponds to correct spelling for the typo dept with target depth',
#   'candidate number 1 corresponds to correct spelling for the typo deside with target decide',
#   'candidate number 1 corresponds to correct spelling for the typo diem with target deem',
#   'candidate number 7 corresponds to correct spelling for the typo dear with target deer',
#   'candidate number 1 corresponds to correct spelling for the typo defense with target defence',
#   'candidate number 1 corresponds to correct spelling for the typo deficite with target deficit',
#   'candidate number 1 corresponds to correct spelling for the typo demaned with target demand',
#   'candidate number 1 corresponds to correct spelling for the typo dence with target dense',
#   'candidate number 6 corresponds to correct spelling for the typo dest with target desk',
#   'candidate number 1 corresponds to correct spelling for the typo dispatched with target despatched',
#   'candidate number 1 corresponds to correct spelling for the typo dide with target died',
#   'candidate number 2 corresponds to correct spelling for the typo dime with target dine',
#   'candidate number 2 corresponds to correct spelling for the typo dinner with target dinners',
#   'candidate number 1 corresponds to correct spelling for the typo durty with target dirty',
#   'candidate number 1 corresponds to correct spelling for the typo discoverd with target discovery',
#   'candidate number 1 corresponds to correct spelling for the typo discreet with target discrete',
#   'candidate number 1 corresponds to correct spelling for the typo discusted with target disgusted',
#   'candidate number 1 corresponds to correct spelling for the typo disrupte with target disrupt',
#   'candidate number 3 corresponds to correct spelling for the typo div with target dive',
#   'candidate number 2 corresponds to correct spelling for the typo divide with target divine',
#   'candidate number 1 corresponds to correct spelling for the typo to with target do',
#   'candidate number 4 corresponds to correct spelling for the typo doge with target dodge',
#   'candidate number 3 corresponds to correct spelling for the typo dol with target dole',
#   'candidate number 5 corresponds to correct spelling for the typo dall with target doll',
#   'candidate number 1 corresponds to correct spelling for the typo dor with target door',
#   'candidate number 3 corresponds to correct spelling for the typo does with target dose',
#   'candidate number 1 corresponds to correct spelling for the typo dout with target doubt',
#   'candidate number 1 corresponds to correct spelling for the typo dov with target dove',
#   'candidate number 1 corresponds to correct spelling for the typo drage with target drag',
#   'candidate number 1 corresponds to correct spelling for the typo drak with target drank',
#   'candidate number 2 corresponds to correct spelling for the typo drapped with target draped',
#   'candidate number 1 corresponds to correct spelling for the typo drow with target drew',
#   'candidate number 1 corresponds to correct spelling for the typo dred with target dread',
#   'candidate number 1 corresponds to correct spelling for the typo drid with target dried',
#   'candidate number 1 corresponds to correct spelling for the typo dreft with target drift',
#   'candidate number 1 corresponds to correct spelling for the typo drile with target drill',
#   'candidate number 3 corresponds to correct spelling for the typo duk with target duck',
#   'candidate number 2 corresponds to correct spelling for the typo duty with target duly',
#   'candidate number 3 corresponds to correct spelling for the typo dum with target dumb',
#   'candidate number 1 corresponds to correct spelling for the typo duste with target dusty',
#   'candidate number 2 corresponds to correct spelling for the typo er with target ear',
#   'candidate number 5 corresponds to correct spelling for the typo hearn with target earn',
#   'candidate number 2 corresponds to correct spelling for the typo et with target eat',
#   'candidate number 1 corresponds to correct spelling for the typo hedge with target edge',
#   'candidate number 2 corresponds to correct spelling for the typo eeg with target egg',
#   'candidate number 1 corresponds to correct spelling for the typo egges with target eggs',
#   'candidate number 1 corresponds to correct spelling for the typo eigth with target eighth',
#   'candidate number 1 corresponds to correct spelling for the typo ether with target either',
#   'candidate number 1 corresponds to correct spelling for the typo elss with target else',
#   'candidate number 1 corresponds to correct spelling for the typo emotion with target emotions',
#   'candidate number 1 corresponds to correct spelling for the typo employe with target employee',
#   'candidate number 1 corresponds to correct spelling for the typo unable with target enable',
#   'candidate number 2 corresponds to correct spelling for the typo and with target end',
#   'candidate number 1 corresponds to correct spelling for the typo equire with target enquire',
#   'candidate number 5 corresponds to correct spelling for the typo err with target ere',
#   'candidate number 1 corresponds to correct spelling for the typo errow with target error',
#   'candidate number 2 corresponds to correct spelling for the typo ect with target etc',
#   'candidate number 1 corresponds to correct spelling for the typo every with target ever',
#   'candidate number 1 corresponds to correct spelling for the typo evolved with target evolve',
#   'candidate number 1 corresponds to correct spelling for the typo exiting with target exciting',
#   'candidate number 3 corresponds to correct spelling for the typo expent with target expert',
#   'candidate number 1 corresponds to correct spelling for the typo leye with target eye',
#   'candidate number 1 corresponds to correct spelling for the typo facilty with target faculty',
#   'candidate number 2 corresponds to correct spelling for the typo fary with target fairy',
#   'candidate number 2 corresponds to correct spelling for the typo full with target fall',
#   'candidate number 3 corresponds to correct spelling for the typo fance with target fence',
#   'candidate number 2 corresponds to correct spelling for the typo for with target far',
#   'candidate number 3 corresponds to correct spelling for the typo form with target farm',
#   'candidate number 1 corresponds to correct spelling for the typo fassion with target fashion',
#   'candidate number 4 corresponds to correct spelling for the typo fat with target fast',
#   'candidate number 1 corresponds to correct spelling for the typo fest with target feast',
#   'candidate number 1 corresponds to correct spelling for the typo fether with target feather',
#   'candidate number 5 corresponds to correct spelling for the typo feed with target fed',
#   'candidate number 2 corresponds to correct spelling for the typo fea with target fee',
#   'candidate number 1 corresponds to correct spelling for the typo fed with target feed',
#   'candidate number 7 corresponds to correct spelling for the typo fell with target feel',
#   'candidate number 2 corresponds to correct spelling for the typo felling with target feeling',
#   'candidate number 13 corresponds to correct spelling for the typo fill with target file',
#   'candidate number 1 corresponds to correct spelling for the typo fery with target ferry',
#   'candidate number 3 corresponds to correct spelling for the typo fate with target fete',
#   'candidate number 2 corresponds to correct spelling for the typo fete with target fetes',
#   'candidate number 1 corresponds to correct spelling for the typo ferce with target fierce',
#   'candidate number 1 corresponds to correct spelling for the typo firey with target fiery',
#   'candidate number 3 corresponds to correct spelling for the typo fith with target fifth',
#   'candidate number 2 corresponds to correct spelling for the typo fright with target fight',
#   'candidate number 2 corresponds to correct spelling for the typo fild with target filed',
#   'candidate number 3 corresponds to correct spelling for the typo filling with target filing',
#   'candidate number 3 corresponds to correct spelling for the typo firms with target films',
#   'candidate number 1 corresponds to correct spelling for the typo fond with target find',
#   'candidate number 4 corresponds to correct spelling for the typo find with target fine',
#   'candidate number 1 corresponds to correct spelling for the typo finst with target finest',
#   'candidate number 6 corresponds to correct spelling for the typo fur with target fir',
#   'candidate number 1 corresponds to correct spelling for the typo frie with target fire',
#   'candidate number 1 corresponds to correct spelling for the typo ferm with target firm',
#   'candidate number 1 corresponds to correct spelling for the typo fite with target fit',
#   'candidate number 1 corresponds to correct spelling for the typo flead with target fled',
#   'candidate number 1 corresponds to correct spelling for the typo flow with target flew',
#   'candidate number 3 corresponds to correct spelling for the typo flot with target float',
#   'candidate number 1 corresponds to correct spelling for the typo flok with target flock',
#   'candidate number 1 corresponds to correct spelling for the typo flor with target floor',
#   'candidate number 3 corresponds to correct spelling for the typo fould with target fold',
#   'candidate number 1 corresponds to correct spelling for the typo fouk with target folk',
#   'candidate number 1 corresponds to correct spelling for the typo polks with target folks',
#   'candidate number 6 corresponds to correct spelling for the typo found with target fund',
#   'candidate number 2 corresponds to correct spelling for the typo hood with target food',
#   'candidate number 5 corresponds to correct spelling for the typo foll with target fool',
#   'candidate number 2 corresponds to correct spelling for the typo or with target for',
#   'candidate number 1 corresponds to correct spelling for the typo forke with target fork',
#   'candidate number 1 corresponds to correct spelling for the typo from with target form',
#   'candidate number 1 corresponds to correct spelling for the typo fram with target frame',
#   'candidate number 1 corresponds to correct spelling for the typo frame with target frames',
#   'candidate number 1 corresponds to correct spelling for the typo freze with target freeze',
#   'candidate number 4 corresponds to correct spelling for the typo forg with target frog',
#   'candidate number 2 corresponds to correct spelling for the typo forst with target frost',
#   'candidate number 1 corresponds to correct spelling for the typo frose with target froze',
#   'candidate number 1 corresponds to correct spelling for the typo fule with target fuel',
#   'candidate number 1 corresponds to correct spelling for the typo fulfillment with target fulfilment',
#   'candidate number 3 corresponds to correct spelling for the typo fon with target fun',
#   'candidate number 4 corresponds to correct spelling for the typo furr with target fur',
#   'candidate number 1 corresponds to correct spelling for the typo fers with target furs',
#   'candidate number 1 corresponds to correct spelling for the typo futher with target further',
#   'candidate number 1 corresponds to correct spelling for the typo fus with target fuss',
#   'candidate number 1 corresponds to correct spelling for the typo gane with target game',
#   'candidate number 1 corresponds to correct spelling for the typo gams with target games',
#   'candidate number 4 corresponds to correct spelling for the typo grage with target garage',
#   'candidate number 5 corresponds to correct spelling for the typo gase with target gas',
#   'candidate number 1 corresponds to correct spelling for the typo guage with target gauge',
#   'candidate number 4 corresponds to correct spelling for the typo jay with target gay',
#   'candidate number 1 corresponds to correct spelling for the typo gees with target geese',
#   'candidate number 3 corresponds to correct spelling for the typo jem with target gem',
#   'candidate number 1 corresponds to correct spelling for the typo gentlemen with target gentleman',
#   'candidate number 1 corresponds to correct spelling for the typo gentleman with target gentlemen',
#   'candidate number 5 corresponds to correct spelling for the typo lowed with target glowed',
#   'candidate number 1 corresponds to correct spelling for the typo knawing with target gnawing',
#   'candidate number 10 corresponds to correct spelling for the typo got with target goat',
#   'candidate number 1 corresponds to correct spelling for the typo goot with target got',
#   'candidate number 10 corresponds to correct spelling for the typo grown with target groan',
#   'candidate number 3 corresponds to correct spelling for the typo grabe with target grab',
#   'candidate number 2 corresponds to correct spelling for the typo grad with target grade',
#   'candidate number 1 corresponds to correct spelling for the typo graps with target grapes',
#   'candidate number 1 corresponds to correct spelling for the typo greas with target grease',
#   'candidate number 1 corresponds to correct spelling for the typo great with target greet',
#   'candidate number 2 corresponds to correct spelling for the typo grined with target grind',
#   'candidate number 1 corresponds to correct spelling for the typo gripe with target grip',
#   'candidate number 1 corresponds to correct spelling for the typo gripped with target grippe',
#   'candidate number 1 corresponds to correct spelling for the typo groun with target grown',
#   'candidate number 2 corresponds to correct spelling for the typo gest with target guest',
#   'candidate number 1 corresponds to correct spelling for the typo gun with target gum',
#   'candidate number 2 corresponds to correct spelling for the typo gon with target gun',
#   'candidate number 1 corresponds to correct spelling for the typo haned with target handed',
#   'candidate number 7 corresponds to correct spelling for the typo hand with target hang',
#   'candidate number 1 corresponds to correct spelling for the typo happly with target happily',
#   'candidate number 1 corresponds to correct spelling for the typo hrd with target hard',
#   'candidate number 1 corresponds to correct spelling for the typo hast with target haste',
#   'candidate number 3 corresponds to correct spelling for the typo hot with target hat',
#   'candidate number 9 corresponds to correct spelling for the typo hat with target hate',
#   'candidate number 16 corresponds to correct spelling for the typo hall with target haul',
#   'candidate number 4 corresponds to correct spelling for the typo hark with target hawk',
#   'candidate number 2 corresponds to correct spelling for the typo the with target they',
#   'candidate number 1 corresponds to correct spelling for the typo hed with target head',
#   'candidate number 1 corresponds to correct spelling for the typo heep with target heap',
#   'candidate number 2 corresponds to correct spelling for the typo her with target hear',
#   'candidate number 2 corresponds to correct spelling for the typo pedge with target hedge',
#   'candidate number 10 corresponds to correct spelling for the typo hell with target heel',
#   'candidate number 1 corresponds to correct spelling for the typo hight with target height',
#   'candidate number 1 corresponds to correct spelling for the typo helo with target hello',
#   'candidate number 9 corresponds to correct spelling for the typo han with target hen',
#   'candidate number 5 corresponds to correct spelling for the typo heard with target herd',
#   'candidate number 4 corresponds to correct spelling for the typo there with target here',
#   'candidate number 2 corresponds to correct spelling for the typo heroe with target hero',
#   'candidate number 3 corresponds to correct spelling for the typo hid with target hide',
#   'candidate number 1 corresponds to correct spelling for the typo hile with target hill',
#   'candidate number 4 corresponds to correct spelling for the typo his with target him',
#   'candidate number 2 corresponds to correct spelling for the typo hent with target hint',
#   'candidate number 2 corresponds to correct spelling for the typo this with target his',
#   'candidate number 1 corresponds to correct spelling for the typo it with target its',
#   'candidate number 4 corresponds to correct spelling for the typo hourse with target hoarse',
#   'candidate number 1 corresponds to correct spelling for the typo houx with target hoax',
#   'candidate number 10 corresponds to correct spelling for the typo hold with target hole',
#   'candidate number 1 corresponds to correct spelling for the typo hok with target hook',
#   'candidate number 4 corresponds to correct spelling for the typo hope with target hop',
#   'candidate number 2 corresponds to correct spelling for the typo hon with target horn',
#   'candidate number 2 corresponds to correct spelling for the typo horried with target horrid',
#   'candidate number 3 corresponds to correct spelling for the typo thot with target hot',
#   'candidate number 1 corresponds to correct spelling for the typo hunge with target hung',
#   'candidate number 3 corresponds to correct spelling for the typo hert with target hurt',
#   'candidate number 1 corresponds to correct spelling for the typo ideas with target idea',
#   'candidate number 1 corresponds to correct spelling for the typo idel with target idle',
#   'candidate number 7 corresponds to correct spelling for the typo ills with target ill',
#   'candidate number 2 corresponds to correct spelling for the typo limitation with target imitation',
#   'candidate number 1 corresponds to correct spelling for the typo insense with target incense',
#   'candidate number 1 corresponds to correct spelling for the typo injur with target injure',
#   'candidate number 1 corresponds to correct spelling for the typo inut with target input',
#   'candidate number 2 corresponds to correct spelling for the typo ensure with target insure',
#   'candidate number 1 corresponds to correct spelling for the typo irn with target iron',
#   'candidate number 1 corresponds to correct spelling for the typo iland with target island',
#   'candidate number 2 corresponds to correct spelling for the typo is with target it',
#   'candidate number 3 corresponds to correct spelling for the typo tiem with target item',
#   'candidate number 2 corresponds to correct spelling for the typo ivery with target ivory',
#   'candidate number 1 corresponds to correct spelling for the typo uam with target jam',
#   'candidate number 2 corresponds to correct spelling for the typo jur with target jar',
#   'candidate number 1 corresponds to correct spelling for the typo joly with target jolly',
#   'candidate number 1 corresponds to correct spelling for the typo jumper with target jumped',
#   'candidate number 1 corresponds to correct spelling for the typo kins with target kinds',
#   'candidate number 1 corresponds to correct spelling for the typo kis with target kiss',
#   'candidate number 3 corresponds to correct spelling for the typo kit with target kite',
#   'candidate number 2 corresponds to correct spelling for the typo nit with target knit',
#   'candidate number 1 corresponds to correct spelling for the typo nock with target knock',
#   'candidate number 7 corresponds to correct spelling for the typo not with target nut',
#   'candidate number 1 corresponds to correct spelling for the typo now with target new',
#   'candidate number 2 corresponds to correct spelling for the typo lable with target label',
#   'candidate number 4 corresponds to correct spelling for the typo lase with target lace',
#   'candidate number 2 corresponds to correct spelling for the typo lader with target ladder',
#   'candidate number 1 corresponds to correct spelling for the typo lak with target lake',
#   'candidate number 12 corresponds to correct spelling for the typo lame with target lamb',
#   'candidate number 3 corresponds to correct spelling for the typo lane with target lame',
#   'candidate number 3 corresponds to correct spelling for the typo lasher with target laser',
#   'candidate number 1 corresponds to correct spelling for the typo lust with target last',
#   'candidate number 1 corresponds to correct spelling for the typo latter with target later',
#   'candidate number 2 corresponds to correct spelling for the typo taugh with target laugh',
#   'candidate number 1 corresponds to correct spelling for the typo laughes with target laughs',
#   'candidate number 2 corresponds to correct spelling for the typo lown with target lawn',
#   'candidate number 3 corresponds to correct spelling for the typo lawer with target lawyer',
#   'candidate number 2 corresponds to correct spelling for the typo leafe with target leaf',
#   'candidate number 1 corresponds to correct spelling for the typo leek with target leak',
#   'candidate number 3 corresponds to correct spelling for the typo leep with target leap',
#   'candidate number 7 corresponds to correct spelling for the typo lest with target less',
#   'candidate number 5 corresponds to correct spelling for the typo lees with target leeds',
#   'candidate number 1 corresponds to correct spelling for the typo leged with target legged',
#   'candidate number 1 corresponds to correct spelling for the typo lemen with target lemon',
#   'candidate number 3 corresponds to correct spelling for the typo leand with target lend',
#   'candidate number 2 corresponds to correct spelling for the typo lessons with target lesson',
#   'candidate number 3 corresponds to correct spelling for the typo license with target licence',
#   'candidate number 4 corresponds to correct spelling for the typo lik with target lick',
#   'candidate number 4 corresponds to correct spelling for the typo led with target lid',
#   'candidate number 3 corresponds to correct spelling for the typo lise with target lies',
#   'candidate number 1 corresponds to correct spelling for the typo liew with target lieu',
#   'candidate number 1 corresponds to correct spelling for the typo left with target lift',
#   'candidate number 2 corresponds to correct spelling for the typo ight with target light',
#   'candidate number 3 corresponds to correct spelling for the typo lighted with target lighter',
#   'candidate number 2 corresponds to correct spelling for the typo lighting with target lightning',
#   'candidate number 1 corresponds to correct spelling for the typo likes with target liked',
#   'candidate number 3 corresponds to correct spelling for the typo liks with target likes',
#   'candidate number 3 corresponds to correct spelling for the typo lime with target limb',
#   'candidate number 4 corresponds to correct spelling for the typo line with target lime',
#   'candidate number 3 corresponds to correct spelling for the typo lits with target list',
#   'candidate number 1 corresponds to correct spelling for the typo locat with target locate',
#   'candidate number 2 corresponds to correct spelling for the typo loge with target log',
#   'candidate number 5 corresponds to correct spelling for the typo lose with target loss',
#   'candidate number 1 corresponds to correct spelling for the typo loose with target lose',
#   'candidate number 1 corresponds to correct spelling for the typo looses with target loses',
#   'candidate number 11 corresponds to correct spelling for the typo lost with target lot',
#   'candidate number 1 corresponds to correct spelling for the typo lowe with target low',
#   'candidate number 1 corresponds to correct spelling for the typo loest with target lowest',
#   'candidate number 1 corresponds to correct spelling for the typo luckly with target luckily',
#   'candidate number 2 corresponds to correct spelling for the typo nad with target mad',
#   'candidate number 1 corresponds to correct spelling for the typo mame with target made',
#   'candidate number 10 corresponds to correct spelling for the typo mall with target mail',
#   'candidate number 1 corresponds to correct spelling for the typo mony with target many',
#   'candidate number 2 corresponds to correct spelling for the typo mape with target map',
#   'candidate number 2 corresponds to correct spelling for the typo mach with target match',
#   'candidate number 1 corresponds to correct spelling for the typo mary with target marry',
#   'candidate number 5 corresponds to correct spelling for the typo mast with target mask',
#   'candidate number 1 corresponds to correct spelling for the typo mas with target mass',
#   'candidate number 1 corresponds to correct spelling for the typo mater with target master',
#   'candidate number 6 corresponds to correct spelling for the typo nat with target mat',
#   'candidate number 1 corresponds to correct spelling for the typo maches with target matches',
#   'candidate number 2 corresponds to correct spelling for the typo mattes with target mates',
#   'candidate number 3 corresponds to correct spelling for the typo mates with target mats',
#   'candidate number 1 corresponds to correct spelling for the typo mather with target matter',
#   'candidate number 1 corresponds to correct spelling for the typo mattres with target mattress',
#   'candidate number 2 corresponds to correct spelling for the typo my with target me',
#   'candidate number 9 corresponds to correct spelling for the typo mell with target meal',
#   'candidate number 1 corresponds to correct spelling for the typo meen with target mean',
#   'candidate number 2 corresponds to correct spelling for the typo meet with target meat',
#   'candidate number 1 corresponds to correct spelling for the typo medel with target medal',
#   'candidate number 1 corresponds to correct spelling for the typo mete with target meet',
#   'candidate number 2 corresponds to correct spelling for the typo mon with target moon',
#   'candidate number 1 corresponds to correct spelling for the typo marry with target merry',
#   'candidate number 2 corresponds to correct spelling for the typo mes with target mess',
#   'candidate number 1 corresponds to correct spelling for the typo mise with target mice',
#   'candidate number 3 corresponds to correct spelling for the typo mist with target midst',
#   'candidate number 1 corresponds to correct spelling for the typo miled with target mild',
#   'candidate number 9 corresponds to correct spelling for the typo mill with target mile',
#   'candidate number 1 corresponds to correct spelling for the typo mils with target miles',
#   'candidate number 1 corresponds to correct spelling for the typo nill with target mill',
#   'candidate number 8 corresponds to correct spelling for the typo mind with target mine',
#   'candidate number 2 corresponds to correct spelling for the typo mirrow with target mirror',
#   'candidate number 3 corresponds to correct spelling for the typo moin with target moan',
#   'candidate number 1 corresponds to correct spelling for the typo moning with target moaning',
#   'candidate number 1 corresponds to correct spelling for the typo mouths with target months',
#   'candidate number 2 corresponds to correct spelling for the typo morning with target mornings',
#   'candidate number 2 corresponds to correct spelling for the typo morsal with target morsel',
#   'candidate number 1 corresponds to correct spelling for the typo moter with target motor',
#   'candidate number 1 corresponds to correct spelling for the typo mostache with target moustache',
#   'candidate number 4 corresponds to correct spelling for the typo mut with target mud',
#   'candidate number 2 corresponds to correct spelling for the typo name with target named',
#   'candidate number 4 corresponds to correct spelling for the typo map with target nap',
#   'candidate number 4 corresponds to correct spelling for the typo naught with target naughty',
#   'candidate number 4 corresponds to correct spelling for the typo net with target neat',
#   'candidate number 1 corresponds to correct spelling for the typo needd with target need',
#   'candidate number 1 corresponds to correct spelling for the typo nedded with target needed',
#   'candidate number 1 corresponds to correct spelling for the typo neighbor with target neighbour',
#   'candidate number 1 corresponds to correct spelling for the typo nast with target nest',
#   'candidate number 1 corresponds to correct spelling for the typo nin with target nine',
#   'candidate number 6 corresponds to correct spelling for the typo on with target no',
#   'candidate number 1 corresponds to correct spelling for the typo nose with target noise',
#   'candidate number 7 corresponds to correct spelling for the typo non with target noon',
#   'candidate number 1 corresponds to correct spelling for the typo nore with target nor',
#   'candidate number 1 corresponds to correct spelling for the typo noth with target north',
#   'candidate number 3 corresponds to correct spelling for the typo ont with target one',
#   'candidate number 1 corresponds to correct spelling for the typo notably with target notable',
#   'candidate number 1 corresponds to correct spelling for the typo notted with target noted',
#   'candidate number 1 corresponds to correct spelling for the typo nots with target notes',
#   'candidate number 1 corresponds to correct spelling for the typo nuse with target nurse',
#   'candidate number 1 corresponds to correct spelling for the typo outs with target oats',
#   'candidate number 1 corresponds to correct spelling for the typo obviousl with target obvious',
#   'candidate number 1 corresponds to correct spelling for the typo ofer with target offer',
#   'candidate number 11 corresponds to correct spelling for the typo o with target oh',
#   'candidate number 5 corresponds to correct spelling for the typo oll with target oil',
#   'candidate number 4 corresponds to correct spelling for the typo one with target ones',
#   'candidate number 1 corresponds to correct spelling for the typo opne with target open',
#   'candidate number 1 corresponds to correct spelling for the typo owr with target our',
#   'candidate number 3 corresponds to correct spelling for the typo ut with target out',
#   'candidate number 5 corresponds to correct spelling for the typo oul with target owl',
#   'candidate number 1 corresponds to correct spelling for the typo owne with target own',
#   'candidate number 1 corresponds to correct spelling for the typo oned with target owned',
#   'candidate number 2 corresponds to correct spelling for the typo ownes with target owns',
#   'candidate number 2 corresponds to correct spelling for the typo pag with target pig',
# ...
#   'candidate number 1 corresponds to correct spelling for the typo sonner with target sooner',
#   'candidate number 2 corresponds to correct spelling for the typo sor with target sore',
#   'candidate number 8 corresponds to correct spelling for the typo sout with target sort',
#   'candidate number 1 corresponds to correct spelling for the typo saught with target sought',
#   'candidate number 2 corresponds to correct spelling for the typo sup with target soup',
#   'candidate number 1 corresponds to correct spelling for the typo sourse with target source',
#   'candidate number 4 corresponds to correct spelling for the typo sew with target sow',
#   'candidate number 1 corresponds to correct spelling for the typo spad with target spade',
#   'candidate number 1 corresponds to correct spelling for the typo spere with target sphere',
#   'candidate number 1 corresponds to correct spelling for the typo spead with target speed',
#   'candidate number 1 corresponds to correct spelling for the typo spiter with target spider',
#   'candidate number 6 corresponds to correct spelling for the typo spen with target spin',
#   'candidate number 1 corresponds to correct spelling for the typo spite with target spit',
#   'candidate number 1 corresponds to correct spelling for the typo spol with target spoil',
#   'candidate number 2 corresponds to correct spelling for the typo spoon with target spoons',
#   'candidate number 2 corresponds to correct spelling for the typo sprot with target sport',
#   'candidate number 3 corresponds to correct spelling for the typo storts with target sports',
#   'candidate number 1 corresponds to correct spelling for the typo srot with target spot',
#   'candidate number 1 corresponds to correct spelling for the typo star with target stair',
#   'candidate number 1 corresponds to correct spelling for the typo stap with target stop',
#   'candidate number 3 corresponds to correct spelling for the typo sand with target stand',
#   'candidate number 1 corresponds to correct spelling for the typo str with target star',
#   'candidate number 1 corresponds to correct spelling for the typo stors with target stars',
#   'candidate number 2 corresponds to correct spelling for the typo startes with target starts',
#   'candidate number 2 corresponds to correct spelling for the typo stave with target starve',
#   'candidate number 2 corresponds to correct spelling for the typo statu with target statue',
#   'candidate number 1 corresponds to correct spelling for the typo staye with target stay',
#   'candidate number 1 corresponds to correct spelling for the typo staing with target staying',
#   'candidate number 1 corresponds to correct spelling for the typo stel with target steal',
#   'candidate number 7 corresponds to correct spelling for the typo stelling with target stealing',
#   'candidate number 1 corresponds to correct spelling for the typo step with target steep',
#   'candidate number 3 corresponds to correct spelling for the typo ster with target steer',
#   'candidate number 2 corresponds to correct spelling for the typo stife with target stiff',
#   'candidate number 1 corresponds to correct spelling for the typo stich with target stitch',
#   'candidate number 4 corresponds to correct spelling for the typo stold with target stole',
#   'candidate number 1 corresponds to correct spelling for the typo stopen with target stolen',
#   'candidate number 1 corresponds to correct spelling for the typo stor with target store',
#   'candidate number 2 corresponds to correct spelling for the typo stort with target story',
#   'candidate number 1 corresponds to correct spelling for the typo strick with target strict',
#   'candidate number 1 corresponds to correct spelling for the typo stricke with target strike',
#   'candidate number 1 corresponds to correct spelling for the typo stomp with target stump',
#   'candidate number 1 corresponds to correct spelling for the typo stile with target style',
#   'candidate number 1 corresponds to correct spelling for the typo sumit with target submit',
#   'candidate number 2 corresponds to correct spelling for the typo suite with target suit',
#   'candidate number 1 corresponds to correct spelling for the typo suites with target suits',
#   'candidate number 3 corresponds to correct spelling for the typo sume with target sums',
#   'candidate number 1 corresponds to correct spelling for the typo sonk with target sunk',
#   'candidate number 1 corresponds to correct spelling for the typo support with target supports',
#   'candidate number 2 corresponds to correct spelling for the typo sue with target sure',
#   'candidate number 1 corresponds to correct spelling for the typo swop with target swap',
#   'candidate number 1 corresponds to correct spelling for the typo sweetes with target sweetest',
#   'candidate number 1 corresponds to correct spelling for the typo sweet with target sweets',
#   'candidate number 2 corresponds to correct spelling for the typo swin with target swim',
#   'candidate number 1 corresponds to correct spelling for the typo swich with target switch',
#   'candidate number 4 corresponds to correct spelling for the typo sord with target sword',
#   'candidate number 1 corresponds to correct spelling for the typo table with target tables',
#   'candidate number 1 corresponds to correct spelling for the typo tablt with target tablet',
#   'candidate number 2 corresponds to correct spelling for the typo takle with target tackle',
#   'candidate number 4 corresponds to correct spelling for the typo tage with target tag',
#   'candidate number 11 corresponds to correct spelling for the typo tall with target tail',
#   'candidate number 1 corresponds to correct spelling for the typo takin with target taking',
#   'candidate number 1 corresponds to correct spelling for the typo taked with target talked',
#   'candidate number 1 corresponds to correct spelling for the typo toll with target tall',
#   'candidate number 5 corresponds to correct spelling for the typo tam with target tame',
#   'candidate number 7 corresponds to correct spelling for the typo tare with target tar',
#   'candidate number 1 corresponds to correct spelling for the typo tee with target tea',
#   'candidate number 3 corresponds to correct spelling for the typo term with target team',
#   'candidate number 1 corresponds to correct spelling for the typo teese with target tease',
#   'candidate number 2 corresponds to correct spelling for the typo tens with target ten',
#   'candidate number 6 corresponds to correct spelling for the typo tent with target tenth',
#   'candidate number 1 corresponds to correct spelling for the typo turm with target term',
#   'candidate number 1 corresponds to correct spelling for the typo terrible with target terribly',
#   'candidate number 3 corresponds to correct spelling for the typo test with target tests',
#   'candidate number 1 corresponds to correct spelling for the typo then with target them',
#   'candidate number 1 corresponds to correct spelling for the typo think with target thank',
#   'candidate number 1 corresponds to correct spelling for the typo thinking with target thanking',
#   'candidate number 1 corresponds to correct spelling for the typo thik with target thick',
#   'candidate number 1 corresponds to correct spelling for the typo theif with target thief',
#   'candidate number 2 corresponds to correct spelling for the typo tin with target thin',
#   'candidate number 1 corresponds to correct spelling for the typo thirdy with target thirdly',
#   'candidate number 1 corresponds to correct spelling for the typo thurough with target thorough',
#   'candidate number 1 corresponds to correct spelling for the typo through with target though',
#   'candidate number 1 corresponds to correct spelling for the typo thought with target thoughts',
#   'candidate number 3 corresponds to correct spelling for the typo thow with target throw',
#   'candidate number 1 corresponds to correct spelling for the typo thum with target thumb',
#   'candidate number 1 corresponds to correct spelling for the typo tile with target till',
#   'candidate number 1 corresponds to correct spelling for the typo timed with target timid',
#   'candidate number 5 corresponds to correct spelling for the typo ten with target tin',
#   'candidate number 3 corresponds to correct spelling for the typo tep with target tip',
#   'candidate number 2 corresponds to correct spelling for the typo tier with target tire',
#   'candidate number 1 corresponds to correct spelling for the typo tried with target tired',
#   'candidate number 1 corresponds to correct spelling for the typo tittle with target title',
#   'candidate number 2 corresponds to correct spelling for the typo two with target too',
#   'candidate number 5 corresponds to correct spelling for the typo tost with target toast',
#   'candidate number 9 corresponds to correct spelling for the typo tow with target toe',
#   'candidate number 6 corresponds to correct spelling for the typo tun with target ton',
#   'candidate number 4 corresponds to correct spelling for the typo tol with target tool',
#   'candidate number 1 corresponds to correct spelling for the typo toches with target torches',
#   'candidate number 3 corresponds to correct spelling for the typo tor with target tore',
#   'candidate number 2 corresponds to correct spelling for the typo turn with target torn',
#   'candidate number 1 corresponds to correct spelling for the typo tuch with target touch',
#   'candidate number 1 corresponds to correct spelling for the typo towl with target towel',
#   'candidate number 9 corresponds to correct spelling for the typo toy with target toys',
#   'candidate number 1 corresponds to correct spelling for the typo trap with target tramp',
#   'candidate number 1 corresponds to correct spelling for the typo tranquillity with target tranquility',
#   'candidate number 2 corresponds to correct spelling for the typo tre with target tree',
#   'candidate number 4 corresponds to correct spelling for the typo tress with target trees',
#   'candidate number 2 corresponds to correct spelling for the typo trem with target trim',
#   'candidate number 2 corresponds to correct spelling for the typo troup with target troop',
#   'candidate number 2 corresponds to correct spelling for the typo truk with target truck',
#   'candidate number 2 corresponds to correct spelling for the typo tob with target tub',
#   'candidate number 1 corresponds to correct spelling for the typo twen with target twin',
#   'candidate number 1 corresponds to correct spelling for the typo twe with target two',
#   'candidate number 1 corresponds to correct spelling for the typo untimate with target ultimate',
#   'candidate number 1 corresponds to correct spelling for the typo use with target us',
#   'candidate number 1 corresponds to correct spelling for the typo vage with target vague',
#   'candidate number 1 corresponds to correct spelling for the typo vun with target van',
#   'candidate number 1 corresponds to correct spelling for the typo vew with target view',
#   'candidate number 3 corresponds to correct spelling for the typo vin with target vine',
#   'candidate number 1 corresponds to correct spelling for the typo wast with target west',
#   'candidate number 4 corresponds to correct spelling for the typo want with target wait',
#   'candidate number 1 corresponds to correct spelling for the typo wated with target waited',
#   'candidate number 3 corresponds to correct spelling for the typo waek with target wake',
#   'candidate number 4 corresponds to correct spelling for the typo woll with target wool',
#   'candidate number 1 corresponds to correct spelling for the typo whant with target want',
#   'candidate number 1 corresponds to correct spelling for the typo wantes with target wants',
#   'candidate number 2 corresponds to correct spelling for the typo wor with target wore',
#   'candidate number 1 corresponds to correct spelling for the typo weary with target wary',
#   'candidate number 1 corresponds to correct spelling for the typo waching with target watching',
#   'candidate number 2 corresponds to correct spelling for the typo wate with target waste',
#   'candidate number 1 corresponds to correct spelling for the typo wached with target watched',
#   'candidate number 3 corresponds to correct spelling for the typo wa with target way',
#   'candidate number 5 corresponds to correct spelling for the typo way with target ways',
#   'candidate number 2 corresponds to correct spelling for the typo wey with target we',
#   'candidate number 1 corresponds to correct spelling for the typo week with target weeks',
#   'candidate number 2 corresponds to correct spelling for the typo weare with target wear',
#   'candidate number 2 corresponds to correct spelling for the typo wery with target weary',
#   'candidate number 1 corresponds to correct spelling for the typo wether with target weather',
#   'candidate number 2 corresponds to correct spelling for the typo weve with target weave',
#   'candidate number 1 corresponds to correct spelling for the typo will with target well',
#   'candidate number 3 corresponds to correct spelling for the typo weat with target wheat',
#   'candidate number 1 corresponds to correct spelling for the typo weel with target wheel',
#   'candidate number 4 corresponds to correct spelling for the typo wich with target witch',
#   'candidate number 5 corresponds to correct spelling for the typo wile with target wild',
#   'candidate number 1 corresponds to correct spelling for the typo wip with target wipe',
#   'candidate number 1 corresponds to correct spelling for the typo wite with target white',
#   'candidate number 1 corresponds to correct spelling for the typo wido with target widow',
#   'candidate number 2 corresponds to correct spelling for the typo with with target width',
#   'candidate number 1 corresponds to correct spelling for the typo weg with target wig',
#   'candidate number 6 corresponds to correct spelling for the typo wind with target win',
#   'candidate number 2 corresponds to correct spelling for the typo win with target wind',
#   'candidate number 1 corresponds to correct spelling for the typo witer with target winter',
#   'candidate number 1 corresponds to correct spelling for the typo wize with target wise',
#   'candidate number 2 corresponds to correct spelling for the typo wis with target wish',
#   'candidate number 1 corresponds to correct spelling for the typo women with target woman',
#   'candidate number 2 corresponds to correct spelling for the typo wone with target won',
#   'candidate number 1 corresponds to correct spelling for the typo wod with target wood',
#   'candidate number 2 corresponds to correct spelling for the typo wollen with target woolen',
#   'candidate number 3 corresponds to correct spelling for the typo wood with target word',
#   'candidate number 1 corresponds to correct spelling for the typo wourld with target world',
#   'candidate number 1 corresponds to correct spelling for the typo warn with target worn',
#   'candidate number 2 corresponds to correct spelling for the typo worring with target worrying',
#   'candidate number 3 corresponds to correct spelling for the typo worse with target worst',
#   'candidate number 1 corresponds to correct spelling for the typo woth with target worth',
#   'candidate number 2 corresponds to correct spelling for the typo rap with target wrap',
#   'candidate number 3 corresponds to correct spelling for the typo reath with target wreath',
#   'candidate number 1 corresponds to correct spelling for the typo rist with target wrist',
#   'candidate number 1 corresponds to correct spelling for the typo writter with target writer',
#   'candidate number 2 corresponds to correct spelling for the typo yorn with target yarn',
#   'candidate number 1 corresponds to correct spelling for the typo yel with target yell',
#   'candidate number 1 corresponds to correct spelling for the typo yoman with target yeoman',
#   'candidate number 2 corresponds to correct spelling for the typo yas with target yes',
#   'candidate number 1 corresponds to correct spelling for the typo yat with target yet'])

# %% [markdown]
# Performance is fairly okay, 69% is not that bad! Of course, it is a problem that some words are not in the lexicon, so perhaps they can are recognised as English words but are not in the absolute probability function. In that sense, smoothing the absolute probabilities of the words dictionary, too, might have helped.
#
# Now, however, it is time for the next step: what happens when context comes into play?

# %% [markdown]
# ## Step 7: Integrating context
#
# A spelling corrector using the noisy channel is useful, but typos don't occur in an isolated manner, they are usually part of a bigger sentence. Our previous typo corrector in the sentence does not make use of context, but that might be useful given that some words can occur around other words more than others.
#
# Thus, I will use a **bigram language model**, taking into account the word before and the word after. An example of how this would work is shown below, from [Jurafsky and Martin (2020, p.6-7)](https://web.stanford.edu/~jurafsky/slp3/B.pdf). In this case, the sentences to be corrected was
#
# *\". . . was called a “stellar and versatile ***acress*** whose combination of sass and glamour has defined her. . . \"*
#
# According to our **noisy channel model**, *acress* would be corrected as *across*, yet it should be *actress* giving the context.

# %%
correct_typos("was called a stellar and versatile acress whose combination of sass and glamour has defined her")
# Out:
# "stellar" has been recognised as a typo, but cannot be corrected at this time
# "versatile" has been recognised as a typo, but cannot be corrected at this time
# 'was called a stellar and versatile across whose combination of says and glamour his defined her'

# %% [markdown]
# Well, in our model we have the additional problem that *stellar* and *versatile* are not seen as English words... But coming back to the problem of **acress**.
#
# We would have calculate the **probability of the intended word occurring after the prior word** and **the probability of the next word occurring after the intended word**.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then, we also need to multiply it by the **noisy channel probability**.

# %% [markdown]
# ### Step 7.1: Making bigrams and a bigram corpus
#
# First, I wrote a function to create bigrams from a corpus, which we will need later. I also decided to make a bigger corpus: in addition to big.txt, I add the Brown corpus and the Reuters corpus. This way, we have more bigrams.

# %%
def bigram_corpus(corpus):
    """Function that takes a corpus in the form of a list and returns a list of tuples of bigrams"""
    ngrams = zip(*[corpus[i:] for i in range(2)])
    return list(ngrams)

bigram_corpus(["hello", "i", "am", "programming"])
# Out:
# [('hello', 'i'), ('i', 'am'), ('am', 'programming')]

# %%
nltk.download('reuters')
from nltk.corpus import reuters
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     /Users/sashakenjeeva/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!

# %% [markdown]
# I remove punctuation. This is not ideal, because some punctuation will give us clues as to corrections, but given the limited model, this is better to avoid bigrams like ("hello", " , ") and instead have ("hello", "how") for *hello, how are you?*

# %%
punct_re = r"[^\w\s]" #a pattern that will match anything that is not a word or not a space

# %%
no_punct_big_txt = [word for word in big_txt if not re.search(punct_re, word)]
no_punct_brown_words = [word for word in brown_words if not re.search(punct_re, word)]
no_punct_reuters_corpus = [word.lower() for word in reuters.words() if not re.search(punct_re, word)]
no_punct_corpus = no_punct_big_txt + no_punct_brown_words + no_punct_reuters_corpus
no_punct_corpus
# Out:
# ['the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  '15',
#  'in',
#  'our',
#  'series',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'copyright',
#  'laws',
#  'are',
#  'changing',
#  'all',
#  'over',
#  'the',
#  'world',
#  'be',
#  'sure',
#  'to',
#  'check',
#  'the',
#  'copyright',
#  'laws',
#  'for',
#  'your',
#  'country',
#  'before',
#  'downloading',
#  'or',
#  'redistributing',
#  'this',
#  'or',
#  'any',
#  'other',
#  'project',
#  'gutenberg',
#  'ebook',
#  'this',
#  'header',
#  'should',
#  'be',
#  'the',
#  'first',
#  'thing',
#  'seen',
#  'when',
#  'viewing',
#  'this',
#  'project',
#  'gutenberg',
#  'file',
#  'please',
#  'do',
#  'not',
#  'remove',
#  'it',
#  'do',
#  'not',
#  'change',
#  'or',
#  'edit',
#  'the',
#  'header',
#  'without',
#  'written',
#  'permission',
#  'please',
#  'read',
#  'the',
#  'legal',
#  'small',
#  'print',
#  'and',
#  'other',
#  'information',
#  'about',
#  'the',
#  'ebook',
#  'and',
#  'project',
#  'gutenberg',
#  'at',
#  'the',
#  'bottom',
#  'of',
#  'this',
#  'file',
#  'included',
#  'is',
#  'important',
#  'information',
#  'about',
#  'your',
#  'specific',
#  'rights',
#  'and',
#  'restrictions',
#  'in',
#  'how',
#  'the',
#  'file',
#  'may',
#  'be',
#  'used',
#  'you',
#  'can',
#  'also',
#  'find',
#  'out',
#  'about',
#  'how',
#  'to',
#  'make',
#  'a',
#  'donation',
#  'to',
#  'project',
#  'gutenberg',
#  'and',
#  'how',
#  'to',
#  'get',
#  'involved',
#  'to',
#  'the',
#  'world',
#  'of',
#  'free',
#  'plain',
#  'vanilla',
#  'electronic',
#  'readable',
#  'by',
#  'both',
#  'humans',
#  'and',
#  'by',
#  'computers',
#  'since',
#  'ebooks',
#  'were',
#  'prepared',
#  'by',
#  'thousands',
#  'of',
#  'volunteers',
#  'title',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'author',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'release',
#  'date',
#  'march',
#  '1999',
#  'ebook',
#  '1661',
#  'most',
#  'recently',
#  'updated',
#  'november',
#  '29',
#  '2002',
#  'edition',
#  '12',
#  'language',
#  'english',
#  'character',
#  'set',
#  'encoding',
#  'ascii',
#  'start',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'additional',
#  'editing',
#  'by',
#  'jose',
#  'menendez',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'contents',
#  'i',
#  'a',
#  'scandal',
#  'in',
#  'bohemia',
#  'ii',
#  'the',
#  'league',
#  'iii',
#  'a',
#  'case',
#  'of',
#  'identity',
#  'iv',
#  'the',
#  'boscombe',
#  'valley',
#  'mystery',
#  'the',
#  'five',
#  'orange',
#  'pips',
#  'vi',
#  'the',
#  'man',
#  'with',
#  'the',
#  'twisted',
#  'lip',
#  'vii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'blue',
#  'carbuncle',
#  'viii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'speckled',
#  'band',
#  'ix',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'engineer',
#  'thumb',
#  'x',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'noble',
#  'bachelor',
#  'xi',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'beryl',
#  'coronet',
#  'xii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'copper',
#  'beeches',
#  'adventure',
#  'i',
#  'a',
#  'scandal',
#  'in',
#  'bohemia',
#  'i',
#  'to',
#  'sherlock',
#  'holmes',
#  'she',
#  'is',
#  'always',
#  'the',
#  'woman',
#  'i',
#  'have',
#  'seldom',
#  'heard',
#  'him',
#  'mention',
#  'her',
#  'under',
#  'any',
#  'other',
#  'name',
#  'in',
#  'his',
#  'eyes',
#  'she',
#  'eclipses',
#  'and',
#  'predominates',
#  'the',
#  'whole',
#  'of',
#  'her',
#  'sex',
#  'it',
#  'was',
#  'not',
#  'that',
#  'he',
#  'felt',
#  'any',
#  'emotion',
#  'akin',
#  'to',
#  'love',
#  'for',
#  'irene',
#  'adler',
#  'all',
#  'emotions',
#  'and',
#  'that',
#  'one',
#  'particularly',
#  'were',
#  'abhorrent',
#  'to',
#  'his',
#  'cold',
#  'precise',
#  'but',
#  'admirably',
#  'balanced',
#  'mind',
#  'he',
#  'was',
#  'i',
#  'take',
#  'it',
#  'the',
#  'most',
#  'perfect',
#  'reasoning',
#  'and',
#  'observing',
#  'machine',
#  'that',
#  'the',
#  'world',
#  'has',
#  'seen',
#  'but',
#  'as',
#  'a',
#  'lover',
#  'he',
#  'would',
#  'have',
#  'placed',
#  'himself',
#  'in',
#  'a',
#  'false',
#  'position',
#  'he',
#  'never',
#  'spoke',
#  'of',
#  'the',
#  'softer',
#  'passions',
#  'save',
#  'with',
#  'a',
#  'gibe',
#  'and',
#  'a',
#  'sneer',
#  'they',
#  'were',
#  'admirable',
#  'things',
#  'for',
#  'the',
#  'observer',
#  'excellent',
#  'for',
#  'drawing',
#  'the',
#  'veil',
#  'from',
#  'men',
#  'motives',
#  'and',
#  'actions',
#  'but',
#  'for',
#  'the',
#  'trained',
#  'reasoner',
#  'to',
#  'admit',
#  'such',
#  'intrusions',
#  'into',
#  'his',
#  'own',
#  'delicate',
#  'and',
#  'finely',
#  'adjusted',
#  'temperament',
#  'was',
#  'to',
#  'introduce',
#  'a',
#  'distracting',
#  'factor',
#  'which',
#  'might',
#  'throw',
#  'a',
#  'doubt',
#  'upon',
#  'all',
#  'his',
#  'mental',
#  'results',
#  'grit',
#  'in',
#  'a',
#  'sensitive',
#  'instrument',
#  'or',
#  'a',
#  'crack',
#  'in',
#  'one',
#  'of',
#  'his',
#  'own',
#  'lenses',
#  'would',
#  'not',
#  'be',
#  'more',
#  'disturbing',
#  'than',
#  'a',
#  'strong',
#  'emotion',
#  'in',
#  'a',
#  'nature',
#  'such',
#  'as',
#  'his',
#  'and',
#  'yet',
#  'there',
#  'was',
#  'but',
#  'one',
#  'woman',
#  'to',
#  'him',
#  'and',
#  'that',
#  'woman',
#  'was',
#  'the',
#  'late',
#  'irene',
#  'adler',
#  'of',
#  'dubious',
#  'and',
#  'questionable',
#  'memory',
#  'i',
#  'had',
#  'seen',
#  'little',
#  'of',
#  'holmes',
#  'lately',
#  'my',
#  'marriage',
#  'had',
#  'drifted',
#  'us',
#  'away',
#  'from',
#  'each',
#  'other',
#  'my',
#  'own',
#  'complete',
#  'happiness',
#  'and',
#  'the',
#  'interests',
#  'which',
#  'rise',
#  'up',
#  'around',
#  'the',
#  'man',
#  'who',
#  'first',
#  'finds',
#  'himself',
#  'master',
#  'of',
#  'his',
#  'own',
#  'establishment',
#  'were',
#  'sufficient',
#  'to',
#  'absorb',
#  'all',
#  'my',
#  'attention',
#  'while',
#  'holmes',
#  'who',
#  'loathed',
#  'every',
#  'form',
#  'of',
#  'society',
#  'with',
#  'his',
#  'whole',
#  'bohemian',
#  'soul',
#  'remained',
#  'in',
#  'our',
#  'lodgings',
#  'in',
#  'baker',
#  'street',
#  'buried',
#  'among',
#  'his',
#  'old',
#  'books',
#  'and',
#  'alternating',
#  'from',
#  'week',
#  'to',
#  'week',
#  'between',
#  'cocaine',
#  'and',
#  'ambition',
#  'the',
#  'drowsiness',
#  'of',
#  'the',
#  'drug',
#  'and',
#  'the',
#  'fierce',
#  'energy',
#  'of',
#  'his',
#  'own',
#  'keen',
#  'nature',
#  'he',
#  'was',
#  'still',
#  'as',
#  'ever',
#  'deeply',
#  'attracted',
#  'by',
#  'the',
#  'study',
#  'of',
#  'crime',
#  'and',
#  'occupied',
#  'his',
#  'immense',
#  'faculties',
#  'and',
#  'extraordinary',
#  'powers',
#  'of',
#  'observation',
#  'in',
#  'following',
#  'out',
#  'those',
#  'clues',
#  'and',
#  'clearing',
#  'up',
#  'those',
#  'mysteries',
#  'which',
#  'had',
#  'been',
#  'abandoned',
#  'as',
#  'hopeless',
#  'by',
#  'the',
#  'official',
#  'police',
#  'from',
#  'time',
#  'to',
#  'time',
#  'i',
#  'heard',
#  'some',
#  'vague',
#  'account',
#  'of',
#  'his',
#  'doings',
#  'of',
#  'his',
#  'summons',
#  'to',
#  'odessa',
#  'in',
#  'the',
#  'case',
#  'of',
#  'the',
#  'trepoff',
#  'murder',
#  'of',
#  'his',
#  'clearing',
#  'up',
#  'of',
#  'the',
#  'singular',
#  'tragedy',
#  'of',
#  'the',
#  'atkinson',
#  'brothers',
#  'at',
#  'trincomalee',
#  'and',
#  'finally',
#  'of',
#  'the',
#  'mission',
#  'which',
#  'he',
#  'had',
#  'accomplished',
#  'so',
#  'delicately',
#  'and',
#  'successfully',
#  'for',
#  'the',
#  'reigning',
#  'family',
#  'of',
#  'holland',
#  'beyond',
#  'these',
#  'signs',
#  'of',
#  'his',
#  'activity',
#  'however',
#  'which',
#  'i',
#  'merely',
#  'shared',
#  'with',
#  'all',
#  'the',
#  'readers',
#  'of',
#  'the',
#  'daily',
#  'press',
#  'i',
#  'knew',
#  'little',
#  'of',
#  'my',
#  'former',
#  'friend',
#  'and',
#  'companion',
#  'one',
#  'night',
#  'it',
#  'was',
#  'on',
#  'the',
#  'twentieth',
#  'of',
#  'march',
#  '1888',
#  'i',
#  'was',
#  'returning',
#  'from',
#  'a',
#  'journey',
#  'to',
#  'a',
#  'patient',
#  'for',
#  'i',
#  'had',
#  'now',
#  'returned',
#  'to',
#  'civil',
#  'practice',
#  'when',
#  'my',
#  'way',
#  'led',
#  'me',
#  'through',
#  'baker',
#  'street',
#  'as',
#  'i',
#  'passed',
#  'the',
#  'door',
#  'which',
#  'must',
#  'always',
#  'be',
#  'associated',
#  'in',
#  'my',
#  'mind',
#  'with',
#  'my',
#  'wooing',
#  'and',
#  'with',
#  'the',
#  'dark',
#  'incidents',
#  'of',
#  'the',
#  'study',
#  'in',
#  'scarlet',
#  'i',
#  'was',
#  'seized',
#  'with',
#  'a',
#  'keen',
#  'desire',
#  'to',
#  'see',
#  'holmes',
#  'again',
#  'and',
#  'to',
#  'know',
#  'how',
#  'he',
#  'was',
#  'employing',
#  'his',
#  'extraordinary',
#  'powers',
#  'his',
#  'rooms',
#  'were',
#  'brilliantly',
#  'lit',
#  'and',
#  'even',
#  'as',
#  'i',
#  'looked',
#  'up',
#  'i',
#  'saw',
#  'his',
#  'tall',
#  'spare',
#  'figure',
#  'pass',
#  'twice',
#  'in',
#  'a',
#  'dark',
#  'silhouette',
#  'against',
#  'the',
#  'blind',
#  'he',
#  'was',
#  'pacing',
#  'the',
#  'room',
#  'swiftly',
#  'eagerly',
#  'with',
#  'his',
#  'head',
#  'sunk',
#  'upon',
#  'his',
#  'chest',
#  'and',
#  'his',
#  'hands',
#  'clasped',
#  'behind',
#  'him',
#  'to',
#  'me',
#  'who',
#  'knew',
#  'his',
#  'every',
#  'mood',
#  'and',
#  'habit',
#  'his',
#  'attitude',
#  'and',
#  'manner',
#  'told',
#  'their',
#  'own',
#  'story',
#  'he',
#  'was',
#  'at',
#  'work',
#  'again',
#  'he',
#  'had',
#  'risen',
#  'out',
#  'of',
#  'his',
#  'dreams',
#  'and',
#  'was',
#  'hot',
#  'upon',
#  'the',
#  'scent',
#  'of',
#  'some',
#  'new',
#  'problem',
#  'i',
#  'rang',
#  'the',
#  'bell',
#  'and',
#  'was',
#  'shown',
#  'up',
#  'to',
#  'the',
#  'chamber',
#  'which',
#  'had',
#  'formerly',
#  'been',
#  'in',
#  'part',
#  'my',
#  'own',
#  'his',
#  'manner',
#  'was',
#  'not',
#  'effusive',
#  'it',
#  'seldom',
#  'was',
#  'but',
#  'he',
#  'was',
#  'glad',
#  'i',
#  'think',
#  'to',
#  'see',
#  'me',
#  'with',
#  'hardly',
#  'a',
#  'word',
#  'spoken',
#  'but',
#  'with',
#  'a',
#  'kindly',
#  'eye',
#  'he',
#  'waved',
#  'me',
#  'to',
#  'an',
#  'armchair',
#  'threw',
#  'across',
#  'his',
#  'case',
#  'of',
#  'cigars',
#  'and',
#  'indicated',
#  'a',
#  'spirit',
#  'case',
#  'and',
#  'a',
#  'gasogene',
#  'in',
#  'the',
#  'corner',
#  'then',
#  'he',
#  'stood',
#  'before',
#  'the',
#  'fire',
#  'and',
#  'looked',
#  'me',
#  'over',
#  'in',
#  'his',
#  'singular',
#  'introspective',
#  'fashion',
#  'wedlock',
#  'suits',
#  'you',
#  'he',
#  'remarked',
#  'i',
#  'think',
#  'watson',
#  'that',
#  'you',
#  'have',
#  'put',
#  'on',
#  'seven',
#  'and',
#  'a',
#  'half',
#  'pounds',
#  'since',
#  'i',
#  'saw',
#  'you',
#  'seven',
#  'i',
#  ...]

# %% [markdown]
# Making a list of bigrams out of this big corpus:

# %%
bigrams_list = (bigram_corpus(no_punct_big_txt) + bigram_corpus(no_punct_brown_words) + bigram_corpus(no_punct_reuters_corpus))
bigrams_list
# Out:
# [('the', 'project'),
#  ('project', 'gutenberg'),
#  ('gutenberg', 'ebook'),
#  ('ebook', 'of'),
#  ('of', 'the'),
#  ('the', 'adventures'),
#  ('adventures', 'of'),
#  ('of', 'sherlock'),
#  ('sherlock', 'holmes'),
#  ('holmes', 'by'),
#  ('by', 'sir'),
#  ('sir', 'arthur'),
#  ('arthur', 'conan'),
#  ('conan', 'doyle'),
#  ('doyle', '15'),
#  ('15', 'in'),
#  ('in', 'our'),
#  ('our', 'series'),
#  ('series', 'by'),
#  ('by', 'sir'),
#  ('sir', 'arthur'),
#  ('arthur', 'conan'),
#  ('conan', 'doyle'),
#  ('doyle', 'copyright'),
#  ('copyright', 'laws'),
#  ('laws', 'are'),
#  ('are', 'changing'),
#  ('changing', 'all'),
#  ('all', 'over'),
#  ('over', 'the'),
#  ('the', 'world'),
#  ('world', 'be'),
#  ('be', 'sure'),
#  ('sure', 'to'),
#  ('to', 'check'),
#  ('check', 'the'),
#  ('the', 'copyright'),
#  ('copyright', 'laws'),
#  ('laws', 'for'),
#  ('for', 'your'),
#  ('your', 'country'),
#  ('country', 'before'),
#  ('before', 'downloading'),
#  ('downloading', 'or'),
#  ('or', 'redistributing'),
#  ('redistributing', 'this'),
#  ('this', 'or'),
#  ('or', 'any'),
#  ('any', 'other'),
#  ('other', 'project'),
#  ('project', 'gutenberg'),
#  ('gutenberg', 'ebook'),
#  ('ebook', 'this'),
#  ('this', 'header'),
#  ('header', 'should'),
#  ('should', 'be'),
#  ('be', 'the'),
#  ('the', 'first'),
#  ('first', 'thing'),
#  ('thing', 'seen'),
#  ('seen', 'when'),
#  ('when', 'viewing'),
#  ('viewing', 'this'),
#  ('this', 'project'),
#  ('project', 'gutenberg'),
#  ('gutenberg', 'file'),
#  ('file', 'please'),
#  ('please', 'do'),
#  ('do', 'not'),
#  ('not', 'remove'),
#  ('remove', 'it'),
#  ('it', 'do'),
#  ('do', 'not'),
#  ('not', 'change'),
#  ('change', 'or'),
#  ('or', 'edit'),
#  ('edit', 'the'),
#  ('the', 'header'),
#  ('header', 'without'),
#  ('without', 'written'),
#  ('written', 'permission'),
#  ('permission', 'please'),
#  ('please', 'read'),
#  ('read', 'the'),
#  ('the', 'legal'),
#  ('legal', 'small'),
#  ('small', 'print'),
#  ('print', 'and'),
#  ('and', 'other'),
#  ('other', 'information'),
#  ('information', 'about'),
#  ('about', 'the'),
#  ('the', 'ebook'),
#  ('ebook', 'and'),
#  ('and', 'project'),
#  ('project', 'gutenberg'),
#  ('gutenberg', 'at'),
#  ('at', 'the'),
#  ('the', 'bottom'),
#  ('bottom', 'of'),
#  ('of', 'this'),
#  ('this', 'file'),
#  ('file', 'included'),
#  ('included', 'is'),
#  ('is', 'important'),
#  ('important', 'information'),
#  ('information', 'about'),
#  ('about', 'your'),
#  ('your', 'specific'),
#  ('specific', 'rights'),
#  ('rights', 'and'),
#  ('and', 'restrictions'),
#  ('restrictions', 'in'),
#  ('in', 'how'),
#  ('how', 'the'),
#  ('the', 'file'),
#  ('file', 'may'),
#  ('may', 'be'),
#  ('be', 'used'),
#  ('used', 'you'),
#  ('you', 'can'),
#  ('can', 'also'),
#  ('also', 'find'),
#  ('find', 'out'),
#  ('out', 'about'),
#  ('about', 'how'),
#  ('how', 'to'),
#  ('to', 'make'),
#  ('make', 'a'),
#  ('a', 'donation'),
#  ('donation', 'to'),
#  ('to', 'project'),
#  ('project', 'gutenberg'),
#  ('gutenberg', 'and'),
#  ('and', 'how'),
#  ('how', 'to'),
#  ('to', 'get'),
#  ('get', 'involved'),
#  ('involved', 'to'),
#  ('to', 'the'),
#  ('the', 'world'),
#  ('world', 'of'),
#  ('of', 'free'),
#  ('free', 'plain'),
#  ('plain', 'vanilla'),
#  ('vanilla', 'electronic'),
#  ('electronic', 'readable'),
#  ('readable', 'by'),
#  ('by', 'both'),
#  ('both', 'humans'),
#  ('humans', 'and'),
#  ('and', 'by'),
#  ('by', 'computers'),
#  ('computers', 'since'),
#  ('since', 'ebooks'),
#  ('ebooks', 'were'),
#  ('were', 'prepared'),
#  ('prepared', 'by'),
#  ('by', 'thousands'),
#  ('thousands', 'of'),
#  ('of', 'volunteers'),
#  ('volunteers', 'title'),
#  ('title', 'the'),
#  ('the', 'adventures'),
#  ('adventures', 'of'),
#  ('of', 'sherlock'),
#  ('sherlock', 'holmes'),
#  ('holmes', 'author'),
#  ('author', 'sir'),
#  ('sir', 'arthur'),
#  ('arthur', 'conan'),
#  ('conan', 'doyle'),
#  ('doyle', 'release'),
#  ('release', 'date'),
#  ('date', 'march'),
#  ('march', '1999'),
#  ('1999', 'ebook'),
#  ('ebook', '1661'),
#  ('1661', 'most'),
#  ('most', 'recently'),
#  ('recently', 'updated'),
#  ('updated', 'november'),
#  ('november', '29'),
#  ('29', '2002'),
#  ('2002', 'edition'),
#  ('edition', '12'),
#  ('12', 'language'),
#  ('language', 'english'),
#  ('english', 'character'),
#  ('character', 'set'),
#  ('set', 'encoding'),
#  ('encoding', 'ascii'),
#  ('ascii', 'start'),
#  ('start', 'of'),
#  ('of', 'the'),
#  ('the', 'project'),
#  ('project', 'gutenberg'),
#  ('gutenberg', 'ebook'),
#  ('ebook', 'the'),
#  ('the', 'adventures'),
#  ('adventures', 'of'),
#  ('of', 'sherlock'),
#  ('sherlock', 'holmes'),
#  ('holmes', 'additional'),
#  ('additional', 'editing'),
#  ('editing', 'by'),
#  ('by', 'jose'),
#  ('jose', 'menendez'),
#  ('menendez', 'the'),
#  ('the', 'adventures'),
#  ('adventures', 'of'),
#  ('of', 'sherlock'),
#  ('sherlock', 'holmes'),
#  ('holmes', 'by'),
#  ('by', 'sir'),
#  ('sir', 'arthur'),
#  ('arthur', 'conan'),
#  ('conan', 'doyle'),
#  ('doyle', 'contents'),
#  ('contents', 'i'),
#  ('i', 'a'),
#  ('a', 'scandal'),
#  ('scandal', 'in'),
#  ('in', 'bohemia'),
#  ('bohemia', 'ii'),
#  ('ii', 'the'),
#  ('the', 'league'),
#  ('league', 'iii'),
#  ('iii', 'a'),
#  ('a', 'case'),
#  ('case', 'of'),
#  ('of', 'identity'),
#  ('identity', 'iv'),
#  ('iv', 'the'),
#  ('the', 'boscombe'),
#  ('boscombe', 'valley'),
#  ('valley', 'mystery'),
#  ('mystery', 'the'),
#  ('the', 'five'),
#  ('five', 'orange'),
#  ('orange', 'pips'),
#  ('pips', 'vi'),
#  ('vi', 'the'),
#  ('the', 'man'),
#  ('man', 'with'),
#  ('with', 'the'),
#  ('the', 'twisted'),
#  ('twisted', 'lip'),
#  ('lip', 'vii'),
#  ('vii', 'the'),
#  ('the', 'adventure'),
#  ('adventure', 'of'),
#  ('of', 'the'),
#  ('the', 'blue'),
#  ('blue', 'carbuncle'),
#  ('carbuncle', 'viii'),
#  ('viii', 'the'),
#  ('the', 'adventure'),
#  ('adventure', 'of'),
#  ('of', 'the'),
#  ('the', 'speckled'),
#  ('speckled', 'band'),
#  ('band', 'ix'),
#  ('ix', 'the'),
#  ('the', 'adventure'),
#  ('adventure', 'of'),
#  ('of', 'the'),
#  ('the', 'engineer'),
#  ('engineer', 'thumb'),
#  ('thumb', 'x'),
#  ('x', 'the'),
#  ('the', 'adventure'),
#  ('adventure', 'of'),
#  ('of', 'the'),
#  ('the', 'noble'),
#  ('noble', 'bachelor'),
#  ('bachelor', 'xi'),
#  ('xi', 'the'),
#  ('the', 'adventure'),
#  ('adventure', 'of'),
#  ('of', 'the'),
#  ('the', 'beryl'),
#  ('beryl', 'coronet'),
#  ('coronet', 'xii'),
#  ('xii', 'the'),
#  ('the', 'adventure'),
#  ('adventure', 'of'),
#  ('of', 'the'),
#  ('the', 'copper'),
#  ('copper', 'beeches'),
#  ('beeches', 'adventure'),
#  ('adventure', 'i'),
#  ('i', 'a'),
#  ('a', 'scandal'),
#  ('scandal', 'in'),
#  ('in', 'bohemia'),
#  ('bohemia', 'i'),
#  ('i', 'to'),
#  ('to', 'sherlock'),
#  ('sherlock', 'holmes'),
#  ('holmes', 'she'),
#  ('she', 'is'),
#  ('is', 'always'),
#  ('always', 'the'),
#  ('the', 'woman'),
#  ('woman', 'i'),
#  ('i', 'have'),
#  ('have', 'seldom'),
#  ('seldom', 'heard'),
#  ('heard', 'him'),
#  ('him', 'mention'),
#  ('mention', 'her'),
#  ('her', 'under'),
#  ('under', 'any'),
#  ('any', 'other'),
#  ('other', 'name'),
#  ('name', 'in'),
#  ('in', 'his'),
#  ('his', 'eyes'),
#  ('eyes', 'she'),
#  ('she', 'eclipses'),
#  ('eclipses', 'and'),
#  ('and', 'predominates'),
#  ('predominates', 'the'),
#  ('the', 'whole'),
#  ('whole', 'of'),
#  ('of', 'her'),
#  ('her', 'sex'),
#  ('sex', 'it'),
#  ('it', 'was'),
#  ('was', 'not'),
#  ('not', 'that'),
#  ('that', 'he'),
#  ('he', 'felt'),
#  ('felt', 'any'),
#  ('any', 'emotion'),
#  ('emotion', 'akin'),
#  ('akin', 'to'),
#  ('to', 'love'),
#  ('love', 'for'),
#  ('for', 'irene'),
#  ('irene', 'adler'),
#  ('adler', 'all'),
#  ('all', 'emotions'),
#  ('emotions', 'and'),
#  ('and', 'that'),
#  ('that', 'one'),
#  ('one', 'particularly'),
#  ('particularly', 'were'),
#  ('were', 'abhorrent'),
#  ('abhorrent', 'to'),
#  ('to', 'his'),
#  ('his', 'cold'),
#  ('cold', 'precise'),
#  ('precise', 'but'),
#  ('but', 'admirably'),
#  ('admirably', 'balanced'),
#  ('balanced', 'mind'),
#  ('mind', 'he'),
#  ('he', 'was'),
#  ('was', 'i'),
#  ('i', 'take'),
#  ('take', 'it'),
#  ('it', 'the'),
#  ('the', 'most'),
#  ('most', 'perfect'),
#  ('perfect', 'reasoning'),
#  ('reasoning', 'and'),
#  ('and', 'observing'),
#  ('observing', 'machine'),
#  ('machine', 'that'),
#  ('that', 'the'),
#  ('the', 'world'),
#  ('world', 'has'),
#  ('has', 'seen'),
#  ('seen', 'but'),
#  ('but', 'as'),
#  ('as', 'a'),
#  ('a', 'lover'),
#  ('lover', 'he'),
#  ('he', 'would'),
#  ('would', 'have'),
#  ('have', 'placed'),
#  ('placed', 'himself'),
#  ('himself', 'in'),
#  ('in', 'a'),
#  ('a', 'false'),
#  ('false', 'position'),
#  ('position', 'he'),
#  ('he', 'never'),
#  ('never', 'spoke'),
#  ('spoke', 'of'),
#  ('of', 'the'),
#  ('the', 'softer'),
#  ('softer', 'passions'),
#  ('passions', 'save'),
#  ('save', 'with'),
#  ('with', 'a'),
#  ('a', 'gibe'),
#  ('gibe', 'and'),
#  ('and', 'a'),
#  ('a', 'sneer'),
#  ('sneer', 'they'),
#  ('they', 'were'),
#  ('were', 'admirable'),
#  ('admirable', 'things'),
#  ('things', 'for'),
#  ('for', 'the'),
#  ('the', 'observer'),
#  ('observer', 'excellent'),
#  ('excellent', 'for'),
#  ('for', 'drawing'),
#  ('drawing', 'the'),
#  ('the', 'veil'),
#  ('veil', 'from'),
#  ('from', 'men'),
#  ('men', 'motives'),
#  ('motives', 'and'),
#  ('and', 'actions'),
#  ('actions', 'but'),
#  ('but', 'for'),
#  ('for', 'the'),
#  ('the', 'trained'),
#  ('trained', 'reasoner'),
#  ('reasoner', 'to'),
#  ('to', 'admit'),
#  ('admit', 'such'),
#  ('such', 'intrusions'),
#  ('intrusions', 'into'),
#  ('into', 'his'),
#  ('his', 'own'),
#  ('own', 'delicate'),
#  ('delicate', 'and'),
#  ('and', 'finely'),
#  ('finely', 'adjusted'),
#  ('adjusted', 'temperament'),
#  ('temperament', 'was'),
#  ('was', 'to'),
#  ('to', 'introduce'),
#  ('introduce', 'a'),
#  ('a', 'distracting'),
#  ('distracting', 'factor'),
#  ('factor', 'which'),
#  ('which', 'might'),
#  ('might', 'throw'),
#  ('throw', 'a'),
#  ('a', 'doubt'),
#  ('doubt', 'upon'),
#  ('upon', 'all'),
#  ('all', 'his'),
#  ('his', 'mental'),
#  ('mental', 'results'),
#  ('results', 'grit'),
#  ('grit', 'in'),
#  ('in', 'a'),
#  ('a', 'sensitive'),
#  ('sensitive', 'instrument'),
#  ('instrument', 'or'),
#  ('or', 'a'),
#  ('a', 'crack'),
#  ('crack', 'in'),
#  ('in', 'one'),
#  ('one', 'of'),
#  ('of', 'his'),
#  ('his', 'own'),
#  ('own', 'lenses'),
#  ('lenses', 'would'),
#  ('would', 'not'),
#  ('not', 'be'),
#  ('be', 'more'),
#  ('more', 'disturbing'),
#  ('disturbing', 'than'),
#  ('than', 'a'),
#  ('a', 'strong'),
#  ('strong', 'emotion'),
#  ('emotion', 'in'),
#  ('in', 'a'),
#  ('a', 'nature'),
#  ('nature', 'such'),
#  ('such', 'as'),
#  ('as', 'his'),
#  ('his', 'and'),
#  ('and', 'yet'),
#  ('yet', 'there'),
#  ('there', 'was'),
#  ('was', 'but'),
#  ('but', 'one'),
#  ('one', 'woman'),
#  ('woman', 'to'),
#  ('to', 'him'),
#  ('him', 'and'),
#  ('and', 'that'),
#  ('that', 'woman'),
#  ('woman', 'was'),
#  ('was', 'the'),
#  ('the', 'late'),
#  ('late', 'irene'),
#  ('irene', 'adler'),
#  ('adler', 'of'),
#  ('of', 'dubious'),
#  ('dubious', 'and'),
#  ('and', 'questionable'),
#  ('questionable', 'memory'),
#  ('memory', 'i'),
#  ('i', 'had'),
#  ('had', 'seen'),
#  ('seen', 'little'),
#  ('little', 'of'),
#  ('of', 'holmes'),
#  ('holmes', 'lately'),
#  ('lately', 'my'),
#  ('my', 'marriage'),
#  ('marriage', 'had'),
#  ('had', 'drifted'),
#  ('drifted', 'us'),
#  ('us', 'away'),
#  ('away', 'from'),
#  ('from', 'each'),
#  ('each', 'other'),
#  ('other', 'my'),
#  ('my', 'own'),
#  ('own', 'complete'),
#  ('complete', 'happiness'),
#  ('happiness', 'and'),
#  ('and', 'the'),
#  ('the', 'interests'),
#  ('interests', 'which'),
#  ('which', 'rise'),
#  ('rise', 'up'),
#  ('up', 'around'),
#  ('around', 'the'),
#  ('the', 'man'),
#  ('man', 'who'),
#  ('who', 'first'),
#  ('first', 'finds'),
#  ('finds', 'himself'),
#  ('himself', 'master'),
#  ('master', 'of'),
#  ('of', 'his'),
#  ('his', 'own'),
#  ('own', 'establishment'),
#  ('establishment', 'were'),
#  ('were', 'sufficient'),
#  ('sufficient', 'to'),
#  ('to', 'absorb'),
#  ('absorb', 'all'),
#  ('all', 'my'),
#  ('my', 'attention'),
#  ('attention', 'while'),
#  ('while', 'holmes'),
#  ('holmes', 'who'),
#  ('who', 'loathed'),
#  ('loathed', 'every'),
#  ('every', 'form'),
#  ('form', 'of'),
#  ('of', 'society'),
#  ('society', 'with'),
#  ('with', 'his'),
#  ('his', 'whole'),
#  ('whole', 'bohemian'),
#  ('bohemian', 'soul'),
#  ('soul', 'remained'),
#  ('remained', 'in'),
#  ('in', 'our'),
#  ('our', 'lodgings'),
#  ('lodgings', 'in'),
#  ('in', 'baker'),
#  ('baker', 'street'),
#  ('street', 'buried'),
#  ('buried', 'among'),
#  ('among', 'his'),
#  ('his', 'old'),
#  ('old', 'books'),
#  ('books', 'and'),
#  ('and', 'alternating'),
#  ('alternating', 'from'),
#  ('from', 'week'),
#  ('week', 'to'),
#  ('to', 'week'),
#  ('week', 'between'),
#  ('between', 'cocaine'),
#  ('cocaine', 'and'),
#  ('and', 'ambition'),
#  ('ambition', 'the'),
#  ('the', 'drowsiness'),
#  ('drowsiness', 'of'),
#  ('of', 'the'),
#  ('the', 'drug'),
#  ('drug', 'and'),
#  ('and', 'the'),
#  ('the', 'fierce'),
#  ('fierce', 'energy'),
#  ('energy', 'of'),
#  ('of', 'his'),
#  ('his', 'own'),
#  ('own', 'keen'),
#  ('keen', 'nature'),
#  ('nature', 'he'),
#  ('he', 'was'),
#  ('was', 'still'),
#  ('still', 'as'),
#  ('as', 'ever'),
#  ('ever', 'deeply'),
#  ('deeply', 'attracted'),
#  ('attracted', 'by'),
#  ('by', 'the'),
#  ('the', 'study'),
#  ('study', 'of'),
#  ('of', 'crime'),
#  ('crime', 'and'),
#  ('and', 'occupied'),
#  ('occupied', 'his'),
#  ('his', 'immense'),
#  ('immense', 'faculties'),
#  ('faculties', 'and'),
#  ('and', 'extraordinary'),
#  ('extraordinary', 'powers'),
#  ('powers', 'of'),
#  ('of', 'observation'),
#  ('observation', 'in'),
#  ('in', 'following'),
#  ('following', 'out'),
#  ('out', 'those'),
#  ('those', 'clues'),
#  ('clues', 'and'),
#  ('and', 'clearing'),
#  ('clearing', 'up'),
#  ('up', 'those'),
#  ('those', 'mysteries'),
#  ('mysteries', 'which'),
#  ('which', 'had'),
#  ('had', 'been'),
#  ('been', 'abandoned'),
#  ('abandoned', 'as'),
#  ('as', 'hopeless'),
#  ('hopeless', 'by'),
#  ('by', 'the'),
#  ('the', 'official'),
#  ('official', 'police'),
#  ('police', 'from'),
#  ('from', 'time'),
#  ('time', 'to'),
#  ('to', 'time'),
#  ('time', 'i'),
#  ('i', 'heard'),
#  ('heard', 'some'),
#  ('some', 'vague'),
#  ('vague', 'account'),
#  ('account', 'of'),
#  ('of', 'his'),
#  ('his', 'doings'),
#  ('doings', 'of'),
#  ('of', 'his'),
#  ('his', 'summons'),
#  ('summons', 'to'),
#  ('to', 'odessa'),
#  ('odessa', 'in'),
#  ('in', 'the'),
#  ('the', 'case'),
#  ('case', 'of'),
#  ('of', 'the'),
#  ('the', 'trepoff'),
#  ('trepoff', 'murder'),
#  ('murder', 'of'),
#  ('of', 'his'),
#  ('his', 'clearing'),
#  ('clearing', 'up'),
#  ('up', 'of'),
#  ('of', 'the'),
#  ('the', 'singular'),
#  ('singular', 'tragedy'),
#  ('tragedy', 'of'),
#  ('of', 'the'),
#  ('the', 'atkinson'),
#  ('atkinson', 'brothers'),
#  ('brothers', 'at'),
#  ('at', 'trincomalee'),
#  ('trincomalee', 'and'),
#  ('and', 'finally'),
#  ('finally', 'of'),
#  ('of', 'the'),
#  ('the', 'mission'),
#  ('mission', 'which'),
#  ('which', 'he'),
#  ('he', 'had'),
#  ('had', 'accomplished'),
#  ('accomplished', 'so'),
#  ('so', 'delicately'),
#  ('delicately', 'and'),
#  ('and', 'successfully'),
#  ('successfully', 'for'),
#  ('for', 'the'),
#  ('the', 'reigning'),
#  ('reigning', 'family'),
#  ('family', 'of'),
#  ('of', 'holland'),
#  ('holland', 'beyond'),
#  ('beyond', 'these'),
#  ('these', 'signs'),
#  ('signs', 'of'),
#  ('of', 'his'),
#  ('his', 'activity'),
#  ('activity', 'however'),
#  ('however', 'which'),
#  ('which', 'i'),
#  ('i', 'merely'),
#  ('merely', 'shared'),
#  ('shared', 'with'),
#  ('with', 'all'),
#  ('all', 'the'),
#  ('the', 'readers'),
#  ('readers', 'of'),
#  ('of', 'the'),
#  ('the', 'daily'),
#  ('daily', 'press'),
#  ('press', 'i'),
#  ('i', 'knew'),
#  ('knew', 'little'),
#  ('little', 'of'),
#  ('of', 'my'),
#  ('my', 'former'),
#  ('former', 'friend'),
#  ('friend', 'and'),
#  ('and', 'companion'),
#  ('companion', 'one'),
#  ('one', 'night'),
#  ('night', 'it'),
#  ('it', 'was'),
#  ('was', 'on'),
#  ('on', 'the'),
#  ('the', 'twentieth'),
#  ('twentieth', 'of'),
#  ('of', 'march'),
#  ('march', '1888'),
#  ('1888', 'i'),
#  ('i', 'was'),
#  ('was', 'returning'),
#  ('returning', 'from'),
#  ('from', 'a'),
#  ('a', 'journey'),
#  ('journey', 'to'),
#  ('to', 'a'),
#  ('a', 'patient'),
#  ('patient', 'for'),
#  ('for', 'i'),
#  ('i', 'had'),
#  ('had', 'now'),
#  ('now', 'returned'),
#  ('returned', 'to'),
#  ('to', 'civil'),
#  ('civil', 'practice'),
#  ('practice', 'when'),
#  ('when', 'my'),
#  ('my', 'way'),
#  ('way', 'led'),
#  ('led', 'me'),
#  ('me', 'through'),
#  ('through', 'baker'),
#  ('baker', 'street'),
#  ('street', 'as'),
#  ('as', 'i'),
#  ('i', 'passed'),
#  ('passed', 'the'),
#  ('the', 'door'),
#  ('door', 'which'),
#  ('which', 'must'),
#  ('must', 'always'),
#  ('always', 'be'),
#  ('be', 'associated'),
#  ('associated', 'in'),
#  ('in', 'my'),
#  ('my', 'mind'),
#  ('mind', 'with'),
#  ('with', 'my'),
#  ('my', 'wooing'),
#  ('wooing', 'and'),
#  ('and', 'with'),
#  ('with', 'the'),
#  ('the', 'dark'),
#  ('dark', 'incidents'),
#  ('incidents', 'of'),
#  ('of', 'the'),
#  ('the', 'study'),
#  ('study', 'in'),
#  ('in', 'scarlet'),
#  ('scarlet', 'i'),
#  ('i', 'was'),
#  ('was', 'seized'),
#  ('seized', 'with'),
#  ('with', 'a'),
#  ('a', 'keen'),
#  ('keen', 'desire'),
#  ('desire', 'to'),
#  ('to', 'see'),
#  ('see', 'holmes'),
#  ('holmes', 'again'),
#  ('again', 'and'),
#  ('and', 'to'),
#  ('to', 'know'),
#  ('know', 'how'),
#  ('how', 'he'),
#  ('he', 'was'),
#  ('was', 'employing'),
#  ('employing', 'his'),
#  ('his', 'extraordinary'),
#  ('extraordinary', 'powers'),
#  ('powers', 'his'),
#  ('his', 'rooms'),
#  ('rooms', 'were'),
#  ('were', 'brilliantly'),
#  ('brilliantly', 'lit'),
#  ('lit', 'and'),
#  ('and', 'even'),
#  ('even', 'as'),
#  ('as', 'i'),
#  ('i', 'looked'),
#  ('looked', 'up'),
#  ('up', 'i'),
#  ('i', 'saw'),
#  ('saw', 'his'),
#  ('his', 'tall'),
#  ('tall', 'spare'),
#  ('spare', 'figure'),
#  ('figure', 'pass'),
#  ('pass', 'twice'),
#  ('twice', 'in'),
#  ('in', 'a'),
#  ('a', 'dark'),
#  ('dark', 'silhouette'),
#  ('silhouette', 'against'),
#  ('against', 'the'),
#  ('the', 'blind'),
#  ('blind', 'he'),
#  ('he', 'was'),
#  ('was', 'pacing'),
#  ('pacing', 'the'),
#  ('the', 'room'),
#  ('room', 'swiftly'),
#  ('swiftly', 'eagerly'),
#  ('eagerly', 'with'),
#  ('with', 'his'),
#  ('his', 'head'),
#  ('head', 'sunk'),
#  ('sunk', 'upon'),
#  ('upon', 'his'),
#  ('his', 'chest'),
#  ('chest', 'and'),
#  ('and', 'his'),
#  ('his', 'hands'),
#  ('hands', 'clasped'),
#  ('clasped', 'behind'),
#  ('behind', 'him'),
#  ('him', 'to'),
#  ('to', 'me'),
#  ('me', 'who'),
#  ('who', 'knew'),
#  ('knew', 'his'),
#  ('his', 'every'),
#  ('every', 'mood'),
#  ('mood', 'and'),
#  ('and', 'habit'),
#  ('habit', 'his'),
#  ('his', 'attitude'),
#  ('attitude', 'and'),
#  ('and', 'manner'),
#  ('manner', 'told'),
#  ('told', 'their'),
#  ('their', 'own'),
#  ('own', 'story'),
#  ('story', 'he'),
#  ('he', 'was'),
#  ('was', 'at'),
#  ('at', 'work'),
#  ('work', 'again'),
#  ('again', 'he'),
#  ('he', 'had'),
#  ('had', 'risen'),
#  ('risen', 'out'),
#  ('out', 'of'),
#  ('of', 'his'),
#  ('his', 'dreams'),
#  ('dreams', 'and'),
#  ('and', 'was'),
#  ('was', 'hot'),
#  ('hot', 'upon'),
#  ('upon', 'the'),
#  ('the', 'scent'),
#  ('scent', 'of'),
#  ('of', 'some'),
#  ('some', 'new'),
#  ('new', 'problem'),
#  ('problem', 'i'),
#  ('i', 'rang'),
#  ('rang', 'the'),
#  ('the', 'bell'),
#  ('bell', 'and'),
#  ('and', 'was'),
#  ('was', 'shown'),
#  ('shown', 'up'),
#  ('up', 'to'),
#  ('to', 'the'),
#  ('the', 'chamber'),
#  ('chamber', 'which'),
#  ('which', 'had'),
#  ('had', 'formerly'),
#  ('formerly', 'been'),
#  ('been', 'in'),
#  ('in', 'part'),
#  ('part', 'my'),
#  ('my', 'own'),
#  ('own', 'his'),
#  ('his', 'manner'),
#  ('manner', 'was'),
#  ('was', 'not'),
#  ('not', 'effusive'),
#  ('effusive', 'it'),
#  ('it', 'seldom'),
#  ('seldom', 'was'),
#  ('was', 'but'),
#  ('but', 'he'),
#  ('he', 'was'),
#  ('was', 'glad'),
#  ('glad', 'i'),
#  ('i', 'think'),
#  ('think', 'to'),
#  ('to', 'see'),
#  ('see', 'me'),
#  ('me', 'with'),
#  ('with', 'hardly'),
#  ('hardly', 'a'),
#  ('a', 'word'),
#  ('word', 'spoken'),
#  ('spoken', 'but'),
#  ('but', 'with'),
#  ('with', 'a'),
#  ('a', 'kindly'),
#  ('kindly', 'eye'),
#  ('eye', 'he'),
#  ('he', 'waved'),
#  ('waved', 'me'),
#  ('me', 'to'),
#  ('to', 'an'),
#  ('an', 'armchair'),
#  ('armchair', 'threw'),
#  ('threw', 'across'),
#  ('across', 'his'),
#  ('his', 'case'),
#  ('case', 'of'),
#  ('of', 'cigars'),
#  ('cigars', 'and'),
#  ('and', 'indicated'),
#  ('indicated', 'a'),
#  ('a', 'spirit'),
#  ('spirit', 'case'),
#  ('case', 'and'),
#  ('and', 'a'),
#  ('a', 'gasogene'),
#  ('gasogene', 'in'),
#  ('in', 'the'),
#  ('the', 'corner'),
#  ('corner', 'then'),
#  ('then', 'he'),
#  ('he', 'stood'),
#  ('stood', 'before'),
#  ('before', 'the'),
#  ('the', 'fire'),
#  ('fire', 'and'),
#  ('and', 'looked'),
#  ('looked', 'me'),
#  ('me', 'over'),
#  ('over', 'in'),
#  ('in', 'his'),
#  ('his', 'singular'),
#  ('singular', 'introspective'),
#  ('introspective', 'fashion'),
#  ('fashion', 'wedlock'),
#  ('wedlock', 'suits'),
#  ('suits', 'you'),
#  ('you', 'he'),
#  ('he', 'remarked'),
#  ('remarked', 'i'),
#  ('i', 'think'),
#  ('think', 'watson'),
#  ('watson', 'that'),
#  ('that', 'you'),
#  ('you', 'have'),
#  ('have', 'put'),
#  ('put', 'on'),
#  ('on', 'seven'),
#  ('seven', 'and'),
#  ('and', 'a'),
#  ('a', 'half'),
#  ('half', 'pounds'),
#  ('pounds', 'since'),
#  ('since', 'i'),
#  ('i', 'saw'),
#  ('saw', 'you'),
#  ('you', 'seven'),
#  ('seven', 'i'),
#  ('i', 'answered'),
#  ...]

# %% [markdown]
# Checking if our example is in the corpus:

# %%
("versatile", "actress") in bigrams_list
# Out:
# False

# %%
("versatile", "across") in bigrams_list
# Out:
# False

# %% [markdown]
# Nope, we will need **Laplace smoothing** here, too. This is because we need to give **some probability** to bigrams not seen in the corpus.

# %% [markdown]
# ### Step 7.2: Bigram frequency dictionary and smoothed probabilties dictionary
#
# So, I develop a function that counts bigrams. I use the function I had developed earlier (dict_freq).

# %%
bigram_count_dict = dict_freq(bigrams_list)
bigram_count_dict
# Out:
# {('of', 'the'): 29170,
#  ('in', 'the'): 19276,
#  ('to', 'the'): 10473,
#  ('and', 'the'): 7077,
#  ('on', 'the'): 6984,
#  ('for', 'the'): 5982,
#  ('said', 'the'): 5915,
#  ('u', 's'): 5699,
#  ('at', 'the'): 5097,
#  ('to', 'be'): 4972,
#  ('by', 'the'): 4844,
#  ('with', 'the'): 4748,
#  ('from', 'the'): 4610,
#  ('said', 'it'): 4441,
#  ('mln', 'dlrs'): 4401,
#  ('of', 'a'): 4340,
#  ('in', 'a'): 4323,
#  ('that', 'the'): 4161,
#  ('it', 'is'): 3968,
#  ('mln', 'vs'): 3922,
#  ('it', 'was'): 3410,
#  ('he', 'said'): 3354,
#  ('cts', 'vs'): 3312,
#  ('the', 'company'): 3254,
#  ('with', 'a'): 2854,
#  ('as', 'a'): 2595,
#  ('000', 'vs'): 2582,
#  ('will', 'be'): 2500,
#  ('he', 'was'): 2473,
#  ('he', 'had'): 2402,
#  ('had', 'been'): 2360,
#  ('the', 'u'): 2270,
#  ('to', 'a'): 2246,
#  ('did', 'not'): 2218,
#  ('cts', 'net'): 2196,
#  ('the', 'same'): 2162,
#  ('the', 'first'): 2159,
#  ('would', 'be'): 2141,
#  ('for', 'a'): 2099,
#  ('as', 'the'): 2006,
#  ('of', 'his'): 1952,
#  ('and', 'a'): 1920,
#  ('is', 'a'): 1903,
#  ('into', 'the'): 1882,
#  ('vs', 'loss'): 1776,
#  ('dlrs', 'in'): 1761,
#  ('may', 'be'): 1714,
#  ('has', 'been'): 1712,
#  ('was', 'a'): 1682,
#  ('is', 'the'): 1676,
#  ('one', 'of'): 1668,
#  ('it', 'said'): 1667,
#  ('billion', 'dlrs'): 1664,
#  ('have', 'been'): 1659,
#  ('pct', 'of'): 1616,
#  ('that', 'he'): 1613,
#  ('there', 'is'): 1554,
#  ('of', 'its'): 1542,
#  ('the', 'united'): 1530,
#  ('000', 'dlrs'): 1527,
#  ('said', 'he'): 1493,
#  ('in', 'his'): 1483,
#  ('last', 'year'): 1442,
#  ('united', 'states'): 1440,
#  ('5', 'mln'): 1362,
#  ('inc', 'lt'): 1362,
#  ('pct', 'in'): 1361,
#  ('over', 'the'): 1347,
#  ('all', 'the'): 1345,
#  ('that', 'it'): 1343,
#  ('the', 'new'): 1340,
#  ('on', 'a'): 1324,
#  ('was', 'the'): 1317,
#  ('more', 'than'): 1301,
#  ('out', 'of'): 1290,
#  ('there', 'was'): 1285,
#  ('is', 'not'): 1284,
#  ('by', 'a'): 1274,
#  ('when', 'the'): 1268,
#  ('company', 'said'): 1263,
#  ('but', 'the'): 1238,
#  ('dlrs', 'vs'): 1238,
#  ('a', 'share'): 1234,
#  ('of', 'this'): 1222,
#  ('000', 'revs'): 1210,
#  ('and', 'in'): 1196,
#  ('and', 'that'): 1193,
#  ('it', 'has'): 1186,
#  ('should', 'be'): 1178,
#  ('vs', '1'): 1176,
#  ('2', 'mln'): 1161,
#  ('up', 'to'): 1157,
#  ('1', 'mln'): 1157,
#  ('at', 'a'): 1143,
#  ('under', 'the'): 1142,
#  ('3', 'mln'): 1130,
#  ('this', 'year'): 1127,
#  ('the', 'government'): 1119,
#  ('was', 'not'): 1106,
#  ('6', 'mln'): 1106,
#  ('said', 'that'): 1105,
#  ('the', 'other'): 1102,
#  ('4', 'mln'): 1092,
#  ('8', 'mln'): 1082,
#  ('net', 'shr'): 1080,
#  ('they', 'were'): 1078,
#  ('corp', 'lt'): 1078,
#  ('said', 'in'): 1077,
#  ('in', '1986'): 1075,
#  ('prince', 'andrew'): 1067,
#  ('9', 'mln'): 1060,
#  ('000', 'tonnes'): 1055,
#  ('avg', 'shrs'): 1052,
#  ('the', 'bank'): 1047,
#  ('if', 'the'): 1045,
#  ('in', 'which'): 1036,
#  ('a', 'year'): 1031,
#  ('per', 'share'): 1029,
#  ('it', 'would'): 1023,
#  ('dlrs', 'a'): 1017,
#  ('and', 'he'): 1016,
#  ('during', 'the'): 1016,
#  ('to', 'him'): 1015,
#  ('7', 'mln'): 1015,
#  ('in', 'january'): 1007,
#  ('end', 'of'): 1003,
#  ('i', 'have'): 1001,
#  ('vs', 'profit'): 997,
#  ('the', 'dollar'): 994,
#  ('and', 'to'): 992,
#  ('part', 'of'): 978,
#  ('0', 'mln'): 978,
#  ('new', 'york'): 969,
#  ('could', 'not'): 963,
#  ('in', 'february'): 960,
#  ('net', 'loss'): 951,
#  ('expected', 'to'): 950,
#  ('to', 'his'): 945,
#  ('the', 'world'): 944,
#  ('the', 'most'): 940,
#  ('it', 'will'): 939,
#  ('in', 'this'): 937,
#  ('through', 'the'): 935,
#  ('due', 'to'): 927,
#  ('i', 'am'): 913,
#  ('the', 'end'): 912,
#  ('dlrs', 'or'): 907,
#  ('bank', 'of'): 905,
#  ('a', 'new'): 905,
#  ('inc', 'said'): 903,
#  ('to', 'make'): 902,
#  ('from', 'a'): 901,
#  ('mln', 'stg'): 899,
#  ('about', 'the'): 897,
#  ('would', 'have'): 897,
#  ('this', 'is'): 889,
#  ('after', 'the'): 887,
#  ('number', 'of'): 880,
#  ('to', 'have'): 874,
#  ('shr', 'loss'): 868,
#  ('the', 'year'): 862,
#  ('they', 'are'): 861,
#  ('of', 'their'): 859,
#  ('must', 'be'): 858,
#  ('such', 'as'): 856,
#  ('against', 'the'): 855,
#  ('in', 'its'): 853,
#  ('to', 'do'): 851,
#  ('the', 'french'): 846,
#  ('4th', 'qtr'): 843,
#  ('the', 'old'): 841,
#  ('and', 'i'): 835,
#  ('the', 'two'): 834,
#  ('qtr', 'net'): 826,
#  ('as', 'he'): 825,
#  ('with', 'his'): 817,
#  ('not', 'be'): 814,
#  ('a', 'few'): 814,
#  ('mln', 'tonnes'): 809,
#  ('can', 'be'): 798,
#  ('of', 'an'): 792,
#  ('and', 'his'): 781,
#  ('to', 'buy'): 781,
#  ('she', 'was'): 779,
#  ('he', 'is'): 778,
#  ('be', 'a'): 776,
#  ('when', 'he'): 776,
#  ('to', 'take'): 775,
#  ('mln', 'note'): 773,
#  ('between', 'the'): 772,
#  ('which', 'is'): 770,
#  ('that', 'is'): 764,
#  ('could', 'be'): 764,
#  ('said', 'its'): 757,
#  ('who', 'had'): 756,
#  ('to', 'see'): 754,
#  ('because', 'of'): 754,
#  ('the', 'whole'): 752,
#  ('would', 'not'): 743,
#  ('him', 'and'): 743,
#  ('and', 'then'): 739,
#  ('he', 'would'): 738,
#  ('does', 'not'): 737,
#  ('5', 'pct'): 734,
#  ('net', 'profit'): 728,
#  ('before', 'the'): 727,
#  ('compared', 'with'): 724,
#  ('in', '1985'): 723,
#  ('which', 'the'): 719,
#  ('and', 'other'): 713,
#  ('we', 'have'): 713,
#  ('on', 'his'): 712,
#  ('corp', 'said'): 709,
#  ('at', 'least'): 708,
#  ('is', 'to'): 707,
#  ('but', 'he'): 706,
#  ('not', 'to'): 706,
#  ('she', 'had'): 701,
#  ('as', 'well'): 701,
#  ('in', 'an'): 697,
#  ('a', 'man'): 696,
#  ('to', 'her'): 695,
#  ('tonnes', 'of'): 695,
#  ('of', 'them'): 694,
#  ('have', 'to'): 692,
#  ('as', 'if'): 690,
#  ('the', 'last'): 687,
#  ('there', 'are'): 681,
#  ('that', 'they'): 680,
#  ('the', 'next'): 676,
#  ('the', 'state'): 675,
#  ('of', 'all'): 668,
#  ('but', 'it'): 666,
#  ('and', 'it'): 665,
#  ('such', 'a'): 662,
#  ('it', 'had'): 657,
#  ('according', 'to'): 655,
#  ('the', 'country'): 653,
#  ('do', 'not'): 647,
#  ('i', 'was'): 645,
#  ('the', 'market'): 644,
#  ('nine', 'mths'): 644,
#  ('had', 'to'): 642,
#  ('to', 'sell'): 642,
#  ('mln', 'avg'): 642,
#  ('they', 'said'): 641,
#  ('there', 'were'): 640,
#  ('of', 'her'): 639,
#  ('which', 'he'): 639,
#  ('sale', 'of'): 636,
#  ('vs', '2'): 634,
#  ('have', 'a'): 631,
#  ('that', 'i'): 631,
#  ('the', 'house'): 627,
#  ('u', 'k'): 626,
#  ('they', 'had'): 624,
#  ('cts', 'a'): 624,
#  ('he', 'did'): 619,
#  ('company', 's'): 617,
#  ('we', 'are'): 611,
#  ('as', 'to'): 608,
#  ('the', 'second'): 607,
#  ('his', 'own'): 605,
#  ('dlrs', 'per'): 605,
#  ('was', 'in'): 604,
#  ('said', 'they'): 601,
#  ('dlrs', 'net'): 601,
#  ('sources', 'said'): 600,
#  ('than', 'the'): 599,
#  ('pct', 'from'): 598,
#  ('after', 'a'): 597,
#  ('he', 'added'): 595,
#  ('seemed', 'to'): 595,
#  ('had', 'a'): 594,
#  ('to', 'get'): 593,
#  ('some', 'of'): 593,
#  ('a', 'little'): 590,
#  ('also', 'said'): 590,
#  ('oper', 'net'): 590,
#  ('of', 'these'): 588,
#  ('mths', 'shr'): 588,
#  ('up', 'the'): 584,
#  ('well', 'as'): 580,
#  ('he', 'could'): 579,
#  ('in', 'their'): 578,
#  ('to', 'say'): 577,
#  ('had', 'not'): 577,
#  ('the', 'emperor'): 575,
#  ('3rd', 'qtr'): 574,
#  ('upon', 'the'): 571,
#  ('4', 'pct'): 571,
#  ('him', 'to'): 569,
#  ('the', 'federal'): 568,
#  ('first', 'quarter'): 567,
#  ('that', 'a'): 566,
#  ('loss', 'of'): 563,
#  ('1', '2'): 563,
#  ('it', 'may'): 560,
#  ('agreed', 'to'): 559,
#  ('billion', 'vs'): 558,
#  ('so', 'that'): 556,
#  ('to', 'go'): 554,
#  ('the', 'time'): 554,
#  ('dlrs', 'from'): 553,
#  ('of', 'it'): 551,
#  ('the', 'sale'): 551,
#  ('central', 'bank'): 546,
#  ('likely', 'to'): 542,
#  ('into', 'a'): 541,
#  ('2', 'pct'): 541,
#  ('if', 'you'): 540,
#  ('to', 'acquire'): 540,
#  ('oper', 'shr'): 540,
#  ('of', 'which'): 539,
#  ('as', 'it'): 536,
#  ('which', 'was'): 535,
#  ('were', 'not'): 535,
#  ('1st', 'qtr'): 535,
#  ('and', 'was'): 534,
#  ('is', 'expected'): 530,
#  ('of', 'that'): 529,
#  ('said', 'a'): 527,
#  ('able', 'to'): 525,
#  ('the', 'door'): 524,
#  ('the', 'current'): 524,
#  ('be', 'the'): 520,
#  ('of', '1'): 520,
#  ('and', 'is'): 519,
#  ('shr', 'profit'): 516,
#  ('rise', 'in'): 515,
#  ('to', 'me'): 513,
#  ('are', 'not'): 513,
#  ('spokesman', 'said'): 512,
#  ('the', 'right'): 510,
#  ('began', 'to'): 510,
#  ('stake', 'in'): 509,
#  ('princess', 'mary'): 509,
#  ('among', 'the'): 507,
#  ('in', '1987'): 505,
#  ('do', 'you'): 504,
#  ('last', 'week'): 504,
#  ('of', 'our'): 503,
#  ('1986', '87'): 502,
#  ('was', 'to'): 501,
#  ('the', 'group'): 500,
#  ('going', 'to'): 499,
#  ('or', 'the'): 498,
#  ('the', 'general'): 498,
#  ('the', 'american'): 493,
#  ('those', 'who'): 489,
#  ('vs', '3'): 489,
#  ('year', 'shr'): 488,
#  ('000', 'sales'): 488,
#  ('mln', 'revs'): 488,
#  ('but', 'i'): 487,
#  ('the', 'way'): 485,
#  ('like', 'a'): 485,
#  ('it', 'to'): 483,
#  ('and', 'of'): 482,
#  ('i', 'had'): 480,
#  ('it', 'and'): 479,
#  ('use', 'of'): 478,
#  ('will', 'not'): 477,
#  ('increase', 'in'): 477,
#  ('of', 'course'): 476,
#  ('common', 'stock'): 476,
#  ('he', 'has'): 475,
#  ('last', 'month'): 475,
#  ('and', 'its'): 473,
#  ('a', 'long'): 472,
#  ('the', 'only'): 471,
#  ('is', 'that'): 470,
#  ('the', 'previous'): 470,
#  ('pct', 'to'): 470,
#  ('and', 'with'): 468,
#  ('this', 'was'): 468,
#  ('you', 'have'): 467,
#  ('as', 'an'): 465,
#  ('of', 'new'): 465,
#  ('the', 'room'): 464,
#  ('year', 'ago'): 463,
#  ('while', 'the'): 462,
#  ('that', 'was'): 460,
#  ('the', 'past'): 460,
#  ('you', 'are'): 459,
#  ('analysts', 'said'): 459,
#  ('that', 'she'): 457,
#  ('loss', '1'): 457,
#  ('who', 'was'): 456,
#  ('result', 'of'): 455,
#  ('billion', 'in'): 455,
#  ('8', 'pct'): 455,
#  ('for', 'an'): 453,
#  ('a', 'good'): 451,
#  ('to', 'give'): 451,
#  ('his', 'head'): 449,
#  ('to', 'an'): 448,
#  ('with', 'an'): 447,
#  ('dlrs', 'and'): 447,
#  ('and', 'so'): 446,
#  ('that', 'there'): 445,
#  ('she', 'said'): 445,
#  ('if', 'it'): 445,
#  ('since', 'the'): 445,
#  ('the', 'central'): 445,
#  ('interest', 'rates'): 445,
#  ('what', 'is'): 444,
#  ('not', 'only'): 443,
#  ('is', 'in'): 442,
#  ('a', 'very'): 442,
#  ('most', 'of'): 442,
#  ('qtly', 'div'): 442,
#  ('i', 'think'): 441,
#  ('subject', 'to'): 441,
#  ('told', 'reuters'): 441,
#  ('i', 'do'): 440,
#  ('for', 'example'): 439,
#  ('form', 'of'): 436,
#  ('in', 'her'): 436,
#  ('down', 'the'): 435,
#  ('where', 'the'): 434,
#  ('of', 'about'): 433,
#  ('the', 'national'): 433,
#  ('up', 'and'): 432,
#  ('shares', 'of'): 432,
#  ('mln', 'dlr'): 431,
#  ('no', 'one'): 430,
#  ('his', 'eyes'): 428,
#  ('money', 'market'): 428,
#  ('cts', 'prior'): 428,
#  ('the', 'people'): 427,
#  ('at', 'all'): 426,
#  ('the', 'great'): 425,
#  ('and', 'there'): 424,
#  ('all', 'of'): 424,
#  ('if', 'he'): 423,
#  ('the', 'department'): 423,
#  ('that', 'of'): 420,
#  ('was', 'no'): 419,
#  ('sales', 'of'): 419,
#  ('the', 'fact'): 418,
#  ('a', 'small'): 417,
#  ('in', 'that'): 417,
#  ('want', 'to'): 417,
#  ('what', 'he'): 416,
#  ('based', 'on'): 414,
#  ('that', 'in'): 413,
#  ('march', '31'): 412,
#  ('cts', 'per'): 412,
#  ('group', 'of'): 411,
#  ('the', 'total'): 410,
#  ('might', 'be'): 409,
#  ('rose', 'to'): 408,
#  ('plans', 'to'): 408,
#  ('as', 'they'): 406,
#  ('year', 'the'): 406,
#  ('value', 'of'): 403,
#  ('in', 'december'): 403,
#  ('officials', 'said'): 403,
#  ('rate', 'of'): 401,
#  ('a', 'large'): 400,
#  ('is', 'no'): 400,
#  ('fact', 'that'): 400,
#  ('department', 'said'): 400,
#  ('1', 'pct'): 400,
#  ('less', 'than'): 398,
#  ('the', 'west'): 398,
#  ('a', 'result'): 397,
#  ('used', 'to'): 396,
#  ('a', 'statement'): 396,
#  ('back', 'to'): 395,
#  ('with', 'her'): 393,
#  ('along', 'the'): 392,
#  ('interest', 'in'): 391,
#  ('oil', 'and'): 391,
#  ('time', 'to'): 389,
#  ('that', 'we'): 389,
#  ('terms', 'of'): 389,
#  ('rather', 'than'): 388,
#  ('are', 'the'): 388,
#  ('when', 'it'): 388,
#  ('the', 'man'): 385,
#  ('to', 'meet'): 384,
#  ('and', 'had'): 384,
#  ('the', 'best'): 384,
#  ('members', 'of'): 384,
#  ('cts', 'oper'): 384,
#  ('dlrs', 'for'): 383,
#  ('you', 'know'): 382,
#  ('and', 'as'): 382,
#  ('amount', 'of'): 382,
#  ('year', 'earlier'): 382,
#  ('mln', 'in'): 382,
#  ('they', 'have'): 381,
#  ('and', 'they'): 381,
#  ('trying', 'to'): 381,
#  ('the', 'patient'): 380,
#  ('the', 'third'): 379,
#  ('to', 'their'): 378,
#  ('crude', 'oil'): 378,
#  ('in', 'addition'): 377,
#  ('of', 'those'): 377,
#  ('west', 'germany'): 376,
#  ('on', 'its'): 375,
#  ('the', 'ec'): 374,
#  ('i', 'know'): 373,
#  ('to', '1'): 371,
#  ('3', 'pct'): 371,
#  ('which', 'had'): 369,
#  ('not', 'a'): 366,
#  ('that', 'had'): 366,
#  ('in', 'order'): 365,
#  ('his', 'face'): 365,
#  ('them', 'to'): 365,
#  ('and', 'at'): 364,
#  ('share', 'in'): 364,
#  ('of', 'one'): 363,
#  ('the', 'skin'): 363,
#  ('shr', '1'): 363,
#  ('the', 'count'): 362,
#  ('for', 'all'): 362,
#  ('9', 'pct'): 362,
#  ('for', 'his'): 361,
#  ('continue', 'to'): 361,
#  ('or', 'a'): 360,
#  ('the', 'more'): 360,
#  ('foreign', 'exchange'): 359,
#  ('6', 'pct'): 359,
#  ('7', 'pct'): 357,
#  ('and', 'all'): 356,
#  ('no', 'longer'): 356,
#  ('their', 'own'): 355,
#  ('to', 'keep'): 354,
#  ('the', 'war'): 354,
#  ('from', 'his'): 353,
#  ('across', 'the'): 353,
#  ('with', 'its'): 353,
#  ('met', 'with'): 353,
#  ('to', 'its'): 351,
#  ('told', 'the'): 351,
#  ('it', 'the'): 350,
#  ('and', 'not'): 350,
#  ('had', 'no'): 350,
#  ('dealers', 'said'): 349,
#  ('that', 'this'): 348,
#  ('vs', '4'): 348,
#  ('order', 'to'): 347,
#  ('be', 'made'): 346,
#  ('the', 'day'): 345,
#  ('came', 'to'): 345,
#  ('out', 'the'): 345,
#  ('to', 'help'): 344,
#  ('which', 'has'): 344,
#  ('which', 'are'): 343,
#  ('in', 'new'): 343,
#  ('the', 'case'): 342,
#  ('looked', 'at'): 342,
#  ('is', 'an'): 342,
#  ('have', 'the'): 342,
#  ('in', 'march'): 342,
#  ('year', 'net'): 342,
#  ('net', 'includes'): 342,
#  ('and', 'co'): 341,
#  ('at', 'this'): 340,
#  ('co', 'lt'): 340,
#  ('and', 'more'): 339,
#  ('above', 'the'): 338,
#  ('s', 'trade'): 338,
#  ('year', 'and'): 337,
#  ('as', 'i'): 336,
#  ('ltd', 'lt'): 336,
#  ('the', 'army'): 335,
#  ('at', 'his'): 334,
#  ('in', 'front'): 334,
#  ('said', 'to'): 334,
#  ('quarter', 'and'): 333,
#  ('within', 'the'): 333,
#  ('the', 'agreement'): 333,
#  ('the', 'offer'): 333,
#  ('the', 'number'): 332,
#  ('1986', 'the'): 332,
#  ('and', 'for'): 331,
#  ('for', 'one'): 331,
#  ('in', 'all'): 331,
#  ('up', 'from'): 330,
#  ('not', 'the'): 329,
#  ('common', 'shares'): 329,
#  ('to', 'find'): 328,
#  ('come', 'to'): 328,
#  ('with', 'him'): 328,
#  ('dlrs', 'the'): 328,
#  ('side', 'of'): 327,
#  ('the', 'acquisition'): 327,
#  ('official', 'said'): 327,
#  ('year', 's'): 327,
#  ('at', 'once'): 326,
#  ('and', 'an'): 326,
#  ('went', 'to'): 326,
#  ('him', 'he'): 325,
#  ('for', 'him'): 325,
#  ('kind', 'of'): 325,
#  ('prior', 'pay'): 325,
#  ('the', 'price'): 324,
#  ('the', 'south'): 323,
#  ('dlrs', 'to'): 322,
#  ('which', 'it'): 321,
#  ('the', 'countess'): 321,
#  ('this', 'week'): 321,
#  ('a', 'great'): 320,
#  ('has', 'a'): 320,
#  ('what', 'was'): 320,
#  ('dlrs', 'of'): 320,
#  ('way', 'to'): 319,
#  ('tried', 'to'): 319,
#  ('the', 'soviet'): 319,
#  ('instead', 'of'): 318,
#  ('of', 'any'): 318,
#  ('as', 'in'): 318,
#  ('acquisition', 'of'): 318,
#  ('to', 'this'): 317,
#  ('price', 'of'): 317,
#  ('of', 'u'): 316,
#  ('it', 'expects'): 316,
#  ('oil', 'prices'): 316,
#  ('and', 'by'): 315,
#  ('the', 'main'): 315,
#  ('west', 'german'): 315,
#  ('tender', 'offer'): 315,
#  ('stock', 'split'): 315,
#  ('for', 'this'): 313,
#  ('fourth', 'quarter'): 313,
#  ('away', 'from'): 312,
#  ('to', 'one'): 312,
#  ('only', 'a'): 312,
#  ('1', '5'): 312,
#  ('japan', 's'): 312,
#  ('i', 'can'): 311,
#  ('net', '1'): 311,
#  ('mln', 'year'): 311,
#  ('loss', 'shr'): 311,
#  ('it', 'in'): 310,
#  ('than', 'a'): 309,
#  ('enough', 'to'): 309,
#  ('has', 'not'): 309,
#  ('he', 'told'): 309,
#  ('when', 'they'): 309,
#  ('securities', 'and'): 309,
#  ('all', 'that'): 308,
#  ('at', 'that'): 307,
#  ('because', 'the'): 307,
#  ('in', 'some'): 307,
#  ('and', 'their'): 307,
#  ('1', '4'): 307,
#  ('and', 'this'): 306,
#  ('and', 'she'): 306,
#  ('to', 'come'): 306,
#  ('to', 'pay'): 306,
#  ('will', 'have'): 306,
#  ('if', 'they'): 306,
#  ('is', 'also'): 306,
#  ('a', 'major'): 306,
#  ('5', 'billion'): 306,
#  ('up', 'in'): 305,
#  ('him', 'the'): 305,
#  ('the', 'rest'): 305,
#  ('is', 'it'): 304,
#  ('same', 'time'): 304,
#  ('the', 'president'): 304,
#  ('record', 'april'): 304,
#  ('you', 'can'): 303,
#  ('the', 'one'): 303,
#  ('the', 'european'): 303,
#  ('off', 'the'): 302,
#  ('on', 'march'): 302,
#  ('the', 'very'): 301,
#  ('the', 'fed'): 301,
#  ('and', 'will'): 300,
#  ('and', 'we'): 300,
#  ('half', 'of'): 300,
#  ('of', 'japan'): 300,
#  ('a', 'barrel'): 300,
#  ('they', 'would'): 299,
#  ('and', 'said'): 299,
#  ('industries', 'inc'): 299,
#  ('buffer', 'stock'): 299,
#  ('at', 'her'): 298,
#  ('the', 'men'): 297,
#  ('a', 'number'): 297,
#  ('those', 'of'): 297,
#  ('3', '4'): 297,
#  ('50', 'dlrs'): 297,
#  ('him', 'in'): 296,
#  ('but', 'they'): 296,
#  ('the', 'public'): 296,
#  ('gain', 'of'): 296,
#  ('in', 'my'): 295,
#  ('of', 'life'): 295,
#  ('10', 'pct'): 295,
#  ('be', 'in'): 294,
#  ('wanted', 'to'): 294,
#  ('the', 'middle'): 294,
#  ('state', 'of'): 294,
#  ('its', 'board'): 294,
#  ('mln', 'shares'): 294,
#  ('of', 'my'): 293,
#  ('the', 'fourth'): 293,
#  ('and', 'exchange'): 293,
#  ('the', 'international'): 293,
#  ('the', 'official'): 292,
#  ('he', 'thought'): 292,
#  ('at', 'him'): 291,
#  ('we', 'can'): 291,
#  ('so', 'far'): 291,
#  ('as', 'much'): 290,
#  ('until', 'the'): 290,
#  ('the', 'trade'): 290,
#  ('to', 'increase'): 290,
#  ('vs', '5'): 290,
#  ('make', 'a'): 289,
#  ('a', 'letter'): 289,
#  ('trade', 'deficit'): 289,
#  ('that', 'if'): 288,
#  ('go', 'to'): 287,
#  ('the', 'securities'): 287,
#  ('fell', 'to'): 286,
#  ('mln', 'nine'): 286,
#  ('record', 'march'): 286,
#  ('of', 'england'): 285,
#  ('the', 'economy'): 285,
#  ('jan', '31'): 285,
#  ('when', 'i'): 284,
#  ('like', 'the'): 284,
#  ('not', 'been'): 283,
#  ('can', 'not'): 283,
#  ('the', 'merger'): 283,
#  ('that', 'you'): 282,
#  ('for', 'its'): 282,
#  ('just', 'as'): 282,
#  ('necessary', 'to'): 282,
#  ('cost', 'of'): 282,
#  ('her', 'and'): 281,
#  ('his', 'wife'): 281,
#  ('but', 'in'): 281,
#  ('to', 'cut'): 281,
#  ('1985', '86'): 281,
#  ('in', 'one'): 280,
#  ('the', 'present'): 280,
#  ('the', 'use'): 280,
#  ('front', 'of'): 280,
#  ('made', 'a'): 280,
#  ('of', 'what'): 280,
#  ('the', 'young'): 280,
#  ('said', 'this'): 280,
#  ('exchange', 'commission'): 280,
#  ('was', 'still'): 279,
#  ('and', 'on'): 279,
#  ('the', 'disease'): 279,
#  ('toward', 'the'): 278,
#  ('50', 'pct'): 278,
#  ('09', '87'): 278,
#  ('that', 'would'): 277,
#  ('me', 'to'): 276,
#  ('in', 'any'): 276,
#  ('one', 'another'): 276,
#  ('a', 'single'): 275,
#  ('may', 'have'): 275,
#  ('is', 'still'): 275,
#  ('that', 'his'): 274,
#  ('the', 'matter'): 274,
#  ('look', 'at'): 274,
#  ('a', 'total'): 274,
#  ('the', 'board'): 274,
#  ('bank', 'said'): 274,
#  ('pct', 'the'): 274,
#  ('my', 'dear'): 273,
#  ('the', 'gulf'): 273,
#  ('and', 'when'): 272,
#  ('the', 'little'): 272,
#  ('were', 'the'): 272,
#  ('president', 'of'): 272,
#  ('said', 'i'): 271,
#  ('by', 'an'): 271,
#  ('said', 'there'): 271,
#  ('are', 'you'): 271,
#  ('to', 'them'): 271,
#  ('s', 'agriculture'): 271,
#  ('i', 'will'): 270,
#  ('the', 'field'): 270,
#  ('growth', 'in'): 270,
#  ('declined', 'to'): 270,
#  ('man', 'who'): 269,
#  ('for', 'some'): 269,
#  ('see', 'the'): 269,
#  ('the', 'week'): 269,
#  ('traders', 'said'): 269,
#  ('around', 'the'): 268,
#  ('to', 'you'): 268,
#  ('but', 'that'): 268,
#  ('rise', 'to'): 268,
#  ('level', 'of'): 268,
#  ('billion', 'marks'): 268,
#  ('which', 'would'): 267,
#  ('not', 'have'): 266,
#  ('the', 'question'): 266,
#  ('soon', 'as'): 266,
#  ('said', 'but'): 266,
#  ('of', 'such'): 265,
#  ('per', 'cent'): 265,
#  ('the', 'british'): 265,
#  ('long', 'term'): 265,
#  ('i', 'could'): 264,
#  ('to', 'which'): 264,
#  ('as', 'she'): 264,
#  ('the', 'report'): 264,
#  ('the', 'future'): 263,
#  ('down', 'to'): 263,
#  ('the', 'stock'): 263,
#  ('two', 'cts'): 263,
#  ('he', 'felt'): 262,
#  ('not', 'know'): 262,
#  ('course', 'of'): 262,
#  ('down', 'from'): 262,
#  ('2nd', 'qtr'): 262,
#  ('as', 'soon'): 261,
#  ('be', 'used'): 260,
#  ('but', 'a'): 260,
#  ('a', 'day'): 260,
#  ('so', 'much'): 260,
#  ('by', 'his'): 259,
#  ('is', 'now'): 259,
#  ('the', 'money'): 259,
#  ('right', 'to'): 259,
#  ('and', 'are'): 259,
#  ('of', 'american'): 259,
#  ('to', '2'): 259,
#  ('qtr', 'loss'): 259,
#  ('the', 'road'): 258,
#  ('a', 'group'): 258,
#  ('year', 'to'): 258,
#  ('soviet', 'union'): 258,
#  ('not', 'yet'): 257,
#  ('of', '1986'): 257,
#  ('to', 'it'): 256,
#  ('i', 'shall'): 256,
#  ('what', 'the'): 256,
#  ('the', 'enemy'): 256,
#  ('s', 'and'): 256,
#  ('pct', 'and'): 256,
#  ('in', 'our'): 255,
#  ('told', 'a'): 255,
#  ('20', 'pct'): 255,
#  ('european', 'community'): 255,
#  ('shall', 'be'): 254,
#  ('because', 'it'): 254,
#  ('many', 'of'): 254,
#  ('two', 'years'): 253,
#  ('and', 'now'): 253,
#  ('looking', 'at'): 253,
#  ('but', 'not'): 253,
#  ('the', 'union'): 253,
#  ('to', 'reduce'): 253,
#  ('the', 'lower'): 252,
#  ('which', 'they'): 252,
#  ('known', 'as'): 252,
#  ('expects', 'to'): 252,
#  ('shares', 'or'): 252,
#  ('billion', 'dlr'): 252,
#  ('and', 'if'): 251,
#  ('the', 'result'): 251,
#  ('control', 'of'): 251,
#  ('period', 'of'): 251,
#  ('federal', 'reserve'): 251,
#  ('of', '2'): 251,
#  ('tonnes', 'in'): 251,
#  ('in', 'fact'): 250,
#  ('fall', 'in'): 250,
#  ('agriculture', 'department'): 250,
#  ('i', 'would'): 249,
#  ('you', 'will'): 249,
#  ('of', 'him'): 249,
#  ('it', 'seemed'): 249,
#  ('that', 'all'): 249,
#  ('mln', 'barrels'): 249,
#  ('for', 'it'): 248,
#  ('associated', 'with'): 248,
#  ('had', 'the'): 248,
#  ('the', 'city'): 248,
#  ('the', 'north'): 248,
#  ('he', 'saw'): 248,
#  ('share', 'of'): 248,
#  ('the', 'russian'): 248,
#  ('offer', 'for'): 248,
#  ('of', 'some'): 247,
#  ('went', 'on'): 247,
#  ('he', 'went'): 247,
#  ('five', 'pct'): 247,
#  ('dlrs', 'on'): 247,
#  ('co', 'said'): 247,
#  ('discontinued', 'operations'): 247,
#  ('note', '1986'): 247,
#  ('the', 'latter'): 246,
#  ('unable', 'to'): 246,
#  ('10', 'cts'): 246,
#  ('to', 'look'): 245,
#  ('and', 'her'): 245,
#  ('been', 'a'): 245,
#  ('to', 'work'): 245,
#  ('the', 'joint'): 245,
#  ('fiscal', 'year'): 245,
#  ('and', 'even'): 244,
#  ('close', 'to'): 244,
#  ('the', 'long'): 244,
#  ('money', 'supply'): 244,
#  ('and', 'what'): 243,
#  ('had', 'come'): 243,
#  ('in', 'other'): 243,
#  ('it', 'also'): 243,
#  ('first', 'time'): 243,
#  ('the', 'japanese'): 243,
#  ('loss', '2'): 243,
#  ('with', 'which'): 242,
#  ('time', 'the'): 242,
#  ('say', 'that'): 242,
#  ('its', 'own'): 242,
#  ('out', 'to'): 242,
#  ('i', 'should'): 241,
#  ('them', 'and'): 241,
#  ('quarter', 'of'): 241,
#  ('the', 'following'): 241,
#  ('he', 'knew'): 240,
#  ('and', 'gas'): 240,
#  ('trade', 'surplus'): 240,
#  ('1986', 'net'): 240,
#  ('qtr', 'and'): 240,
#  ('to', 'show'): 239,
#  ('of', 'two'): 239,
#  ('who', 'were'): 239,
#  ('or', 'more'): 239,
#  ('from', 'its'): 239,
#  ('on', 'april'): 239,
#  ('plc', 'lt'): 239,
#  ('long', 'as'): 238,
#  ('need', 'to'): 238,
#  ('share', 'for'): 238,
#  ('but', 'there'): 237,
#  ('to', 'raise'): 237,
#  ('for', 'her'): 237,
#  ('in', 'cash'): 237,
#  ('if', 'i'): 236,
#  ('might', 'have'): 236,
#  ('this', 'time'): 236,
#  ('growth', 'of'): 236,
#  ('the', 'yen'): 236,
#  ('if', 'we'): 235,
#  ('were', 'to'): 235,
#  ('series', 'of'): 235,
#  ('old', 'man'): 235,
#  ('he', 'asked'): 234,
#  ('or', 'to'): 234,
#  ('the', 'system'): 234,
#  ('owned', 'by'): 234,
#  ('an', 'agreement'): 234,
#  ('the', 'proposed'): 234,
#  ('2', '5'): 234,
#  ('nil', 'nil'): 234,
#  ('when', 'she'): 233,
#  ('to', 'prevent'): 233,
#  ('and', 'went'): 233,
#  ('and', 'from'): 233,
#  ('development', 'of'): 233,
#  ('added', 'that'): 233,
#  ('short', 'term'): 233,
#  ('five', 'cts'): 233,
#  ('for', 'their'): 232,
#  ('the', 'form'): 232,
#  ('the', 'surface'): 232,
#  ('the', 'senate'): 232,
#  ('to', 'that'): 231,
#  ('sense', 'of'): 231,
#  ('try', 'to'): 231,
#  ('states', 'and'): 231,
#  ('of', '3'): 231,
#  ('pay', 'april'): 231,
#  ('and', 'you'): 230,
#  ('with', 'their'): 230,
#  ('the', 'three'): 230,
#  ('in', 'it'): 230,
#  ('they', 'could'): 230,
#  ('total', 'of'): 230,
#  ('exchange', 'rate'): 230,
#  ('the', 'bundesbank'): 230,
#  ('the', 'table'): 229,
#  ('who', 'is'): 229,
#  ('not', 'in'): 229,
#  ('it', 'he'): 229,
#  ('him', 'a'): 229,
#  ('compared', 'to'): 229,
#  ('means', 'of'): 229,
#  ('1', '1'): 229,
#  ('of', 'record'): 229,
#  ...}

# %% [markdown]
# We also need a frequency of words for the denominator later (frequency of **word before in the bigram**)

# %%
freq_words = dict_freq(no_punct_corpus)
freq_words
# Out:
# {'the': 218649,
#  'of': 113209,
#  'and': 92759,
#  'to': 91232,
#  'in': 72523,
#  'a': 69337,
#  'said': 30808,
#  'that': 30622,
#  'it': 30513,
#  'for': 30192,
#  'is': 27594,
#  'he': 27147,
#  'was': 27057,
#  'with': 23208,
#  'on': 22618,
#  'as': 19886,
#  'at': 19175,
#  'by': 19083,
#  'be': 18889,
#  'mln': 18624,
#  'from': 18268,
#  'his': 17703,
#  'not': 15897,
#  's': 15713,
#  'had': 15503,
#  'vs': 14346,
#  'but': 13622,
#  'i': 13542,
#  'or': 12803,
#  'this': 12719,
#  'dlrs': 12418,
#  'which': 12067,
#  'an': 11715,
#  'are': 11255,
#  'its': 10896,
#  '1': 10707,
#  'were': 10673,
#  'have': 10567,
#  '000': 10278,
#  'they': 10143,
#  'pct': 9811,
#  'will': 9767,
#  'one': 9555,
#  'would': 9366,
#  'you': 9045,
#  'has': 8914,
#  'lt': 8697,
#  'year': 8471,
#  'all': 8419,
#  'cts': 8362,
#  'her': 8330,
#  'him': 7917,
#  '2': 7205,
#  'been': 7142,
#  'net': 7037,
#  'their': 6995,
#  'there': 6966,
#  'she': 6962,
#  'up': 6448,
#  'u': 6417,
#  'when': 6170,
#  'we': 6138,
#  'about': 6124,
#  'if': 6120,
#  'more': 6092,
#  'may': 6083,
#  'no': 5967,
#  'who': 5904,
#  'billion': 5902,
#  'new': 5547,
#  '3': 5540,
#  'so': 5491,
#  'loss': 5352,
#  'what': 5329,
#  'two': 5156,
#  'company': 5147,
#  'into': 4936,
#  '5': 4926,
#  'out': 4861,
#  'other': 4854,
#  'than': 4781,
#  'could': 4780,
#  '4': 4690,
#  'after': 4586,
#  'some': 4575,
#  'last': 4483,
#  'only': 4461,
#  'first': 4440,
#  'them': 4431,
#  '1986': 4396,
#  'also': 4336,
#  'shr': 4183,
#  'inc': 4122,
#  'now': 3967,
#  'over': 3961,
#  'time': 3945,
#  'do': 3854,
#  'bank': 3841,
#  'did': 3635,
#  'my': 3615,
#  '7': 3605,
#  '6': 3581,
#  'can': 3544,
#  'any': 3473,
#  'trade': 3451,
#  'such': 3423,
#  'oil': 3403,
#  'corp': 3401,
#  '8': 3378,
#  'share': 3328,
#  'these': 3260,
#  'then': 3184,
#  'before': 3142,
#  'me': 3133,
#  'made': 3116,
#  'should': 3055,
#  'market': 3017,
#  'profit': 3010,
#  'under': 2987,
#  '9': 2978,
#  '0': 2952,
#  'down': 2895,
#  'man': 2879,
#  'our': 2817,
#  'stock': 2807,
#  'government': 2788,
#  'against': 2778,
#  'three': 2764,
#  'shares': 2702,
#  'most': 2677,
#  'qtr': 2675,
#  'group': 2641,
#  '10': 2609,
#  'because': 2589,
#  'very': 2560,
#  'per': 2558,
#  'well': 2544,
#  'like': 2518,
#  'through': 2512,
#  'tonnes': 2512,
#  'between': 2454,
#  'those': 2449,
#  'how': 2409,
#  'even': 2402,
#  '1987': 2397,
#  'while': 2384,
#  'years': 2372,
#  'sales': 2359,
#  'states': 2352,
#  'same': 2342,
#  'told': 2330,
#  'still': 2329,
#  'must': 2324,
#  'world': 2322,
#  'long': 2314,
#  'revs': 2313,
#  'march': 2308,
#  'prices': 2299,
#  'american': 2272,
#  'your': 2228,
#  'state': 2192,
#  'being': 2181,
#  'where': 2170,
#  'day': 2162,
#  'april': 2156,
#  'rate': 2144,
#  'see': 2125,
#  'end': 2110,
#  'little': 2103,
#  'much': 2101,
#  'way': 2082,
#  'week': 2055,
#  'general': 2042,
#  'back': 2034,
#  'another': 2023,
#  'many': 1985,
#  'price': 1979,
#  'prince': 1976,
#  'pierre': 1975,
#  'take': 1970,
#  'japan': 1950,
#  'people': 1945,
#  'just': 1942,
#  'united': 1936,
#  'interest': 1932,
#  'quarter': 1929,
#  'both': 1922,
#  'men': 1921,
#  'old': 1919,
#  'co': 1907,
#  'february': 1902,
#  '15': 1900,
#  'make': 1888,
#  'without': 1882,
#  'own': 1881,
#  'offer': 1858,
#  'five': 1836,
#  'each': 1834,
#  'know': 1830,
#  'january': 1825,
#  'today': 1822,
#  'note': 1821,
#  'off': 1814,
#  'come': 1809,
#  'here': 1801,
#  'life': 1776,
#  'go': 1774,
#  'himself': 1771,
#  'tax': 1771,
#  'good': 1770,
#  'foreign': 1769,
#  'during': 1763,
#  'came': 1744,
#  'say': 1743,
#  'part': 1740,
#  '30': 1732,
#  'house': 1730,
#  'agreement': 1725,
#  'exchange': 1713,
#  '20': 1713,
#  '1985': 1711,
#  'dollar': 1710,
#  'since': 1706,
#  'rose': 1693,
#  'around': 1692,
#  'expected': 1692,
#  'upon': 1677,
#  'production': 1662,
#  'rise': 1658,
#  'again': 1657,
#  '31': 1650,
#  'business': 1638,
#  'too': 1636,
#  'french': 1636,
#  'international': 1622,
#  '50': 1620,
#  'however': 1615,
#  'face': 1615,
#  'went': 1612,
#  'might': 1611,
#  'money': 1608,
#  'great': 1593,
#  'president': 1591,
#  '12': 1589,
#  'added': 1588,
#  'four': 1580,
#  'asked': 1577,
#  'six': 1574,
#  'common': 1573,
#  'total': 1568,
#  'national': 1567,
#  'us': 1560,
#  'right': 1546,
#  'growth': 1533,
#  'war': 1512,
#  'thought': 1497,
#  'current': 1487,
#  'increase': 1482,
#  'record': 1479,
#  'west': 1475,
#  'month': 1475,
#  'rates': 1472,
#  'high': 1470,
#  'next': 1457,
#  'get': 1454,
#  '25': 1449,
#  'left': 1447,
#  'ltd': 1441,
#  'place': 1433,
#  'board': 1432,
#  'work': 1429,
#  'set': 1423,
#  'nine': 1416,
#  'meeting': 1393,
#  'away': 1389,
#  'economic': 1361,
#  'room': 1355,
#  'official': 1350,
#  'months': 1350,
#  'began': 1341,
#  'never': 1340,
#  'industry': 1339,
#  'eyes': 1338,
#  'days': 1336,
#  'dlr': 1336,
#  '11': 1321,
#  'head': 1311,
#  'hand': 1311,
#  'major': 1311,
#  'small': 1297,
#  'use': 1294,
#  'system': 1292,
#  'cut': 1291,
#  '16': 1291,
#  'earlier': 1280,
#  'few': 1278,
#  'think': 1277,
#  'federal': 1268,
#  'country': 1264,
#  'due': 1263,
#  'period': 1254,
#  '13': 1249,
#  'further': 1244,
#  'department': 1243,
#  'does': 1242,
#  'says': 1242,
#  'every': 1240,
#  'exports': 1236,
#  'pay': 1229,
#  'stg': 1225,
#  'report': 1222,
#  'used': 1219,
#  'less': 1219,
#  'already': 1217,
#  'give': 1216,
#  'until': 1210,
#  'natasha': 1205,
#  'south': 1202,
#  'public': 1194,
#  'oper': 1193,
#  'large': 1192,
#  'though': 1191,
#  'put': 1187,
#  'something': 1187,
#  'andrew': 1187,
#  'found': 1186,
#  'early': 1181,
#  'lower': 1171,
#  'fell': 1164,
#  'second': 1163,
#  'half': 1162,
#  'far': 1159,
#  'once': 1158,
#  'called': 1158,
#  'whole': 1155,
#  'looked': 1155,
#  'unit': 1154,
#  'countries': 1151,
#  'took': 1140,
#  'several': 1137,
#  'sale': 1134,
#  'nothing': 1129,
#  'why': 1126,
#  'number': 1126,
#  'yet': 1125,
#  'possible': 1123,
#  'central': 1123,
#  'always': 1114,
#  'among': 1112,
#  'given': 1111,
#  'action': 1110,
#  'earnings': 1110,
#  'banks': 1107,
#  '14': 1105,
#  'felt': 1104,
#  'union': 1100,
#  'policy': 1093,
#  '87': 1092,
#  'export': 1092,
#  'power': 1089,
#  '17': 1088,
#  'avg': 1087,
#  'held': 1086,
#  'operations': 1086,
#  'higher': 1084,
#  'buy': 1082,
#  'shrs': 1079,
#  'result': 1077,
#  'wheat': 1077,
#  'home': 1075,
#  'am': 1075,
#  'look': 1074,
#  'saw': 1071,
#  'seemed': 1066,
#  'officials': 1065,
#  '18': 1065,
#  'agreed': 1064,
#  'having': 1063,
#  'december': 1063,
#  'later': 1062,
#  'form': 1057,
#  'plan': 1054,
#  'full': 1050,
#  'dividend': 1049,
#  'financial': 1039,
#  'cash': 1036,
#  'seen': 1035,
#  'fall': 1031,
#  'young': 1028,
#  'japanese': 1026,
#  'companies': 1024,
#  'capital': 1023,
#  'within': 1021,
#  'ago': 1020,
#  'open': 1020,
#  'shall': 1019,
#  'help': 1018,
#  'point': 1015,
#  'order': 1007,
#  'results': 1004,
#  'investment': 1002,
#  'ec': 1000,
#  'certain': 998,
#  'af': 997,
#  'sources': 995,
#  'free': 994,
#  'above': 993,
#  'spokesman': 991,
#  'york': 988,
#  'become': 987,
#  'products': 985,
#  'program': 983,
#  'present': 981,
#  'statement': 977,
#  'compared': 975,
#  'imports': 973,
#  'case': 972,
#  'whether': 972,
#  'going': 972,
#  'acquisition': 970,
#  '28': 967,
#  'stake': 966,
#  'taken': 964,
#  'position': 959,
#  'side': 959,
#  'analysts': 950,
#  'reported': 947,
#  'mths': 947,
#  'let': 946,
#  'course': 943,
#  'terms': 942,
#  'development': 940,
#  'gave': 936,
#  'almost': 926,
#  'princess': 926,
#  'gas': 926,
#  'better': 924,
#  'includes': 919,
#  'heard': 909,
#  'army': 909,
#  'yen': 906,
#  'based': 905,
#  'gain': 904,
#  'term': 903,
#  'white': 901,
#  'commission': 899,
#  'knew': 898,
#  'third': 896,
#  'debt': 895,
#  'credit': 893,
#  'markets': 891,
#  'june': 889,
#  'deficit': 888,
#  'short': 883,
#  'line': 881,
#  'currency': 881,
#  'night': 880,
#  'along': 878,
#  'service': 876,
#  'sugar': 875,
#  'minister': 874,
#  '100': 871,
#  '19': 871,
#  'demand': 869,
#  'moscow': 869,
#  'need': 868,
#  'prior': 867,
#  'often': 861,
#  'figures': 860,
#  '4th': 860,
#  'seven': 858,
#  'increased': 858,
#  'level': 858,
#  'want': 856,
#  'turned': 856,
#  'value': 856,
#  'show': 855,
#  'done': 853,
#  'securities': 852,
#  'least': 850,
#  'tender': 850,
#  '22': 850,
#  'name': 849,
#  'sell': 849,
#  'others': 849,
#  'congress': 848,
#  'firm': 847,
#  'o': 846,
#  'industrial': 846,
#  'canada': 846,
#  'ended': 844,
#  'yesterday': 844,
#  'announced': 844,
#  'gold': 843,
#  'soon': 842,
#  'door': 841,
#  'yes': 838,
#  'domestic': 837,
#  'making': 834,
#  'law': 832,
#  'close': 831,
#  'find': 830,
#  'quite': 829,
#  'fact': 829,
#  'shareholders': 828,
#  'plans': 827,
#  'members': 827,
#  'following': 826,
#  'chairman': 825,
#  'recent': 824,
#  'german': 823,
#  'past': 823,
#  'trading': 822,
#  'change': 820,
#  'european': 818,
#  'likely': 818,
#  'met': 818,
#  'count': 815,
#  'merger': 815,
#  'although': 814,
#  'hands': 812,
#  'got': 812,
#  'reserves': 810,
#  'area': 808,
#  'average': 807,
#  'supply': 801,
#  'eight': 800,
#  'toward': 800,
#  'british': 799,
#  'city': 798,
#  'including': 793,
#  'mary': 790,
#  'moment': 790,
#  'tell': 789,
#  'important': 788,
#  'enough': 779,
#  'usually': 777,
#  'income': 777,
#  'round': 775,
#  'k': 775,
#  'chief': 775,
#  'act': 774,
#  'rostov': 774,
#  'strong': 773,
#  'coffee': 773,
#  'assets': 773,
#  'annual': 771,
#  'morning': 770,
#  'brought': 769,
#  'grain': 769,
#  'crude': 767,
#  '24': 766,
#  'light': 764,
#  'rather': 763,
#  '40': 761,
#  'future': 760,
#  'received': 758,
#  'cost': 758,
#  'management': 756,
#  'looking': 755,
#  'industries': 755,
#  'talks': 755,
#  'best': 752,
#  'surplus': 752,
#  'things': 751,
#  'words': 747,
#  'fed': 747,
#  'matter': 745,
#  'north': 745,
#  'output': 745,
#  'behind': 744,
#  'near': 742,
#  'issue': 741,
#  '23': 739,
#  'low': 738,
#  'agriculture': 738,
#  'control': 736,
#  'anything': 732,
#  'question': 731,
#  'proposed': 730,
#  'below': 729,
#  'washington': 729,
#  'continue': 726,
#  'account': 725,
#  'england': 724,
#  'water': 724,
#  'economy': 724,
#  'conditions': 723,
#  'move': 723,
#  'love': 722,
#  'special': 722,
#  'means': 720,
#  'subject': 720,
#  'bill': 719,
#  'disease': 715,
#  'nations': 715,
#  'known': 714,
#  'officer': 713,
#  'necessary': 712,
#  '27': 710,
#  'corn': 707,
#  'stood': 705,
#  'voice': 704,
#  'real': 704,
#  'energy': 703,
#  'letter': 703,
#  'father': 702,
#  'local': 702,
#  'continued': 700,
#  'effect': 700,
#  'news': 699,
#  'late': 698,
#  'private': 696,
#  'reached': 696,
#  'either': 693,
#  't': 692,
#  'america': 691,
#  'support': 690,
#  'mind': 689,
#  'field': 689,
#  'political': 688,
#  'court': 688,
#  'pressure': 688,
#  'previous': 687,
#  'div': 687,
#  'itself': 685,
#  'costs': 685,
#  'canadian': 685,
#  'different': 683,
#  'bid': 681,
#  '500': 679,
#  'nil': 677,
#  'taking': 676,
#  'force': 676,
#  'operating': 676,
#  'thing': 675,
#  'saying': 675,
#  'loan': 675,
#  'sold': 673,
#  'family': 671,
#  'times': 670,
#  'god': 670,
#  'purchase': 667,
#  'fiscal': 667,
#  'especially': 666,
#  'joint': 666,
#  'body': 665,
#  'according': 665,
#  'raised': 664,
#  'committee': 662,
#  'owned': 661,
#  'suddenly': 660,
#  'sometimes': 659,
#  'previously': 659,
#  'whom': 658,
#  '21': 658,
#  'expects': 656,
#  'cases': 655,
#  'everything': 655,
#  '60': 655,
#  'land': 654,
#  'estimated': 653,
#  '35': 653,
#  'outstanding': 652,
#  'nicholas': 651,
#  'history': 650,
#  'ever': 648,
#  'amount': 648,
#  'feet': 645,
#  'probably': 645,
#  '26': 645,
#  'john': 644,
#  'community': 641,
#  'emperor': 641,
#  'subsidiary': 641,
#  'bone': 640,
#  'cause': 638,
#  'air': 636,
#  'example': 635,
#  'administration': 634,
#  'traders': 634,
#  'soviet': 633,
#  'together': 631,
#  'dealers': 631,
#  'secretary': 628,
#  'acquire': 628,
#  'party': 626,
#  'split': 624,
#  'meet': 619,
#  'marks': 619,
#  'finance': 619,
#  'themselves': 617,
#  'study': 615,
#  'office': 615,
#  '1st': 615,
#  'followed': 614,
#  'really': 614,
#  'include': 614,
#  'became': 612,
#  'death': 611,
#  'china': 609,
#  '75': 607,
#  'front': 606,
#  'farm': 605,
#  'keep': 602,
#  'gulf': 602,
#  'services': 600,
#  'bought': 600,
#  'available': 600,
#  'basis': 598,
#  'napoleon': 598,
#  'passed': 596,
#  'return': 596,
#  '3rd': 596,
#  'association': 596,
#  'wife': 595,
#  'september': 595,
#  'thus': 595,
#  'western': 594,
#  'skin': 593,
#  'led': 591,
#  'data': 591,
#  'blood': 591,
#  'natural': 591,
#  'alone': 590,
#  'deal': 590,
#  'weeks': 587,
#  'word': 586,
#  'children': 586,
#  'producers': 586,
#  'treasury': 584,
#  'longer': 583,
#  'tissue': 581,
#  'ministry': 580,
#  'clear': 579,
#  'sets': 579,
#  'problems': 578,
#  'chapter': 576,
#  'stocks': 576,
#  'non': 576,
#  'leave': 575,
#  'problem': 574,
#  'call': 574,
#  'able': 574,
#  'women': 574,
#  'reason': 573,
#  'kind': 573,
#  'across': 572,
#  'battle': 572,
#  'believe': 571,
#  'proposal': 570,
#  'understand': 569,
#  'reserve': 569,
#  'france': 567,
#  'changes': 566,
#  'budget': 566,
#  'germany': 565,
#  'opec': 565,
#  'paid': 563,
#  'effective': 563,
#  'sat': 562,
#  'showed': 561,
#  'east': 559,
#  'brazil': 559,
#  'areas': 559,
#  'wanted': 557,
#  'paris': 556,
#  'levels': 555,
#  'street': 554,
#  'de': 554,
#  'process': 553,
#  'military': 552,
#  'feeling': 552,
#  'lead': 551,
#  'perhaps': 551,
#  'remain': 551,
#  'final': 549,
#  'acquired': 549,
#  'systems': 549,
#  'figure': 548,
#  'sent': 548,
#  'lost': 547,
#  'big': 547,
#  'goods': 547,
#  'forecast': 547,
#  'southern': 546,
#  'funds': 546,
#  'fire': 544,
#  'woman': 542,
#  'council': 542,
#  'russian': 541,
#  'hold': 540,
#  'july': 540,
#  '80': 539,
#  'usda': 539,
#  'information': 538,
#  'nor': 537,
#  'decision': 537,
#  'start': 536,
#  'movement': 536,
#  'school': 536,
#  'sees': 536,
#  'project': 532,
#  'rights': 532,
#  'fourth': 532,
#  'profits': 531,
#  'reuters': 531,
#  'london': 528,
#  'parts': 527,
#  'whose': 525,
#  'mother': 525,
#  'division': 525,
#  'holmes': 524,
#  'hard': 524,
#  'crop': 520,
#  'loans': 519,
#  'oh': 518,
#  'labor': 518,
#  'kutuzov': 517,
#  'qtly': 517,
#  'coming': 516,
#  'main': 515,
#  'holding': 515,
#  '29': 514,
#  'view': 514,
#  'provide': 514,
#  'social': 514,
#  'table': 513,
#  'measures': 512,
#  '45': 512,
#  'talk': 511,
#  'condition': 511,
#  'food': 510,
#  'petroleum': 510,
#  'plc': 510,
#  'paper': 505,
#  'situation': 505,
#  'baker': 504,
#  'son': 503,
#  'entered': 502,
#  'europe': 501,
#  'despite': 500,
#  'drop': 499,
#  'closed': 499,
#  'decided': 499,
#  'dear': 498,
#  '200': 497,
#  'plant': 497,
#  'completed': 496,
#  'countess': 495,
#  'surface': 495,
#  'additional': 494,
#  'cold': 493,
#  'moved': 491,
#  'charge': 491,
#  'approval': 491,
#  'operation': 491,
#  'balance': 490,
#  'rest': 489,
#  'texas': 489,
#  'greater': 487,
#  'decline': 487,
#  'treatment': 487,
#  'immediately': 486,
#  'turn': 486,
#  'ran': 486,
#  'offered': 486,
#  'needed': 486,
#  'inflation': 486,
#  'nearly': 484,
#  'smile': 484,
#  'resources': 484,
#  'kept': 484,
#  'run': 483,
#  '300': 483,
#  'human': 482,
#  'bring': 481,
#  'growing': 481,
#  'base': 480,
#  'red': 479,
#  'losses': 479,
#  'bpd': 479,
#  'adjusted': 478,
#  'heavy': 478,
#  'noted': 477,
#  'conference': 477,
#  'intervention': 476,
#  'remained': 475,
#  'road': 475,
#  'patient': 474,
#  'payments': 474,
#  'black': 472,
#  'm': 472,
#  'opened': 471,
#  'reduce': 471,
#  'approved': 470,
#  'carried': 469,
#  'wall': 469,
#  'class': 469,
#  'herself': 468,
#  'church': 468,
#  'soldiers': 467,
#  'pacific': 467,
#  'various': 467,
#  '32': 467,
#  'beginning': 466,
#  'lines': 465,
#  'lay': 464,
#  'october': 464,
#  'savings': 464,
#  'largest': 463,
#  'true': 462,
#  'difficult': 462,
#  'c': 461,
#  'monetary': 461,
#  'heart': 460,
#  'complete': 459,
#  'gone': 458,
#  'farmers': 458,
#  'range': 458,
#  '86': 458,
#  'jan': 458,
#  'particularly': 457,
#  'former': 457,
#  'contract': 457,
#  'therefore': 454,
#  'trying': 454,
#  'fixed': 454,
#  '70': 454,
#  '34': 454,
#  'hours': 453,
#  'expect': 453,
#  'beyond': 452,
#  'similar': 452,
#  'sense': 452,
#  'product': 452,
#  'import': 452,
#  '33': 452,
#  'member': 451,
#  'sound': 451,
#  'seems': 451,
#  'orders': 451,
#  'ask': 451,
#  'commercial': 451,
#  'accord': 451,
#  'consumer': 451,
#  'ready': 450,
#  'trust': 449,
#  'considered': 449,
#  'ten': 448,
#  'barrels': 447,
#  'single': 446,
#  'executive': 446,
#  'sure': 445,
#  'horse': 445,
#  'prime': 445,
#  'outside': 444,
#  'forward': 444,
#  'nation': 444,
#  '1988': 444,
#  'sonya': 443,
#  'n': 443,
#  'addition': 442,
#  'officers': 442,
#  'rising': 442,
#  'property': 442,
#  'worth': 441,
#  'hope': 439,
#  'required': 438,
#  'started': 436,
#  'feel': 436,
#  'revenues': 436,
#  'extraordinary': 435,
#  'raise': 434,
#  'commerce': 434,
#  'forces': 434,
#  'pact': 434,
#  'tried': 433,
#  'feb': 433,
#  'daily': 431,
#  'society': 430,
#  'leading': 429,
#  'equipment': 429,
#  'francs': 428,
#  'formed': 427,
#  'reagan': 427,
#  'instead': 426,
#  'consider': 426,
#  'attention': 425,
#  'peace': 424,
#  'units': 422,
#  'produced': 421,
#  'declared': 421,
#  '90': 421,
#  'l': 421,
#  'english': 420,
#  'issued': 420,
#  'laws': 419,
#  'tomorrow': 419,
#  'denisov': 419,
#  ...}

# %% [markdown]
# After having the 'ingredients' for probability calculations, we can make the **smoothed probabilities**. For **smoothed bigrams** this is what the formula looks like (from [slide 49 and 52 by Jurafsky](https://web.stanford.edu/class/cs124/lec/languagemodeling.pdf)). The **V** is the length of the dictionary.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def smoothed_likelihood(bigram):
    """Function that takes a bigram and returns a float its smoothed likelihood"""
    global V #we will need this later
    try: 
        if bigram in bigram_count_dict: #if the bigram is in the dict
            bigram_count = bigram_count_dict[bigram] + 1 #smooth it
        else: #if not in the dict
            bigram_count = 1 #give it a count of 1
            
        word_before_count = freq_words[bigram[0]] #first word of bigram  
        V = len(no_punct_corpus) #length of dictionary
        denominator = word_before_count + V #the count plus the length
        p = bigram_count/denominator #final probability
        return p
    except KeyError as no_word: #if the prior word of the bigram is not in the corpus
        print(no_word, "of bigram", bigram, "not in corpus")

# %%
smoothed_likelihood(("hello", "you"))
# Out:
# 2.813944784775433e-07

# %%
smoothed_likelihood(("why", "you"))
# Out:
# 1.2377477042593148e-05

# %%
smoothed_likelihood(("cinderella", "is"))
# Out:
# 'cinderella' of bigram ('cinderella', 'is') not in corpus

# %% [markdown]
# Let's try the example of *acress* vs *across* given before. Indeed, the likelihood is bigger for *actress* in context, but we haven't integrated the noisy channel probability yet.

# %%
smoothed_likelihood(("talented", "actress")) * smoothed_likelihood(("actress", "whose"))
# Out:
# 7.918287479930996e-14

# %%
smoothed_likelihood(("talented", "actress")) * smoothed_likelihood(("actress", "whose"))> smoothed_likelihood(("talented", "across")) * smoothed_likelihood(("across", "whose"))
# Out:
# True

# %% [markdown]
# ### Step 7.3: Final Function
#
# Here, I develop the final function. It takes into account the **noisy channel probability** and **the smoothed bigram probabilities**. There are a lot of conditions to account for the position of the typo, the various errors that can be raised (e.g., word not in lexicon, overall_best_match empty) and finally it should give the correct sentence.

# %%
def better_spell_corrector(sentence):
    """Function that takes a sentence and corrects the typo based on surrounding context"""
    global d_sorted #for later if we want to see the rankings
    
    if len(sentence.split()) == 1: #if the sentence is just one word
        return overall_best_match(sentence) #give the best match with noisy channel model
    
    typos = spot_typos(sentence) #spot the typos 
    
    if len(typos) == 0: #if not typos
        return sentence #return sentence as is
    
    else:
        d = {}
        split_sentence = [x.lower() for x in sentence.split()] #transform sentence into list of lowercase words for handling it
        for typo_id in typos: #for each typo in the typos spotted
            try: #we need this because the overall_best_match function does not always return a best and other, sometimes it returns an error
                best_cand, all_cand = overall_best_match(typo_id) #split the overall best match into the best and the whole candidate list
                if split_sentence.index(typo_id) != 0 and split_sentence.index(typo_id) != (len(split_sentence) - 1): #if the typo has surrounding words
                    word_before = split_sentence[split_sentence.index(typo_id)-1] #take the word before the typo
                    word_after = split_sentence[split_sentence.index(typo_id)+1] #take the word after the typo
                    for cand in all_cand: #for each candidate for the typo
                        given_word_before = smoothed_likelihood((word_before, cand)) #smoothed probability of bigram of wordbefore-cand
                        given_word_after = smoothed_likelihood((cand, word_after)) #smoothed probability of bigram of cand-wordafter
                        prob = (given_word_before*given_word_after)*float(all_cand_probs_sort[cand]) #multiply by noisy channel probability
                        d[cand] = prob #populate the dictionary
                if split_sentence.index(typo_id) == 0: #if the typo is in position 0 (no word before)
                    word_after = split_sentence[1] #take the word after the typo
                    for cand in all_cand: #for each candidate for the typo
                        given_word_after = smoothed_likelihood((cand, word_after)) 
                        d[cand] = given_word_after*float(all_cand_probs_sort[cand]) #only multiply noisy channel probability by given word after, since no word before
                if split_sentence.index(typo_id) == (len(split_sentence) - 1): #if the typo is in last position (no word after)
                    word_before = split_sentence[-2] #take the word before the typo
                    for cand in all_cand: #for each candidate of the typo
                        given_word_before = smoothed_likelihood((word_before, cand)) #only multiply noisy channel probability by given word before, since no word after
                        d[cand] = given_word_before*float(all_cand_probs_sort[cand])
                
                d_sorted = {k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse = True)} #sort candidates
                best = max(d_sorted, key=d_sorted.get) #extract best
                split_sentence[split_sentence.index(typo_id)] = best #substitute typo with the best candidate
                d = {} #reset in case there are more typos
                
            except ValueError: #when the the word is not in the lexicon and so overall best match gives error
                print("\"" + typo_id + "\" has been recognised as a typo, but cannot be corrected at this time")
              
    correct_sentence = " ".join(split_sentence) #join sentence into string
    return correct_sentence

# %% [markdown]
# Let's try testing this with our example (changing *versatile* and *stellar* since they are not recognised as English words):

# %%
better_spell_corrector("the talented acress can sing")
# Out:
# 'the talented across can sing'

# %%
d_sorted
# Out:
# {'across': 5.97918941292195e-19,
#  'acres': 3.788650024566497e-20,
#  'actress': 1.8576302427918116e-20,
#  'access': 6.270967818069465e-21,
#  'caress': 1.8845571929567878e-21}

# %% [markdown]
# Not what expected... It seems that the probability of mistyping *across* as *acress* is still higher than the probability of mistyping *actress* as *acress* in this context, even though the resulting sentence in ungrammatical. this is probably because *across* has just a way too high score in the **noisy channel probability**, as well as very high **incidence** in the corpus. This also explains why *acres* is in second position: probably more high frequency than *actress* in our corpus. Okay, so clear **limitation**. There should be a way to make the **context probability** weight more in certain cases (like these), but I haven't figured out how to yet...
#
# Let's try another example:

# %%
better_spell_corrector("many acress of land")
# Out:
# 'many acres of land'

# %%
d_sorted
# Out:
# {'acres': 8.065339933303228e-18,
#  'across': 5.975866616197946e-19,
#  'access': 5.640734584998829e-20,
#  'actress': 6.188659691980102e-21,
#  'caress': 1.8835098937269916e-21}

# %% [markdown]
# When the context clearly disambiguates, like above, *acres* wins.
#
# Let's try other examples and tricky cases:

# %%
better_spell_corrector("he had a long berd")
# Out:
# 'he had a long beard'

# %%
better_spell_corrector("thev flower isd blooming")
# Out:
# 'the flower is blooming'

# %%
better_spell_corrector("the eletcrical powr is shut down")
# Out:
# 'the electrical power is shut down'

# %% [markdown]
# This is a good example of how the **better spell corrector** is indeed **better** (*wander* vs *wonder*):

# %%
better_spell_corrector("i was wndering hw you were")
# Out:
# 'i was wondering how you were'

# %%
correct_typos("i was wndering hw you were")
# Out:
# 'i was wandering how you were'

# %% [markdown]
# When one of the typos does not have its corresponding candidates in the dictionary, it still corrects the others

# %%
better_spell_corrector("cindrella is wearing an amzing dress")
# Out:
# "cindrella" has been recognised as a typo, but cannot be corrected at this time
# 'cindrella is wearing an amazing dress'

# %% [markdown]
# 3. When the sentence is already (probably) correct

# %%
better_spell_corrector("the talented actress can sing")
# Out:
# 'the talented actress can sing'

# %% [markdown]
# I made a user version, too:

# %%
def better_spell_corrector_user():
    """Function that takes user input and gives a correction of the sentence"""
    sentence = input("you typed this: ")
    return better_spell_corrector(sentence)

# %%
better_spell_corrector_user()
# Out:
# you typed this: i am abslutely xhausted
# 'i am absolutely exhausted'

# %%
better_spell_corrector_user()
# Out:
# you typed this: i had to dea with a lot of errors
# 'i had to deal with a lot of error'

# %%
better_spell_corrector_user()
# Out:
# you typed this: is my typo corrector god or bad?
# "corrector" has been recognised as a typo, but cannot be corrected at this time
# "?" has been recognised as a typo, but cannot be corrected at this time
# 'is my type corrector god or bad?'

# %%
better_spell_corrector_user()
# Out:
# you typed this: hllo how ar you
# 'hello how ar you'

# %% [markdown]
# Not always super great... Let's evaluate.

# %% [markdown]
# ## Step 8. Evaluation and conclusion
#
# While this spelling corrector took me a lot of effort and I tried to account for a lot of factors (I am impressed by early programmers who had to figure this out all by themselves), clearly there are still big limitations.
#
# ### Step 8.1: Problems
#
# - It doesn't correct when there is a space/lack of space

# %%
better_spell_corrector("it cannot kn ow that kn_ow is know")
# Out:
# "kn_ow" has been recognised as a typo, but cannot be corrected at this time
# 'it cannot in of that kn_ow is know'

# %% [markdown]
# - It is a bit of a problem when it comes to **lowercase/uppercase** and **punctation**.
#
# The bigram model deletes punctuation and so there is no way for the spell corrector to know that something should be uppercase after a dot, for instance. In order to account for that, there should be a condition that tells you that if the prior word is a dot in the bigram, then the word should be uppercase.
#
# Additionally, the spell corrector takes the dot as a typo, although that is not very problematic, since it just leaves it there.

# %%
better_spell_corrector("it cannot know this. i should be big")
# Out:
# "." has been recognised as a typo, but cannot be corrected at this time
# 'it cannot know this. i should be big'

# %% [markdown]
# - When a word is not in the corpus (e.g., low frequency), but it is the correct candidate, it will not be given --> maybe smoothing would have helped here, too. This is what I had mentioned already.

# %%
better_spell_corrector("the xylphone is a nice instrument")
# Out:
# "xylphone" has been recognised as a typo, but cannot be corrected at this time
# 'the xylphone is a nice instrument'

# %% [markdown]
# - Does not take into account tokenization problems.

# %%
better_spell_corrector("does not understand that this i sjust a problem of adding a letter of one word to the beginning of the next word")
# Out:
# 'does not understand that this i just a problem of adding a letter of one word to the beginning of the next word'

# %% [markdown]
# - Does not take into account homophones. Some mistakes are due to phonetic similarity, such as writing *fone* instead of *phone*

# %%
better_spell_corrector("i called with my fone")
# Out:
# 'i called with my one'

# %% [markdown]
# - Does not deal well with something mispelled as a real-word. Sometimes, a word is an English word, but the meant word is still another one... My spell corrector does not do well with that.

# %%
better_spell_corrector("He flower is red. He should be the!")
# Out:
# "." has been recognised as a typo, but cannot be corrected at this time
# "!" has been recognised as a typo, but cannot be corrected at this time
# 'he flower is red. he should be the!'

# %% [markdown]
# - Finally, my spell corrector does not take into account semantics or agreement. For instance, correcting a singular verb to a plural verb if the noun is plural.

# %%
better_spell_corrector("the mice is grey")
# Out:
# 'the mice is grey'

# %% [markdown]
# ### Step 8.2: Short coda
#
# To some extent, my spelling corrector managed to improve when I added context, which was already amazing. Of course, as seen above, many exceptions are not captured, but it does a fair job at correcting simple examples, especially when words are high-frequency and/or when the bigrams are present in the bigrams corpora. Thus, usage of big corpora is essential to such tasks.
#
# This project proved to be a great exercise to understand even further the complexity of language and how much we, as humans, have to deal with, and therefore how incredibly hard it is to transfer this knowledge to computers.
#
# At the beginning of the report, I said that my spelling corrector should be able to do this:
#
# *\"I **walke** to the **suprmarket** **tody**\"* --> *\"I **walked** to the **supermarket** **today**\"*

# %%
better_spell_corrector_user()
# Out:
# you typed this: I walke to the suprmarket tody
# 'i walked to the supermarket today'

# %% [markdown]
# And it does!

# %% [markdown]
# ## Resources used

# %% [markdown]
# In order to develop my program, I followed several sources:
# - the [original article](https://www.aclweb.org/anthology/C90-2036.pdf) by Kernighan, Church and Gale (1990)
# - [this chapter on spelling corrections](https://web.stanford.edu/~jurafsky/slp3/B.pdf) and [this chapter on n-gram models](https://web.stanford.edu/~jurafsky/slp3/3.pdf) from the *Speech and Language Processing* book by Jurafsky and Martin (2020)
# - [these slides on language modeling](https://web.stanford.edu/~jurafsky/slp3/slides/LM_4.pdf) and [these slides on spelling corrections](https://web.stanford.edu/class/cs124/lec/spelling.pdf) by Jurafsky
# - [this chapter on spelling correction](http://norvig.com/ngrams/ch14.pdf) by Norvig in the *Beautiful Data* book (Segaran and Hammerbacher, 2009)
# - [this guide on how to write a spelling corrector](http://norvig.com/spell-correct.html) by Norvig
# - the [big.txt corpus](http://norvig.com/big.txt) and the [spell-errors.txt corpus](http://norvig.com/ngrams/spell-errors.txt) as my training set, both kindly provided by Norvig [here](http://norvig.com/ngrams/))
# - [this video on spelling correctors](https://www.youtube.com/watch?v=Ue17s4KL8lw&ab_channel=ArtificialIntelligence-AllinOne) and [this video on Laplace smoothing](https://www.youtube.com/watch?v=ebeGh8HM4Jo&ab_channel=Andr%C3%A9RibeiroMiranda) by André Ribeiro Miranda
# - [these slides on Laplace smoothing](https://web.stanford.edu/class/cs276/handouts/spell_correction.ppt) by Christopher Manning and Pandu Nayak
# - [the typo corpus by Birkbeck](https://www.dcs.bbk.ac.uk/~ROGER/missp.dat) as my test set.
#
# ... And, of course, [Stack Overflow](https://stackoverflow.com/) for my infinite questions, problems and bugs.
